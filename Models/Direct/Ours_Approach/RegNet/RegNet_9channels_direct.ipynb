# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp /content/gdrive/MyDrive/dl_project/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("2+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149910.jpg', 'frame_150128.jpg', 'fram...      1
# 1      ('frame_149935.jpg', 'frame_149924.jpg', 'fram...      2
# 2      ('frame_149931.jpg', 'frame_149915.jpg', 'fram...      2
# 3      ('frame_149949.jpg', 'frame_149922.jpg', 'fram...      2
# 4      ('frame_149941.jpg', 'frame_150459.jpg', 'fram...      3
# ...                                                  ...    ...
# 18078  ('frame_174612.jpg', 'frame_174586.jpg', 'fram...      2
# 18079  ('frame_174574.jpg', 'frame_180855.jpg', 'fram...      1
# 18080  ('frame_174580.jpg', 'frame_174634.jpg', 'fram...      0
# 18081  ('frame_174619.jpg', 'frame_181123.jpg', 'fram...      3
# 18082  ('frame_174585.jpg', 'frame_174623.jpg', 'fram...      0
#
# [18083 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            images.extend(img)
        x = torch.stack(images)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([9, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
batch_size = 128

# training data
train_set = MyDataSet(train_data)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding,num_classes))


    def forward(self, x):
      out = self.cnn(x)
      out = self.mlp(out)
      return out

# %%
numEpochs = 100
in_features = 9 # TODO: change RGB channels according to num of frames
embedding = 512

learningRate = 0.1
weightDecay = 1e-4

num_classes = 6

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_classes)
#network.load_state_dict(torch.load("model_checkpoints/resnet34/lr_0.1-2/model_2.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_2+1/best_model_" + str(epoch) + ".pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 0	Batch: 50	Avg-Loss: 4.1997	Training Accuracy : 0.2055
# Epoch: 0	Batch: 100	Avg-Loss: 1.8722	Training Accuracy : 0.2431
# Epoch: 0	Batch: 150	Avg-Loss: 1.6113	Training Accuracy : 0.2723
# Epoch: 0	Batch: 200	Avg-Loss: 1.4047	Training Accuracy : 0.3281
# Epoch: 0	Batch: 250	Avg-Loss: 1.1958	Training Accuracy : 0.4066
# Epoch: 0	Batch: 300	Avg-Loss: 0.9690	Training Accuracy : 0.4630
# Epoch: 0	Batch: 350	Avg-Loss: 0.8695	Training Accuracy : 0.4797
# Epoch: 0	Batch: 400	Avg-Loss: 0.9055	Training Accuracy : 0.4877
# Epoch: 0	Batch: 450	Avg-Loss: 0.8615	Training Accuracy : 0.4894
# Epoch: 0	Batch: 500	Avg-Loss: 0.8544	Training Accuracy : 0.4773
# Epoch: 0	Batch: 550	Avg-Loss: 0.8318	Training Accuracy : 0.4878
# Epoch: 0	Batch: 600	Avg-Loss: 0.8250	Training Accuracy : 0.4859
# Epoch: 0	Batch: 650	Avg-Loss: 0.8140	Training Accuracy : 0.4816
# Epoch: 0, Validation Loss: 0.806, Validation Accuracy: 0.486
# Epoch: 1	Batch: 50	Avg-Loss: 0.8223	Training Accuracy : 0.4836
# Epoch: 1	Batch: 100	Avg-Loss: 0.8216	Training Accuracy : 0.4834
# Epoch: 1	Batch: 150	Avg-Loss: 0.8143	Training Accuracy : 0.4823
# Epoch: 1	Batch: 200	Avg-Loss: 0.8196	Training Accuracy : 0.4947
# Epoch: 1	Batch: 250	Avg-Loss: 0.8113	Training Accuracy : 0.4850
# Epoch: 1	Batch: 300	Avg-Loss: 0.7958	Training Accuracy : 0.4798
# Epoch: 1	Batch: 350	Avg-Loss: 0.7948	Training Accuracy : 0.4944
# Epoch: 1	Batch: 400	Avg-Loss: 0.8016	Training Accuracy : 0.4913
# Epoch: 1	Batch: 450	Avg-Loss: 0.8101	Training Accuracy : 0.4905
# Epoch: 1	Batch: 500	Avg-Loss: 0.8019	Training Accuracy : 0.4853
# Epoch: 1	Batch: 550	Avg-Loss: 0.8115	Training Accuracy : 0.4698
# Epoch: 1	Batch: 600	Avg-Loss: 0.8006	Training Accuracy : 0.4756
# Epoch: 1	Batch: 650	Avg-Loss: 0.7976	Training Accuracy : 0.4811
# Epoch: 1, Validation Loss: 0.782, Validation Accuracy: 0.488
# Epoch: 2	Batch: 50	Avg-Loss: 0.7808	Training Accuracy : 0.4853
# Epoch: 2	Batch: 100	Avg-Loss: 0.8036	Training Accuracy : 0.4805
# Epoch: 2	Batch: 150	Avg-Loss: 0.7965	Training Accuracy : 0.4852
# Epoch: 2	Batch: 200	Avg-Loss: 0.8167	Training Accuracy : 0.4842
# Epoch: 2	Batch: 250	Avg-Loss: 0.8056	Training Accuracy : 0.4817
# Epoch: 2	Batch: 300	Avg-Loss: 0.7999	Training Accuracy : 0.4831
# Epoch: 2	Batch: 350	Avg-Loss: 0.7918	Training Accuracy : 0.4833
# Epoch: 2	Batch: 400	Avg-Loss: 0.7987	Training Accuracy : 0.4834
# Epoch: 2	Batch: 450	Avg-Loss: 0.7988	Training Accuracy : 0.4742
# Epoch: 2	Batch: 500	Avg-Loss: 0.8099	Training Accuracy : 0.4744
# Epoch: 2	Batch: 550	Avg-Loss: 0.7867	Training Accuracy : 0.4856
# Epoch: 2	Batch: 600	Avg-Loss: 0.7861	Training Accuracy : 0.4844
# Epoch: 2	Batch: 650	Avg-Loss: 0.7890	Training Accuracy : 0.4836
# Epoch: 2, Validation Loss: 0.782, Validation Accuracy: 0.481
# Epoch: 3	Batch: 50	Avg-Loss: 0.8023	Training Accuracy : 0.4766
# Epoch: 3	Batch: 100	Avg-Loss: 0.7862	Training Accuracy : 0.4955
# Epoch: 3	Batch: 150	Avg-Loss: 0.7999	Training Accuracy : 0.5012
# Epoch: 3	Batch: 200	Avg-Loss: 0.7875	Training Accuracy : 0.4848
# Epoch: 3	Batch: 250	Avg-Loss: 0.7933	Training Accuracy : 0.4877
# Epoch: 3	Batch: 300	Avg-Loss: 0.7901	Training Accuracy : 0.4752
# Epoch: 3	Batch: 350	Avg-Loss: 0.7826	Training Accuracy : 0.4783
# Epoch: 3	Batch: 400	Avg-Loss: 0.7880	Training Accuracy : 0.4817
# Epoch: 3	Batch: 450	Avg-Loss: 0.7870	Training Accuracy : 0.4819
# Epoch: 3	Batch: 500	Avg-Loss: 0.7844	Training Accuracy : 0.4766
# Epoch: 3	Batch: 550	Avg-Loss: 0.7916	Training Accuracy : 0.4819
# Epoch: 3	Batch: 600	Avg-Loss: 0.7812	Training Accuracy : 0.4781
# Epoch: 3	Batch: 650	Avg-Loss: 0.7947	Training Accuracy : 0.4891
# Epoch: 3, Validation Loss: 0.791, Validation Accuracy: 0.488
# Epoch: 4	Batch: 50	Avg-Loss: 0.8005	Training Accuracy : 0.4942
# Epoch: 4	Batch: 100	Avg-Loss: 0.7912	Training Accuracy : 0.4861
# Epoch: 4	Batch: 150	Avg-Loss: 0.7826	Training Accuracy : 0.4788
# Epoch: 4	Batch: 200	Avg-Loss: 0.7843	Training Accuracy : 0.4794
# Epoch: 4	Batch: 250	Avg-Loss: 0.7886	Training Accuracy : 0.4942
# Epoch: 4	Batch: 300	Avg-Loss: 0.7936	Training Accuracy : 0.4798
# Epoch: 4	Batch: 350	Avg-Loss: 0.7880	Training Accuracy : 0.4873
# Epoch: 4	Batch: 400	Avg-Loss: 0.7807	Training Accuracy : 0.4845
# Epoch: 4	Batch: 450	Avg-Loss: 0.7752	Training Accuracy : 0.4948
# Epoch: 4	Batch: 500	Avg-Loss: 0.7864	Training Accuracy : 0.4798
# Epoch: 4	Batch: 550	Avg-Loss: 0.7896	Training Accuracy : 0.4911
# Epoch: 4	Batch: 600	Avg-Loss: 0.7796	Training Accuracy : 0.4873
# Epoch: 4	Batch: 650	Avg-Loss: 0.7795	Training Accuracy : 0.4806
# Epoch: 4, Validation Loss: 0.775, Validation Accuracy: 0.485
# Epoch: 5	Batch: 50	Avg-Loss: 0.7855	Training Accuracy : 0.4902
# Epoch: 5	Batch: 100	Avg-Loss: 0.7777	Training Accuracy : 0.4784
# Epoch: 5	Batch: 150	Avg-Loss: 0.7936	Training Accuracy : 0.4820
# Epoch: 5	Batch: 200	Avg-Loss: 0.7966	Training Accuracy : 0.4798
# Epoch: 5	Batch: 250	Avg-Loss: 0.7873	Training Accuracy : 0.4845
# Epoch: 5	Batch: 300	Avg-Loss: 0.7890	Training Accuracy : 0.4884
# Epoch: 5	Batch: 350	Avg-Loss: 0.7747	Training Accuracy : 0.4852
# Epoch: 5	Batch: 400	Avg-Loss: 0.7777	Training Accuracy : 0.4880
# Epoch: 5	Batch: 450	Avg-Loss: 0.7875	Training Accuracy : 0.4830
# Epoch: 5	Batch: 500	Avg-Loss: 0.7787	Training Accuracy : 0.4806
# Epoch: 5	Batch: 550	Avg-Loss: 0.7826	Training Accuracy : 0.4900
# Epoch: 5	Batch: 600	Avg-Loss: 0.7790	Training Accuracy : 0.4794
# Epoch: 5	Batch: 650	Avg-Loss: 0.7792	Training Accuracy : 0.4769
# Epoch: 5, Validation Loss: 0.771, Validation Accuracy: 0.489
# Epoch: 6	Batch: 50	Avg-Loss: 0.7694	Training Accuracy : 0.4877
# Epoch: 6	Batch: 100	Avg-Loss: 0.7884	Training Accuracy : 0.4872
# Epoch: 6	Batch: 150	Avg-Loss: 0.7724	Training Accuracy : 0.4839
# Epoch: 6	Batch: 200	Avg-Loss: 0.7775	Training Accuracy : 0.4775
# Epoch: 6	Batch: 250	Avg-Loss: 0.7807	Training Accuracy : 0.4942
# Epoch: 6	Batch: 300	Avg-Loss: 0.7837	Training Accuracy : 0.4886
# Epoch: 6	Batch: 350	Avg-Loss: 0.7886	Training Accuracy : 0.4897
# Epoch: 6	Batch: 400	Avg-Loss: 0.7860	Training Accuracy : 0.4809
# Epoch: 6	Batch: 450	Avg-Loss: 0.7798	Training Accuracy : 0.4908
# Epoch: 6	Batch: 500	Avg-Loss: 0.7874	Training Accuracy : 0.4781
# Epoch: 6	Batch: 550	Avg-Loss: 0.7789	Training Accuracy : 0.4864
# Epoch: 6	Batch: 600	Avg-Loss: 0.7891	Training Accuracy : 0.4858
# Epoch: 6	Batch: 650	Avg-Loss: 0.7841	Training Accuracy : 0.4745
# Epoch: 6, Validation Loss: 0.773, Validation Accuracy: 0.487
# Epoch: 7	Batch: 50	Avg-Loss: 0.7772	Training Accuracy : 0.4913
# Epoch: 7	Batch: 100	Avg-Loss: 0.7795	Training Accuracy : 0.4948
# Epoch: 7	Batch: 150	Avg-Loss: 0.7821	Training Accuracy : 0.4848
# Epoch: 7	Batch: 200	Avg-Loss: 0.7798	Training Accuracy : 0.4789
# Epoch: 7	Batch: 250	Avg-Loss: 0.7807	Training Accuracy : 0.4917
# Epoch: 7	Batch: 300	Avg-Loss: 0.7755	Training Accuracy : 0.4809
# Epoch: 7	Batch: 350	Avg-Loss: 0.7794	Training Accuracy : 0.4903
# Epoch: 7	Batch: 400	Avg-Loss: 0.7646	Training Accuracy : 0.4916
# Epoch: 7	Batch: 450	Avg-Loss: 0.7907	Training Accuracy : 0.4811
# Epoch: 7	Batch: 500	Avg-Loss: 0.7734	Training Accuracy : 0.4733
# Epoch: 7	Batch: 550	Avg-Loss: 0.7717	Training Accuracy : 0.4919
# Epoch: 7	Batch: 600	Avg-Loss: 0.7788	Training Accuracy : 0.4766
# Epoch: 7	Batch: 650	Avg-Loss: 0.7759	Training Accuracy : 0.4861
# Epoch: 7, Validation Loss: 0.779, Validation Accuracy: 0.483
# Epoch: 8	Batch: 50	Avg-Loss: 0.7743	Training Accuracy : 0.4825
# Epoch: 8	Batch: 100	Avg-Loss: 0.7830	Training Accuracy : 0.4756
# Epoch: 8	Batch: 150	Avg-Loss: 0.7830	Training Accuracy : 0.4938
# Epoch: 8	Batch: 200	Avg-Loss: 0.7649	Training Accuracy : 0.4877
# Epoch: 8	Batch: 250	Avg-Loss: 0.7777	Training Accuracy : 0.4850
# Epoch: 8	Batch: 300	Avg-Loss: 0.7710	Training Accuracy : 0.4936
# Epoch: 8	Batch: 350	Avg-Loss: 0.7749	Training Accuracy : 0.4897
# Epoch: 8	Batch: 400	Avg-Loss: 0.7755	Training Accuracy : 0.4848
# Epoch: 8	Batch: 450	Avg-Loss: 0.7714	Training Accuracy : 0.4808
# Epoch: 8	Batch: 500	Avg-Loss: 0.7637	Training Accuracy : 0.4905
# Epoch: 8	Batch: 550	Avg-Loss: 0.7826	Training Accuracy : 0.4936
# Epoch: 8	Batch: 600	Avg-Loss: 0.7679	Training Accuracy : 0.4777
# Epoch: 8	Batch: 650	Avg-Loss: 0.7706	Training Accuracy : 0.4842
# Epoch     9: reducing learning rate of group 0 to 5.0000e-02.
# Epoch: 8, Validation Loss: 0.778, Validation Accuracy: 0.488
# Epoch: 9	Batch: 50	Avg-Loss: 0.7573	Training Accuracy : 0.4963
# Epoch: 9	Batch: 100	Avg-Loss: 0.7638	Training Accuracy : 0.4720
# Epoch: 9	Batch: 150	Avg-Loss: 0.7614	Training Accuracy : 0.4850
# Epoch: 9	Batch: 200	Avg-Loss: 0.7643	Training Accuracy : 0.4859
# Epoch: 9	Batch: 250	Avg-Loss: 0.7605	Training Accuracy : 0.4863
# Epoch: 9	Batch: 300	Avg-Loss: 0.7612	Training Accuracy : 0.4872
# Epoch: 9	Batch: 350	Avg-Loss: 0.7666	Training Accuracy : 0.4917
# Epoch: 9	Batch: 400	Avg-Loss: 0.7578	Training Accuracy : 0.4970
# Epoch: 9	Batch: 450	Avg-Loss: 0.7579	Training Accuracy : 0.4848
# Epoch: 9	Batch: 500	Avg-Loss: 0.7640	Training Accuracy : 0.4895
# Epoch: 9	Batch: 550	Avg-Loss: 0.7570	Training Accuracy : 0.4888
# Epoch: 9	Batch: 600	Avg-Loss: 0.7677	Training Accuracy : 0.4945
# Epoch: 9	Batch: 650	Avg-Loss: 0.7613	Training Accuracy : 0.4952
# Epoch: 9, Validation Loss: 0.768, Validation Accuracy: 0.481
# Epoch: 10	Batch: 50	Avg-Loss: 0.7579	Training Accuracy : 0.4853
# Epoch: 10	Batch: 100	Avg-Loss: 0.7653	Training Accuracy : 0.4819
# Epoch: 10	Batch: 150	Avg-Loss: 0.7642	Training Accuracy : 0.4930
# Epoch: 10	Batch: 200	Avg-Loss: 0.7579	Training Accuracy : 0.4855
# Epoch: 10	Batch: 250	Avg-Loss: 0.7621	Training Accuracy : 0.4873
# Epoch: 10	Batch: 300	Avg-Loss: 0.7568	Training Accuracy : 0.4958
# Epoch: 10	Batch: 350	Avg-Loss: 0.7572	Training Accuracy : 0.4994
# Epoch: 10	Batch: 400	Avg-Loss: 0.7570	Training Accuracy : 0.4986
# Epoch: 10	Batch: 450	Avg-Loss: 0.7605	Training Accuracy : 0.4850
# Epoch: 10	Batch: 500	Avg-Loss: 0.7610	Training Accuracy : 0.4869
# Epoch: 10	Batch: 550	Avg-Loss: 0.7600	Training Accuracy : 0.4916
# Epoch: 10	Batch: 600	Avg-Loss: 0.7622	Training Accuracy : 0.4938
# Epoch: 10	Batch: 650	Avg-Loss: 0.7557	Training Accuracy : 0.4850
# Epoch: 10, Validation Loss: 0.764, Validation Accuracy: 0.490
# Epoch: 11	Batch: 50	Avg-Loss: 0.7644	Training Accuracy : 0.4806
# Epoch: 11	Batch: 100	Avg-Loss: 0.7639	Training Accuracy : 0.4780
# Epoch: 11	Batch: 150	Avg-Loss: 0.7566	Training Accuracy : 0.4752
# Epoch: 11	Batch: 200	Avg-Loss: 0.7553	Training Accuracy : 0.4884
# Epoch: 11	Batch: 250	Avg-Loss: 0.7614	Training Accuracy : 0.4900
# Epoch: 11	Batch: 300	Avg-Loss: 0.7618	Training Accuracy : 0.4752
# Epoch: 11	Batch: 350	Avg-Loss: 0.7614	Training Accuracy : 0.4878
# Epoch: 11	Batch: 400	Avg-Loss: 0.7631	Training Accuracy : 0.4878
# Epoch: 11	Batch: 450	Avg-Loss: 0.7510	Training Accuracy : 0.4911
# Epoch: 11	Batch: 500	Avg-Loss: 0.7559	Training Accuracy : 0.4928
# Epoch: 11	Batch: 550	Avg-Loss: 0.7640	Training Accuracy : 0.4800
# Epoch: 11	Batch: 600	Avg-Loss: 0.7675	Training Accuracy : 0.4869
# Epoch: 11	Batch: 650	Avg-Loss: 0.7632	Training Accuracy : 0.4798
# Epoch: 11, Validation Loss: 0.766, Validation Accuracy: 0.490
# Epoch: 12	Batch: 50	Avg-Loss: 0.7605	Training Accuracy : 0.4925
# Epoch: 12	Batch: 100	Avg-Loss: 0.7606	Training Accuracy : 0.4856
# Epoch: 12	Batch: 150	Avg-Loss: 0.7560	Training Accuracy : 0.4914
# Epoch: 12	Batch: 200	Avg-Loss: 0.7559	Training Accuracy : 0.5056
# Epoch: 12	Batch: 250	Avg-Loss: 0.7517	Training Accuracy : 0.4895
# Epoch: 12	Batch: 300	Avg-Loss: 0.7556	Training Accuracy : 0.4923
# Epoch: 12	Batch: 350	Avg-Loss: 0.7634	Training Accuracy : 0.4934
# Epoch: 12	Batch: 400	Avg-Loss: 0.7623	Training Accuracy : 0.4859
# Epoch: 12	Batch: 450	Avg-Loss: 0.7626	Training Accuracy : 0.4866
# Epoch: 12	Batch: 500	Avg-Loss: 0.7595	Training Accuracy : 0.4861
# Epoch: 12	Batch: 550	Avg-Loss: 0.7546	Training Accuracy : 0.4984
# Epoch: 12	Batch: 600	Avg-Loss: 0.7569	Training Accuracy : 0.4934
# Epoch: 12	Batch: 650	Avg-Loss: 0.7635	Training Accuracy : 0.4820
# Epoch: 12, Validation Loss: 0.780, Validation Accuracy: 0.483
# Epoch: 13	Batch: 50	Avg-Loss: 0.7634	Training Accuracy : 0.5006
# Epoch: 13	Batch: 100	Avg-Loss: 0.7629	Training Accuracy : 0.4895
# Epoch: 13	Batch: 150	Avg-Loss: 0.7546	Training Accuracy : 0.4858
# Epoch: 13	Batch: 200	Avg-Loss: 0.7657	Training Accuracy : 0.4869
# Epoch: 13	Batch: 250	Avg-Loss: 0.7563	Training Accuracy : 0.4883
# Epoch: 13	Batch: 300	Avg-Loss: 0.7570	Training Accuracy : 0.4870
# Epoch: 13	Batch: 350	Avg-Loss: 0.7559	Training Accuracy : 0.4919
# Epoch: 13	Batch: 400	Avg-Loss: 0.7534	Training Accuracy : 0.4847
# Epoch: 13	Batch: 450	Avg-Loss: 0.7548	Training Accuracy : 0.4967
# Epoch: 13	Batch: 500	Avg-Loss: 0.7606	Training Accuracy : 0.4775
# Epoch: 13	Batch: 550	Avg-Loss: 0.7521	Training Accuracy : 0.4933
# Epoch: 13	Batch: 600	Avg-Loss: 0.7538	Training Accuracy : 0.4816
# Epoch: 13	Batch: 650	Avg-Loss: 0.7593	Training Accuracy : 0.4902
# Epoch    14: reducing learning rate of group 0 to 2.5000e-02.
# Epoch: 13, Validation Loss: 0.775, Validation Accuracy: 0.489
# Epoch: 14	Batch: 50	Avg-Loss: 0.7467	Training Accuracy : 0.4817
# Epoch: 14	Batch: 100	Avg-Loss: 0.7558	Training Accuracy : 0.4791
# Epoch: 14	Batch: 150	Avg-Loss: 0.7532	Training Accuracy : 0.4955
# Epoch: 14	Batch: 200	Avg-Loss: 0.7463	Training Accuracy : 0.4894
# Epoch: 14	Batch: 250	Avg-Loss: 0.7568	Training Accuracy : 0.4844
# Epoch: 14	Batch: 300	Avg-Loss: 0.7511	Training Accuracy : 0.4858
# Epoch: 14	Batch: 350	Avg-Loss: 0.7415	Training Accuracy : 0.4983
# Epoch: 14	Batch: 400	Avg-Loss: 0.7471	Training Accuracy : 0.4972
# Epoch: 14	Batch: 450	Avg-Loss: 0.7553	Training Accuracy : 0.4889
# Epoch: 14	Batch: 500	Avg-Loss: 0.7526	Training Accuracy : 0.4878
# Epoch: 14	Batch: 550	Avg-Loss: 0.7539	Training Accuracy : 0.4897
# Epoch: 14	Batch: 600	Avg-Loss: 0.7563	Training Accuracy : 0.4816
# Epoch: 14	Batch: 650	Avg-Loss: 0.7496	Training Accuracy : 0.4830
# Epoch: 14, Validation Loss: 0.771, Validation Accuracy: 0.490
# Epoch: 15	Batch: 50	Avg-Loss: 0.7528	Training Accuracy : 0.4950
# Epoch: 15	Batch: 100	Avg-Loss: 0.7454	Training Accuracy : 0.4992
# Epoch: 15	Batch: 150	Avg-Loss: 0.7504	Training Accuracy : 0.4911
# Epoch: 15	Batch: 200	Avg-Loss: 0.7487	Training Accuracy : 0.4928
# Epoch: 15	Batch: 250	Avg-Loss: 0.7497	Training Accuracy : 0.4963
# Epoch: 15	Batch: 300	Avg-Loss: 0.7477	Training Accuracy : 0.4791
# Epoch: 15	Batch: 350	Avg-Loss: 0.7563	Training Accuracy : 0.4778
# Epoch: 15	Batch: 400	Avg-Loss: 0.7522	Training Accuracy : 0.4984
# Epoch: 15	Batch: 450	Avg-Loss: 0.7520	Training Accuracy : 0.4875
# Epoch: 15	Batch: 500	Avg-Loss: 0.7508	Training Accuracy : 0.4944
# Epoch: 15	Batch: 550	Avg-Loss: 0.7558	Training Accuracy : 0.4933
# Epoch: 15	Batch: 600	Avg-Loss: 0.7482	Training Accuracy : 0.4953
# Epoch: 15	Batch: 650	Avg-Loss: 0.7424	Training Accuracy : 0.4959
# Epoch: 15, Validation Loss: 0.770, Validation Accuracy: 0.490
# Epoch: 16	Batch: 50	Avg-Loss: 0.7403	Training Accuracy : 0.4902
# Epoch: 16	Batch: 100	Avg-Loss: 0.7472	Training Accuracy : 0.4953
# Epoch: 16	Batch: 150	Avg-Loss: 0.7472	Training Accuracy : 0.4852
# Epoch: 16	Batch: 200	Avg-Loss: 0.7491	Training Accuracy : 0.4923
# Epoch: 16	Batch: 250	Avg-Loss: 0.7490	Training Accuracy : 0.4886
# Epoch: 16	Batch: 300	Avg-Loss: 0.7481	Training Accuracy : 0.4830
# Epoch: 16	Batch: 350	Avg-Loss: 0.7468	Training Accuracy : 0.4852
# Epoch: 16	Batch: 400	Avg-Loss: 0.7500	Training Accuracy : 0.4823
# Epoch: 16	Batch: 450	Avg-Loss: 0.7454	Training Accuracy : 0.4947
# Epoch: 16	Batch: 500	Avg-Loss: 0.7518	Training Accuracy : 0.4923
# Epoch: 16	Batch: 550	Avg-Loss: 0.7476	Training Accuracy : 0.4884
# Epoch: 16	Batch: 600	Avg-Loss: 0.7531	Training Accuracy : 0.4872
# Epoch: 16	Batch: 650	Avg-Loss: 0.7520	Training Accuracy : 0.4916
# Epoch    17: reducing learning rate of group 0 to 1.2500e-02.
# Epoch: 16, Validation Loss: 0.768, Validation Accuracy: 0.492
# Epoch: 17	Batch: 50	Avg-Loss: 0.7481	Training Accuracy : 0.4961
# Epoch: 17	Batch: 100	Avg-Loss: 0.7415	Training Accuracy : 0.4917
# Epoch: 17	Batch: 150	Avg-Loss: 0.7454	Training Accuracy : 0.4928
# Epoch: 17	Batch: 200	Avg-Loss: 0.7419	Training Accuracy : 0.5003
# Epoch: 17	Batch: 250	Avg-Loss: 0.7420	Training Accuracy : 0.4858
# Epoch: 17	Batch: 300	Avg-Loss: 0.7396	Training Accuracy : 0.4970
# Epoch: 17	Batch: 350	Avg-Loss: 0.7441	Training Accuracy : 0.5008
# Epoch: 17	Batch: 400	Avg-Loss: 0.7433	Training Accuracy : 0.5052
# Epoch: 17	Batch: 450	Avg-Loss: 0.7403	Training Accuracy : 0.4897
# Epoch: 17	Batch: 500	Avg-Loss: 0.7472	Training Accuracy : 0.5011
# Epoch: 17	Batch: 550	Avg-Loss: 0.7466	Training Accuracy : 0.4811
# Epoch: 17	Batch: 600	Avg-Loss: 0.7455	Training Accuracy : 0.4945
# Epoch: 17	Batch: 650	Avg-Loss: 0.7467	Training Accuracy : 0.4913
# Epoch: 17, Validation Loss: 0.771, Validation Accuracy: 0.485
# Epoch: 18	Batch: 50	Avg-Loss: 0.7424	Training Accuracy : 0.4956
# Epoch: 18	Batch: 100	Avg-Loss: 0.7410	Training Accuracy : 0.4864
# Epoch: 18	Batch: 150	Avg-Loss: 0.7400	Training Accuracy : 0.5012
# Epoch: 18	Batch: 200	Avg-Loss: 0.7432	Training Accuracy : 0.4873
# Epoch: 18	Batch: 250	Avg-Loss: 0.7363	Training Accuracy : 0.4886
# Epoch: 18	Batch: 300	Avg-Loss: 0.7423	Training Accuracy : 0.4969
# Epoch: 18	Batch: 350	Avg-Loss: 0.7410	Training Accuracy : 0.4942
# Epoch: 18	Batch: 400	Avg-Loss: 0.7431	Training Accuracy : 0.4903
# Epoch: 18	Batch: 450	Avg-Loss: 0.7428	Training Accuracy : 0.4958
# Epoch: 18	Batch: 500	Avg-Loss: 0.7467	Training Accuracy : 0.4936
# Epoch: 18	Batch: 550	Avg-Loss: 0.7450	Training Accuracy : 0.4884
# Epoch: 18	Batch: 600	Avg-Loss: 0.7461	Training Accuracy : 0.4897
# Epoch: 18	Batch: 650	Avg-Loss: 0.7446	Training Accuracy : 0.4864
# Epoch: 18, Validation Loss: 0.770, Validation Accuracy: 0.488
# Epoch: 19	Batch: 50	Avg-Loss: 0.7408	Training Accuracy : 0.4989
# Epoch: 19	Batch: 100	Avg-Loss: 0.7463	Training Accuracy : 0.4930
# Epoch: 19	Batch: 150	Avg-Loss: 0.7414	Training Accuracy : 0.4958
# Epoch: 19	Batch: 200	Avg-Loss: 0.7457	Training Accuracy : 0.4948
# Epoch: 19	Batch: 250	Avg-Loss: 0.7413	Training Accuracy : 0.4781
# Epoch: 19	Batch: 300	Avg-Loss: 0.7401	Training Accuracy : 0.4955
# Epoch: 19	Batch: 350	Avg-Loss: 0.7432	Training Accuracy : 0.4969
# Epoch: 19	Batch: 400	Avg-Loss: 0.7401	Training Accuracy : 0.4916
# Epoch: 19	Batch: 450	Avg-Loss: 0.7413	Training Accuracy : 0.4927
# Epoch: 19	Batch: 500	Avg-Loss: 0.7423	Training Accuracy : 0.4958
# Epoch: 19	Batch: 550	Avg-Loss: 0.7444	Training Accuracy : 0.4928
# Epoch: 19	Batch: 600	Avg-Loss: 0.7398	Training Accuracy : 0.5045
# Epoch: 19	Batch: 650	Avg-Loss: 0.7416	Training Accuracy : 0.4827
# Epoch    20: reducing learning rate of group 0 to 6.2500e-03.
# Epoch: 19, Validation Loss: 0.769, Validation Accuracy: 0.493
# Epoch: 20	Batch: 50	Avg-Loss: 0.7366	Training Accuracy : 0.4923
# Epoch: 20	Batch: 100	Avg-Loss: 0.7391	Training Accuracy : 0.4834
# Epoch: 20	Batch: 150	Avg-Loss: 0.7410	Training Accuracy : 0.4963
# Epoch: 20	Batch: 200	Avg-Loss: 0.7346	Training Accuracy : 0.5002
# Epoch: 20	Batch: 250	Avg-Loss: 0.7377	Training Accuracy : 0.4864
# Epoch: 20	Batch: 300	Avg-Loss: 0.7382	Training Accuracy : 0.4886
# Epoch: 20	Batch: 350	Avg-Loss: 0.7405	Training Accuracy : 0.4858
# Epoch: 20	Batch: 400	Avg-Loss: 0.7402	Training Accuracy : 0.4970
# Epoch: 20	Batch: 450	Avg-Loss: 0.7377	Training Accuracy : 0.4875
# Epoch: 20	Batch: 500	Avg-Loss: 0.7351	Training Accuracy : 0.4947
# Epoch: 20	Batch: 550	Avg-Loss: 0.7374	Training Accuracy : 0.4991
# Epoch: 20	Batch: 600	Avg-Loss: 0.7357	Training Accuracy : 0.4961
# Epoch: 20	Batch: 650	Avg-Loss: 0.7423	Training Accuracy : 0.4983
# Epoch: 20, Validation Loss: 0.772, Validation Accuracy: 0.491
# Epoch: 21	Batch: 50	Avg-Loss: 0.7379	Training Accuracy : 0.4852
# Epoch: 21	Batch: 100	Avg-Loss: 0.7345	Training Accuracy : 0.4959
# Epoch: 21	Batch: 150	Avg-Loss: 0.7360	Training Accuracy : 0.5042
# Epoch: 21	Batch: 200	Avg-Loss: 0.7406	Training Accuracy : 0.4977
# Epoch: 21	Batch: 250	Avg-Loss: 0.7338	Training Accuracy : 0.4927
# Epoch: 21	Batch: 300	Avg-Loss: 0.7394	Training Accuracy : 0.4967
# Epoch: 21	Batch: 350	Avg-Loss: 0.7385	Training Accuracy : 0.4877
# Epoch: 21	Batch: 400	Avg-Loss: 0.7330	Training Accuracy : 0.4978
# Epoch: 21	Batch: 450	Avg-Loss: 0.7343	Training Accuracy : 0.5005
# Epoch: 21	Batch: 500	Avg-Loss: 0.7371	Training Accuracy : 0.4842
# Epoch: 21	Batch: 550	Avg-Loss: 0.7415	Training Accuracy : 0.4970
# Epoch: 21	Batch: 600	Avg-Loss: 0.7354	Training Accuracy : 0.4927
# Epoch: 21	Batch: 650	Avg-Loss: 0.7359	Training Accuracy : 0.4925
# Epoch: 21, Validation Loss: 0.772, Validation Accuracy: 0.488
# Epoch: 22	Batch: 50	Avg-Loss: 0.7350	Training Accuracy : 0.4991
# Epoch: 22	Batch: 100	Avg-Loss: 0.7338	Training Accuracy : 0.4963
# Epoch: 22	Batch: 150	Avg-Loss: 0.7360	Training Accuracy : 0.4984
# Epoch: 22	Batch: 200	Avg-Loss: 0.7307	Training Accuracy : 0.4970
# Epoch: 22	Batch: 250	Avg-Loss: 0.7389	Training Accuracy : 0.4998
# Epoch: 22	Batch: 300	Avg-Loss: 0.7354	Training Accuracy : 0.4975
# Epoch: 22	Batch: 350	Avg-Loss: 0.7367	Training Accuracy : 0.4933
# Epoch: 22	Batch: 400	Avg-Loss: 0.7416	Training Accuracy : 0.4908
# Epoch: 22	Batch: 450	Avg-Loss: 0.7362	Training Accuracy : 0.5002
# Epoch: 22	Batch: 500	Avg-Loss: 0.7376	Training Accuracy : 0.4994
# Epoch: 22	Batch: 550	Avg-Loss: 0.7319	Training Accuracy : 0.5022
# Epoch: 22	Batch: 600	Avg-Loss: 0.7363	Training Accuracy : 0.4894
# Epoch: 22	Batch: 650	Avg-Loss: 0.7394	Training Accuracy : 0.4944
# Epoch    23: reducing learning rate of group 0 to 3.1250e-03.
# Epoch: 22, Validation Loss: 0.772, Validation Accuracy: 0.490
# Epoch: 23	Batch: 50	Avg-Loss: 0.7382	Training Accuracy : 0.5050
# Epoch: 23	Batch: 100	Avg-Loss: 0.7302	Training Accuracy : 0.5008
# Epoch: 23	Batch: 150	Avg-Loss: 0.7330	Training Accuracy : 0.4930
# Epoch: 23	Batch: 200	Avg-Loss: 0.7309	Training Accuracy : 0.5030
# Epoch: 23	Batch: 250	Avg-Loss: 0.7376	Training Accuracy : 0.4850
# Epoch: 23	Batch: 300	Avg-Loss: 0.7297	Training Accuracy : 0.4959
# Epoch: 23	Batch: 350	Avg-Loss: 0.7283	Training Accuracy : 0.4786
# Epoch: 23	Batch: 400	Avg-Loss: 0.7315	Training Accuracy : 0.4983
# Epoch: 23	Batch: 450	Avg-Loss: 0.7326	Training Accuracy : 0.4950
# Epoch: 23	Batch: 500	Avg-Loss: 0.7367	Training Accuracy : 0.5052
# Epoch: 23	Batch: 550	Avg-Loss: 0.7355	Training Accuracy : 0.4839
# Epoch: 23	Batch: 600	Avg-Loss: 0.7340	Training Accuracy : 0.4909
# Epoch: 23	Batch: 650	Avg-Loss: 0.7361	Training Accuracy : 0.4898
# Epoch: 23, Validation Loss: 0.773, Validation Accuracy: 0.485
# Epoch: 24	Batch: 50	Avg-Loss: 0.7310	Training Accuracy : 0.5031
# Epoch: 24	Batch: 100	Avg-Loss: 0.7342	Training Accuracy : 0.4939
# Epoch: 24	Batch: 150	Avg-Loss: 0.7293	Training Accuracy : 0.4908
# Epoch: 24	Batch: 200	Avg-Loss: 0.7290	Training Accuracy : 0.4994
# Epoch: 24	Batch: 250	Avg-Loss: 0.7336	Training Accuracy : 0.4919
# Epoch: 24	Batch: 300	Avg-Loss: 0.7328	Training Accuracy : 0.4867
# Epoch: 24	Batch: 350	Avg-Loss: 0.7291	Training Accuracy : 0.4909
# Epoch: 24	Batch: 400	Avg-Loss: 0.7319	Training Accuracy : 0.5023
# Epoch: 24	Batch: 450	Avg-Loss: 0.7402	Training Accuracy : 0.4942
# Epoch: 24	Batch: 500	Avg-Loss: 0.7321	Training Accuracy : 0.4934
# Epoch: 24	Batch: 550	Avg-Loss: 0.7295	Training Accuracy : 0.4944
# Epoch: 24	Batch: 600	Avg-Loss: 0.7354	Training Accuracy : 0.4830
# Epoch: 24	Batch: 650	Avg-Loss: 0.7328	Training Accuracy : 0.4942
# Epoch: 24, Validation Loss: 0.774, Validation Accuracy: 0.491
# Epoch: 25	Batch: 50	Avg-Loss: 0.7326	Training Accuracy : 0.4916
# Epoch: 25	Batch: 100	Avg-Loss: 0.7256	Training Accuracy : 0.4983
# Epoch: 25	Batch: 150	Avg-Loss: 0.7299	Training Accuracy : 0.5044
# Epoch: 25	Batch: 200	Avg-Loss: 0.7320	Training Accuracy : 0.4908
# Epoch: 25	Batch: 250	Avg-Loss: 0.7324	Training Accuracy : 0.5098
# Epoch: 25	Batch: 300	Avg-Loss: 0.7295	Training Accuracy : 0.5050
# Epoch: 25	Batch: 350	Avg-Loss: 0.7328	Training Accuracy : 0.4944
# Epoch: 25	Batch: 400	Avg-Loss: 0.7344	Training Accuracy : 0.4933
# Epoch: 25	Batch: 450	Avg-Loss: 0.7343	Training Accuracy : 0.4977
# Epoch: 25	Batch: 500	Avg-Loss: 0.7273	Training Accuracy : 0.4894
# Epoch: 25	Batch: 550	Avg-Loss: 0.7333	Training Accuracy : 0.4970
# Epoch: 25	Batch: 600	Avg-Loss: 0.7299	Training Accuracy : 0.4911
# Epoch: 25	Batch: 650	Avg-Loss: 0.7298	Training Accuracy : 0.4967
# Epoch    26: reducing learning rate of group 0 to 1.5625e-03.
# Epoch: 25, Validation Loss: 0.777, Validation Accuracy: 0.493
# Epoch: 26	Batch: 50	Avg-Loss: 0.7288	Training Accuracy : 0.4970
# Epoch: 26	Batch: 100	Avg-Loss: 0.7299	Training Accuracy : 0.4913
# Epoch: 26	Batch: 150	Avg-Loss: 0.7229	Training Accuracy : 0.5027
# Epoch: 26	Batch: 200	Avg-Loss: 0.7288	Training Accuracy : 0.5008
# Epoch: 26	Batch: 250	Avg-Loss: 0.7293	Training Accuracy : 0.4986
# Epoch: 26	Batch: 300	Avg-Loss: 0.7257	Training Accuracy : 0.4941
# Epoch: 26	Batch: 350	Avg-Loss: 0.7295	Training Accuracy : 0.4931
# Epoch: 26	Batch: 400	Avg-Loss: 0.7267	Training Accuracy : 0.4936
# Epoch: 26	Batch: 450	Avg-Loss: 0.7274	Training Accuracy : 0.4952
# Epoch: 26	Batch: 500	Avg-Loss: 0.7346	Training Accuracy : 0.5011
# Epoch: 26	Batch: 550	Avg-Loss: 0.7347	Training Accuracy : 0.4955
# Epoch: 26	Batch: 600	Avg-Loss: 0.7291	Training Accuracy : 0.5003
# Epoch: 26	Batch: 650	Avg-Loss: 0.7292	Training Accuracy : 0.4895
# Epoch: 26, Validation Loss: 0.777, Validation Accuracy: 0.496
# Epoch: 27	Batch: 50	Avg-Loss: 0.7304	Training Accuracy : 0.4998
# Epoch: 27	Batch: 100	Avg-Loss: 0.7328	Training Accuracy : 0.4930
# Epoch: 27	Batch: 150	Avg-Loss: 0.7221	Training Accuracy : 0.4984
# Epoch: 27	Batch: 200	Avg-Loss: 0.7250	Training Accuracy : 0.5006
# Epoch: 27	Batch: 250	Avg-Loss: 0.7254	Training Accuracy : 0.5028
# Epoch: 27	Batch: 300	Avg-Loss: 0.7249	Training Accuracy : 0.5028
# Epoch: 27	Batch: 350	Avg-Loss: 0.7276	Training Accuracy : 0.4988
# Epoch: 27	Batch: 400	Avg-Loss: 0.7326	Training Accuracy : 0.5130
# Epoch: 27	Batch: 450	Avg-Loss: 0.7319	Training Accuracy : 0.4938
# Epoch: 27	Batch: 500	Avg-Loss: 0.7288	Training Accuracy : 0.4998
# Epoch: 27	Batch: 550	Avg-Loss: 0.7300	Training Accuracy : 0.4983
# Epoch: 27	Batch: 600	Avg-Loss: 0.7266	Training Accuracy : 0.4861
# Epoch: 27	Batch: 650	Avg-Loss: 0.7282	Training Accuracy : 0.4941
# Epoch: 27, Validation Loss: 0.777, Validation Accuracy: 0.488
# Epoch: 28	Batch: 50	Avg-Loss: 0.7263	Training Accuracy : 0.5028
# Epoch: 28	Batch: 100	Avg-Loss: 0.7248	Training Accuracy : 0.4944
# Epoch: 28	Batch: 150	Avg-Loss: 0.7284	Training Accuracy : 0.5008
# Epoch: 28	Batch: 200	Avg-Loss: 0.7259	Training Accuracy : 0.5011
# Epoch: 28	Batch: 250	Avg-Loss: 0.7301	Training Accuracy : 0.4969
# Epoch: 28	Batch: 300	Avg-Loss: 0.7276	Training Accuracy : 0.4873
# Epoch: 28	Batch: 350	Avg-Loss: 0.7293	Training Accuracy : 0.5005
# Epoch: 28	Batch: 400	Avg-Loss: 0.7256	Training Accuracy : 0.5030
# Epoch: 28	Batch: 450	Avg-Loss: 0.7256	Training Accuracy : 0.4888
# Epoch: 28	Batch: 500	Avg-Loss: 0.7296	Training Accuracy : 0.4888
# Epoch: 28	Batch: 550	Avg-Loss: 0.7284	Training Accuracy : 0.4866
# Epoch: 28	Batch: 600	Avg-Loss: 0.7258	Training Accuracy : 0.5067
# Epoch: 28	Batch: 650	Avg-Loss: 0.7280	Training Accuracy : 0.4977
# Epoch    29: reducing learning rate of group 0 to 7.8125e-04.
# Epoch: 28, Validation Loss: 0.780, Validation Accuracy: 0.498
# Epoch: 29	Batch: 50	Avg-Loss: 0.7219	Training Accuracy : 0.4992
# Epoch: 29	Batch: 100	Avg-Loss: 0.7241	Training Accuracy : 0.5091
# Epoch: 29	Batch: 150	Avg-Loss: 0.7234	Training Accuracy : 0.5012
# Epoch: 29	Batch: 200	Avg-Loss: 0.7244	Training Accuracy : 0.5017
# Epoch: 29	Batch: 250	Avg-Loss: 0.7224	Training Accuracy : 0.4911
# Epoch: 29	Batch: 300	Avg-Loss: 0.7262	Training Accuracy : 0.5012
# Epoch: 29	Batch: 350	Avg-Loss: 0.7294	Training Accuracy : 0.4884
# Epoch: 29	Batch: 400	Avg-Loss: 0.7254	Training Accuracy : 0.4942
# Epoch: 29	Batch: 450	Avg-Loss: 0.7303	Training Accuracy : 0.4841
# Epoch: 29	Batch: 500	Avg-Loss: 0.7260	Training Accuracy : 0.5014
# Epoch: 29	Batch: 550	Avg-Loss: 0.7261	Training Accuracy : 0.5005
# Epoch: 29	Batch: 600	Avg-Loss: 0.7285	Training Accuracy : 0.5033
# Epoch: 29	Batch: 650	Avg-Loss: 0.7258	Training Accuracy : 0.5025
# Epoch: 29, Validation Loss: 0.781, Validation Accuracy: 0.490
# Epoch: 30	Batch: 50	Avg-Loss: 0.7249	Training Accuracy : 0.5025
# Epoch: 30	Batch: 100	Avg-Loss: 0.7279	Training Accuracy : 0.5014
# Epoch: 30	Batch: 150	Avg-Loss: 0.7270	Training Accuracy : 0.5027
# Epoch: 30	Batch: 200	Avg-Loss: 0.7234	Training Accuracy : 0.5022
# Epoch: 30	Batch: 250	Avg-Loss: 0.7230	Training Accuracy : 0.4963
# Epoch: 30	Batch: 300	Avg-Loss: 0.7316	Training Accuracy : 0.4923
# Epoch: 30	Batch: 350	Avg-Loss: 0.7262	Training Accuracy : 0.4873
# Epoch: 30	Batch: 400	Avg-Loss: 0.7213	Training Accuracy : 0.4958
# Epoch: 30	Batch: 450	Avg-Loss: 0.7217	Training Accuracy : 0.5002
# Epoch: 30	Batch: 500	Avg-Loss: 0.7251	Training Accuracy : 0.5016
# Epoch: 30	Batch: 550	Avg-Loss: 0.7240	Training Accuracy : 0.4919
# Epoch: 30	Batch: 600	Avg-Loss: 0.7209	Training Accuracy : 0.5078
# Epoch: 30	Batch: 650	Avg-Loss: 0.7267	Training Accuracy : 0.5059
# Epoch: 30, Validation Loss: 0.783, Validation Accuracy: 0.488
# Epoch: 31	Batch: 50	Avg-Loss: 0.7240	Training Accuracy : 0.4973
# Epoch: 31	Batch: 100	Avg-Loss: 0.7244	Training Accuracy : 0.5022
# Epoch: 31	Batch: 150	Avg-Loss: 0.7202	Training Accuracy : 0.4919
# Epoch: 31	Batch: 200	Avg-Loss: 0.7256	Training Accuracy : 0.5064
# Epoch: 31	Batch: 250	Avg-Loss: 0.7272	Training Accuracy : 0.4964
# Epoch: 31	Batch: 300	Avg-Loss: 0.7275	Training Accuracy : 0.4998
# Epoch: 31	Batch: 350	Avg-Loss: 0.7208	Training Accuracy : 0.5061
# Epoch: 31	Batch: 400	Avg-Loss: 0.7305	Training Accuracy : 0.4988
# Epoch: 31	Batch: 450	Avg-Loss: 0.7263	Training Accuracy : 0.5017
# Epoch: 31	Batch: 500	Avg-Loss: 0.7232	Training Accuracy : 0.4961
# Epoch: 31	Batch: 550	Avg-Loss: 0.7228	Training Accuracy : 0.4991
# Epoch: 31	Batch: 600	Avg-Loss: 0.7192	Training Accuracy : 0.5027
# Epoch: 31	Batch: 650	Avg-Loss: 0.7248	Training Accuracy : 0.4936
# Epoch    32: reducing learning rate of group 0 to 3.9063e-04.
# Epoch: 31, Validation Loss: 0.783, Validation Accuracy: 0.493
# Epoch: 32	Batch: 50	Avg-Loss: 0.7212	Training Accuracy : 0.4964
# Epoch: 32	Batch: 100	Avg-Loss: 0.7227	Training Accuracy : 0.4956
# Epoch: 32	Batch: 150	Avg-Loss: 0.7225	Training Accuracy : 0.5008
# Epoch: 32	Batch: 200	Avg-Loss: 0.7234	Training Accuracy : 0.5072
# Epoch: 32	Batch: 250	Avg-Loss: 0.7189	Training Accuracy : 0.5033
# Epoch: 32	Batch: 300	Avg-Loss: 0.7235	Training Accuracy : 0.5009
# Epoch: 32	Batch: 350	Avg-Loss: 0.7235	Training Accuracy : 0.5030
# Epoch: 32	Batch: 400	Avg-Loss: 0.7186	Training Accuracy : 0.5069
# Epoch: 32	Batch: 450	Avg-Loss: 0.7257	Training Accuracy : 0.4948
# Epoch: 32	Batch: 500	Avg-Loss: 0.7223	Training Accuracy : 0.5003
# Epoch: 32	Batch: 550	Avg-Loss: 0.7222	Training Accuracy : 0.5053
# Epoch: 32	Batch: 600	Avg-Loss: 0.7263	Training Accuracy : 0.4953
# Epoch: 32	Batch: 650	Avg-Loss: 0.7255	Training Accuracy : 0.4922
# Epoch: 32, Validation Loss: 0.783, Validation Accuracy: 0.492
# Epoch: 33	Batch: 50	Avg-Loss: 0.7240	Training Accuracy : 0.5042
# Epoch: 33	Batch: 100	Avg-Loss: 0.7250	Training Accuracy : 0.5106
# Epoch: 33	Batch: 150	Avg-Loss: 0.7207	Training Accuracy : 0.4981
# Epoch: 33	Batch: 200	Avg-Loss: 0.7183	Training Accuracy : 0.4988
# Epoch: 33	Batch: 250	Avg-Loss: 0.7215	Training Accuracy : 0.5027
# Epoch: 33	Batch: 300	Avg-Loss: 0.7183	Training Accuracy : 0.5069
# Epoch: 33	Batch: 350	Avg-Loss: 0.7248	Training Accuracy : 0.4995
# Epoch: 33	Batch: 400	Avg-Loss: 0.7242	Training Accuracy : 0.4992
# Epoch: 33	Batch: 450	Avg-Loss: 0.7191	Training Accuracy : 0.4969
# Epoch: 33	Batch: 500	Avg-Loss: 0.7331	Training Accuracy : 0.4848
# Epoch: 33	Batch: 550	Avg-Loss: 0.7215	Training Accuracy : 0.5067
# Epoch: 33	Batch: 600	Avg-Loss: 0.7220	Training Accuracy : 0.4961
# Epoch: 33	Batch: 650	Avg-Loss: 0.7220	Training Accuracy : 0.5019
# Epoch: 33, Validation Loss: 0.782, Validation Accuracy: 0.493
# Epoch: 34	Batch: 50	Avg-Loss: 0.7258	Training Accuracy : 0.4977
# Epoch: 34	Batch: 100	Avg-Loss: 0.7239	Training Accuracy : 0.4925
# Epoch: 34	Batch: 150	Avg-Loss: 0.7232	Training Accuracy : 0.5064
# Epoch: 34	Batch: 200	Avg-Loss: 0.7231	Training Accuracy : 0.4980
# Epoch: 34	Batch: 250	Avg-Loss: 0.7245	Training Accuracy : 0.4969
# Epoch: 34	Batch: 300	Avg-Loss: 0.7205	Training Accuracy : 0.4963
# Epoch: 34	Batch: 350	Avg-Loss: 0.7191	Training Accuracy : 0.4969
# Epoch: 34	Batch: 400	Avg-Loss: 0.7191	Training Accuracy : 0.5022
# Epoch: 34	Batch: 450	Avg-Loss: 0.7295	Training Accuracy : 0.5011
# Epoch: 34	Batch: 500	Avg-Loss: 0.7245	Training Accuracy : 0.5052
# Epoch: 34	Batch: 550	Avg-Loss: 0.7279	Training Accuracy : 0.4922
# Epoch: 34	Batch: 600	Avg-Loss: 0.7192	Training Accuracy : 0.5038
# Epoch: 34	Batch: 650	Avg-Loss: 0.7192	Training Accuracy : 0.4986
# Epoch    35: reducing learning rate of group 0 to 1.9531e-04.
# Epoch: 34, Validation Loss: 0.784, Validation Accuracy: 0.491
# Epoch: 35	Batch: 50	Avg-Loss: 0.7230	Training Accuracy : 0.5081
# Epoch: 35	Batch: 100	Avg-Loss: 0.7235	Training Accuracy : 0.5052
# Epoch: 35	Batch: 150	Avg-Loss: 0.7196	Training Accuracy : 0.4948
# Epoch: 35	Batch: 200	Avg-Loss: 0.7209	Training Accuracy : 0.5127
# Epoch: 35	Batch: 250	Avg-Loss: 0.7234	Training Accuracy : 0.4983
# Epoch: 35	Batch: 300	Avg-Loss: 0.7230	Training Accuracy : 0.4908
# Epoch: 35	Batch: 350	Avg-Loss: 0.7223	Training Accuracy : 0.5080
# Epoch: 35	Batch: 400	Avg-Loss: 0.7201	Training Accuracy : 0.4898
# Epoch: 35	Batch: 450	Avg-Loss: 0.7210	Training Accuracy : 0.5022
# Epoch: 35	Batch: 500	Avg-Loss: 0.7255	Training Accuracy : 0.5003
# Epoch: 35	Batch: 550	Avg-Loss: 0.7228	Training Accuracy : 0.4908
# Epoch: 35	Batch: 600	Avg-Loss: 0.7190	Training Accuracy : 0.5112
# Epoch: 35	Batch: 650	Avg-Loss: 0.7210	Training Accuracy : 0.4947
# Epoch: 35, Validation Loss: 0.785, Validation Accuracy: 0.492
# Epoch: 36	Batch: 50	Avg-Loss: 0.7221	Training Accuracy : 0.5081
# Epoch: 36	Batch: 100	Avg-Loss: 0.7250	Training Accuracy : 0.5028
# Epoch: 36	Batch: 150	Avg-Loss: 0.7151	Training Accuracy : 0.5086
# Epoch: 36	Batch: 200	Avg-Loss: 0.7211	Training Accuracy : 0.5003
# Epoch: 36	Batch: 250	Avg-Loss: 0.7244	Training Accuracy : 0.5064
# Epoch: 36	Batch: 300	Avg-Loss: 0.7202	Training Accuracy : 0.4978
# Epoch: 36	Batch: 350	Avg-Loss: 0.7197	Training Accuracy : 0.4934
# Epoch: 36	Batch: 400	Avg-Loss: 0.7212	Training Accuracy : 0.5045
# Epoch: 36	Batch: 450	Avg-Loss: 0.7235	Training Accuracy : 0.4956
# Epoch: 36	Batch: 500	Avg-Loss: 0.7162	Training Accuracy : 0.5019
# Epoch: 36	Batch: 550	Avg-Loss: 0.7236	Training Accuracy : 0.5094
# Epoch: 36	Batch: 600	Avg-Loss: 0.7254	Training Accuracy : 0.4973
# Epoch: 36	Batch: 650	Avg-Loss: 0.7197	Training Accuracy : 0.5033
# Epoch: 36, Validation Loss: 0.785, Validation Accuracy: 0.491
# Epoch: 37	Batch: 50	Avg-Loss: 0.7208	Training Accuracy : 0.5092
# Epoch: 37	Batch: 100	Avg-Loss: 0.7237	Training Accuracy : 0.4900
# Epoch: 37	Batch: 150	Avg-Loss: 0.7193	Training Accuracy : 0.5009
# Epoch: 37	Batch: 200	Avg-Loss: 0.7212	Training Accuracy : 0.4991
# Epoch: 37	Batch: 250	Avg-Loss: 0.7211	Training Accuracy : 0.4989
# Epoch: 37	Batch: 300	Avg-Loss: 0.7185	Training Accuracy : 0.5134
# Epoch: 37	Batch: 350	Avg-Loss: 0.7200	Training Accuracy : 0.5020
# Epoch: 37	Batch: 400	Avg-Loss: 0.7199	Training Accuracy : 0.5053
# Epoch: 37	Batch: 450	Avg-Loss: 0.7219	Training Accuracy : 0.5041
# Epoch: 37	Batch: 500	Avg-Loss: 0.7208	Training Accuracy : 0.5009
# Epoch: 37	Batch: 550	Avg-Loss: 0.7224	Training Accuracy : 0.5095
# Epoch: 37	Batch: 600	Avg-Loss: 0.7188	Training Accuracy : 0.4983
# Epoch: 37	Batch: 650	Avg-Loss: 0.7249	Training Accuracy : 0.5000
# Epoch    38: reducing learning rate of group 0 to 9.7656e-05.
# Epoch: 37, Validation Loss: 0.785, Validation Accuracy: 0.492
# Epoch: 38	Batch: 50	Avg-Loss: 0.7198	Training Accuracy : 0.5070
# Epoch: 38	Batch: 100	Avg-Loss: 0.7209	Training Accuracy : 0.5041
# Epoch: 38	Batch: 150	Avg-Loss: 0.7229	Training Accuracy : 0.5062
# Epoch: 38	Batch: 200	Avg-Loss: 0.7256	Training Accuracy : 0.4961
# Epoch: 38	Batch: 250	Avg-Loss: 0.7184	Training Accuracy : 0.4900
# Epoch: 38	Batch: 300	Avg-Loss: 0.7177	Training Accuracy : 0.4981
# Epoch: 38	Batch: 350	Avg-Loss: 0.7231	Training Accuracy : 0.4891
# Epoch: 38	Batch: 400	Avg-Loss: 0.7236	Training Accuracy : 0.5066
# Epoch: 38	Batch: 450	Avg-Loss: 0.7204	Training Accuracy : 0.5078
# Epoch: 38	Batch: 500	Avg-Loss: 0.7167	Training Accuracy : 0.4986
# Epoch: 38	Batch: 550	Avg-Loss: 0.7188	Training Accuracy : 0.4988
# Epoch: 38	Batch: 600	Avg-Loss: 0.7251	Training Accuracy : 0.5019
# Epoch: 38	Batch: 650	Avg-Loss: 0.7176	Training Accuracy : 0.5047
# Epoch: 38, Validation Loss: 0.786, Validation Accuracy: 0.491
# Epoch: 39	Batch: 50	Avg-Loss: 0.7209	Training Accuracy : 0.4920
# Epoch: 39	Batch: 100	Avg-Loss: 0.7240	Training Accuracy : 0.5023
# Epoch: 39	Batch: 150	Avg-Loss: 0.7201	Training Accuracy : 0.5055
# Epoch: 39	Batch: 200	Avg-Loss: 0.7216	Training Accuracy : 0.5002
# Epoch: 39	Batch: 250	Avg-Loss: 0.7238	Training Accuracy : 0.5036
# Epoch: 39	Batch: 300	Avg-Loss: 0.7214	Training Accuracy : 0.5020
# Epoch: 39	Batch: 350	Avg-Loss: 0.7185	Training Accuracy : 0.5009
# Epoch: 39	Batch: 400	Avg-Loss: 0.7174	Training Accuracy : 0.4992
# Epoch: 39	Batch: 450	Avg-Loss: 0.7178	Training Accuracy : 0.4966
# Epoch: 39	Batch: 500	Avg-Loss: 0.7167	Training Accuracy : 0.5102
# Epoch: 39	Batch: 550	Avg-Loss: 0.7254	Training Accuracy : 0.5003
# Epoch: 39	Batch: 600	Avg-Loss: 0.7195	Training Accuracy : 0.5088
# Epoch: 39	Batch: 650	Avg-Loss: 0.7184	Training Accuracy : 0.4992
# Epoch: 39, Validation Loss: 0.787, Validation Accuracy: 0.493
# Epoch: 40	Batch: 50	Avg-Loss: 0.7217	Training Accuracy : 0.4986
# Epoch: 40	Batch: 100	Avg-Loss: 0.7265	Training Accuracy : 0.4938
# Epoch: 40	Batch: 150	Avg-Loss: 0.7199	Training Accuracy : 0.4922
# Epoch: 40	Batch: 200	Avg-Loss: 0.7212	Training Accuracy : 0.5062
# Epoch: 40	Batch: 250	Avg-Loss: 0.7210	Training Accuracy : 0.5064
# Epoch: 40	Batch: 300	Avg-Loss: 0.7221	Training Accuracy : 0.5052
# Epoch: 40	Batch: 350	Avg-Loss: 0.7178	Training Accuracy : 0.5020
# Epoch: 40	Batch: 400	Avg-Loss: 0.7219	Training Accuracy : 0.5006
# Epoch: 40	Batch: 450	Avg-Loss: 0.7219	Training Accuracy : 0.5042
# Epoch: 40	Batch: 500	Avg-Loss: 0.7167	Training Accuracy : 0.4989
# Epoch: 40	Batch: 550	Avg-Loss: 0.7190	Training Accuracy : 0.5098
# Epoch: 40	Batch: 600	Avg-Loss: 0.7247	Training Accuracy : 0.5033
# Epoch: 40	Batch: 650	Avg-Loss: 0.7221	Training Accuracy : 0.5030
# Epoch    41: reducing learning rate of group 0 to 4.8828e-05.
# Epoch: 40, Validation Loss: 0.786, Validation Accuracy: 0.493
# Epoch: 41	Batch: 50	Avg-Loss: 0.7181	Training Accuracy : 0.4995
# Epoch: 41	Batch: 100	Avg-Loss: 0.7187	Training Accuracy : 0.4919
# Epoch: 41	Batch: 150	Avg-Loss: 0.7200	Training Accuracy : 0.5034
# Epoch: 41	Batch: 200	Avg-Loss: 0.7198	Training Accuracy : 0.5009
# Epoch: 41	Batch: 250	Avg-Loss: 0.7235	Training Accuracy : 0.5016
# Epoch: 41	Batch: 300	Avg-Loss: 0.7218	Training Accuracy : 0.5011
# Epoch: 41	Batch: 350	Avg-Loss: 0.7178	Training Accuracy : 0.5039
# Epoch: 41	Batch: 400	Avg-Loss: 0.7219	Training Accuracy : 0.5038
# Epoch: 41	Batch: 450	Avg-Loss: 0.7163	Training Accuracy : 0.5048
# Epoch: 41	Batch: 500	Avg-Loss: 0.7172	Training Accuracy : 0.5036
# Epoch: 41	Batch: 550	Avg-Loss: 0.7219	Training Accuracy : 0.5067
# Epoch: 41	Batch: 600	Avg-Loss: 0.7225	Training Accuracy : 0.4925
# Epoch: 41	Batch: 650	Avg-Loss: 0.7220	Training Accuracy : 0.4964
# Epoch: 41, Validation Loss: 0.786, Validation Accuracy: 0.493
# Epoch: 42	Batch: 50	Avg-Loss: 0.7195	Training Accuracy : 0.4919
# Epoch: 42	Batch: 100	Avg-Loss: 0.7192	Training Accuracy : 0.5072
# Epoch: 42	Batch: 150	Avg-Loss: 0.7253	Training Accuracy : 0.4992
# Epoch: 42	Batch: 200	Avg-Loss: 0.7152	Training Accuracy : 0.5053
# Epoch: 42	Batch: 250	Avg-Loss: 0.7204	Training Accuracy : 0.5003
# Epoch: 42	Batch: 300	Avg-Loss: 0.7182	Training Accuracy : 0.5066
# Epoch: 42	Batch: 350	Avg-Loss: 0.7195	Training Accuracy : 0.5008
# Epoch: 42	Batch: 400	Avg-Loss: 0.7152	Training Accuracy : 0.5106
# Epoch: 42	Batch: 450	Avg-Loss: 0.7252	Training Accuracy : 0.5078
# Epoch: 42	Batch: 500	Avg-Loss: 0.7200	Training Accuracy : 0.4989
# Epoch: 42	Batch: 550	Avg-Loss: 0.7165	Training Accuracy : 0.4955
# Epoch: 42	Batch: 600	Avg-Loss: 0.7188	Training Accuracy : 0.4984
# Epoch: 42	Batch: 650	Avg-Loss: 0.7215	Training Accuracy : 0.4952
# Epoch: 42, Validation Loss: 0.789, Validation Accuracy: 0.490
# Epoch: 43	Batch: 50	Avg-Loss: 0.7227	Training Accuracy : 0.5020
# Epoch: 43	Batch: 100	Avg-Loss: 0.7151	Training Accuracy : 0.5000
# Epoch: 43	Batch: 150	Avg-Loss: 0.7179	Training Accuracy : 0.5077
# Epoch: 43	Batch: 200	Avg-Loss: 0.7193	Training Accuracy : 0.5045
# Epoch: 43	Batch: 250	Avg-Loss: 0.7174	Training Accuracy : 0.4923
# Epoch: 43	Batch: 300	Avg-Loss: 0.7188	Training Accuracy : 0.5020
# Epoch: 43	Batch: 350	Avg-Loss: 0.7205	Training Accuracy : 0.4903
# Epoch: 43	Batch: 400	Avg-Loss: 0.7188	Training Accuracy : 0.5052
# Epoch: 43	Batch: 450	Avg-Loss: 0.7181	Training Accuracy : 0.5052
# Epoch: 43	Batch: 500	Avg-Loss: 0.7214	Training Accuracy : 0.5000
# Epoch: 43	Batch: 550	Avg-Loss: 0.7188	Training Accuracy : 0.5000
# Epoch: 43	Batch: 600	Avg-Loss: 0.7191	Training Accuracy : 0.4983
# Epoch: 43	Batch: 650	Avg-Loss: 0.7226	Training Accuracy : 0.5027
# Epoch    44: reducing learning rate of group 0 to 2.4414e-05.
# Epoch: 43, Validation Loss: 0.787, Validation Accuracy: 0.490
# Epoch: 44	Batch: 50	Avg-Loss: 0.7210	Training Accuracy : 0.4988
# Epoch: 44	Batch: 100	Avg-Loss: 0.7213	Training Accuracy : 0.5067
# Epoch: 44	Batch: 150	Avg-Loss: 0.7208	Training Accuracy : 0.5022
# Epoch: 44	Batch: 200	Avg-Loss: 0.7189	Training Accuracy : 0.5000
# Epoch: 44	Batch: 250	Avg-Loss: 0.7182	Training Accuracy : 0.4877
# Epoch: 44	Batch: 300	Avg-Loss: 0.7220	Training Accuracy : 0.5144
# Epoch: 44	Batch: 350	Avg-Loss: 0.7202	Training Accuracy : 0.4939
# Epoch: 44	Batch: 400	Avg-Loss: 0.7168	Training Accuracy : 0.5102
# Epoch: 44	Batch: 450	Avg-Loss: 0.7183	Training Accuracy : 0.4984
# Epoch: 44	Batch: 500	Avg-Loss: 0.7197	Training Accuracy : 0.5048
# Epoch: 44	Batch: 550	Avg-Loss: 0.7206	Training Accuracy : 0.4970
# Epoch: 44	Batch: 600	Avg-Loss: 0.7189	Training Accuracy : 0.4891
# Epoch: 44	Batch: 650	Avg-Loss: 0.7194	Training Accuracy : 0.5097
# Epoch: 44, Validation Loss: 0.786, Validation Accuracy: 0.492
# Epoch: 45	Batch: 50	Avg-Loss: 0.7230	Training Accuracy : 0.4948
# Epoch: 45	Batch: 100	Avg-Loss: 0.7192	Training Accuracy : 0.4964
# Epoch: 45	Batch: 150	Avg-Loss: 0.7219	Training Accuracy : 0.5008
# Epoch: 45	Batch: 200	Avg-Loss: 0.7169	Training Accuracy : 0.4950
# Epoch: 45	Batch: 250	Avg-Loss: 0.7186	Training Accuracy : 0.5002
# Epoch: 45	Batch: 300	Avg-Loss: 0.7193	Training Accuracy : 0.5044
# Epoch: 45	Batch: 350	Avg-Loss: 0.7170	Training Accuracy : 0.5095
# Epoch: 45	Batch: 400	Avg-Loss: 0.7225	Training Accuracy : 0.5016
# Epoch: 45	Batch: 450	Avg-Loss: 0.7170	Training Accuracy : 0.5005
# Epoch: 45	Batch: 500	Avg-Loss: 0.7199	Training Accuracy : 0.5033
# Epoch: 45	Batch: 550	Avg-Loss: 0.7171	Training Accuracy : 0.5080
# Epoch: 45	Batch: 600	Avg-Loss: 0.7215	Training Accuracy : 0.5019
# Epoch: 45	Batch: 650	Avg-Loss: 0.7209	Training Accuracy : 0.5084
# Epoch: 45, Validation Loss: 0.787, Validation Accuracy: 0.492
# Epoch: 46	Batch: 50	Avg-Loss: 0.7219	Training Accuracy : 0.4988
# Epoch: 46	Batch: 100	Avg-Loss: 0.7173	Training Accuracy : 0.5183
# Epoch: 46	Batch: 150	Avg-Loss: 0.7185	Training Accuracy : 0.4991
# Epoch: 46	Batch: 200	Avg-Loss: 0.7159	Training Accuracy : 0.5039
# Epoch: 46	Batch: 250	Avg-Loss: 0.7191	Training Accuracy : 0.4991
# Epoch: 46	Batch: 300	Avg-Loss: 0.7182	Training Accuracy : 0.5102
# Epoch: 46	Batch: 350	Avg-Loss: 0.7215	Training Accuracy : 0.5075
# Epoch: 46	Batch: 400	Avg-Loss: 0.7137	Training Accuracy : 0.5016
# Epoch: 46	Batch: 450	Avg-Loss: 0.7205	Training Accuracy : 0.5020
# Epoch: 46	Batch: 500	Avg-Loss: 0.7185	Training Accuracy : 0.4938
# Epoch: 46	Batch: 550	Avg-Loss: 0.7254	Training Accuracy : 0.5000
# Epoch: 46	Batch: 600	Avg-Loss: 0.7187	Training Accuracy : 0.5025
# Epoch: 46	Batch: 650	Avg-Loss: 0.7248	Training Accuracy : 0.4913
# Epoch    47: reducing learning rate of group 0 to 1.2207e-05.
# Epoch: 46, Validation Loss: 0.788, Validation Accuracy: 0.491
# Epoch: 47	Batch: 50	Avg-Loss: 0.7170	Training Accuracy : 0.4948
# Epoch: 47	Batch: 100	Avg-Loss: 0.7172	Training Accuracy : 0.5045
# Epoch: 47	Batch: 150	Avg-Loss: 0.7206	Training Accuracy : 0.5044
# Epoch: 47	Batch: 200	Avg-Loss: 0.7247	Training Accuracy : 0.5070
# Epoch: 47	Batch: 250	Avg-Loss: 0.7208	Training Accuracy : 0.5002
# Epoch: 47	Batch: 300	Avg-Loss: 0.7242	Training Accuracy : 0.4945
# Epoch: 47	Batch: 350	Avg-Loss: 0.7157	Training Accuracy : 0.5033
# Epoch: 47	Batch: 400	Avg-Loss: 0.7218	Training Accuracy : 0.5028
# Epoch: 47	Batch: 450	Avg-Loss: 0.7225	Training Accuracy : 0.4920
# Epoch: 47	Batch: 500	Avg-Loss: 0.7148	Training Accuracy : 0.5131
# Epoch: 47	Batch: 550	Avg-Loss: 0.7201	Training Accuracy : 0.5094
# Epoch: 47	Batch: 600	Avg-Loss: 0.7186	Training Accuracy : 0.4994
# Epoch: 47	Batch: 650	Avg-Loss: 0.7227	Training Accuracy : 0.5067
# Epoch: 47, Validation Loss: 0.788, Validation Accuracy: 0.491
# Epoch: 48	Batch: 50	Avg-Loss: 0.7235	Training Accuracy : 0.4964
# Epoch: 48	Batch: 100	Avg-Loss: 0.7171	Training Accuracy : 0.4952
# Epoch: 48	Batch: 150	Avg-Loss: 0.7191	Training Accuracy : 0.5022
# Epoch: 48	Batch: 200	Avg-Loss: 0.7188	Training Accuracy : 0.5003
# Epoch: 48	Batch: 250	Avg-Loss: 0.7167	Training Accuracy : 0.4997
# Epoch: 48	Batch: 300	Avg-Loss: 0.7200	Training Accuracy : 0.4944
# Epoch: 48	Batch: 350	Avg-Loss: 0.7193	Training Accuracy : 0.4995
# Epoch: 48	Batch: 400	Avg-Loss: 0.7190	Training Accuracy : 0.4995
# Epoch: 48	Batch: 450	Avg-Loss: 0.7199	Training Accuracy : 0.4994
# Epoch: 48	Batch: 500	Avg-Loss: 0.7224	Training Accuracy : 0.5075
# Epoch: 48	Batch: 550	Avg-Loss: 0.7212	Training Accuracy : 0.5058
# Epoch: 48	Batch: 600	Avg-Loss: 0.7184	Training Accuracy : 0.5033
# Epoch: 48	Batch: 650	Avg-Loss: 0.7185	Training Accuracy : 0.5028
# Epoch: 48, Validation Loss: 0.787, Validation Accuracy: 0.492
# Epoch: 49	Batch: 50	Avg-Loss: 0.7204	Training Accuracy : 0.4925
# Epoch: 49	Batch: 100	Avg-Loss: 0.7196	Training Accuracy : 0.4931
# Epoch: 49	Batch: 150	Avg-Loss: 0.7184	Training Accuracy : 0.5072
# Epoch: 49	Batch: 200	Avg-Loss: 0.7192	Training Accuracy : 0.5095
# Epoch: 49	Batch: 250	Avg-Loss: 0.7144	Training Accuracy : 0.5058
# Epoch: 49	Batch: 300	Avg-Loss: 0.7212	Training Accuracy : 0.5012
# Epoch: 49	Batch: 350	Avg-Loss: 0.7189	Training Accuracy : 0.5016
# Epoch: 49	Batch: 400	Avg-Loss: 0.7180	Training Accuracy : 0.4927
# Epoch: 49	Batch: 450	Avg-Loss: 0.7200	Training Accuracy : 0.4945
# Epoch: 49	Batch: 500	Avg-Loss: 0.7172	Training Accuracy : 0.5066
# Epoch: 49	Batch: 550	Avg-Loss: 0.7192	Training Accuracy : 0.4983
# Epoch: 49	Batch: 600	Avg-Loss: 0.7227	Training Accuracy : 0.5025
# Epoch: 49	Batch: 650	Avg-Loss: 0.7172	Training Accuracy : 0.5070
# Epoch    50: reducing learning rate of group 0 to 6.1035e-06.
# Epoch: 49, Validation Loss: 0.787, Validation Accuracy: 0.493
# Epoch: 50	Batch: 50	Avg-Loss: 0.7187	Training Accuracy : 0.5038
# Epoch: 50	Batch: 100	Avg-Loss: 0.7180	Training Accuracy : 0.4895
# Epoch: 50	Batch: 150	Avg-Loss: 0.7180	Training Accuracy : 0.5094
# Epoch: 50	Batch: 200	Avg-Loss: 0.7193	Training Accuracy : 0.4948
# Epoch: 50	Batch: 250	Avg-Loss: 0.7208	Training Accuracy : 0.4947
# Epoch: 50	Batch: 300	Avg-Loss: 0.7183	Training Accuracy : 0.4941
# Epoch: 50	Batch: 350	Avg-Loss: 0.7212	Training Accuracy : 0.5075
# Epoch: 50	Batch: 400	Avg-Loss: 0.7162	Training Accuracy : 0.5030
# Epoch: 50	Batch: 450	Avg-Loss: 0.7210	Training Accuracy : 0.4983
# Epoch: 50	Batch: 500	Avg-Loss: 0.7166	Training Accuracy : 0.5022
# Epoch: 50	Batch: 550	Avg-Loss: 0.7206	Training Accuracy : 0.5030
# Epoch: 50	Batch: 600	Avg-Loss: 0.7143	Training Accuracy : 0.5038
# Epoch: 50	Batch: 650	Avg-Loss: 0.7226	Training Accuracy : 0.4955
# Epoch: 50, Validation Loss: 0.788, Validation Accuracy: 0.493
# Epoch: 51	Batch: 50	Avg-Loss: 0.7206	Training Accuracy : 0.5064
# Epoch: 51	Batch: 100	Avg-Loss: 0.7185	Training Accuracy : 0.5075
# Epoch: 51	Batch: 150	Avg-Loss: 0.7158	Training Accuracy : 0.4981
# Epoch: 51	Batch: 200	Avg-Loss: 0.7185	Training Accuracy : 0.4994
# Epoch: 51	Batch: 250	Avg-Loss: 0.7152	Training Accuracy : 0.4983
# Epoch: 51	Batch: 300	Avg-Loss: 0.7222	Training Accuracy : 0.5061
# Epoch: 51	Batch: 350	Avg-Loss: 0.7177	Training Accuracy : 0.5105
# Epoch: 51	Batch: 400	Avg-Loss: 0.7204	Training Accuracy : 0.4967
# Epoch: 51	Batch: 450	Avg-Loss: 0.7203	Training Accuracy : 0.4819
# Epoch: 51	Batch: 500	Avg-Loss: 0.7183	Training Accuracy : 0.5094
# Epoch: 51	Batch: 550	Avg-Loss: 0.7206	Training Accuracy : 0.5002
# Epoch: 51	Batch: 600	Avg-Loss: 0.7186	Training Accuracy : 0.4981
# Epoch: 51	Batch: 650	Avg-Loss: 0.7225	Training Accuracy : 0.5006
# Epoch: 51, Validation Loss: 0.787, Validation Accuracy: 0.491
# Epoch: 52	Batch: 50	Avg-Loss: 0.7195	Training Accuracy : 0.5061
# Epoch: 52	Batch: 100	Avg-Loss: 0.7185	Training Accuracy : 0.4931
# Epoch: 52	Batch: 150	Avg-Loss: 0.7161	Training Accuracy : 0.5088
# Epoch: 52	Batch: 200	Avg-Loss: 0.7181	Training Accuracy : 0.4986
# Epoch: 52	Batch: 250	Avg-Loss: 0.7202	Training Accuracy : 0.5088
# Epoch: 52	Batch: 300	Avg-Loss: 0.7179	Training Accuracy : 0.5100
# Epoch: 52	Batch: 350	Avg-Loss: 0.7179	Training Accuracy : 0.5148
# Epoch: 52	Batch: 400	Avg-Loss: 0.7217	Training Accuracy : 0.5036
# Epoch: 52	Batch: 450	Avg-Loss: 0.7172	Training Accuracy : 0.5002
# Epoch: 52	Batch: 500	Avg-Loss: 0.7223	Training Accuracy : 0.5000
# Epoch: 52	Batch: 550	Avg-Loss: 0.7155	Training Accuracy : 0.4981
# Epoch: 52	Batch: 600	Avg-Loss: 0.7173	Training Accuracy : 0.5020
# Epoch: 52	Batch: 650	Avg-Loss: 0.7251	Training Accuracy : 0.4967
# Epoch    53: reducing learning rate of group 0 to 3.0518e-06.
# Epoch: 52, Validation Loss: 0.788, Validation Accuracy: 0.491
# Epoch: 53	Batch: 50	Avg-Loss: 0.7157	Training Accuracy : 0.5011
# Epoch: 53	Batch: 100	Avg-Loss: 0.7216	Training Accuracy : 0.4977
# Epoch: 53	Batch: 150	Avg-Loss: 0.7199	Training Accuracy : 0.5119
# Epoch: 53	Batch: 200	Avg-Loss: 0.7176	Training Accuracy : 0.5023
# Epoch: 53	Batch: 250	Avg-Loss: 0.7180	Training Accuracy : 0.5041
# Epoch: 53	Batch: 300	Avg-Loss: 0.7173	Training Accuracy : 0.4977
# Epoch: 53	Batch: 350	Avg-Loss: 0.7174	Training Accuracy : 0.4970
# Epoch: 53	Batch: 400	Avg-Loss: 0.7147	Training Accuracy : 0.5014
# Epoch: 53	Batch: 450	Avg-Loss: 0.7210	Training Accuracy : 0.5038
# Epoch: 53	Batch: 500	Avg-Loss: 0.7195	Training Accuracy : 0.4897
# Epoch: 53	Batch: 550	Avg-Loss: 0.7201	Training Accuracy : 0.5073
# Epoch: 53	Batch: 600	Avg-Loss: 0.7210	Training Accuracy : 0.4961
# Epoch: 53	Batch: 650	Avg-Loss: 0.7225	Training Accuracy : 0.5000
# Epoch: 53, Validation Loss: 0.787, Validation Accuracy: 0.492
# Epoch: 54	Batch: 50	Avg-Loss: 0.7150	Training Accuracy : 0.5050
# Epoch: 54	Batch: 100	Avg-Loss: 0.7164	Training Accuracy : 0.5044
# Epoch: 54	Batch: 150	Avg-Loss: 0.7135	Training Accuracy : 0.5056
# Epoch: 54	Batch: 200	Avg-Loss: 0.7204	Training Accuracy : 0.4917
# Epoch: 54	Batch: 250	Avg-Loss: 0.7192	Training Accuracy : 0.5078
# Epoch: 54	Batch: 300	Avg-Loss: 0.7175	Training Accuracy : 0.5012
# Epoch: 54	Batch: 350	Avg-Loss: 0.7205	Training Accuracy : 0.4981
# Epoch: 54	Batch: 400	Avg-Loss: 0.7231	Training Accuracy : 0.5011
# Epoch: 54	Batch: 450	Avg-Loss: 0.7182	Training Accuracy : 0.5062
# Epoch: 54	Batch: 500	Avg-Loss: 0.7249	Training Accuracy : 0.5034
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-ecd6c2a80a6c> in <module>()
#       9         optimizer.zero_grad()
#      10         x.requires_grad_()
# ---> 11         x, y = x.to(device), y.to(device)
#      12         outputs = network(x)
#      13         num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
#
# KeyboardInterrupt:

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Fri Nov 26 21:07:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    32W / 250W |   1091MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_2+1/best_model_28.pt"))
network = network.to(device)

# %%
network.eval()
num_correct = 0
for x, y in tqdm(test_loader):
  x, y = x.to(device), y.to(device)
  outputs = network(x)
  num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

test_acc = num_correct / len(test_set)
print(test_acc)
# Out:
# 100%|██████████| 142/142 [01:40<00:00,  1.42it/s]
# 0.4846540950063596

# %%
print(test_acc)
# Out:
# 0.4829950782502903

# %%
print(test_acc)
# Out:
# 0.4852624011502516
