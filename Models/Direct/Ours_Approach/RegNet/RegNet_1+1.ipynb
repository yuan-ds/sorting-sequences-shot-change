# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/dl_project/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("1+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                          frames  label
# 0      ('frame_149840.jpg', 'frame_151422.jpg')      0
# 1      ('frame_151595.jpg', 'frame_149880.jpg')      1
# 2      ('frame_151667.jpg', 'frame_149876.jpg')      1
# 3      ('frame_149876.jpg', 'frame_151705.jpg')      0
# 4      ('frame_149852.jpg', 'frame_151768.jpg')      0
# ...                                         ...    ...
# 18141  ('frame_174615.jpg', 'frame_180809.jpg')      0
# 18142  ('frame_180855.jpg', 'frame_174653.jpg')      1
# 18143  ('frame_180890.jpg', 'frame_174594.jpg')      1
# 18144  ('frame_181123.jpg', 'frame_174612.jpg')      1
# 18145  ('frame_174574.jpg', 'frame_181333.jpg')      0
#
# [18146 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            images.extend(img)
        x = torch.stack(images)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([6, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
batch_size = 128

# training data
train_set = MyDataSet(train_data)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding,num_classes))


    def forward(self, x):
      out = self.cnn(x)
      out = self.mlp(out)
      return out

# %%
numEpochs = 100
in_features = 6 # TODO: change RGB channels according to num of frames
embedding = 512

learningRate = 0.1
weightDecay = 1e-4

num_classes = 2

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_classes)
#network.load_state_dict(torch.load("model_checkpoints/resnet34/lr_0.1-2/model_2.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_1+1/best_model_" + str(epoch) + ".pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 0	Batch: 50	Avg-Loss: 1.4680	Training Accuracy : 0.5058
# Epoch: 0	Batch: 100	Avg-Loss: 0.7030	Training Accuracy : 0.4877
# Epoch: 0	Batch: 150	Avg-Loss: 0.6980	Training Accuracy : 0.4977
# Epoch: 0	Batch: 200	Avg-Loss: 0.6968	Training Accuracy : 0.5022
# Epoch: 0	Batch: 250	Avg-Loss: 0.6960	Training Accuracy : 0.5072
# Epoch: 0	Batch: 300	Avg-Loss: 0.6950	Training Accuracy : 0.4964
# Epoch: 0	Batch: 350	Avg-Loss: 0.6953	Training Accuracy : 0.4989
# Epoch: 0	Batch: 400	Avg-Loss: 0.6946	Training Accuracy : 0.5031
# Epoch: 0	Batch: 450	Avg-Loss: 0.6944	Training Accuracy : 0.5003
# Epoch: 0	Batch: 500	Avg-Loss: 0.6931	Training Accuracy : 0.5162
# Epoch: 0	Batch: 550	Avg-Loss: 0.6952	Training Accuracy : 0.4833
# Epoch: 0	Batch: 600	Avg-Loss: 0.6949	Training Accuracy : 0.4936
# Epoch: 0	Batch: 650	Avg-Loss: 0.6931	Training Accuracy : 0.5064
# Epoch: 0, Validation Loss: 0.692, Validation Accuracy: 0.518
# Epoch: 1	Batch: 50	Avg-Loss: 0.6958	Training Accuracy : 0.5003
# Epoch: 1	Batch: 100	Avg-Loss: 0.6948	Training Accuracy : 0.5064
# Epoch: 1	Batch: 150	Avg-Loss: 0.6944	Training Accuracy : 0.5031
# Epoch: 1	Batch: 200	Avg-Loss: 0.6946	Training Accuracy : 0.5016
# Epoch: 1	Batch: 250	Avg-Loss: 0.6935	Training Accuracy : 0.5034
# Epoch: 1	Batch: 300	Avg-Loss: 0.6933	Training Accuracy : 0.4998
# Epoch: 1	Batch: 350	Avg-Loss: 0.6943	Training Accuracy : 0.4973
# Epoch: 1	Batch: 400	Avg-Loss: 0.6943	Training Accuracy : 0.4983
# Epoch: 1	Batch: 450	Avg-Loss: 0.6947	Training Accuracy : 0.4947
# Epoch: 1	Batch: 500	Avg-Loss: 0.6946	Training Accuracy : 0.4983
# Epoch: 1	Batch: 550	Avg-Loss: 0.6947	Training Accuracy : 0.5006
# Epoch: 1	Batch: 600	Avg-Loss: 0.6937	Training Accuracy : 0.5006
# Epoch: 1	Batch: 650	Avg-Loss: 0.6936	Training Accuracy : 0.5011
# Epoch: 1, Validation Loss: 0.692, Validation Accuracy: 0.530
# Epoch: 2	Batch: 50	Avg-Loss: 0.6938	Training Accuracy : 0.5177
# Epoch: 2	Batch: 100	Avg-Loss: 0.6932	Training Accuracy : 0.5036
# Epoch: 2	Batch: 150	Avg-Loss: 0.6950	Training Accuracy : 0.4925
# Epoch: 2	Batch: 200	Avg-Loss: 0.6938	Training Accuracy : 0.5077
# Epoch: 2	Batch: 250	Avg-Loss: 0.6928	Training Accuracy : 0.5125
# Epoch: 2	Batch: 300	Avg-Loss: 0.6943	Training Accuracy : 0.5108
# Epoch: 2	Batch: 350	Avg-Loss: 0.6932	Training Accuracy : 0.5094
# Epoch: 2	Batch: 400	Avg-Loss: 0.6938	Training Accuracy : 0.5081
# Epoch: 2	Batch: 450	Avg-Loss: 0.6951	Training Accuracy : 0.5033
# Epoch: 2	Batch: 500	Avg-Loss: 0.6927	Training Accuracy : 0.5084
# Epoch: 2	Batch: 550	Avg-Loss: 0.6938	Training Accuracy : 0.5005
# Epoch: 2	Batch: 600	Avg-Loss: 0.6943	Training Accuracy : 0.4989
# Epoch: 2	Batch: 650	Avg-Loss: 0.6929	Training Accuracy : 0.5131
# Epoch: 2, Validation Loss: 0.693, Validation Accuracy: 0.496
# Epoch: 3	Batch: 50	Avg-Loss: 0.6923	Training Accuracy : 0.5136
# Epoch: 3	Batch: 100	Avg-Loss: 0.6936	Training Accuracy : 0.5108
# Epoch: 3	Batch: 150	Avg-Loss: 0.6927	Training Accuracy : 0.5192
# Epoch: 3	Batch: 200	Avg-Loss: 0.6930	Training Accuracy : 0.5177
# Epoch: 3	Batch: 250	Avg-Loss: 0.6930	Training Accuracy : 0.5003
# Epoch: 3	Batch: 300	Avg-Loss: 0.6944	Training Accuracy : 0.5028
# Epoch: 3	Batch: 350	Avg-Loss: 0.6925	Training Accuracy : 0.5217
# Epoch: 3	Batch: 400	Avg-Loss: 0.6926	Training Accuracy : 0.5173
# Epoch: 3	Batch: 450	Avg-Loss: 0.6983	Training Accuracy : 0.4958
# Epoch: 3	Batch: 500	Avg-Loss: 0.6911	Training Accuracy : 0.5239
# Epoch: 3	Batch: 550	Avg-Loss: 0.6921	Training Accuracy : 0.5158
# Epoch: 3	Batch: 600	Avg-Loss: 0.6918	Training Accuracy : 0.5236
# Epoch: 3	Batch: 650	Avg-Loss: 0.6908	Training Accuracy : 0.5298
# Epoch: 3, Validation Loss: 0.693, Validation Accuracy: 0.510
# Epoch: 4	Batch: 50	Avg-Loss: 0.6904	Training Accuracy : 0.5278
# Epoch: 4	Batch: 100	Avg-Loss: 0.6902	Training Accuracy : 0.5317
# Epoch: 6	Batch: 500	Avg-Loss: 0.6853	Training Accuracy : 0.5414
# Epoch: 6	Batch: 550	Avg-Loss: 0.6897	Training Accuracy : 0.5370
# Epoch: 6	Batch: 600	Avg-Loss: 0.6856	Training Accuracy : 0.5481
# Epoch: 6	Batch: 650	Avg-Loss: 0.6864	Training Accuracy : 0.5337
# Epoch: 6, Validation Loss: 0.692, Validation Accuracy: 0.515
# Epoch: 7	Batch: 50	Avg-Loss: 0.6833	Training Accuracy : 0.5522
# Epoch: 7	Batch: 100	Avg-Loss: 0.6870	Training Accuracy : 0.5353
# Epoch: 7	Batch: 150	Avg-Loss: 0.6892	Training Accuracy : 0.5206
# Epoch: 7	Batch: 200	Avg-Loss: 0.6849	Training Accuracy : 0.5408
# Epoch: 7	Batch: 250	Avg-Loss: 0.6851	Training Accuracy : 0.5497
# Epoch: 7	Batch: 300	Avg-Loss: 0.6826	Training Accuracy : 0.5378
# Epoch: 7	Batch: 350	Avg-Loss: 0.6840	Training Accuracy : 0.5458
# Epoch: 7	Batch: 400	Avg-Loss: 0.6829	Training Accuracy : 0.5503
# Epoch: 7	Batch: 450	Avg-Loss: 0.6850	Training Accuracy : 0.5434
# Epoch: 7	Batch: 500	Avg-Loss: 0.6850	Training Accuracy : 0.5445
# Epoch: 7	Batch: 550	Avg-Loss: 0.6850	Training Accuracy : 0.5445
# Epoch: 7	Batch: 600	Avg-Loss: 0.6798	Training Accuracy : 0.5550
# Epoch: 7	Batch: 650	Avg-Loss: 0.6840	Training Accuracy : 0.5537
# Epoch     8: reducing learning rate of group 0 to 5.0000e-02.
# Epoch: 7, Validation Loss: 0.693, Validation Accuracy: 0.521
# Epoch: 8	Batch: 50	Avg-Loss: 0.6794	Training Accuracy : 0.5569
# Epoch: 8	Batch: 100	Avg-Loss: 0.6793	Training Accuracy : 0.5617
# Epoch: 8	Batch: 150	Avg-Loss: 0.6753	Training Accuracy : 0.5686
# Epoch: 8	Batch: 200	Avg-Loss: 0.6740	Training Accuracy : 0.5630
# Epoch: 8	Batch: 250	Avg-Loss: 0.6758	Training Accuracy : 0.5652
# Epoch: 8	Batch: 300	Avg-Loss: 0.6766	Training Accuracy : 0.5667
# Epoch: 8	Batch: 350	Avg-Loss: 0.6755	Training Accuracy : 0.5675
# Epoch: 8	Batch: 400	Avg-Loss: 0.6738	Training Accuracy : 0.5763
# Epoch: 8	Batch: 450	Avg-Loss: 0.6778	Training Accuracy : 0.5552
# Epoch: 8	Batch: 500	Avg-Loss: 0.6755	Training Accuracy : 0.5661
# Epoch: 8	Batch: 550	Avg-Loss: 0.6737	Training Accuracy : 0.5709
# Epoch: 8	Batch: 600	Avg-Loss: 0.6798	Training Accuracy : 0.5608
# Epoch: 8	Batch: 650	Avg-Loss: 0.6763	Training Accuracy : 0.5737
# Epoch: 8, Validation Loss: 0.709, Validation Accuracy: 0.480
# Epoch: 9	Batch: 50	Avg-Loss: 0.6738	Training Accuracy : 0.5675
# Epoch: 9	Batch: 100	Avg-Loss: 0.6716	Training Accuracy : 0.5761
# Epoch: 9	Batch: 150	Avg-Loss: 0.6715	Training Accuracy : 0.5766
# Epoch: 9	Batch: 200	Avg-Loss: 0.6751	Training Accuracy : 0.5737
# Epoch: 9	Batch: 250	Avg-Loss: 0.6706	Training Accuracy : 0.5684
# Epoch: 9	Batch: 300	Avg-Loss: 0.6691	Training Accuracy : 0.5820
# Epoch: 9	Batch: 350	Avg-Loss: 0.6740	Training Accuracy : 0.5736
# Epoch: 9	Batch: 400	Avg-Loss: 0.6693	Training Accuracy : 0.5775
# Epoch: 9	Batch: 450	Avg-Loss: 0.6712	Training Accuracy : 0.5737
# Epoch: 9	Batch: 500	Avg-Loss: 0.6757	Training Accuracy : 0.5644
# Epoch: 9	Batch: 550	Avg-Loss: 0.6712	Training Accuracy : 0.5766
# Epoch: 9	Batch: 600	Avg-Loss: 0.6668	Training Accuracy : 0.5891
# Epoch: 9	Batch: 650	Avg-Loss: 0.6752	Training Accuracy : 0.5717
# Epoch: 9, Validation Loss: 0.698, Validation Accuracy: 0.507
# Epoch: 10	Batch: 50	Avg-Loss: 0.6699	Training Accuracy : 0.5783
# Epoch: 10	Batch: 100	Avg-Loss: 0.6691	Training Accuracy : 0.5863
# Epoch: 10	Batch: 150	Avg-Loss: 0.6714	Training Accuracy : 0.5756
# Epoch: 10	Batch: 200	Avg-Loss: 0.6655	Training Accuracy : 0.5909
# Epoch: 10	Batch: 250	Avg-Loss: 0.6636	Training Accuracy : 0.5961
# Epoch: 10	Batch: 300	Avg-Loss: 0.6678	Training Accuracy : 0.5883
# Epoch: 10	Batch: 350	Avg-Loss: 0.6659	Training Accuracy : 0.5853
# Epoch: 10	Batch: 400	Avg-Loss: 0.6720	Training Accuracy : 0.5802
# Epoch: 10	Batch: 450	Avg-Loss: 0.6674	Training Accuracy : 0.5914
# Epoch: 10	Batch: 500	Avg-Loss: 0.6711	Training Accuracy : 0.5875
# Epoch: 10	Batch: 550	Avg-Loss: 0.6600	Training Accuracy : 0.5947
# Epoch: 10	Batch: 600	Avg-Loss: 0.6679	Training Accuracy : 0.5800
# Epoch: 10	Batch: 650	Avg-Loss: 0.6612	Training Accuracy : 0.5920
# Epoch    11: reducing learning rate of group 0 to 2.5000e-02.
# Epoch: 10, Validation Loss: 0.754, Validation Accuracy: 0.481
# Epoch: 11	Batch: 50	Avg-Loss: 0.6527	Training Accuracy : 0.6119
# Epoch: 11	Batch: 100	Avg-Loss: 0.6516	Training Accuracy : 0.6134
# Epoch: 11	Batch: 150	Avg-Loss: 0.6535	Training Accuracy : 0.6103
# Epoch: 11	Batch: 200	Avg-Loss: 0.6521	Training Accuracy : 0.6144
# Epoch: 11	Batch: 250	Avg-Loss: 0.6524	Training Accuracy : 0.6122
# Epoch: 11	Batch: 300	Avg-Loss: 0.6556	Training Accuracy : 0.6061
# Epoch: 11	Batch: 350	Avg-Loss: 0.6387	Training Accuracy : 0.6303
# Epoch: 11	Batch: 400	Avg-Loss: 0.6498	Training Accuracy : 0.6112
# Epoch: 11	Batch: 450	Avg-Loss: 0.6443	Training Accuracy : 0.6206
# Epoch: 14	Batch: 100	Avg-Loss: 0.5211	Training Accuracy : 0.7395
# Epoch: 14	Batch: 150	Avg-Loss: 0.5243	Training Accuracy : 0.7369
# Epoch: 14	Batch: 200	Avg-Loss: 0.5180	Training Accuracy : 0.7452
# Epoch: 14	Batch: 250	Avg-Loss: 0.5106	Training Accuracy : 0.7467
# Epoch: 14	Batch: 300	Avg-Loss: 0.5065	Training Accuracy : 0.7486
# Epoch: 14	Batch: 350	Avg-Loss: 0.4987	Training Accuracy : 0.7497
# Epoch: 14	Batch: 400	Avg-Loss: 0.5188	Training Accuracy : 0.7388
# Epoch: 14	Batch: 450	Avg-Loss: 0.5024	Training Accuracy : 0.7536
# Epoch: 14	Batch: 500	Avg-Loss: 0.5084	Training Accuracy : 0.7492
# Epoch: 14	Batch: 550	Avg-Loss: 0.4972	Training Accuracy : 0.7516
# Epoch: 14	Batch: 600	Avg-Loss: 0.4943	Training Accuracy : 0.7562
# Epoch: 14	Batch: 650	Avg-Loss: 0.4879	Training Accuracy : 0.7667
# Epoch: 14, Validation Loss: 0.940, Validation Accuracy: 0.499
# Epoch: 15	Batch: 50	Avg-Loss: 0.4447	Training Accuracy : 0.7902
# Epoch: 15	Batch: 100	Avg-Loss: 0.4514	Training Accuracy : 0.7792
# Epoch: 15	Batch: 150	Avg-Loss: 0.4501	Training Accuracy : 0.7861
# Epoch: 15	Batch: 200	Avg-Loss: 0.4634	Training Accuracy : 0.7758
# Epoch: 15	Batch: 250	Avg-Loss: 0.4507	Training Accuracy : 0.7845
# Epoch: 15	Batch: 300	Avg-Loss: 0.4526	Training Accuracy : 0.7866
# Epoch: 15	Batch: 350	Avg-Loss: 0.4497	Training Accuracy : 0.7830
# Epoch: 15	Batch: 400	Avg-Loss: 0.4501	Training Accuracy : 0.7895
# Epoch: 15	Batch: 450	Avg-Loss: 0.4431	Training Accuracy : 0.7886
# Epoch: 15	Batch: 500	Avg-Loss: 0.4357	Training Accuracy : 0.7909
# Epoch: 15	Batch: 550	Avg-Loss: 0.4317	Training Accuracy : 0.7978
# Epoch: 15	Batch: 600	Avg-Loss: 0.4275	Training Accuracy : 0.7998
# Epoch: 15	Batch: 650	Avg-Loss: 0.4288	Training Accuracy : 0.8013
# Epoch: 15, Validation Loss: 0.964, Validation Accuracy: 0.530
# Epoch: 16	Batch: 50	Avg-Loss: 0.3999	Training Accuracy : 0.8186
# Epoch: 16	Batch: 100	Avg-Loss: 0.3990	Training Accuracy : 0.8189
# Epoch: 16	Batch: 150	Avg-Loss: 0.3936	Training Accuracy : 0.8163
# Epoch: 16	Batch: 200	Avg-Loss: 0.3855	Training Accuracy : 0.8222
# Epoch: 16	Batch: 250	Avg-Loss: 0.3976	Training Accuracy : 0.8159
# Epoch: 16	Batch: 300	Avg-Loss: 0.4010	Training Accuracy : 0.8116
# Epoch: 16	Batch: 350	Avg-Loss: 0.4102	Training Accuracy : 0.8095
# Epoch: 16	Batch: 400	Avg-Loss: 0.3873	Training Accuracy : 0.8244
# Epoch: 16	Batch: 450	Avg-Loss: 0.3784	Training Accuracy : 0.8278
# Epoch: 16	Batch: 500	Avg-Loss: 0.3902	Training Accuracy : 0.8228
# Epoch: 16	Batch: 550	Avg-Loss: 0.3852	Training Accuracy : 0.8272
# Epoch: 16	Batch: 600	Avg-Loss: 0.3847	Training Accuracy : 0.8250
# Epoch: 16	Batch: 650	Avg-Loss: 0.3744	Training Accuracy : 0.8280
# Epoch    17: reducing learning rate of group 0 to 6.2500e-03.
# Epoch: 16, Validation Loss: 1.015, Validation Accuracy: 0.519
# Epoch: 17	Batch: 50	Avg-Loss: 0.3132	Training Accuracy : 0.8658
# Epoch: 17	Batch: 100	Avg-Loss: 0.3039	Training Accuracy : 0.8700
# Epoch: 17	Batch: 150	Avg-Loss: 0.2904	Training Accuracy : 0.8730
# Epoch: 17	Batch: 200	Avg-Loss: 0.2960	Training Accuracy : 0.8712
# Epoch: 17	Batch: 250	Avg-Loss: 0.2933	Training Accuracy : 0.8730
# Epoch: 17	Batch: 300	Avg-Loss: 0.2901	Training Accuracy : 0.8752
# Epoch: 17	Batch: 350	Avg-Loss: 0.2958	Training Accuracy : 0.8752
# Epoch: 17	Batch: 400	Avg-Loss: 0.2822	Training Accuracy : 0.8752
# Epoch: 17	Batch: 450	Avg-Loss: 0.2937	Training Accuracy : 0.8714
# Epoch: 17	Batch: 500	Avg-Loss: 0.2849	Training Accuracy : 0.8762
# Epoch: 17	Batch: 550	Avg-Loss: 0.2652	Training Accuracy : 0.8927
# Epoch: 17	Batch: 600	Avg-Loss: 0.2806	Training Accuracy : 0.8784
# Epoch: 17	Batch: 650	Avg-Loss: 0.2803	Training Accuracy : 0.8822
# Epoch: 17, Validation Loss: 1.440, Validation Accuracy: 0.507
# Epoch: 18	Batch: 50	Avg-Loss: 0.2475	Training Accuracy : 0.8981
# Epoch: 18	Batch: 100	Avg-Loss: 0.2456	Training Accuracy : 0.8942
# Epoch: 18	Batch: 150	Avg-Loss: 0.2544	Training Accuracy : 0.8888
# Epoch: 18	Batch: 200	Avg-Loss: 0.2475	Training Accuracy : 0.8944
# Epoch: 18	Batch: 250	Avg-Loss: 0.2656	Training Accuracy : 0.8838
# Epoch: 18	Batch: 300	Avg-Loss: 0.2738	Training Accuracy : 0.8855
# Epoch: 18	Batch: 350	Avg-Loss: 0.2587	Training Accuracy : 0.8897
# Epoch: 18	Batch: 400	Avg-Loss: 0.2559	Training Accuracy : 0.8914
# Epoch: 18	Batch: 450	Avg-Loss: 0.2620	Training Accuracy : 0.8877
# Epoch: 18	Batch: 500	Avg-Loss: 0.2729	Training Accuracy : 0.8844
# Epoch: 18	Batch: 550	Avg-Loss: 0.2576	Training Accuracy : 0.8928
# Epoch: 18	Batch: 600	Avg-Loss: 0.2744	Training Accuracy : 0.8803
# Epoch: 18	Batch: 650	Avg-Loss: 0.2551	Training Accuracy : 0.8945
# Epoch: 18, Validation Loss: 1.559, Validation Accuracy: 0.508
# Epoch: 19	Batch: 50	Avg-Loss: 0.2220	Training Accuracy : 0.9044
# Epoch: 19	Batch: 100	Avg-Loss: 0.2254	Training Accuracy : 0.9066
# Epoch: 19	Batch: 150	Avg-Loss: 0.2289	Training Accuracy : 0.9062
# Epoch: 19	Batch: 200	Avg-Loss: 0.2430	Training Accuracy : 0.9036
# Epoch: 19	Batch: 250	Avg-Loss: 0.2392	Training Accuracy : 0.9020
# Epoch: 19	Batch: 300	Avg-Loss: 0.2236	Training Accuracy : 0.9084
# Epoch: 19	Batch: 350	Avg-Loss: 0.2284	Training Accuracy : 0.9030
# Epoch: 19	Batch: 400	Avg-Loss: 0.2392	Training Accuracy : 0.8986
# Epoch: 19	Batch: 450	Avg-Loss: 0.2501	Training Accuracy : 0.8920
# Epoch: 19	Batch: 500	Avg-Loss: 0.2449	Training Accuracy : 0.8972
# Epoch: 19	Batch: 550	Avg-Loss: 0.2555	Training Accuracy : 0.8966
# Epoch: 19	Batch: 600	Avg-Loss: 0.2455	Training Accuracy : 0.9002
# Epoch: 19	Batch: 650	Avg-Loss: 0.2366	Training Accuracy : 0.9061
# Epoch    20: reducing learning rate of group 0 to 3.1250e-03.
# Epoch: 19, Validation Loss: 1.629, Validation Accuracy: 0.515
# Epoch: 20	Batch: 50	Avg-Loss: 0.1885	Training Accuracy : 0.9239
# Epoch: 20	Batch: 100	Avg-Loss: 0.1862	Training Accuracy : 0.9245
# Epoch: 20	Batch: 150	Avg-Loss: 0.1690	Training Accuracy : 0.9327
# Epoch: 20	Batch: 200	Avg-Loss: 0.1685	Training Accuracy : 0.9327
# Epoch: 20	Batch: 250	Avg-Loss: 0.1832	Training Accuracy : 0.9256
# Epoch: 20	Batch: 300	Avg-Loss: 0.1631	Training Accuracy : 0.9352
# Epoch: 20	Batch: 350	Avg-Loss: 0.1674	Training Accuracy : 0.9277
# Epoch: 20	Batch: 400	Avg-Loss: 0.1678	Training Accuracy : 0.9334
# Epoch: 20	Batch: 450	Avg-Loss: 0.1674	Training Accuracy : 0.9306
# Epoch: 20	Batch: 500	Avg-Loss: 0.1726	Training Accuracy : 0.9287
# Epoch: 20	Batch: 550	Avg-Loss: 0.1875	Training Accuracy : 0.9230
# Epoch: 20	Batch: 600	Avg-Loss: 0.1762	Training Accuracy : 0.9261
# Epoch: 20	Batch: 650	Avg-Loss: 0.1705	Training Accuracy : 0.9308
# Epoch: 20, Validation Loss: 1.871, Validation Accuracy: 0.523
# Epoch: 21	Batch: 50	Avg-Loss: 0.1393	Training Accuracy : 0.9470
# Epoch: 21	Batch: 100	Avg-Loss: 0.1382	Training Accuracy : 0.9463
# Epoch: 21	Batch: 150	Avg-Loss: 0.1377	Training Accuracy : 0.9448
# Epoch: 21	Batch: 200	Avg-Loss: 0.1403	Training Accuracy : 0.9473
# Epoch: 21	Batch: 250	Avg-Loss: 0.1507	Training Accuracy : 0.9386
# Epoch: 21	Batch: 300	Avg-Loss: 0.1562	Training Accuracy : 0.9378
# Epoch: 21	Batch: 350	Avg-Loss: 0.1427	Training Accuracy : 0.9423
# Epoch: 21	Batch: 400	Avg-Loss: 0.1664	Training Accuracy : 0.9333
# Epoch: 24	Batch: 50	Avg-Loss: 0.0823	Training Accuracy : 0.9675
# Epoch: 24	Batch: 100	Avg-Loss: 0.0743	Training Accuracy : 0.9722
# Epoch: 24	Batch: 150	Avg-Loss: 0.0761	Training Accuracy : 0.9694
# Epoch: 24	Batch: 200	Avg-Loss: 0.0813	Training Accuracy : 0.9675
# Epoch: 24	Batch: 250	Avg-Loss: 0.0811	Training Accuracy : 0.9675
# Epoch: 24	Batch: 300	Avg-Loss: 0.0928	Training Accuracy : 0.9645
# Epoch: 24	Batch: 350	Avg-Loss: 0.0869	Training Accuracy : 0.9670
# Epoch: 24	Batch: 400	Avg-Loss: 0.0841	Training Accuracy : 0.9659
# Epoch: 24	Batch: 450	Avg-Loss: 0.0928	Training Accuracy : 0.9645
# Epoch: 24	Batch: 500	Avg-Loss: 0.0892	Training Accuracy : 0.9663
# Epoch: 24	Batch: 550	Avg-Loss: 0.0948	Training Accuracy : 0.9619
# Epoch: 24	Batch: 600	Avg-Loss: 0.0955	Training Accuracy : 0.9631
# Epoch: 24	Batch: 650	Avg-Loss: 0.0911	Training Accuracy : 0.9630
# Epoch: 24, Validation Loss: 2.738, Validation Accuracy: 0.517
# Epoch: 25	Batch: 50	Avg-Loss: 0.0782	Training Accuracy : 0.9709
# Epoch: 25	Batch: 100	Avg-Loss: 0.0783	Training Accuracy : 0.9681
# Epoch: 25	Batch: 150	Avg-Loss: 0.0780	Training Accuracy : 0.9730
# Epoch: 25	Batch: 200	Avg-Loss: 0.0766	Training Accuracy : 0.9711
# Epoch: 25	Batch: 250	Avg-Loss: 0.0747	Training Accuracy : 0.9706
# Epoch: 25	Batch: 300	Avg-Loss: 0.0738	Training Accuracy : 0.9714
# Epoch: 25	Batch: 350	Avg-Loss: 0.0863	Training Accuracy : 0.9673
# Epoch: 25	Batch: 400	Avg-Loss: 0.0901	Training Accuracy : 0.9644
# Epoch: 25	Batch: 450	Avg-Loss: 0.0812	Training Accuracy : 0.9689
# Epoch: 25	Batch: 500	Avg-Loss: 0.0801	Training Accuracy : 0.9703
# Epoch: 25	Batch: 550	Avg-Loss: 0.0894	Training Accuracy : 0.9642
# Epoch: 25	Batch: 600	Avg-Loss: 0.0708	Training Accuracy : 0.9730
# Epoch: 25	Batch: 650	Avg-Loss: 0.0798	Training Accuracy : 0.9711
# Epoch    26: reducing learning rate of group 0 to 7.8125e-04.
# Epoch: 25, Validation Loss: 2.909, Validation Accuracy: 0.515
# Epoch: 26	Batch: 50	Avg-Loss: 0.0658	Training Accuracy : 0.9761
# Epoch: 26	Batch: 100	Avg-Loss: 0.0564	Training Accuracy : 0.9784
# Epoch: 26	Batch: 150	Avg-Loss: 0.0556	Training Accuracy : 0.9805
# Epoch: 26	Batch: 200	Avg-Loss: 0.0573	Training Accuracy : 0.9777
# Epoch: 26	Batch: 250	Avg-Loss: 0.0560	Training Accuracy : 0.9788
# Epoch: 26	Batch: 300	Avg-Loss: 0.0713	Training Accuracy : 0.9753
# Epoch: 26	Batch: 350	Avg-Loss: 0.0579	Training Accuracy : 0.9792
# Epoch: 26	Batch: 400	Avg-Loss: 0.0616	Training Accuracy : 0.9769
# Epoch: 26	Batch: 450	Avg-Loss: 0.0565	Training Accuracy : 0.9780
# Epoch: 26	Batch: 500	Avg-Loss: 0.0503	Training Accuracy : 0.9802
# Epoch: 26	Batch: 550	Avg-Loss: 0.0591	Training Accuracy : 0.9783
# Epoch: 26	Batch: 600	Avg-Loss: 0.0601	Training Accuracy : 0.9733
# Epoch: 26	Batch: 650	Avg-Loss: 0.0611	Training Accuracy : 0.9756
# Epoch: 26, Validation Loss: 3.284, Validation Accuracy: 0.508
# Epoch: 27	Batch: 50	Avg-Loss: 0.0416	Training Accuracy : 0.9845
# Epoch: 27	Batch: 100	Avg-Loss: 0.0397	Training Accuracy : 0.9869
# Epoch: 27	Batch: 150	Avg-Loss: 0.0466	Training Accuracy : 0.9823
# Epoch: 27	Batch: 200	Avg-Loss: 0.0494	Training Accuracy : 0.9814
# Epoch: 27	Batch: 250	Avg-Loss: 0.0474	Training Accuracy : 0.9823
# Epoch: 27	Batch: 300	Avg-Loss: 0.0572	Training Accuracy : 0.9811
# Epoch: 27	Batch: 350	Avg-Loss: 0.0575	Training Accuracy : 0.9797
# Epoch: 27	Batch: 400	Avg-Loss: 0.0572	Training Accuracy : 0.9795
# Epoch: 27	Batch: 450	Avg-Loss: 0.0517	Training Accuracy : 0.9798
# Epoch: 27	Batch: 500	Avg-Loss: 0.0601	Training Accuracy : 0.9795
# Epoch: 27	Batch: 550	Avg-Loss: 0.0446	Training Accuracy : 0.9834
# Epoch: 27	Batch: 600	Avg-Loss: 0.0563	Training Accuracy : 0.9791
# Epoch: 27	Batch: 650	Avg-Loss: 0.0430	Training Accuracy : 0.9853
# Epoch: 27, Validation Loss: 3.553, Validation Accuracy: 0.509
# Epoch: 28	Batch: 50	Avg-Loss: 0.0434	Training Accuracy : 0.9831
# Epoch: 28	Batch: 100	Avg-Loss: 0.0416	Training Accuracy : 0.9844
# Epoch: 28	Batch: 150	Avg-Loss: 0.0457	Training Accuracy : 0.9841
# Epoch: 28	Batch: 200	Avg-Loss: 0.0457	Training Accuracy : 0.9816
# Epoch: 28	Batch: 250	Avg-Loss: 0.0416	Training Accuracy : 0.9855
# Epoch: 28	Batch: 300	Avg-Loss: 0.0492	Training Accuracy : 0.9812
# Epoch: 28	Batch: 350	Avg-Loss: 0.0464	Training Accuracy : 0.9827
# Epoch: 28	Batch: 400	Avg-Loss: 0.0491	Training Accuracy : 0.9812
# Epoch: 28	Batch: 450	Avg-Loss: 0.0517	Training Accuracy : 0.9806
# Epoch: 28	Batch: 500	Avg-Loss: 0.0515	Training Accuracy : 0.9823
# Epoch: 28	Batch: 550	Avg-Loss: 0.0589	Training Accuracy : 0.9789
# Epoch: 28	Batch: 600	Avg-Loss: 0.0504	Training Accuracy : 0.9798
# Epoch: 28	Batch: 650	Avg-Loss: 0.0468	Training Accuracy : 0.9814
# Epoch    29: reducing learning rate of group 0 to 3.9063e-04.
# Epoch: 33, Validation Loss: 4.105, Validation Accuracy: 0.511
# Epoch: 34	Batch: 50	Avg-Loss: 0.0201	Training Accuracy : 0.9927
# Epoch: 34	Batch: 100	Avg-Loss: 0.0240	Training Accuracy : 0.9919
# Epoch: 34	Batch: 150	Avg-Loss: 0.0279	Training Accuracy : 0.9909
# Epoch: 34	Batch: 200	Avg-Loss: 0.0230	Training Accuracy : 0.9919
# Epoch: 34	Batch: 250	Avg-Loss: 0.0234	Training Accuracy : 0.9917
# Epoch: 34	Batch: 300	Avg-Loss: 0.0201	Training Accuracy : 0.9927
# Epoch: 34	Batch: 350	Avg-Loss: 0.0256	Training Accuracy : 0.9916
# Epoch: 34	Batch: 400	Avg-Loss: 0.0273	Training Accuracy : 0.9908
# Epoch: 34	Batch: 450	Avg-Loss: 0.0280	Training Accuracy : 0.9908
# Epoch: 34	Batch: 500	Avg-Loss: 0.0357	Training Accuracy : 0.9878
# Epoch: 34	Batch: 550	Avg-Loss: 0.0278	Training Accuracy : 0.9895
# Epoch: 34	Batch: 600	Avg-Loss: 0.0263	Training Accuracy : 0.9905
# Epoch: 34	Batch: 650	Avg-Loss: 0.0266	Training Accuracy : 0.9900
# Epoch    35: reducing learning rate of group 0 to 9.7656e-05.
# Epoch: 34, Validation Loss: 4.146, Validation Accuracy: 0.511
# Epoch: 35	Batch: 50	Avg-Loss: 0.0199	Training Accuracy : 0.9933
# Epoch: 35	Batch: 100	Avg-Loss: 0.0227	Training Accuracy : 0.9925
# Epoch: 35	Batch: 150	Avg-Loss: 0.0209	Training Accuracy : 0.9923
# Epoch: 35	Batch: 200	Avg-Loss: 0.0302	Training Accuracy : 0.9912
# Epoch: 35	Batch: 250	Avg-Loss: 0.0242	Training Accuracy : 0.9919
# Epoch: 35	Batch: 300	Avg-Loss: 0.0226	Training Accuracy : 0.9927
# Epoch: 35	Batch: 350	Avg-Loss: 0.0231	Training Accuracy : 0.9912
# Epoch: 35	Batch: 400	Avg-Loss: 0.0227	Training Accuracy : 0.9920
# Epoch: 35	Batch: 450	Avg-Loss: 0.0194	Training Accuracy : 0.9930
# Epoch: 35	Batch: 500	Avg-Loss: 0.0287	Training Accuracy : 0.9891
# Epoch: 35	Batch: 550	Avg-Loss: 0.0255	Training Accuracy : 0.9905
# Epoch: 35	Batch: 600	Avg-Loss: 0.0206	Training Accuracy : 0.9927
# Epoch: 35	Batch: 650	Avg-Loss: 0.0282	Training Accuracy : 0.9903
# Epoch: 35, Validation Loss: 4.176, Validation Accuracy: 0.512
# Epoch: 36	Batch: 50	Avg-Loss: 0.0192	Training Accuracy : 0.9938
# Epoch: 36	Batch: 100	Avg-Loss: 0.0217	Training Accuracy : 0.9920
# Epoch: 36	Batch: 150	Avg-Loss: 0.0173	Training Accuracy : 0.9939
# Epoch: 36	Batch: 200	Avg-Loss: 0.0204	Training Accuracy : 0.9928
# Epoch: 36	Batch: 250	Avg-Loss: 0.0276	Training Accuracy : 0.9909
# Epoch: 36	Batch: 300	Avg-Loss: 0.0231	Training Accuracy : 0.9928
# Epoch: 36	Batch: 350	Avg-Loss: 0.0258	Training Accuracy : 0.9900
# Epoch: 36	Batch: 400	Avg-Loss: 0.0212	Training Accuracy : 0.9931
# Epoch: 36	Batch: 450	Avg-Loss: 0.0253	Training Accuracy : 0.9914
# Epoch: 36	Batch: 500	Avg-Loss: 0.0215	Training Accuracy : 0.9933
# Epoch: 36	Batch: 550	Avg-Loss: 0.0275	Training Accuracy : 0.9905
# Epoch: 36	Batch: 600	Avg-Loss: 0.0220	Training Accuracy : 0.9925
# Epoch: 36	Batch: 650	Avg-Loss: 0.0223	Training Accuracy : 0.9920
# Epoch: 36, Validation Loss: 4.177, Validation Accuracy: 0.511
# Epoch: 37	Batch: 50	Avg-Loss: 0.0259	Training Accuracy : 0.9905
# Epoch: 37	Batch: 100	Avg-Loss: 0.0195	Training Accuracy : 0.9936
# Epoch: 37	Batch: 150	Avg-Loss: 0.0233	Training Accuracy : 0.9930
# Epoch: 37	Batch: 200	Avg-Loss: 0.0228	Training Accuracy : 0.9919
# Epoch: 37	Batch: 250	Avg-Loss: 0.0222	Training Accuracy : 0.9927
# Epoch: 37	Batch: 300	Avg-Loss: 0.0329	Training Accuracy : 0.9884
# Epoch: 37	Batch: 350	Avg-Loss: 0.0242	Training Accuracy : 0.9919
# Epoch: 37	Batch: 400	Avg-Loss: 0.0198	Training Accuracy : 0.9930
# Epoch: 37	Batch: 450	Avg-Loss: 0.0213	Training Accuracy : 0.9931
# Epoch: 37	Batch: 500	Avg-Loss: 0.0248	Training Accuracy : 0.9920
# Epoch: 37	Batch: 550	Avg-Loss: 0.0293	Training Accuracy : 0.9906
# Epoch: 37	Batch: 600	Avg-Loss: 0.0195	Training Accuracy : 0.9944
# Epoch: 37	Batch: 650	Avg-Loss: 0.0204	Training Accuracy : 0.9916
# Epoch    38: reducing learning rate of group 0 to 4.8828e-05.
# Epoch: 37, Validation Loss: 4.245, Validation Accuracy: 0.509
# Epoch: 38	Batch: 50	Avg-Loss: 0.0222	Training Accuracy : 0.9920
# Epoch: 38	Batch: 100	Avg-Loss: 0.0247	Training Accuracy : 0.9919
# Epoch: 38	Batch: 150	Avg-Loss: 0.0178	Training Accuracy : 0.9933
# Epoch: 38	Batch: 200	Avg-Loss: 0.0290	Training Accuracy : 0.9898
# Epoch: 38	Batch: 250	Avg-Loss: 0.0230	Training Accuracy : 0.9922
# Epoch: 38	Batch: 300	Avg-Loss: 0.0177	Training Accuracy : 0.9934
# Epoch: 38	Batch: 350	Avg-Loss: 0.0209	Training Accuracy : 0.9927
# Epoch: 38	Batch: 400	Avg-Loss: 0.0201	Training Accuracy : 0.9939
# Epoch: 38	Batch: 450	Avg-Loss: 0.0199	Training Accuracy : 0.9927
# Epoch: 38	Batch: 500	Avg-Loss: 0.0233	Training Accuracy : 0.9922
# Epoch: 38	Batch: 550	Avg-Loss: 0.0210	Training Accuracy : 0.9922
# Epoch: 38	Batch: 600	Avg-Loss: 0.0204	Training Accuracy : 0.9923
# Epoch: 41	Batch: 300	Avg-Loss: 0.0197	Training Accuracy : 0.9939
# Epoch: 41	Batch: 350	Avg-Loss: 0.0264	Training Accuracy : 0.9906
# Epoch: 41	Batch: 400	Avg-Loss: 0.0191	Training Accuracy : 0.9931
# Epoch: 41	Batch: 450	Avg-Loss: 0.0179	Training Accuracy : 0.9923
# Epoch: 41	Batch: 500	Avg-Loss: 0.0213	Training Accuracy : 0.9914
# Epoch: 41	Batch: 550	Avg-Loss: 0.0177	Training Accuracy : 0.9938
# Epoch: 41	Batch: 600	Avg-Loss: 0.0233	Training Accuracy : 0.9922
# Epoch: 41	Batch: 650	Avg-Loss: 0.0167	Training Accuracy : 0.9939
# Epoch: 41, Validation Loss: 4.285, Validation Accuracy: 0.511
# Epoch: 42	Batch: 50	Avg-Loss: 0.0184	Training Accuracy : 0.9938
# Epoch: 42	Batch: 100	Avg-Loss: 0.0208	Training Accuracy : 0.9930
# Epoch: 42	Batch: 150	Avg-Loss: 0.0150	Training Accuracy : 0.9956
# Epoch: 42	Batch: 200	Avg-Loss: 0.0237	Training Accuracy : 0.9917
# Epoch: 42	Batch: 250	Avg-Loss: 0.0229	Training Accuracy : 0.9931
# Epoch: 42	Batch: 300	Avg-Loss: 0.0173	Training Accuracy : 0.9945
# Epoch: 42	Batch: 350	Avg-Loss: 0.0178	Training Accuracy : 0.9938
# Epoch: 42	Batch: 400	Avg-Loss: 0.0191	Training Accuracy : 0.9936
# Epoch: 42	Batch: 450	Avg-Loss: 0.0237	Training Accuracy : 0.9902
# Epoch: 42	Batch: 500	Avg-Loss: 0.0156	Training Accuracy : 0.9941
# Epoch: 42	Batch: 550	Avg-Loss: 0.0185	Training Accuracy : 0.9936
# Epoch: 42	Batch: 600	Avg-Loss: 0.0334	Training Accuracy : 0.9898
# Epoch: 42	Batch: 650	Avg-Loss: 0.0232	Training Accuracy : 0.9908
# Epoch: 42, Validation Loss: 4.340, Validation Accuracy: 0.514
# Epoch: 43	Batch: 50	Avg-Loss: 0.0241	Training Accuracy : 0.9917
# Epoch: 43	Batch: 100	Avg-Loss: 0.0231	Training Accuracy : 0.9920
# Epoch: 43	Batch: 150	Avg-Loss: 0.0256	Training Accuracy : 0.9914
# Epoch: 43	Batch: 200	Avg-Loss: 0.0254	Training Accuracy : 0.9903
# Epoch: 43	Batch: 250	Avg-Loss: 0.0167	Training Accuracy : 0.9942
# Epoch: 43	Batch: 300	Avg-Loss: 0.0198	Training Accuracy : 0.9931
# Epoch: 43	Batch: 350	Avg-Loss: 0.0204	Training Accuracy : 0.9928
# Epoch: 43	Batch: 400	Avg-Loss: 0.0228	Training Accuracy : 0.9920
# Epoch: 43	Batch: 450	Avg-Loss: 0.0209	Training Accuracy : 0.9925
# Epoch: 43	Batch: 500	Avg-Loss: 0.0300	Training Accuracy : 0.9916
# Epoch: 43	Batch: 550	Avg-Loss: 0.0242	Training Accuracy : 0.9911
# Epoch: 43	Batch: 600	Avg-Loss: 0.0191	Training Accuracy : 0.9941
# Epoch: 43	Batch: 650	Avg-Loss: 0.0189	Training Accuracy : 0.9931
# Epoch    44: reducing learning rate of group 0 to 1.2207e-05.
# Epoch: 43, Validation Loss: 4.293, Validation Accuracy: 0.511
# Epoch: 44	Batch: 50	Avg-Loss: 0.0201	Training Accuracy : 0.9925
# Epoch: 44	Batch: 100	Avg-Loss: 0.0129	Training Accuracy : 0.9969
# Epoch: 44	Batch: 150	Avg-Loss: 0.0220	Training Accuracy : 0.9922
# Epoch: 44	Batch: 200	Avg-Loss: 0.0211	Training Accuracy : 0.9922
# Epoch: 44	Batch: 250	Avg-Loss: 0.0296	Training Accuracy : 0.9892
# Epoch: 44	Batch: 300	Avg-Loss: 0.0193	Training Accuracy : 0.9931
# Epoch: 44	Batch: 350	Avg-Loss: 0.0188	Training Accuracy : 0.9936
# Epoch: 44	Batch: 400	Avg-Loss: 0.0184	Training Accuracy : 0.9941
# Epoch: 44	Batch: 450	Avg-Loss: 0.0195	Training Accuracy : 0.9939
# Epoch: 44	Batch: 500	Avg-Loss: 0.0182	Training Accuracy : 0.9936
# Epoch: 44	Batch: 550	Avg-Loss: 0.0240	Training Accuracy : 0.9920
# Epoch: 44	Batch: 600	Avg-Loss: 0.0192	Training Accuracy : 0.9933
# Epoch: 44	Batch: 650	Avg-Loss: 0.0167	Training Accuracy : 0.9945
# Epoch: 44, Validation Loss: 4.321, Validation Accuracy: 0.514
# Epoch: 45	Batch: 50	Avg-Loss: 0.0240	Training Accuracy : 0.9911
# Epoch: 45	Batch: 100	Avg-Loss: 0.0194	Training Accuracy : 0.9923
# Epoch: 45	Batch: 150	Avg-Loss: 0.0199	Training Accuracy : 0.9930
# Epoch: 45	Batch: 200	Avg-Loss: 0.0169	Training Accuracy : 0.9944
# Epoch: 45	Batch: 250	Avg-Loss: 0.0218	Training Accuracy : 0.9927
# Epoch: 45	Batch: 300	Avg-Loss: 0.0259	Training Accuracy : 0.9912
# Epoch: 45	Batch: 350	Avg-Loss: 0.0166	Training Accuracy : 0.9953
# Epoch: 45	Batch: 400	Avg-Loss: 0.0227	Training Accuracy : 0.9919
# Epoch: 45	Batch: 450	Avg-Loss: 0.0154	Training Accuracy : 0.9955
# Epoch: 45	Batch: 500	Avg-Loss: 0.0188	Training Accuracy : 0.9942
# Epoch: 45	Batch: 550	Avg-Loss: 0.0135	Training Accuracy : 0.9967
# Epoch: 45	Batch: 600	Avg-Loss: 0.0150	Training Accuracy : 0.9956
# Epoch: 45	Batch: 650	Avg-Loss: 0.0202	Training Accuracy : 0.9931
# Epoch: 45, Validation Loss: 4.280, Validation Accuracy: 0.512
# Epoch: 46	Batch: 50	Avg-Loss: 0.0167	Training Accuracy : 0.9942
# Epoch: 46	Batch: 100	Avg-Loss: 0.0252	Training Accuracy : 0.9925
# Epoch: 46	Batch: 150	Avg-Loss: 0.0215	Training Accuracy : 0.9933
# Epoch: 46	Batch: 200	Avg-Loss: 0.0158	Training Accuracy : 0.9938
# Epoch: 46	Batch: 250	Avg-Loss: 0.0192	Training Accuracy : 0.9933
# Epoch: 48	Batch: 600	Avg-Loss: 0.0194	Training Accuracy : 0.9933
# Epoch: 48	Batch: 650	Avg-Loss: 0.0168	Training Accuracy : 0.9945
# Epoch: 48, Validation Loss: 4.280, Validation Accuracy: 0.513
# Epoch: 49	Batch: 50	Avg-Loss: 0.0195	Training Accuracy : 0.9942
# Epoch: 49	Batch: 100	Avg-Loss: 0.0260	Training Accuracy : 0.9912
# Epoch: 49	Batch: 150	Avg-Loss: 0.0257	Training Accuracy : 0.9922
# Epoch: 49	Batch: 200	Avg-Loss: 0.0247	Training Accuracy : 0.9922
# Epoch: 49	Batch: 250	Avg-Loss: 0.0185	Training Accuracy : 0.9938
# Epoch: 49	Batch: 300	Avg-Loss: 0.0221	Training Accuracy : 0.9922
# Epoch: 49	Batch: 350	Avg-Loss: 0.0184	Training Accuracy : 0.9941
# Epoch: 49	Batch: 400	Avg-Loss: 0.0226	Training Accuracy : 0.9916
# Epoch: 49	Batch: 450	Avg-Loss: 0.0235	Training Accuracy : 0.9919
# Epoch: 49	Batch: 500	Avg-Loss: 0.0157	Training Accuracy : 0.9953
# Epoch: 49	Batch: 550	Avg-Loss: 0.0186	Training Accuracy : 0.9938
# Epoch: 49	Batch: 600	Avg-Loss: 0.0268	Training Accuracy : 0.9902
# Epoch: 49	Batch: 650	Avg-Loss: 0.0174	Training Accuracy : 0.9945
# Epoch    50: reducing learning rate of group 0 to 3.0518e-06.
# Epoch: 49, Validation Loss: 4.280, Validation Accuracy: 0.511
# Epoch: 50	Batch: 50	Avg-Loss: 0.0177	Training Accuracy : 0.9942
# Epoch: 50	Batch: 100	Avg-Loss: 0.0205	Training Accuracy : 0.9933
# Epoch: 50	Batch: 150	Avg-Loss: 0.0204	Training Accuracy : 0.9939
# Epoch: 50	Batch: 200	Avg-Loss: 0.0182	Training Accuracy : 0.9930
# Epoch: 50	Batch: 250	Avg-Loss: 0.0236	Training Accuracy : 0.9925
# Epoch: 50	Batch: 300	Avg-Loss: 0.0185	Training Accuracy : 0.9938
# Epoch: 50	Batch: 350	Avg-Loss: 0.0232	Training Accuracy : 0.9927
# Epoch: 50	Batch: 400	Avg-Loss: 0.0182	Training Accuracy : 0.9934
# Epoch: 50	Batch: 450	Avg-Loss: 0.0151	Training Accuracy : 0.9958
# Epoch: 50	Batch: 500	Avg-Loss: 0.0198	Training Accuracy : 0.9936
# Epoch: 50	Batch: 550	Avg-Loss: 0.0223	Training Accuracy : 0.9934
# Epoch: 50	Batch: 600	Avg-Loss: 0.0189	Training Accuracy : 0.9934
# Epoch: 50	Batch: 650	Avg-Loss: 0.0246	Training Accuracy : 0.9903
# Epoch: 50, Validation Loss: 4.270, Validation Accuracy: 0.510
# Epoch: 51	Batch: 50	Avg-Loss: 0.0179	Training Accuracy : 0.9941
# Epoch: 51	Batch: 100	Avg-Loss: 0.0193	Training Accuracy : 0.9944
# Epoch: 51	Batch: 150	Avg-Loss: 0.0189	Training Accuracy : 0.9936
# Epoch: 51	Batch: 200	Avg-Loss: 0.0166	Training Accuracy : 0.9952
# Epoch: 55	Batch: 250	Avg-Loss: 0.0256	Training Accuracy : 0.9917
# Epoch: 55	Batch: 300	Avg-Loss: 0.0201	Training Accuracy : 0.9925
# Epoch: 55	Batch: 350	Avg-Loss: 0.0154	Training Accuracy : 0.9950
# Epoch: 55	Batch: 400	Avg-Loss: 0.0195	Training Accuracy : 0.9931
# Epoch: 55	Batch: 450	Avg-Loss: 0.0184	Training Accuracy : 0.9931
# Epoch: 55	Batch: 500	Avg-Loss: 0.0160	Training Accuracy : 0.9952
# Epoch: 55	Batch: 550	Avg-Loss: 0.0193	Training Accuracy : 0.9933
# Epoch: 55	Batch: 600	Avg-Loss: 0.0165	Training Accuracy : 0.9941
# Epoch: 55	Batch: 650	Avg-Loss: 0.0230	Training Accuracy : 0.9923
# Epoch    56: reducing learning rate of group 0 to 7.6294e-07.
# Epoch: 55, Validation Loss: 4.295, Validation Accuracy: 0.512
# Epoch: 56	Batch: 50	Avg-Loss: 0.0258	Training Accuracy : 0.9905
# Epoch: 56	Batch: 100	Avg-Loss: 0.0183	Training Accuracy : 0.9938
# Epoch: 56	Batch: 150	Avg-Loss: 0.0248	Training Accuracy : 0.9906
# Epoch: 56	Batch: 200	Avg-Loss: 0.0212	Training Accuracy : 0.9928
# Epoch: 56	Batch: 250	Avg-Loss: 0.0224	Training Accuracy : 0.9923
# Epoch: 56	Batch: 300	Avg-Loss: 0.0175	Training Accuracy : 0.9941
# Epoch: 56	Batch: 350	Avg-Loss: 0.0188	Training Accuracy : 0.9944
# Epoch: 56	Batch: 400	Avg-Loss: 0.0273	Training Accuracy : 0.9917
# Epoch: 56	Batch: 450	Avg-Loss: 0.0178	Training Accuracy : 0.9945
# Epoch: 56	Batch: 500	Avg-Loss: 0.0177	Training Accuracy : 0.9942
# Epoch: 56	Batch: 550	Avg-Loss: 0.0316	Training Accuracy : 0.9883
# Epoch: 56	Batch: 600	Avg-Loss: 0.0222	Training Accuracy : 0.9927
# Epoch: 56	Batch: 650	Avg-Loss: 0.0186	Training Accuracy : 0.9933
# Epoch: 56, Validation Loss: 4.365, Validation Accuracy: 0.512
# Epoch: 57	Batch: 50	Avg-Loss: 0.0169	Training Accuracy : 0.9947
# Epoch: 57	Batch: 100	Avg-Loss: 0.0320	Training Accuracy : 0.9909
# Epoch: 57	Batch: 150	Avg-Loss: 0.0304	Training Accuracy : 0.9909
# Epoch: 57	Batch: 200	Avg-Loss: 0.0148	Training Accuracy : 0.9947
# Epoch: 57	Batch: 250	Avg-Loss: 0.0169	Training Accuracy : 0.9948
# Epoch: 57	Batch: 300	Avg-Loss: 0.0198	Training Accuracy : 0.9930
# Epoch: 57	Batch: 350	Avg-Loss: 0.0149	Training Accuracy : 0.9950
# Epoch: 57	Batch: 400	Avg-Loss: 0.0229	Training Accuracy : 0.9916
# Epoch: 57	Batch: 450	Avg-Loss: 0.0236	Training Accuracy : 0.9914
# Epoch: 57	Batch: 500	Avg-Loss: 0.0226	Training Accuracy : 0.9922
# Epoch: 57	Batch: 550	Avg-Loss: 0.0177	Training Accuracy : 0.9938
# Epoch: 60	Batch: 200	Avg-Loss: 0.0159	Training Accuracy : 0.9952
# Epoch: 60	Batch: 250	Avg-Loss: 0.0211	Training Accuracy : 0.9920
# Epoch: 60	Batch: 300	Avg-Loss: 0.0194	Training Accuracy : 0.9936
# Epoch: 60	Batch: 350	Avg-Loss: 0.0194	Training Accuracy : 0.9930
# Epoch: 60	Batch: 400	Avg-Loss: 0.0222	Training Accuracy : 0.9933
# Epoch: 60	Batch: 450	Avg-Loss: 0.0196	Training Accuracy : 0.9925
# Epoch: 60	Batch: 500	Avg-Loss: 0.0174	Training Accuracy : 0.9944
# Epoch: 60	Batch: 550	Avg-Loss: 0.0229	Training Accuracy : 0.9920
# Epoch: 60	Batch: 600	Avg-Loss: 0.0202	Training Accuracy : 0.9927
# Epoch: 60	Batch: 650	Avg-Loss: 0.0253	Training Accuracy : 0.9916
# Epoch: 60, Validation Loss: 4.314, Validation Accuracy: 0.511
# Epoch: 61	Batch: 50	Avg-Loss: 0.0196	Training Accuracy : 0.9930
# Epoch: 61	Batch: 100	Avg-Loss: 0.0159	Training Accuracy : 0.9944
# Epoch: 61	Batch: 150	Avg-Loss: 0.0207	Training Accuracy : 0.9928
# Epoch: 61	Batch: 200	Avg-Loss: 0.0224	Training Accuracy : 0.9916
# Epoch: 61	Batch: 250	Avg-Loss: 0.0167	Training Accuracy : 0.9948
# Epoch: 61	Batch: 300	Avg-Loss: 0.0185	Training Accuracy : 0.9936
# Epoch: 61	Batch: 350	Avg-Loss: 0.0192	Training Accuracy : 0.9936
# Epoch: 61	Batch: 400	Avg-Loss: 0.0190	Training Accuracy : 0.9939
# Epoch: 61	Batch: 450	Avg-Loss: 0.0154	Training Accuracy : 0.9947
# Epoch: 61	Batch: 500	Avg-Loss: 0.0162	Training Accuracy : 0.9939
# Epoch: 61	Batch: 550	Avg-Loss: 0.0164	Training Accuracy : 0.9941
# Epoch: 61	Batch: 600	Avg-Loss: 0.0164	Training Accuracy : 0.9948
# Epoch: 61	Batch: 650	Avg-Loss: 0.0209	Training Accuracy : 0.9934
# Epoch    62: reducing learning rate of group 0 to 1.9073e-07.
# Epoch: 61, Validation Loss: 4.342, Validation Accuracy: 0.512
# Epoch: 62	Batch: 50	Avg-Loss: 0.0201	Training Accuracy : 0.9933
# Epoch: 62	Batch: 100	Avg-Loss: 0.0240	Training Accuracy : 0.9928
# Epoch: 62	Batch: 150	Avg-Loss: 0.0158	Training Accuracy : 0.9939
# Epoch: 62	Batch: 200	Avg-Loss: 0.0210	Training Accuracy : 0.9933
# Epoch: 62	Batch: 250	Avg-Loss: 0.0180	Training Accuracy : 0.9939
# Epoch: 62	Batch: 300	Avg-Loss: 0.0159	Training Accuracy : 0.9958
# Epoch: 62	Batch: 350	Avg-Loss: 0.0219	Training Accuracy : 0.9920
# Epoch: 62	Batch: 400	Avg-Loss: 0.0205	Training Accuracy : 0.9925
# Epoch: 62	Batch: 450	Avg-Loss: 0.0203	Training Accuracy : 0.9930
# Epoch: 62	Batch: 500	Avg-Loss: 0.0196	Training Accuracy : 0.9931
# Epoch: 62	Batch: 550	Avg-Loss: 0.0228	Training Accuracy : 0.9908
# Epoch: 62	Batch: 600	Avg-Loss: 0.0181	Training Accuracy : 0.9939
# Epoch: 62	Batch: 650	Avg-Loss: 0.0209	Training Accuracy : 0.9927
# Epoch: 62, Validation Loss: 4.378, Validation Accuracy: 0.513
# Epoch: 63	Batch: 50	Avg-Loss: 0.0188	Training Accuracy : 0.9919
# Epoch: 63	Batch: 100	Avg-Loss: 0.0166	Training Accuracy : 0.9942
# Epoch: 63	Batch: 150	Avg-Loss: 0.0223	Training Accuracy : 0.9911
# Epoch: 63	Batch: 200	Avg-Loss: 0.0202	Training Accuracy : 0.9933
# Epoch: 63	Batch: 250	Avg-Loss: 0.0177	Training Accuracy : 0.9939
# Epoch: 63	Batch: 300	Avg-Loss: 0.0189	Training Accuracy : 0.9933
# Epoch: 63	Batch: 350	Avg-Loss: 0.0219	Training Accuracy : 0.9927
# Epoch: 63	Batch: 400	Avg-Loss: 0.0199	Training Accuracy : 0.9933
# Epoch: 63	Batch: 450	Avg-Loss: 0.0192	Training Accuracy : 0.9933
# Epoch: 63	Batch: 500	Avg-Loss: 0.0268	Training Accuracy : 0.9911
# Epoch: 63	Batch: 550	Avg-Loss: 0.0294	Training Accuracy : 0.9897
# Epoch: 63	Batch: 600	Avg-Loss: 0.0207	Training Accuracy : 0.9925
# Epoch: 63	Batch: 650	Avg-Loss: 0.0232	Training Accuracy : 0.9925
# Epoch: 63, Validation Loss: 4.259, Validation Accuracy: 0.513
# Epoch: 64	Batch: 50	Avg-Loss: 0.0213	Training Accuracy : 0.9917
# Epoch: 64	Batch: 100	Avg-Loss: 0.0226	Training Accuracy : 0.9917
# Epoch: 64	Batch: 150	Avg-Loss: 0.0199	Training Accuracy : 0.9934
# Epoch: 64	Batch: 200	Avg-Loss: 0.0174	Training Accuracy : 0.9941
# Epoch: 64	Batch: 250	Avg-Loss: 0.0177	Training Accuracy : 0.9941
# Epoch: 64	Batch: 300	Avg-Loss: 0.0179	Training Accuracy : 0.9934
# Epoch: 64	Batch: 350	Avg-Loss: 0.0164	Training Accuracy : 0.9944
# Epoch: 64	Batch: 400	Avg-Loss: 0.0124	Training Accuracy : 0.9962
# Epoch: 64	Batch: 450	Avg-Loss: 0.0211	Training Accuracy : 0.9948
# Epoch: 64	Batch: 500	Avg-Loss: 0.0191	Training Accuracy : 0.9938
# Epoch: 64	Batch: 550	Avg-Loss: 0.0199	Training Accuracy : 0.9933
# Epoch: 64	Batch: 600	Avg-Loss: 0.0256	Training Accuracy : 0.9900
# Epoch: 64	Batch: 650	Avg-Loss: 0.0246	Training Accuracy : 0.9923
# Epoch    65: reducing learning rate of group 0 to 9.5367e-08.
# Epoch: 64, Validation Loss: 4.258, Validation Accuracy: 0.512
# Epoch: 65	Batch: 50	Avg-Loss: 0.0173	Training Accuracy : 0.9950
# Epoch: 65	Batch: 100	Avg-Loss: 0.0219	Training Accuracy : 0.9922
# Epoch: 65	Batch: 150	Avg-Loss: 0.0182	Training Accuracy : 0.9930
# Epoch: 65	Batch: 200	Avg-Loss: 0.0212	Training Accuracy : 0.9922
# Epoch: 65	Batch: 250	Avg-Loss: 0.0203	Training Accuracy : 0.9925
# Epoch: 65	Batch: 300	Avg-Loss: 0.0190	Training Accuracy : 0.9933
# Epoch: 65	Batch: 350	Avg-Loss: 0.0232	Training Accuracy : 0.9920
# Epoch: 65	Batch: 400	Avg-Loss: 0.0210	Training Accuracy : 0.9925
# Epoch: 65	Batch: 450	Avg-Loss: 0.0167	Training Accuracy : 0.9942
# Epoch: 65	Batch: 500	Avg-Loss: 0.0212	Training Accuracy : 0.9930
# Epoch: 65	Batch: 550	Avg-Loss: 0.0155	Training Accuracy : 0.9956
# Epoch: 65	Batch: 600	Avg-Loss: 0.0165	Training Accuracy : 0.9952
# Epoch: 65	Batch: 650	Avg-Loss: 0.0230	Training Accuracy : 0.9920
# Epoch: 65, Validation Loss: 4.370, Validation Accuracy: 0.511
# Epoch: 66	Batch: 50	Avg-Loss: 0.0136	Training Accuracy : 0.9967
# Epoch: 66	Batch: 100	Avg-Loss: 0.0134	Training Accuracy : 0.9962
# Epoch: 66	Batch: 150	Avg-Loss: 0.0168	Training Accuracy : 0.9948
# Epoch: 66	Batch: 200	Avg-Loss: 0.0195	Training Accuracy : 0.9928
# Epoch: 66	Batch: 250	Avg-Loss: 0.0286	Training Accuracy : 0.9917
# Epoch: 66	Batch: 300	Avg-Loss: 0.0161	Training Accuracy : 0.9942
# Epoch: 66	Batch: 350	Avg-Loss: 0.0199	Training Accuracy : 0.9928
# Epoch: 66	Batch: 400	Avg-Loss: 0.0235	Training Accuracy : 0.9922
# Epoch: 66	Batch: 450	Avg-Loss: 0.0167	Training Accuracy : 0.9952
# Epoch: 66	Batch: 500	Avg-Loss: 0.0196	Training Accuracy : 0.9933
# Epoch: 66	Batch: 550	Avg-Loss: 0.0203	Training Accuracy : 0.9928
# Epoch: 66	Batch: 600	Avg-Loss: 0.0323	Training Accuracy : 0.9906
# Epoch: 66	Batch: 650	Avg-Loss: 0.0182	Training Accuracy : 0.9942
# Epoch: 66, Validation Loss: 4.313, Validation Accuracy: 0.513
# Epoch: 67	Batch: 50	Avg-Loss: 0.0177	Training Accuracy : 0.9934
# Epoch: 67	Batch: 100	Avg-Loss: 0.0168	Training Accuracy : 0.9944
# Epoch: 67	Batch: 150	Avg-Loss: 0.0201	Training Accuracy : 0.9922
# Epoch: 67	Batch: 200	Avg-Loss: 0.0204	Training Accuracy : 0.9916
# Epoch: 67	Batch: 250	Avg-Loss: 0.0226	Training Accuracy : 0.9917
# Epoch: 67	Batch: 300	Avg-Loss: 0.0164	Training Accuracy : 0.9953
# Epoch: 67	Batch: 350	Avg-Loss: 0.0220	Training Accuracy : 0.9905
# Epoch: 67	Batch: 400	Avg-Loss: 0.0162	Training Accuracy : 0.9950
# Epoch: 67	Batch: 450	Avg-Loss: 0.0186	Training Accuracy : 0.9939
# Epoch: 67	Batch: 500	Avg-Loss: 0.0181	Training Accuracy : 0.9928
# Epoch: 67	Batch: 550	Avg-Loss: 0.0206	Training Accuracy : 0.9927
# Epoch: 67	Batch: 600	Avg-Loss: 0.0233	Training Accuracy : 0.9916
# Epoch: 67	Batch: 650	Avg-Loss: 0.0212	Training Accuracy : 0.9916
# Epoch    68: reducing learning rate of group 0 to 4.7684e-08.
# Epoch: 67, Validation Loss: 4.372, Validation Accuracy: 0.508
# Epoch: 68	Batch: 50	Avg-Loss: 0.0185	Training Accuracy : 0.9920
# Epoch: 68	Batch: 100	Avg-Loss: 0.0324	Training Accuracy : 0.9889
# Epoch: 68	Batch: 150	Avg-Loss: 0.0165	Training Accuracy : 0.9945
# Epoch: 68	Batch: 200	Avg-Loss: 0.0268	Training Accuracy : 0.9914
# Epoch: 68	Batch: 250	Avg-Loss: 0.0151	Training Accuracy : 0.9952
# Epoch: 68	Batch: 300	Avg-Loss: 0.0248	Training Accuracy : 0.9919
# Epoch: 68	Batch: 350	Avg-Loss: 0.0192	Training Accuracy : 0.9930
# Epoch: 68	Batch: 400	Avg-Loss: 0.0150	Training Accuracy : 0.9961
# Epoch: 68	Batch: 450	Avg-Loss: 0.0211	Training Accuracy : 0.9931
# Epoch: 68	Batch: 500	Avg-Loss: 0.0271	Training Accuracy : 0.9897
# Epoch: 68	Batch: 550	Avg-Loss: 0.0224	Training Accuracy : 0.9916
# Epoch: 68	Batch: 600	Avg-Loss: 0.0216	Training Accuracy : 0.9933
# Epoch: 68	Batch: 650	Avg-Loss: 0.0212	Training Accuracy : 0.9923
# Epoch: 68, Validation Loss: 4.298, Validation Accuracy: 0.512
# Epoch: 69	Batch: 50	Avg-Loss: 0.0213	Training Accuracy : 0.9922
# Epoch: 69	Batch: 100	Avg-Loss: 0.0161	Training Accuracy : 0.9952
# Epoch: 69	Batch: 150	Avg-Loss: 0.0253	Training Accuracy : 0.9922
# Epoch: 69	Batch: 200	Avg-Loss: 0.0283	Training Accuracy : 0.9909
# Epoch: 69	Batch: 250	Avg-Loss: 0.0202	Training Accuracy : 0.9936
# Epoch: 69	Batch: 300	Avg-Loss: 0.0208	Training Accuracy : 0.9933
# Epoch: 69	Batch: 350	Avg-Loss: 0.0179	Training Accuracy : 0.9945
# Epoch: 69	Batch: 400	Avg-Loss: 0.0209	Training Accuracy : 0.9931
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-11214fc76365> in <module>()
#      16
#      17         loss = criterion(outputs, y.long())
# ---> 18         loss.backward()
#      19         optimizer.step()
#      20         avg_loss += loss.item()
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     157
#     158
#
# KeyboardInterrupt:

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Fri Nov 26 18:24:24 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0    56W / 250W |   7597MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_1+1/best_model_4.pt"))
network = network.to(device)

# %%
network.eval()
num_correct = 0
for x, y in tqdm(test_loader):
  x, y = x.to(device), y.to(device)
  outputs = network(x)
  num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

test_acc = num_correct / len(test_set)
print(test_acc)
# Out:
# 100%|██████████| 142/142 [01:05<00:00,  2.15it/s]
# 0.4769095117381241

# %%
print(test_acc)
# Out:
# 0.247840864768485
