# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("4+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149670.jpg', 'frame_149739.jpg', 'fram...     16
# 1      ('frame_149738.jpg', 'frame_149692.jpg', 'fram...     80
# 2      ('frame_149729.jpg', 'frame_149716.jpg', 'fram...     86
# 3      ('frame_149669.jpg', 'frame_149712.jpg', 'fram...      7
# 4      ('frame_149683.jpg', 'frame_149707.jpg', 'fram...     34
# ...                                                  ...    ...
# 17942  ('frame_180809.jpg', 'frame_174579.jpg', 'fram...    101
# 17943  ('frame_174581.jpg', 'frame_174634.jpg', 'fram...     14
# 17944  ('frame_174605.jpg', 'frame_174596.jpg', 'fram...     54
# 17945  ('frame_181123.jpg', 'frame_174585.jpg', 'fram...     96
# 17946  ('frame_181333.jpg', 'frame_174579.jpg', 'fram...     97
#
# [17947 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, transform=None, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]
        self.transform = transform

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            # img = torchvision.transforms.Normalize(mean=[0.2068, 0.2242, 0.2269], std=[0.2520, 0.2394, 0.2320])(img)
            if self.transform:
                img = self.transform(img)
            images.extend(img)
        x = torch.stack(images)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([15, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
# transform_train = torchvision.transforms.Compose([
#     torchvision.transforms.Normalize(mean=[0.4967, 0.4858, 0.4584, 0.4969, 0.4700, 0.4585, 0.4964, 0.4854, 0.4580, 0.4972, 0.4862, 0.4585, 0.4964, 0.4857, 0.4584],
#                                       std=[0.2681, 0.2574, 0.2433, 0.2678, 0.2500, 0.2429, 0.2679, 0.2572, 0.2428, 0.2680, 0.2573, 0.2428, 0.2680, 0.2574, 0.2431])
# ])

transform_train = torchvision.transforms.Compose([
    torchvision.transforms.ColorJitter(brightness=0, contrast=0, saturation=0.3, hue=0)
])

# %%
batch_size = 128

# training data
train_set = MyDataSet(train_data, transform_train)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %%
# def batch_mean_and_sd(loader, num_channels):
    
#     cnt = 0
#     fst_moment = torch.empty(num_channels)
#     snd_moment = torch.empty(num_channels)

#     for images, _ in tqdm(loader):
#         b, c, h, w = images.shape
#         nb_pixels = b * h * w
#         sum_ = torch.sum(images, dim=[0, 2, 3])
#         sum_of_square = torch.sum(images ** 2,
#                                   dim=[0, 2, 3])
#         fst_moment = (cnt * fst_moment + sum_) / (cnt + nb_pixels)
#         snd_moment = (cnt * snd_moment + sum_of_square) / (cnt + nb_pixels)
#         cnt += nb_pixels

#     mean, std = fst_moment, torch.sqrt(snd_moment - fst_moment ** 2)        
#     return mean,std
  
# num_channels = 15
# mean, std = batch_mean_and_sd(train_loader, num_channels)
# print("mean and std: \n", mean, std)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding,num_classes))


    def forward(self, x):
      out = self.cnn(x)
      out = self.mlp(out)
      return out

# %%
numEpochs = 100
in_features = 15 # TODO: change RGB channels according to num of frames
embedding = 512

learningRate = 0.1
weightDecay = 1e-4

num_classes = 120

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_classes)
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(16, numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/regnet_ours_data3/best_model_" + str(epoch) + ".pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 16	Batch: 50	Avg-Loss: 1.2918	Training Accuracy : 0.4658
# Epoch: 16	Batch: 100	Avg-Loss: 1.3102	Training Accuracy : 0.4637
# Epoch: 16	Batch: 150	Avg-Loss: 1.3382	Training Accuracy : 0.4470
# Epoch: 16	Batch: 200	Avg-Loss: 1.3649	Training Accuracy : 0.4419
# Epoch: 16	Batch: 250	Avg-Loss: 1.3706	Training Accuracy : 0.4506
# Epoch: 16	Batch: 300	Avg-Loss: 1.3462	Training Accuracy : 0.4594
# Epoch: 16	Batch: 350	Avg-Loss: 1.3579	Training Accuracy : 0.4533
# Epoch: 16	Batch: 400	Avg-Loss: 1.3940	Training Accuracy : 0.4452
# Epoch: 16	Batch: 450	Avg-Loss: 1.4237	Training Accuracy : 0.4320
# Epoch: 16	Batch: 500	Avg-Loss: 1.3810	Training Accuracy : 0.4547
# Epoch: 16	Batch: 550	Avg-Loss: 1.3786	Training Accuracy : 0.4528
# Epoch: 16	Batch: 600	Avg-Loss: 1.3988	Training Accuracy : 0.4511
# Epoch: 16	Batch: 650	Avg-Loss: 1.4014	Training Accuracy : 0.4587
# Epoch: 16, Validation Loss: 2.697, Validation Accuracy: 0.275
# Epoch: 17	Batch: 50	Avg-Loss: 1.2425	Training Accuracy : 0.4992
# Epoch: 17	Batch: 100	Avg-Loss: 1.2379	Training Accuracy : 0.5005
# Epoch: 17	Batch: 150	Avg-Loss: 1.2888	Training Accuracy : 0.4867
# Epoch: 17	Batch: 200	Avg-Loss: 1.2913	Training Accuracy : 0.4942
# Epoch: 17	Batch: 250	Avg-Loss: 1.2932	Training Accuracy : 0.4972
# Epoch: 17	Batch: 300	Avg-Loss: 1.2846	Training Accuracy : 0.5056
# Epoch: 17	Batch: 350	Avg-Loss: 1.2934	Training Accuracy : 0.4991
# Epoch: 17	Batch: 400	Avg-Loss: 1.3078	Training Accuracy : 0.4983
# Epoch: 17	Batch: 450	Avg-Loss: 1.3369	Training Accuracy : 0.4952
# Epoch: 17	Batch: 500	Avg-Loss: 1.2870	Training Accuracy : 0.5044
# Epoch: 17	Batch: 550	Avg-Loss: 1.3018	Training Accuracy : 0.5162
# Epoch: 17	Batch: 600	Avg-Loss: 1.3111	Training Accuracy : 0.5145
# Epoch: 17	Batch: 650	Avg-Loss: 1.2936	Training Accuracy : 0.5169
# Epoch: 17, Validation Loss: 2.750, Validation Accuracy: 0.259
# Epoch: 18	Batch: 50	Avg-Loss: 1.1655	Training Accuracy : 0.5672
# Epoch: 18	Batch: 100	Avg-Loss: 1.1461	Training Accuracy : 0.5717
# Epoch: 18	Batch: 150	Avg-Loss: 1.1426	Training Accuracy : 0.5794
# Epoch: 18	Batch: 200	Avg-Loss: 1.1894	Training Accuracy : 0.5689
# Epoch: 18	Batch: 250	Avg-Loss: 1.1613	Training Accuracy : 0.5742
# Epoch: 18	Batch: 300	Avg-Loss: 1.1846	Training Accuracy : 0.5702
# Epoch: 18	Batch: 350	Avg-Loss: 1.1835	Training Accuracy : 0.5695
# Epoch: 18	Batch: 400	Avg-Loss: 1.2205	Training Accuracy : 0.5636
# Epoch: 18	Batch: 450	Avg-Loss: 1.2103	Training Accuracy : 0.5731
# Epoch: 18	Batch: 500	Avg-Loss: 1.1756	Training Accuracy : 0.5900
# Epoch: 18	Batch: 550	Avg-Loss: 1.1728	Training Accuracy : 0.5850
# Epoch: 18	Batch: 600	Avg-Loss: 1.1834	Training Accuracy : 0.5837
# Epoch: 18	Batch: 650	Avg-Loss: 1.1564	Training Accuracy : 0.5989
# Epoch: 18, Validation Loss: 3.438, Validation Accuracy: 0.244
# Epoch: 19	Batch: 50	Avg-Loss: 0.9822	Training Accuracy : 0.6622
# Epoch: 19	Batch: 100	Avg-Loss: 0.9706	Training Accuracy : 0.6597
# Epoch: 19	Batch: 150	Avg-Loss: 1.0241	Training Accuracy : 0.6511
# Epoch: 19	Batch: 200	Avg-Loss: 0.9891	Training Accuracy : 0.6555
# Epoch: 19	Batch: 250	Avg-Loss: 1.0414	Training Accuracy : 0.6378
# Epoch: 19	Batch: 300	Avg-Loss: 1.0036	Training Accuracy : 0.6530
# Epoch: 19	Batch: 350	Avg-Loss: 1.0036	Training Accuracy : 0.6594
# Epoch: 19	Batch: 400	Avg-Loss: 1.0316	Training Accuracy : 0.6506
# Epoch: 19	Batch: 450	Avg-Loss: 1.0299	Training Accuracy : 0.6483
# Epoch: 19	Batch: 500	Avg-Loss: 1.0093	Training Accuracy : 0.6597
# Epoch: 19	Batch: 550	Avg-Loss: 1.0185	Training Accuracy : 0.6561
# Epoch: 19	Batch: 600	Avg-Loss: 1.0259	Training Accuracy : 0.6494
# Epoch: 19	Batch: 650	Avg-Loss: 1.0366	Training Accuracy : 0.6431
# Epoch     4: reducing learning rate of group 0 to 1.2500e-02.
# Epoch: 19, Validation Loss: 3.339, Validation Accuracy: 0.243
# Epoch: 20	Batch: 50	Avg-Loss: 0.7493	Training Accuracy : 0.7502
# Epoch: 20	Batch: 100	Avg-Loss: 0.6808	Training Accuracy : 0.7700
# Epoch: 20	Batch: 150	Avg-Loss: 0.6502	Training Accuracy : 0.7855
# Epoch: 20	Batch: 200	Avg-Loss: 0.6196	Training Accuracy : 0.7947
# Epoch: 20	Batch: 250	Avg-Loss: 0.6574	Training Accuracy : 0.7772
# Epoch: 20	Batch: 300	Avg-Loss: 0.6221	Training Accuracy : 0.7911
# Epoch: 20	Batch: 350	Avg-Loss: 0.6171	Training Accuracy : 0.7942
# Epoch: 20	Batch: 400	Avg-Loss: 0.6072	Training Accuracy : 0.7944
# Epoch: 20	Batch: 450	Avg-Loss: 0.6221	Training Accuracy : 0.7863
# Epoch: 20	Batch: 500	Avg-Loss: 0.6443	Training Accuracy : 0.7825
# Epoch: 20	Batch: 550	Avg-Loss: 0.6369	Training Accuracy : 0.7817
# Epoch: 20	Batch: 600	Avg-Loss: 0.6202	Training Accuracy : 0.7884
# Epoch: 20	Batch: 650	Avg-Loss: 0.6249	Training Accuracy : 0.7852
# Epoch: 20, Validation Loss: 4.123, Validation Accuracy: 0.272
# Epoch: 21	Batch: 50	Avg-Loss: 0.5022	Training Accuracy : 0.8358
# Epoch: 21	Batch: 100	Avg-Loss: 0.4818	Training Accuracy : 0.8406
# Epoch: 21	Batch: 150	Avg-Loss: 0.4533	Training Accuracy : 0.8503
# Epoch: 21	Batch: 200	Avg-Loss: 0.4791	Training Accuracy : 0.8402
# Epoch: 21	Batch: 250	Avg-Loss: 0.4880	Training Accuracy : 0.8364
# Epoch: 21	Batch: 300	Avg-Loss: 0.5209	Training Accuracy : 0.8273
# Epoch: 21	Batch: 350	Avg-Loss: 0.5187	Training Accuracy : 0.8222
# Epoch: 21	Batch: 400	Avg-Loss: 0.5048	Training Accuracy : 0.8309
# Epoch: 21	Batch: 450	Avg-Loss: 0.4956	Training Accuracy : 0.8336
# Epoch: 21	Batch: 500	Avg-Loss: 0.4983	Training Accuracy : 0.8305
# Epoch: 21	Batch: 550	Avg-Loss: 0.5591	Training Accuracy : 0.8102
# Epoch: 21	Batch: 600	Avg-Loss: 0.5467	Training Accuracy : 0.8130
# Epoch: 21	Batch: 650	Avg-Loss: 0.5573	Training Accuracy : 0.8061
# Epoch: 21, Validation Loss: 4.610, Validation Accuracy: 0.268
# Epoch: 22	Batch: 50	Avg-Loss: 0.4314	Training Accuracy : 0.8595
# Epoch: 22	Batch: 100	Avg-Loss: 0.3963	Training Accuracy : 0.8678
# Epoch: 22	Batch: 150	Avg-Loss: 0.3997	Training Accuracy : 0.8694
# Epoch: 22	Batch: 200	Avg-Loss: 0.4030	Training Accuracy : 0.8670
# Epoch: 22	Batch: 250	Avg-Loss: 0.4408	Training Accuracy : 0.8502
# Epoch: 22	Batch: 300	Avg-Loss: 0.4444	Training Accuracy : 0.8516
# Epoch: 22	Batch: 350	Avg-Loss: 0.4542	Training Accuracy : 0.8467
# Epoch: 22	Batch: 400	Avg-Loss: 0.4371	Training Accuracy : 0.8531
# Epoch: 22	Batch: 450	Avg-Loss: 0.4670	Training Accuracy : 0.8423
# Epoch: 22	Batch: 500	Avg-Loss: 0.4799	Training Accuracy : 0.8397
# Epoch: 22	Batch: 550	Avg-Loss: 0.4464	Training Accuracy : 0.8425
# Epoch: 22	Batch: 600	Avg-Loss: 0.4817	Training Accuracy : 0.8398
# Epoch: 22	Batch: 650	Avg-Loss: 0.5054	Training Accuracy : 0.8287
# Epoch     7: reducing learning rate of group 0 to 6.2500e-03.
# Epoch: 22, Validation Loss: 4.410, Validation Accuracy: 0.262
# Epoch: 23	Batch: 50	Avg-Loss: 0.3490	Training Accuracy : 0.8891
# Epoch: 23	Batch: 100	Avg-Loss: 0.3154	Training Accuracy : 0.9000
# Epoch: 23	Batch: 150	Avg-Loss: 0.3036	Training Accuracy : 0.9044
# Epoch: 23	Batch: 200	Avg-Loss: 0.3049	Training Accuracy : 0.9023
# Epoch: 23	Batch: 250	Avg-Loss: 0.3098	Training Accuracy : 0.9005
# Epoch: 23	Batch: 300	Avg-Loss: 0.3126	Training Accuracy : 0.9023
# Epoch: 23	Batch: 350	Avg-Loss: 0.2996	Training Accuracy : 0.9059
# Epoch: 23	Batch: 400	Avg-Loss: 0.3022	Training Accuracy : 0.9020
# Epoch: 23	Batch: 450	Avg-Loss: 0.2950	Training Accuracy : 0.9077
# Epoch: 23	Batch: 500	Avg-Loss: 0.2810	Training Accuracy : 0.9106
# Epoch: 23	Batch: 550	Avg-Loss: 0.2846	Training Accuracy : 0.9102
# Epoch: 23	Batch: 600	Avg-Loss: 0.3028	Training Accuracy : 0.9044
# Epoch: 23	Batch: 650	Avg-Loss: 0.2845	Training Accuracy : 0.9080
# Epoch: 23, Validation Loss: 4.839, Validation Accuracy: 0.278
# Epoch: 24	Batch: 50	Avg-Loss: 0.2399	Training Accuracy : 0.9272
# Epoch: 24	Batch: 100	Avg-Loss: 0.2391	Training Accuracy : 0.9281
# Epoch: 24	Batch: 150	Avg-Loss: 0.2289	Training Accuracy : 0.9300
# Epoch: 24	Batch: 200	Avg-Loss: 0.2267	Training Accuracy : 0.9331
# Epoch: 24	Batch: 250	Avg-Loss: 0.2378	Training Accuracy : 0.9272
# Epoch: 24	Batch: 300	Avg-Loss: 0.2285	Training Accuracy : 0.9280
# Epoch: 24	Batch: 350	Avg-Loss: 0.2402	Training Accuracy : 0.9286
# Epoch: 24	Batch: 400	Avg-Loss: 0.2378	Training Accuracy : 0.9263
# Epoch: 24	Batch: 450	Avg-Loss: 0.2424	Training Accuracy : 0.9264
# Epoch: 24	Batch: 500	Avg-Loss: 0.2393	Training Accuracy : 0.9258
# Epoch: 24	Batch: 550	Avg-Loss: 0.2397	Training Accuracy : 0.9252
# Epoch: 24	Batch: 600	Avg-Loss: 0.2642	Training Accuracy : 0.9164
# Epoch: 24	Batch: 650	Avg-Loss: 0.2490	Training Accuracy : 0.9220
# Epoch: 24, Validation Loss: 4.987, Validation Accuracy: 0.273
# Epoch: 25	Batch: 50	Avg-Loss: 0.2072	Training Accuracy : 0.9389
# Epoch: 25	Batch: 100	Avg-Loss: 0.1929	Training Accuracy : 0.9425
# Epoch: 25	Batch: 150	Avg-Loss: 0.1929	Training Accuracy : 0.9447
# Epoch: 25	Batch: 200	Avg-Loss: 0.1998	Training Accuracy : 0.9402
# Epoch: 25	Batch: 250	Avg-Loss: 0.2183	Training Accuracy : 0.9352
# Epoch: 25	Batch: 300	Avg-Loss: 0.2112	Training Accuracy : 0.9369
# Epoch: 25	Batch: 350	Avg-Loss: 0.2130	Training Accuracy : 0.9345
# Epoch: 25	Batch: 400	Avg-Loss: 0.2082	Training Accuracy : 0.9345
# Epoch: 25	Batch: 450	Avg-Loss: 0.2273	Training Accuracy : 0.9303
# Epoch: 25	Batch: 500	Avg-Loss: 0.2246	Training Accuracy : 0.9341
# Epoch: 25	Batch: 550	Avg-Loss: 0.2245	Training Accuracy : 0.9337
# Epoch: 25	Batch: 600	Avg-Loss: 0.2136	Training Accuracy : 0.9339
# Epoch: 25	Batch: 650	Avg-Loss: 0.2283	Training Accuracy : 0.9313
# Epoch    10: reducing learning rate of group 0 to 3.1250e-03.
# Epoch: 25, Validation Loss: 5.282, Validation Accuracy: 0.271
# Epoch: 26	Batch: 50	Avg-Loss: 0.1886	Training Accuracy : 0.9473
# Epoch: 26	Batch: 100	Avg-Loss: 0.1798	Training Accuracy : 0.9467
# Epoch: 26	Batch: 150	Avg-Loss: 0.1896	Training Accuracy : 0.9444
# Epoch: 26	Batch: 200	Avg-Loss: 0.1586	Training Accuracy : 0.9586
# Epoch: 26	Batch: 250	Avg-Loss: 0.1745	Training Accuracy : 0.9503
# Epoch: 26	Batch: 300	Avg-Loss: 0.1642	Training Accuracy : 0.9548
# Epoch: 26	Batch: 350	Avg-Loss: 0.1502	Training Accuracy : 0.9566
# Epoch: 26	Batch: 400	Avg-Loss: 0.1538	Training Accuracy : 0.9569
# Epoch: 26	Batch: 450	Avg-Loss: 0.1699	Training Accuracy : 0.9516
# Epoch: 26	Batch: 500	Avg-Loss: 0.1746	Training Accuracy : 0.9494
# Epoch: 26	Batch: 550	Avg-Loss: 0.1812	Training Accuracy : 0.9483
# Epoch: 26	Batch: 600	Avg-Loss: 0.1759	Training Accuracy : 0.9480
# Epoch: 26	Batch: 650	Avg-Loss: 0.1626	Training Accuracy : 0.9517
# Epoch: 26, Validation Loss: 5.258, Validation Accuracy: 0.274
# Epoch: 27	Batch: 50	Avg-Loss: 0.1568	Training Accuracy : 0.9545
# Epoch: 27	Batch: 100	Avg-Loss: 0.1405	Training Accuracy : 0.9636
# Epoch: 27	Batch: 150	Avg-Loss: 0.1579	Training Accuracy : 0.9575
# Epoch: 27	Batch: 200	Avg-Loss: 0.1578	Training Accuracy : 0.9552
# Epoch: 27	Batch: 250	Avg-Loss: 0.1550	Training Accuracy : 0.9572
# Epoch: 27	Batch: 300	Avg-Loss: 0.1591	Training Accuracy : 0.9534
# Epoch: 27	Batch: 350	Avg-Loss: 0.1599	Training Accuracy : 0.9552
# Epoch: 27	Batch: 400	Avg-Loss: 0.1541	Training Accuracy : 0.9558
# Epoch: 27	Batch: 450	Avg-Loss: 0.1613	Training Accuracy : 0.9547
# Epoch: 27	Batch: 500	Avg-Loss: 0.1452	Training Accuracy : 0.9602
# Epoch: 27	Batch: 550	Avg-Loss: 0.1554	Training Accuracy : 0.9558
# Epoch: 27	Batch: 600	Avg-Loss: 0.1410	Training Accuracy : 0.9595
# Epoch: 27	Batch: 650	Avg-Loss: 0.1496	Training Accuracy : 0.9578
# Epoch: 27, Validation Loss: 5.373, Validation Accuracy: 0.269
# Epoch: 28	Batch: 50	Avg-Loss: 0.1341	Training Accuracy : 0.9659
# Epoch: 28	Batch: 100	Avg-Loss: 0.1436	Training Accuracy : 0.9597
# Epoch: 28	Batch: 150	Avg-Loss: 0.1459	Training Accuracy : 0.9605
# Epoch: 28	Batch: 200	Avg-Loss: 0.1444	Training Accuracy : 0.9580
# Epoch: 28	Batch: 250	Avg-Loss: 0.1419	Training Accuracy : 0.9606
# Epoch: 28	Batch: 300	Avg-Loss: 0.1416	Training Accuracy : 0.9602
# Epoch: 28	Batch: 350	Avg-Loss: 0.1432	Training Accuracy : 0.9608
# Epoch: 28	Batch: 400	Avg-Loss: 0.1457	Training Accuracy : 0.9586
# Epoch: 28	Batch: 450	Avg-Loss: 0.1556	Training Accuracy : 0.9539
# Epoch: 28	Batch: 500	Avg-Loss: 0.1357	Training Accuracy : 0.9628
# Epoch: 28	Batch: 550	Avg-Loss: 0.1419	Training Accuracy : 0.9605
# Epoch: 28	Batch: 600	Avg-Loss: 0.1442	Training Accuracy : 0.9586
# Epoch: 28	Batch: 650	Avg-Loss: 0.1569	Training Accuracy : 0.9566
# Epoch    13: reducing learning rate of group 0 to 1.5625e-03.
# Epoch: 28, Validation Loss: 5.463, Validation Accuracy: 0.270
# Epoch: 29	Batch: 50	Avg-Loss: 0.1433	Training Accuracy : 0.9611
# Epoch: 29	Batch: 100	Avg-Loss: 0.1298	Training Accuracy : 0.9652
# Epoch: 29	Batch: 150	Avg-Loss: 0.1355	Training Accuracy : 0.9650
# Epoch: 29	Batch: 200	Avg-Loss: 0.1229	Training Accuracy : 0.9667
# Epoch: 29	Batch: 250	Avg-Loss: 0.1355	Training Accuracy : 0.9620
# Epoch: 29	Batch: 300	Avg-Loss: 0.1275	Training Accuracy : 0.9652
# Epoch: 29	Batch: 350	Avg-Loss: 0.1314	Training Accuracy : 0.9636
# Epoch: 29	Batch: 400	Avg-Loss: 0.1289	Training Accuracy : 0.9658
# Epoch: 29	Batch: 450	Avg-Loss: 0.1290	Training Accuracy : 0.9655
# Epoch: 29	Batch: 500	Avg-Loss: 0.1339	Training Accuracy : 0.9628
# Epoch: 29	Batch: 550	Avg-Loss: 0.1229	Training Accuracy : 0.9669
# Epoch: 29	Batch: 600	Avg-Loss: 0.1287	Training Accuracy : 0.9652
# Epoch: 29	Batch: 650	Avg-Loss: 0.1235	Training Accuracy : 0.9675
# Epoch: 29, Validation Loss: 5.458, Validation Accuracy: 0.274
# Epoch: 30	Batch: 50	Avg-Loss: 0.1139	Training Accuracy : 0.9688
# Epoch: 30	Batch: 100	Avg-Loss: 0.1116	Training Accuracy : 0.9719
# Epoch: 30	Batch: 150	Avg-Loss: 0.1246	Training Accuracy : 0.9659
# Epoch: 30	Batch: 200	Avg-Loss: 0.1263	Training Accuracy : 0.9673
# Epoch: 30	Batch: 250	Avg-Loss: 0.1162	Training Accuracy : 0.9667
# Epoch: 30	Batch: 300	Avg-Loss: 0.1206	Training Accuracy : 0.9675
# Epoch: 30	Batch: 350	Avg-Loss: 0.1170	Training Accuracy : 0.9658
# Epoch: 30	Batch: 400	Avg-Loss: 0.1433	Training Accuracy : 0.9622
# Epoch: 30	Batch: 450	Avg-Loss: 0.1159	Training Accuracy : 0.9675
# Epoch: 30	Batch: 500	Avg-Loss: 0.1198	Training Accuracy : 0.9673
# Epoch: 30	Batch: 550	Avg-Loss: 0.1430	Training Accuracy : 0.9611
# Epoch: 30	Batch: 600	Avg-Loss: 0.1123	Training Accuracy : 0.9714
# Epoch: 30	Batch: 650	Avg-Loss: 0.1210	Training Accuracy : 0.9675
# Epoch: 30, Validation Loss: 5.518, Validation Accuracy: 0.273
# Epoch: 31	Batch: 50	Avg-Loss: 0.1191	Training Accuracy : 0.9681
# Epoch: 31	Batch: 100	Avg-Loss: 0.1021	Training Accuracy : 0.9734
# Epoch: 31	Batch: 150	Avg-Loss: 0.1154	Training Accuracy : 0.9700
# Epoch: 31	Batch: 200	Avg-Loss: 0.1130	Training Accuracy : 0.9692
# Epoch: 31	Batch: 250	Avg-Loss: 0.1155	Training Accuracy : 0.9669
# Epoch: 31	Batch: 300	Avg-Loss: 0.1127	Training Accuracy : 0.9691
# Epoch: 31	Batch: 350	Avg-Loss: 0.1126	Training Accuracy : 0.9688
# Epoch: 31	Batch: 400	Avg-Loss: 0.1193	Training Accuracy : 0.9672
# Epoch: 31	Batch: 450	Avg-Loss: 0.1235	Training Accuracy : 0.9667
# Epoch: 31	Batch: 500	Avg-Loss: 0.1157	Training Accuracy : 0.9684
# Epoch: 31	Batch: 550	Avg-Loss: 0.1307	Training Accuracy : 0.9642
# Epoch: 31	Batch: 600	Avg-Loss: 0.1131	Training Accuracy : 0.9695
# Epoch: 31	Batch: 650	Avg-Loss: 0.1120	Training Accuracy : 0.9700
# Epoch    16: reducing learning rate of group 0 to 7.8125e-04.
# Epoch: 31, Validation Loss: 5.532, Validation Accuracy: 0.272
# Epoch: 32	Batch: 50	Avg-Loss: 0.1193	Training Accuracy : 0.9681
# Epoch: 32	Batch: 100	Avg-Loss: 0.1015	Training Accuracy : 0.9742
# Epoch: 32	Batch: 150	Avg-Loss: 0.1006	Training Accuracy : 0.9741
# Epoch: 32	Batch: 200	Avg-Loss: 0.1136	Training Accuracy : 0.9708
# Epoch: 32	Batch: 250	Avg-Loss: 0.1084	Training Accuracy : 0.9714
# Epoch: 32	Batch: 300	Avg-Loss: 0.1161	Training Accuracy : 0.9684
# Epoch: 32	Batch: 350	Avg-Loss: 0.1096	Training Accuracy : 0.9711
# Epoch: 32	Batch: 400	Avg-Loss: 0.1094	Training Accuracy : 0.9708
# Epoch: 32	Batch: 450	Avg-Loss: 0.1131	Training Accuracy : 0.9712
# Epoch: 32	Batch: 500	Avg-Loss: 0.1086	Training Accuracy : 0.9712
# Epoch: 32	Batch: 550	Avg-Loss: 0.1176	Training Accuracy : 0.9670
# Epoch: 32	Batch: 600	Avg-Loss: 0.1161	Training Accuracy : 0.9686
# Epoch: 32	Batch: 650	Avg-Loss: 0.0986	Training Accuracy : 0.9731
# Epoch: 32, Validation Loss: 5.556, Validation Accuracy: 0.270

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Mon Nov 29 23:24:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    38W / 250W |   1459MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/regnet_ours_data3/best_model_23.pt"))
network = network.to(device)

# %%
network.eval()
num_correct = 0
for x, y in tqdm(test_loader):
  x, y = x.to(device), y.to(device)
  outputs = network(x)
  num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

test_acc = num_correct / len(test_set)
print(test_acc)
# Out:
# 100%|██████████| 141/141 [02:42<00:00,  1.15s/it]
# 0.2584275923552683

# %%
print(test_acc)
# Out:
# 0.2584275923552683
