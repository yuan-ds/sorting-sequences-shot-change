# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("4+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149670.jpg', 'frame_149739.jpg', 'fram...     16
# 1      ('frame_149738.jpg', 'frame_149692.jpg', 'fram...     80
# 2      ('frame_149729.jpg', 'frame_149716.jpg', 'fram...     86
# 3      ('frame_149669.jpg', 'frame_149712.jpg', 'fram...      7
# 4      ('frame_149683.jpg', 'frame_149707.jpg', 'fram...     34
# ...                                                  ...    ...
# 17942  ('frame_180809.jpg', 'frame_174579.jpg', 'fram...    101
# 17943  ('frame_174581.jpg', 'frame_174634.jpg', 'fram...     14
# 17944  ('frame_174605.jpg', 'frame_174596.jpg', 'fram...     54
# 17945  ('frame_181123.jpg', 'frame_174585.jpg', 'fram...     96
# 17946  ('frame_181333.jpg', 'frame_174579.jpg', 'fram...     97
#
# [17947 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, transform=None, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]
        self.transform = transform

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            # img = torchvision.transforms.Normalize(mean=[0.2068, 0.2242, 0.2269], std=[0.2520, 0.2394, 0.2320])(img)
            images.extend(img)
        x = torch.stack(images)
        if self.transform:
          x = self.transform(x)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([15, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
# transform_train = torchvision.transforms.Compose([
#     torchvision.transforms.Normalize(mean=[0.4967, 0.4858, 0.4584, 0.4969, 0.4700, 0.4585, 0.4964, 0.4854, 0.4580, 0.4972, 0.4862, 0.4585, 0.4964, 0.4857, 0.4584],
#                                       std=[0.2681, 0.2574, 0.2433, 0.2678, 0.2500, 0.2429, 0.2679, 0.2572, 0.2428, 0.2680, 0.2573, 0.2428, 0.2680, 0.2574, 0.2431])
# ])

transform_train = torchvision.transforms.Compose([
    torchvision.transforms.RandomCrop(224, padding=28),
    torchvision.transforms.RandomHorizontalFlip(p=0.5)
])

# %%
batch_size = 128

# training data
train_set = MyDataSet(train_data, transform_train)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %%
# def batch_mean_and_sd(loader, num_channels):
    
#     cnt = 0
#     fst_moment = torch.empty(num_channels)
#     snd_moment = torch.empty(num_channels)

#     for images, _ in tqdm(loader):
#         b, c, h, w = images.shape
#         nb_pixels = b * h * w
#         sum_ = torch.sum(images, dim=[0, 2, 3])
#         sum_of_square = torch.sum(images ** 2,
#                                   dim=[0, 2, 3])
#         fst_moment = (cnt * fst_moment + sum_) / (cnt + nb_pixels)
#         snd_moment = (cnt * snd_moment + sum_of_square) / (cnt + nb_pixels)
#         cnt += nb_pixels

#     mean, std = fst_moment, torch.sqrt(snd_moment - fst_moment ** 2)        
#     return mean,std
  
# num_channels = 15
# mean, std = batch_mean_and_sd(train_loader, num_channels)
# print("mean and std: \n", mean, std)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding,num_classes))


    def forward(self, x):
      out = self.cnn(x)
      out = self.mlp(out)
      return out

# %%
numEpochs = 100
in_features = 15 # TODO: change RGB channels according to num of frames
embedding = 512

learningRate = 0.1
weightDecay = 1e-4

num_classes = 120

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/regnet_ours_data8/best_model_18.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(19, numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/regnet_ours_data8/best_model_" + str(epoch) + ".pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 19	Batch: 50	Avg-Loss: 1.8585	Training Accuracy : 0.3280
# Epoch: 19	Batch: 100	Avg-Loss: 1.8736	Training Accuracy : 0.3203
# Epoch: 19	Batch: 150	Avg-Loss: 1.8791	Training Accuracy : 0.3161
# Epoch: 19	Batch: 200	Avg-Loss: 1.8691	Training Accuracy : 0.3252
# Epoch: 19	Batch: 250	Avg-Loss: 1.8999	Training Accuracy : 0.3156
# Epoch: 19	Batch: 300	Avg-Loss: 1.8936	Training Accuracy : 0.3137
# Epoch: 19	Batch: 350	Avg-Loss: 1.8819	Training Accuracy : 0.3234
# Epoch: 19	Batch: 400	Avg-Loss: 1.8739	Training Accuracy : 0.3177
# Epoch: 19	Batch: 450	Avg-Loss: 1.9318	Training Accuracy : 0.3038
# Epoch: 19	Batch: 500	Avg-Loss: 1.8973	Training Accuracy : 0.3183
# Epoch: 19	Batch: 550	Avg-Loss: 1.8821	Training Accuracy : 0.3187
# Epoch: 19	Batch: 600	Avg-Loss: 1.8459	Training Accuracy : 0.3217
# Epoch: 19	Batch: 650	Avg-Loss: 1.8910	Training Accuracy : 0.3189
# Epoch: 19, Validation Loss: 2.081, Validation Accuracy: 0.300
# Epoch: 20	Batch: 50	Avg-Loss: 1.8324	Training Accuracy : 0.3286
# Epoch: 20	Batch: 100	Avg-Loss: 1.8558	Training Accuracy : 0.3236
# Epoch: 20	Batch: 150	Avg-Loss: 1.8848	Training Accuracy : 0.3203
# Epoch: 20	Batch: 200	Avg-Loss: 1.8899	Training Accuracy : 0.3233
# Epoch: 20	Batch: 250	Avg-Loss: 1.8661	Training Accuracy : 0.3134
# Epoch: 20	Batch: 300	Avg-Loss: 1.8558	Training Accuracy : 0.3317
# Epoch: 20	Batch: 350	Avg-Loss: 1.8913	Training Accuracy : 0.3227
# Epoch: 20	Batch: 400	Avg-Loss: 1.8703	Training Accuracy : 0.3137
# Epoch: 20	Batch: 450	Avg-Loss: 1.8303	Training Accuracy : 0.3242
# Epoch: 20	Batch: 500	Avg-Loss: 1.8639	Training Accuracy : 0.3203
# Epoch: 20	Batch: 550	Avg-Loss: 1.8901	Training Accuracy : 0.3270
# Epoch: 20	Batch: 600	Avg-Loss: 1.8690	Training Accuracy : 0.3184
# Epoch: 20	Batch: 650	Avg-Loss: 1.8578	Training Accuracy : 0.3234
# Epoch: 20, Validation Loss: 2.134, Validation Accuracy: 0.298
# Epoch: 21	Batch: 50	Avg-Loss: 1.8262	Training Accuracy : 0.3325
# Epoch: 21	Batch: 100	Avg-Loss: 1.8295	Training Accuracy : 0.3311
# Epoch: 21	Batch: 150	Avg-Loss: 1.8347	Training Accuracy : 0.3270
# Epoch: 21	Batch: 200	Avg-Loss: 1.8341	Training Accuracy : 0.3322
# Epoch: 21	Batch: 250	Avg-Loss: 1.8639	Training Accuracy : 0.3312
# Epoch: 21	Batch: 300	Avg-Loss: 1.8345	Training Accuracy : 0.3280
# Epoch: 21	Batch: 350	Avg-Loss: 1.8449	Training Accuracy : 0.3247
# Epoch: 21	Batch: 400	Avg-Loss: 1.8555	Training Accuracy : 0.3255
# Epoch: 21	Batch: 450	Avg-Loss: 1.8595	Training Accuracy : 0.3198
# Epoch: 21	Batch: 500	Avg-Loss: 1.8360	Training Accuracy : 0.3281
# Epoch: 21	Batch: 550	Avg-Loss: 1.8630	Training Accuracy : 0.3250
# Epoch: 21	Batch: 600	Avg-Loss: 1.8323	Training Accuracy : 0.3353
# Epoch: 21	Batch: 650	Avg-Loss: 1.8301	Training Accuracy : 0.3264
# Epoch: 21, Validation Loss: 2.446, Validation Accuracy: 0.289
# Epoch: 22	Batch: 50	Avg-Loss: 1.8348	Training Accuracy : 0.3286
# Epoch: 22	Batch: 100	Avg-Loss: 1.8061	Training Accuracy : 0.3369
# Epoch: 22	Batch: 150	Avg-Loss: 1.8071	Training Accuracy : 0.3314
# Epoch: 22	Batch: 200	Avg-Loss: 1.8203	Training Accuracy : 0.3311
# Epoch: 22	Batch: 250	Avg-Loss: 1.8104	Training Accuracy : 0.3373
# Epoch: 22	Batch: 300	Avg-Loss: 1.8116	Training Accuracy : 0.3325
# Epoch: 22	Batch: 350	Avg-Loss: 1.7922	Training Accuracy : 0.3400
# Epoch: 22	Batch: 400	Avg-Loss: 1.8144	Training Accuracy : 0.3352
# Epoch: 22	Batch: 450	Avg-Loss: 1.8618	Training Accuracy : 0.3262
# Epoch: 22	Batch: 500	Avg-Loss: 1.8249	Training Accuracy : 0.3325
# Epoch: 22	Batch: 550	Avg-Loss: 1.8345	Training Accuracy : 0.3287
# Epoch: 22	Batch: 600	Avg-Loss: 1.8282	Training Accuracy : 0.3387
# Epoch: 22	Batch: 650	Avg-Loss: 1.8392	Training Accuracy : 0.3159
# Epoch     4: reducing learning rate of group 0 to 2.5000e-02.
# Epoch: 22, Validation Loss: 2.283, Validation Accuracy: 0.290
# Epoch: 23	Batch: 50	Avg-Loss: 1.7154	Training Accuracy : 0.3595
# Epoch: 23	Batch: 100	Avg-Loss: 1.6795	Training Accuracy : 0.3678
# Epoch: 23	Batch: 150	Avg-Loss: 1.7058	Training Accuracy : 0.3619
# Epoch: 23	Batch: 200	Avg-Loss: 1.6630	Training Accuracy : 0.3725
# Epoch: 23	Batch: 250	Avg-Loss: 1.6943	Training Accuracy : 0.3627
# Epoch: 23	Batch: 300	Avg-Loss: 1.6987	Training Accuracy : 0.3581
# Epoch: 23	Batch: 350	Avg-Loss: 1.6695	Training Accuracy : 0.3641
# Epoch: 23	Batch: 400	Avg-Loss: 1.6800	Training Accuracy : 0.3570
# Epoch: 23	Batch: 450	Avg-Loss: 1.6754	Training Accuracy : 0.3673
# Epoch: 23	Batch: 500	Avg-Loss: 1.6780	Training Accuracy : 0.3639
# Epoch: 23	Batch: 550	Avg-Loss: 1.6743	Training Accuracy : 0.3694
# Epoch: 23	Batch: 600	Avg-Loss: 1.6587	Training Accuracy : 0.3706
# Epoch: 23	Batch: 650	Avg-Loss: 1.6799	Training Accuracy : 0.3705
# Epoch: 23, Validation Loss: 2.278, Validation Accuracy: 0.311
# Epoch: 24	Batch: 50	Avg-Loss: 1.6260	Training Accuracy : 0.3809
# Epoch: 24	Batch: 100	Avg-Loss: 1.6415	Training Accuracy : 0.3802
# Epoch: 24	Batch: 150	Avg-Loss: 1.6510	Training Accuracy : 0.3717
# Epoch: 24	Batch: 200	Avg-Loss: 1.6486	Training Accuracy : 0.3806
# Epoch: 24	Batch: 250	Avg-Loss: 1.6598	Training Accuracy : 0.3678
# Epoch: 24	Batch: 300	Avg-Loss: 1.6155	Training Accuracy : 0.3830
# Epoch: 24	Batch: 350	Avg-Loss: 1.6228	Training Accuracy : 0.3858
# Epoch: 24	Batch: 400	Avg-Loss: 1.6578	Training Accuracy : 0.3797
# Epoch: 24	Batch: 450	Avg-Loss: 1.6574	Training Accuracy : 0.3691
# Epoch: 24	Batch: 500	Avg-Loss: 1.6270	Training Accuracy : 0.3792
# Epoch: 24	Batch: 550	Avg-Loss: 1.6413	Training Accuracy : 0.3795
# Epoch: 24	Batch: 600	Avg-Loss: 1.6398	Training Accuracy : 0.3725
# Epoch: 24	Batch: 650	Avg-Loss: 1.6675	Training Accuracy : 0.3619
# Epoch: 24, Validation Loss: 2.254, Validation Accuracy: 0.307
# Epoch: 25	Batch: 50	Avg-Loss: 1.6028	Training Accuracy : 0.3808
# Epoch: 25	Batch: 100	Avg-Loss: 1.6217	Training Accuracy : 0.3822
# Epoch: 25	Batch: 150	Avg-Loss: 1.6092	Training Accuracy : 0.3908
# Epoch: 25	Batch: 200	Avg-Loss: 1.6022	Training Accuracy : 0.3853
# Epoch: 25	Batch: 250	Avg-Loss: 1.6027	Training Accuracy : 0.3802
# Epoch: 25	Batch: 300	Avg-Loss: 1.6120	Training Accuracy : 0.3862
# Epoch: 25	Batch: 350	Avg-Loss: 1.6019	Training Accuracy : 0.3877
# Epoch: 25	Batch: 400	Avg-Loss: 1.6104	Training Accuracy : 0.3820
# Epoch: 25	Batch: 450	Avg-Loss: 1.6243	Training Accuracy : 0.3881
# Epoch: 25	Batch: 500	Avg-Loss: 1.6070	Training Accuracy : 0.3900
# Epoch: 25	Batch: 550	Avg-Loss: 1.6304	Training Accuracy : 0.3845
# Epoch: 25	Batch: 600	Avg-Loss: 1.5902	Training Accuracy : 0.3923
# Epoch: 25	Batch: 650	Avg-Loss: 1.6059	Training Accuracy : 0.3819
# Epoch     7: reducing learning rate of group 0 to 1.2500e-02.
# Epoch: 25, Validation Loss: 2.322, Validation Accuracy: 0.306
# Epoch: 26	Batch: 50	Avg-Loss: 1.5236	Training Accuracy : 0.4189
# Epoch: 26	Batch: 100	Avg-Loss: 1.4941	Training Accuracy : 0.4198
# Epoch: 26	Batch: 150	Avg-Loss: 1.5033	Training Accuracy : 0.4269
# Epoch: 26	Batch: 200	Avg-Loss: 1.4618	Training Accuracy : 0.4372
# Epoch: 26	Batch: 250	Avg-Loss: 1.4781	Training Accuracy : 0.4258
# Epoch: 26	Batch: 300	Avg-Loss: 1.4636	Training Accuracy : 0.4328
# Epoch: 26	Batch: 350	Avg-Loss: 1.4617	Training Accuracy : 0.4320
# Epoch: 26	Batch: 400	Avg-Loss: 1.4751	Training Accuracy : 0.4364
# Epoch: 26	Batch: 450	Avg-Loss: 1.4434	Training Accuracy : 0.4338
# Epoch: 26	Batch: 500	Avg-Loss: 1.4722	Training Accuracy : 0.4297
# Epoch: 26	Batch: 550	Avg-Loss: 1.4385	Training Accuracy : 0.4378
# Epoch: 26	Batch: 600	Avg-Loss: 1.4691	Training Accuracy : 0.4339
# Epoch: 26	Batch: 650	Avg-Loss: 1.4586	Training Accuracy : 0.4389
# Epoch: 26, Validation Loss: 2.265, Validation Accuracy: 0.309
# Epoch: 27	Batch: 50	Avg-Loss: 1.4223	Training Accuracy : 0.4441
# Epoch: 27	Batch: 100	Avg-Loss: 1.4111	Training Accuracy : 0.4541
# Epoch: 27	Batch: 150	Avg-Loss: 1.4311	Training Accuracy : 0.4475
# Epoch: 27	Batch: 200	Avg-Loss: 1.4285	Training Accuracy : 0.4520
# Epoch: 27	Batch: 250	Avg-Loss: 1.4213	Training Accuracy : 0.4464
# Epoch: 27	Batch: 300	Avg-Loss: 1.4362	Training Accuracy : 0.4458
# Epoch: 27	Batch: 350	Avg-Loss: 1.4220	Training Accuracy : 0.4569
# Epoch: 27	Batch: 400	Avg-Loss: 1.4238	Training Accuracy : 0.4528
# Epoch: 27	Batch: 450	Avg-Loss: 1.4182	Training Accuracy : 0.4528
# Epoch: 27	Batch: 500	Avg-Loss: 1.4269	Training Accuracy : 0.4525
# Epoch: 27	Batch: 550	Avg-Loss: 1.4436	Training Accuracy : 0.4322
# Epoch: 27	Batch: 600	Avg-Loss: 1.4489	Training Accuracy : 0.4491
# Epoch: 27	Batch: 650	Avg-Loss: 1.4210	Training Accuracy : 0.4623
# Epoch: 27, Validation Loss: 2.410, Validation Accuracy: 0.303
# Epoch: 28	Batch: 50	Avg-Loss: 1.3696	Training Accuracy : 0.4823
# Epoch: 28	Batch: 100	Avg-Loss: 1.3769	Training Accuracy : 0.4783
# Epoch: 28	Batch: 150	Avg-Loss: 1.3564	Training Accuracy : 0.4828
# Epoch: 28	Batch: 200	Avg-Loss: 1.3797	Training Accuracy : 0.4719
# Epoch: 28	Batch: 250	Avg-Loss: 1.3781	Training Accuracy : 0.4734
# Epoch: 28	Batch: 300	Avg-Loss: 1.3819	Training Accuracy : 0.4717
# Epoch: 28	Batch: 350	Avg-Loss: 1.3994	Training Accuracy : 0.4681
# Epoch: 28	Batch: 400	Avg-Loss: 1.4010	Training Accuracy : 0.4694
# Epoch: 28	Batch: 450	Avg-Loss: 1.3605	Training Accuracy : 0.4828
# Epoch: 28	Batch: 500	Avg-Loss: 1.3676	Training Accuracy : 0.4798
# Epoch: 28	Batch: 550	Avg-Loss: 1.3840	Training Accuracy : 0.4869
# Epoch: 28	Batch: 600	Avg-Loss: 1.3752	Training Accuracy : 0.4839
# Epoch: 28	Batch: 650	Avg-Loss: 1.3692	Training Accuracy : 0.4839
# Epoch    10: reducing learning rate of group 0 to 6.2500e-03.
# Epoch: 28, Validation Loss: 2.435, Validation Accuracy: 0.302
# Epoch: 29	Batch: 50	Avg-Loss: 1.2935	Training Accuracy : 0.5225
# Epoch: 29	Batch: 100	Avg-Loss: 1.2615	Training Accuracy : 0.5327
# Epoch: 29	Batch: 150	Avg-Loss: 1.2335	Training Accuracy : 0.5420
# Epoch: 29	Batch: 200	Avg-Loss: 1.2016	Training Accuracy : 0.5514
# Epoch: 29	Batch: 250	Avg-Loss: 1.2188	Training Accuracy : 0.5466
# Epoch: 29	Batch: 300	Avg-Loss: 1.2031	Training Accuracy : 0.5511
# Epoch: 29	Batch: 350	Avg-Loss: 1.1839	Training Accuracy : 0.5563
# Epoch: 29	Batch: 400	Avg-Loss: 1.2007	Training Accuracy : 0.5528
# Epoch: 29	Batch: 450	Avg-Loss: 1.2034	Training Accuracy : 0.5519
# Epoch: 29	Batch: 500	Avg-Loss: 1.1881	Training Accuracy : 0.5589
# Epoch: 29	Batch: 550	Avg-Loss: 1.1980	Training Accuracy : 0.5567
# Epoch: 29	Batch: 600	Avg-Loss: 1.2001	Training Accuracy : 0.5567
# Epoch: 29	Batch: 650	Avg-Loss: 1.2110	Training Accuracy : 0.5513
# Epoch: 29, Validation Loss: 2.563, Validation Accuracy: 0.302
# Epoch: 30	Batch: 50	Avg-Loss: 1.1510	Training Accuracy : 0.5798
# Epoch: 30	Batch: 100	Avg-Loss: 1.1355	Training Accuracy : 0.5781
# Epoch: 30	Batch: 150	Avg-Loss: 1.1541	Training Accuracy : 0.5837
# Epoch: 30	Batch: 200	Avg-Loss: 1.1306	Training Accuracy : 0.5942
# Epoch: 30	Batch: 250	Avg-Loss: 1.1316	Training Accuracy : 0.5847
# Epoch: 30	Batch: 300	Avg-Loss: 1.1492	Training Accuracy : 0.5859
# Epoch: 30	Batch: 350	Avg-Loss: 1.1264	Training Accuracy : 0.5889
# Epoch: 30	Batch: 400	Avg-Loss: 1.1352	Training Accuracy : 0.5941
# Epoch: 30	Batch: 450	Avg-Loss: 1.1306	Training Accuracy : 0.5836
# Epoch: 30	Batch: 500	Avg-Loss: 1.1276	Training Accuracy : 0.5883
# Epoch: 30	Batch: 550	Avg-Loss: 1.1262	Training Accuracy : 0.5877
# Epoch: 30	Batch: 600	Avg-Loss: 1.1110	Training Accuracy : 0.6052
# Epoch: 30	Batch: 650	Avg-Loss: 1.1112	Training Accuracy : 0.6045
# Epoch: 30, Validation Loss: 2.620, Validation Accuracy: 0.291
# Epoch: 31	Batch: 50	Avg-Loss: 1.0768	Training Accuracy : 0.6184
# Epoch: 31	Batch: 100	Avg-Loss: 1.0368	Training Accuracy : 0.6311
# Epoch: 31	Batch: 150	Avg-Loss: 1.0555	Training Accuracy : 0.6223
# Epoch: 31	Batch: 200	Avg-Loss: 1.0542	Training Accuracy : 0.6258
# Epoch: 31	Batch: 250	Avg-Loss: 1.0500	Training Accuracy : 0.6283
# Epoch: 31	Batch: 300	Avg-Loss: 1.0773	Training Accuracy : 0.6134
# Epoch: 31	Batch: 350	Avg-Loss: 1.0528	Training Accuracy : 0.6206
# Epoch: 31	Batch: 400	Avg-Loss: 1.0614	Training Accuracy : 0.6205
# Epoch: 31	Batch: 450	Avg-Loss: 1.0347	Training Accuracy : 0.6325
# Epoch: 31	Batch: 500	Avg-Loss: 1.0765	Training Accuracy : 0.6127
# Epoch: 31	Batch: 550	Avg-Loss: 1.0491	Training Accuracy : 0.6259
# Epoch: 31	Batch: 600	Avg-Loss: 1.0395	Training Accuracy : 0.6264
# Epoch: 31	Batch: 650	Avg-Loss: 1.0752	Training Accuracy : 0.6178
# Epoch    13: reducing learning rate of group 0 to 3.1250e-03.
# Epoch: 31, Validation Loss: 2.775, Validation Accuracy: 0.289
# Epoch: 32	Batch: 50	Avg-Loss: 0.9331	Training Accuracy : 0.6669
# Epoch: 32	Batch: 100	Avg-Loss: 0.9229	Training Accuracy : 0.6823
# Epoch: 32	Batch: 150	Avg-Loss: 0.8942	Training Accuracy : 0.6873
# Epoch: 32	Batch: 200	Avg-Loss: 0.9140	Training Accuracy : 0.6827
# Epoch: 32	Batch: 250	Avg-Loss: 0.9122	Training Accuracy : 0.6816
# Epoch: 32	Batch: 300	Avg-Loss: 0.9045	Training Accuracy : 0.6867
# Epoch: 32	Batch: 350	Avg-Loss: 0.9000	Training Accuracy : 0.6877
# Epoch: 32	Batch: 400	Avg-Loss: 0.8915	Training Accuracy : 0.6834
# Epoch: 32	Batch: 450	Avg-Loss: 0.8816	Training Accuracy : 0.6853
# Epoch: 32	Batch: 500	Avg-Loss: 0.8903	Training Accuracy : 0.6845
# Epoch: 32	Batch: 550	Avg-Loss: 0.8722	Training Accuracy : 0.6981
# Epoch: 32	Batch: 600	Avg-Loss: 0.8957	Training Accuracy : 0.6802
# Epoch: 32	Batch: 650	Avg-Loss: 0.8744	Training Accuracy : 0.6866
# Epoch: 32, Validation Loss: 2.856, Validation Accuracy: 0.295
# Epoch: 33	Batch: 50	Avg-Loss: 0.8355	Training Accuracy : 0.7127
# Epoch: 33	Batch: 100	Avg-Loss: 0.8168	Training Accuracy : 0.7164
# Epoch: 33	Batch: 150	Avg-Loss: 0.8360	Training Accuracy : 0.7061
# Epoch: 33	Batch: 200	Avg-Loss: 0.8706	Training Accuracy : 0.6948
# Epoch: 33	Batch: 250	Avg-Loss: 0.8275	Training Accuracy : 0.7105
# Epoch: 33	Batch: 300	Avg-Loss: 0.8356	Training Accuracy : 0.7137
# Epoch: 33	Batch: 350	Avg-Loss: 0.8484	Training Accuracy : 0.7078
# Epoch: 33	Batch: 400	Avg-Loss: 0.8565	Training Accuracy : 0.7033
# Epoch: 33	Batch: 450	Avg-Loss: 0.8493	Training Accuracy : 0.6967
# Epoch: 33	Batch: 500	Avg-Loss: 0.8279	Training Accuracy : 0.7070
# Epoch: 33	Batch: 550	Avg-Loss: 0.8566	Training Accuracy : 0.7036
# Epoch: 33	Batch: 600	Avg-Loss: 0.8303	Training Accuracy : 0.7125
# Epoch: 33	Batch: 650	Avg-Loss: 0.8300	Training Accuracy : 0.7166
# Epoch: 33, Validation Loss: 3.064, Validation Accuracy: 0.290
# Epoch: 34	Batch: 50	Avg-Loss: 0.7883	Training Accuracy : 0.7245
# Epoch: 34	Batch: 100	Avg-Loss: 0.7722	Training Accuracy : 0.7317
# Epoch: 34	Batch: 150	Avg-Loss: 0.7805	Training Accuracy : 0.7336
# Epoch: 34	Batch: 200	Avg-Loss: 0.7930	Training Accuracy : 0.7250
# Epoch: 34	Batch: 250	Avg-Loss: 0.7930	Training Accuracy : 0.7270
# Epoch: 34	Batch: 300	Avg-Loss: 0.7833	Training Accuracy : 0.7239
# Epoch: 34	Batch: 350	Avg-Loss: 0.8109	Training Accuracy : 0.7198
# Epoch: 34	Batch: 400	Avg-Loss: 0.7973	Training Accuracy : 0.7250
# Epoch: 34	Batch: 450	Avg-Loss: 0.7836	Training Accuracy : 0.7289
# Epoch: 34	Batch: 500	Avg-Loss: 0.8108	Training Accuracy : 0.7169
# Epoch: 34	Batch: 550	Avg-Loss: 0.7959	Training Accuracy : 0.7214
# Epoch: 34	Batch: 600	Avg-Loss: 0.7839	Training Accuracy : 0.7252
# Epoch: 34	Batch: 650	Avg-Loss: 0.7973	Training Accuracy : 0.7192
# Epoch    16: reducing learning rate of group 0 to 1.5625e-03.
# Epoch: 34, Validation Loss: 3.124, Validation Accuracy: 0.293
# Epoch: 35	Batch: 50	Avg-Loss: 0.7253	Training Accuracy : 0.7533
# Epoch: 35	Batch: 100	Avg-Loss: 0.6858	Training Accuracy : 0.7738
# Epoch: 35	Batch: 150	Avg-Loss: 0.7177	Training Accuracy : 0.7528
# Epoch: 35	Batch: 200	Avg-Loss: 0.6883	Training Accuracy : 0.7731
# Epoch: 35	Batch: 250	Avg-Loss: 0.6822	Training Accuracy : 0.7650
# Epoch: 35	Batch: 300	Avg-Loss: 0.6995	Training Accuracy : 0.7597
# Epoch: 35	Batch: 350	Avg-Loss: 0.6995	Training Accuracy : 0.7602
# Epoch: 35	Batch: 400	Avg-Loss: 0.6614	Training Accuracy : 0.7709
# Epoch: 35	Batch: 450	Avg-Loss: 0.6915	Training Accuracy : 0.7630
# Epoch: 35	Batch: 500	Avg-Loss: 0.6859	Training Accuracy : 0.7647
# Epoch: 35	Batch: 550	Avg-Loss: 0.6899	Training Accuracy : 0.7694
# Epoch: 35	Batch: 600	Avg-Loss: 0.6714	Training Accuracy : 0.7692
# Epoch: 35	Batch: 650	Avg-Loss: 0.6877	Training Accuracy : 0.7614
# Epoch: 35, Validation Loss: 3.206, Validation Accuracy: 0.281
# Epoch: 36	Batch: 50	Avg-Loss: 0.6606	Training Accuracy : 0.7741
# Epoch: 36	Batch: 100	Avg-Loss: 0.6614	Training Accuracy : 0.7731
# Epoch: 36	Batch: 150	Avg-Loss: 0.6445	Training Accuracy : 0.7889
# Epoch: 36	Batch: 200	Avg-Loss: 0.6687	Training Accuracy : 0.7688
# Epoch: 36	Batch: 250	Avg-Loss: 0.6582	Training Accuracy : 0.7752
# Epoch: 36	Batch: 300	Avg-Loss: 0.6619	Training Accuracy : 0.7733
# Epoch: 36	Batch: 350	Avg-Loss: 0.6414	Training Accuracy : 0.7837
# Epoch: 36	Batch: 400	Avg-Loss: 0.6526	Training Accuracy : 0.7738
# Epoch: 36	Batch: 450	Avg-Loss: 0.6657	Training Accuracy : 0.7739
# Epoch: 36	Batch: 500	Avg-Loss: 0.6496	Training Accuracy : 0.7781
# Epoch: 36	Batch: 550	Avg-Loss: 0.6525	Training Accuracy : 0.7688
# Epoch: 36	Batch: 600	Avg-Loss: 0.6394	Training Accuracy : 0.7819
# Epoch: 36	Batch: 650	Avg-Loss: 0.6772	Training Accuracy : 0.7723
# Epoch: 36, Validation Loss: 3.252, Validation Accuracy: 0.285
# Epoch: 37	Batch: 50	Avg-Loss: 0.6220	Training Accuracy : 0.7913
# Epoch: 37	Batch: 100	Avg-Loss: 0.6241	Training Accuracy : 0.7877
# Epoch: 37	Batch: 150	Avg-Loss: 0.6261	Training Accuracy : 0.7909
# Epoch: 37	Batch: 200	Avg-Loss: 0.6205	Training Accuracy : 0.7895
# Epoch: 37	Batch: 250	Avg-Loss: 0.6330	Training Accuracy : 0.7839
# Epoch: 37	Batch: 300	Avg-Loss: 0.6297	Training Accuracy : 0.7817
# Epoch: 37	Batch: 350	Avg-Loss: 0.6252	Training Accuracy : 0.7820
# Epoch: 37	Batch: 400	Avg-Loss: 0.6174	Training Accuracy : 0.7831
# Epoch: 37	Batch: 450	Avg-Loss: 0.6393	Training Accuracy : 0.7748
# Epoch: 37	Batch: 500	Avg-Loss: 0.6460	Training Accuracy : 0.7823
# Epoch: 37	Batch: 550	Avg-Loss: 0.6222	Training Accuracy : 0.7919
# Epoch: 37	Batch: 600	Avg-Loss: 0.6411	Training Accuracy : 0.7812
# Epoch: 37	Batch: 650	Avg-Loss: 0.6496	Training Accuracy : 0.7742
# Epoch    19: reducing learning rate of group 0 to 7.8125e-04.
# Epoch: 37, Validation Loss: 3.367, Validation Accuracy: 0.284
# Epoch: 38	Batch: 50	Avg-Loss: 0.5895	Training Accuracy : 0.7978
# Epoch: 38	Batch: 100	Avg-Loss: 0.5624	Training Accuracy : 0.8098
# Epoch: 38	Batch: 150	Avg-Loss: 0.5677	Training Accuracy : 0.8042
# Epoch: 38	Batch: 200	Avg-Loss: 0.5937	Training Accuracy : 0.7989
# Epoch: 38	Batch: 250	Avg-Loss: 0.5738	Training Accuracy : 0.8069
# Epoch: 38	Batch: 300	Avg-Loss: 0.5660	Training Accuracy : 0.8125
# Epoch: 38	Batch: 350	Avg-Loss: 0.5943	Training Accuracy : 0.7986
# Epoch: 38	Batch: 400	Avg-Loss: 0.5762	Training Accuracy : 0.8081
# Epoch: 38	Batch: 450	Avg-Loss: 0.5787	Training Accuracy : 0.8023
# Epoch: 38	Batch: 500	Avg-Loss: 0.5936	Training Accuracy : 0.8027
# Epoch: 38	Batch: 550	Avg-Loss: 0.5678	Training Accuracy : 0.8045
# Epoch: 38	Batch: 600	Avg-Loss: 0.5831	Training Accuracy : 0.8078
# Epoch: 38	Batch: 650	Avg-Loss: 0.5661	Training Accuracy : 0.8066
# Epoch: 38, Validation Loss: 3.416, Validation Accuracy: 0.288
# Epoch: 39	Batch: 50	Avg-Loss: 0.5451	Training Accuracy : 0.8203
# Epoch: 39	Batch: 100	Avg-Loss: 0.5620	Training Accuracy : 0.8098
# Epoch: 39	Batch: 150	Avg-Loss: 0.5638	Training Accuracy : 0.8094
# Epoch: 39	Batch: 200	Avg-Loss: 0.5586	Training Accuracy : 0.8120
# Epoch: 39	Batch: 250	Avg-Loss: 0.5477	Training Accuracy : 0.8237
# Epoch: 39	Batch: 300	Avg-Loss: 0.5524	Training Accuracy : 0.8086
# Epoch: 39	Batch: 350	Avg-Loss: 0.5605	Training Accuracy : 0.8103
# Epoch: 39	Batch: 400	Avg-Loss: 0.5588	Training Accuracy : 0.8127
# Epoch: 39	Batch: 450	Avg-Loss: 0.5480	Training Accuracy : 0.8122
# Epoch: 39	Batch: 500	Avg-Loss: 0.5523	Training Accuracy : 0.8137
# Epoch: 39	Batch: 550	Avg-Loss: 0.5701	Training Accuracy : 0.8064
# Epoch: 39	Batch: 600	Avg-Loss: 0.5781	Training Accuracy : 0.8055
# Epoch: 39	Batch: 650	Avg-Loss: 0.5635	Training Accuracy : 0.8072
# Epoch: 39, Validation Loss: 3.471, Validation Accuracy: 0.282
# Epoch: 40	Batch: 50	Avg-Loss: 0.5227	Training Accuracy : 0.8250
# Epoch: 40	Batch: 100	Avg-Loss: 0.5318	Training Accuracy : 0.8216
# Epoch: 40	Batch: 150	Avg-Loss: 0.5583	Training Accuracy : 0.8094
# Epoch: 40	Batch: 200	Avg-Loss: 0.5187	Training Accuracy : 0.8261
# Epoch: 40	Batch: 250	Avg-Loss: 0.5500	Training Accuracy : 0.8137
# Epoch: 40	Batch: 300	Avg-Loss: 0.5290	Training Accuracy : 0.8192
# Epoch: 40	Batch: 350	Avg-Loss: 0.5679	Training Accuracy : 0.8122
# Epoch: 40	Batch: 400	Avg-Loss: 0.5429	Training Accuracy : 0.8131
# Epoch: 40	Batch: 450	Avg-Loss: 0.5348	Training Accuracy : 0.8213
# Epoch: 40	Batch: 500	Avg-Loss: 0.5711	Training Accuracy : 0.8114
# Epoch: 40	Batch: 550	Avg-Loss: 0.5465	Training Accuracy : 0.8216
# Epoch: 40	Batch: 600	Avg-Loss: 0.5322	Training Accuracy : 0.8219
# Epoch: 40	Batch: 650	Avg-Loss: 0.5352	Training Accuracy : 0.8183
# Epoch    22: reducing learning rate of group 0 to 3.9063e-04.
# Epoch: 40, Validation Loss: 3.531, Validation Accuracy: 0.278
# Epoch: 41	Batch: 50	Avg-Loss: 0.5169	Training Accuracy : 0.8287
# Epoch: 41	Batch: 100	Avg-Loss: 0.5262	Training Accuracy : 0.8239
# Epoch: 41	Batch: 150	Avg-Loss: 0.5055	Training Accuracy : 0.8333
# Epoch: 41	Batch: 200	Avg-Loss: 0.5137	Training Accuracy : 0.8255
# Epoch: 41	Batch: 250	Avg-Loss: 0.4929	Training Accuracy : 0.8363
# Epoch: 41	Batch: 300	Avg-Loss: 0.5227	Training Accuracy : 0.8239
# Epoch: 41	Batch: 350	Avg-Loss: 0.5113	Training Accuracy : 0.8300
# Epoch: 41	Batch: 400	Avg-Loss: 0.5058	Training Accuracy : 0.8311
# Epoch: 41	Batch: 450	Avg-Loss: 0.5037	Training Accuracy : 0.8300
# Epoch: 41	Batch: 500	Avg-Loss: 0.5276	Training Accuracy : 0.8205
# Epoch: 41	Batch: 550	Avg-Loss: 0.5192	Training Accuracy : 0.8280
# Epoch: 41	Batch: 600	Avg-Loss: 0.5033	Training Accuracy : 0.8336
# Epoch: 41	Batch: 650	Avg-Loss: 0.5275	Training Accuracy : 0.8208
# Epoch: 41, Validation Loss: 3.559, Validation Accuracy: 0.283
# Epoch: 42	Batch: 50	Avg-Loss: 0.4858	Training Accuracy : 0.8367
# Epoch: 42	Batch: 100	Avg-Loss: 0.5114	Training Accuracy : 0.8291
# Epoch: 42	Batch: 150	Avg-Loss: 0.4656	Training Accuracy : 0.8462
# Epoch: 42	Batch: 200	Avg-Loss: 0.5088	Training Accuracy : 0.8302
# Epoch: 42	Batch: 250	Avg-Loss: 0.5059	Training Accuracy : 0.8311
# Epoch: 42	Batch: 300	Avg-Loss: 0.5107	Training Accuracy : 0.8266
# Epoch: 42	Batch: 350	Avg-Loss: 0.4997	Training Accuracy : 0.8387
# Epoch: 42	Batch: 400	Avg-Loss: 0.5234	Training Accuracy : 0.8267
# Epoch: 42	Batch: 450	Avg-Loss: 0.5028	Training Accuracy : 0.8330
# Epoch: 42	Batch: 500	Avg-Loss: 0.5207	Training Accuracy : 0.8278
# Epoch: 42	Batch: 550	Avg-Loss: 0.4736	Training Accuracy : 0.8417
# Epoch: 42	Batch: 600	Avg-Loss: 0.4833	Training Accuracy : 0.8348
# Epoch: 42	Batch: 650	Avg-Loss: 0.4961	Training Accuracy : 0.8358
# Epoch: 42, Validation Loss: 3.566, Validation Accuracy: 0.285
# Epoch: 43	Batch: 50	Avg-Loss: 0.4850	Training Accuracy : 0.8455
# Epoch: 43	Batch: 100	Avg-Loss: 0.4892	Training Accuracy : 0.8392
# Epoch: 43	Batch: 150	Avg-Loss: 0.4942	Training Accuracy : 0.8331
# Epoch: 43	Batch: 200	Avg-Loss: 0.4969	Training Accuracy : 0.8350
# Epoch: 43	Batch: 250	Avg-Loss: 0.4901	Training Accuracy : 0.8373
# Epoch: 43	Batch: 300	Avg-Loss: 0.4745	Training Accuracy : 0.8403
# Epoch: 43	Batch: 350	Avg-Loss: 0.4826	Training Accuracy : 0.8372
# Epoch: 43	Batch: 400	Avg-Loss: 0.5118	Training Accuracy : 0.8267

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Mon Nov 29 23:24:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    38W / 250W |   1459MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/regnet_ours_data8/best_model_23.pt"))
network = network.to(device)

# %%
network.eval()
num_correct = 0
for x, y in tqdm(test_loader):
  x, y = x.to(device), y.to(device)
  outputs = network(x)
  num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

test_acc = num_correct / len(test_set)
print(test_acc)
# Out:
#   0%|          | 0/141 [00:00<?, ?it/s]
# 0.29614977433554357

# %%
print(test_acc)
# Out:
# 0.29614977433554357
