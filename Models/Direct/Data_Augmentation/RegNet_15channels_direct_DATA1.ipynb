# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/dl_project/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("4+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149670.jpg', 'frame_149739.jpg', 'fram...     16
# 1      ('frame_149738.jpg', 'frame_149692.jpg', 'fram...     80
# 2      ('frame_149729.jpg', 'frame_149716.jpg', 'fram...     86
# 3      ('frame_149669.jpg', 'frame_149712.jpg', 'fram...      7
# 4      ('frame_149683.jpg', 'frame_149707.jpg', 'fram...     34
# ...                                                  ...    ...
# 17942  ('frame_180809.jpg', 'frame_174579.jpg', 'fram...    101
# 17943  ('frame_174581.jpg', 'frame_174634.jpg', 'fram...     14
# 17944  ('frame_174605.jpg', 'frame_174596.jpg', 'fram...     54
# 17945  ('frame_181123.jpg', 'frame_174585.jpg', 'fram...     96
# 17946  ('frame_181333.jpg', 'frame_174579.jpg', 'fram...     97
#
# [17947 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, transform=None, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]
        self.transform = transform

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            # img = torchvision.transforms.Normalize(mean=[0.2068, 0.2242, 0.2269], std=[0.2520, 0.2394, 0.2320])(img)
            if self.transform:
                img = self.transform(img)
            images.extend(img)
        x = torch.stack(images)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([15, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
# transform_train = torchvision.transforms.Compose([
#     torchvision.transforms.Normalize(mean=[0.4967, 0.4858, 0.4584, 0.4969, 0.4700, 0.4585, 0.4964, 0.4854, 0.4580, 0.4972, 0.4862, 0.4585, 0.4964, 0.4857, 0.4584],
#                                       std=[0.2681, 0.2574, 0.2433, 0.2678, 0.2500, 0.2429, 0.2679, 0.2572, 0.2428, 0.2680, 0.2573, 0.2428, 0.2680, 0.2574, 0.2431])
# ])

transform_train = torchvision.transforms.Compose([
    torchvision.transforms.ColorJitter(brightness=0.3, contrast=0, saturation=0, hue=0)
])

# %%
batch_size = 128

# training data
train_set = MyDataSet(train_data, transform_train)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %%
# def batch_mean_and_sd(loader, num_channels):
    
#     cnt = 0
#     fst_moment = torch.empty(num_channels)
#     snd_moment = torch.empty(num_channels)

#     for images, _ in tqdm(loader):
#         b, c, h, w = images.shape
#         nb_pixels = b * h * w
#         sum_ = torch.sum(images, dim=[0, 2, 3])
#         sum_of_square = torch.sum(images ** 2,
#                                   dim=[0, 2, 3])
#         fst_moment = (cnt * fst_moment + sum_) / (cnt + nb_pixels)
#         snd_moment = (cnt * snd_moment + sum_of_square) / (cnt + nb_pixels)
#         cnt += nb_pixels

#     mean, std = fst_moment, torch.sqrt(snd_moment - fst_moment ** 2)        
#     return mean,std
  
# num_channels = 15
# mean, std = batch_mean_and_sd(train_loader, num_channels)
# print("mean and std: \n", mean, std)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding,num_classes))


    def forward(self, x):
      out = self.cnn(x)
      out = self.mlp(out)
      return out

# %%
numEpochs = 100
in_features = 15 # TODO: change RGB channels according to num of frames
embedding = 512

learningRate = 0.1
weightDecay = 1e-4

num_classes = 120

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_classes)
#network.load_state_dict(torch.load("model_checkpoints/resnet34/lr_0.1-2/model_2.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_4+1_ours_data1/best_model_" + str(epoch) + ".pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 0	Batch: 50	Avg-Loss: 5.0286	Training Accuracy : 0.0084
# Epoch: 0	Batch: 100	Avg-Loss: 4.5434	Training Accuracy : 0.0180
# Epoch: 0	Batch: 150	Avg-Loss: 3.9048	Training Accuracy : 0.0330
# Epoch: 0	Batch: 200	Avg-Loss: 3.6110	Training Accuracy : 0.0334
# Epoch: 0	Batch: 250	Avg-Loss: 3.4853	Training Accuracy : 0.0420
# Epoch: 0	Batch: 300	Avg-Loss: 3.4339	Training Accuracy : 0.0398
# Epoch: 0	Batch: 350	Avg-Loss: 3.4263	Training Accuracy : 0.0445
# Epoch: 0	Batch: 400	Avg-Loss: 3.3998	Training Accuracy : 0.0422
# Epoch: 0	Batch: 450	Avg-Loss: 3.3763	Training Accuracy : 0.0495
# Epoch: 0	Batch: 500	Avg-Loss: 3.3599	Training Accuracy : 0.0461
# Epoch: 0	Batch: 550	Avg-Loss: 3.3479	Training Accuracy : 0.0514
# Epoch: 0	Batch: 600	Avg-Loss: 3.3333	Training Accuracy : 0.0478
# Epoch: 0	Batch: 650	Avg-Loss: 3.3117	Training Accuracy : 0.0488
# Epoch: 0, Validation Loss: 3.322, Validation Accuracy: 0.057
# Epoch: 1	Batch: 50	Avg-Loss: 3.3011	Training Accuracy : 0.0567
# Epoch: 1	Batch: 100	Avg-Loss: 3.2843	Training Accuracy : 0.0630
# Epoch: 1	Batch: 150	Avg-Loss: 3.2840	Training Accuracy : 0.0577
# Epoch: 1	Batch: 200	Avg-Loss: 3.2760	Training Accuracy : 0.0611
# Epoch: 1	Batch: 250	Avg-Loss: 3.2713	Training Accuracy : 0.0569
# Epoch: 1	Batch: 300	Avg-Loss: 3.2503	Training Accuracy : 0.0612
# Epoch: 1	Batch: 350	Avg-Loss: 3.2613	Training Accuracy : 0.0608
# Epoch: 1	Batch: 400	Avg-Loss: 3.2421	Training Accuracy : 0.0612
# Epoch: 1	Batch: 450	Avg-Loss: 3.2183	Training Accuracy : 0.0708
# Epoch: 1	Batch: 500	Avg-Loss: 3.2210	Training Accuracy : 0.0734
# Epoch: 1	Batch: 550	Avg-Loss: 3.2091	Training Accuracy : 0.0731
# Epoch: 1	Batch: 600	Avg-Loss: 3.2241	Training Accuracy : 0.0667
# Epoch: 1	Batch: 650	Avg-Loss: 3.1899	Training Accuracy : 0.0688
# Epoch: 1, Validation Loss: 3.137, Validation Accuracy: 0.077
# Epoch: 2	Batch: 50	Avg-Loss: 3.1807	Training Accuracy : 0.0744
# Epoch: 2	Batch: 100	Avg-Loss: 3.1588	Training Accuracy : 0.0737
# Epoch: 2	Batch: 150	Avg-Loss: 3.1433	Training Accuracy : 0.0806
# Epoch: 2	Batch: 200	Avg-Loss: 3.1414	Training Accuracy : 0.0817
# Epoch: 2	Batch: 250	Avg-Loss: 3.1371	Training Accuracy : 0.0786
# Epoch: 2	Batch: 300	Avg-Loss: 3.1281	Training Accuracy : 0.0827
# Epoch: 2	Batch: 350	Avg-Loss: 3.1110	Training Accuracy : 0.0902
# Epoch: 2	Batch: 400	Avg-Loss: 3.0947	Training Accuracy : 0.0902
# Epoch: 2	Batch: 450	Avg-Loss: 3.1032	Training Accuracy : 0.0964
# Epoch: 2	Batch: 500	Avg-Loss: 3.0855	Training Accuracy : 0.0887
# Epoch: 2	Batch: 550	Avg-Loss: 3.0579	Training Accuracy : 0.0947
# Epoch: 2	Batch: 600	Avg-Loss: 3.0696	Training Accuracy : 0.0909
# Epoch: 2	Batch: 650	Avg-Loss: 3.0708	Training Accuracy : 0.0897
# Epoch: 2, Validation Loss: 3.049, Validation Accuracy: 0.096
# Epoch: 3	Batch: 50	Avg-Loss: 3.0556	Training Accuracy : 0.1020
# Epoch: 3	Batch: 100	Avg-Loss: 3.0566	Training Accuracy : 0.0956
# Epoch: 3	Batch: 150	Avg-Loss: 3.0645	Training Accuracy : 0.0931
# Epoch: 3	Batch: 200	Avg-Loss: 3.0382	Training Accuracy : 0.0994
# Epoch: 3	Batch: 250	Avg-Loss: 3.0186	Training Accuracy : 0.1005
# Epoch: 3	Batch: 300	Avg-Loss: 3.0212	Training Accuracy : 0.0989
# Epoch: 3	Batch: 350	Avg-Loss: 3.0284	Training Accuracy : 0.0989
# Epoch: 3	Batch: 400	Avg-Loss: 3.0122	Training Accuracy : 0.1053
# Epoch: 3	Batch: 450	Avg-Loss: 2.9978	Training Accuracy : 0.1039
# Epoch: 3	Batch: 500	Avg-Loss: 2.9359	Training Accuracy : 0.1158
# Epoch: 3	Batch: 550	Avg-Loss: 2.9299	Training Accuracy : 0.1138
# Epoch: 3	Batch: 600	Avg-Loss: 2.9109	Training Accuracy : 0.1195
# Epoch: 3	Batch: 650	Avg-Loss: 2.8849	Training Accuracy : 0.1175
# Epoch: 3, Validation Loss: 2.845, Validation Accuracy: 0.132
# Epoch: 4	Batch: 50	Avg-Loss: 2.8994	Training Accuracy : 0.1298
# Epoch: 4	Batch: 100	Avg-Loss: 2.8650	Training Accuracy : 0.1283
# Epoch: 4	Batch: 150	Avg-Loss: 2.8058	Training Accuracy : 0.1373
# Epoch: 4	Batch: 200	Avg-Loss: 2.7316	Training Accuracy : 0.1525
# Epoch: 4	Batch: 250	Avg-Loss: 2.7674	Training Accuracy : 0.1456
# Epoch: 4	Batch: 300	Avg-Loss: 2.7617	Training Accuracy : 0.1514
# Epoch: 4	Batch: 350	Avg-Loss: 2.7233	Training Accuracy : 0.1625
# Epoch: 4	Batch: 400	Avg-Loss: 2.7110	Training Accuracy : 0.1558
# Epoch: 4	Batch: 450	Avg-Loss: 2.6912	Training Accuracy : 0.1606
# Epoch: 4	Batch: 500	Avg-Loss: 2.6995	Training Accuracy : 0.1680
# Epoch: 4	Batch: 550	Avg-Loss: 2.6898	Training Accuracy : 0.1613
# Epoch: 4	Batch: 600	Avg-Loss: 2.6538	Training Accuracy : 0.1638
# Epoch: 4	Batch: 650	Avg-Loss: 2.6519	Training Accuracy : 0.1775
# Epoch: 4, Validation Loss: 2.648, Validation Accuracy: 0.171
# Epoch: 5	Batch: 50	Avg-Loss: 2.6144	Training Accuracy : 0.1753
# Epoch: 5	Batch: 100	Avg-Loss: 2.5767	Training Accuracy : 0.1884
# Epoch: 5	Batch: 150	Avg-Loss: 2.5962	Training Accuracy : 0.1850
# Epoch: 5	Batch: 200	Avg-Loss: 2.5703	Training Accuracy : 0.1859
# Epoch: 5	Batch: 250	Avg-Loss: 2.5845	Training Accuracy : 0.1909
# Epoch: 5	Batch: 300	Avg-Loss: 2.5578	Training Accuracy : 0.1978
# Epoch: 5	Batch: 350	Avg-Loss: 2.5828	Training Accuracy : 0.1786
# Epoch: 5	Batch: 400	Avg-Loss: 2.5749	Training Accuracy : 0.1867
# Epoch: 5	Batch: 450	Avg-Loss: 2.5482	Training Accuracy : 0.1948
# Epoch: 5	Batch: 500	Avg-Loss: 2.5578	Training Accuracy : 0.1862
# Epoch: 5	Batch: 550	Avg-Loss: 2.5252	Training Accuracy : 0.1903
# Epoch: 5	Batch: 600	Avg-Loss: 2.5156	Training Accuracy : 0.1945
# Epoch: 5	Batch: 650	Avg-Loss: 2.5343	Training Accuracy : 0.1925
# Epoch: 5, Validation Loss: 2.532, Validation Accuracy: 0.197
# Epoch: 6	Batch: 50	Avg-Loss: 2.5001	Training Accuracy : 0.2022
# Epoch: 6	Batch: 100	Avg-Loss: 2.4734	Training Accuracy : 0.2023
# Epoch: 6	Batch: 150	Avg-Loss: 2.4677	Training Accuracy : 0.2052
# Epoch: 6	Batch: 200	Avg-Loss: 2.4856	Training Accuracy : 0.2053
# Epoch: 6	Batch: 250	Avg-Loss: 2.4615	Training Accuracy : 0.1991
# Epoch: 6	Batch: 300	Avg-Loss: 2.4540	Training Accuracy : 0.2066
# Epoch: 6	Batch: 350	Avg-Loss: 2.4636	Training Accuracy : 0.2017
# Epoch: 6	Batch: 400	Avg-Loss: 2.4619	Training Accuracy : 0.2086
# Epoch: 6	Batch: 450	Avg-Loss: 2.4355	Training Accuracy : 0.2077
# Epoch: 6	Batch: 500	Avg-Loss: 2.4622	Training Accuracy : 0.2069
# Epoch: 6	Batch: 550	Avg-Loss: 2.4481	Training Accuracy : 0.2139
# Epoch: 6	Batch: 600	Avg-Loss: 2.4253	Training Accuracy : 0.2105
# Epoch: 6	Batch: 650	Avg-Loss: 2.4796	Training Accuracy : 0.2080
# Epoch: 6, Validation Loss: 2.478, Validation Accuracy: 0.202
# Epoch: 7	Batch: 50	Avg-Loss: 2.4162	Training Accuracy : 0.2184
# Epoch: 7	Batch: 100	Avg-Loss: 2.4174	Training Accuracy : 0.2194
# Epoch: 7	Batch: 150	Avg-Loss: 2.3938	Training Accuracy : 0.2175
# Epoch: 7	Batch: 200	Avg-Loss: 2.4053	Training Accuracy : 0.2120
# Epoch: 7	Batch: 250	Avg-Loss: 2.4170	Training Accuracy : 0.2170
# Epoch: 7	Batch: 300	Avg-Loss: 2.3733	Training Accuracy : 0.2161
# Epoch: 7	Batch: 350	Avg-Loss: 2.3930	Training Accuracy : 0.2180
# Epoch: 7	Batch: 400	Avg-Loss: 2.3758	Training Accuracy : 0.2197
# Epoch: 7	Batch: 450	Avg-Loss: 2.3713	Training Accuracy : 0.2305
# Epoch: 7	Batch: 500	Avg-Loss: 2.4074	Training Accuracy : 0.2109
# Epoch: 7	Batch: 550	Avg-Loss: 2.3970	Training Accuracy : 0.2056
# Epoch: 7	Batch: 600	Avg-Loss: 2.3554	Training Accuracy : 0.2259
# Epoch: 7	Batch: 650	Avg-Loss: 2.3528	Training Accuracy : 0.2236
# Epoch: 7, Validation Loss: 2.685, Validation Accuracy: 0.183
# Epoch: 8	Batch: 50	Avg-Loss: 2.3343	Training Accuracy : 0.2345
# Epoch: 8	Batch: 100	Avg-Loss: 2.3211	Training Accuracy : 0.2330
# Epoch: 8	Batch: 150	Avg-Loss: 2.3200	Training Accuracy : 0.2330
# Epoch: 8	Batch: 200	Avg-Loss: 2.3424	Training Accuracy : 0.2308
# Epoch: 8	Batch: 250	Avg-Loss: 2.3568	Training Accuracy : 0.2264
# Epoch: 8	Batch: 300	Avg-Loss: 2.3164	Training Accuracy : 0.2367
# Epoch: 8	Batch: 350	Avg-Loss: 2.3180	Training Accuracy : 0.2313
# Epoch: 8	Batch: 400	Avg-Loss: 2.3452	Training Accuracy : 0.2291
# Epoch: 8	Batch: 450	Avg-Loss: 2.3302	Training Accuracy : 0.2300
# Epoch: 8	Batch: 500	Avg-Loss: 2.3290	Training Accuracy : 0.2352
# Epoch: 8	Batch: 550	Avg-Loss: 2.3085	Training Accuracy : 0.2375
# Epoch: 8	Batch: 600	Avg-Loss: 2.3201	Training Accuracy : 0.2313
# Epoch: 8	Batch: 650	Avg-Loss: 2.3087	Training Accuracy : 0.2352
# Epoch: 8, Validation Loss: 2.384, Validation Accuracy: 0.223
# Epoch: 9	Batch: 50	Avg-Loss: 2.2723	Training Accuracy : 0.2383
# Epoch: 9	Batch: 100	Avg-Loss: 2.3090	Training Accuracy : 0.2375
# Epoch: 9	Batch: 150	Avg-Loss: 2.2855	Training Accuracy : 0.2444
# Epoch: 9	Batch: 200	Avg-Loss: 2.2386	Training Accuracy : 0.2441
# Epoch: 9	Batch: 250	Avg-Loss: 2.2944	Training Accuracy : 0.2362
# Epoch: 9	Batch: 300	Avg-Loss: 2.2809	Training Accuracy : 0.2311
# Epoch: 9	Batch: 350	Avg-Loss: 2.2647	Training Accuracy : 0.2442
# Epoch: 9	Batch: 400	Avg-Loss: 2.3084	Training Accuracy : 0.2406
# Epoch: 9	Batch: 450	Avg-Loss: 2.2798	Training Accuracy : 0.2391
# Epoch: 9	Batch: 500	Avg-Loss: 2.2633	Training Accuracy : 0.2498
# Epoch: 9	Batch: 550	Avg-Loss: 2.2588	Training Accuracy : 0.2383
# Epoch: 9	Batch: 600	Avg-Loss: 2.2684	Training Accuracy : 0.2327
# Epoch: 9	Batch: 650	Avg-Loss: 2.2538	Training Accuracy : 0.2417
# Epoch: 9, Validation Loss: 2.385, Validation Accuracy: 0.227
# Epoch: 10	Batch: 50	Avg-Loss: 2.2154	Training Accuracy : 0.2486
# Epoch: 10	Batch: 100	Avg-Loss: 2.2130	Training Accuracy : 0.2534
# Epoch: 10	Batch: 150	Avg-Loss: 2.2936	Training Accuracy : 0.2409
# Epoch: 10	Batch: 200	Avg-Loss: 2.3231	Training Accuracy : 0.2339
# Epoch: 10	Batch: 250	Avg-Loss: 2.2612	Training Accuracy : 0.2472
# Epoch: 10	Batch: 300	Avg-Loss: 2.2630	Training Accuracy : 0.2412
# Epoch: 10	Batch: 350	Avg-Loss: 2.2821	Training Accuracy : 0.2344
# Epoch: 10	Batch: 400	Avg-Loss: 2.2537	Training Accuracy : 0.2412
# Epoch: 10	Batch: 450	Avg-Loss: 2.2821	Training Accuracy : 0.2408
# Epoch: 10	Batch: 500	Avg-Loss: 2.2221	Training Accuracy : 0.2442
# Epoch: 10	Batch: 550	Avg-Loss: 2.1948	Training Accuracy : 0.2691
# Epoch: 10	Batch: 600	Avg-Loss: 2.2274	Training Accuracy : 0.2462
# Epoch: 10	Batch: 650	Avg-Loss: 2.2202	Training Accuracy : 0.2559
# Epoch: 10, Validation Loss: 2.347, Validation Accuracy: 0.235
# Epoch: 11	Batch: 50	Avg-Loss: 2.1920	Training Accuracy : 0.2555
# Epoch: 11	Batch: 100	Avg-Loss: 2.1938	Training Accuracy : 0.2531
# Epoch: 11	Batch: 150	Avg-Loss: 2.2040	Training Accuracy : 0.2420
# Epoch: 11	Batch: 200	Avg-Loss: 2.2244	Training Accuracy : 0.2439
# Epoch: 11	Batch: 250	Avg-Loss: 2.1972	Training Accuracy : 0.2528
# Epoch: 11	Batch: 300	Avg-Loss: 2.1748	Training Accuracy : 0.2573
# Epoch: 11	Batch: 350	Avg-Loss: 2.2253	Training Accuracy : 0.2405
# Epoch: 11	Batch: 400	Avg-Loss: 2.2246	Training Accuracy : 0.2492
# Epoch: 11	Batch: 450	Avg-Loss: 2.1980	Training Accuracy : 0.2597
# Epoch: 11	Batch: 500	Avg-Loss: 2.2047	Training Accuracy : 0.2528
# Epoch: 11	Batch: 550	Avg-Loss: 2.1857	Training Accuracy : 0.2498
# Epoch: 11	Batch: 600	Avg-Loss: 2.1757	Training Accuracy : 0.2584
# Epoch: 11	Batch: 650	Avg-Loss: 2.2022	Training Accuracy : 0.2491
# Epoch: 11, Validation Loss: 2.327, Validation Accuracy: 0.239
# Epoch: 12	Batch: 50	Avg-Loss: 2.1406	Training Accuracy : 0.2691
# Epoch: 12	Batch: 100	Avg-Loss: 2.1730	Training Accuracy : 0.2530
# Epoch: 12	Batch: 150	Avg-Loss: 2.1587	Training Accuracy : 0.2564
# Epoch: 12	Batch: 200	Avg-Loss: 2.1171	Training Accuracy : 0.2628
# Epoch: 12	Batch: 250	Avg-Loss: 2.1622	Training Accuracy : 0.2559
# Epoch: 12	Batch: 300	Avg-Loss: 2.1470	Training Accuracy : 0.2683
# Epoch: 12	Batch: 350	Avg-Loss: 2.1397	Training Accuracy : 0.2619
# Epoch: 12	Batch: 400	Avg-Loss: 2.1448	Training Accuracy : 0.2603
# Epoch: 12	Batch: 450	Avg-Loss: 2.1396	Training Accuracy : 0.2587
# Epoch: 12	Batch: 500	Avg-Loss: 2.1334	Training Accuracy : 0.2658
# Epoch: 12	Batch: 550	Avg-Loss: 2.1614	Training Accuracy : 0.2583
# Epoch: 12	Batch: 600	Avg-Loss: 2.1231	Training Accuracy : 0.2681
# Epoch: 12	Batch: 650	Avg-Loss: 2.1506	Training Accuracy : 0.2595
# Epoch: 12, Validation Loss: 2.314, Validation Accuracy: 0.249
# Epoch: 13	Batch: 50	Avg-Loss: 2.0536	Training Accuracy : 0.2773
# Epoch: 13	Batch: 100	Avg-Loss: 2.0566	Training Accuracy : 0.2687
# Epoch: 13	Batch: 150	Avg-Loss: 2.0795	Training Accuracy : 0.2708
# Epoch: 13	Batch: 200	Avg-Loss: 2.0823	Training Accuracy : 0.2687
# Epoch: 13	Batch: 250	Avg-Loss: 2.0740	Training Accuracy : 0.2783
# Epoch: 13	Batch: 300	Avg-Loss: 2.1065	Training Accuracy : 0.2634
# Epoch: 13	Batch: 350	Avg-Loss: 2.1040	Training Accuracy : 0.2712
# Epoch: 13	Batch: 400	Avg-Loss: 2.0677	Training Accuracy : 0.2684
# Epoch: 13	Batch: 450	Avg-Loss: 2.1018	Training Accuracy : 0.2673
# Epoch: 13	Batch: 500	Avg-Loss: 2.0802	Training Accuracy : 0.2756
# Epoch: 13	Batch: 550	Avg-Loss: 2.0797	Training Accuracy : 0.2744
# Epoch: 13	Batch: 600	Avg-Loss: 2.0952	Training Accuracy : 0.2730
# Epoch: 13	Batch: 650	Avg-Loss: 2.0657	Training Accuracy : 0.2791
# Epoch: 13, Validation Loss: 2.479, Validation Accuracy: 0.223
# Epoch: 14	Batch: 50	Avg-Loss: 2.0132	Training Accuracy : 0.2834
# Epoch: 14	Batch: 100	Avg-Loss: 2.0001	Training Accuracy : 0.2798
# Epoch: 14	Batch: 150	Avg-Loss: 1.9938	Training Accuracy : 0.2850
# Epoch: 14	Batch: 200	Avg-Loss: 2.0242	Training Accuracy : 0.2805
# Epoch: 14	Batch: 250	Avg-Loss: 2.0203	Training Accuracy : 0.2864
# Epoch: 14	Batch: 300	Avg-Loss: 2.0293	Training Accuracy : 0.2752
# Epoch: 14	Batch: 350	Avg-Loss: 2.0065	Training Accuracy : 0.2805
# Epoch: 14	Batch: 400	Avg-Loss: 2.0416	Training Accuracy : 0.2777
# Epoch: 14	Batch: 450	Avg-Loss: 2.0319	Training Accuracy : 0.2711
# Epoch: 14	Batch: 500	Avg-Loss: 2.0229	Training Accuracy : 0.2725
# Epoch: 14	Batch: 550	Avg-Loss: 1.9928	Training Accuracy : 0.2844
# Epoch: 14	Batch: 600	Avg-Loss: 2.0287	Training Accuracy : 0.2866
# Epoch: 14	Batch: 650	Avg-Loss: 2.0015	Training Accuracy : 0.2858
# Epoch: 14, Validation Loss: 2.363, Validation Accuracy: 0.238
# Epoch: 15	Batch: 50	Avg-Loss: 1.9183	Training Accuracy : 0.3003
# Epoch: 15	Batch: 100	Avg-Loss: 1.9312	Training Accuracy : 0.2955
# Epoch: 15	Batch: 150	Avg-Loss: 1.9430	Training Accuracy : 0.2958
# Epoch: 15	Batch: 200	Avg-Loss: 1.9456	Training Accuracy : 0.2903
# Epoch: 15	Batch: 250	Avg-Loss: 1.9345	Training Accuracy : 0.2934
# Epoch: 15	Batch: 300	Avg-Loss: 1.9492	Training Accuracy : 0.2959
# Epoch: 15	Batch: 350	Avg-Loss: 1.9357	Training Accuracy : 0.2836
# Epoch: 15	Batch: 400	Avg-Loss: 1.9548	Training Accuracy : 0.2959
# Epoch: 15	Batch: 450	Avg-Loss: 1.9346	Training Accuracy : 0.2975
# Epoch: 15	Batch: 500	Avg-Loss: 1.9387	Training Accuracy : 0.2969
# Epoch: 15	Batch: 550	Avg-Loss: 1.9132	Training Accuracy : 0.2892
# Epoch: 15	Batch: 600	Avg-Loss: 1.9228	Training Accuracy : 0.2941
# Epoch: 15	Batch: 650	Avg-Loss: 1.9181	Training Accuracy : 0.2909
# Epoch    16: reducing learning rate of group 0 to 5.0000e-02.
# Epoch: 15, Validation Loss: 2.511, Validation Accuracy: 0.221
# Epoch: 16	Batch: 50	Avg-Loss: 1.6999	Training Accuracy : 0.3392
# Epoch: 16	Batch: 100	Avg-Loss: 1.6552	Training Accuracy : 0.3575
# Epoch: 16	Batch: 150	Avg-Loss: 1.6493	Training Accuracy : 0.3511
# Epoch: 16	Batch: 200	Avg-Loss: 1.6370	Training Accuracy : 0.3614
# Epoch: 16	Batch: 250	Avg-Loss: 1.6282	Training Accuracy : 0.3705
# Epoch: 16	Batch: 300	Avg-Loss: 1.6369	Training Accuracy : 0.3648
# Epoch: 16	Batch: 350	Avg-Loss: 1.6394	Training Accuracy : 0.3634
# Epoch: 16	Batch: 400	Avg-Loss: 1.6475	Training Accuracy : 0.3647
# Epoch: 16	Batch: 450	Avg-Loss: 1.6459	Training Accuracy : 0.3638
# Epoch: 16	Batch: 500	Avg-Loss: 1.6271	Training Accuracy : 0.3627
# Epoch: 16	Batch: 550	Avg-Loss: 1.6634	Training Accuracy : 0.3634
# Epoch: 16	Batch: 600	Avg-Loss: 1.5945	Training Accuracy : 0.3817
# Epoch: 16	Batch: 650	Avg-Loss: 1.6198	Training Accuracy : 0.3745
# Epoch: 16, Validation Loss: 2.587, Validation Accuracy: 0.250
# Epoch: 17	Batch: 50	Avg-Loss: 1.4792	Training Accuracy : 0.4152
# Epoch: 17	Batch: 100	Avg-Loss: 1.5206	Training Accuracy : 0.4022
# Epoch: 17	Batch: 150	Avg-Loss: 1.4989	Training Accuracy : 0.4159
# Epoch: 17	Batch: 200	Avg-Loss: 1.5433	Training Accuracy : 0.4075
# Epoch: 17	Batch: 250	Avg-Loss: 1.5464	Training Accuracy : 0.4023
# Epoch: 17	Batch: 300	Avg-Loss: 1.5085	Training Accuracy : 0.4138
# Epoch: 17	Batch: 350	Avg-Loss: 1.5749	Training Accuracy : 0.4017
# Epoch: 17	Batch: 400	Avg-Loss: 1.5412	Training Accuracy : 0.4213
# Epoch: 17	Batch: 450	Avg-Loss: 1.5547	Training Accuracy : 0.4128
# Epoch: 17	Batch: 500	Avg-Loss: 1.5209	Training Accuracy : 0.4231
# Epoch: 17	Batch: 550	Avg-Loss: 1.5356	Training Accuracy : 0.4225
# Epoch: 17	Batch: 600	Avg-Loss: 1.5820	Training Accuracy : 0.4111
# Epoch: 17	Batch: 650	Avg-Loss: 1.5383	Training Accuracy : 0.4261
# Epoch: 17, Validation Loss: 2.748, Validation Accuracy: 0.235
# Epoch: 18	Batch: 50	Avg-Loss: 1.4053	Training Accuracy : 0.4797
# Epoch: 18	Batch: 100	Avg-Loss: 1.3959	Training Accuracy : 0.4848
# Epoch: 18	Batch: 150	Avg-Loss: 1.4094	Training Accuracy : 0.4813
# Epoch: 18	Batch: 200	Avg-Loss: 1.4368	Training Accuracy : 0.4744
# Epoch: 18	Batch: 250	Avg-Loss: 1.4505	Training Accuracy : 0.4748
# Epoch: 18	Batch: 300	Avg-Loss: 1.4286	Training Accuracy : 0.4856
# Epoch: 18	Batch: 350	Avg-Loss: 1.4405	Training Accuracy : 0.4753
# Epoch: 18	Batch: 400	Avg-Loss: 1.4359	Training Accuracy : 0.4898
# Epoch: 18	Batch: 450	Avg-Loss: 1.4211	Training Accuracy : 0.4936
# Epoch: 18	Batch: 500	Avg-Loss: 1.4437	Training Accuracy : 0.4848
# Epoch: 18	Batch: 550	Avg-Loss: 1.4287	Training Accuracy : 0.4952
# Epoch: 18	Batch: 600	Avg-Loss: 1.3887	Training Accuracy : 0.5139
# Epoch: 18	Batch: 650	Avg-Loss: 1.4442	Training Accuracy : 0.4977
# Epoch    19: reducing learning rate of group 0 to 2.5000e-02.
# Epoch: 18, Validation Loss: 2.912, Validation Accuracy: 0.239
# Epoch: 19	Batch: 50	Avg-Loss: 1.1361	Training Accuracy : 0.6044
# Epoch: 19	Batch: 100	Avg-Loss: 1.0555	Training Accuracy : 0.6275
# Epoch: 19	Batch: 150	Avg-Loss: 1.0373	Training Accuracy : 0.6331
# Epoch: 19	Batch: 200	Avg-Loss: 1.0467	Training Accuracy : 0.6366
# Epoch: 19	Batch: 250	Avg-Loss: 1.0411	Training Accuracy : 0.6430
# Epoch: 19	Batch: 300	Avg-Loss: 1.0008	Training Accuracy : 0.6500
# Epoch: 19	Batch: 350	Avg-Loss: 1.0450	Training Accuracy : 0.6469
# Epoch: 19	Batch: 400	Avg-Loss: 1.0143	Training Accuracy : 0.6508
# Epoch: 19	Batch: 450	Avg-Loss: 1.0218	Training Accuracy : 0.6495
# Epoch: 19	Batch: 500	Avg-Loss: 1.0149	Training Accuracy : 0.6555
# Epoch: 19	Batch: 550	Avg-Loss: 1.0249	Training Accuracy : 0.6523
# Epoch: 19	Batch: 600	Avg-Loss: 1.0109	Training Accuracy : 0.6637
# Epoch: 19	Batch: 650	Avg-Loss: 1.0182	Training Accuracy : 0.6553
# Epoch: 19, Validation Loss: 3.371, Validation Accuracy: 0.250
# Epoch: 20	Batch: 50	Avg-Loss: 0.8321	Training Accuracy : 0.7183
# Epoch: 20	Batch: 100	Avg-Loss: 0.7989	Training Accuracy : 0.7264
# Epoch: 20	Batch: 150	Avg-Loss: 0.8756	Training Accuracy : 0.7016
# Epoch: 20	Batch: 200	Avg-Loss: 0.8325	Training Accuracy : 0.7194
# Epoch: 20	Batch: 250	Avg-Loss: 0.8454	Training Accuracy : 0.7095
# Epoch: 20	Batch: 300	Avg-Loss: 0.8709	Training Accuracy : 0.7044
# Epoch: 20	Batch: 350	Avg-Loss: 0.8805	Training Accuracy : 0.7037
# Epoch: 20	Batch: 400	Avg-Loss: 0.8889	Training Accuracy : 0.7013
# Epoch: 20	Batch: 450	Avg-Loss: 0.9221	Training Accuracy : 0.6877
# Epoch: 20	Batch: 500	Avg-Loss: 0.8815	Training Accuracy : 0.7047
# Epoch: 20	Batch: 550	Avg-Loss: 0.8925	Training Accuracy : 0.6956
# Epoch: 20	Batch: 600	Avg-Loss: 0.8935	Training Accuracy : 0.7047
# Epoch: 20	Batch: 650	Avg-Loss: 0.8751	Training Accuracy : 0.7047
# Epoch: 20, Validation Loss: 3.591, Validation Accuracy: 0.226
# Epoch: 21	Batch: 50	Avg-Loss: 0.7323	Training Accuracy : 0.7561
# Epoch: 21	Batch: 100	Avg-Loss: 0.7411	Training Accuracy : 0.7503
# Epoch: 21	Batch: 150	Avg-Loss: 0.7387	Training Accuracy : 0.7517
# Epoch: 21	Batch: 200	Avg-Loss: 0.7244	Training Accuracy : 0.7616
# Epoch: 21	Batch: 250	Avg-Loss: 0.7510	Training Accuracy : 0.7492
# Epoch: 21	Batch: 300	Avg-Loss: 0.7650	Training Accuracy : 0.7383
# Epoch: 21	Batch: 350	Avg-Loss: 0.7579	Training Accuracy : 0.7439
# Epoch: 21	Batch: 400	Avg-Loss: 0.7789	Training Accuracy : 0.7311
# Epoch: 21	Batch: 450	Avg-Loss: 0.7903	Training Accuracy : 0.7334
# Epoch: 21	Batch: 500	Avg-Loss: 0.7999	Training Accuracy : 0.7302
# Epoch: 21	Batch: 550	Avg-Loss: 0.7610	Training Accuracy : 0.7406
# Epoch: 21	Batch: 600	Avg-Loss: 0.8009	Training Accuracy : 0.7230
# Epoch: 21	Batch: 650	Avg-Loss: 0.7986	Training Accuracy : 0.7300
# Epoch    22: reducing learning rate of group 0 to 1.2500e-02.
# Epoch: 21, Validation Loss: 3.737, Validation Accuracy: 0.234
# Epoch: 22	Batch: 50	Avg-Loss: 0.6079	Training Accuracy : 0.8025
# Epoch: 22	Batch: 100	Avg-Loss: 0.5427	Training Accuracy : 0.8222
# Epoch: 22	Batch: 150	Avg-Loss: 0.5152	Training Accuracy : 0.8256
# Epoch: 22	Batch: 200	Avg-Loss: 0.4867	Training Accuracy : 0.8438
# Epoch: 22	Batch: 250	Avg-Loss: 0.4992	Training Accuracy : 0.8337
# Epoch: 22	Batch: 300	Avg-Loss: 0.4830	Training Accuracy : 0.8422
# Epoch: 22	Batch: 350	Avg-Loss: 0.4959	Training Accuracy : 0.8356
# Epoch: 22	Batch: 400	Avg-Loss: 0.5016	Training Accuracy : 0.8302
# Epoch: 22	Batch: 450	Avg-Loss: 0.4884	Training Accuracy : 0.8384
# Epoch: 22	Batch: 500	Avg-Loss: 0.4937	Training Accuracy : 0.8359
# Epoch: 22	Batch: 550	Avg-Loss: 0.4874	Training Accuracy : 0.8378
# Epoch: 22	Batch: 600	Avg-Loss: 0.5032	Training Accuracy : 0.8344
# Epoch: 22	Batch: 650	Avg-Loss: 0.5103	Training Accuracy : 0.8261
# Epoch: 22, Validation Loss: 4.352, Validation Accuracy: 0.246
# Epoch: 23	Batch: 50	Avg-Loss: 0.3961	Training Accuracy : 0.8722
# Epoch: 23	Batch: 100	Avg-Loss: 0.3858	Training Accuracy : 0.8750
# Epoch: 23	Batch: 150	Avg-Loss: 0.3933	Training Accuracy : 0.8725
# Epoch: 23	Batch: 200	Avg-Loss: 0.3918	Training Accuracy : 0.8725
# Epoch: 23	Batch: 250	Avg-Loss: 0.4120	Training Accuracy : 0.8620
# Epoch: 23	Batch: 300	Avg-Loss: 0.3914	Training Accuracy : 0.8664
# Epoch: 23	Batch: 350	Avg-Loss: 0.4174	Training Accuracy : 0.8583
# Epoch: 23	Batch: 400	Avg-Loss: 0.4096	Training Accuracy : 0.8653
# Epoch: 23	Batch: 450	Avg-Loss: 0.4187	Training Accuracy : 0.8608
# Epoch: 23	Batch: 500	Avg-Loss: 0.4264	Training Accuracy : 0.8631
# Epoch: 23	Batch: 550	Avg-Loss: 0.4414	Training Accuracy : 0.8539
# Epoch: 23	Batch: 600	Avg-Loss: 0.4357	Training Accuracy : 0.8533
# Epoch: 23	Batch: 650	Avg-Loss: 0.4472	Training Accuracy : 0.8477
# Epoch: 23, Validation Loss: 4.820, Validation Accuracy: 0.243
# Epoch: 24	Batch: 50	Avg-Loss: 0.3662	Training Accuracy : 0.8814
# Epoch: 24	Batch: 100	Avg-Loss: 0.3452	Training Accuracy : 0.8881
# Epoch: 24	Batch: 150	Avg-Loss: 0.3562	Training Accuracy : 0.8834
# Epoch: 24	Batch: 200	Avg-Loss: 0.3545	Training Accuracy : 0.8811
# Epoch: 24	Batch: 250	Avg-Loss: 0.3709	Training Accuracy : 0.8814
# Epoch: 24	Batch: 300	Avg-Loss: 0.3496	Training Accuracy : 0.8881
# Epoch: 24	Batch: 350	Avg-Loss: 0.3597	Training Accuracy : 0.8806
# Epoch: 24	Batch: 400	Avg-Loss: 0.3777	Training Accuracy : 0.8744
# Epoch: 24	Batch: 450	Avg-Loss: 0.4022	Training Accuracy : 0.8645
# Epoch: 24	Batch: 500	Avg-Loss: 0.3737	Training Accuracy : 0.8755
# Epoch: 24	Batch: 550	Avg-Loss: 0.4199	Training Accuracy : 0.8591
# Epoch: 24	Batch: 600	Avg-Loss: 0.3882	Training Accuracy : 0.8695
# Epoch: 24	Batch: 650	Avg-Loss: 0.4056	Training Accuracy : 0.8653
# Epoch    25: reducing learning rate of group 0 to 6.2500e-03.
# Epoch: 24, Validation Loss: 4.811, Validation Accuracy: 0.245
# Epoch: 25	Batch: 50	Avg-Loss: 0.3115	Training Accuracy : 0.9023
# Epoch: 25	Batch: 100	Avg-Loss: 0.2853	Training Accuracy : 0.9116
# Epoch: 25	Batch: 150	Avg-Loss: 0.2906	Training Accuracy : 0.9097
# Epoch: 25	Batch: 200	Avg-Loss: 0.2765	Training Accuracy : 0.9136
# Epoch: 25	Batch: 250	Avg-Loss: 0.2745	Training Accuracy : 0.9144
# Epoch: 25	Batch: 300	Avg-Loss: 0.2850	Training Accuracy : 0.9117
# Epoch: 25	Batch: 350	Avg-Loss: 0.2772	Training Accuracy : 0.9094
# Epoch: 25	Batch: 400	Avg-Loss: 0.2862	Training Accuracy : 0.9105
# Epoch: 25	Batch: 450	Avg-Loss: 0.2701	Training Accuracy : 0.9120
# Epoch: 25	Batch: 500	Avg-Loss: 0.2905	Training Accuracy : 0.9061
# Epoch: 25	Batch: 550	Avg-Loss: 0.2860	Training Accuracy : 0.9098
# Epoch: 25	Batch: 600	Avg-Loss: 0.2844	Training Accuracy : 0.9109
# Epoch: 25	Batch: 650	Avg-Loss: 0.2913	Training Accuracy : 0.9073
# Epoch: 25, Validation Loss: 5.079, Validation Accuracy: 0.248
# Epoch: 26	Batch: 50	Avg-Loss: 0.2405	Training Accuracy : 0.9300
# Epoch: 26	Batch: 100	Avg-Loss: 0.2462	Training Accuracy : 0.9269
# Epoch: 26	Batch: 150	Avg-Loss: 0.2313	Training Accuracy : 0.9305
# Epoch: 26	Batch: 200	Avg-Loss: 0.2449	Training Accuracy : 0.9255
# Epoch: 26	Batch: 250	Avg-Loss: 0.2551	Training Accuracy : 0.9195
# Epoch: 26	Batch: 300	Avg-Loss: 0.2304	Training Accuracy : 0.9298
# Epoch: 26	Batch: 350	Avg-Loss: 0.2379	Training Accuracy : 0.9223
# Epoch: 26	Batch: 400	Avg-Loss: 0.2459	Training Accuracy : 0.9217
# Epoch: 26	Batch: 450	Avg-Loss: 0.2366	Training Accuracy : 0.9287
# Epoch: 26	Batch: 500	Avg-Loss: 0.2325	Training Accuracy : 0.9295
# Epoch: 26	Batch: 550	Avg-Loss: 0.2271	Training Accuracy : 0.9284
# Epoch: 26	Batch: 600	Avg-Loss: 0.2385	Training Accuracy : 0.9267
# Epoch: 26	Batch: 650	Avg-Loss: 0.2414	Training Accuracy : 0.9252
# Epoch: 26, Validation Loss: 5.393, Validation Accuracy: 0.247
# Epoch: 27	Batch: 50	Avg-Loss: 0.2257	Training Accuracy : 0.9320
# Epoch: 27	Batch: 100	Avg-Loss: 0.2089	Training Accuracy : 0.9359
# Epoch: 27	Batch: 150	Avg-Loss: 0.2251	Training Accuracy : 0.9314
# Epoch: 27	Batch: 200	Avg-Loss: 0.2211	Training Accuracy : 0.9344
# Epoch: 27	Batch: 250	Avg-Loss: 0.2179	Training Accuracy : 0.9345
# Epoch: 27	Batch: 300	Avg-Loss: 0.2190	Training Accuracy : 0.9323
# Epoch: 27	Batch: 350	Avg-Loss: 0.2210	Training Accuracy : 0.9314
# Epoch: 27	Batch: 400	Avg-Loss: 0.2213	Training Accuracy : 0.9317
# Epoch: 27	Batch: 450	Avg-Loss: 0.2178	Training Accuracy : 0.9311
# Epoch: 27	Batch: 500	Avg-Loss: 0.2243	Training Accuracy : 0.9297
# Epoch: 27	Batch: 550	Avg-Loss: 0.2446	Training Accuracy : 0.9239
# Epoch: 27	Batch: 600	Avg-Loss: 0.2249	Training Accuracy : 0.9313
# Epoch: 27	Batch: 650	Avg-Loss: 0.2080	Training Accuracy : 0.9366
# Epoch    28: reducing learning rate of group 0 to 3.1250e-03.
# Epoch: 27, Validation Loss: 5.565, Validation Accuracy: 0.247
# Epoch: 28	Batch: 50	Avg-Loss: 0.1839	Training Accuracy : 0.9455
# Epoch: 28	Batch: 100	Avg-Loss: 0.1832	Training Accuracy : 0.9461
# Epoch: 28	Batch: 150	Avg-Loss: 0.1912	Training Accuracy : 0.9437
# Epoch: 28	Batch: 200	Avg-Loss: 0.1763	Training Accuracy : 0.9475
# Epoch: 28	Batch: 250	Avg-Loss: 0.1926	Training Accuracy : 0.9423
# Epoch: 28	Batch: 300	Avg-Loss: 0.1921	Training Accuracy : 0.9427
# Epoch: 28	Batch: 350	Avg-Loss: 0.1835	Training Accuracy : 0.9463
# Epoch: 28	Batch: 400	Avg-Loss: 0.1844	Training Accuracy : 0.9436
# Epoch: 28	Batch: 450	Avg-Loss: 0.1759	Training Accuracy : 0.9466
# Epoch: 28	Batch: 500	Avg-Loss: 0.1864	Training Accuracy : 0.9445
# Epoch: 28	Batch: 550	Avg-Loss: 0.1821	Training Accuracy : 0.9436
# Epoch: 28	Batch: 600	Avg-Loss: 0.1949	Training Accuracy : 0.9450
# Epoch: 28	Batch: 650	Avg-Loss: 0.1895	Training Accuracy : 0.9437
# Epoch: 28, Validation Loss: 5.608, Validation Accuracy: 0.245
# Epoch: 29	Batch: 50	Avg-Loss: 0.1632	Training Accuracy : 0.9523
# Epoch: 29	Batch: 100	Avg-Loss: 0.1920	Training Accuracy : 0.9452
# Epoch: 29	Batch: 150	Avg-Loss: 0.1692	Training Accuracy : 0.9498
# Epoch: 29	Batch: 200	Avg-Loss: 0.1585	Training Accuracy : 0.9534
# Epoch: 29	Batch: 250	Avg-Loss: 0.1761	Training Accuracy : 0.9469
# Epoch: 29	Batch: 300	Avg-Loss: 0.1749	Training Accuracy : 0.9483
# Epoch: 29	Batch: 350	Avg-Loss: 0.1713	Training Accuracy : 0.9491
# Epoch: 29	Batch: 400	Avg-Loss: 0.1690	Training Accuracy : 0.9519
# Epoch: 29	Batch: 450	Avg-Loss: 0.1640	Training Accuracy : 0.9527
# Epoch: 29	Batch: 500	Avg-Loss: 0.1793	Training Accuracy : 0.9487
# Epoch: 29	Batch: 550	Avg-Loss: 0.1719	Training Accuracy : 0.9487
# Epoch: 29	Batch: 600	Avg-Loss: 0.1842	Training Accuracy : 0.9448
# Epoch: 29	Batch: 650	Avg-Loss: 0.1847	Training Accuracy : 0.9430
# Epoch: 29, Validation Loss: 5.652, Validation Accuracy: 0.244
# Epoch: 30	Batch: 50	Avg-Loss: 0.1672	Training Accuracy : 0.9547
# Epoch: 30	Batch: 100	Avg-Loss: 0.1629	Training Accuracy : 0.9539
# Epoch: 30	Batch: 150	Avg-Loss: 0.1501	Training Accuracy : 0.9559
# Epoch: 30	Batch: 200	Avg-Loss: 0.1649	Training Accuracy : 0.9537
# Epoch: 30	Batch: 250	Avg-Loss: 0.1597	Training Accuracy : 0.9522
# Epoch: 30	Batch: 300	Avg-Loss: 0.1546	Training Accuracy : 0.9566
# Epoch: 30	Batch: 350	Avg-Loss: 0.1787	Training Accuracy : 0.9473
# Epoch: 30	Batch: 400	Avg-Loss: 0.1744	Training Accuracy : 0.9480
# Epoch: 30	Batch: 450	Avg-Loss: 0.1788	Training Accuracy : 0.9487
# Epoch: 30	Batch: 500	Avg-Loss: 0.1513	Training Accuracy : 0.9564
# Epoch: 30	Batch: 550	Avg-Loss: 0.1467	Training Accuracy : 0.9553
# Epoch: 30	Batch: 600	Avg-Loss: 0.1725	Training Accuracy : 0.9514
# Epoch: 30	Batch: 650	Avg-Loss: 0.1677	Training Accuracy : 0.9514
# Epoch    31: reducing learning rate of group 0 to 1.5625e-03.
# Epoch: 30, Validation Loss: 5.796, Validation Accuracy: 0.247
# Epoch: 31	Batch: 50	Avg-Loss: 0.1539	Training Accuracy : 0.9564
# Epoch: 31	Batch: 100	Avg-Loss: 0.1562	Training Accuracy : 0.9544
# Epoch: 31	Batch: 150	Avg-Loss: 0.1570	Training Accuracy : 0.9522
# Epoch: 31	Batch: 200	Avg-Loss: 0.1554	Training Accuracy : 0.9545
# Epoch: 31	Batch: 250	Avg-Loss: 0.1554	Training Accuracy : 0.9545
# Epoch: 31	Batch: 300	Avg-Loss: 0.1492	Training Accuracy : 0.9564
# Epoch: 31	Batch: 350	Avg-Loss: 0.1588	Training Accuracy : 0.9547
# Epoch: 31	Batch: 400	Avg-Loss: 0.1512	Training Accuracy : 0.9572
# Epoch: 31	Batch: 450	Avg-Loss: 0.1447	Training Accuracy : 0.9577
# Epoch: 31	Batch: 500	Avg-Loss: 0.1439	Training Accuracy : 0.9573
# Epoch: 31	Batch: 550	Avg-Loss: 0.1514	Training Accuracy : 0.9572
# Epoch: 31	Batch: 600	Avg-Loss: 0.1571	Training Accuracy : 0.9528
# Epoch: 31	Batch: 650	Avg-Loss: 0.1367	Training Accuracy : 0.9608
# Epoch: 31, Validation Loss: 5.806, Validation Accuracy: 0.245
# Epoch: 32	Batch: 50	Avg-Loss: 0.1471	Training Accuracy : 0.9580
# Epoch: 32	Batch: 100	Avg-Loss: 0.1329	Training Accuracy : 0.9631
# Epoch: 32	Batch: 150	Avg-Loss: 0.1480	Training Accuracy : 0.9578
# Epoch: 32	Batch: 200	Avg-Loss: 0.1501	Training Accuracy : 0.9561
# Epoch: 32	Batch: 250	Avg-Loss: 0.1499	Training Accuracy : 0.9558
# Epoch: 32	Batch: 300	Avg-Loss: 0.1485	Training Accuracy : 0.9548
# Epoch: 32	Batch: 350	Avg-Loss: 0.1476	Training Accuracy : 0.9573
# Epoch: 32	Batch: 400	Avg-Loss: 0.1390	Training Accuracy : 0.9591
# Epoch: 32	Batch: 450	Avg-Loss: 0.1453	Training Accuracy : 0.9581
# Epoch: 32	Batch: 500	Avg-Loss: 0.1479	Training Accuracy : 0.9577
# Epoch: 32	Batch: 550	Avg-Loss: 0.1617	Training Accuracy : 0.9527
# Epoch: 32	Batch: 600	Avg-Loss: 0.1534	Training Accuracy : 0.9569
# Epoch: 32	Batch: 650	Avg-Loss: 0.1378	Training Accuracy : 0.9609
# Epoch: 32, Validation Loss: 5.787, Validation Accuracy: 0.248
# Epoch: 33	Batch: 50	Avg-Loss: 0.1383	Training Accuracy : 0.9608
# Epoch: 33	Batch: 100	Avg-Loss: 0.1359	Training Accuracy : 0.9613
# Epoch: 33	Batch: 150	Avg-Loss: 0.1430	Training Accuracy : 0.9586
# Epoch: 33	Batch: 200	Avg-Loss: 0.1470	Training Accuracy : 0.9570
# Epoch: 33	Batch: 250	Avg-Loss: 0.1407	Training Accuracy : 0.9581
# Epoch: 33	Batch: 300	Avg-Loss: 0.1420	Training Accuracy : 0.9595
# Epoch: 33	Batch: 350	Avg-Loss: 0.1382	Training Accuracy : 0.9613
# Epoch: 33	Batch: 400	Avg-Loss: 0.1408	Training Accuracy : 0.9589
# Epoch: 33	Batch: 450	Avg-Loss: 0.1477	Training Accuracy : 0.9572
# Epoch: 33	Batch: 500	Avg-Loss: 0.1369	Training Accuracy : 0.9617
# Epoch: 33	Batch: 550	Avg-Loss: 0.1465	Training Accuracy : 0.9592
# Epoch: 33	Batch: 600	Avg-Loss: 0.1369	Training Accuracy : 0.9617
# Epoch: 33	Batch: 650	Avg-Loss: 0.1491	Training Accuracy : 0.9553
# Epoch    34: reducing learning rate of group 0 to 7.8125e-04.
# Epoch: 33, Validation Loss: 5.867, Validation Accuracy: 0.243
# Epoch: 34	Batch: 50	Avg-Loss: 0.1343	Training Accuracy : 0.9619
# Epoch: 34	Batch: 100	Avg-Loss: 0.1241	Training Accuracy : 0.9650
# Epoch: 34	Batch: 150	Avg-Loss: 0.1328	Training Accuracy : 0.9630
# Epoch: 34	Batch: 200	Avg-Loss: 0.1262	Training Accuracy : 0.9633
# Epoch: 34	Batch: 250	Avg-Loss: 0.1391	Training Accuracy : 0.9628
# Epoch: 34	Batch: 300	Avg-Loss: 0.1504	Training Accuracy : 0.9584
# Epoch: 34	Batch: 350	Avg-Loss: 0.1218	Training Accuracy : 0.9655
# Epoch: 34	Batch: 400	Avg-Loss: 0.1364	Training Accuracy : 0.9606
# Epoch: 34	Batch: 450	Avg-Loss: 0.1389	Training Accuracy : 0.9617
# Epoch: 34	Batch: 500	Avg-Loss: 0.1308	Training Accuracy : 0.9637
# Epoch: 34	Batch: 550	Avg-Loss: 0.1396	Training Accuracy : 0.9609
# Epoch: 34	Batch: 600	Avg-Loss: 0.1361	Training Accuracy : 0.9603
# Epoch: 34	Batch: 650	Avg-Loss: 0.1304	Training Accuracy : 0.9627
# Epoch: 34, Validation Loss: 5.855, Validation Accuracy: 0.246
# Epoch: 35	Batch: 50	Avg-Loss: 0.1232	Training Accuracy : 0.9678
# Epoch: 35	Batch: 100	Avg-Loss: 0.1359	Training Accuracy : 0.9609
# Epoch: 35	Batch: 150	Avg-Loss: 0.1324	Training Accuracy : 0.9628
# Epoch: 35	Batch: 200	Avg-Loss: 0.1227	Training Accuracy : 0.9684
# Epoch: 35	Batch: 250	Avg-Loss: 0.1332	Training Accuracy : 0.9616
# Epoch: 35	Batch: 300	Avg-Loss: 0.1384	Training Accuracy : 0.9584
# Epoch: 35	Batch: 350	Avg-Loss: 0.1247	Training Accuracy : 0.9652
# Epoch: 35	Batch: 400	Avg-Loss: 0.1342	Training Accuracy : 0.9622
# Epoch: 35	Batch: 450	Avg-Loss: 0.1229	Training Accuracy : 0.9672
# Epoch: 35	Batch: 500	Avg-Loss: 0.1326	Training Accuracy : 0.9625
# Epoch: 35	Batch: 550	Avg-Loss: 0.1306	Training Accuracy : 0.9623
# Epoch: 35	Batch: 600	Avg-Loss: 0.1333	Training Accuracy : 0.9647
# Epoch: 35	Batch: 650	Avg-Loss: 0.1308	Training Accuracy : 0.9631
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-6ced6f4908c9> in <module>()
#      35       avg_val_loss = 0.0
#      36       num_correct = 0
# ---> 37       for batch_num, (x, y) in enumerate(val_loader):
#      38           x, y = x.to(device), y.to(device)
#      39           outputs = network(x)
#
# KeyboardInterrupt:

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Mon Nov 29 23:23:01 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P0    38W / 250W |   1091MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_4+1_ours_data1/best_model_16.pt"))
network = network.to(device)

# %%
network.eval()
num_correct = 0
for x, y in tqdm(test_loader):
  x, y = x.to(device), y.to(device)
  outputs = network(x)
  num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

test_acc = num_correct / len(test_set)
print(test_acc)
# Out:
# 100%|██████████| 141/141 [02:51<00:00,  1.22s/it]
# 0.24199030478631525

# %%
print(test_acc)
# Out:
# 0.247840864768485
