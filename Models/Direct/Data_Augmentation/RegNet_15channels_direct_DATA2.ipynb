# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/dl_project/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("4+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149670.jpg', 'frame_149739.jpg', 'fram...     16
# 1      ('frame_149738.jpg', 'frame_149692.jpg', 'fram...     80
# 2      ('frame_149729.jpg', 'frame_149716.jpg', 'fram...     86
# 3      ('frame_149669.jpg', 'frame_149712.jpg', 'fram...      7
# 4      ('frame_149683.jpg', 'frame_149707.jpg', 'fram...     34
# ...                                                  ...    ...
# 17942  ('frame_180809.jpg', 'frame_174579.jpg', 'fram...    101
# 17943  ('frame_174581.jpg', 'frame_174634.jpg', 'fram...     14
# 17944  ('frame_174605.jpg', 'frame_174596.jpg', 'fram...     54
# 17945  ('frame_181123.jpg', 'frame_174585.jpg', 'fram...     96
# 17946  ('frame_181333.jpg', 'frame_174579.jpg', 'fram...     97
#
# [17947 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, transform=None, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]
        self.transform = transform

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            # img = torchvision.transforms.Normalize(mean=[0.2068, 0.2242, 0.2269], std=[0.2520, 0.2394, 0.2320])(img)
            if self.transform:
                img = self.transform(img)
            images.extend(img)
        x = torch.stack(images)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([15, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
# transform_train = torchvision.transforms.Compose([
#     torchvision.transforms.Normalize(mean=[0.4967, 0.4858, 0.4584, 0.4969, 0.4700, 0.4585, 0.4964, 0.4854, 0.4580, 0.4972, 0.4862, 0.4585, 0.4964, 0.4857, 0.4584],
#                                       std=[0.2681, 0.2574, 0.2433, 0.2678, 0.2500, 0.2429, 0.2679, 0.2572, 0.2428, 0.2680, 0.2573, 0.2428, 0.2680, 0.2574, 0.2431])
# ])

transform_train = torchvision.transforms.Compose([
    torchvision.transforms.ColorJitter(brightness=0, contrast=0.3, saturation=0, hue=0)
])

# %%
batch_size = 128

# training data
train_set = MyDataSet(train_data, transform_train)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %%
# def batch_mean_and_sd(loader, num_channels):
    
#     cnt = 0
#     fst_moment = torch.empty(num_channels)
#     snd_moment = torch.empty(num_channels)

#     for images, _ in tqdm(loader):
#         b, c, h, w = images.shape
#         nb_pixels = b * h * w
#         sum_ = torch.sum(images, dim=[0, 2, 3])
#         sum_of_square = torch.sum(images ** 2,
#                                   dim=[0, 2, 3])
#         fst_moment = (cnt * fst_moment + sum_) / (cnt + nb_pixels)
#         snd_moment = (cnt * snd_moment + sum_of_square) / (cnt + nb_pixels)
#         cnt += nb_pixels

#     mean, std = fst_moment, torch.sqrt(snd_moment - fst_moment ** 2)        
#     return mean,std
  
# num_channels = 15
# mean, std = batch_mean_and_sd(train_loader, num_channels)
# print("mean and std: \n", mean, std)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding,num_classes))


    def forward(self, x):
      out = self.cnn(x)
      out = self.mlp(out)
      return out

# %%
numEpochs = 100
in_features = 15 # TODO: change RGB channels according to num of frames
embedding = 512

learningRate = 0.1
weightDecay = 1e-4

num_classes = 120

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_classes)
#network.load_state_dict(torch.load("model_checkpoints/resnet34/lr_0.1-2/model_2.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_4+1_ours_data2/best_model_" + str(epoch) + ".pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 0	Batch: 50	Avg-Loss: 5.0513	Training Accuracy : 0.0080
# Epoch: 0	Batch: 100	Avg-Loss: 4.6588	Training Accuracy : 0.0158
# Epoch: 0	Batch: 150	Avg-Loss: 4.2157	Training Accuracy : 0.0273
# Epoch: 0	Batch: 200	Avg-Loss: 3.5609	Training Accuracy : 0.0391
# Epoch: 0	Batch: 250	Avg-Loss: 3.4492	Training Accuracy : 0.0431
# Epoch: 0	Batch: 300	Avg-Loss: 3.4040	Training Accuracy : 0.0402
# Epoch: 0	Batch: 350	Avg-Loss: 3.3866	Training Accuracy : 0.0477
# Epoch: 0	Batch: 400	Avg-Loss: 3.3538	Training Accuracy : 0.0483
# Epoch: 0	Batch: 450	Avg-Loss: 3.3661	Training Accuracy : 0.0467
# Epoch: 0	Batch: 500	Avg-Loss: 3.3388	Training Accuracy : 0.0528
# Epoch: 0	Batch: 550	Avg-Loss: 3.3256	Training Accuracy : 0.0516
# Epoch: 0	Batch: 600	Avg-Loss: 3.3192	Training Accuracy : 0.0484
# Epoch: 0	Batch: 650	Avg-Loss: 3.3022	Training Accuracy : 0.0531
# Epoch: 0, Validation Loss: 3.296, Validation Accuracy: 0.056
# Epoch: 1	Batch: 50	Avg-Loss: 3.2953	Training Accuracy : 0.0577
# Epoch: 1	Batch: 100	Avg-Loss: 3.2776	Training Accuracy : 0.0606
# Epoch: 1	Batch: 150	Avg-Loss: 3.2637	Training Accuracy : 0.0541
# Epoch: 1	Batch: 200	Avg-Loss: 3.2689	Training Accuracy : 0.0634
# Epoch: 1	Batch: 250	Avg-Loss: 3.2529	Training Accuracy : 0.0658
# Epoch: 1	Batch: 300	Avg-Loss: 3.2450	Training Accuracy : 0.0619
# Epoch: 1	Batch: 350	Avg-Loss: 3.2220	Training Accuracy : 0.0667
# Epoch: 1	Batch: 400	Avg-Loss: 3.2263	Training Accuracy : 0.0655
# Epoch: 1	Batch: 450	Avg-Loss: 3.2211	Training Accuracy : 0.0684
# Epoch: 1	Batch: 500	Avg-Loss: 3.2107	Training Accuracy : 0.0672
# Epoch: 1	Batch: 550	Avg-Loss: 3.1842	Training Accuracy : 0.0700
# Epoch: 1	Batch: 600	Avg-Loss: 3.1869	Training Accuracy : 0.0728
# Epoch: 1	Batch: 650	Avg-Loss: 3.1764	Training Accuracy : 0.0761
# Epoch: 1, Validation Loss: 3.164, Validation Accuracy: 0.075
# Epoch: 2	Batch: 50	Avg-Loss: 3.1669	Training Accuracy : 0.0778
# Epoch: 2	Batch: 100	Avg-Loss: 3.1512	Training Accuracy : 0.0784
# Epoch: 2	Batch: 150	Avg-Loss: 3.1356	Training Accuracy : 0.0781
# Epoch: 2	Batch: 200	Avg-Loss: 3.1378	Training Accuracy : 0.0794
# Epoch: 2	Batch: 250	Avg-Loss: 3.1380	Training Accuracy : 0.0820
# Epoch: 2	Batch: 300	Avg-Loss: 3.1059	Training Accuracy : 0.0819
# Epoch: 2	Batch: 350	Avg-Loss: 3.1054	Training Accuracy : 0.0833
# Epoch: 2	Batch: 400	Avg-Loss: 3.0999	Training Accuracy : 0.0895
# Epoch: 2	Batch: 450	Avg-Loss: 3.1009	Training Accuracy : 0.0872
# Epoch: 2	Batch: 500	Avg-Loss: 3.0857	Training Accuracy : 0.0908
# Epoch: 2	Batch: 550	Avg-Loss: 3.1010	Training Accuracy : 0.0834
# Epoch: 2	Batch: 600	Avg-Loss: 3.0615	Training Accuracy : 0.0897
# Epoch: 2	Batch: 650	Avg-Loss: 3.0585	Training Accuracy : 0.0902
# Epoch: 2, Validation Loss: 3.030, Validation Accuracy: 0.101
# Epoch: 3	Batch: 50	Avg-Loss: 3.0592	Training Accuracy : 0.0925
# Epoch: 3	Batch: 100	Avg-Loss: 3.0271	Training Accuracy : 0.1070
# Epoch: 3	Batch: 150	Avg-Loss: 3.0000	Training Accuracy : 0.1080
# Epoch: 3	Batch: 200	Avg-Loss: 2.9778	Training Accuracy : 0.1087
# Epoch: 3	Batch: 250	Avg-Loss: 2.9807	Training Accuracy : 0.1064
# Epoch: 3	Batch: 300	Avg-Loss: 2.9661	Training Accuracy : 0.1127
# Epoch: 3	Batch: 350	Avg-Loss: 2.9304	Training Accuracy : 0.1158
# Epoch: 3	Batch: 400	Avg-Loss: 2.9265	Training Accuracy : 0.1253
# Epoch: 3	Batch: 450	Avg-Loss: 2.8877	Training Accuracy : 0.1227
# Epoch: 3	Batch: 500	Avg-Loss: 2.8985	Training Accuracy : 0.1269
# Epoch: 3	Batch: 550	Avg-Loss: 2.8528	Training Accuracy : 0.1359
# Epoch: 3	Batch: 600	Avg-Loss: 2.8282	Training Accuracy : 0.1366
# Epoch: 3	Batch: 650	Avg-Loss: 2.8245	Training Accuracy : 0.1386
# Epoch: 3, Validation Loss: 2.800, Validation Accuracy: 0.143
# Epoch: 4	Batch: 50	Avg-Loss: 2.8311	Training Accuracy : 0.1352
# Epoch: 4	Batch: 100	Avg-Loss: 2.7665	Training Accuracy : 0.1466
# Epoch: 4	Batch: 150	Avg-Loss: 2.7287	Training Accuracy : 0.1553
# Epoch: 4	Batch: 200	Avg-Loss: 2.7410	Training Accuracy : 0.1541
# Epoch: 4	Batch: 250	Avg-Loss: 2.7217	Training Accuracy : 0.1583
# Epoch: 4	Batch: 300	Avg-Loss: 2.7199	Training Accuracy : 0.1533
# Epoch: 4	Batch: 350	Avg-Loss: 2.7465	Training Accuracy : 0.1534
# Epoch: 4	Batch: 400	Avg-Loss: 2.6882	Training Accuracy : 0.1589
# Epoch: 4	Batch: 450	Avg-Loss: 2.6639	Training Accuracy : 0.1655
# Epoch: 4	Batch: 500	Avg-Loss: 2.6769	Training Accuracy : 0.1628
# Epoch: 4	Batch: 550	Avg-Loss: 2.7032	Training Accuracy : 0.1652
# Epoch: 4	Batch: 600	Avg-Loss: 2.6511	Training Accuracy : 0.1675
# Epoch: 4	Batch: 650	Avg-Loss: 2.6947	Training Accuracy : 0.1581
# Epoch: 4, Validation Loss: 2.757, Validation Accuracy: 0.157
# Epoch: 5	Batch: 50	Avg-Loss: 2.6420	Training Accuracy : 0.1736
# Epoch: 5	Batch: 100	Avg-Loss: 2.6141	Training Accuracy : 0.1791
# Epoch: 5	Batch: 150	Avg-Loss: 2.5733	Training Accuracy : 0.1836
# Epoch: 5	Batch: 200	Avg-Loss: 2.5814	Training Accuracy : 0.1803
# Epoch: 5	Batch: 250	Avg-Loss: 2.5723	Training Accuracy : 0.1825
# Epoch: 5	Batch: 300	Avg-Loss: 2.6844	Training Accuracy : 0.1625
# Epoch: 5	Batch: 350	Avg-Loss: 2.6053	Training Accuracy : 0.1820
# Epoch: 5	Batch: 400	Avg-Loss: 2.5974	Training Accuracy : 0.1814
# Epoch: 5	Batch: 450	Avg-Loss: 2.5976	Training Accuracy : 0.1759
# Epoch: 5	Batch: 500	Avg-Loss: 2.6201	Training Accuracy : 0.1659
# Epoch: 5	Batch: 550	Avg-Loss: 2.5785	Training Accuracy : 0.1823
# Epoch: 5	Batch: 600	Avg-Loss: 2.5592	Training Accuracy : 0.1881
# Epoch: 5	Batch: 650	Avg-Loss: 2.5458	Training Accuracy : 0.1905
# Epoch: 5, Validation Loss: 2.630, Validation Accuracy: 0.185
# Epoch: 6	Batch: 50	Avg-Loss: 2.5387	Training Accuracy : 0.1917
# Epoch: 6	Batch: 100	Avg-Loss: 2.5127	Training Accuracy : 0.1966
# Epoch: 6	Batch: 150	Avg-Loss: 2.4990	Training Accuracy : 0.1966
# Epoch: 6	Batch: 200	Avg-Loss: 2.4736	Training Accuracy : 0.2003
# Epoch: 6	Batch: 250	Avg-Loss: 2.5164	Training Accuracy : 0.1992
# Epoch: 6	Batch: 300	Avg-Loss: 2.5020	Training Accuracy : 0.1986
# Epoch: 6	Batch: 350	Avg-Loss: 2.4644	Training Accuracy : 0.2002
# Epoch: 6	Batch: 400	Avg-Loss: 2.4559	Training Accuracy : 0.2002
# Epoch: 6	Batch: 450	Avg-Loss: 2.4758	Training Accuracy : 0.2020
# Epoch: 6	Batch: 500	Avg-Loss: 2.4715	Training Accuracy : 0.2002
# Epoch: 6	Batch: 550	Avg-Loss: 2.5313	Training Accuracy : 0.1927
# Epoch: 6	Batch: 600	Avg-Loss: 2.4868	Training Accuracy : 0.2044
# Epoch: 6	Batch: 650	Avg-Loss: 2.4637	Training Accuracy : 0.2045
# Epoch: 6, Validation Loss: 2.917, Validation Accuracy: 0.160
# Epoch: 7	Batch: 50	Avg-Loss: 2.4285	Training Accuracy : 0.2036
# Epoch: 7	Batch: 100	Avg-Loss: 2.4029	Training Accuracy : 0.2108
# Epoch: 7	Batch: 150	Avg-Loss: 2.4112	Training Accuracy : 0.2180
# Epoch: 7	Batch: 200	Avg-Loss: 2.4072	Training Accuracy : 0.2117
# Epoch: 7	Batch: 250	Avg-Loss: 2.4178	Training Accuracy : 0.2161
# Epoch: 7	Batch: 300	Avg-Loss: 2.3995	Training Accuracy : 0.2230
# Epoch: 7	Batch: 350	Avg-Loss: 2.4341	Training Accuracy : 0.2189
# Epoch: 7	Batch: 400	Avg-Loss: 2.3888	Training Accuracy : 0.2155
# Epoch: 7	Batch: 450	Avg-Loss: 2.3925	Training Accuracy : 0.2148
# Epoch: 7	Batch: 500	Avg-Loss: 2.3989	Training Accuracy : 0.2133
# Epoch: 7	Batch: 550	Avg-Loss: 2.3943	Training Accuracy : 0.2197
# Epoch: 7	Batch: 600	Avg-Loss: 2.3775	Training Accuracy : 0.2080
# Epoch: 7	Batch: 650	Avg-Loss: 2.3920	Training Accuracy : 0.2166
# Epoch: 7, Validation Loss: 2.432, Validation Accuracy: 0.210
# Epoch: 8	Batch: 50	Avg-Loss: 2.3645	Training Accuracy : 0.2127
# Epoch: 8	Batch: 100	Avg-Loss: 2.3776	Training Accuracy : 0.2177
# Epoch: 8	Batch: 150	Avg-Loss: 2.3565	Training Accuracy : 0.2303
# Epoch: 8	Batch: 200	Avg-Loss: 2.3542	Training Accuracy : 0.2180
# Epoch: 8	Batch: 250	Avg-Loss: 2.3448	Training Accuracy : 0.2356
# Epoch: 8	Batch: 300	Avg-Loss: 2.3774	Training Accuracy : 0.2137
# Epoch: 8	Batch: 350	Avg-Loss: 2.3468	Training Accuracy : 0.2275
# Epoch: 8	Batch: 400	Avg-Loss: 2.3874	Training Accuracy : 0.2195
# Epoch: 8	Batch: 450	Avg-Loss: 2.4008	Training Accuracy : 0.2181
# Epoch: 8	Batch: 500	Avg-Loss: 2.3455	Training Accuracy : 0.2297
# Epoch: 8	Batch: 550	Avg-Loss: 2.3631	Training Accuracy : 0.2206
# Epoch: 8	Batch: 600	Avg-Loss: 2.3995	Training Accuracy : 0.2150
# Epoch: 8	Batch: 650	Avg-Loss: 2.3613	Training Accuracy : 0.2172
# Epoch: 8, Validation Loss: 2.374, Validation Accuracy: 0.224
# Epoch: 9	Batch: 50	Avg-Loss: 2.2969	Training Accuracy : 0.2297
# Epoch: 9	Batch: 100	Avg-Loss: 2.2958	Training Accuracy : 0.2305
# Epoch: 9	Batch: 150	Avg-Loss: 2.3000	Training Accuracy : 0.2316
# Epoch: 9	Batch: 200	Avg-Loss: 2.3394	Training Accuracy : 0.2261
# Epoch: 9	Batch: 250	Avg-Loss: 2.2850	Training Accuracy : 0.2369
# Epoch: 9	Batch: 300	Avg-Loss: 2.3357	Training Accuracy : 0.2206
# Epoch: 9	Batch: 350	Avg-Loss: 2.3136	Training Accuracy : 0.2420
# Epoch: 9	Batch: 400	Avg-Loss: 2.3151	Training Accuracy : 0.2286
# Epoch: 9	Batch: 450	Avg-Loss: 2.3181	Training Accuracy : 0.2367
# Epoch: 9	Batch: 500	Avg-Loss: 2.3120	Training Accuracy : 0.2391
# Epoch: 9	Batch: 550	Avg-Loss: 2.3035	Training Accuracy : 0.2347
# Epoch: 9	Batch: 600	Avg-Loss: 2.2823	Training Accuracy : 0.2383
# Epoch: 9	Batch: 650	Avg-Loss: 2.3406	Training Accuracy : 0.2177
# Epoch: 9, Validation Loss: 2.412, Validation Accuracy: 0.220
# Epoch: 10	Batch: 50	Avg-Loss: 2.2344	Training Accuracy : 0.2398
# Epoch: 10	Batch: 100	Avg-Loss: 2.2401	Training Accuracy : 0.2497
# Epoch: 10	Batch: 150	Avg-Loss: 2.2907	Training Accuracy : 0.2362
# Epoch: 10	Batch: 200	Avg-Loss: 2.2668	Training Accuracy : 0.2428
# Epoch: 10	Batch: 250	Avg-Loss: 2.2519	Training Accuracy : 0.2433
# Epoch: 10	Batch: 300	Avg-Loss: 2.2552	Training Accuracy : 0.2494
# Epoch: 10	Batch: 350	Avg-Loss: 2.2608	Training Accuracy : 0.2409
# Epoch: 10	Batch: 400	Avg-Loss: 2.2665	Training Accuracy : 0.2455
# Epoch: 10	Batch: 450	Avg-Loss: 2.2511	Training Accuracy : 0.2448
# Epoch: 10	Batch: 500	Avg-Loss: 2.2576	Training Accuracy : 0.2422
# Epoch: 10	Batch: 550	Avg-Loss: 2.2443	Training Accuracy : 0.2338
# Epoch: 10	Batch: 600	Avg-Loss: 2.2233	Training Accuracy : 0.2492
# Epoch: 10	Batch: 650	Avg-Loss: 2.2381	Training Accuracy : 0.2484
# Epoch: 10, Validation Loss: 2.398, Validation Accuracy: 0.225
# Epoch: 11	Batch: 50	Avg-Loss: 2.1988	Training Accuracy : 0.2431
# Epoch: 11	Batch: 100	Avg-Loss: 2.2315	Training Accuracy : 0.2417
# Epoch: 11	Batch: 150	Avg-Loss: 2.2079	Training Accuracy : 0.2498
# Epoch: 11	Batch: 200	Avg-Loss: 2.1936	Training Accuracy : 0.2472
# Epoch: 11	Batch: 250	Avg-Loss: 2.2087	Training Accuracy : 0.2575
# Epoch: 11	Batch: 300	Avg-Loss: 2.1802	Training Accuracy : 0.2519
# Epoch: 11	Batch: 350	Avg-Loss: 2.2365	Training Accuracy : 0.2456
# Epoch: 11	Batch: 400	Avg-Loss: 2.1872	Training Accuracy : 0.2512
# Epoch: 11	Batch: 450	Avg-Loss: 2.2186	Training Accuracy : 0.2456
# Epoch: 11	Batch: 500	Avg-Loss: 2.1962	Training Accuracy : 0.2483
# Epoch: 11	Batch: 550	Avg-Loss: 2.1834	Training Accuracy : 0.2519
# Epoch: 11	Batch: 600	Avg-Loss: 2.1955	Training Accuracy : 0.2505
# Epoch: 11	Batch: 650	Avg-Loss: 2.1719	Training Accuracy : 0.2464
# Epoch    12: reducing learning rate of group 0 to 5.0000e-02.
# Epoch: 11, Validation Loss: 2.519, Validation Accuracy: 0.219
# Epoch: 12	Batch: 50	Avg-Loss: 2.0584	Training Accuracy : 0.2670
# Epoch: 12	Batch: 100	Avg-Loss: 2.0122	Training Accuracy : 0.2856
# Epoch: 12	Batch: 150	Avg-Loss: 1.9638	Training Accuracy : 0.2897
# Epoch: 12	Batch: 200	Avg-Loss: 1.9789	Training Accuracy : 0.2855
# Epoch: 12	Batch: 250	Avg-Loss: 1.9730	Training Accuracy : 0.2806
# Epoch: 12	Batch: 300	Avg-Loss: 1.9646	Training Accuracy : 0.2930
# Epoch: 12	Batch: 350	Avg-Loss: 1.9576	Training Accuracy : 0.3020
# Epoch: 12	Batch: 400	Avg-Loss: 1.9461	Training Accuracy : 0.2827
# Epoch: 12	Batch: 450	Avg-Loss: 1.9688	Training Accuracy : 0.2930
# Epoch: 12	Batch: 500	Avg-Loss: 1.9534	Training Accuracy : 0.2941
# Epoch: 12	Batch: 550	Avg-Loss: 1.9780	Training Accuracy : 0.2825
# Epoch: 12	Batch: 600	Avg-Loss: 1.9569	Training Accuracy : 0.2902
# Epoch: 12	Batch: 650	Avg-Loss: 1.9527	Training Accuracy : 0.2905
# Epoch: 12, Validation Loss: 2.478, Validation Accuracy: 0.235
# Epoch: 13	Batch: 50	Avg-Loss: 1.8287	Training Accuracy : 0.3187
# Epoch: 13	Batch: 100	Avg-Loss: 1.8615	Training Accuracy : 0.3077
# Epoch: 13	Batch: 150	Avg-Loss: 1.9121	Training Accuracy : 0.3019
# Epoch: 13	Batch: 200	Avg-Loss: 1.8683	Training Accuracy : 0.3139
# Epoch: 13	Batch: 250	Avg-Loss: 1.8789	Training Accuracy : 0.3028
# Epoch: 13	Batch: 300	Avg-Loss: 1.8598	Training Accuracy : 0.3111
# Epoch: 13	Batch: 350	Avg-Loss: 1.8712	Training Accuracy : 0.3114
# Epoch: 13	Batch: 400	Avg-Loss: 1.8531	Training Accuracy : 0.3100
# Epoch: 13	Batch: 450	Avg-Loss: 1.8410	Training Accuracy : 0.3131
# Epoch: 13	Batch: 500	Avg-Loss: 1.8839	Training Accuracy : 0.3036
# Epoch: 13	Batch: 550	Avg-Loss: 1.8648	Training Accuracy : 0.3103
# Epoch: 13	Batch: 600	Avg-Loss: 1.8414	Training Accuracy : 0.3212
# Epoch: 13	Batch: 650	Avg-Loss: 1.8531	Training Accuracy : 0.3125
# Epoch: 13, Validation Loss: 2.621, Validation Accuracy: 0.234
# Epoch: 14	Batch: 50	Avg-Loss: 1.7364	Training Accuracy : 0.3425
# Epoch: 14	Batch: 100	Avg-Loss: 1.7523	Training Accuracy : 0.3419
# Epoch: 14	Batch: 150	Avg-Loss: 1.7364	Training Accuracy : 0.3406
# Epoch: 14	Batch: 200	Avg-Loss: 1.7491	Training Accuracy : 0.3375
# Epoch: 14	Batch: 250	Avg-Loss: 1.7879	Training Accuracy : 0.3331
# Epoch: 14	Batch: 300	Avg-Loss: 1.7734	Training Accuracy : 0.3312
# Epoch: 14	Batch: 350	Avg-Loss: 1.7584	Training Accuracy : 0.3319
# Epoch: 14	Batch: 400	Avg-Loss: 1.7576	Training Accuracy : 0.3309
# Epoch: 14	Batch: 450	Avg-Loss: 1.7573	Training Accuracy : 0.3403
# Epoch: 14	Batch: 500	Avg-Loss: 1.7152	Training Accuracy : 0.3620
# Epoch: 14	Batch: 550	Avg-Loss: 1.7511	Training Accuracy : 0.3477
# Epoch: 14	Batch: 600	Avg-Loss: 1.7440	Training Accuracy : 0.3467
# Epoch: 14	Batch: 650	Avg-Loss: 1.7478	Training Accuracy : 0.3517
# Epoch    15: reducing learning rate of group 0 to 2.5000e-02.
# Epoch: 14, Validation Loss: 2.821, Validation Accuracy: 0.231
# Epoch: 15	Batch: 50	Avg-Loss: 1.5503	Training Accuracy : 0.4097
# Epoch: 15	Batch: 100	Avg-Loss: 1.4845	Training Accuracy : 0.4194
# Epoch: 15	Batch: 150	Avg-Loss: 1.4891	Training Accuracy : 0.4227
# Epoch: 15	Batch: 200	Avg-Loss: 1.4927	Training Accuracy : 0.4400
# Epoch: 15	Batch: 250	Avg-Loss: 1.4497	Training Accuracy : 0.4427
# Epoch: 15	Batch: 300	Avg-Loss: 1.4700	Training Accuracy : 0.4403
# Epoch: 15	Batch: 350	Avg-Loss: 1.4612	Training Accuracy : 0.4462
# Epoch: 15	Batch: 400	Avg-Loss: 1.4772	Training Accuracy : 0.4494
# Epoch: 15	Batch: 450	Avg-Loss: 1.4666	Training Accuracy : 0.4523
# Epoch: 15	Batch: 500	Avg-Loss: 1.4631	Training Accuracy : 0.4525
# Epoch: 15	Batch: 550	Avg-Loss: 1.4335	Training Accuracy : 0.4639
# Epoch: 15	Batch: 600	Avg-Loss: 1.4496	Training Accuracy : 0.4702
# Epoch: 15	Batch: 650	Avg-Loss: 1.4432	Training Accuracy : 0.4708
# Epoch: 15, Validation Loss: 2.965, Validation Accuracy: 0.238
# Epoch: 16	Batch: 50	Avg-Loss: 1.3012	Training Accuracy : 0.5209
# Epoch: 16	Batch: 100	Avg-Loss: 1.2864	Training Accuracy : 0.5267
# Epoch: 16	Batch: 150	Avg-Loss: 1.3036	Training Accuracy : 0.5256
# Epoch: 16	Batch: 200	Avg-Loss: 1.3208	Training Accuracy : 0.5331
# Epoch: 16	Batch: 250	Avg-Loss: 1.3417	Training Accuracy : 0.5261
# Epoch: 16	Batch: 300	Avg-Loss: 1.3116	Training Accuracy : 0.5277
# Epoch: 16	Batch: 350	Avg-Loss: 1.3578	Training Accuracy : 0.5192
# Epoch: 16	Batch: 400	Avg-Loss: 1.3149	Training Accuracy : 0.5345
# Epoch: 16	Batch: 450	Avg-Loss: 1.3126	Training Accuracy : 0.5364
# Epoch: 16	Batch: 500	Avg-Loss: 1.2849	Training Accuracy : 0.5408
# Epoch: 16	Batch: 550	Avg-Loss: 1.3337	Training Accuracy : 0.5487
# Epoch: 16	Batch: 600	Avg-Loss: 1.3372	Training Accuracy : 0.5450
# Epoch: 16	Batch: 650	Avg-Loss: 1.2854	Training Accuracy : 0.5569
# Epoch: 16, Validation Loss: 3.289, Validation Accuracy: 0.229
# Epoch: 17	Batch: 50	Avg-Loss: 1.1715	Training Accuracy : 0.6041
# Epoch: 17	Batch: 100	Avg-Loss: 1.1610	Training Accuracy : 0.5981
# Epoch: 17	Batch: 150	Avg-Loss: 1.1425	Training Accuracy : 0.6073
# Epoch: 17	Batch: 200	Avg-Loss: 1.1394	Training Accuracy : 0.6116
# Epoch: 17	Batch: 250	Avg-Loss: 1.1189	Training Accuracy : 0.6216
# Epoch: 17	Batch: 300	Avg-Loss: 1.1748	Training Accuracy : 0.6080
# Epoch: 17	Batch: 350	Avg-Loss: 1.1245	Training Accuracy : 0.6205
# Epoch: 17	Batch: 400	Avg-Loss: 1.1583	Training Accuracy : 0.6078
# Epoch: 17	Batch: 450	Avg-Loss: 1.1538	Training Accuracy : 0.6106
# Epoch: 17	Batch: 500	Avg-Loss: 1.1503	Training Accuracy : 0.6095
# Epoch: 17	Batch: 550	Avg-Loss: 1.1597	Training Accuracy : 0.6092
# Epoch: 17	Batch: 600	Avg-Loss: 1.1212	Training Accuracy : 0.6334
# Epoch: 17	Batch: 650	Avg-Loss: 1.1050	Training Accuracy : 0.6334
# Epoch    18: reducing learning rate of group 0 to 1.2500e-02.
# Epoch: 17, Validation Loss: 3.634, Validation Accuracy: 0.227
# Epoch: 18	Batch: 50	Avg-Loss: 0.9088	Training Accuracy : 0.6995
# Epoch: 18	Batch: 100	Avg-Loss: 0.8215	Training Accuracy : 0.7261
# Epoch: 18	Batch: 150	Avg-Loss: 0.8055	Training Accuracy : 0.7320
# Epoch: 18	Batch: 200	Avg-Loss: 0.8019	Training Accuracy : 0.7391
# Epoch: 18	Batch: 250	Avg-Loss: 0.7989	Training Accuracy : 0.7316
# Epoch: 18	Batch: 300	Avg-Loss: 0.7720	Training Accuracy : 0.7450
# Epoch: 18	Batch: 350	Avg-Loss: 0.7520	Training Accuracy : 0.7516
# Epoch: 18	Batch: 400	Avg-Loss: 0.7863	Training Accuracy : 0.7389
# Epoch: 18	Batch: 450	Avg-Loss: 0.7940	Training Accuracy : 0.7355
# Epoch: 18	Batch: 500	Avg-Loss: 0.7737	Training Accuracy : 0.7441
# Epoch: 18	Batch: 550	Avg-Loss: 0.7713	Training Accuracy : 0.7395
# Epoch: 18	Batch: 600	Avg-Loss: 0.7668	Training Accuracy : 0.7428
# Epoch: 18	Batch: 650	Avg-Loss: 0.7885	Training Accuracy : 0.7330
# Epoch: 18, Validation Loss: 3.957, Validation Accuracy: 0.237
# Epoch: 19	Batch: 50	Avg-Loss: 0.6566	Training Accuracy : 0.7814
# Epoch: 19	Batch: 100	Avg-Loss: 0.6473	Training Accuracy : 0.7837
# Epoch: 19	Batch: 150	Avg-Loss: 0.6409	Training Accuracy : 0.7828
# Epoch: 19	Batch: 200	Avg-Loss: 0.6599	Training Accuracy : 0.7806
# Epoch: 19	Batch: 250	Avg-Loss: 0.6588	Training Accuracy : 0.7791
# Epoch: 19	Batch: 300	Avg-Loss: 0.6944	Training Accuracy : 0.7717
# Epoch: 19	Batch: 350	Avg-Loss: 0.6781	Training Accuracy : 0.7728
# Epoch: 19	Batch: 400	Avg-Loss: 0.6388	Training Accuracy : 0.7859
# Epoch: 19	Batch: 450	Avg-Loss: 0.6653	Training Accuracy : 0.7792
# Epoch: 19	Batch: 500	Avg-Loss: 0.6746	Training Accuracy : 0.7700
# Epoch: 19	Batch: 550	Avg-Loss: 0.6961	Training Accuracy : 0.7659
# Epoch: 19	Batch: 600	Avg-Loss: 0.6926	Training Accuracy : 0.7639
# Epoch: 19	Batch: 650	Avg-Loss: 0.7010	Training Accuracy : 0.7658
# Epoch: 19, Validation Loss: 4.336, Validation Accuracy: 0.245
# Epoch: 20	Batch: 50	Avg-Loss: 0.6017	Training Accuracy : 0.8006
# Epoch: 20	Batch: 100	Avg-Loss: 0.5952	Training Accuracy : 0.7967
# Epoch: 20	Batch: 150	Avg-Loss: 0.5906	Training Accuracy : 0.8027
# Epoch: 20	Batch: 200	Avg-Loss: 0.5992	Training Accuracy : 0.7966
# Epoch: 20	Batch: 250	Avg-Loss: 0.5813	Training Accuracy : 0.8087
# Epoch: 20	Batch: 300	Avg-Loss: 0.6011	Training Accuracy : 0.7966
# Epoch: 20	Batch: 350	Avg-Loss: 0.6000	Training Accuracy : 0.7906
# Epoch: 20	Batch: 400	Avg-Loss: 0.6120	Training Accuracy : 0.7881
# Epoch: 20	Batch: 450	Avg-Loss: 0.6054	Training Accuracy : 0.7947
# Epoch: 20	Batch: 500	Avg-Loss: 0.6049	Training Accuracy : 0.7923
# Epoch: 20	Batch: 550	Avg-Loss: 0.6307	Training Accuracy : 0.7822
# Epoch: 20	Batch: 600	Avg-Loss: 0.6477	Training Accuracy : 0.7814
# Epoch: 20	Batch: 650	Avg-Loss: 0.6343	Training Accuracy : 0.7855
# Epoch    21: reducing learning rate of group 0 to 6.2500e-03.
# Epoch: 20, Validation Loss: 4.561, Validation Accuracy: 0.234
# Epoch: 21	Batch: 50	Avg-Loss: 0.4982	Training Accuracy : 0.8345
# Epoch: 21	Batch: 100	Avg-Loss: 0.5154	Training Accuracy : 0.8358
# Epoch: 21	Batch: 150	Avg-Loss: 0.4412	Training Accuracy : 0.8556
# Epoch: 21	Batch: 200	Avg-Loss: 0.4620	Training Accuracy : 0.8488
# Epoch: 21	Batch: 250	Avg-Loss: 0.4584	Training Accuracy : 0.8472
# Epoch: 21	Batch: 300	Avg-Loss: 0.4545	Training Accuracy : 0.8505
# Epoch: 21	Batch: 350	Avg-Loss: 0.4497	Training Accuracy : 0.8514
# Epoch: 21	Batch: 400	Avg-Loss: 0.4532	Training Accuracy : 0.8527
# Epoch: 21	Batch: 450	Avg-Loss: 0.4499	Training Accuracy : 0.8495
# Epoch: 21	Batch: 500	Avg-Loss: 0.4555	Training Accuracy : 0.8506
# Epoch: 21	Batch: 550	Avg-Loss: 0.4548	Training Accuracy : 0.8478
# Epoch: 21	Batch: 600	Avg-Loss: 0.4501	Training Accuracy : 0.8517
# Epoch: 21	Batch: 650	Avg-Loss: 0.4517	Training Accuracy : 0.8541
# Epoch: 21, Validation Loss: 4.972, Validation Accuracy: 0.233
# Epoch: 22	Batch: 50	Avg-Loss: 0.4010	Training Accuracy : 0.8712
# Epoch: 22	Batch: 100	Avg-Loss: 0.3877	Training Accuracy : 0.8762
# Epoch: 22	Batch: 150	Avg-Loss: 0.3886	Training Accuracy : 0.8736
# Epoch: 22	Batch: 200	Avg-Loss: 0.3834	Training Accuracy : 0.8795
# Epoch: 22	Batch: 250	Avg-Loss: 0.3856	Training Accuracy : 0.8750
# Epoch: 22	Batch: 300	Avg-Loss: 0.3861	Training Accuracy : 0.8712
# Epoch: 22	Batch: 350	Avg-Loss: 0.3685	Training Accuracy : 0.8766
# Epoch: 22	Batch: 400	Avg-Loss: 0.3926	Training Accuracy : 0.8719
# Epoch: 22	Batch: 450	Avg-Loss: 0.4027	Training Accuracy : 0.8723
# Epoch: 22	Batch: 500	Avg-Loss: 0.3973	Training Accuracy : 0.8741
# Epoch: 22	Batch: 550	Avg-Loss: 0.3963	Training Accuracy : 0.8700
# Epoch: 22	Batch: 600	Avg-Loss: 0.4030	Training Accuracy : 0.8683
# Epoch: 22	Batch: 650	Avg-Loss: 0.3819	Training Accuracy : 0.8764
# Epoch: 22, Validation Loss: 5.023, Validation Accuracy: 0.238
# Epoch: 23	Batch: 50	Avg-Loss: 0.3607	Training Accuracy : 0.8867
# Epoch: 23	Batch: 100	Avg-Loss: 0.3408	Training Accuracy : 0.8933
# Epoch: 23	Batch: 150	Avg-Loss: 0.3613	Training Accuracy : 0.8859
# Epoch: 23	Batch: 200	Avg-Loss: 0.3601	Training Accuracy : 0.8862
# Epoch: 23	Batch: 250	Avg-Loss: 0.3207	Training Accuracy : 0.8966
# Epoch: 23	Batch: 300	Avg-Loss: 0.3565	Training Accuracy : 0.8839
# Epoch: 23	Batch: 350	Avg-Loss: 0.3575	Training Accuracy : 0.8836
# Epoch: 23	Batch: 400	Avg-Loss: 0.3454	Training Accuracy : 0.8875
# Epoch: 23	Batch: 450	Avg-Loss: 0.3567	Training Accuracy : 0.8856
# Epoch: 23	Batch: 500	Avg-Loss: 0.3715	Training Accuracy : 0.8827
# Epoch: 23	Batch: 550	Avg-Loss: 0.3745	Training Accuracy : 0.8730
# Epoch: 23	Batch: 600	Avg-Loss: 0.3507	Training Accuracy : 0.8848
# Epoch: 23	Batch: 650	Avg-Loss: 0.3698	Training Accuracy : 0.8812
# Epoch    24: reducing learning rate of group 0 to 3.1250e-03.
# Epoch: 23, Validation Loss: 5.220, Validation Accuracy: 0.242
# Epoch: 24	Batch: 50	Avg-Loss: 0.3193	Training Accuracy : 0.8984
# Epoch: 24	Batch: 100	Avg-Loss: 0.2979	Training Accuracy : 0.9098
# Epoch: 24	Batch: 150	Avg-Loss: 0.3062	Training Accuracy : 0.9036
# Epoch: 24	Batch: 200	Avg-Loss: 0.2965	Training Accuracy : 0.9097
# Epoch: 24	Batch: 250	Avg-Loss: 0.2768	Training Accuracy : 0.9144
# Epoch: 24	Batch: 300	Avg-Loss: 0.2876	Training Accuracy : 0.9117
# Epoch: 24	Batch: 350	Avg-Loss: 0.2816	Training Accuracy : 0.9178
# Epoch: 24	Batch: 400	Avg-Loss: 0.3112	Training Accuracy : 0.9055
# Epoch: 24	Batch: 450	Avg-Loss: 0.3013	Training Accuracy : 0.9066
# Epoch: 24	Batch: 500	Avg-Loss: 0.3017	Training Accuracy : 0.9052
# Epoch: 24	Batch: 550	Avg-Loss: 0.2968	Training Accuracy : 0.9069
# Epoch: 24	Batch: 600	Avg-Loss: 0.2977	Training Accuracy : 0.9087
# Epoch: 24	Batch: 650	Avg-Loss: 0.3142	Training Accuracy : 0.8991
# Epoch: 24, Validation Loss: 5.287, Validation Accuracy: 0.239
# Epoch: 25	Batch: 50	Avg-Loss: 0.2721	Training Accuracy : 0.9208
# Epoch: 25	Batch: 100	Avg-Loss: 0.2657	Training Accuracy : 0.9205
# Epoch: 25	Batch: 150	Avg-Loss: 0.2701	Training Accuracy : 0.9172
# Epoch: 25	Batch: 200	Avg-Loss: 0.2698	Training Accuracy : 0.9170
# Epoch: 25	Batch: 250	Avg-Loss: 0.2578	Training Accuracy : 0.9245
# Epoch: 25	Batch: 300	Avg-Loss: 0.2664	Training Accuracy : 0.9161
# Epoch: 25	Batch: 350	Avg-Loss: 0.2650	Training Accuracy : 0.9223
# Epoch: 25	Batch: 400	Avg-Loss: 0.2572	Training Accuracy : 0.9198
# Epoch: 25	Batch: 450	Avg-Loss: 0.2798	Training Accuracy : 0.9111
# Epoch: 25	Batch: 500	Avg-Loss: 0.2806	Training Accuracy : 0.9147
# Epoch: 25	Batch: 550	Avg-Loss: 0.2782	Training Accuracy : 0.9125
# Epoch: 25	Batch: 600	Avg-Loss: 0.2716	Training Accuracy : 0.9167
# Epoch: 25	Batch: 650	Avg-Loss: 0.2772	Training Accuracy : 0.9116
# Epoch: 25, Validation Loss: 5.364, Validation Accuracy: 0.233
# Epoch: 26	Batch: 50	Avg-Loss: 0.2542	Training Accuracy : 0.9248
# Epoch: 26	Batch: 100	Avg-Loss: 0.2436	Training Accuracy : 0.9287
# Epoch: 26	Batch: 150	Avg-Loss: 0.2615	Training Accuracy : 0.9191
# Epoch: 26	Batch: 200	Avg-Loss: 0.2644	Training Accuracy : 0.9227
# Epoch: 26	Batch: 250	Avg-Loss: 0.2438	Training Accuracy : 0.9295
# Epoch: 26	Batch: 300	Avg-Loss: 0.2599	Training Accuracy : 0.9213
# Epoch: 26	Batch: 350	Avg-Loss: 0.2547	Training Accuracy : 0.9250
# Epoch: 26	Batch: 400	Avg-Loss: 0.2703	Training Accuracy : 0.9175
# Epoch: 26	Batch: 450	Avg-Loss: 0.2590	Training Accuracy : 0.9206
# Epoch: 26	Batch: 500	Avg-Loss: 0.2634	Training Accuracy : 0.9213
# Epoch: 26	Batch: 550	Avg-Loss: 0.2591	Training Accuracy : 0.9223
# Epoch: 26	Batch: 600	Avg-Loss: 0.2718	Training Accuracy : 0.9200
# Epoch: 26	Batch: 650	Avg-Loss: 0.2601	Training Accuracy : 0.9219
# Epoch    27: reducing learning rate of group 0 to 1.5625e-03.
# Epoch: 26, Validation Loss: 5.565, Validation Accuracy: 0.237
# Epoch: 27	Batch: 50	Avg-Loss: 0.2377	Training Accuracy : 0.9311
# Epoch: 27	Batch: 100	Avg-Loss: 0.2293	Training Accuracy : 0.9342
# Epoch: 27	Batch: 150	Avg-Loss: 0.2339	Training Accuracy : 0.9305
# Epoch: 27	Batch: 200	Avg-Loss: 0.2156	Training Accuracy : 0.9395
# Epoch: 27	Batch: 250	Avg-Loss: 0.2304	Training Accuracy : 0.9333
# Epoch: 27	Batch: 300	Avg-Loss: 0.2307	Training Accuracy : 0.9325
# Epoch: 27	Batch: 350	Avg-Loss: 0.2261	Training Accuracy : 0.9341
# Epoch: 27	Batch: 400	Avg-Loss: 0.2429	Training Accuracy : 0.9269
# Epoch: 27	Batch: 450	Avg-Loss: 0.2309	Training Accuracy : 0.9327
# Epoch: 27	Batch: 500	Avg-Loss: 0.2226	Training Accuracy : 0.9334
# Epoch: 27	Batch: 550	Avg-Loss: 0.2233	Training Accuracy : 0.9344
# Epoch: 27	Batch: 600	Avg-Loss: 0.2392	Training Accuracy : 0.9280
# Epoch: 27	Batch: 650	Avg-Loss: 0.2365	Training Accuracy : 0.9330
# Epoch: 27, Validation Loss: 5.646, Validation Accuracy: 0.238
# Epoch: 28	Batch: 50	Avg-Loss: 0.2250	Training Accuracy : 0.9320
# Epoch: 28	Batch: 100	Avg-Loss: 0.2161	Training Accuracy : 0.9389
# Epoch: 28	Batch: 150	Avg-Loss: 0.2159	Training Accuracy : 0.9397
# Epoch: 28	Batch: 200	Avg-Loss: 0.2302	Training Accuracy : 0.9322
# Epoch: 28	Batch: 250	Avg-Loss: 0.2133	Training Accuracy : 0.9364
# Epoch: 28	Batch: 300	Avg-Loss: 0.2053	Training Accuracy : 0.9392
# Epoch: 28	Batch: 350	Avg-Loss: 0.2111	Training Accuracy : 0.9392
# Epoch: 28	Batch: 400	Avg-Loss: 0.2185	Training Accuracy : 0.9350
# Epoch: 28	Batch: 450	Avg-Loss: 0.2339	Training Accuracy : 0.9328
# Epoch: 28	Batch: 500	Avg-Loss: 0.2257	Training Accuracy : 0.9337
# Epoch: 28	Batch: 550	Avg-Loss: 0.2193	Training Accuracy : 0.9364
# Epoch: 28	Batch: 600	Avg-Loss: 0.2395	Training Accuracy : 0.9287
# Epoch: 28	Batch: 650	Avg-Loss: 0.2289	Training Accuracy : 0.9325
# Epoch: 28, Validation Loss: 6.015, Validation Accuracy: 0.234
# Epoch: 29	Batch: 50	Avg-Loss: 0.2103	Training Accuracy : 0.9370
# Epoch: 29	Batch: 100	Avg-Loss: 0.2201	Training Accuracy : 0.9337
# Epoch: 29	Batch: 150	Avg-Loss: 0.2142	Training Accuracy : 0.9402
# Epoch: 29	Batch: 200	Avg-Loss: 0.2206	Training Accuracy : 0.9370
# Epoch: 29	Batch: 250	Avg-Loss: 0.2106	Training Accuracy : 0.9397
# Epoch: 29	Batch: 300	Avg-Loss: 0.2043	Training Accuracy : 0.9408
# Epoch: 29	Batch: 350	Avg-Loss: 0.2199	Training Accuracy : 0.9355
# Epoch: 29	Batch: 400	Avg-Loss: 0.2132	Training Accuracy : 0.9384
# Epoch: 29	Batch: 450	Avg-Loss: 0.2233	Training Accuracy : 0.9342
# Epoch: 29	Batch: 500	Avg-Loss: 0.2098	Training Accuracy : 0.9395
# Epoch: 29	Batch: 550	Avg-Loss: 0.2132	Training Accuracy : 0.9366
# Epoch: 29	Batch: 600	Avg-Loss: 0.2243	Training Accuracy : 0.9341
# Epoch: 29	Batch: 650	Avg-Loss: 0.1989	Training Accuracy : 0.9406
# Epoch    30: reducing learning rate of group 0 to 7.8125e-04.
# Epoch: 29, Validation Loss: 5.728, Validation Accuracy: 0.235
# Epoch: 30	Batch: 50	Avg-Loss: 0.2027	Training Accuracy : 0.9381
# Epoch: 30	Batch: 100	Avg-Loss: 0.2027	Training Accuracy : 0.9416
# Epoch: 30	Batch: 150	Avg-Loss: 0.1967	Training Accuracy : 0.9439
# Epoch: 30	Batch: 200	Avg-Loss: 0.1938	Training Accuracy : 0.9453
# Epoch: 30	Batch: 250	Avg-Loss: 0.2030	Training Accuracy : 0.9428
# Epoch: 30	Batch: 300	Avg-Loss: 0.1934	Training Accuracy : 0.9441
# Epoch: 30	Batch: 350	Avg-Loss: 0.1910	Training Accuracy : 0.9458
# Epoch: 30	Batch: 400	Avg-Loss: 0.2067	Training Accuracy : 0.9411
# Epoch: 30	Batch: 450	Avg-Loss: 0.2094	Training Accuracy : 0.9405
# Epoch: 30	Batch: 500	Avg-Loss: 0.2012	Training Accuracy : 0.9422
# Epoch: 30	Batch: 550	Avg-Loss: 0.1986	Training Accuracy : 0.9431
# Epoch: 30	Batch: 600	Avg-Loss: 0.2041	Training Accuracy : 0.9391
# Epoch: 30	Batch: 650	Avg-Loss: 0.2058	Training Accuracy : 0.9408
# Epoch: 30, Validation Loss: 6.207, Validation Accuracy: 0.234
# Epoch: 31	Batch: 50	Avg-Loss: 0.1840	Training Accuracy : 0.9475
# Epoch: 31	Batch: 100	Avg-Loss: 0.1775	Training Accuracy : 0.9502
# Epoch: 31	Batch: 150	Avg-Loss: 0.1871	Training Accuracy : 0.9477
# Epoch: 31	Batch: 200	Avg-Loss: 0.1989	Training Accuracy : 0.9433
# Epoch: 31	Batch: 250	Avg-Loss: 0.1959	Training Accuracy : 0.9461
# Epoch: 31	Batch: 300	Avg-Loss: 0.1920	Training Accuracy : 0.9428
# Epoch: 31	Batch: 350	Avg-Loss: 0.1870	Training Accuracy : 0.9464
# Epoch: 31	Batch: 400	Avg-Loss: 0.2051	Training Accuracy : 0.9411
# Epoch: 31	Batch: 450	Avg-Loss: 0.2002	Training Accuracy : 0.9413
# Epoch: 31	Batch: 500	Avg-Loss: 0.2100	Training Accuracy : 0.9372
# Epoch: 31	Batch: 550	Avg-Loss: 0.2111	Training Accuracy : 0.9416
# Epoch: 31	Batch: 600	Avg-Loss: 0.1928	Training Accuracy : 0.9458
# Epoch: 31	Batch: 650	Avg-Loss: 0.2004	Training Accuracy : 0.9430
# Epoch: 31, Validation Loss: 6.108, Validation Accuracy: 0.233
# Epoch: 32	Batch: 50	Avg-Loss: 0.1779	Training Accuracy : 0.9502
# Epoch: 32	Batch: 100	Avg-Loss: 0.1820	Training Accuracy : 0.9494
# Epoch: 32	Batch: 150	Avg-Loss: 0.1931	Training Accuracy : 0.9463
# Epoch: 32	Batch: 200	Avg-Loss: 0.1929	Training Accuracy : 0.9452
# Epoch: 32	Batch: 250	Avg-Loss: 0.1769	Training Accuracy : 0.9489
# Epoch: 32	Batch: 300	Avg-Loss: 0.2013	Training Accuracy : 0.9458
# Epoch: 32	Batch: 350	Avg-Loss: 0.1825	Training Accuracy : 0.9475
# Epoch: 32	Batch: 400	Avg-Loss: 0.1874	Training Accuracy : 0.9458
# Epoch: 32	Batch: 450	Avg-Loss: 0.1949	Training Accuracy : 0.9448
# Epoch: 32	Batch: 500	Avg-Loss: 0.1949	Training Accuracy : 0.9458
# Epoch: 32	Batch: 550	Avg-Loss: 0.1975	Training Accuracy : 0.9433
# Epoch: 32	Batch: 600	Avg-Loss: 0.1940	Training Accuracy : 0.9441
# Epoch: 32	Batch: 650	Avg-Loss: 0.1994	Training Accuracy : 0.9441
# Epoch    33: reducing learning rate of group 0 to 3.9063e-04.
# Epoch: 32, Validation Loss: 6.275, Validation Accuracy: 0.233
# Epoch: 33	Batch: 50	Avg-Loss: 0.1830	Training Accuracy : 0.9484
# Epoch: 33	Batch: 100	Avg-Loss: 0.1629	Training Accuracy : 0.9544
# Epoch: 33	Batch: 150	Avg-Loss: 0.1875	Training Accuracy : 0.9478
# Epoch: 33	Batch: 200	Avg-Loss: 0.1804	Training Accuracy : 0.9502
# Epoch: 33	Batch: 250	Avg-Loss: 0.1851	Training Accuracy : 0.9478
# Epoch: 33	Batch: 300	Avg-Loss: 0.1945	Training Accuracy : 0.9427
# Epoch: 33	Batch: 350	Avg-Loss: 0.1771	Training Accuracy : 0.9487
# Epoch: 33	Batch: 400	Avg-Loss: 0.1839	Training Accuracy : 0.9470
# Epoch: 33	Batch: 450	Avg-Loss: 0.1921	Training Accuracy : 0.9472
# Epoch: 33	Batch: 500	Avg-Loss: 0.1800	Training Accuracy : 0.9480
# Epoch: 33	Batch: 550	Avg-Loss: 0.1923	Training Accuracy : 0.9463
# Epoch: 33	Batch: 600	Avg-Loss: 0.1880	Training Accuracy : 0.9461
# Epoch: 33	Batch: 650	Avg-Loss: 0.1821	Training Accuracy : 0.9489
# Epoch: 33, Validation Loss: 5.851, Validation Accuracy: 0.233
# Epoch: 34	Batch: 50	Avg-Loss: 0.1669	Training Accuracy : 0.9528
# Epoch: 34	Batch: 100	Avg-Loss: 0.1699	Training Accuracy : 0.9527
# Epoch: 34	Batch: 150	Avg-Loss: 0.1778	Training Accuracy : 0.9495
# Epoch: 34	Batch: 200	Avg-Loss: 0.1807	Training Accuracy : 0.9484
# Epoch: 34	Batch: 250	Avg-Loss: 0.1829	Training Accuracy : 0.9494
# Epoch: 34	Batch: 300	Avg-Loss: 0.1788	Training Accuracy : 0.9473
# Epoch: 34	Batch: 350	Avg-Loss: 0.1875	Training Accuracy : 0.9481
# Epoch: 34	Batch: 400	Avg-Loss: 0.1751	Training Accuracy : 0.9511
# Epoch: 34	Batch: 450	Avg-Loss: 0.1805	Training Accuracy : 0.9472
# Epoch: 34	Batch: 500	Avg-Loss: 0.1967	Training Accuracy : 0.9439
# Epoch: 34	Batch: 550	Avg-Loss: 0.1861	Training Accuracy : 0.9478
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-5ba80d10be1c> in <module>()
#      16
#      17         loss = criterion(outputs, y.long())
# ---> 18         loss.backward()
#      19         optimizer.step()
#      20         avg_loss += loss.item()
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     157
#     158
#
# KeyboardInterrupt:

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Mon Nov 29 23:24:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    38W / 250W |   1459MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_4+1_ours_data2/best_model_19.pt"))
network = network.to(device)

# %%
network.eval()
num_correct = 0
for x, y in tqdm(test_loader):
  x, y = x.to(device), y.to(device)
  outputs = network(x)
  num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

test_acc = num_correct / len(test_set)
print(test_acc)
# Out:
# 100%|██████████| 141/141 [02:46<00:00,  1.18s/it]
# 0.21045300050147658

# %%
print(test_acc)
# Out:
# 0.247840864768485
