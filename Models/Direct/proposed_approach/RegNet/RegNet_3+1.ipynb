# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp /content/gdrive/MyDrive/dl_project/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("3+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149932.jpg', 'frame_149907.jpg', 'fram...      7
# 1      ('frame_149933.jpg', 'frame_152295.jpg', 'fram...     10
# 2      ('frame_149903.jpg', 'frame_152323.jpg', 'fram...      4
# 3      ('frame_152463.jpg', 'frame_149941.jpg', 'fram...     22
# 4      ('frame_149930.jpg', 'frame_152761.jpg', 'fram...     11
# ...                                                  ...    ...
# 18049  ('frame_174654.jpg', 'frame_180809.jpg', 'fram...     17
# 18050  ('frame_174580.jpg', 'frame_174619.jpg', 'fram...      3
# 18051  ('frame_180890.jpg', 'frame_174567.jpg', 'fram...     19
# 18052  ('frame_174586.jpg', 'frame_174612.jpg', 'fram...      1
# 18053  ('frame_181333.jpg', 'frame_174654.jpg', 'fram...     23
#
# [18054 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            images.extend(img)
        x = torch.stack(images)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([12, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
batch_size = 128

# training data
train_set = MyDataSet(train_data)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding,num_classes))


    def forward(self, x):
      out = self.cnn(x)
      out = self.mlp(out)
      return out

# %%
numEpochs = 100
in_features = 12 # TODO: change RGB channels according to num of frames
embedding = 512

learningRate = 0.1
weightDecay = 1e-4

num_classes = 24

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_classes)
#network.load_state_dict(torch.load("model_checkpoints/resnet34/lr_0.1-2/model_2.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_3+1/best_model_" + str(epoch) + ".pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 0	Batch: 50	Avg-Loss: 3.1401	Training Accuracy : 0.0813
# Epoch: 0	Batch: 100	Avg-Loss: 2.1210	Training Accuracy : 0.1552
# Epoch: 0	Batch: 150	Avg-Loss: 1.9793	Training Accuracy : 0.1641
# Epoch: 0	Batch: 200	Avg-Loss: 1.9519	Training Accuracy : 0.1650
# Epoch: 0	Batch: 250	Avg-Loss: 1.9368	Training Accuracy : 0.1823
# Epoch: 0	Batch: 300	Avg-Loss: 1.9015	Training Accuracy : 0.1822
# Epoch: 0	Batch: 350	Avg-Loss: 1.9061	Training Accuracy : 0.1905
# Epoch: 0	Batch: 400	Avg-Loss: 1.8805	Training Accuracy : 0.1930
# Epoch: 0	Batch: 450	Avg-Loss: 1.8930	Training Accuracy : 0.1966
# Epoch: 0	Batch: 500	Avg-Loss: 1.8509	Training Accuracy : 0.2019
# Epoch: 0	Batch: 550	Avg-Loss: 1.8749	Training Accuracy : 0.2111
# Epoch: 0	Batch: 600	Avg-Loss: 1.8508	Training Accuracy : 0.2253
# Epoch: 0	Batch: 650	Avg-Loss: 1.8422	Training Accuracy : 0.2133
# Epoch: 0, Validation Loss: 1.843, Validation Accuracy: 0.230
# Epoch: 1	Batch: 50	Avg-Loss: 1.8168	Training Accuracy : 0.2302
# Epoch: 1	Batch: 100	Avg-Loss: 1.8089	Training Accuracy : 0.2327
# Epoch: 1	Batch: 150	Avg-Loss: 1.8066	Training Accuracy : 0.2462
# Epoch: 1	Batch: 200	Avg-Loss: 1.7936	Training Accuracy : 0.2380
# Epoch: 1	Batch: 250	Avg-Loss: 1.7800	Training Accuracy : 0.2437
# Epoch: 1	Batch: 300	Avg-Loss: 1.7800	Training Accuracy : 0.2409
# Epoch: 1	Batch: 350	Avg-Loss: 1.7460	Training Accuracy : 0.2519
# Epoch: 1	Batch: 400	Avg-Loss: 1.7558	Training Accuracy : 0.2525
# Epoch: 1	Batch: 450	Avg-Loss: 1.7569	Training Accuracy : 0.2533
# Epoch: 1	Batch: 500	Avg-Loss: 1.7427	Training Accuracy : 0.2545
# Epoch: 1	Batch: 550	Avg-Loss: 1.7287	Training Accuracy : 0.2634
# Epoch: 1	Batch: 600	Avg-Loss: 1.7191	Training Accuracy : 0.2573
# Epoch: 1	Batch: 650	Avg-Loss: 1.7091	Training Accuracy : 0.2684
# Epoch: 1, Validation Loss: 1.696, Validation Accuracy: 0.278
# Epoch: 2	Batch: 50	Avg-Loss: 1.7199	Training Accuracy : 0.2612
# Epoch: 2	Batch: 100	Avg-Loss: 1.7004	Training Accuracy : 0.2834
# Epoch: 2	Batch: 150	Avg-Loss: 1.6962	Training Accuracy : 0.2863
# Epoch: 2	Batch: 200	Avg-Loss: 1.6811	Training Accuracy : 0.2755
# Epoch: 2	Batch: 250	Avg-Loss: 1.6823	Training Accuracy : 0.2772
# Epoch: 2	Batch: 300	Avg-Loss: 1.6769	Training Accuracy : 0.2670
# Epoch: 2	Batch: 350	Avg-Loss: 1.6828	Training Accuracy : 0.2770
# Epoch: 2	Batch: 400	Avg-Loss: 1.6724	Training Accuracy : 0.2775
# Epoch: 2	Batch: 450	Avg-Loss: 1.6767	Training Accuracy : 0.2863
# Epoch: 2	Batch: 500	Avg-Loss: 1.6705	Training Accuracy : 0.2692
# Epoch: 2	Batch: 550	Avg-Loss: 1.6775	Training Accuracy : 0.2727
# Epoch: 2	Batch: 600	Avg-Loss: 1.6572	Training Accuracy : 0.2889
# Epoch: 2	Batch: 650	Avg-Loss: 1.6356	Training Accuracy : 0.2886
# Epoch: 2, Validation Loss: 1.685, Validation Accuracy: 0.288
# Epoch: 3	Batch: 50	Avg-Loss: 1.6764	Training Accuracy : 0.2736
# Epoch: 3	Batch: 100	Avg-Loss: 1.6288	Training Accuracy : 0.2839
# Epoch: 3	Batch: 150	Avg-Loss: 1.6061	Training Accuracy : 0.3050
# Epoch: 3	Batch: 200	Avg-Loss: 1.6096	Training Accuracy : 0.3031
# Epoch: 3	Batch: 250	Avg-Loss: 1.6111	Training Accuracy : 0.2959
# Epoch: 3	Batch: 300	Avg-Loss: 1.6201	Training Accuracy : 0.3002
# Epoch: 3	Batch: 350	Avg-Loss: 1.6225	Training Accuracy : 0.2928
# Epoch: 3	Batch: 400	Avg-Loss: 1.6103	Training Accuracy : 0.2938
# Epoch: 3	Batch: 450	Avg-Loss: 1.6351	Training Accuracy : 0.2906
# Epoch: 3	Batch: 500	Avg-Loss: 1.6006	Training Accuracy : 0.3030
# Epoch: 3	Batch: 550	Avg-Loss: 1.6006	Training Accuracy : 0.3030
# Epoch: 3	Batch: 600	Avg-Loss: 1.5899	Training Accuracy : 0.2931
# Epoch: 3	Batch: 650	Avg-Loss: 1.5880	Training Accuracy : 0.3083
# Epoch: 3, Validation Loss: 1.566, Validation Accuracy: 0.309
# Epoch: 4	Batch: 50	Avg-Loss: 1.6295	Training Accuracy : 0.2866
# Epoch: 4	Batch: 100	Avg-Loss: 1.5923	Training Accuracy : 0.3017
# Epoch: 4	Batch: 150	Avg-Loss: 1.5792	Training Accuracy : 0.3050
# Epoch: 4	Batch: 200	Avg-Loss: 1.5782	Training Accuracy : 0.3027
# Epoch: 4	Batch: 250	Avg-Loss: 1.5481	Training Accuracy : 0.3127
# Epoch: 4	Batch: 300	Avg-Loss: 1.5515	Training Accuracy : 0.3066
# Epoch: 4	Batch: 350	Avg-Loss: 1.5619	Training Accuracy : 0.3122
# Epoch: 4	Batch: 400	Avg-Loss: 1.5612	Training Accuracy : 0.3131
# Epoch: 4	Batch: 450	Avg-Loss: 1.5763	Training Accuracy : 0.3086
# Epoch: 4	Batch: 500	Avg-Loss: 1.5441	Training Accuracy : 0.3247
# Epoch: 4	Batch: 550	Avg-Loss: 1.5529	Training Accuracy : 0.3128
# Epoch: 4	Batch: 600	Avg-Loss: 1.5527	Training Accuracy : 0.3120
# Epoch: 4	Batch: 650	Avg-Loss: 1.5468	Training Accuracy : 0.3052
# Epoch: 4, Validation Loss: 1.540, Validation Accuracy: 0.323
# Epoch: 5	Batch: 50	Avg-Loss: 1.5579	Training Accuracy : 0.3134
# Epoch: 5	Batch: 100	Avg-Loss: 1.5412	Training Accuracy : 0.3227
# Epoch: 5	Batch: 150	Avg-Loss: 1.5371	Training Accuracy : 0.3183
# Epoch: 5	Batch: 200	Avg-Loss: 1.5422	Training Accuracy : 0.3155
# Epoch: 5	Batch: 250	Avg-Loss: 1.5247	Training Accuracy : 0.3233
# Epoch: 5	Batch: 300	Avg-Loss: 1.5417	Training Accuracy : 0.3119
# Epoch: 5	Batch: 350	Avg-Loss: 1.5358	Training Accuracy : 0.3177
# Epoch: 5	Batch: 400	Avg-Loss: 1.5370	Training Accuracy : 0.3198
# Epoch: 5	Batch: 450	Avg-Loss: 1.5196	Training Accuracy : 0.3227
# Epoch: 5	Batch: 500	Avg-Loss: 1.5208	Training Accuracy : 0.3217
# Epoch: 5	Batch: 550	Avg-Loss: 1.5004	Training Accuracy : 0.3277
# Epoch: 5	Batch: 600	Avg-Loss: 1.5090	Training Accuracy : 0.3331
# Epoch: 5	Batch: 650	Avg-Loss: 1.5025	Training Accuracy : 0.3170
# Epoch: 5, Validation Loss: 1.579, Validation Accuracy: 0.320
# Epoch: 6	Batch: 50	Avg-Loss: 1.5092	Training Accuracy : 0.3353
# Epoch: 6	Batch: 100	Avg-Loss: 1.5149	Training Accuracy : 0.3362
# Epoch: 6	Batch: 150	Avg-Loss: 1.4985	Training Accuracy : 0.3375
# Epoch: 6	Batch: 200	Avg-Loss: 1.5021	Training Accuracy : 0.3230
# Epoch: 6	Batch: 250	Avg-Loss: 1.5075	Training Accuracy : 0.3227
# Epoch: 6	Batch: 300	Avg-Loss: 1.4856	Training Accuracy : 0.3337
# Epoch: 6	Batch: 350	Avg-Loss: 1.5056	Training Accuracy : 0.3303
# Epoch: 6	Batch: 400	Avg-Loss: 1.5067	Training Accuracy : 0.3370
# Epoch: 6	Batch: 450	Avg-Loss: 1.4738	Training Accuracy : 0.3337
# Epoch: 6	Batch: 500	Avg-Loss: 1.5174	Training Accuracy : 0.3242
# Epoch: 6	Batch: 550	Avg-Loss: 1.4851	Training Accuracy : 0.3319
# Epoch: 6	Batch: 600	Avg-Loss: 1.5156	Training Accuracy : 0.3322
# Epoch: 6	Batch: 650	Avg-Loss: 1.4962	Training Accuracy : 0.3225
# Epoch: 6, Validation Loss: 1.654, Validation Accuracy: 0.300
# Epoch: 7	Batch: 50	Avg-Loss: 1.5365	Training Accuracy : 0.3206
# Epoch: 7	Batch: 100	Avg-Loss: 1.4999	Training Accuracy : 0.3258
# Epoch: 7	Batch: 150	Avg-Loss: 1.4836	Training Accuracy : 0.3319
# Epoch: 7	Batch: 200	Avg-Loss: 1.4985	Training Accuracy : 0.3242
# Epoch: 7	Batch: 250	Avg-Loss: 1.4546	Training Accuracy : 0.3330
# Epoch: 7	Batch: 300	Avg-Loss: 1.4676	Training Accuracy : 0.3314
# Epoch: 7	Batch: 350	Avg-Loss: 1.4820	Training Accuracy : 0.3273
# Epoch: 7	Batch: 400	Avg-Loss: 1.5052	Training Accuracy : 0.3208
# Epoch: 7	Batch: 450	Avg-Loss: 1.4942	Training Accuracy : 0.3277
# Epoch: 7	Batch: 500	Avg-Loss: 1.4789	Training Accuracy : 0.3366
# Epoch: 7	Batch: 550	Avg-Loss: 1.4743	Training Accuracy : 0.3375
# Epoch: 7	Batch: 600	Avg-Loss: 1.4624	Training Accuracy : 0.3417
# Epoch: 7	Batch: 650	Avg-Loss: 1.4569	Training Accuracy : 0.3481
# Epoch: 7, Validation Loss: 1.517, Validation Accuracy: 0.329
# Epoch: 8	Batch: 50	Avg-Loss: 1.5084	Training Accuracy : 0.3281
# Epoch: 8	Batch: 100	Avg-Loss: 1.4634	Training Accuracy : 0.3333
# Epoch: 8	Batch: 150	Avg-Loss: 1.4561	Training Accuracy : 0.3500
# Epoch: 8	Batch: 200	Avg-Loss: 1.4663	Training Accuracy : 0.3450
# Epoch: 8	Batch: 250	Avg-Loss: 1.4725	Training Accuracy : 0.3322
# Epoch: 8	Batch: 300	Avg-Loss: 1.4475	Training Accuracy : 0.3538
# Epoch: 8	Batch: 350	Avg-Loss: 1.4614	Training Accuracy : 0.3400
# Epoch: 8	Batch: 400	Avg-Loss: 1.4571	Training Accuracy : 0.3488
# Epoch: 8	Batch: 450	Avg-Loss: 1.4472	Training Accuracy : 0.3495
# Epoch: 8	Batch: 500	Avg-Loss: 1.4528	Training Accuracy : 0.3475
# Epoch: 8	Batch: 550	Avg-Loss: 1.4453	Training Accuracy : 0.3434
# Epoch: 8	Batch: 600	Avg-Loss: 1.4287	Training Accuracy : 0.3581
# Epoch: 8	Batch: 650	Avg-Loss: 1.4424	Training Accuracy : 0.3403
# Epoch: 8, Validation Loss: 1.544, Validation Accuracy: 0.321
# Epoch: 9	Batch: 50	Avg-Loss: 1.4352	Training Accuracy : 0.3427
# Epoch: 9	Batch: 100	Avg-Loss: 1.4278	Training Accuracy : 0.3548
# Epoch: 9	Batch: 150	Avg-Loss: 1.4062	Training Accuracy : 0.3602
# Epoch: 9	Batch: 200	Avg-Loss: 1.4053	Training Accuracy : 0.3592
# Epoch: 9	Batch: 250	Avg-Loss: 1.4175	Training Accuracy : 0.3444
# Epoch: 9	Batch: 300	Avg-Loss: 1.4292	Training Accuracy : 0.3556
# Epoch: 9	Batch: 350	Avg-Loss: 1.4211	Training Accuracy : 0.3419
# Epoch: 9	Batch: 400	Avg-Loss: 1.4258	Training Accuracy : 0.3539
# Epoch: 9	Batch: 450	Avg-Loss: 1.4243	Training Accuracy : 0.3456
# Epoch: 9	Batch: 500	Avg-Loss: 1.4073	Training Accuracy : 0.3589
# Epoch: 9	Batch: 550	Avg-Loss: 1.4153	Training Accuracy : 0.3625
# Epoch: 9	Batch: 600	Avg-Loss: 1.4171	Training Accuracy : 0.3541
# Epoch: 9	Batch: 650	Avg-Loss: 1.4051	Training Accuracy : 0.3656
# Epoch: 9, Validation Loss: 1.545, Validation Accuracy: 0.337
# Epoch: 10	Batch: 50	Avg-Loss: 1.4031	Training Accuracy : 0.3691
# Epoch: 10	Batch: 100	Avg-Loss: 1.3806	Training Accuracy : 0.3634
# Epoch: 10	Batch: 150	Avg-Loss: 1.3832	Training Accuracy : 0.3620
# Epoch: 10	Batch: 200	Avg-Loss: 1.3571	Training Accuracy : 0.3605
# Epoch: 10	Batch: 250	Avg-Loss: 1.3801	Training Accuracy : 0.3700
# Epoch: 10	Batch: 300	Avg-Loss: 1.3669	Training Accuracy : 0.3750
# Epoch: 10	Batch: 350	Avg-Loss: 1.3563	Training Accuracy : 0.3719
# Epoch: 10	Batch: 400	Avg-Loss: 1.3482	Training Accuracy : 0.3714
# Epoch: 10	Batch: 450	Avg-Loss: 1.3613	Training Accuracy : 0.3702
# Epoch: 10	Batch: 500	Avg-Loss: 1.3915	Training Accuracy : 0.3569
# Epoch: 10	Batch: 550	Avg-Loss: 1.3519	Training Accuracy : 0.3758
# Epoch: 10	Batch: 600	Avg-Loss: 1.3878	Training Accuracy : 0.3558
# Epoch: 10	Batch: 650	Avg-Loss: 1.3883	Training Accuracy : 0.3659
# Epoch    11: reducing learning rate of group 0 to 5.0000e-02.
# Epoch: 10, Validation Loss: 1.861, Validation Accuracy: 0.327
# Epoch: 11	Batch: 50	Avg-Loss: 1.2905	Training Accuracy : 0.3925
# Epoch: 11	Batch: 100	Avg-Loss: 1.2400	Training Accuracy : 0.4080
# Epoch: 11	Batch: 150	Avg-Loss: 1.2325	Training Accuracy : 0.4058
# Epoch: 11	Batch: 200	Avg-Loss: 1.2096	Training Accuracy : 0.4208
# Epoch: 11	Batch: 250	Avg-Loss: 1.2327	Training Accuracy : 0.4175
# Epoch: 11	Batch: 300	Avg-Loss: 1.2116	Training Accuracy : 0.4250
# Epoch: 11	Batch: 350	Avg-Loss: 1.2295	Training Accuracy : 0.4178
# Epoch: 11	Batch: 400	Avg-Loss: 1.2158	Training Accuracy : 0.4336
# Epoch: 11	Batch: 450	Avg-Loss: 1.2224	Training Accuracy : 0.4252
# Epoch: 11	Batch: 500	Avg-Loss: 1.2279	Training Accuracy : 0.4248
# Epoch: 11	Batch: 550	Avg-Loss: 1.2061	Training Accuracy : 0.4344
# Epoch: 11	Batch: 600	Avg-Loss: 1.2118	Training Accuracy : 0.4338
# Epoch: 11	Batch: 650	Avg-Loss: 1.2179	Training Accuracy : 0.4266
# Epoch: 11, Validation Loss: 2.212, Validation Accuracy: 0.336
# Epoch: 12	Batch: 50	Avg-Loss: 1.1494	Training Accuracy : 0.4633
# Epoch: 12	Batch: 100	Avg-Loss: 1.1543	Training Accuracy : 0.4667
# Epoch: 12	Batch: 150	Avg-Loss: 1.1488	Training Accuracy : 0.4794
# Epoch: 12	Batch: 200	Avg-Loss: 1.1363	Training Accuracy : 0.4795
# Epoch: 12	Batch: 250	Avg-Loss: 1.1769	Training Accuracy : 0.4683
# Epoch: 12	Batch: 300	Avg-Loss: 1.1457	Training Accuracy : 0.4805
# Epoch: 12	Batch: 350	Avg-Loss: 1.1703	Training Accuracy : 0.4692
# Epoch: 12	Batch: 400	Avg-Loss: 1.1387	Training Accuracy : 0.4889
# Epoch: 12	Batch: 450	Avg-Loss: 1.1625	Training Accuracy : 0.4852
# Epoch: 12	Batch: 500	Avg-Loss: 1.1325	Training Accuracy : 0.5025
# Epoch: 12	Batch: 550	Avg-Loss: 1.1234	Training Accuracy : 0.5066
# Epoch: 12	Batch: 600	Avg-Loss: 1.1318	Training Accuracy : 0.5150
# Epoch: 12	Batch: 650	Avg-Loss: 1.1241	Training Accuracy : 0.5259
# Epoch: 12, Validation Loss: 2.508, Validation Accuracy: 0.329
# Epoch: 13	Batch: 50	Avg-Loss: 1.0515	Training Accuracy : 0.5509
# Epoch: 13	Batch: 100	Avg-Loss: 1.0219	Training Accuracy : 0.5756
# Epoch: 13	Batch: 150	Avg-Loss: 1.0647	Training Accuracy : 0.5555
# Epoch: 13	Batch: 200	Avg-Loss: 1.0209	Training Accuracy : 0.5770
# Epoch: 13	Batch: 250	Avg-Loss: 1.0220	Training Accuracy : 0.5789
# Epoch: 13	Batch: 300	Avg-Loss: 1.0006	Training Accuracy : 0.5950
# Epoch: 13	Batch: 350	Avg-Loss: 0.9772	Training Accuracy : 0.6083
# Epoch: 13	Batch: 400	Avg-Loss: 0.9680	Training Accuracy : 0.6083
# Epoch: 13	Batch: 450	Avg-Loss: 0.9713	Training Accuracy : 0.6205
# Epoch: 13	Batch: 500	Avg-Loss: 0.9727	Training Accuracy : 0.6214
# Epoch: 13	Batch: 550	Avg-Loss: 0.9188	Training Accuracy : 0.6405
# Epoch: 13	Batch: 600	Avg-Loss: 0.9125	Training Accuracy : 0.6347
# Epoch: 13	Batch: 650	Avg-Loss: 0.8931	Training Accuracy : 0.6517
# Epoch    14: reducing learning rate of group 0 to 2.5000e-02.
# Epoch: 13, Validation Loss: 2.185, Validation Accuracy: 0.336
# Epoch: 14	Batch: 50	Avg-Loss: 0.7124	Training Accuracy : 0.7195
# Epoch: 14	Batch: 100	Avg-Loss: 0.6367	Training Accuracy : 0.7583
# Epoch: 14	Batch: 150	Avg-Loss: 0.6202	Training Accuracy : 0.7656
# Epoch: 14	Batch: 200	Avg-Loss: 0.6180	Training Accuracy : 0.7675
# Epoch: 14	Batch: 250	Avg-Loss: 0.5957	Training Accuracy : 0.7739
# Epoch: 14	Batch: 300	Avg-Loss: 0.5889	Training Accuracy : 0.7758
# Epoch: 14	Batch: 350	Avg-Loss: 0.6135	Training Accuracy : 0.7677
# Epoch: 14	Batch: 400	Avg-Loss: 0.6207	Training Accuracy : 0.7672
# Epoch: 14	Batch: 450	Avg-Loss: 0.6220	Training Accuracy : 0.7608
# Epoch: 14	Batch: 500	Avg-Loss: 0.5907	Training Accuracy : 0.7777
# Epoch: 14	Batch: 550	Avg-Loss: 0.5868	Training Accuracy : 0.7783
# Epoch: 14	Batch: 600	Avg-Loss: 0.5678	Training Accuracy : 0.7842
# Epoch: 14	Batch: 650	Avg-Loss: 0.5993	Training Accuracy : 0.7716
# Epoch: 14, Validation Loss: 2.802, Validation Accuracy: 0.324
# Epoch: 15	Batch: 50	Avg-Loss: 0.4721	Training Accuracy : 0.8192
# Epoch: 15	Batch: 100	Avg-Loss: 0.4692	Training Accuracy : 0.8163
# Epoch: 15	Batch: 150	Avg-Loss: 0.4607	Training Accuracy : 0.8197
# Epoch: 15	Batch: 200	Avg-Loss: 0.4547	Training Accuracy : 0.8239
# Epoch: 15	Batch: 250	Avg-Loss: 0.4872	Training Accuracy : 0.8208
# Epoch: 15	Batch: 300	Avg-Loss: 0.4743	Training Accuracy : 0.8166
# Epoch: 15	Batch: 350	Avg-Loss: 0.4883	Training Accuracy : 0.8116
# Epoch: 15	Batch: 400	Avg-Loss: 0.4955	Training Accuracy : 0.8064
# Epoch: 15	Batch: 450	Avg-Loss: 0.4765	Training Accuracy : 0.8178
# Epoch: 15	Batch: 500	Avg-Loss: 0.5020	Training Accuracy : 0.8048
# Epoch: 15	Batch: 550	Avg-Loss: 0.5014	Training Accuracy : 0.8117
# Epoch: 15	Batch: 600	Avg-Loss: 0.5067	Training Accuracy : 0.8061
# Epoch: 15	Batch: 650	Avg-Loss: 0.5173	Training Accuracy : 0.8098
# Epoch: 15, Validation Loss: 2.920, Validation Accuracy: 0.338
# Epoch: 16	Batch: 50	Avg-Loss: 0.4302	Training Accuracy : 0.8373
# Epoch: 16	Batch: 100	Avg-Loss: 0.4001	Training Accuracy : 0.8461
# Epoch: 16	Batch: 150	Avg-Loss: 0.3909	Training Accuracy : 0.8492
# Epoch: 16	Batch: 200	Avg-Loss: 0.4046	Training Accuracy : 0.8481
# Epoch: 16	Batch: 250	Avg-Loss: 0.4079	Training Accuracy : 0.8430
# Epoch: 16	Batch: 300	Avg-Loss: 0.4338	Training Accuracy : 0.8333
# Epoch: 16	Batch: 350	Avg-Loss: 0.4387	Training Accuracy : 0.8303
# Epoch: 16	Batch: 400	Avg-Loss: 0.4091	Training Accuracy : 0.8436
# Epoch: 16	Batch: 450	Avg-Loss: 0.4415	Training Accuracy : 0.8308
# Epoch: 16	Batch: 500	Avg-Loss: 0.4188	Training Accuracy : 0.8386
# Epoch: 16	Batch: 550	Avg-Loss: 0.5446	Training Accuracy : 0.7986
# Epoch: 16	Batch: 600	Avg-Loss: 0.7204	Training Accuracy : 0.7294
# Epoch: 16	Batch: 650	Avg-Loss: 0.5379	Training Accuracy : 0.8013
# Epoch    17: reducing learning rate of group 0 to 1.2500e-02.
# Epoch: 16, Validation Loss: 2.877, Validation Accuracy: 0.322
# Epoch: 17	Batch: 50	Avg-Loss: 0.3886	Training Accuracy : 0.8517
# Epoch: 17	Batch: 100	Avg-Loss: 0.3363	Training Accuracy : 0.8680
# Epoch: 17	Batch: 150	Avg-Loss: 0.3378	Training Accuracy : 0.8720
# Epoch: 17	Batch: 200	Avg-Loss: 0.3159	Training Accuracy : 0.8797
# Epoch: 17	Batch: 250	Avg-Loss: 0.3071	Training Accuracy : 0.8844
# Epoch: 17	Batch: 300	Avg-Loss: 0.2983	Training Accuracy : 0.8816
# Epoch: 17	Batch: 350	Avg-Loss: 0.2975	Training Accuracy : 0.8862
# Epoch: 17	Batch: 400	Avg-Loss: 0.3119	Training Accuracy : 0.8800
# Epoch: 17	Batch: 450	Avg-Loss: 0.2894	Training Accuracy : 0.8862
# Epoch: 17	Batch: 500	Avg-Loss: 0.2994	Training Accuracy : 0.8830
# Epoch: 17	Batch: 550	Avg-Loss: 0.3078	Training Accuracy : 0.8808
# Epoch: 17	Batch: 600	Avg-Loss: 0.3028	Training Accuracy : 0.8805
# Epoch: 17	Batch: 650	Avg-Loss: 0.2891	Training Accuracy : 0.8870
# Epoch: 17, Validation Loss: 3.077, Validation Accuracy: 0.328
# Epoch: 18	Batch: 50	Avg-Loss: 0.2219	Training Accuracy : 0.9116
# Epoch: 18	Batch: 100	Avg-Loss: 0.2278	Training Accuracy : 0.9117
# Epoch: 18	Batch: 150	Avg-Loss: 0.2263	Training Accuracy : 0.9119
# Epoch: 18	Batch: 200	Avg-Loss: 0.2073	Training Accuracy : 0.9186
# Epoch: 18	Batch: 250	Avg-Loss: 0.2235	Training Accuracy : 0.9105
# Epoch: 18	Batch: 300	Avg-Loss: 0.2309	Training Accuracy : 0.9062
# Epoch: 18	Batch: 350	Avg-Loss: 0.2264	Training Accuracy : 0.9095
# Epoch: 18	Batch: 400	Avg-Loss: 0.2268	Training Accuracy : 0.9100
# Epoch: 18	Batch: 450	Avg-Loss: 0.2264	Training Accuracy : 0.9062
# Epoch: 18	Batch: 500	Avg-Loss: 0.2428	Training Accuracy : 0.9059
# Epoch: 18	Batch: 550	Avg-Loss: 0.2419	Training Accuracy : 0.9039
# Epoch: 18	Batch: 600	Avg-Loss: 0.2320	Training Accuracy : 0.9033
# Epoch: 18	Batch: 650	Avg-Loss: 0.2270	Training Accuracy : 0.9078
# Epoch: 18, Validation Loss: 3.684, Validation Accuracy: 0.329
# Epoch: 19	Batch: 50	Avg-Loss: 0.2045	Training Accuracy : 0.9222
# Epoch: 19	Batch: 100	Avg-Loss: 0.2065	Training Accuracy : 0.9189
# Epoch: 19	Batch: 150	Avg-Loss: 0.1978	Training Accuracy : 0.9270
# Epoch: 19	Batch: 200	Avg-Loss: 0.1874	Training Accuracy : 0.9247
# Epoch: 19	Batch: 250	Avg-Loss: 0.2019	Training Accuracy : 0.9200
# Epoch: 19	Batch: 300	Avg-Loss: 0.2100	Training Accuracy : 0.9141
# Epoch: 19	Batch: 350	Avg-Loss: 0.2036	Training Accuracy : 0.9187
# Epoch: 19	Batch: 400	Avg-Loss: 0.1979	Training Accuracy : 0.9244
# Epoch: 19	Batch: 450	Avg-Loss: 0.2131	Training Accuracy : 0.9147
# Epoch: 19	Batch: 500	Avg-Loss: 0.1987	Training Accuracy : 0.9225
# Epoch: 19	Batch: 550	Avg-Loss: 0.2142	Training Accuracy : 0.9134
# Epoch: 19	Batch: 600	Avg-Loss: 0.2168	Training Accuracy : 0.9136
# Epoch: 19	Batch: 650	Avg-Loss: 0.2102	Training Accuracy : 0.9156
# Epoch    20: reducing learning rate of group 0 to 6.2500e-03.
# Epoch: 19, Validation Loss: 3.609, Validation Accuracy: 0.327
# Epoch: 20	Batch: 50	Avg-Loss: 0.1684	Training Accuracy : 0.9348
# Epoch: 20	Batch: 100	Avg-Loss: 0.1607	Training Accuracy : 0.9366
# Epoch: 20	Batch: 150	Avg-Loss: 0.1447	Training Accuracy : 0.9425
# Epoch: 20	Batch: 200	Avg-Loss: 0.1416	Training Accuracy : 0.9447
# Epoch: 20	Batch: 250	Avg-Loss: 0.1422	Training Accuracy : 0.9445
# Epoch: 20	Batch: 300	Avg-Loss: 0.1381	Training Accuracy : 0.9456
# Epoch: 20	Batch: 350	Avg-Loss: 0.1481	Training Accuracy : 0.9403
# Epoch: 20	Batch: 400	Avg-Loss: 0.1409	Training Accuracy : 0.9450
# Epoch: 20	Batch: 450	Avg-Loss: 0.1361	Training Accuracy : 0.9434
# Epoch: 20	Batch: 500	Avg-Loss: 0.1399	Training Accuracy : 0.9400
# Epoch: 20	Batch: 550	Avg-Loss: 0.1395	Training Accuracy : 0.9428
# Epoch: 20	Batch: 600	Avg-Loss: 0.1486	Training Accuracy : 0.9405
# Epoch: 20	Batch: 650	Avg-Loss: 0.1341	Training Accuracy : 0.9469
# Epoch: 20, Validation Loss: 3.786, Validation Accuracy: 0.336
# Epoch: 21	Batch: 50	Avg-Loss: 0.1274	Training Accuracy : 0.9492
# Epoch: 21	Batch: 100	Avg-Loss: 0.1187	Training Accuracy : 0.9563
# Epoch: 21	Batch: 150	Avg-Loss: 0.1168	Training Accuracy : 0.9542
# Epoch: 21	Batch: 200	Avg-Loss: 0.1144	Training Accuracy : 0.9561
# Epoch: 21	Batch: 250	Avg-Loss: 0.1097	Training Accuracy : 0.9547
# Epoch: 21	Batch: 300	Avg-Loss: 0.1196	Training Accuracy : 0.9517
# Epoch: 21	Batch: 350	Avg-Loss: 0.1240	Training Accuracy : 0.9497
# Epoch: 21	Batch: 400	Avg-Loss: 0.1274	Training Accuracy : 0.9478
# Epoch: 21	Batch: 450	Avg-Loss: 0.1153	Training Accuracy : 0.9566
# Epoch: 21	Batch: 500	Avg-Loss: 0.1232	Training Accuracy : 0.9487
# Epoch: 21	Batch: 550	Avg-Loss: 0.1154	Training Accuracy : 0.9556
# Epoch: 21	Batch: 600	Avg-Loss: 0.1189	Training Accuracy : 0.9514
# Epoch: 21	Batch: 650	Avg-Loss: 0.1280	Training Accuracy : 0.9453
# Epoch: 21, Validation Loss: 4.169, Validation Accuracy: 0.323
# Epoch: 22	Batch: 50	Avg-Loss: 0.1011	Training Accuracy : 0.9591
# Epoch: 22	Batch: 100	Avg-Loss: 0.1061	Training Accuracy : 0.9580
# Epoch: 22	Batch: 150	Avg-Loss: 0.1013	Training Accuracy : 0.9608
# Epoch: 22	Batch: 200	Avg-Loss: 0.1019	Training Accuracy : 0.9623
# Epoch: 22	Batch: 250	Avg-Loss: 0.1067	Training Accuracy : 0.9586
# Epoch: 22	Batch: 300	Avg-Loss: 0.1013	Training Accuracy : 0.9598
# Epoch: 22	Batch: 350	Avg-Loss: 0.1074	Training Accuracy : 0.9553
# Epoch: 22	Batch: 400	Avg-Loss: 0.1112	Training Accuracy : 0.9523
# Epoch: 22	Batch: 450	Avg-Loss: 0.1167	Training Accuracy : 0.9545
# Epoch: 22	Batch: 500	Avg-Loss: 0.0973	Training Accuracy : 0.9614
# Epoch: 22	Batch: 550	Avg-Loss: 0.1104	Training Accuracy : 0.9534
# Epoch: 22	Batch: 600	Avg-Loss: 0.1097	Training Accuracy : 0.9555
# Epoch: 22	Batch: 650	Avg-Loss: 0.1199	Training Accuracy : 0.9509
# Epoch    23: reducing learning rate of group 0 to 3.1250e-03.
# Epoch: 22, Validation Loss: 4.128, Validation Accuracy: 0.328
# Epoch: 23	Batch: 50	Avg-Loss: 0.0889	Training Accuracy : 0.9658
# Epoch: 23	Batch: 100	Avg-Loss: 0.0952	Training Accuracy : 0.9637
# Epoch: 23	Batch: 150	Avg-Loss: 0.0976	Training Accuracy : 0.9617
# Epoch: 23	Batch: 200	Avg-Loss: 0.0898	Training Accuracy : 0.9656
# Epoch: 23	Batch: 250	Avg-Loss: 0.0848	Training Accuracy : 0.9681
# Epoch: 23	Batch: 300	Avg-Loss: 0.0878	Training Accuracy : 0.9645
# Epoch: 23	Batch: 350	Avg-Loss: 0.0933	Training Accuracy : 0.9644
# Epoch: 23	Batch: 400	Avg-Loss: 0.0894	Training Accuracy : 0.9645
# Epoch: 23	Batch: 450	Avg-Loss: 0.0927	Training Accuracy : 0.9633
# Epoch: 23	Batch: 500	Avg-Loss: 0.0845	Training Accuracy : 0.9669
# Epoch: 23	Batch: 550	Avg-Loss: 0.0877	Training Accuracy : 0.9655
# Epoch: 23	Batch: 600	Avg-Loss: 0.0853	Training Accuracy : 0.9656
# Epoch: 23	Batch: 650	Avg-Loss: 0.0881	Training Accuracy : 0.9650
# Epoch: 23, Validation Loss: 4.323, Validation Accuracy: 0.330
# Epoch: 24	Batch: 50	Avg-Loss: 0.0839	Training Accuracy : 0.9666
# Epoch: 24	Batch: 100	Avg-Loss: 0.0885	Training Accuracy : 0.9644
# Epoch: 24	Batch: 150	Avg-Loss: 0.0815	Training Accuracy : 0.9692
# Epoch: 24	Batch: 200	Avg-Loss: 0.0793	Training Accuracy : 0.9706
# Epoch: 24	Batch: 250	Avg-Loss: 0.0773	Training Accuracy : 0.9705
# Epoch: 24	Batch: 300	Avg-Loss: 0.0836	Training Accuracy : 0.9678
# Epoch: 24	Batch: 350	Avg-Loss: 0.0807	Training Accuracy : 0.9689
# Epoch: 24	Batch: 400	Avg-Loss: 0.0797	Training Accuracy : 0.9692
# Epoch: 24	Batch: 450	Avg-Loss: 0.0820	Training Accuracy : 0.9688
# Epoch: 24	Batch: 500	Avg-Loss: 0.0855	Training Accuracy : 0.9655
# Epoch: 24	Batch: 550	Avg-Loss: 0.0809	Training Accuracy : 0.9686
# Epoch: 24	Batch: 600	Avg-Loss: 0.0841	Training Accuracy : 0.9650
# Epoch: 24	Batch: 650	Avg-Loss: 0.0799	Training Accuracy : 0.9691
# Epoch: 24, Validation Loss: 4.272, Validation Accuracy: 0.320
# Epoch: 25	Batch: 50	Avg-Loss: 0.0758	Training Accuracy : 0.9723
# Epoch: 25	Batch: 100	Avg-Loss: 0.0680	Training Accuracy : 0.9728
# Epoch: 25	Batch: 150	Avg-Loss: 0.0705	Training Accuracy : 0.9733
# Epoch: 25	Batch: 200	Avg-Loss: 0.0816	Training Accuracy : 0.9650
# Epoch: 25	Batch: 250	Avg-Loss: 0.0808	Training Accuracy : 0.9684
# Epoch: 25	Batch: 300	Avg-Loss: 0.0749	Training Accuracy : 0.9736
# Epoch: 25	Batch: 350	Avg-Loss: 0.0719	Training Accuracy : 0.9747
# Epoch: 25	Batch: 400	Avg-Loss: 0.0796	Training Accuracy : 0.9697
# Epoch: 25	Batch: 450	Avg-Loss: 0.0752	Training Accuracy : 0.9705
# Epoch: 25	Batch: 500	Avg-Loss: 0.0737	Training Accuracy : 0.9711
# Epoch: 25	Batch: 550	Avg-Loss: 0.0823	Training Accuracy : 0.9684
# Epoch: 25	Batch: 600	Avg-Loss: 0.0845	Training Accuracy : 0.9689
# Epoch: 25	Batch: 650	Avg-Loss: 0.0749	Training Accuracy : 0.9705
# Epoch    26: reducing learning rate of group 0 to 1.5625e-03.
# Epoch: 25, Validation Loss: 4.306, Validation Accuracy: 0.323
# Epoch: 26	Batch: 50	Avg-Loss: 0.0718	Training Accuracy : 0.9733
# Epoch: 26	Batch: 100	Avg-Loss: 0.0736	Training Accuracy : 0.9717
# Epoch: 26	Batch: 150	Avg-Loss: 0.0711	Training Accuracy : 0.9738
# Epoch: 26	Batch: 200	Avg-Loss: 0.0659	Training Accuracy : 0.9750
# Epoch: 26	Batch: 250	Avg-Loss: 0.0677	Training Accuracy : 0.9741
# Epoch: 26	Batch: 300	Avg-Loss: 0.0730	Training Accuracy : 0.9722
# Epoch: 26	Batch: 350	Avg-Loss: 0.0631	Training Accuracy : 0.9764
# Epoch: 26	Batch: 400	Avg-Loss: 0.0694	Training Accuracy : 0.9731
# Epoch: 26	Batch: 450	Avg-Loss: 0.0695	Training Accuracy : 0.9750
# Epoch: 26	Batch: 500	Avg-Loss: 0.0704	Training Accuracy : 0.9728
# Epoch: 26	Batch: 550	Avg-Loss: 0.0670	Training Accuracy : 0.9741
# Epoch: 26	Batch: 600	Avg-Loss: 0.0611	Training Accuracy : 0.9762
# Epoch: 26	Batch: 650	Avg-Loss: 0.0675	Training Accuracy : 0.9748
# Epoch: 26, Validation Loss: 4.303, Validation Accuracy: 0.326
# Epoch: 27	Batch: 50	Avg-Loss: 0.0661	Training Accuracy : 0.9745
# Epoch: 27	Batch: 100	Avg-Loss: 0.0669	Training Accuracy : 0.9733
# Epoch: 27	Batch: 150	Avg-Loss: 0.0646	Training Accuracy : 0.9764
# Epoch: 27	Batch: 200	Avg-Loss: 0.0606	Training Accuracy : 0.9770
# Epoch: 27	Batch: 250	Avg-Loss: 0.0643	Training Accuracy : 0.9759
# Epoch: 27	Batch: 300	Avg-Loss: 0.0573	Training Accuracy : 0.9798
# Epoch: 27	Batch: 350	Avg-Loss: 0.0632	Training Accuracy : 0.9777
# Epoch: 27	Batch: 400	Avg-Loss: 0.0696	Training Accuracy : 0.9741
# Epoch: 27	Batch: 450	Avg-Loss: 0.0686	Training Accuracy : 0.9730
# Epoch: 27	Batch: 500	Avg-Loss: 0.0619	Training Accuracy : 0.9784
# Epoch: 27	Batch: 550	Avg-Loss: 0.0641	Training Accuracy : 0.9753
# Epoch: 27	Batch: 600	Avg-Loss: 0.0668	Training Accuracy : 0.9731
# Epoch: 27	Batch: 650	Avg-Loss: 0.0611	Training Accuracy : 0.9769
# Epoch: 27, Validation Loss: 4.412, Validation Accuracy: 0.327
# Epoch: 28	Batch: 50	Avg-Loss: 0.0645	Training Accuracy : 0.9758
# Epoch: 28	Batch: 100	Avg-Loss: 0.0617	Training Accuracy : 0.9761
# Epoch: 28	Batch: 150	Avg-Loss: 0.0630	Training Accuracy : 0.9788
# Epoch: 28	Batch: 200	Avg-Loss: 0.0573	Training Accuracy : 0.9780
# Epoch: 28	Batch: 250	Avg-Loss: 0.0607	Training Accuracy : 0.9789
# Epoch: 28	Batch: 300	Avg-Loss: 0.0591	Training Accuracy : 0.9792
# Epoch: 28	Batch: 350	Avg-Loss: 0.0640	Training Accuracy : 0.9758
# Epoch: 28	Batch: 400	Avg-Loss: 0.0598	Training Accuracy : 0.9769
# Epoch: 28	Batch: 450	Avg-Loss: 0.0619	Training Accuracy : 0.9773
# Epoch: 28	Batch: 500	Avg-Loss: 0.0605	Training Accuracy : 0.9770
# Epoch: 28	Batch: 550	Avg-Loss: 0.0660	Training Accuracy : 0.9748
# Epoch: 28	Batch: 600	Avg-Loss: 0.0623	Training Accuracy : 0.9775
# Epoch: 28	Batch: 650	Avg-Loss: 0.0560	Training Accuracy : 0.9809
# Epoch    29: reducing learning rate of group 0 to 7.8125e-04.
# Epoch: 28, Validation Loss: 4.440, Validation Accuracy: 0.326
# Epoch: 29	Batch: 50	Avg-Loss: 0.0582	Training Accuracy : 0.9802
# Epoch: 29	Batch: 100	Avg-Loss: 0.0530	Training Accuracy : 0.9806
# Epoch: 29	Batch: 150	Avg-Loss: 0.0584	Training Accuracy : 0.9791
# Epoch: 29	Batch: 200	Avg-Loss: 0.0522	Training Accuracy : 0.9820
# Epoch: 29	Batch: 250	Avg-Loss: 0.0523	Training Accuracy : 0.9819
# Epoch: 29	Batch: 300	Avg-Loss: 0.0506	Training Accuracy : 0.9820
# Epoch: 29	Batch: 350	Avg-Loss: 0.0549	Training Accuracy : 0.9809
# Epoch: 29	Batch: 400	Avg-Loss: 0.0553	Training Accuracy : 0.9808
# Epoch: 29	Batch: 450	Avg-Loss: 0.0522	Training Accuracy : 0.9816
# Epoch: 29	Batch: 500	Avg-Loss: 0.0560	Training Accuracy : 0.9802
# Epoch: 29	Batch: 550	Avg-Loss: 0.0557	Training Accuracy : 0.9800
# Epoch: 29	Batch: 600	Avg-Loss: 0.0522	Training Accuracy : 0.9794
# Epoch: 29	Batch: 650	Avg-Loss: 0.0588	Training Accuracy : 0.9791
# Epoch: 29, Validation Loss: 4.427, Validation Accuracy: 0.327
# Epoch: 30	Batch: 50	Avg-Loss: 0.0516	Training Accuracy : 0.9805
# Epoch: 30	Batch: 100	Avg-Loss: 0.0506	Training Accuracy : 0.9817
# Epoch: 30	Batch: 150	Avg-Loss: 0.0540	Training Accuracy : 0.9819
# Epoch: 30	Batch: 200	Avg-Loss: 0.0520	Training Accuracy : 0.9823
# Epoch: 30	Batch: 250	Avg-Loss: 0.0481	Training Accuracy : 0.9814
# Epoch: 30	Batch: 300	Avg-Loss: 0.0529	Training Accuracy : 0.9812
# Epoch: 30	Batch: 350	Avg-Loss: 0.0551	Training Accuracy : 0.9794
# Epoch: 30	Batch: 400	Avg-Loss: 0.0525	Training Accuracy : 0.9828
# Epoch: 30	Batch: 450	Avg-Loss: 0.0516	Training Accuracy : 0.9820
# Epoch: 30	Batch: 500	Avg-Loss: 0.0492	Training Accuracy : 0.9828
# Epoch: 30	Batch: 550	Avg-Loss: 0.0510	Training Accuracy : 0.9820
# Epoch: 30	Batch: 600	Avg-Loss: 0.0537	Training Accuracy : 0.9817
# Epoch: 30	Batch: 650	Avg-Loss: 0.0483	Training Accuracy : 0.9827
# Epoch: 30, Validation Loss: 4.367, Validation Accuracy: 0.325
# Epoch: 31	Batch: 50	Avg-Loss: 0.0435	Training Accuracy : 0.9838
# Epoch: 31	Batch: 100	Avg-Loss: 0.0492	Training Accuracy : 0.9817
# Epoch: 31	Batch: 150	Avg-Loss: 0.0462	Training Accuracy : 0.9836
# Epoch: 31	Batch: 200	Avg-Loss: 0.0485	Training Accuracy : 0.9834
# Epoch: 31	Batch: 250	Avg-Loss: 0.0489	Training Accuracy : 0.9834
# Epoch: 31	Batch: 300	Avg-Loss: 0.0520	Training Accuracy : 0.9814
# Epoch: 31	Batch: 350	Avg-Loss: 0.0508	Training Accuracy : 0.9833
# Epoch: 31	Batch: 400	Avg-Loss: 0.0490	Training Accuracy : 0.9822
# Epoch: 31	Batch: 450	Avg-Loss: 0.0451	Training Accuracy : 0.9850
# Epoch: 31	Batch: 500	Avg-Loss: 0.0450	Training Accuracy : 0.9836
# Epoch: 31	Batch: 550	Avg-Loss: 0.0421	Training Accuracy : 0.9853
# Epoch: 31	Batch: 600	Avg-Loss: 0.0464	Training Accuracy : 0.9836
# Epoch: 31	Batch: 650	Avg-Loss: 0.0540	Training Accuracy : 0.9798
# Epoch    32: reducing learning rate of group 0 to 3.9063e-04.
# Epoch: 31, Validation Loss: 4.492, Validation Accuracy: 0.327
# Epoch: 32	Batch: 50	Avg-Loss: 0.0433	Training Accuracy : 0.9861
# Epoch: 32	Batch: 100	Avg-Loss: 0.0473	Training Accuracy : 0.9848
# Epoch: 32	Batch: 150	Avg-Loss: 0.0459	Training Accuracy : 0.9836
# Epoch: 32	Batch: 200	Avg-Loss: 0.0496	Training Accuracy : 0.9820
# Epoch: 32	Batch: 250	Avg-Loss: 0.0480	Training Accuracy : 0.9833
# Epoch: 32	Batch: 300	Avg-Loss: 0.0448	Training Accuracy : 0.9852
# Epoch: 32	Batch: 350	Avg-Loss: 0.0456	Training Accuracy : 0.9852
# Epoch: 32	Batch: 400	Avg-Loss: 0.0475	Training Accuracy : 0.9830
# Epoch: 32	Batch: 450	Avg-Loss: 0.0415	Training Accuracy : 0.9873
# Epoch: 32	Batch: 500	Avg-Loss: 0.0424	Training Accuracy : 0.9848
# Epoch: 32	Batch: 550	Avg-Loss: 0.0461	Training Accuracy : 0.9839
# Epoch: 32	Batch: 600	Avg-Loss: 0.0425	Training Accuracy : 0.9866
# Epoch: 32	Batch: 650	Avg-Loss: 0.0413	Training Accuracy : 0.9862
# Epoch: 32, Validation Loss: 4.462, Validation Accuracy: 0.323
# Epoch: 33	Batch: 50	Avg-Loss: 0.0403	Training Accuracy : 0.9873
# Epoch: 33	Batch: 100	Avg-Loss: 0.0404	Training Accuracy : 0.9861
# Epoch: 33	Batch: 150	Avg-Loss: 0.0383	Training Accuracy : 0.9880
# Epoch: 33	Batch: 200	Avg-Loss: 0.0431	Training Accuracy : 0.9859
# Epoch: 33	Batch: 250	Avg-Loss: 0.0400	Training Accuracy : 0.9878
# Epoch: 33	Batch: 300	Avg-Loss: 0.0426	Training Accuracy : 0.9856
# Epoch: 33	Batch: 350	Avg-Loss: 0.0456	Training Accuracy : 0.9831
# Epoch: 33	Batch: 400	Avg-Loss: 0.0399	Training Accuracy : 0.9869
# Epoch: 33	Batch: 450	Avg-Loss: 0.0464	Training Accuracy : 0.9844
# Epoch: 33	Batch: 500	Avg-Loss: 0.0400	Training Accuracy : 0.9858
# Epoch: 33	Batch: 550	Avg-Loss: 0.0396	Training Accuracy : 0.9859
# Epoch: 33	Batch: 600	Avg-Loss: 0.0389	Training Accuracy : 0.9867
# Epoch: 33	Batch: 650	Avg-Loss: 0.0382	Training Accuracy : 0.9872
# Epoch: 33, Validation Loss: 4.705, Validation Accuracy: 0.323
# Epoch: 34	Batch: 50	Avg-Loss: 0.0415	Training Accuracy : 0.9872
# Epoch: 34	Batch: 100	Avg-Loss: 0.0403	Training Accuracy : 0.9859
# Epoch: 34	Batch: 150	Avg-Loss: 0.0375	Training Accuracy : 0.9867
# Epoch: 34	Batch: 200	Avg-Loss: 0.0376	Training Accuracy : 0.9869
# Epoch: 34	Batch: 250	Avg-Loss: 0.0442	Training Accuracy : 0.9858
# Epoch: 34	Batch: 300	Avg-Loss: 0.0354	Training Accuracy : 0.9889
# Epoch: 34	Batch: 350	Avg-Loss: 0.0411	Training Accuracy : 0.9853
# Epoch: 34	Batch: 400	Avg-Loss: 0.0374	Training Accuracy : 0.9878
# Epoch: 34	Batch: 450	Avg-Loss: 0.0419	Training Accuracy : 0.9880
# Epoch: 34	Batch: 500	Avg-Loss: 0.0437	Training Accuracy : 0.9853
# Epoch: 34	Batch: 550	Avg-Loss: 0.0426	Training Accuracy : 0.9859
# Epoch: 34	Batch: 600	Avg-Loss: 0.0390	Training Accuracy : 0.9872
# Epoch: 34	Batch: 650	Avg-Loss: 0.0392	Training Accuracy : 0.9880
# Epoch    35: reducing learning rate of group 0 to 1.9531e-04.
# Epoch: 34, Validation Loss: 4.374, Validation Accuracy: 0.324
# Epoch: 35	Batch: 50	Avg-Loss: 0.0393	Training Accuracy : 0.9872
# Epoch: 35	Batch: 100	Avg-Loss: 0.0395	Training Accuracy : 0.9852
# Epoch: 35	Batch: 150	Avg-Loss: 0.0387	Training Accuracy : 0.9873
# Epoch: 35	Batch: 200	Avg-Loss: 0.0297	Training Accuracy : 0.9916
# Epoch: 35	Batch: 250	Avg-Loss: 0.0358	Training Accuracy : 0.9895
# Epoch: 35	Batch: 300	Avg-Loss: 0.0412	Training Accuracy : 0.9862
# Epoch: 35	Batch: 350	Avg-Loss: 0.0358	Training Accuracy : 0.9892
# Epoch: 35	Batch: 400	Avg-Loss: 0.0351	Training Accuracy : 0.9892
# Epoch: 35	Batch: 450	Avg-Loss: 0.0430	Training Accuracy : 0.9852
# Epoch: 35	Batch: 500	Avg-Loss: 0.0334	Training Accuracy : 0.9897
# Epoch: 35	Batch: 550	Avg-Loss: 0.0364	Training Accuracy : 0.9880
# Epoch: 35	Batch: 600	Avg-Loss: 0.0383	Training Accuracy : 0.9873
# Epoch: 35	Batch: 650	Avg-Loss: 0.0346	Training Accuracy : 0.9895
# Epoch: 35, Validation Loss: 4.456, Validation Accuracy: 0.327
# Epoch: 36	Batch: 50	Avg-Loss: 0.0383	Training Accuracy : 0.9875
# Epoch: 36	Batch: 100	Avg-Loss: 0.0381	Training Accuracy : 0.9875
# Epoch: 36	Batch: 150	Avg-Loss: 0.0375	Training Accuracy : 0.9881
# Epoch: 36	Batch: 200	Avg-Loss: 0.0378	Training Accuracy : 0.9880
# Epoch: 36	Batch: 250	Avg-Loss: 0.0380	Training Accuracy : 0.9875
# Epoch: 36	Batch: 300	Avg-Loss: 0.0376	Training Accuracy : 0.9875
# Epoch: 36	Batch: 350	Avg-Loss: 0.0338	Training Accuracy : 0.9894
# Epoch: 36	Batch: 400	Avg-Loss: 0.0369	Training Accuracy : 0.9877
# Epoch: 36	Batch: 450	Avg-Loss: 0.0353	Training Accuracy : 0.9894
# Epoch: 36	Batch: 500	Avg-Loss: 0.0317	Training Accuracy : 0.9911
# Epoch: 36	Batch: 550	Avg-Loss: 0.0398	Training Accuracy : 0.9872
# Epoch: 36	Batch: 600	Avg-Loss: 0.0407	Training Accuracy : 0.9877
# Epoch: 36	Batch: 650	Avg-Loss: 0.0376	Training Accuracy : 0.9878
# Epoch: 36, Validation Loss: 4.428, Validation Accuracy: 0.325
# Epoch: 37	Batch: 50	Avg-Loss: 0.0360	Training Accuracy : 0.9884
# Epoch: 37	Batch: 100	Avg-Loss: 0.0356	Training Accuracy : 0.9878
# Epoch: 37	Batch: 150	Avg-Loss: 0.0310	Training Accuracy : 0.9914
# Epoch: 37	Batch: 200	Avg-Loss: 0.0377	Training Accuracy : 0.9878
# Epoch: 37	Batch: 250	Avg-Loss: 0.0330	Training Accuracy : 0.9895
# Epoch: 37	Batch: 300	Avg-Loss: 0.0314	Training Accuracy : 0.9909
# Epoch: 37	Batch: 350	Avg-Loss: 0.0364	Training Accuracy : 0.9880
# Epoch: 37	Batch: 400	Avg-Loss: 0.0388	Training Accuracy : 0.9888
# Epoch: 37	Batch: 450	Avg-Loss: 0.0320	Training Accuracy : 0.9912
# Epoch: 37	Batch: 500	Avg-Loss: 0.0342	Training Accuracy : 0.9888
# Epoch: 37	Batch: 550	Avg-Loss: 0.0384	Training Accuracy : 0.9884
# Epoch: 37	Batch: 600	Avg-Loss: 0.0335	Training Accuracy : 0.9886
# Epoch: 37	Batch: 650	Avg-Loss: 0.0333	Training Accuracy : 0.9898
# Epoch    38: reducing learning rate of group 0 to 9.7656e-05.
# Epoch: 37, Validation Loss: 4.825, Validation Accuracy: 0.322
# Epoch: 38	Batch: 50	Avg-Loss: 0.0300	Training Accuracy : 0.9920
# Epoch: 38	Batch: 100	Avg-Loss: 0.0360	Training Accuracy : 0.9902
# Epoch: 38	Batch: 150	Avg-Loss: 0.0317	Training Accuracy : 0.9897
# Epoch: 38	Batch: 200	Avg-Loss: 0.0335	Training Accuracy : 0.9895
# Epoch: 38	Batch: 250	Avg-Loss: 0.0349	Training Accuracy : 0.9883
# Epoch: 38	Batch: 300	Avg-Loss: 0.0323	Training Accuracy : 0.9902
# Epoch: 38	Batch: 350	Avg-Loss: 0.0345	Training Accuracy : 0.9891
# Epoch: 38	Batch: 400	Avg-Loss: 0.0423	Training Accuracy : 0.9866
# Epoch: 38	Batch: 450	Avg-Loss: 0.0329	Training Accuracy : 0.9897
# Epoch: 38	Batch: 500	Avg-Loss: 0.0329	Training Accuracy : 0.9911
# Epoch: 38	Batch: 550	Avg-Loss: 0.0340	Training Accuracy : 0.9892
# Epoch: 38	Batch: 600	Avg-Loss: 0.0356	Training Accuracy : 0.9889
# Epoch: 38	Batch: 650	Avg-Loss: 0.0348	Training Accuracy : 0.9889
# Epoch: 38, Validation Loss: 4.712, Validation Accuracy: 0.324
# Epoch: 39	Batch: 50	Avg-Loss: 0.0305	Training Accuracy : 0.9911
# Epoch: 39	Batch: 100	Avg-Loss: 0.0356	Training Accuracy : 0.9897
# Epoch: 39	Batch: 150	Avg-Loss: 0.0295	Training Accuracy : 0.9905
# Epoch: 39	Batch: 200	Avg-Loss: 0.0371	Training Accuracy : 0.9867
# Epoch: 39	Batch: 250	Avg-Loss: 0.0303	Training Accuracy : 0.9895
# Epoch: 39	Batch: 300	Avg-Loss: 0.0348	Training Accuracy : 0.9891
# Epoch: 39	Batch: 350	Avg-Loss: 0.0323	Training Accuracy : 0.9894
# Epoch: 39	Batch: 400	Avg-Loss: 0.0328	Training Accuracy : 0.9909
# Epoch: 39	Batch: 450	Avg-Loss: 0.0331	Training Accuracy : 0.9897
# Epoch: 39	Batch: 500	Avg-Loss: 0.0321	Training Accuracy : 0.9897
# Epoch: 39	Batch: 550	Avg-Loss: 0.0329	Training Accuracy : 0.9911
# Epoch: 39	Batch: 600	Avg-Loss: 0.0337	Training Accuracy : 0.9903
# Epoch: 39	Batch: 650	Avg-Loss: 0.0343	Training Accuracy : 0.9897
# Epoch: 39, Validation Loss: 4.694, Validation Accuracy: 0.321
# Epoch: 40	Batch: 50	Avg-Loss: 0.0337	Training Accuracy : 0.9892
# Epoch: 40	Batch: 100	Avg-Loss: 0.0326	Training Accuracy : 0.9897
# Epoch: 40	Batch: 150	Avg-Loss: 0.0348	Training Accuracy : 0.9902
# Epoch: 40	Batch: 200	Avg-Loss: 0.0333	Training Accuracy : 0.9892
# Epoch: 40	Batch: 250	Avg-Loss: 0.0334	Training Accuracy : 0.9889
# Epoch: 40	Batch: 300	Avg-Loss: 0.0323	Training Accuracy : 0.9902
# Epoch: 40	Batch: 350	Avg-Loss: 0.0311	Training Accuracy : 0.9912
# Epoch: 40	Batch: 400	Avg-Loss: 0.0310	Training Accuracy : 0.9905
# Epoch: 40	Batch: 450	Avg-Loss: 0.0352	Training Accuracy : 0.9883
# Epoch: 40	Batch: 500	Avg-Loss: 0.0290	Training Accuracy : 0.9911
# Epoch: 40	Batch: 550	Avg-Loss: 0.0341	Training Accuracy : 0.9889
# Epoch: 40	Batch: 600	Avg-Loss: 0.0305	Training Accuracy : 0.9909
# Epoch: 40	Batch: 650	Avg-Loss: 0.0294	Training Accuracy : 0.9911
# Epoch    41: reducing learning rate of group 0 to 4.8828e-05.
# Epoch: 40, Validation Loss: 4.637, Validation Accuracy: 0.325
# Epoch: 41	Batch: 50	Avg-Loss: 0.0331	Training Accuracy : 0.9898
# Epoch: 41	Batch: 100	Avg-Loss: 0.0257	Training Accuracy : 0.9925
# Epoch: 41	Batch: 150	Avg-Loss: 0.0324	Training Accuracy : 0.9914
# Epoch: 41	Batch: 200	Avg-Loss: 0.0348	Training Accuracy : 0.9892
# Epoch: 41	Batch: 250	Avg-Loss: 0.0352	Training Accuracy : 0.9905
# Epoch: 41	Batch: 300	Avg-Loss: 0.0280	Training Accuracy : 0.9916
# Epoch: 41	Batch: 350	Avg-Loss: 0.0321	Training Accuracy : 0.9911
# Epoch: 41	Batch: 400	Avg-Loss: 0.0326	Training Accuracy : 0.9902
# Epoch: 41	Batch: 450	Avg-Loss: 0.0320	Training Accuracy : 0.9905
# Epoch: 41	Batch: 500	Avg-Loss: 0.0252	Training Accuracy : 0.9923
# Epoch: 41	Batch: 550	Avg-Loss: 0.0328	Training Accuracy : 0.9895
# Epoch: 41	Batch: 600	Avg-Loss: 0.0317	Training Accuracy : 0.9905
# Epoch: 41	Batch: 650	Avg-Loss: 0.0348	Training Accuracy : 0.9892
# Epoch: 41, Validation Loss: 4.350, Validation Accuracy: 0.323
# Epoch: 42	Batch: 50	Avg-Loss: 0.0315	Training Accuracy : 0.9902
# Epoch: 42	Batch: 100	Avg-Loss: 0.0295	Training Accuracy : 0.9916
# Epoch: 42	Batch: 150	Avg-Loss: 0.0339	Training Accuracy : 0.9897
# Epoch: 42	Batch: 200	Avg-Loss: 0.0330	Training Accuracy : 0.9895
# Epoch: 42	Batch: 250	Avg-Loss: 0.0309	Training Accuracy : 0.9891
# Epoch: 42	Batch: 300	Avg-Loss: 0.0317	Training Accuracy : 0.9902
# Epoch: 42	Batch: 350	Avg-Loss: 0.0293	Training Accuracy : 0.9905
# Epoch: 42	Batch: 400	Avg-Loss: 0.0306	Training Accuracy : 0.9916
# Epoch: 42	Batch: 450	Avg-Loss: 0.0277	Training Accuracy : 0.9923
# Epoch: 42	Batch: 500	Avg-Loss: 0.0298	Training Accuracy : 0.9906
# Epoch: 42	Batch: 550	Avg-Loss: 0.0309	Training Accuracy : 0.9909
# Epoch: 42	Batch: 600	Avg-Loss: 0.0328	Training Accuracy : 0.9911
# Epoch: 42	Batch: 650	Avg-Loss: 0.0336	Training Accuracy : 0.9900
# Epoch: 42, Validation Loss: 4.531, Validation Accuracy: 0.324
# Epoch: 43	Batch: 50	Avg-Loss: 0.0392	Training Accuracy : 0.9875
# Epoch: 43	Batch: 100	Avg-Loss: 0.0300	Training Accuracy : 0.9912
# Epoch: 43	Batch: 150	Avg-Loss: 0.0301	Training Accuracy : 0.9919
# Epoch: 43	Batch: 200	Avg-Loss: 0.0272	Training Accuracy : 0.9927
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-5a23c12fa362> in <module>()
#       9         optimizer.zero_grad()
#      10         x.requires_grad_()
# ---> 11         x, y = x.to(device), y.to(device)
#      12         outputs = network(x)
#      13         num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
#
# KeyboardInterrupt:

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_3+1/best_model_15.pt"))
network = network.to(device)

# %%
network.eval()
num_correct = 0
for x, y in tqdm(test_loader):
  x, y = x.to(device), y.to(device)
  outputs = network(x)
  num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

test_acc = num_correct / len(test_set)
print(test_acc)
# Out:
# 100%|██████████| 142/142 [02:13<00:00,  1.06it/s]
# 0.28952032790517335

# %%
print(test_acc)
# Out:
# 0.30879583471806804
