# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/dl_project/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("3+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149932.jpg', 'frame_149907.jpg', 'fram...      7
# 1      ('frame_149933.jpg', 'frame_152295.jpg', 'fram...     10
# 2      ('frame_149903.jpg', 'frame_152323.jpg', 'fram...      4
# 3      ('frame_152463.jpg', 'frame_149941.jpg', 'fram...     22
# 4      ('frame_149930.jpg', 'frame_152761.jpg', 'fram...     11
# ...                                                  ...    ...
# 18049  ('frame_174654.jpg', 'frame_180809.jpg', 'fram...     17
# 18050  ('frame_174580.jpg', 'frame_174619.jpg', 'fram...      3
# 18051  ('frame_180890.jpg', 'frame_174567.jpg', 'fram...     19
# 18052  ('frame_174586.jpg', 'frame_174612.jpg', 'fram...      1
# 18053  ('frame_181333.jpg', 'frame_174654.jpg', 'fram...     23
#
# [18054 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            images.extend(img)
        x = torch.stack(images)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([12, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
batch_size = 64

# training data
train_set = MyDataSet(train_data)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_images, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding*num_images, num_classes))


    def forward(self, x):
      x1 = x[:, 0:3, :, :]
      x2 = x[:, 3:6, :, :]
      x3 = x[:, 6:9, :, :]
      x4 = x[:, 9:12, :, :]

      out1 = self.cnn(x1)
      out2 = self.cnn(x2)
      out3 = self.cnn(x3)
      out4 = self.cnn(x4)

      out = torch.cat([out1, out2, out3, out4], axis=1)
      logits = self.mlp(out)
      return logits

# %%
numEpochs = 100
in_features = 3 # TODO: change RGB channels according to num of frames
embedding = 128

learningRate = 0.01
weightDecay = 1e-4

num_images = 4
num_classes = 24

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_images, num_classes)
#network.load_state_dict(torch.load("model_checkpoints/resnet34/lr_0.1-2/model_2.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        # x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_3+1_base/best_model_" + str(epoch) + ".pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 0	Batch: 50	Avg-Loss: 3.2746	Training Accuracy : 0.0406
# Epoch: 0	Batch: 100	Avg-Loss: 3.2400	Training Accuracy : 0.0375
# Epoch: 0	Batch: 150	Avg-Loss: 3.2259	Training Accuracy : 0.0403
# Epoch: 0	Batch: 200	Avg-Loss: 3.2082	Training Accuracy : 0.0384
# Epoch: 0	Batch: 250	Avg-Loss: 3.2013	Training Accuracy : 0.0466
# Epoch: 0	Batch: 300	Avg-Loss: 3.1989	Training Accuracy : 0.0484
# Epoch: 0	Batch: 350	Avg-Loss: 3.1919	Training Accuracy : 0.0456
# Epoch: 0	Batch: 400	Avg-Loss: 3.1935	Training Accuracy : 0.0462
# Epoch: 0	Batch: 450	Avg-Loss: 3.1926	Training Accuracy : 0.0409
# Epoch: 0	Batch: 500	Avg-Loss: 3.1882	Training Accuracy : 0.0437
# Epoch: 0	Batch: 550	Avg-Loss: 3.1886	Training Accuracy : 0.0500
# Epoch: 0	Batch: 600	Avg-Loss: 3.1829	Training Accuracy : 0.0497
# Epoch: 0	Batch: 650	Avg-Loss: 3.1880	Training Accuracy : 0.0425
# Epoch: 0	Batch: 700	Avg-Loss: 3.1780	Training Accuracy : 0.0563
# Epoch: 0	Batch: 750	Avg-Loss: 3.1832	Training Accuracy : 0.0475
# Epoch: 0	Batch: 800	Avg-Loss: 3.1860	Training Accuracy : 0.0459
# Epoch: 0	Batch: 850	Avg-Loss: 3.1812	Training Accuracy : 0.0491
# Epoch: 0	Batch: 900	Avg-Loss: 3.1826	Training Accuracy : 0.0459
# Epoch: 0	Batch: 950	Avg-Loss: 3.1780	Training Accuracy : 0.0544
# Epoch: 0	Batch: 1000	Avg-Loss: 3.1739	Training Accuracy : 0.0575
# Epoch: 0	Batch: 1050	Avg-Loss: 3.1552	Training Accuracy : 0.0803
# Epoch: 0	Batch: 1100	Avg-Loss: 3.1652	Training Accuracy : 0.0781
# Epoch: 0	Batch: 1150	Avg-Loss: 3.1605	Training Accuracy : 0.0756
# Epoch: 0	Batch: 1200	Avg-Loss: 3.1445	Training Accuracy : 0.0772
# Epoch: 0	Batch: 1250	Avg-Loss: 3.1360	Training Accuracy : 0.0869
# Epoch: 0	Batch: 1300	Avg-Loss: 3.1139	Training Accuracy : 0.0884
# Epoch: 0, Validation Loss: 3.355, Validation Accuracy: 0.062
# Epoch: 1	Batch: 50	Avg-Loss: 3.0869	Training Accuracy : 0.0909
# Epoch: 1	Batch: 100	Avg-Loss: 2.9856	Training Accuracy : 0.1228
# Epoch: 1	Batch: 150	Avg-Loss: 2.9104	Training Accuracy : 0.1263
# Epoch: 1	Batch: 200	Avg-Loss: 2.8179	Training Accuracy : 0.1559
# Epoch: 1	Batch: 250	Avg-Loss: 2.7587	Training Accuracy : 0.1609
# Epoch: 1	Batch: 300	Avg-Loss: 2.6467	Training Accuracy : 0.1834
# Epoch: 1	Batch: 350	Avg-Loss: 2.5291	Training Accuracy : 0.2009
# Epoch: 1	Batch: 400	Avg-Loss: 2.4588	Training Accuracy : 0.2197
# Epoch: 1	Batch: 450	Avg-Loss: 2.4209	Training Accuracy : 0.2338
# Epoch: 1	Batch: 500	Avg-Loss: 2.2935	Training Accuracy : 0.2631
# Epoch: 1	Batch: 550	Avg-Loss: 2.2543	Training Accuracy : 0.2600
# Epoch: 1	Batch: 600	Avg-Loss: 2.1539	Training Accuracy : 0.2966
# Epoch: 1	Batch: 650	Avg-Loss: 2.0612	Training Accuracy : 0.3059
# Epoch: 1	Batch: 700	Avg-Loss: 1.9836	Training Accuracy : 0.3431
# Epoch: 1	Batch: 750	Avg-Loss: 1.8891	Training Accuracy : 0.3572
# Epoch: 1	Batch: 800	Avg-Loss: 1.9163	Training Accuracy : 0.3503
# Epoch: 1	Batch: 850	Avg-Loss: 1.8335	Training Accuracy : 0.3800
# Epoch: 1	Batch: 900	Avg-Loss: 1.7979	Training Accuracy : 0.3841
# Epoch: 1	Batch: 950	Avg-Loss: 1.7062	Training Accuracy : 0.4203
# Epoch: 1	Batch: 1000	Avg-Loss: 1.6901	Training Accuracy : 0.4156
# Epoch: 1	Batch: 1050	Avg-Loss: 1.6648	Training Accuracy : 0.4322
# Epoch: 1	Batch: 1100	Avg-Loss: 1.5893	Training Accuracy : 0.4531
# Epoch: 1	Batch: 1150	Avg-Loss: 1.5011	Training Accuracy : 0.4706
# Epoch: 1	Batch: 1200	Avg-Loss: 1.4675	Training Accuracy : 0.4822
# Epoch: 1	Batch: 1250	Avg-Loss: 1.4966	Training Accuracy : 0.4822
# Epoch: 1	Batch: 1300	Avg-Loss: 1.4671	Training Accuracy : 0.4881
# Epoch: 1, Validation Loss: 4.782, Validation Accuracy: 0.090
# Epoch: 2	Batch: 50	Avg-Loss: 1.4017	Training Accuracy : 0.5244
# Epoch: 2	Batch: 100	Avg-Loss: 1.3468	Training Accuracy : 0.5350
# Epoch: 2	Batch: 150	Avg-Loss: 1.2990	Training Accuracy : 0.5459
# Epoch: 2	Batch: 200	Avg-Loss: 1.3080	Training Accuracy : 0.5456
# Epoch: 2	Batch: 250	Avg-Loss: 1.2326	Training Accuracy : 0.5641
# Epoch: 2	Batch: 300	Avg-Loss: 1.1929	Training Accuracy : 0.5684
# Epoch: 2	Batch: 350	Avg-Loss: 1.1856	Training Accuracy : 0.5750
# Epoch: 2	Batch: 400	Avg-Loss: 1.1434	Training Accuracy : 0.5825
# Epoch: 2	Batch: 450	Avg-Loss: 1.1365	Training Accuracy : 0.5816
# Epoch: 2	Batch: 500	Avg-Loss: 1.0853	Training Accuracy : 0.6072
# Epoch: 2	Batch: 550	Avg-Loss: 1.0879	Training Accuracy : 0.6019
# Epoch: 2	Batch: 600	Avg-Loss: 1.0699	Training Accuracy : 0.6153
# Epoch: 2	Batch: 650	Avg-Loss: 1.0365	Training Accuracy : 0.6434
# Epoch: 2	Batch: 700	Avg-Loss: 1.0739	Training Accuracy : 0.6150
# Epoch: 2	Batch: 750	Avg-Loss: 1.0086	Training Accuracy : 0.6262
# Epoch: 2	Batch: 800	Avg-Loss: 1.0068	Training Accuracy : 0.6297
# Epoch: 2	Batch: 850	Avg-Loss: 0.9502	Training Accuracy : 0.6469
# Epoch: 2	Batch: 900	Avg-Loss: 0.9705	Training Accuracy : 0.6450
# Epoch: 2	Batch: 950	Avg-Loss: 0.9255	Training Accuracy : 0.6631
# Epoch: 2	Batch: 1000	Avg-Loss: 0.8682	Training Accuracy : 0.6806
# Epoch: 2	Batch: 1050	Avg-Loss: 0.9067	Training Accuracy : 0.6725
# Epoch: 2	Batch: 1100	Avg-Loss: 0.8605	Training Accuracy : 0.6884
# Epoch: 2	Batch: 1150	Avg-Loss: 0.8908	Training Accuracy : 0.6687
# Epoch: 2	Batch: 1200	Avg-Loss: 0.8754	Training Accuracy : 0.6697
# Epoch: 2	Batch: 1250	Avg-Loss: 0.8485	Training Accuracy : 0.6825
# Epoch: 2	Batch: 1300	Avg-Loss: 0.8257	Training Accuracy : 0.6872
# Epoch: 2, Validation Loss: 6.272, Validation Accuracy: 0.073
# Epoch: 3	Batch: 50	Avg-Loss: 0.8055	Training Accuracy : 0.7113
# Epoch: 3	Batch: 100	Avg-Loss: 0.8309	Training Accuracy : 0.6953
# Epoch: 3	Batch: 150	Avg-Loss: 0.7836	Training Accuracy : 0.7150
# Epoch: 3	Batch: 200	Avg-Loss: 0.7575	Training Accuracy : 0.7312
# Epoch: 3	Batch: 250	Avg-Loss: 0.8188	Training Accuracy : 0.7059
# Epoch: 3	Batch: 300	Avg-Loss: 0.7953	Training Accuracy : 0.7047
# Epoch: 3	Batch: 350	Avg-Loss: 0.7784	Training Accuracy : 0.7212
# Epoch: 3	Batch: 400	Avg-Loss: 0.7476	Training Accuracy : 0.7231
# Epoch: 3	Batch: 450	Avg-Loss: 0.7830	Training Accuracy : 0.7081
# Epoch: 3	Batch: 500	Avg-Loss: 0.7035	Training Accuracy : 0.7381
# Epoch: 3	Batch: 550	Avg-Loss: 0.7039	Training Accuracy : 0.7416
# Epoch: 3	Batch: 600	Avg-Loss: 0.6768	Training Accuracy : 0.7534
# Epoch: 3	Batch: 650	Avg-Loss: 0.7042	Training Accuracy : 0.7434
# Epoch: 3	Batch: 700	Avg-Loss: 0.6800	Training Accuracy : 0.7519
# Epoch: 3	Batch: 750	Avg-Loss: 0.6567	Training Accuracy : 0.7603
# Epoch: 3	Batch: 800	Avg-Loss: 0.6408	Training Accuracy : 0.7606
# Epoch: 3	Batch: 850	Avg-Loss: 0.6533	Training Accuracy : 0.7566
# Epoch: 3	Batch: 900	Avg-Loss: 0.6435	Training Accuracy : 0.7547
# Epoch: 3	Batch: 950	Avg-Loss: 0.6235	Training Accuracy : 0.7691
# Epoch: 3	Batch: 1000	Avg-Loss: 0.6321	Training Accuracy : 0.7591
# Epoch: 3	Batch: 1050	Avg-Loss: 0.6347	Training Accuracy : 0.7688
# Epoch: 3	Batch: 1100	Avg-Loss: 0.5959	Training Accuracy : 0.7797
# Epoch: 3	Batch: 1150	Avg-Loss: 0.6301	Training Accuracy : 0.7703
# Epoch: 3	Batch: 1200	Avg-Loss: 0.5961	Training Accuracy : 0.7784
# Epoch: 3	Batch: 1250	Avg-Loss: 0.5758	Training Accuracy : 0.7906
# Epoch: 3	Batch: 1300	Avg-Loss: 0.5790	Training Accuracy : 0.7984
# Epoch     4: reducing learning rate of group 0 to 5.0000e-03.
# Epoch: 3, Validation Loss: 8.682, Validation Accuracy: 0.085
# Epoch: 4	Batch: 50	Avg-Loss: 0.5144	Training Accuracy : 0.8069
# Epoch: 4	Batch: 100	Avg-Loss: 0.4241	Training Accuracy : 0.8372
# Epoch: 4	Batch: 150	Avg-Loss: 0.4105	Training Accuracy : 0.8500
# Epoch: 4	Batch: 200	Avg-Loss: 0.3792	Training Accuracy : 0.8588
# Epoch: 4	Batch: 250	Avg-Loss: 0.3615	Training Accuracy : 0.8650
# Epoch: 4	Batch: 300	Avg-Loss: 0.3811	Training Accuracy : 0.8541
# Epoch: 4	Batch: 350	Avg-Loss: 0.3521	Training Accuracy : 0.8622
# Epoch: 4	Batch: 400	Avg-Loss: 0.3568	Training Accuracy : 0.8641
# Epoch: 4	Batch: 450	Avg-Loss: 0.3627	Training Accuracy : 0.8609
# Epoch: 4	Batch: 500	Avg-Loss: 0.3214	Training Accuracy : 0.8728
# Epoch: 4	Batch: 550	Avg-Loss: 0.3487	Training Accuracy : 0.8681
# Epoch: 4	Batch: 600	Avg-Loss: 0.3682	Training Accuracy : 0.8650
# Epoch: 4	Batch: 650	Avg-Loss: 0.3414	Training Accuracy : 0.8681
# Epoch: 4	Batch: 700	Avg-Loss: 0.3258	Training Accuracy : 0.8684
# Epoch: 4	Batch: 750	Avg-Loss: 0.3195	Training Accuracy : 0.8762
# Epoch: 4	Batch: 800	Avg-Loss: 0.3426	Training Accuracy : 0.8734
# Epoch: 4	Batch: 850	Avg-Loss: 0.3393	Training Accuracy : 0.8781
# Epoch: 4	Batch: 900	Avg-Loss: 0.3166	Training Accuracy : 0.8825
# Epoch: 4	Batch: 950	Avg-Loss: 0.3274	Training Accuracy : 0.8694
# Epoch: 4	Batch: 1000	Avg-Loss: 0.3115	Training Accuracy : 0.8753
# Epoch: 4	Batch: 1050	Avg-Loss: 0.2923	Training Accuracy : 0.8853
# Epoch: 4	Batch: 1100	Avg-Loss: 0.3188	Training Accuracy : 0.8741
# Epoch: 4	Batch: 1150	Avg-Loss: 0.2997	Training Accuracy : 0.8897
# Epoch: 4	Batch: 1200	Avg-Loss: 0.2997	Training Accuracy : 0.8800
# Epoch: 4	Batch: 1250	Avg-Loss: 0.3062	Training Accuracy : 0.8850
# Epoch: 4	Batch: 1300	Avg-Loss: 0.3096	Training Accuracy : 0.8831
# Epoch: 4, Validation Loss: 10.369, Validation Accuracy: 0.075
# Epoch: 5	Batch: 50	Avg-Loss: 0.2932	Training Accuracy : 0.8797
# Epoch: 5	Batch: 100	Avg-Loss: 0.3010	Training Accuracy : 0.8906
# Epoch: 5	Batch: 150	Avg-Loss: 0.2841	Training Accuracy : 0.8838
# Epoch: 5	Batch: 200	Avg-Loss: 0.3026	Training Accuracy : 0.8812
# Epoch: 5	Batch: 250	Avg-Loss: 0.2975	Training Accuracy : 0.8831
# Epoch: 5	Batch: 300	Avg-Loss: 0.2977	Training Accuracy : 0.8834
# Epoch: 5	Batch: 350	Avg-Loss: 0.2781	Training Accuracy : 0.8966
# Epoch: 5	Batch: 400	Avg-Loss: 0.2804	Training Accuracy : 0.8888
# Epoch: 5	Batch: 450	Avg-Loss: 0.2813	Training Accuracy : 0.8944
# Epoch: 5	Batch: 500	Avg-Loss: 0.2812	Training Accuracy : 0.8884
# Epoch: 5	Batch: 550	Avg-Loss: 0.2546	Training Accuracy : 0.9066
# Epoch: 5	Batch: 600	Avg-Loss: 0.2582	Training Accuracy : 0.9016
# Epoch: 5	Batch: 650	Avg-Loss: 0.2592	Training Accuracy : 0.9019
# Epoch: 5	Batch: 700	Avg-Loss: 0.2764	Training Accuracy : 0.8919
# Epoch: 5	Batch: 750	Avg-Loss: 0.2692	Training Accuracy : 0.8906
# Epoch: 5	Batch: 800	Avg-Loss: 0.2723	Training Accuracy : 0.8928
# Epoch: 5	Batch: 850	Avg-Loss: 0.2771	Training Accuracy : 0.8959
# Epoch: 5	Batch: 900	Avg-Loss: 0.2636	Training Accuracy : 0.9019
# Epoch: 5	Batch: 950	Avg-Loss: 0.2718	Training Accuracy : 0.8994
# Epoch: 5	Batch: 1000	Avg-Loss: 0.2554	Training Accuracy : 0.9041
# Epoch: 5	Batch: 1050	Avg-Loss: 0.2868	Training Accuracy : 0.8919
# Epoch: 5	Batch: 1100	Avg-Loss: 0.2711	Training Accuracy : 0.8938
# Epoch: 5	Batch: 1150	Avg-Loss: 0.2566	Training Accuracy : 0.8997
# Epoch: 5	Batch: 1200	Avg-Loss: 0.2500	Training Accuracy : 0.9053
# Epoch: 5	Batch: 1250	Avg-Loss: 0.2546	Training Accuracy : 0.9028
# Epoch: 5	Batch: 1300	Avg-Loss: 0.2643	Training Accuracy : 0.8975
# Epoch: 5, Validation Loss: 10.744, Validation Accuracy: 0.075
# Epoch: 6	Batch: 50	Avg-Loss: 0.2463	Training Accuracy : 0.9044
# Epoch: 6	Batch: 100	Avg-Loss: 0.2673	Training Accuracy : 0.8975
# Epoch: 6	Batch: 150	Avg-Loss: 0.2518	Training Accuracy : 0.9003
# Epoch: 6	Batch: 200	Avg-Loss: 0.2328	Training Accuracy : 0.9141
# Epoch: 6	Batch: 250	Avg-Loss: 0.2748	Training Accuracy : 0.8975
# Epoch: 6	Batch: 300	Avg-Loss: 0.2172	Training Accuracy : 0.9191
# Epoch: 6	Batch: 350	Avg-Loss: 0.2768	Training Accuracy : 0.8938
# Epoch: 6	Batch: 400	Avg-Loss: 0.2146	Training Accuracy : 0.9166
# Epoch: 6	Batch: 450	Avg-Loss: 0.2410	Training Accuracy : 0.9125
# Epoch: 6	Batch: 500	Avg-Loss: 0.2395	Training Accuracy : 0.9044
# Epoch: 6	Batch: 550	Avg-Loss: 0.2513	Training Accuracy : 0.9078
# Epoch: 6	Batch: 600	Avg-Loss: 0.2385	Training Accuracy : 0.9103
# Epoch: 6	Batch: 650	Avg-Loss: 0.2435	Training Accuracy : 0.9019
# Epoch: 6	Batch: 700	Avg-Loss: 0.2498	Training Accuracy : 0.8928
# Epoch: 6	Batch: 750	Avg-Loss: 0.2463	Training Accuracy : 0.9091
# Epoch: 6	Batch: 800	Avg-Loss: 0.2789	Training Accuracy : 0.8944
# Epoch: 6	Batch: 850	Avg-Loss: 0.2622	Training Accuracy : 0.9022
# Epoch: 6	Batch: 900	Avg-Loss: 0.2618	Training Accuracy : 0.9031
# Epoch: 6	Batch: 950	Avg-Loss: 0.2299	Training Accuracy : 0.9084
# Epoch: 6	Batch: 1000	Avg-Loss: 0.2522	Training Accuracy : 0.9081
# Epoch: 6	Batch: 1050	Avg-Loss: 0.2464	Training Accuracy : 0.9025
# Epoch: 6	Batch: 1100	Avg-Loss: 0.2408	Training Accuracy : 0.9094
# Epoch: 6	Batch: 1150	Avg-Loss: 0.2459	Training Accuracy : 0.9006
# Epoch: 6	Batch: 1200	Avg-Loss: 0.2535	Training Accuracy : 0.9056
# Epoch: 6	Batch: 1250	Avg-Loss: 0.2543	Training Accuracy : 0.9000
# Epoch: 6	Batch: 1300	Avg-Loss: 0.2492	Training Accuracy : 0.9053
# Epoch     7: reducing learning rate of group 0 to 2.5000e-03.
# Epoch: 6, Validation Loss: 11.475, Validation Accuracy: 0.081
# Epoch: 7	Batch: 50	Avg-Loss: 0.2060	Training Accuracy : 0.9197
# Epoch: 7	Batch: 100	Avg-Loss: 0.1779	Training Accuracy : 0.9272
# Epoch: 7	Batch: 150	Avg-Loss: 0.1748	Training Accuracy : 0.9281
# Epoch: 7	Batch: 200	Avg-Loss: 0.1748	Training Accuracy : 0.9297
# Epoch: 7	Batch: 250	Avg-Loss: 0.1710	Training Accuracy : 0.9297
# Epoch: 7	Batch: 300	Avg-Loss: 0.1688	Training Accuracy : 0.9328
# Epoch: 7	Batch: 350	Avg-Loss: 0.1604	Training Accuracy : 0.9372
# Epoch: 7	Batch: 400	Avg-Loss: 0.1697	Training Accuracy : 0.9322
# Epoch: 7	Batch: 450	Avg-Loss: 0.1623	Training Accuracy : 0.9381
# Epoch: 7	Batch: 500	Avg-Loss: 0.1671	Training Accuracy : 0.9309
# Epoch: 7	Batch: 550	Avg-Loss: 0.1684	Training Accuracy : 0.9306
# Epoch: 7	Batch: 600	Avg-Loss: 0.1596	Training Accuracy : 0.9344
# Epoch: 7	Batch: 650	Avg-Loss: 0.1582	Training Accuracy : 0.9344
# Epoch: 7	Batch: 700	Avg-Loss: 0.1660	Training Accuracy : 0.9328
# Epoch: 7	Batch: 750	Avg-Loss: 0.1643	Training Accuracy : 0.9253
# Epoch: 7	Batch: 800	Avg-Loss: 0.1652	Training Accuracy : 0.9313
# Epoch: 7	Batch: 850	Avg-Loss: 0.1462	Training Accuracy : 0.9400
# Epoch: 7	Batch: 900	Avg-Loss: 0.1580	Training Accuracy : 0.9347
# Epoch: 7	Batch: 950	Avg-Loss: 0.1649	Training Accuracy : 0.9300
# Epoch: 7	Batch: 1000	Avg-Loss: 0.1566	Training Accuracy : 0.9363
# Epoch: 7	Batch: 1050	Avg-Loss: 0.1449	Training Accuracy : 0.9416
# Epoch: 7	Batch: 1100	Avg-Loss: 0.1491	Training Accuracy : 0.9434
# Epoch: 7	Batch: 1150	Avg-Loss: 0.1626	Training Accuracy : 0.9337
# Epoch: 7	Batch: 1200	Avg-Loss: 0.1688	Training Accuracy : 0.9331
# Epoch: 7	Batch: 1250	Avg-Loss: 0.1506	Training Accuracy : 0.9381
# Epoch: 7	Batch: 1300	Avg-Loss: 0.1350	Training Accuracy : 0.9416
# Epoch: 7, Validation Loss: 13.148, Validation Accuracy: 0.084
# Epoch: 8	Batch: 50	Avg-Loss: 0.1295	Training Accuracy : 0.9475
# Epoch: 8	Batch: 100	Avg-Loss: 0.1310	Training Accuracy : 0.9466
# Epoch: 8	Batch: 150	Avg-Loss: 0.1404	Training Accuracy : 0.9419
# Epoch: 8	Batch: 200	Avg-Loss: 0.1497	Training Accuracy : 0.9363
# Epoch: 8	Batch: 250	Avg-Loss: 0.1406	Training Accuracy : 0.9484
# Epoch: 8	Batch: 300	Avg-Loss: 0.1142	Training Accuracy : 0.9534
# Epoch: 8	Batch: 350	Avg-Loss: 0.1313	Training Accuracy : 0.9453
# Epoch: 8	Batch: 400	Avg-Loss: 0.1539	Training Accuracy : 0.9409
# Epoch: 8	Batch: 450	Avg-Loss: 0.1301	Training Accuracy : 0.9431
# Epoch: 8	Batch: 500	Avg-Loss: 0.1306	Training Accuracy : 0.9450
# Epoch: 8	Batch: 550	Avg-Loss: 0.1341	Training Accuracy : 0.9472
# Epoch: 8	Batch: 600	Avg-Loss: 0.1358	Training Accuracy : 0.9463
# Epoch: 8	Batch: 650	Avg-Loss: 0.1453	Training Accuracy : 0.9366
# Epoch: 8	Batch: 700	Avg-Loss: 0.1487	Training Accuracy : 0.9409
# Epoch: 8	Batch: 750	Avg-Loss: 0.1378	Training Accuracy : 0.9403
# Epoch: 8	Batch: 800	Avg-Loss: 0.1407	Training Accuracy : 0.9437
# Epoch: 8	Batch: 850	Avg-Loss: 0.1519	Training Accuracy : 0.9363
# Epoch: 8	Batch: 900	Avg-Loss: 0.1280	Training Accuracy : 0.9444
# Epoch: 8	Batch: 950	Avg-Loss: 0.1358	Training Accuracy : 0.9434
# Epoch: 8	Batch: 1000	Avg-Loss: 0.1562	Training Accuracy : 0.9369
# Epoch: 8	Batch: 1050	Avg-Loss: 0.1430	Training Accuracy : 0.9409
# Epoch: 8	Batch: 1100	Avg-Loss: 0.1366	Training Accuracy : 0.9441
# Epoch: 8	Batch: 1150	Avg-Loss: 0.1493	Training Accuracy : 0.9375
# Epoch: 8	Batch: 1200	Avg-Loss: 0.1301	Training Accuracy : 0.9475
# Epoch: 8	Batch: 1250	Avg-Loss: 0.1360	Training Accuracy : 0.9456
# Epoch: 8	Batch: 1300	Avg-Loss: 0.1334	Training Accuracy : 0.9453
# Epoch: 8, Validation Loss: 13.262, Validation Accuracy: 0.081
# Epoch: 9	Batch: 50	Avg-Loss: 0.1247	Training Accuracy : 0.9450
# Epoch: 9	Batch: 100	Avg-Loss: 0.1185	Training Accuracy : 0.9506
# Epoch: 9	Batch: 150	Avg-Loss: 0.1235	Training Accuracy : 0.9516
# Epoch: 9	Batch: 200	Avg-Loss: 0.1157	Training Accuracy : 0.9522
# Epoch: 9	Batch: 250	Avg-Loss: 0.1115	Training Accuracy : 0.9569
# Epoch: 9	Batch: 300	Avg-Loss: 0.1276	Training Accuracy : 0.9497
# Epoch: 9	Batch: 350	Avg-Loss: 0.1411	Training Accuracy : 0.9419
# Epoch: 9	Batch: 400	Avg-Loss: 0.1338	Training Accuracy : 0.9450
# Epoch: 9	Batch: 450	Avg-Loss: 0.1309	Training Accuracy : 0.9487
# Epoch: 9	Batch: 500	Avg-Loss: 0.1206	Training Accuracy : 0.9497
# Epoch: 9	Batch: 550	Avg-Loss: 0.1247	Training Accuracy : 0.9463
# Epoch: 9	Batch: 600	Avg-Loss: 0.1348	Training Accuracy : 0.9437
# Epoch: 9	Batch: 650	Avg-Loss: 0.1299	Training Accuracy : 0.9425
# Epoch: 9	Batch: 700	Avg-Loss: 0.1238	Training Accuracy : 0.9487
# Epoch: 9	Batch: 750	Avg-Loss: 0.1298	Training Accuracy : 0.9475
# Epoch: 9	Batch: 800	Avg-Loss: 0.1277	Training Accuracy : 0.9478
# Epoch: 9	Batch: 850	Avg-Loss: 0.1218	Training Accuracy : 0.9459
# Epoch: 9	Batch: 900	Avg-Loss: 0.1238	Training Accuracy : 0.9466
# Epoch: 9	Batch: 950	Avg-Loss: 0.1494	Training Accuracy : 0.9347
# Epoch: 9	Batch: 1000	Avg-Loss: 0.1378	Training Accuracy : 0.9406
# Epoch: 9	Batch: 1050	Avg-Loss: 0.1391	Training Accuracy : 0.9431
# Epoch: 9	Batch: 1100	Avg-Loss: 0.1125	Training Accuracy : 0.9516
# Epoch: 9	Batch: 1150	Avg-Loss: 0.1289	Training Accuracy : 0.9437
# Epoch: 9	Batch: 1200	Avg-Loss: 0.1173	Training Accuracy : 0.9481
# Epoch: 9	Batch: 1250	Avg-Loss: 0.1144	Training Accuracy : 0.9550
# Epoch: 9	Batch: 1300	Avg-Loss: 0.1257	Training Accuracy : 0.9475
# Epoch    10: reducing learning rate of group 0 to 1.2500e-03.
# Epoch: 9, Validation Loss: 13.702, Validation Accuracy: 0.074
# Epoch: 10	Batch: 50	Avg-Loss: 0.1131	Training Accuracy : 0.9525
# Epoch: 10	Batch: 100	Avg-Loss: 0.1195	Training Accuracy : 0.9506
# Epoch: 10	Batch: 150	Avg-Loss: 0.1022	Training Accuracy : 0.9563
# Epoch: 10	Batch: 200	Avg-Loss: 0.1126	Training Accuracy : 0.9550
# Epoch: 10	Batch: 250	Avg-Loss: 0.1119	Training Accuracy : 0.9522
# Epoch: 10	Batch: 300	Avg-Loss: 0.0990	Training Accuracy : 0.9587
# Epoch: 10	Batch: 350	Avg-Loss: 0.1061	Training Accuracy : 0.9522
# Epoch: 10	Batch: 400	Avg-Loss: 0.0917	Training Accuracy : 0.9619
# Epoch: 10	Batch: 450	Avg-Loss: 0.1036	Training Accuracy : 0.9559
# Epoch: 10	Batch: 500	Avg-Loss: 0.1047	Training Accuracy : 0.9572
# Epoch: 10	Batch: 550	Avg-Loss: 0.1020	Training Accuracy : 0.9547
# Epoch: 10	Batch: 600	Avg-Loss: 0.0963	Training Accuracy : 0.9581
# Epoch: 10	Batch: 650	Avg-Loss: 0.1054	Training Accuracy : 0.9534
# Epoch: 10	Batch: 700	Avg-Loss: 0.1043	Training Accuracy : 0.9591
# Epoch: 10	Batch: 750	Avg-Loss: 0.1049	Training Accuracy : 0.9544
# Epoch: 10	Batch: 800	Avg-Loss: 0.0863	Training Accuracy : 0.9647
# Epoch: 10	Batch: 850	Avg-Loss: 0.1052	Training Accuracy : 0.9528
# Epoch: 10	Batch: 900	Avg-Loss: 0.1066	Training Accuracy : 0.9563
# Epoch: 10	Batch: 950	Avg-Loss: 0.0932	Training Accuracy : 0.9619
# Epoch: 10	Batch: 1000	Avg-Loss: 0.1053	Training Accuracy : 0.9519
# Epoch: 10	Batch: 1050	Avg-Loss: 0.1047	Training Accuracy : 0.9553
# Epoch: 10	Batch: 1100	Avg-Loss: 0.0983	Training Accuracy : 0.9584
# Epoch: 10	Batch: 1150	Avg-Loss: 0.1063	Training Accuracy : 0.9528
# Epoch: 10	Batch: 1200	Avg-Loss: 0.1006	Training Accuracy : 0.9553
# Epoch: 10	Batch: 1250	Avg-Loss: 0.1066	Training Accuracy : 0.9531
# Epoch: 10	Batch: 1300	Avg-Loss: 0.0966	Training Accuracy : 0.9594
# Epoch: 10, Validation Loss: 14.666, Validation Accuracy: 0.074
# Epoch: 11	Batch: 50	Avg-Loss: 0.0939	Training Accuracy : 0.9603
# Epoch: 11	Batch: 100	Avg-Loss: 0.0997	Training Accuracy : 0.9569
# Epoch: 11	Batch: 150	Avg-Loss: 0.0912	Training Accuracy : 0.9628
# Epoch: 11	Batch: 200	Avg-Loss: 0.0986	Training Accuracy : 0.9572
# Epoch: 11	Batch: 250	Avg-Loss: 0.0874	Training Accuracy : 0.9616
# Epoch: 11	Batch: 300	Avg-Loss: 0.0965	Training Accuracy : 0.9597
# Epoch: 11	Batch: 350	Avg-Loss: 0.1033	Training Accuracy : 0.9566
# Epoch: 11	Batch: 400	Avg-Loss: 0.0970	Training Accuracy : 0.9625
# Epoch: 11	Batch: 450	Avg-Loss: 0.0984	Training Accuracy : 0.9581
# Epoch: 11	Batch: 500	Avg-Loss: 0.0852	Training Accuracy : 0.9647
# Epoch: 11	Batch: 550	Avg-Loss: 0.0885	Training Accuracy : 0.9656
# Epoch: 11	Batch: 600	Avg-Loss: 0.0888	Training Accuracy : 0.9606
# Epoch: 11	Batch: 650	Avg-Loss: 0.0953	Training Accuracy : 0.9581
# Epoch: 11	Batch: 700	Avg-Loss: 0.0981	Training Accuracy : 0.9594
# Epoch: 11	Batch: 750	Avg-Loss: 0.0923	Training Accuracy : 0.9628
# Epoch: 11	Batch: 800	Avg-Loss: 0.0994	Training Accuracy : 0.9575
# Epoch: 11	Batch: 850	Avg-Loss: 0.0917	Training Accuracy : 0.9597
# Epoch: 11	Batch: 900	Avg-Loss: 0.1016	Training Accuracy : 0.9609
# Epoch: 11	Batch: 950	Avg-Loss: 0.0999	Training Accuracy : 0.9563
# Epoch: 11	Batch: 1000	Avg-Loss: 0.1036	Training Accuracy : 0.9541
# Epoch: 11	Batch: 1050	Avg-Loss: 0.1070	Training Accuracy : 0.9559
# Epoch: 11	Batch: 1100	Avg-Loss: 0.1025	Training Accuracy : 0.9553
# Epoch: 11	Batch: 1150	Avg-Loss: 0.1026	Training Accuracy : 0.9559
# Epoch: 11	Batch: 1200	Avg-Loss: 0.1015	Training Accuracy : 0.9606
# Epoch: 11	Batch: 1250	Avg-Loss: 0.0968	Training Accuracy : 0.9584
# Epoch: 11	Batch: 1300	Avg-Loss: 0.0957	Training Accuracy : 0.9597
# Epoch: 11, Validation Loss: 15.260, Validation Accuracy: 0.075
# Epoch: 12	Batch: 50	Avg-Loss: 0.0766	Training Accuracy : 0.9691
# Epoch: 12	Batch: 100	Avg-Loss: 0.0907	Training Accuracy : 0.9628
# Epoch: 12	Batch: 150	Avg-Loss: 0.0930	Training Accuracy : 0.9622
# Epoch: 12	Batch: 200	Avg-Loss: 0.0931	Training Accuracy : 0.9609
# Epoch: 12	Batch: 250	Avg-Loss: 0.0920	Training Accuracy : 0.9628
# Epoch: 12	Batch: 300	Avg-Loss: 0.0922	Training Accuracy : 0.9609
# Epoch: 12	Batch: 350	Avg-Loss: 0.1015	Training Accuracy : 0.9594
# Epoch: 12	Batch: 400	Avg-Loss: 0.0830	Training Accuracy : 0.9625
# Epoch: 12	Batch: 450	Avg-Loss: 0.0911	Training Accuracy : 0.9613
# Epoch: 12	Batch: 500	Avg-Loss: 0.0927	Training Accuracy : 0.9566
# Epoch: 12	Batch: 550	Avg-Loss: 0.1017	Training Accuracy : 0.9522
# Epoch: 12	Batch: 600	Avg-Loss: 0.0884	Training Accuracy : 0.9641
# Epoch: 12	Batch: 650	Avg-Loss: 0.0853	Training Accuracy : 0.9622
# Epoch: 12	Batch: 700	Avg-Loss: 0.0927	Training Accuracy : 0.9584
# Epoch: 12	Batch: 750	Avg-Loss: 0.1005	Training Accuracy : 0.9587
# Epoch: 12	Batch: 800	Avg-Loss: 0.0934	Training Accuracy : 0.9609
# Epoch: 12	Batch: 850	Avg-Loss: 0.0937	Training Accuracy : 0.9594
# Epoch: 12	Batch: 900	Avg-Loss: 0.0830	Training Accuracy : 0.9644
# Epoch: 12	Batch: 950	Avg-Loss: 0.0949	Training Accuracy : 0.9581
# Epoch: 12	Batch: 1000	Avg-Loss: 0.0868	Training Accuracy : 0.9641
# Epoch: 12	Batch: 1050	Avg-Loss: 0.0925	Training Accuracy : 0.9575
# Epoch: 12	Batch: 1100	Avg-Loss: 0.0920	Training Accuracy : 0.9616
# Epoch: 12	Batch: 1150	Avg-Loss: 0.0911	Training Accuracy : 0.9606
# Epoch: 12	Batch: 1200	Avg-Loss: 0.0947	Training Accuracy : 0.9625
# Epoch: 12	Batch: 1250	Avg-Loss: 0.0929	Training Accuracy : 0.9616
# Epoch: 12	Batch: 1300	Avg-Loss: 0.0982	Training Accuracy : 0.9575
# Epoch    13: reducing learning rate of group 0 to 6.2500e-04.
# Epoch: 12, Validation Loss: 15.142, Validation Accuracy: 0.081
# Epoch: 13	Batch: 50	Avg-Loss: 0.0714	Training Accuracy : 0.9694
# Epoch: 13	Batch: 100	Avg-Loss: 0.0855	Training Accuracy : 0.9622
# Epoch: 13	Batch: 150	Avg-Loss: 0.0822	Training Accuracy : 0.9669
# Epoch: 13	Batch: 200	Avg-Loss: 0.0753	Training Accuracy : 0.9675
# Epoch: 13	Batch: 250	Avg-Loss: 0.0793	Training Accuracy : 0.9675
# Epoch: 13	Batch: 300	Avg-Loss: 0.0761	Training Accuracy : 0.9656
# Epoch: 13	Batch: 350	Avg-Loss: 0.0797	Training Accuracy : 0.9647
# Epoch: 13	Batch: 400	Avg-Loss: 0.0838	Training Accuracy : 0.9650
# Epoch: 13	Batch: 450	Avg-Loss: 0.0780	Training Accuracy : 0.9688
# Epoch: 13	Batch: 500	Avg-Loss: 0.0828	Training Accuracy : 0.9666
# Epoch: 13	Batch: 550	Avg-Loss: 0.0861	Training Accuracy : 0.9628
# Epoch: 13	Batch: 600	Avg-Loss: 0.0774	Training Accuracy : 0.9672
# Epoch: 13	Batch: 650	Avg-Loss: 0.0781	Training Accuracy : 0.9656
# Epoch: 13	Batch: 700	Avg-Loss: 0.0846	Training Accuracy : 0.9625
# Epoch: 13	Batch: 750	Avg-Loss: 0.0825	Training Accuracy : 0.9647
# Epoch: 13	Batch: 800	Avg-Loss: 0.0839	Training Accuracy : 0.9619
# Epoch: 13	Batch: 850	Avg-Loss: 0.0935	Training Accuracy : 0.9628
# Epoch: 13	Batch: 900	Avg-Loss: 0.0769	Training Accuracy : 0.9653
# Epoch: 13	Batch: 950	Avg-Loss: 0.0809	Training Accuracy : 0.9653
# Epoch: 13	Batch: 1000	Avg-Loss: 0.0787	Training Accuracy : 0.9684
# Epoch: 13	Batch: 1050	Avg-Loss: 0.0793	Training Accuracy : 0.9672
# Epoch: 13	Batch: 1100	Avg-Loss: 0.0868	Training Accuracy : 0.9600
# Epoch: 13	Batch: 1150	Avg-Loss: 0.0805	Training Accuracy : 0.9634
# Epoch: 13	Batch: 1200	Avg-Loss: 0.0862	Training Accuracy : 0.9609
# Epoch: 13	Batch: 1250	Avg-Loss: 0.0788	Training Accuracy : 0.9659
# Epoch: 13	Batch: 1300	Avg-Loss: 0.0795	Training Accuracy : 0.9659
# Epoch: 13, Validation Loss: 16.079, Validation Accuracy: 0.080
# Epoch: 14	Batch: 50	Avg-Loss: 0.0765	Training Accuracy : 0.9684
# Epoch: 14	Batch: 100	Avg-Loss: 0.0761	Training Accuracy : 0.9700
# Epoch: 14	Batch: 150	Avg-Loss: 0.0735	Training Accuracy : 0.9691
# Epoch: 14	Batch: 200	Avg-Loss: 0.0698	Training Accuracy : 0.9725
# Epoch: 14	Batch: 250	Avg-Loss: 0.0771	Training Accuracy : 0.9691
# Epoch: 14	Batch: 300	Avg-Loss: 0.0754	Training Accuracy : 0.9681
# Epoch: 14	Batch: 350	Avg-Loss: 0.0827	Training Accuracy : 0.9669
# Epoch: 14	Batch: 400	Avg-Loss: 0.0749	Training Accuracy : 0.9700
# Epoch: 14	Batch: 450	Avg-Loss: 0.0723	Training Accuracy : 0.9725
# Epoch: 14	Batch: 500	Avg-Loss: 0.0796	Training Accuracy : 0.9663
# Epoch: 14	Batch: 550	Avg-Loss: 0.0775	Training Accuracy : 0.9650
# Epoch: 14	Batch: 600	Avg-Loss: 0.0698	Training Accuracy : 0.9722
# Epoch: 14	Batch: 650	Avg-Loss: 0.0750	Training Accuracy : 0.9691
# Epoch: 14	Batch: 700	Avg-Loss: 0.0759	Training Accuracy : 0.9659
# Epoch: 14	Batch: 750	Avg-Loss: 0.0721	Training Accuracy : 0.9706
# Epoch: 14	Batch: 800	Avg-Loss: 0.0768	Training Accuracy : 0.9672
# Epoch: 14	Batch: 850	Avg-Loss: 0.0814	Training Accuracy : 0.9634
# Epoch: 14	Batch: 900	Avg-Loss: 0.0785	Training Accuracy : 0.9688
# Epoch: 14	Batch: 950	Avg-Loss: 0.0645	Training Accuracy : 0.9747
# Epoch: 14	Batch: 1000	Avg-Loss: 0.0851	Training Accuracy : 0.9606
# Epoch: 14	Batch: 1050	Avg-Loss: 0.0923	Training Accuracy : 0.9591
# Epoch: 14	Batch: 1100	Avg-Loss: 0.0759	Training Accuracy : 0.9659
# Epoch: 14	Batch: 1150	Avg-Loss: 0.0836	Training Accuracy : 0.9641
# Epoch: 14	Batch: 1200	Avg-Loss: 0.0848	Training Accuracy : 0.9609
# Epoch: 14	Batch: 1250	Avg-Loss: 0.0858	Training Accuracy : 0.9609
# Epoch: 14	Batch: 1300	Avg-Loss: 0.0792	Training Accuracy : 0.9644
# Epoch: 14, Validation Loss: 16.405, Validation Accuracy: 0.077
# Epoch: 15	Batch: 50	Avg-Loss: 0.0775	Training Accuracy : 0.9622
# Epoch: 15	Batch: 100	Avg-Loss: 0.0770	Training Accuracy : 0.9688
# Epoch: 15	Batch: 150	Avg-Loss: 0.0818	Training Accuracy : 0.9622
# Epoch: 15	Batch: 200	Avg-Loss: 0.0728	Training Accuracy : 0.9697
# Epoch: 15	Batch: 250	Avg-Loss: 0.0764	Training Accuracy : 0.9666
# Epoch: 15	Batch: 300	Avg-Loss: 0.0704	Training Accuracy : 0.9716
# Epoch: 15	Batch: 350	Avg-Loss: 0.0663	Training Accuracy : 0.9750
# Epoch: 15	Batch: 400	Avg-Loss: 0.0772	Training Accuracy : 0.9644
# Epoch: 15	Batch: 450	Avg-Loss: 0.0712	Training Accuracy : 0.9697
# Epoch: 15	Batch: 500	Avg-Loss: 0.0730	Training Accuracy : 0.9700
# Epoch: 15	Batch: 550	Avg-Loss: 0.0714	Training Accuracy : 0.9681
# Epoch: 15	Batch: 600	Avg-Loss: 0.0749	Training Accuracy : 0.9669
# Epoch: 15	Batch: 650	Avg-Loss: 0.0712	Training Accuracy : 0.9697
# Epoch: 15	Batch: 700	Avg-Loss: 0.0837	Training Accuracy : 0.9653
# Epoch: 15	Batch: 750	Avg-Loss: 0.0792	Training Accuracy : 0.9697
# Epoch: 15	Batch: 800	Avg-Loss: 0.0764	Training Accuracy : 0.9647
# Epoch: 15	Batch: 850	Avg-Loss: 0.0695	Training Accuracy : 0.9725
# Epoch: 15	Batch: 900	Avg-Loss: 0.0773	Training Accuracy : 0.9663
# Epoch: 15	Batch: 950	Avg-Loss: 0.0714	Training Accuracy : 0.9688
# Epoch: 15	Batch: 1000	Avg-Loss: 0.0809	Training Accuracy : 0.9650
# Epoch: 15	Batch: 1050	Avg-Loss: 0.0830	Training Accuracy : 0.9628
# Epoch: 15	Batch: 1100	Avg-Loss: 0.0686	Training Accuracy : 0.9703
# Epoch: 15	Batch: 1150	Avg-Loss: 0.0703	Training Accuracy : 0.9697
# Epoch: 15	Batch: 1200	Avg-Loss: 0.0851	Training Accuracy : 0.9600
# Epoch: 15	Batch: 1250	Avg-Loss: 0.0816	Training Accuracy : 0.9622
# Epoch: 15	Batch: 1300	Avg-Loss: 0.0733	Training Accuracy : 0.9694
# Epoch    16: reducing learning rate of group 0 to 3.1250e-04.
# Epoch: 15, Validation Loss: 16.539, Validation Accuracy: 0.074
# Epoch: 16	Batch: 50	Avg-Loss: 0.0826	Training Accuracy : 0.9637
# Epoch: 16	Batch: 100	Avg-Loss: 0.0649	Training Accuracy : 0.9725
# Epoch: 16	Batch: 150	Avg-Loss: 0.0676	Training Accuracy : 0.9728
# Epoch: 16	Batch: 200	Avg-Loss: 0.0646	Training Accuracy : 0.9753
# Epoch: 16	Batch: 250	Avg-Loss: 0.0691	Training Accuracy : 0.9734
# Epoch: 16	Batch: 300	Avg-Loss: 0.0725	Training Accuracy : 0.9684
# Epoch: 16	Batch: 350	Avg-Loss: 0.0748	Training Accuracy : 0.9697
# Epoch: 16	Batch: 400	Avg-Loss: 0.0682	Training Accuracy : 0.9709
# Epoch: 16	Batch: 450	Avg-Loss: 0.0739	Training Accuracy : 0.9678
# Epoch: 16	Batch: 500	Avg-Loss: 0.0717	Training Accuracy : 0.9669
# Epoch: 16	Batch: 550	Avg-Loss: 0.0785	Training Accuracy : 0.9681
# Epoch: 16	Batch: 600	Avg-Loss: 0.0755	Training Accuracy : 0.9656
# Epoch: 16	Batch: 650	Avg-Loss: 0.0636	Training Accuracy : 0.9716
# Epoch: 16	Batch: 700	Avg-Loss: 0.0698	Training Accuracy : 0.9716
# Epoch: 16	Batch: 750	Avg-Loss: 0.0671	Training Accuracy : 0.9731
# Epoch: 16	Batch: 800	Avg-Loss: 0.0678	Training Accuracy : 0.9734
# Epoch: 16	Batch: 850	Avg-Loss: 0.0761	Training Accuracy : 0.9697
# Epoch: 16	Batch: 900	Avg-Loss: 0.0688	Training Accuracy : 0.9712
# Epoch: 16	Batch: 950	Avg-Loss: 0.0683	Training Accuracy : 0.9700
# Epoch: 16	Batch: 1000	Avg-Loss: 0.0753	Training Accuracy : 0.9659
# Epoch: 16	Batch: 1050	Avg-Loss: 0.0628	Training Accuracy : 0.9706
# Epoch: 16	Batch: 1100	Avg-Loss: 0.0788	Training Accuracy : 0.9659
# Epoch: 16	Batch: 1150	Avg-Loss: 0.0843	Training Accuracy : 0.9631
# Epoch: 16	Batch: 1200	Avg-Loss: 0.0740	Training Accuracy : 0.9672
# Epoch: 16	Batch: 1250	Avg-Loss: 0.0639	Training Accuracy : 0.9756
# Epoch: 16	Batch: 1300	Avg-Loss: 0.0692	Training Accuracy : 0.9719
# Epoch: 16, Validation Loss: 16.749, Validation Accuracy: 0.078
# Epoch: 17	Batch: 50	Avg-Loss: 0.0639	Training Accuracy : 0.9756
# Epoch: 17	Batch: 100	Avg-Loss: 0.0671	Training Accuracy : 0.9728
# Epoch: 17	Batch: 150	Avg-Loss: 0.0684	Training Accuracy : 0.9700
# Epoch: 17	Batch: 200	Avg-Loss: 0.0677	Training Accuracy : 0.9722
# Epoch: 17	Batch: 250	Avg-Loss: 0.0716	Training Accuracy : 0.9703
# Epoch: 17	Batch: 300	Avg-Loss: 0.0607	Training Accuracy : 0.9762
# Epoch: 17	Batch: 350	Avg-Loss: 0.0657	Training Accuracy : 0.9741
# Epoch: 17	Batch: 400	Avg-Loss: 0.0628	Training Accuracy : 0.9719
# Epoch: 17	Batch: 450	Avg-Loss: 0.0690	Training Accuracy : 0.9697
# Epoch: 17	Batch: 500	Avg-Loss: 0.0757	Training Accuracy : 0.9659
# Epoch: 17	Batch: 550	Avg-Loss: 0.0625	Training Accuracy : 0.9759
# Epoch: 17	Batch: 600	Avg-Loss: 0.0666	Training Accuracy : 0.9697
# Epoch: 17	Batch: 650	Avg-Loss: 0.0689	Training Accuracy : 0.9712
# Epoch: 17	Batch: 700	Avg-Loss: 0.0776	Training Accuracy : 0.9672
# Epoch: 17	Batch: 750	Avg-Loss: 0.0724	Training Accuracy : 0.9653
# Epoch: 17	Batch: 800	Avg-Loss: 0.0714	Training Accuracy : 0.9706
# Epoch: 17	Batch: 850	Avg-Loss: 0.0841	Training Accuracy : 0.9622
# Epoch: 17	Batch: 900	Avg-Loss: 0.0762	Training Accuracy : 0.9656
# Epoch: 17	Batch: 950	Avg-Loss: 0.0816	Training Accuracy : 0.9616
# Epoch: 17	Batch: 1000	Avg-Loss: 0.0640	Training Accuracy : 0.9769
# Epoch: 17	Batch: 1050	Avg-Loss: 0.0704	Training Accuracy : 0.9694
# Epoch: 17	Batch: 1100	Avg-Loss: 0.0732	Training Accuracy : 0.9669
# Epoch: 17	Batch: 1150	Avg-Loss: 0.0645	Training Accuracy : 0.9722
# Epoch: 17	Batch: 1200	Avg-Loss: 0.0708	Training Accuracy : 0.9719
# Epoch: 17	Batch: 1250	Avg-Loss: 0.0661	Training Accuracy : 0.9741
# Epoch: 17	Batch: 1300	Avg-Loss: 0.0675	Training Accuracy : 0.9709
# Epoch: 17, Validation Loss: 16.907, Validation Accuracy: 0.079
# Epoch: 18	Batch: 50	Avg-Loss: 0.0681	Training Accuracy : 0.9722
# Epoch: 18	Batch: 100	Avg-Loss: 0.0710	Training Accuracy : 0.9697
# Epoch: 18	Batch: 150	Avg-Loss: 0.0688	Training Accuracy : 0.9706
# Epoch: 18	Batch: 200	Avg-Loss: 0.0717	Training Accuracy : 0.9684
# Epoch: 18	Batch: 250	Avg-Loss: 0.0674	Training Accuracy : 0.9728
# Epoch: 18	Batch: 300	Avg-Loss: 0.0727	Training Accuracy : 0.9694
# Epoch: 18	Batch: 350	Avg-Loss: 0.0602	Training Accuracy : 0.9741
# Epoch: 18	Batch: 400	Avg-Loss: 0.0676	Training Accuracy : 0.9738
# Epoch: 18	Batch: 450	Avg-Loss: 0.0703	Training Accuracy : 0.9703
# Epoch: 18	Batch: 500	Avg-Loss: 0.0701	Training Accuracy : 0.9728
# Epoch: 18	Batch: 550	Avg-Loss: 0.0693	Training Accuracy : 0.9694
# Epoch: 18	Batch: 600	Avg-Loss: 0.0611	Training Accuracy : 0.9759
# Epoch: 18	Batch: 650	Avg-Loss: 0.0667	Training Accuracy : 0.9744
# Epoch: 18	Batch: 700	Avg-Loss: 0.0642	Training Accuracy : 0.9750
# Epoch: 18	Batch: 750	Avg-Loss: 0.0749	Training Accuracy : 0.9672
# Epoch: 18	Batch: 800	Avg-Loss: 0.0674	Training Accuracy : 0.9688
# Epoch: 18	Batch: 850	Avg-Loss: 0.0752	Training Accuracy : 0.9697
# Epoch: 18	Batch: 900	Avg-Loss: 0.0633	Training Accuracy : 0.9731
# Epoch: 18	Batch: 950	Avg-Loss: 0.0695	Training Accuracy : 0.9712
# Epoch: 18	Batch: 1000	Avg-Loss: 0.0671	Training Accuracy : 0.9700
# Epoch: 18	Batch: 1050	Avg-Loss: 0.0636	Training Accuracy : 0.9744
# Epoch: 18	Batch: 1100	Avg-Loss: 0.0651	Training Accuracy : 0.9731
# Epoch: 18	Batch: 1150	Avg-Loss: 0.0674	Training Accuracy : 0.9688
# Epoch: 18	Batch: 1200	Avg-Loss: 0.0640	Training Accuracy : 0.9747
# Epoch: 18	Batch: 1250	Avg-Loss: 0.0671	Training Accuracy : 0.9725
# Epoch: 18	Batch: 1300	Avg-Loss: 0.0617	Training Accuracy : 0.9741
# Epoch    19: reducing learning rate of group 0 to 1.5625e-04.
# Epoch: 18, Validation Loss: 17.567, Validation Accuracy: 0.074
# Epoch: 19	Batch: 50	Avg-Loss: 0.0668	Training Accuracy : 0.9703
# Epoch: 19	Batch: 100	Avg-Loss: 0.0674	Training Accuracy : 0.9703
# Epoch: 19	Batch: 150	Avg-Loss: 0.0751	Training Accuracy : 0.9659
# Epoch: 19	Batch: 200	Avg-Loss: 0.0643	Training Accuracy : 0.9741
# Epoch: 19	Batch: 250	Avg-Loss: 0.0622	Training Accuracy : 0.9712
# Epoch: 19	Batch: 300	Avg-Loss: 0.0648	Training Accuracy : 0.9722
# Epoch: 19	Batch: 350	Avg-Loss: 0.0707	Training Accuracy : 0.9706
# Epoch: 19	Batch: 400	Avg-Loss: 0.0604	Training Accuracy : 0.9762
# Epoch: 19	Batch: 450	Avg-Loss: 0.0615	Training Accuracy : 0.9762
# Epoch: 19	Batch: 500	Avg-Loss: 0.0713	Training Accuracy : 0.9719
# Epoch: 19	Batch: 550	Avg-Loss: 0.0708	Training Accuracy : 0.9697
# Epoch: 19	Batch: 600	Avg-Loss: 0.0632	Training Accuracy : 0.9709
# Epoch: 19	Batch: 650	Avg-Loss: 0.0680	Training Accuracy : 0.9712
# Epoch: 19	Batch: 700	Avg-Loss: 0.0681	Training Accuracy : 0.9728
# Epoch: 19	Batch: 750	Avg-Loss: 0.0680	Training Accuracy : 0.9728
# Epoch: 19	Batch: 800	Avg-Loss: 0.0536	Training Accuracy : 0.9769
# Epoch: 19	Batch: 850	Avg-Loss: 0.0629	Training Accuracy : 0.9719
# Epoch: 19	Batch: 900	Avg-Loss: 0.0687	Training Accuracy : 0.9719
# Epoch: 19	Batch: 950	Avg-Loss: 0.0631	Training Accuracy : 0.9722
# Epoch: 19	Batch: 1000	Avg-Loss: 0.0634	Training Accuracy : 0.9750
# Epoch: 19	Batch: 1050	Avg-Loss: 0.0613	Training Accuracy : 0.9769
# Epoch: 19	Batch: 1100	Avg-Loss: 0.0631	Training Accuracy : 0.9747
# Epoch: 19	Batch: 1150	Avg-Loss: 0.0634	Training Accuracy : 0.9750
# Epoch: 19	Batch: 1200	Avg-Loss: 0.0706	Training Accuracy : 0.9712
# Epoch: 19	Batch: 1250	Avg-Loss: 0.0649	Training Accuracy : 0.9734
# Epoch: 19	Batch: 1300	Avg-Loss: 0.0656	Training Accuracy : 0.9738
# Epoch: 19, Validation Loss: 17.390, Validation Accuracy: 0.074
# Epoch: 20	Batch: 50	Avg-Loss: 0.0629	Training Accuracy : 0.9747
# Epoch: 20	Batch: 100	Avg-Loss: 0.0658	Training Accuracy : 0.9753
# Epoch: 20	Batch: 150	Avg-Loss: 0.0642	Training Accuracy : 0.9756
# Epoch: 20	Batch: 200	Avg-Loss: 0.0609	Training Accuracy : 0.9762
# Epoch: 20	Batch: 250	Avg-Loss: 0.0569	Training Accuracy : 0.9794
# Epoch: 20	Batch: 300	Avg-Loss: 0.0659	Training Accuracy : 0.9734
# Epoch: 20	Batch: 350	Avg-Loss: 0.0615	Training Accuracy : 0.9744
# Epoch: 20	Batch: 400	Avg-Loss: 0.0641	Training Accuracy : 0.9744
# Epoch: 20	Batch: 450	Avg-Loss: 0.0606	Training Accuracy : 0.9762
# Epoch: 20	Batch: 500	Avg-Loss: 0.0646	Training Accuracy : 0.9725
# Epoch: 20	Batch: 550	Avg-Loss: 0.0667	Training Accuracy : 0.9678
# Epoch: 20	Batch: 600	Avg-Loss: 0.0554	Training Accuracy : 0.9775
# Epoch: 20	Batch: 650	Avg-Loss: 0.0606	Training Accuracy : 0.9753
# Epoch: 20	Batch: 700	Avg-Loss: 0.0619	Training Accuracy : 0.9731
# Epoch: 20	Batch: 750	Avg-Loss: 0.0599	Training Accuracy : 0.9716
# Epoch: 20	Batch: 800	Avg-Loss: 0.0636	Training Accuracy : 0.9734
# Epoch: 20	Batch: 850	Avg-Loss: 0.0577	Training Accuracy : 0.9775
# Epoch: 20	Batch: 900	Avg-Loss: 0.0721	Training Accuracy : 0.9700
# Epoch: 20	Batch: 950	Avg-Loss: 0.0648	Training Accuracy : 0.9728
# Epoch: 20	Batch: 1000	Avg-Loss: 0.0715	Training Accuracy : 0.9709
# Epoch: 20	Batch: 1050	Avg-Loss: 0.0708	Training Accuracy : 0.9694
# Epoch: 20	Batch: 1100	Avg-Loss: 0.0752	Training Accuracy : 0.9684
# Epoch: 20	Batch: 1150	Avg-Loss: 0.0561	Training Accuracy : 0.9769
# Epoch: 20	Batch: 1200	Avg-Loss: 0.0674	Training Accuracy : 0.9706
# Epoch: 20	Batch: 1250	Avg-Loss: 0.0572	Training Accuracy : 0.9756
# Epoch: 20	Batch: 1300	Avg-Loss: 0.0712	Training Accuracy : 0.9728
# Epoch: 20, Validation Loss: 17.875, Validation Accuracy: 0.074
# Epoch: 21	Batch: 50	Avg-Loss: 0.0607	Training Accuracy : 0.9744
# Epoch: 21	Batch: 100	Avg-Loss: 0.0600	Training Accuracy : 0.9759
# Epoch: 21	Batch: 150	Avg-Loss: 0.0605	Training Accuracy : 0.9719
# Epoch: 21	Batch: 200	Avg-Loss: 0.0562	Training Accuracy : 0.9778
# Epoch: 21	Batch: 250	Avg-Loss: 0.0709	Training Accuracy : 0.9684
# Epoch: 21	Batch: 300	Avg-Loss: 0.0571	Training Accuracy : 0.9753
# Epoch: 21	Batch: 350	Avg-Loss: 0.0589	Training Accuracy : 0.9762
# Epoch: 21	Batch: 400	Avg-Loss: 0.0625	Training Accuracy : 0.9741
# Epoch: 21	Batch: 450	Avg-Loss: 0.0668	Training Accuracy : 0.9731
# Epoch: 21	Batch: 500	Avg-Loss: 0.0644	Training Accuracy : 0.9712
# Epoch: 21	Batch: 550	Avg-Loss: 0.0642	Training Accuracy : 0.9725
# Epoch: 21	Batch: 600	Avg-Loss: 0.0629	Training Accuracy : 0.9741
# Epoch: 21	Batch: 650	Avg-Loss: 0.0649	Training Accuracy : 0.9712
# Epoch: 21	Batch: 700	Avg-Loss: 0.0654	Training Accuracy : 0.9703
# Epoch: 21	Batch: 750	Avg-Loss: 0.0672	Training Accuracy : 0.9684
# Epoch: 21	Batch: 800	Avg-Loss: 0.0674	Training Accuracy : 0.9709
# Epoch: 21	Batch: 850	Avg-Loss: 0.0632	Training Accuracy : 0.9747
# Epoch: 21	Batch: 900	Avg-Loss: 0.0711	Training Accuracy : 0.9706
# Epoch: 21	Batch: 950	Avg-Loss: 0.0644	Training Accuracy : 0.9716
# Epoch: 21	Batch: 1000	Avg-Loss: 0.0667	Training Accuracy : 0.9734
# Epoch: 21	Batch: 1050	Avg-Loss: 0.0655	Training Accuracy : 0.9731
# Epoch: 21	Batch: 1100	Avg-Loss: 0.0658	Training Accuracy : 0.9700
# Epoch: 21	Batch: 1150	Avg-Loss: 0.0602	Training Accuracy : 0.9753
# Epoch: 21	Batch: 1200	Avg-Loss: 0.0598	Training Accuracy : 0.9750
# Epoch: 21	Batch: 1250	Avg-Loss: 0.0652	Training Accuracy : 0.9738
# Epoch: 21	Batch: 1300	Avg-Loss: 0.0657	Training Accuracy : 0.9731
# Epoch    22: reducing learning rate of group 0 to 7.8125e-05.
# Epoch: 21, Validation Loss: 17.162, Validation Accuracy: 0.081
# Epoch: 22	Batch: 50	Avg-Loss: 0.0595	Training Accuracy : 0.9791
# Epoch: 22	Batch: 100	Avg-Loss: 0.0586	Training Accuracy : 0.9762
# Epoch: 22	Batch: 150	Avg-Loss: 0.0686	Training Accuracy : 0.9694
# Epoch: 22	Batch: 200	Avg-Loss: 0.0650	Training Accuracy : 0.9719
# Epoch: 22	Batch: 250	Avg-Loss: 0.0622	Training Accuracy : 0.9750
# Epoch: 22	Batch: 300	Avg-Loss: 0.0562	Training Accuracy : 0.9775
# Epoch: 22	Batch: 350	Avg-Loss: 0.0571	Training Accuracy : 0.9778
# Epoch: 22	Batch: 400	Avg-Loss: 0.0691	Training Accuracy : 0.9747
# Epoch: 22	Batch: 450	Avg-Loss: 0.0603	Training Accuracy : 0.9750
# Epoch: 22	Batch: 500	Avg-Loss: 0.0596	Training Accuracy : 0.9778
# Epoch: 22	Batch: 550	Avg-Loss: 0.0582	Training Accuracy : 0.9750
# Epoch: 22	Batch: 600	Avg-Loss: 0.0594	Training Accuracy : 0.9762
# Epoch: 22	Batch: 650	Avg-Loss: 0.0622	Training Accuracy : 0.9719
# Epoch: 22	Batch: 700	Avg-Loss: 0.0653	Training Accuracy : 0.9741
# Epoch: 22	Batch: 750	Avg-Loss: 0.0561	Training Accuracy : 0.9775
# Epoch: 22	Batch: 800	Avg-Loss: 0.0648	Training Accuracy : 0.9738
# Epoch: 22	Batch: 850	Avg-Loss: 0.0571	Training Accuracy : 0.9753
# Epoch: 22	Batch: 900	Avg-Loss: 0.0566	Training Accuracy : 0.9762
# Epoch: 22	Batch: 950	Avg-Loss: 0.0621	Training Accuracy : 0.9741
# Epoch: 22	Batch: 1000	Avg-Loss: 0.0665	Training Accuracy : 0.9706
# Epoch: 22	Batch: 1050	Avg-Loss: 0.0633	Training Accuracy : 0.9734
# Epoch: 22	Batch: 1100	Avg-Loss: 0.0692	Training Accuracy : 0.9678
# Epoch: 22	Batch: 1150	Avg-Loss: 0.0644	Training Accuracy : 0.9700
# Epoch: 22	Batch: 1200	Avg-Loss: 0.0627	Training Accuracy : 0.9750
# Epoch: 22	Batch: 1250	Avg-Loss: 0.0642	Training Accuracy : 0.9741
# Epoch: 22	Batch: 1300	Avg-Loss: 0.0604	Training Accuracy : 0.9762
# Epoch: 22, Validation Loss: 17.881, Validation Accuracy: 0.078
# Epoch: 23	Batch: 50	Avg-Loss: 0.0619	Training Accuracy : 0.9747
# Epoch: 23	Batch: 100	Avg-Loss: 0.0606	Training Accuracy : 0.9759
# Epoch: 23	Batch: 150	Avg-Loss: 0.0670	Training Accuracy : 0.9731
# Epoch: 23	Batch: 200	Avg-Loss: 0.0599	Training Accuracy : 0.9772
# Epoch: 23	Batch: 250	Avg-Loss: 0.0611	Training Accuracy : 0.9731
# Epoch: 23	Batch: 300	Avg-Loss: 0.0634	Training Accuracy : 0.9750
# Epoch: 23	Batch: 350	Avg-Loss: 0.0564	Training Accuracy : 0.9772
# Epoch: 23	Batch: 400	Avg-Loss: 0.0608	Training Accuracy : 0.9728
# Epoch: 23	Batch: 450	Avg-Loss: 0.0615	Training Accuracy : 0.9753
# Epoch: 23	Batch: 500	Avg-Loss: 0.0640	Training Accuracy : 0.9734
# Epoch: 23	Batch: 550	Avg-Loss: 0.0579	Training Accuracy : 0.9806
# Epoch: 23	Batch: 600	Avg-Loss: 0.0577	Training Accuracy : 0.9781
# Epoch: 23	Batch: 650	Avg-Loss: 0.0684	Training Accuracy : 0.9709
# Epoch: 23	Batch: 700	Avg-Loss: 0.0608	Training Accuracy : 0.9762
# Epoch: 23	Batch: 750	Avg-Loss: 0.0575	Training Accuracy : 0.9750
# Epoch: 23	Batch: 800	Avg-Loss: 0.0726	Training Accuracy : 0.9709
# Epoch: 23	Batch: 850	Avg-Loss: 0.0541	Training Accuracy : 0.9775
# Epoch: 23	Batch: 900	Avg-Loss: 0.0635	Training Accuracy : 0.9722
# Epoch: 23	Batch: 950	Avg-Loss: 0.0563	Training Accuracy : 0.9778
# Epoch: 23	Batch: 1000	Avg-Loss: 0.0719	Training Accuracy : 0.9688
# Epoch: 23	Batch: 1050	Avg-Loss: 0.0626	Training Accuracy : 0.9716
# Epoch: 23	Batch: 1100	Avg-Loss: 0.0560	Training Accuracy : 0.9784
# Epoch: 23	Batch: 1150	Avg-Loss: 0.0706	Training Accuracy : 0.9659
# Epoch: 23	Batch: 1200	Avg-Loss: 0.0582	Training Accuracy : 0.9759
# Epoch: 23	Batch: 1250	Avg-Loss: 0.0621	Training Accuracy : 0.9741
# Epoch: 23	Batch: 1300	Avg-Loss: 0.0569	Training Accuracy : 0.9781
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-d8ae64e5fe4f> in <module>()
#      36       num_correct = 0
#      37       for batch_num, (x, y) in enumerate(val_loader):
# ---> 38           x, y = x.to(device), y.to(device)
#      39           outputs = network(x)
#      40           num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
#
# KeyboardInterrupt:

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Sun Nov 28 18:47:48 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P0    45W / 250W |   1123MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_images, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_3+1_base/best_model_1.pt"))
network = network.to(device)

# %%
with torch.no_grad():
  network.eval()
  num_correct = 0
  for x, y in tqdm(test_loader):
    x, y = x.to(device), y.to(device)
    outputs = network(x)
    num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

  test_acc = num_correct / len(test_set)
  print(test_acc)
# Out:
#   0%|          | 0/283 [00:00<?, ?it/s]
# 0.064473246925889

# %%
print(test_acc)
# Out:
# 0.247840864768485
