# %%
from google.colab import drive
import json
drive.mount('/content/gdrive',force_remount=False)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp /content/gdrive/MyDrive/converted_224x224.tar.gz /content
# %cd /content
# Out:
# /content

# %%
# !tar -xvzf /content/converted_224x224.tar.gz

# %%
# !ls /content/converted_224x224/
# Out:
# frame_000001.jpg  frame_053946.jpg  frame_105543.jpg  frame_152735.jpg
# frame_000035.jpg  frame_053947.jpg  frame_105544.jpg  frame_152736.jpg
# frame_000037.jpg  frame_053948.jpg  frame_105545.jpg  frame_152737.jpg
# frame_000038.jpg  frame_053949.jpg  frame_105546.jpg  frame_152738.jpg
# frame_000039.jpg  frame_053950.jpg  frame_105547.jpg  frame_152739.jpg
# frame_000040.jpg  frame_053951.jpg  frame_105548.jpg  frame_152740.jpg
# frame_000042.jpg  frame_053952.jpg  frame_105549.jpg  frame_152741.jpg
# frame_000043.jpg  frame_053953.jpg  frame_105550.jpg  frame_152742.jpg
# frame_000044.jpg  frame_053954.jpg  frame_105551.jpg  frame_152743.jpg
# frame_000045.jpg  frame_053955.jpg  frame_105552.jpg  frame_152744.jpg
# frame_000047.jpg  frame_053956.jpg  frame_105553.jpg  frame_152745.jpg
# frame_000048.jpg  frame_053957.jpg  frame_105554.jpg  frame_152746.jpg
# frame_000049.jpg  frame_053958.jpg  frame_105555.jpg  frame_152747.jpg
# frame_000050.jpg  frame_053959.jpg  frame_105556.jpg  frame_152748.jpg
# frame_000051.jpg  frame_053960.jpg  frame_105557.jpg  frame_152749.jpg
# frame_000052.jpg  frame_053961.jpg  frame_105558.jpg  frame_152750.jpg
# frame_000053.jpg  frame_053962.jpg  frame_105559.jpg  frame_152751.jpg
# frame_000054.jpg  frame_053963.jpg  frame_105560.jpg  frame_152752.jpg
# frame_000055.jpg  frame_053964.jpg  frame_105561.jpg  frame_152753.jpg
# frame_000057.jpg  frame_053965.jpg  frame_105562.jpg  frame_152754.jpg
# frame_000058.jpg  frame_053966.jpg  frame_105563.jpg  frame_152755.jpg
# frame_000059.jpg  frame_053967.jpg  frame_105564.jpg  frame_152757.jpg
# frame_000060.jpg  frame_053968.jpg  frame_105565.jpg  frame_152761.jpg
# frame_000061.jpg  frame_053969.jpg  frame_105566.jpg  frame_152764.jpg
# frame_000062.jpg  frame_053970.jpg  frame_105567.jpg  frame_152768.jpg
# frame_000063.jpg  frame_053971.jpg  frame_105568.jpg  frame_152772.jpg
# frame_000064.jpg  frame_053972.jpg  frame_105569.jpg  frame_152775.jpg
# frame_000065.jpg  frame_053973.jpg  frame_105570.jpg  frame_152779.jpg
# frame_000066.jpg  frame_053974.jpg  frame_105571.jpg  frame_152782.jpg
# frame_000067.jpg  frame_053975.jpg  frame_105572.jpg  frame_152787.jpg
# frame_000068.jpg  frame_053976.jpg  frame_105573.jpg  frame_152790.jpg
# frame_000069.jpg  frame_053977.jpg  frame_105574.jpg  frame_152794.jpg
# frame_000070.jpg  frame_053978.jpg  frame_105575.jpg  frame_152798.jpg
# frame_000071.jpg  frame_053979.jpg  frame_105576.jpg  frame_152802.jpg
# frame_000072.jpg  frame_053980.jpg  frame_105577.jpg  frame_152806.jpg
# frame_000073.jpg  frame_053981.jpg  frame_105578.jpg  frame_152809.jpg
# frame_000074.jpg  frame_053982.jpg  frame_105579.jpg  frame_152813.jpg
# frame_000075.jpg  frame_053983.jpg  frame_105580.jpg  frame_152816.jpg
# frame_000076.jpg  frame_053984.jpg  frame_105581.jpg  frame_152817.jpg
# frame_000077.jpg  frame_053985.jpg  frame_105582.jpg  frame_152821.jpg
# frame_000078.jpg  frame_053986.jpg  frame_105583.jpg  frame_152824.jpg
# frame_000079.jpg  frame_053987.jpg  frame_105584.jpg  frame_152828.jpg
# frame_000080.jpg  frame_053988.jpg  frame_105585.jpg  frame_152832.jpg
# frame_000081.jpg  frame_053989.jpg  frame_105586.jpg  frame_152836.jpg
# frame_000082.jpg  frame_053990.jpg  frame_105587.jpg  frame_152839.jpg
# frame_000083.jpg  frame_053991.jpg  frame_105588.jpg  frame_152843.jpg
# frame_000084.jpg  frame_053992.jpg  frame_105589.jpg  frame_152847.jpg
# frame_000085.jpg  frame_053993.jpg  frame_105590.jpg  frame_152850.jpg
# frame_000086.jpg  frame_053994.jpg  frame_105591.jpg  frame_152855.jpg
# frame_000087.jpg  frame_053995.jpg  frame_105592.jpg  frame_152858.jpg
# frame_000088.jpg  frame_053996.jpg  frame_105593.jpg  frame_152862.jpg
# frame_000089.jpg  frame_053997.jpg  frame_105594.jpg  frame_152865.jpg
# frame_000090.jpg  frame_053998.jpg  frame_105595.jpg  frame_152869.jpg
# frame_000091.jpg  frame_053999.jpg  frame_105596.jpg  frame_152873.jpg
# frame_000092.jpg  frame_054000.jpg  frame_105597.jpg  frame_152877.jpg
# frame_000093.jpg  frame_054001.jpg  frame_105598.jpg  frame_152881.jpg
# frame_000094.jpg  frame_054002.jpg  frame_105599.jpg  frame_152884.jpg
# frame_000095.jpg  frame_054003.jpg  frame_105600.jpg  frame_152887.jpg
# frame_000096.jpg  frame_054004.jpg  frame_105601.jpg  frame_152892.jpg
# frame_000097.jpg  frame_054005.jpg  frame_105602.jpg  frame_152895.jpg
# frame_000098.jpg  frame_054006.jpg  frame_105603.jpg  frame_152899.jpg
# frame_000099.jpg  frame_054007.jpg  frame_105604.jpg  frame_152902.jpg
# frame_000100.jpg  frame_054008.jpg  frame_105605.jpg  frame_152907.jpg
# frame_000101.jpg  frame_054009.jpg  frame_105606.jpg  frame_152911.jpg
# frame_000102.jpg  frame_054010.jpg  frame_105607.jpg  frame_152914.jpg
# frame_000103.jpg  frame_054011.jpg  frame_105608.jpg  frame_152918.jpg
# frame_000104.jpg  frame_054012.jpg  frame_105609.jpg  frame_152922.jpg
# frame_000105.jpg  frame_054013.jpg  frame_105610.jpg  frame_152926.jpg
# frame_000106.jpg  frame_054014.jpg  frame_105611.jpg  frame_152930.jpg
# frame_000107.jpg  frame_054015.jpg  frame_105612.jpg  frame_152933.jpg
# frame_000108.jpg  frame_054016.jpg  frame_105613.jpg  frame_152937.jpg
# frame_000109.jpg  frame_054017.jpg  frame_105614.jpg  frame_152938.jpg
# frame_000110.jpg  frame_054018.jpg  frame_105615.jpg  frame_152939.jpg
# frame_000111.jpg  frame_054019.jpg  frame_105617.jpg  frame_152940.jpg
# frame_000112.jpg  frame_054020.jpg  frame_105618.jpg  frame_152941.jpg
# frame_000113.jpg  frame_054021.jpg  frame_105620.jpg  frame_152942.jpg
# frame_000114.jpg  frame_054022.jpg  frame_105621.jpg  frame_152943.jpg
# frame_000115.jpg  frame_054023.jpg  frame_105622.jpg  frame_152944.jpg
# frame_000116.jpg  frame_054024.jpg  frame_105623.jpg  frame_152945.jpg
# frame_000117.jpg  frame_054025.jpg  frame_105624.jpg  frame_152946.jpg
# frame_000118.jpg  frame_054026.jpg  frame_105625.jpg  frame_152947.jpg
# frame_000119.jpg  frame_054027.jpg  frame_105626.jpg  frame_152948.jpg
# frame_000120.jpg  frame_054028.jpg  frame_105627.jpg  frame_152949.jpg
# frame_000121.jpg  frame_054029.jpg  frame_105628.jpg  frame_152950.jpg
# frame_000122.jpg  frame_054030.jpg  frame_105630.jpg  frame_152951.jpg
# frame_000123.jpg  frame_054031.jpg  frame_105631.jpg  frame_152952.jpg
# frame_000124.jpg  frame_054033.jpg  frame_105632.jpg  frame_152953.jpg
# frame_000125.jpg  frame_054034.jpg  frame_105633.jpg  frame_152954.jpg
# frame_000126.jpg  frame_054035.jpg  frame_105634.jpg  frame_152955.jpg
# frame_000127.jpg  frame_054036.jpg  frame_105635.jpg  frame_152956.jpg
# frame_000128.jpg  frame_054037.jpg  frame_105636.jpg  frame_152957.jpg
# frame_000129.jpg  frame_054038.jpg  frame_105637.jpg  frame_152958.jpg
# frame_000130.jpg  frame_054039.jpg  frame_105638.jpg  frame_152959.jpg
# frame_000131.jpg  frame_054040.jpg  frame_105640.jpg  frame_152960.jpg
# frame_000132.jpg  frame_054041.jpg  frame_105641.jpg  frame_152961.jpg
# frame_000133.jpg  frame_054042.jpg  frame_105642.jpg  frame_152962.jpg
# frame_000134.jpg  frame_054043.jpg  frame_105643.jpg  frame_152963.jpg
# frame_000135.jpg  frame_054044.jpg  frame_105645.jpg  frame_152964.jpg
# frame_000136.jpg  frame_054045.jpg  frame_105646.jpg  frame_152965.jpg
# frame_000137.jpg  frame_054046.jpg  frame_105647.jpg  frame_152966.jpg
# frame_000138.jpg  frame_054047.jpg  frame_105649.jpg  frame_152967.jpg
# frame_000139.jpg  frame_054048.jpg  frame_105650.jpg  frame_152968.jpg
# frame_000140.jpg  frame_054049.jpg  frame_105651.jpg  frame_152969.jpg
# frame_000141.jpg  frame_054050.jpg  frame_105652.jpg  frame_152970.jpg
# frame_000142.jpg  frame_054051.jpg  frame_105653.jpg  frame_152971.jpg
# frame_000143.jpg  frame_054052.jpg  frame_105655.jpg  frame_152972.jpg
# frame_000144.jpg  frame_054053.jpg  frame_105656.jpg  frame_152973.jpg
# frame_000145.jpg  frame_054054.jpg  frame_105657.jpg  frame_152974.jpg
# frame_000146.jpg  frame_054055.jpg  frame_105658.jpg  frame_152975.jpg
# frame_000147.jpg  frame_054056.jpg  frame_105660.jpg  frame_152976.jpg
# frame_000148.jpg  frame_054057.jpg  frame_105661.jpg  frame_152977.jpg
# frame_000149.jpg  frame_054058.jpg  frame_105662.jpg  frame_152978.jpg
# frame_000150.jpg  frame_054059.jpg  frame_105665.jpg  frame_152979.jpg
# frame_000151.jpg  frame_054060.jpg  frame_105666.jpg  frame_152980.jpg
# frame_000152.jpg  frame_054061.jpg  frame_105667.jpg  frame_152981.jpg
# frame_000153.jpg  frame_054062.jpg  frame_105668.jpg  frame_152982.jpg
# frame_000154.jpg  frame_054063.jpg  frame_105670.jpg  frame_152983.jpg
# frame_000155.jpg  frame_054064.jpg  frame_105671.jpg  frame_152984.jpg
# frame_000156.jpg  frame_054065.jpg  frame_105672.jpg  frame_152985.jpg
# frame_000157.jpg  frame_054066.jpg  frame_105673.jpg  frame_152986.jpg
# frame_000158.jpg  frame_054067.jpg  frame_105675.jpg  frame_152987.jpg
# frame_000159.jpg  frame_054068.jpg  frame_105676.jpg  frame_152988.jpg
# frame_000160.jpg  frame_054069.jpg  frame_105677.jpg  frame_152989.jpg
# frame_000161.jpg  frame_054070.jpg  frame_105678.jpg  frame_152990.jpg
# frame_000162.jpg  frame_054071.jpg  frame_105679.jpg  frame_152991.jpg
# frame_000163.jpg  frame_054072.jpg  frame_105680.jpg  frame_152992.jpg
# frame_000164.jpg  frame_054073.jpg  frame_105681.jpg  frame_152993.jpg
# frame_000165.jpg  frame_054074.jpg  frame_105682.jpg  frame_152994.jpg
# frame_000166.jpg  frame_054075.jpg  frame_105683.jpg  frame_152995.jpg
# frame_000167.jpg  frame_054076.jpg  frame_105684.jpg  frame_152996.jpg
# frame_000168.jpg  frame_054077.jpg  frame_105685.jpg  frame_152997.jpg
# frame_000169.jpg  frame_054078.jpg  frame_105686.jpg  frame_152998.jpg
# frame_000170.jpg  frame_054079.jpg  frame_105687.jpg  frame_152999.jpg
# frame_000171.jpg  frame_054080.jpg  frame_105688.jpg  frame_153000.jpg
# frame_000172.jpg  frame_054081.jpg  frame_105690.jpg  frame_153001.jpg
# frame_000173.jpg  frame_054082.jpg  frame_105691.jpg  frame_153002.jpg
# frame_000174.jpg  frame_054083.jpg  frame_105692.jpg  frame_153003.jpg
# frame_000175.jpg  frame_054084.jpg  frame_105693.jpg  frame_153004.jpg
# frame_000176.jpg  frame_054085.jpg  frame_105694.jpg  frame_153005.jpg
# frame_000177.jpg  frame_054086.jpg  frame_105695.jpg  frame_153006.jpg
# frame_000178.jpg  frame_054087.jpg  frame_105696.jpg  frame_153007.jpg
# frame_000179.jpg  frame_054088.jpg  frame_105697.jpg  frame_153008.jpg
# frame_000180.jpg  frame_054089.jpg  frame_105700.jpg  frame_153009.jpg
# frame_000181.jpg  frame_054090.jpg  frame_105701.jpg  frame_153010.jpg
# frame_000182.jpg  frame_054091.jpg  frame_105702.jpg  frame_153011.jpg
# frame_000183.jpg  frame_054092.jpg  frame_105703.jpg  frame_153012.jpg
# frame_000184.jpg  frame_054093.jpg  frame_105705.jpg  frame_153013.jpg
# frame_000185.jpg  frame_054094.jpg  frame_105706.jpg  frame_153014.jpg
# frame_000186.jpg  frame_054095.jpg  frame_105707.jpg  frame_153015.jpg
# frame_000187.jpg  frame_054096.jpg  frame_105708.jpg  frame_153016.jpg
# frame_000188.jpg  frame_054097.jpg  frame_105709.jpg  frame_153017.jpg
# frame_000189.jpg  frame_054098.jpg  frame_105710.jpg  frame_153018.jpg
# frame_000190.jpg  frame_054099.jpg  frame_105711.jpg  frame_153019.jpg
# frame_000191.jpg  frame_054100.jpg  frame_105712.jpg  frame_153020.jpg
# frame_000192.jpg  frame_054101.jpg  frame_105713.jpg  frame_153021.jpg
# frame_000193.jpg  frame_054102.jpg  frame_105714.jpg  frame_153022.jpg
# frame_000194.jpg  frame_054103.jpg  frame_105715.jpg  frame_153023.jpg
# frame_000195.jpg  frame_054104.jpg  frame_105716.jpg  frame_153024.jpg
# frame_000196.jpg  frame_054105.jpg  frame_105717.jpg  frame_153025.jpg
# frame_000197.jpg  frame_054106.jpg  frame_105718.jpg  frame_153026.jpg
# frame_000198.jpg  frame_054107.jpg  frame_105719.jpg  frame_153027.jpg
# frame_000199.jpg  frame_054108.jpg  frame_105720.jpg  frame_153028.jpg
# frame_000200.jpg  frame_054109.jpg  frame_105721.jpg  frame_153029.jpg
# frame_000201.jpg  frame_054110.jpg  frame_105722.jpg  frame_153030.jpg
# frame_000202.jpg  frame_054111.jpg  frame_105723.jpg  frame_153031.jpg
# frame_000203.jpg  frame_054112.jpg  frame_105724.jpg  frame_153032.jpg
# frame_000204.jpg  frame_054113.jpg  frame_105725.jpg  frame_153033.jpg
# frame_000205.jpg  frame_054114.jpg  frame_105726.jpg  frame_153034.jpg
# frame_000206.jpg  frame_054115.jpg  frame_105727.jpg  frame_153035.jpg
# frame_000207.jpg  frame_054116.jpg  frame_105728.jpg  frame_153036.jpg
# frame_000208.jpg  frame_054117.jpg  frame_105729.jpg  frame_153037.jpg
# frame_000209.jpg  frame_054118.jpg  frame_105730.jpg  frame_153038.jpg
# frame_000210.jpg  frame_054119.jpg  frame_105731.jpg  frame_153039.jpg
# frame_000211.jpg  frame_054120.jpg  frame_105732.jpg  frame_153040.jpg
# frame_000212.jpg  frame_054121.jpg  frame_105733.jpg  frame_153041.jpg
# frame_000213.jpg  frame_054122.jpg  frame_105735.jpg  frame_153042.jpg
# frame_000214.jpg  frame_054123.jpg  frame_105736.jpg  frame_153043.jpg
# frame_000215.jpg  frame_054124.jpg  frame_105737.jpg  frame_153044.jpg
# frame_000216.jpg  frame_054125.jpg  frame_105738.jpg  frame_153045.jpg
# frame_000217.jpg  frame_054126.jpg  frame_105740.jpg  frame_153046.jpg
# frame_000218.jpg  frame_054127.jpg  frame_105741.jpg  frame_153047.jpg
# frame_000219.jpg  frame_054128.jpg  frame_105742.jpg  frame_153048.jpg
# frame_000220.jpg  frame_054129.jpg  frame_105743.jpg  frame_153049.jpg
# frame_000221.jpg  frame_054130.jpg  frame_105745.jpg  frame_153050.jpg
# frame_000222.jpg  frame_054131.jpg  frame_105746.jpg  frame_153051.jpg
# frame_000223.jpg  frame_054132.jpg  frame_105747.jpg  frame_153052.jpg
# frame_000224.jpg  frame_054133.jpg  frame_105748.jpg  frame_153053.jpg
# frame_000225.jpg  frame_054134.jpg  frame_105749.jpg  frame_153054.jpg
# frame_000226.jpg  frame_054135.jpg  frame_105750.jpg  frame_153055.jpg
# frame_000227.jpg  frame_054136.jpg  frame_105751.jpg  frame_153056.jpg
# frame_000228.jpg  frame_054137.jpg  frame_105752.jpg  frame_153057.jpg
# frame_000229.jpg  frame_054138.jpg  frame_105753.jpg  frame_153058.jpg
# frame_000230.jpg  frame_054139.jpg  frame_105754.jpg  frame_153059.jpg
# frame_000231.jpg  frame_054140.jpg  frame_105755.jpg  frame_153060.jpg
# frame_000232.jpg  frame_054141.jpg  frame_105756.jpg  frame_153061.jpg
# frame_000233.jpg  frame_054142.jpg  frame_105757.jpg  frame_153062.jpg
# frame_000234.jpg  frame_054143.jpg  frame_105758.jpg  frame_153063.jpg
# frame_000235.jpg  frame_054144.jpg  frame_105760.jpg  frame_153064.jpg
# frame_000236.jpg  frame_054145.jpg  frame_105761.jpg  frame_153065.jpg
# frame_000237.jpg  frame_054146.jpg  frame_105762.jpg  frame_153066.jpg
# frame_000238.jpg  frame_054147.jpg  frame_105763.jpg  frame_153067.jpg
# frame_000239.jpg  frame_054148.jpg  frame_105764.jpg  frame_153068.jpg
# frame_000240.jpg  frame_054149.jpg  frame_105765.jpg  frame_153069.jpg
# frame_000241.jpg  frame_054150.jpg  frame_105766.jpg  frame_153070.jpg
# frame_000242.jpg  frame_054151.jpg  frame_105767.jpg  frame_153071.jpg
# frame_000243.jpg  frame_054152.jpg  frame_105768.jpg  frame_153072.jpg
# frame_000244.jpg  frame_054153.jpg  frame_105769.jpg  frame_153073.jpg
# frame_000245.jpg  frame_054154.jpg  frame_105770.jpg  frame_153074.jpg
# frame_000246.jpg  frame_054155.jpg  frame_105771.jpg  frame_153075.jpg
# frame_000247.jpg  frame_054156.jpg  frame_105772.jpg  frame_153076.jpg
# frame_000248.jpg  frame_054157.jpg  frame_105773.jpg  frame_153077.jpg
# frame_000249.jpg  frame_054158.jpg  frame_105775.jpg  frame_153078.jpg
# frame_000250.jpg  frame_054159.jpg  frame_105776.jpg  frame_153079.jpg
# frame_000251.jpg  frame_054160.jpg  frame_105777.jpg  frame_153080.jpg
# frame_000252.jpg  frame_054161.jpg  frame_105778.jpg  frame_153081.jpg
# frame_000253.jpg  frame_054162.jpg  frame_105780.jpg  frame_153082.jpg
# frame_000254.jpg  frame_054163.jpg  frame_105781.jpg  frame_153083.jpg
# frame_000255.jpg  frame_054164.jpg  frame_105782.jpg  frame_153084.jpg
# frame_000256.jpg  frame_054165.jpg  frame_105783.jpg  frame_153085.jpg
# frame_000257.jpg  frame_054166.jpg  frame_105784.jpg  frame_153086.jpg
# frame_000258.jpg  frame_054167.jpg  frame_105785.jpg  frame_153087.jpg
# frame_000259.jpg  frame_054168.jpg  frame_105786.jpg  frame_153088.jpg
# frame_000260.jpg  frame_054169.jpg  frame_105787.jpg  frame_153089.jpg
# frame_000261.jpg  frame_054170.jpg  frame_105788.jpg  frame_153090.jpg
# frame_000262.jpg  frame_054171.jpg  frame_105790.jpg  frame_153091.jpg
# frame_000263.jpg  frame_054172.jpg  frame_105791.jpg  frame_153092.jpg
# frame_000264.jpg  frame_054173.jpg  frame_105792.jpg  frame_153093.jpg
# frame_000265.jpg  frame_054174.jpg  frame_105793.jpg  frame_153094.jpg
# frame_000266.jpg  frame_054175.jpg  frame_105794.jpg  frame_153095.jpg
# frame_000267.jpg  frame_054176.jpg  frame_105795.jpg  frame_153096.jpg
# frame_000268.jpg  frame_054177.jpg  frame_105797.jpg  frame_153097.jpg
# frame_000269.jpg  frame_054178.jpg  frame_105798.jpg  frame_153098.jpg
# frame_000270.jpg  frame_054179.jpg  frame_105800.jpg  frame_153099.jpg
# frame_000271.jpg  frame_054180.jpg  frame_105801.jpg  frame_153100.jpg
# frame_000272.jpg  frame_054181.jpg  frame_105802.jpg  frame_153101.jpg
# frame_000273.jpg  frame_054182.jpg  frame_105803.jpg  frame_153102.jpg
# frame_000274.jpg  frame_054183.jpg  frame_105804.jpg  frame_153103.jpg
# frame_000275.jpg  frame_054184.jpg  frame_105805.jpg  frame_153104.jpg
# frame_000276.jpg  frame_054185.jpg  frame_105807.jpg  frame_153105.jpg
# frame_000277.jpg  frame_054186.jpg  frame_105808.jpg  frame_153106.jpg
# frame_000278.jpg  frame_054187.jpg  frame_105810.jpg  frame_153107.jpg
# frame_000279.jpg  frame_054188.jpg  frame_105811.jpg  frame_153108.jpg
# frame_000280.jpg  frame_054189.jpg  frame_105813.jpg  frame_153109.jpg
# frame_000281.jpg  frame_054190.jpg  frame_105814.jpg  frame_153110.jpg
# frame_000282.jpg  frame_054191.jpg  frame_105815.jpg  frame_153111.jpg
# frame_000283.jpg  frame_054192.jpg  frame_105816.jpg  frame_153112.jpg
# frame_000284.jpg  frame_054193.jpg  frame_105817.jpg  frame_153113.jpg
# frame_000285.jpg  frame_054194.jpg  frame_105818.jpg  frame_153114.jpg
# frame_000286.jpg  frame_054195.jpg  frame_105819.jpg  frame_153115.jpg
# frame_000287.jpg  frame_054196.jpg  frame_105820.jpg  frame_153116.jpg
# frame_000288.jpg  frame_054197.jpg  frame_105821.jpg  frame_153117.jpg
# frame_000289.jpg  frame_054198.jpg  frame_105822.jpg  frame_153118.jpg
# frame_000290.jpg  frame_054199.jpg  frame_105823.jpg  frame_153119.jpg
# frame_000291.jpg  frame_054200.jpg  frame_105824.jpg  frame_153120.jpg
# frame_000292.jpg  frame_054201.jpg  frame_105825.jpg  frame_153121.jpg
# frame_000293.jpg  frame_054202.jpg  frame_105826.jpg  frame_153122.jpg
# frame_000294.jpg  frame_054203.jpg  frame_105827.jpg  frame_153123.jpg
# frame_000295.jpg  frame_054204.jpg  frame_105828.jpg  frame_153124.jpg
# frame_000296.jpg  frame_054205.jpg  frame_105829.jpg  frame_153125.jpg
# frame_000297.jpg  frame_054206.jpg  frame_105830.jpg  frame_153126.jpg
# frame_000298.jpg  frame_054207.jpg  frame_105831.jpg  frame_153127.jpg
# frame_000299.jpg  frame_054208.jpg  frame_105832.jpg  frame_153128.jpg
# frame_000300.jpg  frame_054209.jpg  frame_105833.jpg  frame_153129.jpg
# frame_000301.jpg  frame_054210.jpg  frame_105834.jpg  frame_153132.jpg
# frame_000302.jpg  frame_054211.jpg  frame_105835.jpg  frame_153134.jpg
# frame_000303.jpg  frame_054212.jpg  frame_105837.jpg  frame_153135.jpg
# frame_000304.jpg  frame_054213.jpg  frame_105838.jpg  frame_153137.jpg
# frame_000305.jpg  frame_054214.jpg  frame_105840.jpg  frame_153138.jpg
# frame_000306.jpg  frame_054215.jpg  frame_105841.jpg  frame_153147.jpg
# frame_000307.jpg  frame_054216.jpg  frame_105842.jpg  frame_153151.jpg
# frame_000308.jpg  frame_054217.jpg  frame_105843.jpg  frame_153153.jpg
# frame_000309.jpg  frame_054218.jpg  frame_105844.jpg  frame_153154.jpg
# frame_000310.jpg  frame_054219.jpg  frame_105845.jpg  frame_153158.jpg
# frame_000311.jpg  frame_054220.jpg  frame_105846.jpg  frame_153162.jpg
# frame_000312.jpg  frame_054221.jpg  frame_105847.jpg  frame_153163.jpg
# frame_000313.jpg  frame_054222.jpg  frame_105848.jpg  frame_153164.jpg
# frame_000314.jpg  frame_054223.jpg  frame_105849.jpg  frame_153165.jpg
# frame_000315.jpg  frame_054224.jpg  frame_105850.jpg  frame_153170.jpg
# frame_000316.jpg  frame_054225.jpg  frame_105852.jpg  frame_153174.jpg
# frame_000317.jpg  frame_054226.jpg  frame_105853.jpg  frame_153177.jpg
# frame_000318.jpg  frame_054227.jpg  frame_105855.jpg  frame_153180.jpg
# frame_000319.jpg  frame_054228.jpg  frame_105856.jpg  frame_153185.jpg
# frame_000320.jpg  frame_054229.jpg  frame_105857.jpg  frame_153189.jpg
# frame_000321.jpg  frame_054230.jpg  frame_105858.jpg  frame_153192.jpg
# frame_000322.jpg  frame_054231.jpg  frame_105859.jpg  frame_153196.jpg
# frame_000323.jpg  frame_054232.jpg  frame_105860.jpg  frame_153199.jpg
# frame_000325.jpg  frame_054233.jpg  frame_105861.jpg  frame_153203.jpg
# frame_000326.jpg  frame_054234.jpg  frame_105862.jpg  frame_153207.jpg
# frame_000327.jpg  frame_054235.jpg  frame_105864.jpg  frame_153208.jpg
# frame_000328.jpg  frame_054236.jpg  frame_105865.jpg  frame_153211.jpg
# frame_000329.jpg  frame_054237.jpg  frame_105866.jpg  frame_153215.jpg
# frame_000330.jpg  frame_054238.jpg  frame_105867.jpg  frame_153218.jpg
# frame_000332.jpg  frame_054239.jpg  frame_105868.jpg  frame_153222.jpg
# frame_000333.jpg  frame_054240.jpg  frame_105869.jpg  frame_153226.jpg
# frame_000379.jpg  frame_054241.jpg  frame_105870.jpg  frame_153230.jpg
# frame_000390.jpg  frame_054242.jpg  frame_105871.jpg  frame_153233.jpg
# frame_000405.jpg  frame_054243.jpg  frame_105872.jpg  frame_153237.jpg
# frame_000415.jpg  frame_054244.jpg  frame_105873.jpg  frame_153241.jpg
# frame_000419.jpg  frame_054245.jpg  frame_105874.jpg  frame_153245.jpg
# frame_000420.jpg  frame_054246.jpg  frame_105875.jpg  frame_153249.jpg
# frame_000422.jpg  frame_054247.jpg  frame_105876.jpg  frame_153252.jpg
# frame_000423.jpg  frame_054248.jpg  frame_105877.jpg  frame_153256.jpg
# frame_000425.jpg  frame_054249.jpg  frame_105878.jpg  frame_153260.jpg
# frame_000427.jpg  frame_054250.jpg  frame_105879.jpg  frame_153264.jpg
# frame_000428.jpg  frame_054251.jpg  frame_105880.jpg  frame_153267.jpg
# frame_000433.jpg  frame_054252.jpg  frame_105883.jpg  frame_153268.jpg
# frame_000435.jpg  frame_054253.jpg  frame_105884.jpg  frame_153270.jpg
# frame_000438.jpg  frame_054254.jpg  frame_105885.jpg  frame_153275.jpg
# frame_000450.jpg  frame_054255.jpg  frame_105886.jpg  frame_153279.jpg
# frame_000525.jpg  frame_054256.jpg  frame_105887.jpg  frame_153282.jpg
# frame_000534.jpg  frame_054257.jpg  frame_105888.jpg  frame_153286.jpg
# frame_000536.jpg  frame_054258.jpg  frame_105889.jpg  frame_153290.jpg
# frame_000538.jpg  frame_054259.jpg  frame_105890.jpg  frame_153291.jpg
# frame_000539.jpg  frame_054260.jpg  frame_105891.jpg  frame_153293.jpg
# frame_000540.jpg  frame_054261.jpg  frame_105892.jpg  frame_153297.jpg
# frame_000542.jpg  frame_054263.jpg  frame_105893.jpg  frame_153298.jpg
# frame_000543.jpg  frame_054266.jpg  frame_105894.jpg  frame_153301.jpg
# frame_000544.jpg  frame_054269.jpg  frame_105895.jpg  frame_153304.jpg
# frame_000545.jpg  frame_054270.jpg  frame_105896.jpg  frame_153308.jpg
# frame_000547.jpg  frame_054271.jpg  frame_105897.jpg  frame_153312.jpg
# frame_000548.jpg  frame_054272.jpg  frame_105898.jpg  frame_153316.jpg
# frame_000550.jpg  frame_054273.jpg  frame_105900.jpg  frame_153320.jpg
# frame_000552.jpg  frame_054274.jpg  frame_105901.jpg  frame_153323.jpg
# frame_000553.jpg  frame_054275.jpg  frame_105902.jpg  frame_153327.jpg
# frame_000555.jpg  frame_054276.jpg  frame_105903.jpg  frame_153328.jpg
# frame_000557.jpg  frame_054277.jpg  frame_105904.jpg  frame_153330.jpg
# frame_000558.jpg  frame_054278.jpg  frame_105905.jpg  frame_153335.jpg
# frame_000560.jpg  frame_054279.jpg  frame_105906.jpg  frame_153339.jpg
# frame_000561.jpg  frame_054281.jpg  frame_105907.jpg  frame_153342.jpg
# frame_000563.jpg  frame_054283.jpg  frame_105908.jpg  frame_153343.jpg
# frame_000564.jpg  frame_054284.jpg  frame_105909.jpg  frame_153346.jpg
# frame_000565.jpg  frame_054286.jpg  frame_105910.jpg  frame_153350.jpg
# frame_000566.jpg  frame_054287.jpg  frame_105911.jpg  frame_153354.jpg
# frame_000605.jpg  frame_054288.jpg  frame_105912.jpg  frame_153357.jpg
# frame_000606.jpg  frame_054289.jpg  frame_105913.jpg  frame_153361.jpg
# frame_000608.jpg  frame_054290.jpg  frame_105914.jpg  frame_153365.jpg
# frame_000610.jpg  frame_054291.jpg  frame_105915.jpg  frame_153368.jpg
# frame_000611.jpg  frame_054292.jpg  frame_105916.jpg  frame_153372.jpg
# frame_000612.jpg  frame_054293.jpg  frame_105917.jpg  frame_153387.jpg
# frame_000613.jpg  frame_054296.jpg  frame_105918.jpg  frame_153391.jpg
# frame_000615.jpg  frame_054299.jpg  frame_105919.jpg  frame_153395.jpg
# frame_000616.jpg  frame_054302.jpg  frame_105920.jpg  frame_153398.jpg
# frame_000617.jpg  frame_054306.jpg  frame_105921.jpg  frame_153402.jpg
# frame_000618.jpg  frame_054309.jpg  frame_105922.jpg  frame_153406.jpg
# frame_000620.jpg  frame_054313.jpg  frame_105923.jpg  frame_153410.jpg
# frame_000621.jpg  frame_054316.jpg  frame_105924.jpg  frame_153414.jpg
# frame_000622.jpg  frame_054317.jpg  frame_105925.jpg  frame_153417.jpg
# frame_000623.jpg  frame_054318.jpg  frame_105926.jpg  frame_153421.jpg
# frame_000625.jpg  frame_054319.jpg  frame_105927.jpg  frame_153424.jpg
# frame_000626.jpg  frame_054320.jpg  frame_105928.jpg  frame_153428.jpg
# frame_000627.jpg  frame_054321.jpg  frame_105929.jpg  frame_153432.jpg
# frame_000628.jpg  frame_054322.jpg  frame_105930.jpg  frame_153447.jpg
# frame_000629.jpg  frame_054323.jpg  frame_105931.jpg  frame_153462.jpg
# frame_000630.jpg  frame_054325.jpg  frame_105932.jpg  frame_153477.jpg
# frame_000631.jpg  frame_054326.jpg  frame_105933.jpg  frame_153489.jpg
# frame_000632.jpg  frame_054327.jpg  frame_105934.jpg  frame_153492.jpg
# frame_000633.jpg  frame_054328.jpg  frame_105935.jpg  frame_153496.jpg
# frame_000634.jpg  frame_054329.jpg  frame_105936.jpg  frame_153507.jpg
# frame_000635.jpg  frame_054330.jpg  frame_105937.jpg  frame_153522.jpg
# frame_000636.jpg  frame_054331.jpg  frame_105938.jpg  frame_153537.jpg
# frame_000637.jpg  frame_054332.jpg  frame_105939.jpg  frame_153552.jpg
# frame_000638.jpg  frame_054333.jpg  frame_105940.jpg  frame_153553.jpg
# frame_000639.jpg  frame_054334.jpg  frame_105941.jpg  frame_153567.jpg
# frame_000640.jpg  frame_054336.jpg  frame_105942.jpg  frame_153568.jpg
# frame_000641.jpg  frame_054337.jpg  frame_105943.jpg  frame_153569.jpg
# frame_000642.jpg  frame_054339.jpg  frame_105945.jpg  frame_153570.jpg
# frame_000643.jpg  frame_054344.jpg  frame_105946.jpg  frame_153571.jpg
# frame_000644.jpg  frame_054347.jpg  frame_105947.jpg  frame_153572.jpg
# frame_000645.jpg  frame_054349.jpg  frame_105948.jpg  frame_153573.jpg
# frame_000646.jpg  frame_054351.jpg  frame_105949.jpg  frame_153574.jpg
# frame_000647.jpg  frame_054354.jpg  frame_105950.jpg  frame_153575.jpg
# frame_000648.jpg  frame_054359.jpg  frame_105951.jpg  frame_153576.jpg
# frame_000649.jpg  frame_054362.jpg  frame_105952.jpg  frame_153577.jpg
# frame_000650.jpg  frame_054366.jpg  frame_105953.jpg  frame_153578.jpg
# frame_000651.jpg  frame_054369.jpg  frame_105954.jpg  frame_153579.jpg
# frame_000652.jpg  frame_054373.jpg  frame_105955.jpg  frame_153580.jpg
# frame_000653.jpg  frame_054377.jpg  frame_105956.jpg  frame_153581.jpg
# frame_000654.jpg  frame_054381.jpg  frame_105957.jpg  frame_153582.jpg
# frame_000655.jpg  frame_054384.jpg  frame_105958.jpg  frame_153583.jpg
# frame_000656.jpg  frame_054388.jpg  frame_105959.jpg  frame_153584.jpg
# frame_000657.jpg  frame_054391.jpg  frame_105960.jpg  frame_153585.jpg
# frame_000658.jpg  frame_054392.jpg  frame_105961.jpg  frame_153586.jpg
# frame_000659.jpg  frame_054393.jpg  frame_105962.jpg  frame_153587.jpg
# frame_000660.jpg  frame_054396.jpg  frame_105963.jpg  frame_153588.jpg
# frame_000661.jpg  frame_054400.jpg  frame_105964.jpg  frame_153589.jpg
# frame_000662.jpg  frame_054403.jpg  frame_105965.jpg  frame_153590.jpg
# frame_000663.jpg  frame_054407.jpg  frame_105966.jpg  frame_153591.jpg
# frame_000664.jpg  frame_054411.jpg  frame_105967.jpg  frame_153592.jpg
# frame_000665.jpg  frame_054413.jpg  frame_105968.jpg  frame_153593.jpg
# frame_000666.jpg  frame_054415.jpg  frame_105970.jpg  frame_153594.jpg
# frame_000667.jpg  frame_054418.jpg  frame_105971.jpg  frame_153595.jpg
# frame_000668.jpg  frame_054419.jpg  frame_105973.jpg  frame_153596.jpg
# frame_000669.jpg  frame_054429.jpg  frame_105975.jpg  frame_153597.jpg
# frame_000670.jpg  frame_054433.jpg  frame_105976.jpg  frame_153598.jpg
# frame_000671.jpg  frame_054434.jpg  frame_105977.jpg  frame_153599.jpg
# frame_000672.jpg  frame_054437.jpg  frame_105978.jpg  frame_153600.jpg
# frame_000673.jpg  frame_054441.jpg  frame_105979.jpg  frame_153601.jpg
# frame_000674.jpg  frame_054445.jpg  frame_105980.jpg  frame_153602.jpg
# frame_000675.jpg  frame_054448.jpg  frame_105981.jpg  frame_153603.jpg
# frame_000676.jpg  frame_054452.jpg  frame_105982.jpg  frame_153604.jpg
# frame_000677.jpg  frame_054456.jpg  frame_105983.jpg  frame_153605.jpg
# frame_000678.jpg  frame_054458.jpg  frame_105984.jpg  frame_153606.jpg
# frame_000679.jpg  frame_054461.jpg  frame_105985.jpg  frame_153607.jpg
# frame_000680.jpg  frame_054462.jpg  frame_105987.jpg  frame_153608.jpg
# frame_000681.jpg  frame_054463.jpg  frame_105988.jpg  frame_153609.jpg
# frame_000682.jpg  frame_054466.jpg  frame_105990.jpg  frame_153610.jpg
# frame_000683.jpg  frame_054467.jpg  frame_105991.jpg  frame_153611.jpg
# frame_000684.jpg  frame_054468.jpg  frame_105992.jpg  frame_153612.jpg
# frame_000685.jpg  frame_054471.jpg  frame_105993.jpg  frame_153613.jpg
# frame_000686.jpg  frame_054474.jpg  frame_105994.jpg  frame_153614.jpg
# frame_000687.jpg  frame_054475.jpg  frame_105995.jpg  frame_153615.jpg
# frame_000688.jpg  frame_054477.jpg  frame_105996.jpg  frame_153616.jpg
# frame_000689.jpg  frame_054478.jpg  frame_105997.jpg  frame_153617.jpg
# frame_000690.jpg  frame_054482.jpg  frame_105999.jpg  frame_153618.jpg
# frame_000691.jpg  frame_054485.jpg  frame_106000.jpg  frame_153619.jpg
# frame_000692.jpg  frame_054486.jpg  frame_106001.jpg  frame_153620.jpg
# frame_000693.jpg  frame_054489.jpg  frame_106002.jpg  frame_153621.jpg
# frame_000694.jpg  frame_054493.jpg  frame_106003.jpg  frame_153622.jpg
# frame_000695.jpg  frame_054497.jpg  frame_106005.jpg  frame_153623.jpg
# frame_000696.jpg  frame_054500.jpg  frame_106006.jpg  frame_153624.jpg
# frame_000697.jpg  frame_054501.jpg  frame_106008.jpg  frame_153625.jpg
# frame_000698.jpg  frame_054504.jpg  frame_106009.jpg  frame_153626.jpg
# frame_000699.jpg  frame_054509.jpg  frame_106010.jpg  frame_153627.jpg
# frame_000700.jpg  frame_054512.jpg  frame_106011.jpg  frame_153628.jpg
# frame_000701.jpg  frame_054516.jpg  frame_106012.jpg  frame_153629.jpg
# frame_000702.jpg  frame_054518.jpg  frame_106013.jpg  frame_153630.jpg
# frame_000703.jpg  frame_054521.jpg  frame_106014.jpg  frame_153631.jpg
# frame_000704.jpg  frame_054524.jpg  frame_106015.jpg  frame_153632.jpg
# frame_000705.jpg  frame_054529.jpg  frame_106016.jpg  frame_153633.jpg
# frame_000706.jpg  frame_054531.jpg  frame_106017.jpg  frame_153634.jpg
# frame_000707.jpg  frame_054532.jpg  frame_106018.jpg  frame_153635.jpg
# frame_000708.jpg  frame_054536.jpg  frame_106019.jpg  frame_153636.jpg
# frame_000709.jpg  frame_054540.jpg  frame_106020.jpg  frame_153637.jpg
# frame_000710.jpg  frame_054544.jpg  frame_106021.jpg  frame_153638.jpg
# frame_000711.jpg  frame_054546.jpg  frame_106022.jpg  frame_153639.jpg
# frame_000712.jpg  frame_054547.jpg  frame_106023.jpg  frame_153640.jpg
# frame_000713.jpg  frame_054551.jpg  frame_106024.jpg  frame_153641.jpg
# frame_000714.jpg  frame_054555.jpg  frame_106025.jpg  frame_153642.jpg
# frame_000715.jpg  frame_054559.jpg  frame_106026.jpg  frame_153643.jpg
# frame_000716.jpg  frame_054560.jpg  frame_106027.jpg  frame_153644.jpg
# frame_000717.jpg  frame_054561.jpg  frame_106028.jpg  frame_153645.jpg
# frame_000718.jpg  frame_054562.jpg  frame_106029.jpg  frame_153646.jpg
# frame_000719.jpg  frame_054566.jpg  frame_106031.jpg  frame_153647.jpg
# frame_000720.jpg  frame_054570.jpg  frame_106032.jpg  frame_153648.jpg
# frame_000721.jpg  frame_054574.jpg  frame_106033.jpg  frame_153649.jpg
# frame_000722.jpg  frame_054575.jpg  frame_106034.jpg  frame_153650.jpg
# frame_000723.jpg  frame_054576.jpg  frame_106035.jpg  frame_153651.jpg
# frame_000724.jpg  frame_054580.jpg  frame_106036.jpg  frame_153652.jpg
# frame_000725.jpg  frame_054584.jpg  frame_106037.jpg  frame_153653.jpg
# frame_000726.jpg  frame_054587.jpg  frame_106038.jpg  frame_153654.jpg
# frame_000727.jpg  frame_054590.jpg  frame_106039.jpg  frame_153655.jpg
# frame_000728.jpg  frame_054592.jpg  frame_106040.jpg  frame_153656.jpg
# frame_000730.jpg  frame_054595.jpg  frame_106041.jpg  frame_153657.jpg
# frame_000731.jpg  frame_054596.jpg  frame_106042.jpg  frame_153658.jpg
# frame_000732.jpg  frame_054597.jpg  frame_106043.jpg  frame_153659.jpg
# frame_000733.jpg  frame_054600.jpg  frame_106044.jpg  frame_153660.jpg
# frame_000734.jpg  frame_054602.jpg  frame_106045.jpg  frame_153661.jpg
# frame_000735.jpg  frame_054604.jpg  frame_106046.jpg  frame_153662.jpg
# frame_000736.jpg  frame_054607.jpg  frame_106047.jpg  frame_153663.jpg
# frame_000737.jpg  frame_054609.jpg  frame_106048.jpg  frame_153664.jpg
# frame_000738.jpg  frame_054611.jpg  frame_106049.jpg  frame_153665.jpg
# frame_000739.jpg  frame_054616.jpg  frame_106050.jpg  frame_153666.jpg
# frame_000740.jpg  frame_054620.jpg  frame_106051.jpg  frame_153667.jpg
# frame_000741.jpg  frame_054623.jpg  frame_106052.jpg  frame_153668.jpg
# frame_000742.jpg  frame_054624.jpg  frame_106053.jpg  frame_153669.jpg
# frame_000743.jpg  frame_054627.jpg  frame_106054.jpg  frame_153670.jpg
# frame_000744.jpg  frame_054631.jpg  frame_106055.jpg  frame_153671.jpg
# frame_000745.jpg  frame_054632.jpg  frame_106056.jpg  frame_153672.jpg
# frame_000746.jpg  frame_054634.jpg  frame_106057.jpg  frame_153673.jpg
# frame_000747.jpg  frame_054639.jpg  frame_106059.jpg  frame_153674.jpg
# frame_000748.jpg  frame_054642.jpg  frame_106060.jpg  frame_153675.jpg
# frame_000749.jpg  frame_054646.jpg  frame_106061.jpg  frame_153676.jpg
# frame_000750.jpg  frame_054650.jpg  frame_106062.jpg  frame_153677.jpg
# frame_000751.jpg  frame_054653.jpg  frame_106063.jpg  frame_153678.jpg
# frame_000752.jpg  frame_054661.jpg  frame_106064.jpg  frame_153679.jpg
# frame_000753.jpg  frame_054662.jpg  frame_106065.jpg  frame_153680.jpg
# frame_000754.jpg  frame_054664.jpg  frame_106066.jpg  frame_153681.jpg
# frame_000755.jpg  frame_054665.jpg  frame_106067.jpg  frame_153682.jpg
# frame_000756.jpg  frame_054667.jpg  frame_106068.jpg  frame_153683.jpg
# frame_000757.jpg  frame_054668.jpg  frame_106069.jpg  frame_153684.jpg
# frame_000758.jpg  frame_054669.jpg  frame_106070.jpg  frame_153685.jpg
# frame_000760.jpg  frame_054670.jpg  frame_106071.jpg  frame_153686.jpg
# frame_000761.jpg  frame_054671.jpg  frame_106072.jpg  frame_153687.jpg
# frame_000762.jpg  frame_054672.jpg  frame_106073.jpg  frame_153688.jpg
# frame_000763.jpg  frame_054674.jpg  frame_106075.jpg  frame_153689.jpg
# frame_000764.jpg  frame_054675.jpg  frame_106076.jpg  frame_153690.jpg
# frame_000765.jpg  frame_054676.jpg  frame_106078.jpg  frame_153691.jpg
# frame_000766.jpg  frame_054677.jpg  frame_106079.jpg  frame_153692.jpg
# frame_000767.jpg  frame_054678.jpg  frame_106080.jpg  frame_153693.jpg
# frame_000768.jpg  frame_054679.jpg  frame_106081.jpg  frame_153694.jpg
# frame_000769.jpg  frame_054680.jpg  frame_106082.jpg  frame_153695.jpg
# frame_000770.jpg  frame_054681.jpg  frame_106083.jpg  frame_153696.jpg
# frame_000771.jpg  frame_054682.jpg  frame_106084.jpg  frame_153697.jpg
# frame_000772.jpg  frame_054683.jpg  frame_106085.jpg  frame_153698.jpg
# frame_000773.jpg  frame_054684.jpg  frame_106086.jpg  frame_153699.jpg
# frame_000775.jpg  frame_054685.jpg  frame_106087.jpg  frame_153700.jpg
# frame_000776.jpg  frame_054686.jpg  frame_106089.jpg  frame_153701.jpg
# frame_000777.jpg  frame_054687.jpg  frame_106090.jpg  frame_153702.jpg
# frame_000778.jpg  frame_054688.jpg  frame_106092.jpg  frame_153703.jpg
# frame_000779.jpg  frame_054689.jpg  frame_106093.jpg  frame_153704.jpg
# frame_000780.jpg  frame_054690.jpg  frame_106094.jpg  frame_153705.jpg
# frame_000781.jpg  frame_054691.jpg  frame_106095.jpg  frame_153706.jpg
# frame_000782.jpg  frame_054692.jpg  frame_106096.jpg  frame_153707.jpg
# frame_000783.jpg  frame_054693.jpg  frame_106097.jpg  frame_153708.jpg
# frame_000784.jpg  frame_054694.jpg  frame_106098.jpg  frame_153709.jpg
# frame_000785.jpg  frame_054695.jpg  frame_106099.jpg  frame_153710.jpg
# frame_000786.jpg  frame_054696.jpg  frame_106100.jpg  frame_153711.jpg
# frame_000787.jpg  frame_054697.jpg  frame_106101.jpg  frame_153712.jpg
# frame_000788.jpg  frame_054698.jpg  frame_106102.jpg  frame_153713.jpg
# frame_000790.jpg  frame_054699.jpg  frame_106104.jpg  frame_153714.jpg
# frame_000791.jpg  frame_054700.jpg  frame_106105.jpg  frame_153715.jpg
# frame_000792.jpg  frame_054701.jpg  frame_106106.jpg  frame_153716.jpg
# frame_000793.jpg  frame_054702.jpg  frame_106107.jpg  frame_153717.jpg
# frame_000794.jpg  frame_054703.jpg  frame_106108.jpg  frame_153718.jpg
# frame_000795.jpg  frame_054704.jpg  frame_106109.jpg  frame_153719.jpg
# frame_000796.jpg  frame_054705.jpg  frame_106110.jpg  frame_153720.jpg
# frame_000797.jpg  frame_054706.jpg  frame_106111.jpg  frame_153721.jpg
# frame_000798.jpg  frame_054707.jpg  frame_106112.jpg  frame_153722.jpg
# frame_000799.jpg  frame_054708.jpg  frame_106113.jpg  frame_153723.jpg
# frame_000800.jpg  frame_054709.jpg  frame_106114.jpg  frame_153724.jpg
# frame_000801.jpg  frame_054710.jpg  frame_106115.jpg  frame_153725.jpg
# frame_000802.jpg  frame_054711.jpg  frame_106116.jpg  frame_153726.jpg
# frame_000803.jpg  frame_054712.jpg  frame_106117.jpg  frame_153727.jpg
# frame_000804.jpg  frame_054713.jpg  frame_106118.jpg  frame_153728.jpg
# frame_000805.jpg  frame_054714.jpg  frame_106120.jpg  frame_153729.jpg
# frame_000806.jpg  frame_054715.jpg  frame_106121.jpg  frame_153730.jpg
# frame_000807.jpg  frame_054716.jpg  frame_106122.jpg  frame_153731.jpg
# frame_000808.jpg  frame_054717.jpg  frame_106123.jpg  frame_153732.jpg
# frame_000809.jpg  frame_054718.jpg  frame_106124.jpg  frame_153733.jpg
# frame_000810.jpg  frame_054719.jpg  frame_106125.jpg  frame_153734.jpg
# frame_000811.jpg  frame_054720.jpg  frame_106126.jpg  frame_153735.jpg
# frame_000812.jpg  frame_054721.jpg  frame_106127.jpg  frame_153736.jpg
# frame_000813.jpg  frame_054722.jpg  frame_106128.jpg  frame_153737.jpg
# frame_000815.jpg  frame_054723.jpg  frame_106129.jpg  frame_153738.jpg
# frame_000816.jpg  frame_054724.jpg  frame_106131.jpg  frame_153739.jpg
# frame_000818.jpg  frame_054725.jpg  frame_106132.jpg  frame_153740.jpg
# frame_000819.jpg  frame_054726.jpg  frame_106133.jpg  frame_153741.jpg
# frame_000820.jpg  frame_054727.jpg  frame_106134.jpg  frame_153742.jpg
# frame_000822.jpg  frame_054728.jpg  frame_106135.jpg  frame_153743.jpg
# frame_000823.jpg  frame_054729.jpg  frame_106136.jpg  frame_153744.jpg
# frame_000824.jpg  frame_054730.jpg  frame_106137.jpg  frame_153745.jpg
# frame_000825.jpg  frame_054731.jpg  frame_106138.jpg  frame_153746.jpg
# frame_000826.jpg  frame_054732.jpg  frame_106139.jpg  frame_153747.jpg
# frame_000827.jpg  frame_054733.jpg  frame_106140.jpg  frame_153748.jpg
# frame_000828.jpg  frame_054734.jpg  frame_106141.jpg  frame_153749.jpg
# frame_000829.jpg  frame_054736.jpg  frame_106142.jpg  frame_153750.jpg
# frame_000830.jpg  frame_054737.jpg  frame_106143.jpg  frame_153751.jpg
# frame_000831.jpg  frame_054738.jpg  frame_106144.jpg  frame_153752.jpg
# frame_000832.jpg  frame_054739.jpg  frame_106145.jpg  frame_153753.jpg
# frame_000833.jpg  frame_054740.jpg  frame_106146.jpg  frame_153754.jpg
# frame_000834.jpg  frame_054741.jpg  frame_106147.jpg  frame_153755.jpg
# frame_000835.jpg  frame_054742.jpg  frame_106148.jpg  frame_153756.jpg
# frame_000836.jpg  frame_054743.jpg  frame_106149.jpg  frame_153757.jpg
# frame_000837.jpg  frame_054744.jpg  frame_106150.jpg  frame_153758.jpg
# frame_000838.jpg  frame_054745.jpg  frame_106151.jpg  frame_153759.jpg
# frame_000839.jpg  frame_054746.jpg  frame_106152.jpg  frame_153760.jpg
# frame_000840.jpg  frame_054747.jpg  frame_106153.jpg  frame_153761.jpg
# frame_000841.jpg  frame_054748.jpg  frame_106154.jpg  frame_153762.jpg
# frame_000842.jpg  frame_054749.jpg  frame_106155.jpg  frame_153763.jpg
# frame_000843.jpg  frame_054750.jpg  frame_106156.jpg  frame_153764.jpg
# frame_000844.jpg  frame_054751.jpg  frame_106157.jpg  frame_153765.jpg
# frame_000845.jpg  frame_054752.jpg  frame_106158.jpg  frame_153766.jpg
# frame_000846.jpg  frame_054753.jpg  frame_106159.jpg  frame_153767.jpg
# frame_000847.jpg  frame_054754.jpg  frame_106160.jpg  frame_153768.jpg
# frame_000848.jpg  frame_054755.jpg  frame_106161.jpg  frame_153769.jpg
# frame_000849.jpg  frame_054756.jpg  frame_106162.jpg  frame_153770.jpg
# frame_000850.jpg  frame_054757.jpg  frame_106164.jpg  frame_153771.jpg
# frame_000851.jpg  frame_054758.jpg  frame_106165.jpg  frame_153772.jpg
# frame_000852.jpg  frame_054759.jpg  frame_106166.jpg  frame_153773.jpg
# frame_000853.jpg  frame_054760.jpg  frame_106167.jpg  frame_153774.jpg
# frame_000854.jpg  frame_054761.jpg  frame_106168.jpg  frame_153775.jpg
# frame_000855.jpg  frame_054762.jpg  frame_106170.jpg  frame_153776.jpg
# frame_000856.jpg  frame_054763.jpg  frame_106171.jpg  frame_153777.jpg
# frame_000857.jpg  frame_054764.jpg  frame_106172.jpg  frame_153778.jpg
# frame_000858.jpg  frame_054766.jpg  frame_106173.jpg  frame_153788.jpg
# frame_000859.jpg  frame_054767.jpg  frame_106174.jpg  frame_153789.jpg
# frame_000860.jpg  frame_054768.jpg  frame_106175.jpg  frame_153790.jpg
# frame_000861.jpg  frame_054769.jpg  frame_106176.jpg  frame_153793.jpg
# frame_000862.jpg  frame_054770.jpg  frame_106177.jpg  frame_153798.jpg
# frame_000863.jpg  frame_054771.jpg  frame_106178.jpg  frame_153800.jpg
# frame_000864.jpg  frame_054772.jpg  frame_106180.jpg  frame_153803.jpg
# frame_000865.jpg  frame_054773.jpg  frame_106182.jpg  frame_153805.jpg
# frame_000866.jpg  frame_054774.jpg  frame_106183.jpg  frame_153808.jpg
# frame_000867.jpg  frame_054775.jpg  frame_106184.jpg  frame_153811.jpg
# frame_000868.jpg  frame_054776.jpg  frame_106185.jpg  frame_153812.jpg
# frame_000869.jpg  frame_054777.jpg  frame_106186.jpg  frame_153815.jpg
# frame_000870.jpg  frame_054778.jpg  frame_106187.jpg  frame_153818.jpg
# frame_000871.jpg  frame_054779.jpg  frame_106188.jpg  frame_153823.jpg
# frame_000872.jpg  frame_054780.jpg  frame_106189.jpg  frame_153830.jpg
# frame_000873.jpg  frame_054781.jpg  frame_106190.jpg  frame_153833.jpg
# frame_000874.jpg  frame_054782.jpg  frame_106191.jpg  frame_153835.jpg
# frame_000875.jpg  frame_054783.jpg  frame_106192.jpg  frame_153838.jpg
# frame_000876.jpg  frame_054784.jpg  frame_106194.jpg  frame_153843.jpg
# frame_000877.jpg  frame_054785.jpg  frame_106195.jpg  frame_153848.jpg
# frame_000878.jpg  frame_054786.jpg  frame_106196.jpg  frame_153853.jpg
# frame_000880.jpg  frame_054787.jpg  frame_106197.jpg  frame_153868.jpg
# frame_000881.jpg  frame_054788.jpg  frame_106198.jpg  frame_153883.jpg
# frame_000882.jpg  frame_054789.jpg  frame_106199.jpg  frame_153898.jpg
# frame_000883.jpg  frame_054790.jpg  frame_106200.jpg  frame_153913.jpg
# frame_000884.jpg  frame_054791.jpg  frame_106201.jpg  frame_153928.jpg
# frame_000885.jpg  frame_054792.jpg  frame_106202.jpg  frame_153932.jpg
# frame_000886.jpg  frame_054793.jpg  frame_106203.jpg  frame_153935.jpg
# frame_000887.jpg  frame_054794.jpg  frame_106204.jpg  frame_153939.jpg
# frame_000888.jpg  frame_054795.jpg  frame_106205.jpg  frame_153943.jpg
# frame_000889.jpg  frame_054796.jpg  frame_106206.jpg  frame_153946.jpg
# frame_000890.jpg  frame_054797.jpg  frame_106207.jpg  frame_153951.jpg
# frame_000891.jpg  frame_054798.jpg  frame_106208.jpg  frame_153954.jpg
# frame_000892.jpg  frame_054799.jpg  frame_106209.jpg  frame_153958.jpg
# frame_000893.jpg  frame_054800.jpg  frame_106210.jpg  frame_153961.jpg
# frame_000894.jpg  frame_054801.jpg  frame_106211.jpg  frame_153965.jpg
# frame_000895.jpg  frame_054802.jpg  frame_106212.jpg  frame_153969.jpg
# frame_000896.jpg  frame_054803.jpg  frame_106213.jpg  frame_153973.jpg
# frame_000897.jpg  frame_054804.jpg  frame_106214.jpg  frame_153977.jpg
# frame_000898.jpg  frame_054805.jpg  frame_106215.jpg  frame_153980.jpg
# frame_000899.jpg  frame_054806.jpg  frame_106216.jpg  frame_153983.jpg
# frame_000900.jpg  frame_054807.jpg  frame_106217.jpg  frame_153988.jpg
# frame_000901.jpg  frame_054808.jpg  frame_106218.jpg  frame_153991.jpg
# frame_000902.jpg  frame_054809.jpg  frame_106219.jpg  frame_153995.jpg
# frame_000903.jpg  frame_054810.jpg  frame_106220.jpg  frame_153998.jpg
# frame_000904.jpg  frame_054811.jpg  frame_106221.jpg  frame_154003.jpg
# frame_000905.jpg  frame_054812.jpg  frame_106222.jpg  frame_154007.jpg
# frame_000906.jpg  frame_054813.jpg  frame_106223.jpg  frame_154011.jpg
# frame_000907.jpg  frame_054814.jpg  frame_106224.jpg  frame_154014.jpg
# frame_000908.jpg  frame_054815.jpg  frame_106225.jpg  frame_154018.jpg
# frame_000909.jpg  frame_054816.jpg  frame_106226.jpg  frame_154022.jpg
# frame_000910.jpg  frame_054817.jpg  frame_106227.jpg  frame_154025.jpg
# frame_000912.jpg  frame_054818.jpg  frame_106228.jpg  frame_154029.jpg
# frame_000913.jpg  frame_054819.jpg  frame_106229.jpg  frame_154033.jpg
# frame_000914.jpg  frame_054820.jpg  frame_106230.jpg  frame_154037.jpg
# frame_000915.jpg  frame_054821.jpg  frame_106231.jpg  frame_154040.jpg
# frame_000916.jpg  frame_054822.jpg  frame_106233.jpg  frame_154044.jpg
# frame_000917.jpg  frame_054824.jpg  frame_106234.jpg  frame_154048.jpg
# frame_000918.jpg  frame_054825.jpg  frame_106236.jpg  frame_154049.jpg
# frame_000919.jpg  frame_054826.jpg  frame_106237.jpg  frame_154051.jpg
# frame_000920.jpg  frame_054827.jpg  frame_106238.jpg  frame_154056.jpg
# frame_000921.jpg  frame_054828.jpg  frame_106240.jpg  frame_154059.jpg
# frame_000922.jpg  frame_054829.jpg  frame_106241.jpg  frame_154063.jpg
# frame_000923.jpg  frame_054830.jpg  frame_106242.jpg  frame_154066.jpg
# frame_000925.jpg  frame_054831.jpg  frame_106243.jpg  frame_154070.jpg
# frame_000926.jpg  frame_054832.jpg  frame_106244.jpg  frame_154074.jpg
# frame_000927.jpg  frame_054833.jpg  frame_106245.jpg  frame_154078.jpg
# frame_000928.jpg  frame_054834.jpg  frame_106246.jpg  frame_154082.jpg
# frame_000929.jpg  frame_054835.jpg  frame_106247.jpg  frame_154085.jpg
# frame_000930.jpg  frame_054836.jpg  frame_106248.jpg  frame_154088.jpg
# frame_000931.jpg  frame_054837.jpg  frame_106249.jpg  frame_154093.jpg
# frame_000932.jpg  frame_054838.jpg  frame_106250.jpg  frame_154096.jpg
# frame_000933.jpg  frame_054839.jpg  frame_106251.jpg  frame_154100.jpg
# frame_000934.jpg  frame_054840.jpg  frame_106252.jpg  frame_154103.jpg
# frame_000935.jpg  frame_054841.jpg  frame_106253.jpg  frame_154108.jpg
# frame_000936.jpg  frame_054842.jpg  frame_106254.jpg  frame_154111.jpg
# frame_000937.jpg  frame_054843.jpg  frame_106255.jpg  frame_154115.jpg
# frame_000938.jpg  frame_054844.jpg  frame_106256.jpg  frame_154120.jpg
# frame_000939.jpg  frame_054845.jpg  frame_106257.jpg  frame_154123.jpg
# frame_000940.jpg  frame_054846.jpg  frame_106258.jpg  frame_154138.jpg
# frame_000941.jpg  frame_054847.jpg  frame_106259.jpg  frame_154153.jpg
# frame_000942.jpg  frame_054848.jpg  frame_106260.jpg  frame_154168.jpg
# frame_000943.jpg  frame_054849.jpg  frame_106261.jpg  frame_154183.jpg
# frame_000944.jpg  frame_054850.jpg  frame_106262.jpg  frame_154198.jpg
# frame_000945.jpg  frame_054851.jpg  frame_106263.jpg  frame_154199.jpg
# frame_000946.jpg  frame_054852.jpg  frame_106264.jpg  frame_154200.jpg
# frame_000947.jpg  frame_054853.jpg  frame_106265.jpg  frame_154201.jpg
# frame_000948.jpg  frame_054854.jpg  frame_106266.jpg  frame_154202.jpg
# frame_000949.jpg  frame_054855.jpg  frame_106267.jpg  frame_154204.jpg
# frame_000950.jpg  frame_054856.jpg  frame_106268.jpg  frame_154205.jpg
# frame_000951.jpg  frame_054857.jpg  frame_106269.jpg  frame_154206.jpg
# frame_000953.jpg  frame_054858.jpg  frame_106270.jpg  frame_154207.jpg
# frame_000954.jpg  frame_054859.jpg  frame_106271.jpg  frame_154208.jpg
# frame_000955.jpg  frame_054860.jpg  frame_106272.jpg  frame_154209.jpg
# frame_000956.jpg  frame_054861.jpg  frame_106273.jpg  frame_154210.jpg
# frame_000957.jpg  frame_054862.jpg  frame_106274.jpg  frame_154211.jpg
# frame_000958.jpg  frame_054863.jpg  frame_106275.jpg  frame_154213.jpg
# frame_000959.jpg  frame_054864.jpg  frame_106276.jpg  frame_154214.jpg
# frame_000960.jpg  frame_054865.jpg  frame_106277.jpg  frame_154215.jpg
# frame_000961.jpg  frame_054866.jpg  frame_106278.jpg  frame_154216.jpg
# frame_000962.jpg  frame_054867.jpg  frame_106279.jpg  frame_154217.jpg
# frame_000963.jpg  frame_054868.jpg  frame_106280.jpg  frame_154218.jpg
# ...
# frame_053700.jpg  frame_105303.jpg  frame_152502.jpg  frame_191272.jpg
# frame_053704.jpg  frame_105304.jpg  frame_152503.jpg  frame_191273.jpg
# frame_053707.jpg  frame_105306.jpg  frame_152504.jpg  frame_191275.jpg
# frame_053709.jpg  frame_105307.jpg  frame_152505.jpg  frame_191276.jpg
# frame_053711.jpg  frame_105308.jpg  frame_152506.jpg  frame_191278.jpg
# frame_053714.jpg  frame_105309.jpg  frame_152507.jpg  frame_191279.jpg
# frame_053715.jpg  frame_105310.jpg  frame_152508.jpg  frame_191280.jpg
# frame_053716.jpg  frame_105311.jpg  frame_152509.jpg  frame_191281.jpg
# frame_053719.jpg  frame_105312.jpg  frame_152510.jpg  frame_191282.jpg
# frame_053723.jpg  frame_105313.jpg  frame_152511.jpg  frame_191283.jpg
# frame_053726.jpg  frame_105314.jpg  frame_152512.jpg  frame_191284.jpg
# frame_053727.jpg  frame_105315.jpg  frame_152513.jpg  frame_191285.jpg
# frame_053728.jpg  frame_105316.jpg  frame_152514.jpg  frame_191286.jpg
# frame_053729.jpg  frame_105317.jpg  frame_152516.jpg  frame_191288.jpg
# frame_053730.jpg  frame_105318.jpg  frame_152517.jpg  frame_191289.jpg
# frame_053731.jpg  frame_105319.jpg  frame_152518.jpg  frame_191290.jpg
# frame_053732.jpg  frame_105320.jpg  frame_152519.jpg  frame_191291.jpg
# frame_053733.jpg  frame_105321.jpg  frame_152520.jpg  frame_191292.jpg
# frame_053734.jpg  frame_105322.jpg  frame_152521.jpg  frame_191294.jpg
# frame_053736.jpg  frame_105324.jpg  frame_152522.jpg  frame_191295.jpg
# frame_053737.jpg  frame_105325.jpg  frame_152523.jpg  frame_191296.jpg
# frame_053738.jpg  frame_105326.jpg  frame_152524.jpg  frame_191297.jpg
# frame_053739.jpg  frame_105327.jpg  frame_152525.jpg  frame_191298.jpg
# frame_053740.jpg  frame_105328.jpg  frame_152526.jpg  frame_191300.jpg
# frame_053741.jpg  frame_105329.jpg  frame_152527.jpg  frame_191301.jpg
# frame_053742.jpg  frame_105330.jpg  frame_152528.jpg  frame_191302.jpg
# frame_053743.jpg  frame_105332.jpg  frame_152529.jpg  frame_191303.jpg
# frame_053744.jpg  frame_105333.jpg  frame_152530.jpg  frame_191304.jpg
# frame_053745.jpg  frame_105334.jpg  frame_152531.jpg  frame_191305.jpg
# frame_053746.jpg  frame_105335.jpg  frame_152532.jpg  frame_191306.jpg
# frame_053747.jpg  frame_105337.jpg  frame_152533.jpg  frame_191307.jpg
# frame_053748.jpg  frame_105338.jpg  frame_152534.jpg  frame_191308.jpg
# frame_053749.jpg  frame_105339.jpg  frame_152535.jpg  frame_191310.jpg
# frame_053750.jpg  frame_105340.jpg  frame_152536.jpg  frame_191311.jpg
# frame_053751.jpg  frame_105342.jpg  frame_152537.jpg  frame_191312.jpg
# frame_053752.jpg  frame_105343.jpg  frame_152538.jpg  frame_191313.jpg
# frame_053753.jpg  frame_105344.jpg  frame_152539.jpg  frame_191314.jpg
# frame_053754.jpg  frame_105345.jpg  frame_152540.jpg  frame_191315.jpg
# frame_053755.jpg  frame_105346.jpg  frame_152541.jpg  frame_191316.jpg
# frame_053756.jpg  frame_105347.jpg  frame_152542.jpg  frame_191317.jpg
# frame_053757.jpg  frame_105349.jpg  frame_152543.jpg  frame_191318.jpg
# frame_053758.jpg  frame_105351.jpg  frame_152544.jpg  frame_191319.jpg
# frame_053759.jpg  frame_105352.jpg  frame_152545.jpg  frame_191320.jpg
# frame_053760.jpg  frame_105353.jpg  frame_152547.jpg  frame_191321.jpg
# frame_053761.jpg  frame_105354.jpg  frame_152548.jpg  frame_191323.jpg
# frame_053762.jpg  frame_105355.jpg  frame_152549.jpg  frame_191324.jpg
# frame_053763.jpg  frame_105357.jpg  frame_152550.jpg  frame_191325.jpg
# frame_053764.jpg  frame_105358.jpg  frame_152551.jpg  frame_191326.jpg
# frame_053765.jpg  frame_105359.jpg  frame_152552.jpg  frame_191327.jpg
# frame_053766.jpg  frame_105360.jpg  frame_152553.jpg  frame_191329.jpg
# frame_053767.jpg  frame_105361.jpg  frame_152554.jpg  frame_191330.jpg
# frame_053768.jpg  frame_105362.jpg  frame_152555.jpg  frame_191331.jpg
# frame_053769.jpg  frame_105363.jpg  frame_152556.jpg  frame_191332.jpg
# frame_053770.jpg  frame_105364.jpg  frame_152557.jpg  frame_191333.jpg
# frame_053771.jpg  frame_105365.jpg  frame_152558.jpg  frame_191335.jpg
# frame_053772.jpg  frame_105366.jpg  frame_152559.jpg  frame_191336.jpg
# frame_053773.jpg  frame_105367.jpg  frame_152560.jpg  frame_191338.jpg
# frame_053774.jpg  frame_105368.jpg  frame_152562.jpg  frame_191339.jpg
# frame_053775.jpg  frame_105369.jpg  frame_152563.jpg  frame_191340.jpg
# frame_053776.jpg  frame_105370.jpg  frame_152564.jpg  frame_191341.jpg
# frame_053777.jpg  frame_105372.jpg  frame_152565.jpg  frame_191342.jpg
# frame_053778.jpg  frame_105373.jpg  frame_152566.jpg  frame_191343.jpg
# frame_053779.jpg  frame_105375.jpg  frame_152567.jpg  frame_191345.jpg
# frame_053780.jpg  frame_105376.jpg  frame_152568.jpg  frame_191346.jpg
# frame_053781.jpg  frame_105377.jpg  frame_152569.jpg  frame_191348.jpg
# frame_053782.jpg  frame_105378.jpg  frame_152570.jpg  frame_191349.jpg
# frame_053783.jpg  frame_105379.jpg  frame_152571.jpg  frame_191350.jpg
# frame_053784.jpg  frame_105380.jpg  frame_152572.jpg  frame_191351.jpg
# frame_053785.jpg  frame_105381.jpg  frame_152573.jpg  frame_191352.jpg
# frame_053786.jpg  frame_105382.jpg  frame_152574.jpg  frame_191354.jpg
# frame_053787.jpg  frame_105383.jpg  frame_152575.jpg  frame_191355.jpg
# frame_053788.jpg  frame_105384.jpg  frame_152576.jpg  frame_191356.jpg
# frame_053789.jpg  frame_105385.jpg  frame_152577.jpg  frame_191357.jpg
# frame_053790.jpg  frame_105387.jpg  frame_152578.jpg  frame_191358.jpg
# frame_053791.jpg  frame_105388.jpg  frame_152579.jpg  frame_191359.jpg
# frame_053792.jpg  frame_105389.jpg  frame_152580.jpg  frame_191360.jpg
# frame_053793.jpg  frame_105390.jpg  frame_152581.jpg  frame_191361.jpg
# frame_053794.jpg  frame_105391.jpg  frame_152582.jpg  frame_191362.jpg
# frame_053795.jpg  frame_105392.jpg  frame_152583.jpg  frame_191363.jpg
# frame_053796.jpg  frame_105393.jpg  frame_152584.jpg  frame_191364.jpg
# frame_053797.jpg  frame_105394.jpg  frame_152585.jpg  frame_191365.jpg
# frame_053798.jpg  frame_105395.jpg  frame_152586.jpg  frame_191366.jpg
# frame_053799.jpg  frame_105396.jpg  frame_152587.jpg  frame_191367.jpg
# frame_053800.jpg  frame_105397.jpg  frame_152588.jpg  frame_191368.jpg
# frame_053801.jpg  frame_105398.jpg  frame_152589.jpg  frame_191370.jpg
# frame_053802.jpg  frame_105399.jpg  frame_152590.jpg  frame_191371.jpg
# frame_053803.jpg  frame_105400.jpg  frame_152592.jpg  frame_191373.jpg
# frame_053804.jpg  frame_105401.jpg  frame_152593.jpg  frame_191374.jpg
# frame_053805.jpg  frame_105402.jpg  frame_152594.jpg  frame_191375.jpg
# frame_053806.jpg  frame_105403.jpg  frame_152595.jpg  frame_191376.jpg
# frame_053807.jpg  frame_105404.jpg  frame_152596.jpg  frame_191377.jpg
# frame_053808.jpg  frame_105405.jpg  frame_152597.jpg  frame_191378.jpg
# frame_053810.jpg  frame_105407.jpg  frame_152598.jpg  frame_191380.jpg
# frame_053811.jpg  frame_105408.jpg  frame_152599.jpg  frame_191381.jpg
# frame_053813.jpg  frame_105409.jpg  frame_152600.jpg  frame_191383.jpg
# frame_053814.jpg  frame_105410.jpg  frame_152601.jpg  frame_191384.jpg
# frame_053815.jpg  frame_105412.jpg  frame_152602.jpg  frame_191385.jpg
# frame_053816.jpg  frame_105413.jpg  frame_152603.jpg  frame_191386.jpg
# frame_053817.jpg  frame_105414.jpg  frame_152604.jpg  frame_191387.jpg
# frame_053818.jpg  frame_105415.jpg  frame_152605.jpg  frame_191389.jpg
# frame_053819.jpg  frame_105416.jpg  frame_152606.jpg  frame_191390.jpg
# frame_053820.jpg  frame_105417.jpg  frame_152607.jpg  frame_191391.jpg
# frame_053821.jpg  frame_105418.jpg  frame_152608.jpg  frame_191393.jpg
# frame_053822.jpg  frame_105419.jpg  frame_152609.jpg  frame_191394.jpg
# frame_053823.jpg  frame_105420.jpg  frame_152610.jpg  frame_191395.jpg
# frame_053824.jpg  frame_105421.jpg  frame_152611.jpg  frame_191396.jpg
# frame_053825.jpg  frame_105422.jpg  frame_152612.jpg  frame_191397.jpg
# frame_053826.jpg  frame_105423.jpg  frame_152613.jpg  frame_191399.jpg
# frame_053827.jpg  frame_105424.jpg  frame_152614.jpg  frame_191400.jpg
# frame_053828.jpg  frame_105425.jpg  frame_152615.jpg  frame_191401.jpg
# frame_053829.jpg  frame_105426.jpg  frame_152616.jpg  frame_191402.jpg
# frame_053830.jpg  frame_105427.jpg  frame_152617.jpg  frame_191403.jpg
# frame_053831.jpg  frame_105428.jpg  frame_152618.jpg  frame_191405.jpg
# frame_053832.jpg  frame_105429.jpg  frame_152619.jpg  frame_191406.jpg
# frame_053833.jpg  frame_105430.jpg  frame_152620.jpg  frame_191408.jpg
# frame_053834.jpg  frame_105431.jpg  frame_152621.jpg  frame_191409.jpg
# frame_053835.jpg  frame_105433.jpg  frame_152622.jpg  frame_191410.jpg
# frame_053836.jpg  frame_105434.jpg  frame_152623.jpg  frame_191411.jpg
# frame_053837.jpg  frame_105435.jpg  frame_152624.jpg  frame_191412.jpg
# frame_053838.jpg  frame_105436.jpg  frame_152625.jpg  frame_191413.jpg
# frame_053839.jpg  frame_105437.jpg  frame_152626.jpg  frame_191415.jpg
# frame_053840.jpg  frame_105438.jpg  frame_152627.jpg  frame_191416.jpg
# frame_053841.jpg  frame_105439.jpg  frame_152628.jpg  frame_191418.jpg
# frame_053842.jpg  frame_105440.jpg  frame_152629.jpg  frame_191419.jpg
# frame_053843.jpg  frame_105441.jpg  frame_152630.jpg  frame_191420.jpg
# frame_053844.jpg  frame_105442.jpg  frame_152631.jpg  frame_191421.jpg
# frame_053845.jpg  frame_105443.jpg  frame_152632.jpg  frame_191422.jpg
# frame_053846.jpg  frame_105444.jpg  frame_152633.jpg  frame_191423.jpg
# frame_053847.jpg  frame_105445.jpg  frame_152634.jpg  frame_191424.jpg
# frame_053848.jpg  frame_105446.jpg  frame_152635.jpg  frame_191425.jpg
# frame_053849.jpg  frame_105447.jpg  frame_152636.jpg  frame_191426.jpg
# frame_053850.jpg  frame_105448.jpg  frame_152637.jpg  frame_191428.jpg
# frame_053851.jpg  frame_105449.jpg  frame_152638.jpg  frame_191429.jpg
# frame_053852.jpg  frame_105450.jpg  frame_152639.jpg  frame_191430.jpg
# frame_053853.jpg  frame_105451.jpg  frame_152640.jpg  frame_191431.jpg
# frame_053854.jpg  frame_105452.jpg  frame_152641.jpg  frame_191432.jpg
# frame_053855.jpg  frame_105453.jpg  frame_152643.jpg  frame_191434.jpg
# frame_053856.jpg  frame_105454.jpg  frame_152644.jpg  frame_191435.jpg
# frame_053857.jpg  frame_105455.jpg  frame_152645.jpg  frame_191436.jpg
# frame_053858.jpg  frame_105456.jpg  frame_152646.jpg  frame_191437.jpg
# frame_053859.jpg  frame_105457.jpg  frame_152647.jpg  frame_191438.jpg
# frame_053860.jpg  frame_105458.jpg  frame_152648.jpg  frame_191440.jpg
# frame_053861.jpg  frame_105459.jpg  frame_152649.jpg  frame_191441.jpg
# frame_053862.jpg  frame_105460.jpg  frame_152650.jpg  frame_191443.jpg
# frame_053863.jpg  frame_105461.jpg  frame_152651.jpg  frame_191444.jpg
# frame_053864.jpg  frame_105462.jpg  frame_152652.jpg  frame_191445.jpg
# frame_053865.jpg  frame_105463.jpg  frame_152653.jpg  frame_191446.jpg
# frame_053866.jpg  frame_105464.jpg  frame_152654.jpg  frame_191447.jpg
# frame_053867.jpg  frame_105465.jpg  frame_152655.jpg  frame_191448.jpg
# frame_053868.jpg  frame_105466.jpg  frame_152656.jpg  frame_191450.jpg
# frame_053869.jpg  frame_105467.jpg  frame_152658.jpg  frame_191451.jpg
# frame_053870.jpg  frame_105468.jpg  frame_152659.jpg  frame_191453.jpg
# frame_053871.jpg  frame_105469.jpg  frame_152660.jpg  frame_191454.jpg
# frame_053872.jpg  frame_105470.jpg  frame_152661.jpg  frame_191455.jpg
# frame_053873.jpg  frame_105471.jpg  frame_152662.jpg  frame_191456.jpg
# frame_053874.jpg  frame_105472.jpg  frame_152663.jpg  frame_191457.jpg
# frame_053875.jpg  frame_105473.jpg  frame_152664.jpg  frame_191459.jpg
# frame_053876.jpg  frame_105474.jpg  frame_152665.jpg  frame_191460.jpg
# frame_053878.jpg  frame_105475.jpg  frame_152666.jpg  frame_191461.jpg
# frame_053879.jpg  frame_105476.jpg  frame_152667.jpg  frame_191463.jpg
# frame_053880.jpg  frame_105477.jpg  frame_152668.jpg  frame_191464.jpg
# frame_053881.jpg  frame_105478.jpg  frame_152669.jpg  frame_191465.jpg
# frame_053882.jpg  frame_105479.jpg  frame_152670.jpg  frame_191466.jpg
# frame_053883.jpg  frame_105480.jpg  frame_152671.jpg  frame_191467.jpg
# frame_053884.jpg  frame_105481.jpg  frame_152672.jpg  frame_191468.jpg
# frame_053885.jpg  frame_105482.jpg  frame_152673.jpg  frame_191469.jpg
# frame_053886.jpg  frame_105483.jpg  frame_152674.jpg  frame_191470.jpg
# frame_053887.jpg  frame_105484.jpg  frame_152675.jpg  frame_191471.jpg
# frame_053888.jpg  frame_105485.jpg  frame_152676.jpg  frame_191472.jpg
# frame_053889.jpg  frame_105486.jpg  frame_152677.jpg  frame_191473.jpg
# frame_053890.jpg  frame_105487.jpg  frame_152678.jpg  frame_191475.jpg
# frame_053891.jpg  frame_105488.jpg  frame_152679.jpg  frame_191476.jpg
# frame_053892.jpg  frame_105489.jpg  frame_152680.jpg  frame_191478.jpg
# frame_053893.jpg  frame_105490.jpg  frame_152681.jpg  frame_191479.jpg
# frame_053894.jpg  frame_105491.jpg  frame_152682.jpg  frame_191480.jpg
# frame_053895.jpg  frame_105492.jpg  frame_152683.jpg  frame_191481.jpg
# frame_053896.jpg  frame_105493.jpg  frame_152685.jpg  frame_191482.jpg
# frame_053897.jpg  frame_105494.jpg  frame_152686.jpg  frame_191483.jpg
# frame_053898.jpg  frame_105495.jpg  frame_152687.jpg  frame_191485.jpg
# frame_053899.jpg  frame_105497.jpg  frame_152688.jpg  frame_191486.jpg
# frame_053900.jpg  frame_105498.jpg  frame_152689.jpg  frame_191488.jpg
# frame_053901.jpg  frame_105499.jpg  frame_152690.jpg  frame_191489.jpg
# frame_053902.jpg  frame_105500.jpg  frame_152691.jpg  frame_191490.jpg
# frame_053903.jpg  frame_105501.jpg  frame_152692.jpg  frame_191491.jpg
# frame_053904.jpg  frame_105502.jpg  frame_152693.jpg  frame_191492.jpg
# frame_053905.jpg  frame_105503.jpg  frame_152695.jpg  frame_191494.jpg
# frame_053906.jpg  frame_105504.jpg  frame_152696.jpg  frame_191495.jpg
# frame_053907.jpg  frame_105505.jpg  frame_152697.jpg  frame_191496.jpg
# frame_053908.jpg  frame_105506.jpg  frame_152698.jpg  frame_191498.jpg
# frame_053909.jpg  frame_105507.jpg  frame_152699.jpg  frame_191499.jpg
# frame_053910.jpg  frame_105508.jpg  frame_152700.jpg  frame_191500.jpg
# frame_053911.jpg  frame_105509.jpg  frame_152701.jpg  frame_191501.jpg
# frame_053912.jpg  frame_105510.jpg  frame_152702.jpg  frame_191502.jpg
# frame_053913.jpg  frame_105511.jpg  frame_152703.jpg  frame_191504.jpg
# frame_053914.jpg  frame_105512.jpg  frame_152704.jpg  frame_191505.jpg
# frame_053915.jpg  frame_105513.jpg  frame_152705.jpg  frame_191506.jpg
# frame_053916.jpg  frame_105514.jpg  frame_152706.jpg  frame_191507.jpg
# frame_053917.jpg  frame_105515.jpg  frame_152707.jpg  frame_191508.jpg
# frame_053918.jpg  frame_105516.jpg  frame_152708.jpg  frame_191510.jpg
# frame_053919.jpg  frame_105517.jpg  frame_152709.jpg  frame_191511.jpg
# frame_053920.jpg  frame_105518.jpg  frame_152710.jpg  frame_191513.jpg
# frame_053921.jpg  frame_105519.jpg  frame_152711.jpg  frame_191514.jpg
# frame_053923.jpg  frame_105520.jpg  frame_152712.jpg  frame_191515.jpg
# frame_053924.jpg  frame_105521.jpg  frame_152713.jpg  frame_191516.jpg
# frame_053925.jpg  frame_105522.jpg  frame_152714.jpg  frame_191517.jpg
# frame_053926.jpg  frame_105523.jpg  frame_152715.jpg  frame_191518.jpg
# frame_053927.jpg  frame_105524.jpg  frame_152716.jpg  frame_191520.jpg
# frame_053928.jpg  frame_105525.jpg  frame_152717.jpg  frame_191521.jpg
# frame_053929.jpg  frame_105526.jpg  frame_152718.jpg  frame_191523.jpg
# frame_053930.jpg  frame_105527.jpg  frame_152719.jpg  frame_191524.jpg
# frame_053931.jpg  frame_105528.jpg  frame_152720.jpg  frame_191525.jpg
# frame_053932.jpg  frame_105529.jpg  frame_152721.jpg  frame_191526.jpg
# frame_053933.jpg  frame_105530.jpg  frame_152722.jpg  frame_191527.jpg
# frame_053934.jpg  frame_105531.jpg  frame_152723.jpg  frame_191529.jpg
# frame_053935.jpg  frame_105532.jpg  frame_152724.jpg  frame_191530.jpg
# frame_053936.jpg  frame_105533.jpg  frame_152725.jpg  frame_191661.jpg
# frame_053937.jpg  frame_105534.jpg  frame_152726.jpg  frame_191676.jpg
# frame_053938.jpg  frame_105535.jpg  frame_152727.jpg  frame_191796.jpg
# frame_053939.jpg  frame_105536.jpg  frame_152728.jpg  frame_191811.jpg
# frame_053940.jpg  frame_105537.jpg  frame_152729.jpg  frame_191842.jpg
# frame_053941.jpg  frame_105538.jpg  frame_152730.jpg  frame_191857.jpg
# frame_053942.jpg  frame_105539.jpg  frame_152731.jpg  frame_191872.jpg
# frame_053943.jpg  frame_105540.jpg  frame_152732.jpg  frame_191879.jpg
# frame_053944.jpg  frame_105541.jpg  frame_152733.jpg
# frame_053945.jpg  frame_105542.jpg  frame_152734.jpg

# %%
import os,inspect
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
import torch.nn as nn

#from torch.cuda.amp import GradScaler
#from torch.cuda.amp import autocast

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim

import warnings
warnings.filterwarnings('ignore')

cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 4 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  4  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# # 1. PairWise DataLoader

# %% [markdown]
# # 2. Data Loading Example

# %%
np.random.seed(0)
df = pd.read_csv("/content/gdrive/MyDrive/pair_out.csv")
print(df.shape[0])
df['split'] = np.random.randn(df.shape[0], 1)
df = df.iloc[:, 1:]
train_msk = df['split'] <= 0.7
val_msk = (df['split'] > 0.7) & (df['split'] <= 0.85)
test_msk = df['split'] > 0.85
train_data = df[train_msk]
val_data = df[val_msk]
test_data = df[test_msk]
# Out:
# 119593

# %%
train_data = train_data.drop('split', 1).reset_index().drop('index',1)
val_data = val_data.drop('split',1).reset_index().drop('index',1)
test_data = test_data.drop('split',1).reset_index().drop('index',1)

# %%
# Define dataset class


class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["[","]",",","'"]:
          x = x.replace(c, "")
          y = y.replace(c,"")
        x = x.split(" ")
        y = y.split(" ")
        y = list(map(lambda x:int(x),y))
        y = torch.FloatTensor(y)
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            img = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                  std=[0.229, 0.224, 0.225])(img)
            images.append(img)
        x = torch.stack(images)
        return x, y

# %%
cur_dir = '/content/converted_224x224/'

# %%
batch_size = 32

# training data
train_set = MyDataSet(train_data)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)
# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %%
# Model 

#These libraries help to interact with the operating system and the runtime environment respectively
import os
import sys

#Model/Training related libraries
import numpy as np
import torch
import torch.nn as nn
from torch import autograd
from torch.autograd import Variable
import torch.nn.functional as F
import torch.optim as optim
import time
from tqdm import tqdm
import pandas as pd
import matplotlib.pyplot as plt
from torchvision import transforms, datasets

#Dataloader libraries
from torch.utils.data import DataLoader, Dataset
from PIL import Image

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channel, out_channel,stride=1):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channel, out_channel, kernel_size=3, stride=stride, padding=1, bias=False, dilation = 1)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.relu1 = nn.ReLU(inplace = True)
        self.conv2 = nn.Conv2d(out_channel, out_channel, kernel_size=3, stride=1, padding= 1, bias=False, dilation = 1)
        self.bn2 =  nn.BatchNorm2d(out_channel)
        if stride == 1:
            self.shortcut = nn.Identity()
        else:
            self.shortcut = nn.Conv2d(in_channel, out_channel, kernel_size=1, stride=stride)
        self.relu2 = nn.ReLU(inplace = True)
    
    def forward(self, x):
        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu1(out)

        out = self.conv2(out)
        out = self.bn2(out)

        shortcut = self.shortcut(x) 
        out = self.relu2(out + shortcut)
        
        return out

# %%
# Instead of using loop
# use slicing:   tesor[index. ..]
# x.squeeze(): squeeze to a vector; remove dimesion;
# x.unsqueeze(1); turns to (#,1)
# tensor.t() only applys to a two dimension tensor
# tensor.transpose applys to all dimesions;
# tensor.transpose(0,1) which dimension to switch
# view tensor won't create a copy; use the view to change the data; (only continous)
# x = x.view(3,4) print(x.is_continous); if you use transpose before, then the x.view won't work becasue view
# is not a contious action
# reshape tensor; (continous and noncontinous)
# x.shape
# check wheter a tensor is continous or not
# is_contiguous() check
# tensor.contiguous()  regturn a contiguous
# tensor.is_contiguous()
#print(tensor)
#print(tensor.stride()) whether the memory is left to right; top to bottom;

# unsqueeze can adding dimensions of 1;

# permute changes the order; transpose is a special case of permute

# %%
# create a tensor
# x.requires_grad_(True); will create a computational graph
# x.grad

# %%
# slicing & torch.cat

# %%
class ClassificationNetwork(nn.Module):
    def __init__(self, in_features, num_classes,feat_dim = 512):
        super().__init__()
        
        self.layers = nn.Sequential(
            nn.Conv2d(in_features, 64, kernel_size=7, stride=2, padding=3, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace = True),
            nn.MaxPool2d(kernel_size = 3, stride = 2, padding = 1),
            ResidualBlock(64,64),
            ResidualBlock(64,64),
            ResidualBlock(64,64),
            ResidualBlock(64,128,stride = 2),
            ResidualBlock(128,128),
            ResidualBlock(128,128),
            ResidualBlock(128,128),
            ResidualBlock(128,256,stride = 2),
            ResidualBlock(256,256),
            ResidualBlock(256,256),
            ResidualBlock(256,256),
            ResidualBlock(256,256),
            ResidualBlock(256,256),
            ResidualBlock(256,512,stride = 2),
            ResidualBlock(512,512),
            ResidualBlock(512,512),
            nn.AdaptiveAvgPool2d((1, 1)), # For each channel, collapses (averages) the entire feature map (height & width) to 1x1
            nn.Flatten(1), # the above ends up with batch_size x 512 x 1 x 1, flatten to batch_size x 512
        )
        self.linear_emb = nn.Linear(512, feat_dim)
        self.relu = nn.ReLU(inplace=True)
        # output of CNN is b*5, 512 
        # before put into linear, has to reshape to x
        self.linear_output_1 = nn.Linear(1024,512)
        self.relu_output = nn.ReLU(inplace=True)
        self.dropout_output = nn.Dropout(p=0.4)
        self.linear_output_2 = nn.Linear(512,num_classes)
        self.sigm = nn.Sigmoid()

        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
          elif isinstance(m, (nn.BatchNorm2d)):
            nn.init.constant_(m.weight, 1)
            nn.init.constant_(m.bias, 0) 

        for m in self.modules():
          if isinstance(m, ResidualBlock):
            nn.init.constant_(m.bn2.weight, 0)  # type: ignore[arg-type]  

    def forward(self, x, return_embedding=False):
        embedding = self.layers(x)
        embedding_out = self.linear_emb(embedding)
        embedding_out = self.relu(embedding_out)

        # output of CNN is b*5, 512 
        # before put into linear, has to reshape to x
        embedding.requires_grad_(True)
        embedding_reshape = torch.reshape(embedding, (-1,5,512))
        # embedding shape is b * 5 * 512
        # slicing and stack
        final_embeddings = []
        B,I,_ = embedding_reshape.shape
        for b in range(B):
          batch = embedding_reshape[b,:,:]
          batch_pair_embeddings = []
          for i in range(I):
            for j in range(i+1, I):
              pair_embedding_1 = batch[i,:]
              pair_embedding_2 = batch[j,:]
              pairs = torch.cat((pair_embedding_1,pair_embedding_2),dim=0)
              batch_pair_embeddings.append(pairs)
          paired_embeddings = torch.stack(batch_pair_embeddings)
          final_embeddings.append(paired_embeddings)
        # batch * 10 , 1024
        paris_embdeddings = torch.stack(final_embeddings).reshape(-1,1024) 
        output = self.linear_output_1(paris_embdeddings)
        output = self.relu_output(output)
        output = self.dropout_output(output)
        # output dimension is b*10, 1
        output = self.linear_output_2(output)
        output = self.sigm(output)

        if return_embedding:
            return embedding_out,output
        else:
            return output

# %%
class ConstomLoss(nn.Module):
    def __init__(self):
        super(ConstomLoss, self).__init__()
 
    def forward(self, out, targets):
      # out shape (b*10, 1)
      # target shape batch * 10
      targets = targets.reshape(-1,1)
      batch, pairs = targets.shape
      loss = torch.nn.BCELoss()(out, targets)
      return loss

# %%
# Train the model

def train_model(train_loader,train_dataset,model,criterion, optimizer):
    training_loss = 0
    accuracy = 0.0
    # Set model in 'Training mode'
    model.train()
    start_time = time.time()
    with tqdm(train_loader) as t:
      for i, (x, y) in enumerate(train_loader):
        t.set_description("Training")
        # clear the gradients
        optimizer.zero_grad()
        x.requires_grad_(True)
        # all data & model on same device
        x = torch.reshape(x, (-1,3, 224, 224))
        x = x.to(device)
        y = y.to(device)
        # compute the model output
        out = model(x)
        # y shape: batch * 10
        # calculate loss
        loss = criterion(out, y)
        # call scalar loss
        # Backward pass
        loss.backward()
        # Update model weights 
        optimizer.step()
       

        #caculate accuracy
        p = torch.reshape(out, (-1, 10) )
        predict = (p > 0.5) * (torch.ones(p.shape).to(device))
        accuracy += (predict == y).sum().item()
        
        training_loss += loss.item()

    end_time = time.time()
    acc = accuracy/(len(train_dataset)*10)
    training_loss /= len(train_loader)
    print('Training Loss: ', training_loss, 'Time: ',end_time - start_time, 's')
    print("Training accuracy: ", acc)
    torch.cuda.empty_cache()
    del x
    del y
    del loss
    return training_loss,acc

# %%
# Evaluate the model

def evaluate_model(val_loader, val_dataset, model,criterion):
  with torch.no_grad():
    model.eval()
    val_loss = 0.0
    accuracy = 0
    # Set model in validation mode
    
    with tqdm(val_loader) as t:
      for i, (x, y) in enumerate(val_loader):
        t.set_description("Evaluating")
         # all data & model on same device
        x = torch.reshape(x, (-1,3, 224, 224))
        x = x.to(device)
        y = y.to(device)
        # evaluate the model on the validation set
        out = model(x)  
        # Calculate validation loss
        # reshape the result from (b*10, 1) to b * 10
        # calculate loss
        loss = criterion(out, y)
  
        #caculate accuracy
        p = torch.reshape(out, (-1, 10) )
        predict = (p > 0.5) * (torch.ones(p.shape).to(device))
        accuracy += (predict == y).sum().item()
        
        val_loss += loss.item()
    
    # Calculate validation accuracy
    acc = accuracy/(len(val_dataset)*10)
    # calculate val loss
    val_loss /= len(val_loader)
    return val_loss,acc

# %%
numEpochs = 80
in_features = 3 # RGB channels
learningRate = 1e-2
weightDecay = 1e-4
num_classes = 1 # only 0 or 1


device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = ClassificationNetwork(in_features, num_classes)
#model = model.to(device)
#print(model)
# Define customized Loss function
criterion = ConstomLoss()

# Adam
optimizer = torch.optim.Adam(model.parameters(), lr=learningRate, weight_decay=weightDecay)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

# %%
base_acc = 0.0

# Define number of epochs
for epoch in range(numEpochs):
    
    # Train
    training_loss, train_acc= train_model(train_loader,train_set,model,criterion, optimizer)
    
    # Validation for validation dataset
    val_loss,val_acc = evaluate_model(val_loader,val_set,model,criterion)

    # scheduler
    scheduler.step(val_loss)
    print("Epoch: ",epoch+1,", current lr:", optimizer.state_dict()['param_groups'][0]['lr'])

    if val_acc > base_acc:
      model_save_name = 'shot_detection.pt'
      path = F"/content/gdrive/My Drive/{model_save_name}"
      print("Epoch: "+str(epoch+1)+",saved model parameter") 
      torch.save(model.state_dict(), path)
      base_acc = val_acc
    
    # Print log of training & validate accuracy
    print("Epoch: "+str(epoch+1)+", Training accuracy: "+str(train_acc*100)+"%, Validation accuracy:"+str(val_acc*100)+"%, Training loss: "+str(training_loss)+", Validation loss:"+str( val_loss))
# Out:
# Training:   0%|          | 0/2834 [22:36<?, ?it/s]
# Training Loss:  0.6964791181984298 Time:  1356.727807044983 s
# Training accuracy:  0.4995776123518059
# Evaluating:   0%|          | 0/166 [00:30<?, ?it/s]
# Epoch:  1 , current lr: 0.01
# Epoch: 1,saved model parameter
# Epoch: 1, Training accuracy: 49.95776123518059%, Validation accuracy:50.797128825085004%, Training loss: 0.6964791181984298, Validation loss:0.6930674206779663
# Training:   0%|          | 0/2834 [22:36<?, ?it/s]
# Training Loss:  0.6934839486865486 Time:  1356.8815035820007 s
# Training accuracy:  0.49884532671629445
# Evaluating:   0%|          | 0/166 [00:30<?, ?it/s]
# Epoch:  2 , current lr: 0.01
# Epoch: 2, Training accuracy: 49.884532671629444%, Validation accuracy:50.797128825085004%, Training loss: 0.6934839486865486, Validation loss:0.6931431379662939
# Training:   0%|          | 0/2834 [22:37<?, ?it/s]
# Training Loss:  0.6935397132694847 Time:  1357.5805752277374 s
# Training accuracy:  0.5001543975737525
# Evaluating:   0%|          | 0/166 [00:30<?, ?it/s]
# Epoch:  3 , current lr: 0.01
# Epoch: 3, Training accuracy: 50.01543975737525%, Validation accuracy:49.202871174914996%, Training loss: 0.6935397132694847, Validation loss:0.693183932677809
# Training:   0%|          | 0/2834 [22:36<?, ?it/s]
# Training Loss:  0.6934875503087767 Time:  1356.0179266929626 s
# Training accuracy:  0.5001345464571271
# Evaluating:   0%|          | 0/166 [00:30<?, ?it/s]
# Epoch:  4 , current lr: 0.01
# Epoch: 4, Training accuracy: 50.013454645712706%, Validation accuracy:49.202871174914996%, Training loss: 0.6934875503087767, Validation loss:0.6937822857535029
# Training:   0%|          | 0/2834 [22:37<?, ?it/s]
# Training Loss:  0.6935143066950052 Time:  1357.0089995861053 s
# Training accuracy:  0.4991100082712986
# Evaluating:   0%|          | 0/166 [00:30<?, ?it/s]
# Epoch:  5 , current lr: 0.005
# Epoch: 5, Training accuracy: 49.91100082712986%, Validation accuracy:50.797128825085004%, Training loss: 0.6935143066950052, Validation loss:0.693029419844409
# Training:   0%|          | 0/2834 [22:37<?, ?it/s]
# Training Loss:  0.6932099568397964 Time:  1357.1161012649536 s
# Training accuracy:  0.49923352633030055
# Evaluating:   0%|          | 0/166 [00:31<?, ?it/s]
# Epoch:  6 , current lr: 0.005
# Epoch: 6, Training accuracy: 49.923352633030056%, Validation accuracy:50.797128825085004%, Training loss: 0.6932099568397964, Validation loss:0.6931079924106598
# Training:   0%|          | 0/2834 [22:38<?, ?it/s]
# Training Loss:  0.6933152101665798 Time:  1358.20028090477 s
# Training accuracy:  0.5001952026468155
# Evaluating:   0%|          | 0/166 [00:30<?, ?it/s]
# Epoch:  7 , current lr: 0.005
# Epoch: 7, Training accuracy: 50.019520264681546%, Validation accuracy:50.797128825085004%, Training loss: 0.6933152101665798, Validation loss:0.6931311046502676
# Training:   0%|          | 0/2834 [22:38<?, ?it/s]
# Training Loss:  0.6933413827469758 Time:  1358.481060743332 s
# Training accuracy:  0.5001764543700028
# Evaluating:   0%|          | 0/166 [00:31<?, ?it/s]
# Epoch:  8 , current lr: 0.005
# Epoch: 8, Training accuracy: 50.01764543700028%, Validation accuracy:50.797128825085004%, Training loss: 0.6933413827469758, Validation loss:0.6930227846984404
# Training:   0%|          | 0/2834 [22:38<?, ?it/s]
# Training Loss:  0.6932988561369116 Time:  1358.1274778842926 s
# Training accuracy:  0.49883870967741933
# Evaluating:   0%|          | 0/166 [00:31<?, ?it/s]
# Epoch:  9 , current lr: 0.0025
# Epoch: 9, Training accuracy: 49.883870967741935%, Validation accuracy:50.797128825085004%, Training loss: 0.6932988561369116, Validation loss:0.6931470050869217
# Training:   0%|          | 0/2834 [22:39<?, ?it/s]
# Training Loss:  0.6931767127803286 Time:  1359.107582807541 s
# Training accuracy:  0.49953019023986767
# Evaluating:   0%|          | 0/166 [00:31<?, ?it/s]
# Epoch:  10 , current lr: 0.0025
# Epoch: 10, Training accuracy: 49.95301902398677%, Validation accuracy:49.202871174914996%, Training loss: 0.6931767127803286, Validation loss:0.693157055650849
# Training:   0%|          | 0/2834 [22:42<?, ?it/s]
# Training Loss:  0.6932088282003989 Time:  1362.2981135845184 s
# Training accuracy:  0.5009131513647642
# Evaluating:   0%|          | 0/166 [00:31<?, ?it/s]
# Epoch:  11 , current lr: 0.0025
# Epoch: 11, Training accuracy: 50.091315136476425%, Validation accuracy:49.202871174914996%, Training loss: 0.6932088282003989, Validation loss:0.6933179178151739
# Training:   0%|          | 0/2834 [22:39<?, ?it/s]
# Training Loss:  0.6932137371918309 Time:  1359.2291185855865 s
# Training accuracy:  0.4985652054039151
# Evaluating:   0%|          | 0/166 [00:31<?, ?it/s]
# Epoch:  12 , current lr: 0.0025
# Epoch: 12, Training accuracy: 49.85652054039151%, Validation accuracy:50.797128825085004%, Training loss: 0.6932137371918309, Validation loss:0.6930614681128996
# Training:   0%|          | 0/2834 [22:37<?, ?it/s]
# Training Loss:  0.6932036194821521 Time:  1357.1944887638092 s
# Training accuracy:  0.4997452440033085
# Evaluating:   0%|          | 0/166 [00:30<?, ?it/s]
# Epoch:  13 , current lr: 0.00125
# Epoch: 13, Training accuracy: 49.97452440033085%, Validation accuracy:49.202871174914996%, Training loss: 0.6932036194821521, Validation loss:0.6941898522606815
# Training:   0%|          | 0/2834 [22:36<?, ?it/s]
# Training Loss:  0.6931878360712621 Time:  1356.8849551677704 s
# Training accuracy:  0.4997849462365591
# Evaluating:   0%|          | 0/166 [00:31<?, ?it/s]
# Epoch:  14 , current lr: 0.00125
# Epoch: 14, Training accuracy: 49.97849462365591%, Validation accuracy:50.797128825085004%, Training loss: 0.6931878360712621, Validation loss:0.6931038046457682
# Training:   0%|          | 0/2834 [22:37<?, ?it/s]
# Training Loss:  0.6931775203244149 Time:  1357.435725927353 s
# Training accuracy:  0.5006043562172594
# Evaluating:   0%|          | 0/166 [00:30<?, ?it/s]
# Epoch:  15 , current lr: 0.00125
# Epoch: 15, Training accuracy: 50.060435621725944%, Validation accuracy:49.202871174914996%, Training loss: 0.6931775203244149, Validation loss:0.6932850322091436
# Training:   0%|          | 0/2834 [11:49<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-3c52eebb5353> in <module>()
#       5
#       6     # Train
# ----> 7     training_loss, train_acc= train_model(train_loader,train_set,model,criterion, optimizer)
#       8
#       9     # Validation for validation dataset
#
# <ipython-input-20-105a1dbc1bbe> in train_model(train_loader, train_dataset, model, criterion, optimizer)
#      24         # call scalar loss
#      25         # Backward pass
# ---> 26         loss.backward()
#      27         # Update model weights
#      28         optimizer.step()
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     157
#     158
#
# KeyboardInterrupt:

# %%
# load model

print("Loading model")
model_save_name = 'shot_detection.pt'
path = F"/content/gdrive/My Drive/{model_save_name}"
model_dict = torch.load(path)
model.load_state_dict(model_dict)
model = model.to(device)
print(model)
# Out:
# Loading model
# ClassificationNetwork(
#   (layers): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (5): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (6): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (7): ResidualBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#       (relu2): ReLU(inplace=True)
#     )
#     (8): ResidualBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (9): ResidualBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (10): ResidualBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (11): ResidualBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#       (relu2): ReLU(inplace=True)
#     )
#     (12): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (13): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (14): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (15): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (16): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (17): ResidualBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#       (relu2): ReLU(inplace=True)
#     )
#     (18): ResidualBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (19): ResidualBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu1): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#       (relu2): ReLU(inplace=True)
#     )
#     (20): AdaptiveAvgPool2d(output_size=(1, 1))
#     (21): Flatten(start_dim=1, end_dim=-1)
#   )
#   (linear_emb): Linear(in_features=512, out_features=512, bias=True)
#   (relu): ReLU(inplace=True)
#   (linear_output_1): Linear(in_features=1024, out_features=512, bias=True)
#   (relu_output): ReLU(inplace=True)
#   (dropout_output): Dropout(p=0.4, inplace=False)
#   (linear_output_2): Linear(in_features=512, out_features=1, bias=True)
#   (sigm): Sigmoid()
# )

# %%
torch.cuda.empty_cache()
with torch.no_grad():
  model.eval()
  accuracy = 0
  with tqdm(test_loader) as t:
    for i, (x, y) in enumerate(test_loader):
      t.set_description("Testing")
      # all data & model on same device
      x = torch.reshape(x, (-1,3, 224, 224))
      x = x.to(device)
      y = y.to(device)
      # evaluate the model on the validation set
      out = model(x)  
      #caculate accuracy
      p = torch.reshape(out, (-1, 10) )
      predict = (p > 0.5) * (torch.ones(p.shape).to(device))
      accuracy += (predict == y).sum().item()

    test_acc = accuracy/ (len(test_set)*10)
    print(test_acc)
# Out:
# Testing:   0%|          | 0/739 [02:22<?, ?it/s]
# 0.5015492719268541
