# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/dl_project/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("4+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149670.jpg', 'frame_149739.jpg', 'fram...     16
# 1      ('frame_149738.jpg', 'frame_149692.jpg', 'fram...     80
# 2      ('frame_149729.jpg', 'frame_149716.jpg', 'fram...     86
# 3      ('frame_149669.jpg', 'frame_149712.jpg', 'fram...      7
# 4      ('frame_149683.jpg', 'frame_149707.jpg', 'fram...     34
# ...                                                  ...    ...
# 17942  ('frame_180809.jpg', 'frame_174579.jpg', 'fram...    101
# 17943  ('frame_174581.jpg', 'frame_174634.jpg', 'fram...     14
# 17944  ('frame_174605.jpg', 'frame_174596.jpg', 'fram...     54
# 17945  ('frame_181123.jpg', 'frame_174585.jpg', 'fram...     96
# 17946  ('frame_181333.jpg', 'frame_174579.jpg', 'fram...     97
#
# [17947 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            images.extend(img)
        x = torch.stack(images)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([15, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
batch_size = 64

# training data
train_set = MyDataSet(train_data)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_images, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding*num_images, num_classes))


    def forward(self, x):
      x1 = x[:, 0:3, :, :]
      x2 = x[:, 3:6, :, :]
      x3 = x[:, 6:9, :, :]
      x4 = x[:, 9:12, :, :]
      x5 = x[:, 12:15, :, :]

      out1 = self.cnn(x1)
      out2 = self.cnn(x2)
      out3 = self.cnn(x3)
      out4 = self.cnn(x4)
      out5 = self.cnn(x5)

      out = torch.cat([out1, out2, out3, out4, out5], axis=1)
      logits = self.mlp(out)
      return logits

# %%
numEpochs = 100
in_features = 3 # TODO: change RGB channels according to num of frames
embedding = 128

learningRate = 0.01
weightDecay = 1e-4

num_images = 5
num_classes = 120

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_images, num_classes)
#network.load_state_dict(torch.load("model_checkpoints/resnet34/lr_0.1-2/model_2.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_4+1_base/best_model_" + str(epoch) + ".pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 0	Batch: 50	Avg-Loss: 4.8919	Training Accuracy : 0.0059
# Epoch: 0	Batch: 100	Avg-Loss: 4.8862	Training Accuracy : 0.0075
# Epoch: 0	Batch: 150	Avg-Loss: 4.8357	Training Accuracy : 0.0075
# Epoch: 0	Batch: 200	Avg-Loss: 4.8257	Training Accuracy : 0.0069
# Epoch: 0	Batch: 250	Avg-Loss: 4.8252	Training Accuracy : 0.0100
# Epoch: 0	Batch: 300	Avg-Loss: 4.8182	Training Accuracy : 0.0094
# Epoch: 0	Batch: 350	Avg-Loss: 4.8119	Training Accuracy : 0.0097
# Epoch: 0	Batch: 400	Avg-Loss: 4.8086	Training Accuracy : 0.0053
# Epoch: 0	Batch: 450	Avg-Loss: 4.8062	Training Accuracy : 0.0097
# Epoch: 0	Batch: 500	Avg-Loss: 4.8030	Training Accuracy : 0.0088
# Epoch: 0	Batch: 550	Avg-Loss: 4.8015	Training Accuracy : 0.0072
# Epoch: 0	Batch: 600	Avg-Loss: 4.8024	Training Accuracy : 0.0053
# Epoch: 0	Batch: 650	Avg-Loss: 4.7999	Training Accuracy : 0.0081
# Epoch: 0	Batch: 700	Avg-Loss: 4.7984	Training Accuracy : 0.0097
# Epoch: 0	Batch: 750	Avg-Loss: 4.7991	Training Accuracy : 0.0091
# Epoch: 0	Batch: 800	Avg-Loss: 4.7970	Training Accuracy : 0.0103
# Epoch: 0	Batch: 850	Avg-Loss: 4.7977	Training Accuracy : 0.0063
# Epoch: 0	Batch: 900	Avg-Loss: 4.7981	Training Accuracy : 0.0088
# Epoch: 0	Batch: 950	Avg-Loss: 4.7939	Training Accuracy : 0.0066
# Epoch: 0	Batch: 1000	Avg-Loss: 4.7973	Training Accuracy : 0.0091
# Epoch: 0	Batch: 1050	Avg-Loss: 4.7934	Training Accuracy : 0.0081
# Epoch: 0	Batch: 1100	Avg-Loss: 4.7957	Training Accuracy : 0.0081
# Epoch: 0	Batch: 1150	Avg-Loss: 4.7938	Training Accuracy : 0.0066
# Epoch: 0	Batch: 1200	Avg-Loss: 4.7944	Training Accuracy : 0.0128
# Epoch: 0	Batch: 1250	Avg-Loss: 4.7931	Training Accuracy : 0.0084
# Epoch: 0	Batch: 1300	Avg-Loss: 4.7964	Training Accuracy : 0.0075
# Epoch: 0, Validation Loss: 4.798, Validation Accuracy: 0.008
# Epoch: 1	Batch: 50	Avg-Loss: 4.7915	Training Accuracy : 0.0088
# Epoch: 1	Batch: 100	Avg-Loss: 4.7909	Training Accuracy : 0.0103
# Epoch: 1	Batch: 150	Avg-Loss: 4.7901	Training Accuracy : 0.0088
# Epoch: 1	Batch: 200	Avg-Loss: 4.7909	Training Accuracy : 0.0091
# Epoch: 1	Batch: 250	Avg-Loss: 4.7924	Training Accuracy : 0.0094
# Epoch: 1	Batch: 300	Avg-Loss: 4.7911	Training Accuracy : 0.0066
# Epoch: 1	Batch: 350	Avg-Loss: 4.7915	Training Accuracy : 0.0103
# Epoch: 1	Batch: 400	Avg-Loss: 4.7909	Training Accuracy : 0.0078
# Epoch: 1	Batch: 450	Avg-Loss: 4.7898	Training Accuracy : 0.0097
# Epoch: 1	Batch: 500	Avg-Loss: 4.7903	Training Accuracy : 0.0069
# Epoch: 1	Batch: 550	Avg-Loss: 4.7896	Training Accuracy : 0.0091
# Epoch: 1	Batch: 600	Avg-Loss: 4.7888	Training Accuracy : 0.0091
# Epoch: 1	Batch: 650	Avg-Loss: 4.7880	Training Accuracy : 0.0084
# Epoch: 1	Batch: 700	Avg-Loss: 4.7899	Training Accuracy : 0.0091
# Epoch: 1	Batch: 750	Avg-Loss: 4.7896	Training Accuracy : 0.0078
# Epoch: 1	Batch: 800	Avg-Loss: 4.7878	Training Accuracy : 0.0128
# Epoch: 1	Batch: 850	Avg-Loss: 4.7892	Training Accuracy : 0.0075
# Epoch: 1	Batch: 900	Avg-Loss: 4.7860	Training Accuracy : 0.0106
# Epoch: 1	Batch: 950	Avg-Loss: 4.7900	Training Accuracy : 0.0103
# Epoch: 1	Batch: 1000	Avg-Loss: 4.7844	Training Accuracy : 0.0119
# Epoch: 1	Batch: 1050	Avg-Loss: 4.7884	Training Accuracy : 0.0119
# Epoch: 1	Batch: 1100	Avg-Loss: 4.7863	Training Accuracy : 0.0100
# Epoch: 1	Batch: 1150	Avg-Loss: 4.7886	Training Accuracy : 0.0109
# Epoch: 1	Batch: 1200	Avg-Loss: 4.7887	Training Accuracy : 0.0106
# Epoch: 1	Batch: 1250	Avg-Loss: 4.7820	Training Accuracy : 0.0134
# Epoch: 1	Batch: 1300	Avg-Loss: 4.7855	Training Accuracy : 0.0112
# Epoch: 1, Validation Loss: 4.790, Validation Accuracy: 0.013
# Epoch: 2	Batch: 50	Avg-Loss: 4.7830	Training Accuracy : 0.0141
# Epoch: 2	Batch: 100	Avg-Loss: 4.7805	Training Accuracy : 0.0156
# Epoch: 2	Batch: 150	Avg-Loss: 4.7769	Training Accuracy : 0.0213
# Epoch: 2	Batch: 200	Avg-Loss: 4.7627	Training Accuracy : 0.0191
# Epoch: 2	Batch: 250	Avg-Loss: 4.7649	Training Accuracy : 0.0191
# Epoch: 2	Batch: 300	Avg-Loss: 4.7646	Training Accuracy : 0.0216
# Epoch: 2	Batch: 350	Avg-Loss: 4.7465	Training Accuracy : 0.0206
# Epoch: 2	Batch: 400	Avg-Loss: 4.7283	Training Accuracy : 0.0213
# Epoch: 2	Batch: 450	Avg-Loss: 4.7352	Training Accuracy : 0.0209
# Epoch: 2	Batch: 500	Avg-Loss: 4.6804	Training Accuracy : 0.0238
# Epoch: 2	Batch: 550	Avg-Loss: 4.6648	Training Accuracy : 0.0250
# Epoch: 2	Batch: 600	Avg-Loss: 4.5528	Training Accuracy : 0.0331
# Epoch: 2	Batch: 650	Avg-Loss: 4.4936	Training Accuracy : 0.0338
# Epoch: 2	Batch: 700	Avg-Loss: 4.3714	Training Accuracy : 0.0441
# Epoch: 2	Batch: 750	Avg-Loss: 4.2160	Training Accuracy : 0.0500
# Epoch: 2	Batch: 800	Avg-Loss: 3.9793	Training Accuracy : 0.0722
# Epoch: 2	Batch: 850	Avg-Loss: 3.9627	Training Accuracy : 0.0594
# Epoch: 2	Batch: 900	Avg-Loss: 3.7087	Training Accuracy : 0.0928
# Epoch: 2	Batch: 950	Avg-Loss: 3.6475	Training Accuracy : 0.0984
# Epoch: 2	Batch: 1000	Avg-Loss: 3.5218	Training Accuracy : 0.1131
# Epoch: 2	Batch: 1050	Avg-Loss: 3.4472	Training Accuracy : 0.1122
# Epoch: 2	Batch: 1100	Avg-Loss: 3.3645	Training Accuracy : 0.1297
# Epoch: 2	Batch: 1150	Avg-Loss: 3.2442	Training Accuracy : 0.1447
# Epoch: 2	Batch: 1200	Avg-Loss: 3.0547	Training Accuracy : 0.1672
# Epoch: 2	Batch: 1250	Avg-Loss: 2.9958	Training Accuracy : 0.1725
# Epoch: 2	Batch: 1300	Avg-Loss: 2.9175	Training Accuracy : 0.1762
# Epoch: 2, Validation Loss: 6.711, Validation Accuracy: 0.020
# Epoch: 3	Batch: 50	Avg-Loss: 2.7544	Training Accuracy : 0.2041
# Epoch: 3	Batch: 100	Avg-Loss: 2.7472	Training Accuracy : 0.2213
# Epoch: 3	Batch: 150	Avg-Loss: 2.6963	Training Accuracy : 0.2228
# Epoch: 3	Batch: 200	Avg-Loss: 2.5701	Training Accuracy : 0.2391
# Epoch: 3	Batch: 250	Avg-Loss: 2.5779	Training Accuracy : 0.2369
# Epoch: 3	Batch: 300	Avg-Loss: 2.5245	Training Accuracy : 0.2569
# Epoch: 3	Batch: 350	Avg-Loss: 2.4529	Training Accuracy : 0.2694
# Epoch: 3	Batch: 400	Avg-Loss: 2.4417	Training Accuracy : 0.2684
# Epoch: 3	Batch: 450	Avg-Loss: 2.3101	Training Accuracy : 0.3006
# Epoch: 3	Batch: 500	Avg-Loss: 2.3852	Training Accuracy : 0.2759
# Epoch: 3	Batch: 550	Avg-Loss: 2.2381	Training Accuracy : 0.3009
# Epoch: 3	Batch: 600	Avg-Loss: 2.2560	Training Accuracy : 0.3050
# Epoch: 3	Batch: 650	Avg-Loss: 2.1491	Training Accuracy : 0.3191
# Epoch: 3	Batch: 700	Avg-Loss: 2.1472	Training Accuracy : 0.3384
# Epoch: 3	Batch: 750	Avg-Loss: 2.0827	Training Accuracy : 0.3466
# Epoch: 3	Batch: 800	Avg-Loss: 2.0633	Training Accuracy : 0.3484
# Epoch: 3	Batch: 850	Avg-Loss: 2.0474	Training Accuracy : 0.3463
# Epoch: 3	Batch: 900	Avg-Loss: 1.9770	Training Accuracy : 0.3616
# Epoch: 3	Batch: 950	Avg-Loss: 1.9277	Training Accuracy : 0.3619
# Epoch: 3	Batch: 1000	Avg-Loss: 1.9143	Training Accuracy : 0.3787
# Epoch: 3	Batch: 1050	Avg-Loss: 1.8853	Training Accuracy : 0.3869
# Epoch: 3	Batch: 1100	Avg-Loss: 1.8549	Training Accuracy : 0.4088
# Epoch: 3	Batch: 1150	Avg-Loss: 1.8041	Training Accuracy : 0.4131
# Epoch: 3	Batch: 1200	Avg-Loss: 1.7425	Training Accuracy : 0.4319
# Epoch: 3	Batch: 1250	Avg-Loss: 1.7970	Training Accuracy : 0.4078
# Epoch: 3	Batch: 1300	Avg-Loss: 1.7064	Training Accuracy : 0.4284
# Epoch: 3, Validation Loss: 9.296, Validation Accuracy: 0.026
# Epoch: 4	Batch: 50	Avg-Loss: 1.6786	Training Accuracy : 0.4419
# Epoch: 4	Batch: 100	Avg-Loss: 1.5755	Training Accuracy : 0.4703
# Epoch: 4	Batch: 150	Avg-Loss: 1.6186	Training Accuracy : 0.4516
# Epoch: 4	Batch: 200	Avg-Loss: 1.5758	Training Accuracy : 0.4759
# Epoch: 4	Batch: 250	Avg-Loss: 1.5750	Training Accuracy : 0.4684
# Epoch: 4	Batch: 300	Avg-Loss: 1.5319	Training Accuracy : 0.4759
# Epoch: 4	Batch: 350	Avg-Loss: 1.5357	Training Accuracy : 0.4881
# Epoch: 4	Batch: 400	Avg-Loss: 1.4829	Training Accuracy : 0.4969
# Epoch: 4	Batch: 450	Avg-Loss: 1.4612	Training Accuracy : 0.5200
# Epoch: 4	Batch: 500	Avg-Loss: 1.4862	Training Accuracy : 0.5091
# Epoch: 4	Batch: 550	Avg-Loss: 1.3856	Training Accuracy : 0.5322
# Epoch: 4	Batch: 600	Avg-Loss: 1.3741	Training Accuracy : 0.5381
# Epoch: 4	Batch: 650	Avg-Loss: 1.3482	Training Accuracy : 0.5397
# Epoch: 4	Batch: 700	Avg-Loss: 1.3766	Training Accuracy : 0.5387
# Epoch: 4	Batch: 750	Avg-Loss: 1.3782	Training Accuracy : 0.5306
# Epoch: 4	Batch: 800	Avg-Loss: 1.3271	Training Accuracy : 0.5350
# Epoch: 4	Batch: 850	Avg-Loss: 1.3333	Training Accuracy : 0.5341
# Epoch: 4	Batch: 900	Avg-Loss: 1.2539	Training Accuracy : 0.5641
# Epoch: 4	Batch: 950	Avg-Loss: 1.2775	Training Accuracy : 0.5725
# Epoch: 4	Batch: 1000	Avg-Loss: 1.1944	Training Accuracy : 0.5884
# Epoch: 4	Batch: 1050	Avg-Loss: 1.2323	Training Accuracy : 0.5691
# Epoch: 4	Batch: 1100	Avg-Loss: 1.1639	Training Accuracy : 0.5953
# Epoch: 4	Batch: 1150	Avg-Loss: 1.1605	Training Accuracy : 0.5966
# Epoch: 4	Batch: 1200	Avg-Loss: 1.2186	Training Accuracy : 0.5850
# Epoch: 4	Batch: 1250	Avg-Loss: 1.2028	Training Accuracy : 0.5969
# Epoch: 4	Batch: 1300	Avg-Loss: 1.1845	Training Accuracy : 0.5941
# Epoch     5: reducing learning rate of group 0 to 5.0000e-03.
# Epoch: 4, Validation Loss: 10.780, Validation Accuracy: 0.030
# Epoch: 5	Batch: 50	Avg-Loss: 0.9358	Training Accuracy : 0.6722
# Epoch: 5	Batch: 100	Avg-Loss: 0.7721	Training Accuracy : 0.7284
# Epoch: 5	Batch: 150	Avg-Loss: 0.7289	Training Accuracy : 0.7394
# Epoch: 5	Batch: 200	Avg-Loss: 0.7365	Training Accuracy : 0.7338
# Epoch: 5	Batch: 250	Avg-Loss: 0.6934	Training Accuracy : 0.7422
# Epoch: 5	Batch: 300	Avg-Loss: 0.6534	Training Accuracy : 0.7503
# Epoch: 5	Batch: 350	Avg-Loss: 0.6718	Training Accuracy : 0.7641
# Epoch: 5	Batch: 400	Avg-Loss: 0.6412	Training Accuracy : 0.7584
# Epoch: 5	Batch: 450	Avg-Loss: 0.6590	Training Accuracy : 0.7622
# Epoch: 5	Batch: 500	Avg-Loss: 0.6511	Training Accuracy : 0.7638
# Epoch: 5	Batch: 550	Avg-Loss: 0.6397	Training Accuracy : 0.7691
# Epoch: 5	Batch: 600	Avg-Loss: 0.5933	Training Accuracy : 0.7806
# Epoch: 5	Batch: 650	Avg-Loss: 0.6070	Training Accuracy : 0.7741
# Epoch: 5	Batch: 700	Avg-Loss: 0.6261	Training Accuracy : 0.7631
# Epoch: 5	Batch: 750	Avg-Loss: 0.5657	Training Accuracy : 0.7941
# Epoch: 5	Batch: 800	Avg-Loss: 0.5813	Training Accuracy : 0.7856
# Epoch: 5	Batch: 850	Avg-Loss: 0.6315	Training Accuracy : 0.7609
# Epoch: 5	Batch: 900	Avg-Loss: 0.5741	Training Accuracy : 0.7934
# Epoch: 5	Batch: 950	Avg-Loss: 0.5686	Training Accuracy : 0.7887
# Epoch: 5	Batch: 1000	Avg-Loss: 0.5747	Training Accuracy : 0.7837
# Epoch: 5	Batch: 1050	Avg-Loss: 0.5643	Training Accuracy : 0.7969
# Epoch: 5	Batch: 1100	Avg-Loss: 0.5910	Training Accuracy : 0.7825
# Epoch: 5	Batch: 1150	Avg-Loss: 0.5106	Training Accuracy : 0.8166
# Epoch: 5	Batch: 1200	Avg-Loss: 0.5547	Training Accuracy : 0.7959
# Epoch: 5	Batch: 1250	Avg-Loss: 0.5006	Training Accuracy : 0.8134
# Epoch: 5	Batch: 1300	Avg-Loss: 0.5136	Training Accuracy : 0.8103
# Epoch: 5, Validation Loss: 15.512, Validation Accuracy: 0.033
# Epoch: 6	Batch: 50	Avg-Loss: 0.4642	Training Accuracy : 0.8228
# Epoch: 6	Batch: 100	Avg-Loss: 0.4725	Training Accuracy : 0.8172
# Epoch: 6	Batch: 150	Avg-Loss: 0.5181	Training Accuracy : 0.8131
# Epoch: 6	Batch: 200	Avg-Loss: 0.4924	Training Accuracy : 0.8181
# Epoch: 6	Batch: 250	Avg-Loss: 0.4857	Training Accuracy : 0.8231
# Epoch: 6	Batch: 300	Avg-Loss: 0.5238	Training Accuracy : 0.8109
# Epoch: 6	Batch: 350	Avg-Loss: 0.4564	Training Accuracy : 0.8191
# Epoch: 6	Batch: 400	Avg-Loss: 0.4779	Training Accuracy : 0.8153
# Epoch: 6	Batch: 450	Avg-Loss: 0.5233	Training Accuracy : 0.7991
# Epoch: 6	Batch: 500	Avg-Loss: 0.5165	Training Accuracy : 0.8094
# Epoch: 6	Batch: 550	Avg-Loss: 0.4985	Training Accuracy : 0.8213
# Epoch: 6	Batch: 600	Avg-Loss: 0.4999	Training Accuracy : 0.8187
# Epoch: 6	Batch: 650	Avg-Loss: 0.5201	Training Accuracy : 0.8000
# Epoch: 6	Batch: 700	Avg-Loss: 0.5219	Training Accuracy : 0.8053
# Epoch: 6	Batch: 750	Avg-Loss: 0.4641	Training Accuracy : 0.8297
# Epoch: 6	Batch: 800	Avg-Loss: 0.5005	Training Accuracy : 0.8063
# Epoch: 6	Batch: 850	Avg-Loss: 0.5048	Training Accuracy : 0.8125
# Epoch: 6	Batch: 900	Avg-Loss: 0.4822	Training Accuracy : 0.8178
# Epoch: 6	Batch: 950	Avg-Loss: 0.4496	Training Accuracy : 0.8372
# Epoch: 6	Batch: 1000	Avg-Loss: 0.4963	Training Accuracy : 0.8172
# Epoch: 6	Batch: 1050	Avg-Loss: 0.4617	Training Accuracy : 0.8231
# Epoch: 6	Batch: 1100	Avg-Loss: 0.4642	Training Accuracy : 0.8322
# Epoch: 6	Batch: 1150	Avg-Loss: 0.4625	Training Accuracy : 0.8259
# Epoch: 6	Batch: 1200	Avg-Loss: 0.4774	Training Accuracy : 0.8281
# Epoch: 6	Batch: 1250	Avg-Loss: 0.4300	Training Accuracy : 0.8337
# Epoch: 6	Batch: 1300	Avg-Loss: 0.4669	Training Accuracy : 0.8375
# Epoch: 6, Validation Loss: 16.936, Validation Accuracy: 0.030
# Epoch: 7	Batch: 50	Avg-Loss: 0.4486	Training Accuracy : 0.8334
# Epoch: 7	Batch: 100	Avg-Loss: 0.4047	Training Accuracy : 0.8478
# Epoch: 7	Batch: 150	Avg-Loss: 0.4157	Training Accuracy : 0.8453
# Epoch: 7	Batch: 200	Avg-Loss: 0.4094	Training Accuracy : 0.8478
# Epoch: 7	Batch: 250	Avg-Loss: 0.4095	Training Accuracy : 0.8497
# Epoch: 7	Batch: 300	Avg-Loss: 0.4076	Training Accuracy : 0.8450
# Epoch: 7	Batch: 350	Avg-Loss: 0.3889	Training Accuracy : 0.8556
# Epoch: 7	Batch: 400	Avg-Loss: 0.4292	Training Accuracy : 0.8391
# Epoch: 7	Batch: 450	Avg-Loss: 0.3965	Training Accuracy : 0.8447
# Epoch: 7	Batch: 500	Avg-Loss: 0.4199	Training Accuracy : 0.8459
# Epoch: 7	Batch: 550	Avg-Loss: 0.4278	Training Accuracy : 0.8459
# Epoch: 7	Batch: 600	Avg-Loss: 0.4109	Training Accuracy : 0.8475
# Epoch: 7	Batch: 650	Avg-Loss: 0.4227	Training Accuracy : 0.8372
# Epoch: 7	Batch: 700	Avg-Loss: 0.3946	Training Accuracy : 0.8528
# Epoch: 7	Batch: 750	Avg-Loss: 0.4137	Training Accuracy : 0.8462
# Epoch: 7	Batch: 800	Avg-Loss: 0.4167	Training Accuracy : 0.8497
# Epoch: 7	Batch: 850	Avg-Loss: 0.4144	Training Accuracy : 0.8431
# Epoch: 7	Batch: 900	Avg-Loss: 0.4436	Training Accuracy : 0.8397
# Epoch: 7	Batch: 950	Avg-Loss: 0.4313	Training Accuracy : 0.8391
# Epoch: 7	Batch: 1000	Avg-Loss: 0.4034	Training Accuracy : 0.8566
# Epoch: 7	Batch: 1050	Avg-Loss: 0.3650	Training Accuracy : 0.8619
# Epoch: 7	Batch: 1100	Avg-Loss: 0.3914	Training Accuracy : 0.8506
# Epoch: 7	Batch: 1150	Avg-Loss: 0.3743	Training Accuracy : 0.8584
# Epoch: 7	Batch: 1200	Avg-Loss: 0.3581	Training Accuracy : 0.8662
# Epoch: 7	Batch: 1250	Avg-Loss: 0.3395	Training Accuracy : 0.8694
# Epoch: 7	Batch: 1300	Avg-Loss: 0.3699	Training Accuracy : 0.8578
# Epoch     8: reducing learning rate of group 0 to 2.5000e-03.
# Epoch: 7, Validation Loss: 18.339, Validation Accuracy: 0.031
# Epoch: 8	Batch: 50	Avg-Loss: 0.3437	Training Accuracy : 0.8638
# Epoch: 8	Batch: 100	Avg-Loss: 0.3040	Training Accuracy : 0.8862
# Epoch: 8	Batch: 150	Avg-Loss: 0.2673	Training Accuracy : 0.8966
# Epoch: 8	Batch: 200	Avg-Loss: 0.2376	Training Accuracy : 0.9081
# Epoch: 8	Batch: 250	Avg-Loss: 0.2309	Training Accuracy : 0.9075
# Epoch: 8	Batch: 300	Avg-Loss: 0.2264	Training Accuracy : 0.9050
# Epoch: 8	Batch: 350	Avg-Loss: 0.2394	Training Accuracy : 0.9069
# Epoch: 8	Batch: 400	Avg-Loss: 0.2377	Training Accuracy : 0.9025
# Epoch: 8	Batch: 450	Avg-Loss: 0.2184	Training Accuracy : 0.9059
# Epoch: 8	Batch: 500	Avg-Loss: 0.2145	Training Accuracy : 0.9103
# Epoch: 8	Batch: 550	Avg-Loss: 0.2418	Training Accuracy : 0.9003
# Epoch: 8	Batch: 600	Avg-Loss: 0.2396	Training Accuracy : 0.9069
# Epoch: 8	Batch: 650	Avg-Loss: 0.1963	Training Accuracy : 0.9231
# Epoch: 8	Batch: 700	Avg-Loss: 0.2357	Training Accuracy : 0.9091
# Epoch: 8	Batch: 750	Avg-Loss: 0.2180	Training Accuracy : 0.9103
# Epoch: 8	Batch: 800	Avg-Loss: 0.2213	Training Accuracy : 0.9131
# Epoch: 8	Batch: 850	Avg-Loss: 0.1946	Training Accuracy : 0.9156
# Epoch: 8	Batch: 900	Avg-Loss: 0.2147	Training Accuracy : 0.9113
# Epoch: 8	Batch: 950	Avg-Loss: 0.1962	Training Accuracy : 0.9225
# Epoch: 8	Batch: 1000	Avg-Loss: 0.2125	Training Accuracy : 0.9116
# Epoch: 8	Batch: 1050	Avg-Loss: 0.2015	Training Accuracy : 0.9163
# Epoch: 8	Batch: 1100	Avg-Loss: 0.1978	Training Accuracy : 0.9219
# Epoch: 8	Batch: 1150	Avg-Loss: 0.1999	Training Accuracy : 0.9191
# Epoch: 8	Batch: 1200	Avg-Loss: 0.2141	Training Accuracy : 0.9153
# Epoch: 8	Batch: 1250	Avg-Loss: 0.2127	Training Accuracy : 0.9147
# Epoch: 8	Batch: 1300	Avg-Loss: 0.1944	Training Accuracy : 0.9244
# Epoch: 8, Validation Loss: 20.108, Validation Accuracy: 0.030
# Epoch: 9	Batch: 50	Avg-Loss: 0.1726	Training Accuracy : 0.9272
# Epoch: 9	Batch: 100	Avg-Loss: 0.1977	Training Accuracy : 0.9234
# Epoch: 9	Batch: 150	Avg-Loss: 0.1942	Training Accuracy : 0.9163
# Epoch: 9	Batch: 200	Avg-Loss: 0.1752	Training Accuracy : 0.9241
# Epoch: 9	Batch: 250	Avg-Loss: 0.1690	Training Accuracy : 0.9309
# Epoch: 9	Batch: 300	Avg-Loss: 0.2024	Training Accuracy : 0.9197
# Epoch: 9	Batch: 350	Avg-Loss: 0.1982	Training Accuracy : 0.9213
# Epoch: 9	Batch: 400	Avg-Loss: 0.2059	Training Accuracy : 0.9175
# Epoch: 9	Batch: 450	Avg-Loss: 0.1956	Training Accuracy : 0.9150
# Epoch: 9	Batch: 500	Avg-Loss: 0.1983	Training Accuracy : 0.9141
# Epoch: 9	Batch: 550	Avg-Loss: 0.1848	Training Accuracy : 0.9244
# Epoch: 9	Batch: 600	Avg-Loss: 0.1761	Training Accuracy : 0.9281
# Epoch: 9	Batch: 650	Avg-Loss: 0.1978	Training Accuracy : 0.9187
# Epoch: 9	Batch: 700	Avg-Loss: 0.2030	Training Accuracy : 0.9141
# Epoch: 9	Batch: 750	Avg-Loss: 0.1804	Training Accuracy : 0.9266
# Epoch: 9	Batch: 800	Avg-Loss: 0.1973	Training Accuracy : 0.9159
# Epoch: 9	Batch: 850	Avg-Loss: 0.2024	Training Accuracy : 0.9234
# Epoch: 9	Batch: 900	Avg-Loss: 0.1840	Training Accuracy : 0.9203
# Epoch: 9	Batch: 950	Avg-Loss: 0.1901	Training Accuracy : 0.9216
# Epoch: 9	Batch: 1000	Avg-Loss: 0.1866	Training Accuracy : 0.9206
# Epoch: 9	Batch: 1050	Avg-Loss: 0.1851	Training Accuracy : 0.9269
# Epoch: 9	Batch: 1100	Avg-Loss: 0.1733	Training Accuracy : 0.9287
# Epoch: 9	Batch: 1150	Avg-Loss: 0.1967	Training Accuracy : 0.9144
# Epoch: 9	Batch: 1200	Avg-Loss: 0.1916	Training Accuracy : 0.9228
# Epoch: 9	Batch: 1250	Avg-Loss: 0.1876	Training Accuracy : 0.9241
# Epoch: 9	Batch: 1300	Avg-Loss: 0.2064	Training Accuracy : 0.9181
# Epoch: 9, Validation Loss: 21.553, Validation Accuracy: 0.029
# Epoch: 10	Batch: 50	Avg-Loss: 0.1881	Training Accuracy : 0.9291
# Epoch: 10	Batch: 100	Avg-Loss: 0.1719	Training Accuracy : 0.9300
# Epoch: 10	Batch: 150	Avg-Loss: 0.1821	Training Accuracy : 0.9256
# Epoch: 10	Batch: 200	Avg-Loss: 0.1623	Training Accuracy : 0.9347
# Epoch: 10	Batch: 250	Avg-Loss: 0.1892	Training Accuracy : 0.9203
# Epoch: 10	Batch: 300	Avg-Loss: 0.1562	Training Accuracy : 0.9378
# Epoch: 10	Batch: 350	Avg-Loss: 0.1819	Training Accuracy : 0.9184
# Epoch: 10	Batch: 400	Avg-Loss: 0.1867	Training Accuracy : 0.9231
# Epoch: 10	Batch: 450	Avg-Loss: 0.1763	Training Accuracy : 0.9231
# Epoch: 10	Batch: 500	Avg-Loss: 0.1737	Training Accuracy : 0.9278
# Epoch: 10	Batch: 550	Avg-Loss: 0.1691	Training Accuracy : 0.9337
# Epoch: 10	Batch: 600	Avg-Loss: 0.1658	Training Accuracy : 0.9278
# Epoch: 10	Batch: 650	Avg-Loss: 0.1665	Training Accuracy : 0.9275
# Epoch: 10	Batch: 700	Avg-Loss: 0.1747	Training Accuracy : 0.9297
# Epoch: 10	Batch: 750	Avg-Loss: 0.1601	Training Accuracy : 0.9328
# Epoch: 10	Batch: 800	Avg-Loss: 0.1690	Training Accuracy : 0.9316
# Epoch: 10	Batch: 850	Avg-Loss: 0.1672	Training Accuracy : 0.9337
# Epoch: 10	Batch: 900	Avg-Loss: 0.1647	Training Accuracy : 0.9325
# Epoch: 10	Batch: 950	Avg-Loss: 0.1733	Training Accuracy : 0.9256
# Epoch: 10	Batch: 1000	Avg-Loss: 0.1822	Training Accuracy : 0.9272
# Epoch: 10	Batch: 1050	Avg-Loss: 0.1769	Training Accuracy : 0.9303
# Epoch: 10	Batch: 1100	Avg-Loss: 0.1751	Training Accuracy : 0.9303
# Epoch: 10	Batch: 1150	Avg-Loss: 0.1717	Training Accuracy : 0.9222
# Epoch: 10	Batch: 1200	Avg-Loss: 0.1682	Training Accuracy : 0.9328
# Epoch: 10	Batch: 1250	Avg-Loss: 0.1731	Training Accuracy : 0.9328
# Epoch: 10	Batch: 1300	Avg-Loss: 0.1772	Training Accuracy : 0.9278
# Epoch    11: reducing learning rate of group 0 to 1.2500e-03.
# Epoch: 10, Validation Loss: 22.109, Validation Accuracy: 0.030
# Epoch: 11	Batch: 50	Avg-Loss: 0.1486	Training Accuracy : 0.9372
# Epoch: 11	Batch: 100	Avg-Loss: 0.1429	Training Accuracy : 0.9366
# Epoch: 11	Batch: 150	Avg-Loss: 0.1440	Training Accuracy : 0.9381
# Epoch: 11	Batch: 200	Avg-Loss: 0.1336	Training Accuracy : 0.9422
# Epoch: 11	Batch: 250	Avg-Loss: 0.1385	Training Accuracy : 0.9428
# Epoch: 11	Batch: 300	Avg-Loss: 0.1339	Training Accuracy : 0.9466
# Epoch: 11	Batch: 350	Avg-Loss: 0.1314	Training Accuracy : 0.9428
# Epoch: 11	Batch: 400	Avg-Loss: 0.1286	Training Accuracy : 0.9487
# Epoch: 11	Batch: 450	Avg-Loss: 0.1340	Training Accuracy : 0.9459
# Epoch: 11	Batch: 500	Avg-Loss: 0.1357	Training Accuracy : 0.9428
# Epoch: 11	Batch: 550	Avg-Loss: 0.1339	Training Accuracy : 0.9378
# Epoch: 11	Batch: 600	Avg-Loss: 0.1328	Training Accuracy : 0.9447
# Epoch: 11	Batch: 650	Avg-Loss: 0.1306	Training Accuracy : 0.9437
# Epoch: 11	Batch: 700	Avg-Loss: 0.1364	Training Accuracy : 0.9400
# Epoch: 11	Batch: 750	Avg-Loss: 0.1285	Training Accuracy : 0.9456
# Epoch: 11	Batch: 800	Avg-Loss: 0.1367	Training Accuracy : 0.9419
# Epoch: 11	Batch: 850	Avg-Loss: 0.1372	Training Accuracy : 0.9450
# Epoch: 11	Batch: 900	Avg-Loss: 0.1243	Training Accuracy : 0.9456
# Epoch: 11	Batch: 950	Avg-Loss: 0.1288	Training Accuracy : 0.9447
# Epoch: 11	Batch: 1000	Avg-Loss: 0.1229	Training Accuracy : 0.9503
# Epoch: 11	Batch: 1050	Avg-Loss: 0.1251	Training Accuracy : 0.9434
# Epoch: 11	Batch: 1100	Avg-Loss: 0.1463	Training Accuracy : 0.9369
# Epoch: 11	Batch: 1150	Avg-Loss: 0.1270	Training Accuracy : 0.9463
# Epoch: 11	Batch: 1200	Avg-Loss: 0.1310	Training Accuracy : 0.9450
# Epoch: 11	Batch: 1250	Avg-Loss: 0.1255	Training Accuracy : 0.9475
# Epoch: 11	Batch: 1300	Avg-Loss: 0.1329	Training Accuracy : 0.9400
# Epoch: 11, Validation Loss: 23.770, Validation Accuracy: 0.027
# Epoch: 12	Batch: 50	Avg-Loss: 0.1180	Training Accuracy : 0.9516
# Epoch: 12	Batch: 100	Avg-Loss: 0.1056	Training Accuracy : 0.9547
# Epoch: 12	Batch: 150	Avg-Loss: 0.1126	Training Accuracy : 0.9563
# Epoch: 12	Batch: 200	Avg-Loss: 0.1166	Training Accuracy : 0.9513
# Epoch: 12	Batch: 250	Avg-Loss: 0.1263	Training Accuracy : 0.9478
# Epoch: 12	Batch: 300	Avg-Loss: 0.1133	Training Accuracy : 0.9528
# Epoch: 12	Batch: 350	Avg-Loss: 0.1184	Training Accuracy : 0.9478
# Epoch: 12	Batch: 400	Avg-Loss: 0.1307	Training Accuracy : 0.9428
# Epoch: 12	Batch: 450	Avg-Loss: 0.1259	Training Accuracy : 0.9453
# Epoch: 12	Batch: 500	Avg-Loss: 0.1277	Training Accuracy : 0.9475
# Epoch: 12	Batch: 550	Avg-Loss: 0.1191	Training Accuracy : 0.9484
# Epoch: 12	Batch: 600	Avg-Loss: 0.1151	Training Accuracy : 0.9503
# Epoch: 12	Batch: 650	Avg-Loss: 0.1247	Training Accuracy : 0.9516
# Epoch: 12	Batch: 700	Avg-Loss: 0.1209	Training Accuracy : 0.9494
# Epoch: 12	Batch: 750	Avg-Loss: 0.1214	Training Accuracy : 0.9491
# Epoch: 12	Batch: 800	Avg-Loss: 0.1215	Training Accuracy : 0.9478
# Epoch: 12	Batch: 850	Avg-Loss: 0.1184	Training Accuracy : 0.9506
# Epoch: 12	Batch: 900	Avg-Loss: 0.1288	Training Accuracy : 0.9394
# Epoch: 12	Batch: 950	Avg-Loss: 0.1166	Training Accuracy : 0.9506
# Epoch: 12	Batch: 1000	Avg-Loss: 0.1220	Training Accuracy : 0.9491
# Epoch: 12	Batch: 1050	Avg-Loss: 0.1210	Training Accuracy : 0.9469
# Epoch: 12	Batch: 1100	Avg-Loss: 0.1228	Training Accuracy : 0.9434
# Epoch: 12	Batch: 1150	Avg-Loss: 0.1244	Training Accuracy : 0.9513
# Epoch: 12	Batch: 1200	Avg-Loss: 0.1177	Training Accuracy : 0.9481
# Epoch: 12	Batch: 1250	Avg-Loss: 0.1131	Training Accuracy : 0.9491
# Epoch: 12	Batch: 1300	Avg-Loss: 0.1269	Training Accuracy : 0.9472
# Epoch: 12, Validation Loss: 24.493, Validation Accuracy: 0.028
# Epoch: 13	Batch: 50	Avg-Loss: 0.1135	Training Accuracy : 0.9522
# Epoch: 13	Batch: 100	Avg-Loss: 0.1084	Training Accuracy : 0.9528
# Epoch: 13	Batch: 150	Avg-Loss: 0.1224	Training Accuracy : 0.9463
# Epoch: 13	Batch: 200	Avg-Loss: 0.1163	Training Accuracy : 0.9497
# Epoch: 13	Batch: 250	Avg-Loss: 0.1164	Training Accuracy : 0.9516
# Epoch: 13	Batch: 300	Avg-Loss: 0.1091	Training Accuracy : 0.9541
# Epoch: 13	Batch: 350	Avg-Loss: 0.1251	Training Accuracy : 0.9478
# Epoch: 13	Batch: 400	Avg-Loss: 0.1224	Training Accuracy : 0.9478
# Epoch: 13	Batch: 450	Avg-Loss: 0.1079	Training Accuracy : 0.9531
# Epoch: 13	Batch: 500	Avg-Loss: 0.1090	Training Accuracy : 0.9534
# Epoch: 13	Batch: 550	Avg-Loss: 0.1074	Training Accuracy : 0.9553
# Epoch: 13	Batch: 600	Avg-Loss: 0.1136	Training Accuracy : 0.9497
# Epoch: 13	Batch: 650	Avg-Loss: 0.1178	Training Accuracy : 0.9528
# Epoch: 13	Batch: 700	Avg-Loss: 0.1124	Training Accuracy : 0.9509
# Epoch: 13	Batch: 750	Avg-Loss: 0.0994	Training Accuracy : 0.9584
# Epoch: 13	Batch: 800	Avg-Loss: 0.1060	Training Accuracy : 0.9531
# Epoch: 13	Batch: 850	Avg-Loss: 0.1150	Training Accuracy : 0.9494
# Epoch: 13	Batch: 900	Avg-Loss: 0.1082	Training Accuracy : 0.9513
# Epoch: 13	Batch: 950	Avg-Loss: 0.1126	Training Accuracy : 0.9475
# Epoch: 13	Batch: 1000	Avg-Loss: 0.1193	Training Accuracy : 0.9484
# Epoch: 13	Batch: 1050	Avg-Loss: 0.1249	Training Accuracy : 0.9475
# Epoch: 13	Batch: 1100	Avg-Loss: 0.1244	Training Accuracy : 0.9456
# Epoch: 13	Batch: 1150	Avg-Loss: 0.1163	Training Accuracy : 0.9500
# Epoch: 13	Batch: 1200	Avg-Loss: 0.1181	Training Accuracy : 0.9497
# Epoch: 13	Batch: 1250	Avg-Loss: 0.1167	Training Accuracy : 0.9500
# Epoch: 13	Batch: 1300	Avg-Loss: 0.1123	Training Accuracy : 0.9544
# Epoch    14: reducing learning rate of group 0 to 6.2500e-04.
# Epoch: 13, Validation Loss: 25.433, Validation Accuracy: 0.028
# Epoch: 14	Batch: 50	Avg-Loss: 0.1064	Training Accuracy : 0.9541
# Epoch: 14	Batch: 100	Avg-Loss: 0.0995	Training Accuracy : 0.9606
# Epoch: 14	Batch: 150	Avg-Loss: 0.1008	Training Accuracy : 0.9616
# Epoch: 14	Batch: 200	Avg-Loss: 0.0879	Training Accuracy : 0.9656
# Epoch: 14	Batch: 250	Avg-Loss: 0.0889	Training Accuracy : 0.9653
# Epoch: 14	Batch: 300	Avg-Loss: 0.0974	Training Accuracy : 0.9587
# Epoch: 14	Batch: 350	Avg-Loss: 0.0957	Training Accuracy : 0.9587
# Epoch: 14	Batch: 400	Avg-Loss: 0.0950	Training Accuracy : 0.9578
# Epoch: 14	Batch: 450	Avg-Loss: 0.1091	Training Accuracy : 0.9556
# Epoch: 14	Batch: 500	Avg-Loss: 0.1198	Training Accuracy : 0.9475
# Epoch: 14	Batch: 550	Avg-Loss: 0.0928	Training Accuracy : 0.9616
# Epoch: 14	Batch: 600	Avg-Loss: 0.1119	Training Accuracy : 0.9550
# Epoch: 14	Batch: 650	Avg-Loss: 0.1101	Training Accuracy : 0.9566
# Epoch: 14	Batch: 700	Avg-Loss: 0.1011	Training Accuracy : 0.9581
# Epoch: 14	Batch: 750	Avg-Loss: 0.1039	Training Accuracy : 0.9541
# Epoch: 14	Batch: 800	Avg-Loss: 0.1080	Training Accuracy : 0.9525
# Epoch: 14	Batch: 850	Avg-Loss: 0.0964	Training Accuracy : 0.9575
# Epoch: 14	Batch: 900	Avg-Loss: 0.1006	Training Accuracy : 0.9531
# Epoch: 14	Batch: 950	Avg-Loss: 0.0861	Training Accuracy : 0.9678
# Epoch: 14	Batch: 1000	Avg-Loss: 0.1014	Training Accuracy : 0.9550
# Epoch: 14	Batch: 1050	Avg-Loss: 0.0921	Training Accuracy : 0.9613
# Epoch: 14	Batch: 1100	Avg-Loss: 0.0995	Training Accuracy : 0.9584
# Epoch: 14	Batch: 1150	Avg-Loss: 0.0977	Training Accuracy : 0.9572
# Epoch: 14	Batch: 1200	Avg-Loss: 0.1071	Training Accuracy : 0.9559
# Epoch: 14	Batch: 1250	Avg-Loss: 0.0987	Training Accuracy : 0.9537
# Epoch: 14	Batch: 1300	Avg-Loss: 0.0978	Training Accuracy : 0.9622
# Epoch: 14, Validation Loss: 26.317, Validation Accuracy: 0.032
# Epoch: 15	Batch: 50	Avg-Loss: 0.0902	Training Accuracy : 0.9606
# Epoch: 15	Batch: 100	Avg-Loss: 0.0926	Training Accuracy : 0.9572
# Epoch: 15	Batch: 150	Avg-Loss: 0.0997	Training Accuracy : 0.9553
# Epoch: 15	Batch: 200	Avg-Loss: 0.0945	Training Accuracy : 0.9616
# Epoch: 15	Batch: 250	Avg-Loss: 0.0831	Training Accuracy : 0.9653
# Epoch: 15	Batch: 300	Avg-Loss: 0.0942	Training Accuracy : 0.9603
# Epoch: 15	Batch: 350	Avg-Loss: 0.0977	Training Accuracy : 0.9569
# Epoch: 15	Batch: 400	Avg-Loss: 0.0891	Training Accuracy : 0.9600
# Epoch: 15	Batch: 450	Avg-Loss: 0.1102	Training Accuracy : 0.9563
# Epoch: 15	Batch: 500	Avg-Loss: 0.0960	Training Accuracy : 0.9563
# Epoch: 15	Batch: 550	Avg-Loss: 0.1009	Training Accuracy : 0.9594
# Epoch: 15	Batch: 600	Avg-Loss: 0.0880	Training Accuracy : 0.9641
# Epoch: 15	Batch: 650	Avg-Loss: 0.0931	Training Accuracy : 0.9584
# Epoch: 15	Batch: 700	Avg-Loss: 0.0847	Training Accuracy : 0.9650
# Epoch: 15	Batch: 750	Avg-Loss: 0.0924	Training Accuracy : 0.9594
# Epoch: 15	Batch: 800	Avg-Loss: 0.0929	Training Accuracy : 0.9606
# Epoch: 15	Batch: 850	Avg-Loss: 0.0972	Training Accuracy : 0.9572
# Epoch: 15	Batch: 900	Avg-Loss: 0.0887	Training Accuracy : 0.9622
# Epoch: 15	Batch: 950	Avg-Loss: 0.0915	Training Accuracy : 0.9631
# Epoch: 15	Batch: 1000	Avg-Loss: 0.0972	Training Accuracy : 0.9569
# Epoch: 15	Batch: 1050	Avg-Loss: 0.0949	Training Accuracy : 0.9619
# Epoch: 15	Batch: 1100	Avg-Loss: 0.1014	Training Accuracy : 0.9525
# Epoch: 15	Batch: 1150	Avg-Loss: 0.1032	Training Accuracy : 0.9522
# Epoch: 15	Batch: 1200	Avg-Loss: 0.0979	Training Accuracy : 0.9537
# Epoch: 15	Batch: 1250	Avg-Loss: 0.1000	Training Accuracy : 0.9591
# Epoch: 15	Batch: 1300	Avg-Loss: 0.0947	Training Accuracy : 0.9581
# Epoch: 15, Validation Loss: 26.937, Validation Accuracy: 0.028
# Epoch: 16	Batch: 50	Avg-Loss: 0.0813	Training Accuracy : 0.9678
# Epoch: 16	Batch: 100	Avg-Loss: 0.0860	Training Accuracy : 0.9622
# Epoch: 16	Batch: 150	Avg-Loss: 0.0833	Training Accuracy : 0.9675
# Epoch: 16	Batch: 200	Avg-Loss: 0.0906	Training Accuracy : 0.9619
# Epoch: 16	Batch: 250	Avg-Loss: 0.0809	Training Accuracy : 0.9681
# Epoch: 16	Batch: 300	Avg-Loss: 0.0859	Training Accuracy : 0.9606
# Epoch: 16	Batch: 350	Avg-Loss: 0.0823	Training Accuracy : 0.9688
# Epoch: 16	Batch: 400	Avg-Loss: 0.0924	Training Accuracy : 0.9613
# Epoch: 16	Batch: 450	Avg-Loss: 0.0806	Training Accuracy : 0.9656
# Epoch: 16	Batch: 500	Avg-Loss: 0.1034	Training Accuracy : 0.9537
# Epoch: 16	Batch: 550	Avg-Loss: 0.0893	Training Accuracy : 0.9613
# Epoch: 16	Batch: 600	Avg-Loss: 0.0861	Training Accuracy : 0.9663
# Epoch: 16	Batch: 650	Avg-Loss: 0.1010	Training Accuracy : 0.9594
# Epoch: 16	Batch: 700	Avg-Loss: 0.1010	Training Accuracy : 0.9572
# Epoch: 16	Batch: 750	Avg-Loss: 0.0892	Training Accuracy : 0.9637
# Epoch: 16	Batch: 800	Avg-Loss: 0.0947	Training Accuracy : 0.9594
# Epoch: 16	Batch: 850	Avg-Loss: 0.0859	Training Accuracy : 0.9644
# Epoch: 16	Batch: 900	Avg-Loss: 0.0831	Training Accuracy : 0.9659
# Epoch: 16	Batch: 950	Avg-Loss: 0.0998	Training Accuracy : 0.9519
# Epoch: 16	Batch: 1000	Avg-Loss: 0.0987	Training Accuracy : 0.9553
# Epoch: 16	Batch: 1050	Avg-Loss: 0.0949	Training Accuracy : 0.9569
# Epoch: 16	Batch: 1100	Avg-Loss: 0.1052	Training Accuracy : 0.9534
# Epoch: 16	Batch: 1150	Avg-Loss: 0.0918	Training Accuracy : 0.9622
# Epoch: 16	Batch: 1200	Avg-Loss: 0.1026	Training Accuracy : 0.9563
# Epoch: 16	Batch: 1250	Avg-Loss: 0.0985	Training Accuracy : 0.9581
# Epoch: 16	Batch: 1300	Avg-Loss: 0.0941	Training Accuracy : 0.9597
# Epoch    17: reducing learning rate of group 0 to 3.1250e-04.
# Epoch: 16, Validation Loss: 28.061, Validation Accuracy: 0.029
# Epoch: 17	Batch: 50	Avg-Loss: 0.0892	Training Accuracy : 0.9637
# Epoch: 17	Batch: 100	Avg-Loss: 0.0816	Training Accuracy : 0.9656
# Epoch: 17	Batch: 150	Avg-Loss: 0.0811	Training Accuracy : 0.9681
# Epoch: 17	Batch: 200	Avg-Loss: 0.0752	Training Accuracy : 0.9694
# Epoch: 17	Batch: 250	Avg-Loss: 0.0834	Training Accuracy : 0.9634
# Epoch: 17	Batch: 300	Avg-Loss: 0.0865	Training Accuracy : 0.9606
# Epoch: 17	Batch: 350	Avg-Loss: 0.0807	Training Accuracy : 0.9678
# Epoch: 17	Batch: 400	Avg-Loss: 0.0814	Training Accuracy : 0.9688
# Epoch: 17	Batch: 450	Avg-Loss: 0.0769	Training Accuracy : 0.9709
# Epoch: 17	Batch: 500	Avg-Loss: 0.0764	Training Accuracy : 0.9694
# Epoch: 17	Batch: 550	Avg-Loss: 0.0839	Training Accuracy : 0.9622
# Epoch: 17	Batch: 600	Avg-Loss: 0.0816	Training Accuracy : 0.9669
# Epoch: 17	Batch: 650	Avg-Loss: 0.0852	Training Accuracy : 0.9659
# Epoch: 17	Batch: 700	Avg-Loss: 0.0818	Training Accuracy : 0.9675
# Epoch: 17	Batch: 750	Avg-Loss: 0.0822	Training Accuracy : 0.9584
# Epoch: 17	Batch: 800	Avg-Loss: 0.0860	Training Accuracy : 0.9631
# Epoch: 17	Batch: 850	Avg-Loss: 0.0895	Training Accuracy : 0.9622
# Epoch: 17	Batch: 900	Avg-Loss: 0.0784	Training Accuracy : 0.9691
# Epoch: 17	Batch: 950	Avg-Loss: 0.0910	Training Accuracy : 0.9575
# Epoch: 17	Batch: 1000	Avg-Loss: 0.0852	Training Accuracy : 0.9653
# Epoch: 17	Batch: 1050	Avg-Loss: 0.0803	Training Accuracy : 0.9656
# Epoch: 17	Batch: 1100	Avg-Loss: 0.0844	Training Accuracy : 0.9634
# Epoch: 17	Batch: 1150	Avg-Loss: 0.0863	Training Accuracy : 0.9647
# Epoch: 17	Batch: 1200	Avg-Loss: 0.0844	Training Accuracy : 0.9606
# Epoch: 17	Batch: 1250	Avg-Loss: 0.0815	Training Accuracy : 0.9644
# Epoch: 17	Batch: 1300	Avg-Loss: 0.0781	Training Accuracy : 0.9681
# Epoch: 17, Validation Loss: 27.897, Validation Accuracy: 0.029
# Epoch: 18	Batch: 50	Avg-Loss: 0.0782	Training Accuracy : 0.9641
# Epoch: 18	Batch: 100	Avg-Loss: 0.0815	Training Accuracy : 0.9666
# Epoch: 18	Batch: 150	Avg-Loss: 0.0801	Training Accuracy : 0.9644
# Epoch: 18	Batch: 200	Avg-Loss: 0.0780	Training Accuracy : 0.9681
# Epoch: 18	Batch: 250	Avg-Loss: 0.0696	Training Accuracy : 0.9712
# Epoch: 18	Batch: 300	Avg-Loss: 0.0747	Training Accuracy : 0.9703
# Epoch: 18	Batch: 350	Avg-Loss: 0.0801	Training Accuracy : 0.9653
# Epoch: 18	Batch: 400	Avg-Loss: 0.0864	Training Accuracy : 0.9644
# Epoch: 18	Batch: 450	Avg-Loss: 0.0798	Training Accuracy : 0.9650
# Epoch: 18	Batch: 500	Avg-Loss: 0.0821	Training Accuracy : 0.9637
# Epoch: 18	Batch: 550	Avg-Loss: 0.0813	Training Accuracy : 0.9653
# Epoch: 18	Batch: 600	Avg-Loss: 0.0769	Training Accuracy : 0.9659
# Epoch: 18	Batch: 650	Avg-Loss: 0.0785	Training Accuracy : 0.9697
# Epoch: 18	Batch: 700	Avg-Loss: 0.0843	Training Accuracy : 0.9637
# Epoch: 18	Batch: 750	Avg-Loss: 0.0876	Training Accuracy : 0.9641
# Epoch: 18	Batch: 800	Avg-Loss: 0.0767	Training Accuracy : 0.9672
# Epoch: 18	Batch: 850	Avg-Loss: 0.0761	Training Accuracy : 0.9691
# Epoch: 18	Batch: 900	Avg-Loss: 0.0837	Training Accuracy : 0.9641
# Epoch: 18	Batch: 950	Avg-Loss: 0.0738	Training Accuracy : 0.9738
# Epoch: 18	Batch: 1000	Avg-Loss: 0.0718	Training Accuracy : 0.9703
# Epoch: 18	Batch: 1050	Avg-Loss: 0.0814	Training Accuracy : 0.9666
# Epoch: 18	Batch: 1100	Avg-Loss: 0.0850	Training Accuracy : 0.9656
# Epoch: 18	Batch: 1150	Avg-Loss: 0.0791	Training Accuracy : 0.9684
# Epoch: 18	Batch: 1200	Avg-Loss: 0.0902	Training Accuracy : 0.9641
# Epoch: 18	Batch: 1250	Avg-Loss: 0.0862	Training Accuracy : 0.9644
# Epoch: 18	Batch: 1300	Avg-Loss: 0.0863	Training Accuracy : 0.9641
# Epoch: 18, Validation Loss: 28.676, Validation Accuracy: 0.029
# Epoch: 19	Batch: 50	Avg-Loss: 0.0738	Training Accuracy : 0.9703
# Epoch: 19	Batch: 100	Avg-Loss: 0.0799	Training Accuracy : 0.9675
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-084c295a2ef7> in <module>()
#      16         loss = criterion(outputs, y.long())
#      17         loss.backward()
# ---> 18         optimizer.step()
#      19         avg_loss += loss.item()
#      20
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/sgd.py in step(self, closure)
#     141                   lr=lr,
#     142                   dampening=dampening,
# --> 143                   nesterov=nesterov)
#     144
#     145             # update momentum_buffers in state
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/_functional.py in sgd(params, d_p_list, momentum_buffer_list, weight_decay, momentum, lr, dampening, nesterov)
#     178                 d_p = buf
#     179
# --> 180         param.add_(d_p, alpha=-lr)
#     181
#     182
#
# KeyboardInterrupt:

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Sun Nov 28 18:49:25 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P0    40W / 250W |   1283MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_images, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_4+1_base/best_model_5.pt"))
network = network.to(device)

# %%
with torch.no_grad():
  network.eval()
  num_correct = 0
  for x, y in tqdm(test_loader):
    x, y = x.to(device), y.to(device)
    outputs = network(x)
    num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

  test_acc = num_correct / len(test_set)
  print(test_acc)
# Out:
# 100%|██████████| 281/281 [02:47<00:00,  1.67it/s]
# 0.01939042736947679

# %%
print(test_acc)
# Out:
# 0.247840864768485
