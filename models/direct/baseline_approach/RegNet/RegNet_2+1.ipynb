# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !cp /content/gdrive/MyDrive/dl_project/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("2+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149910.jpg', 'frame_150128.jpg', 'fram...      1
# 1      ('frame_149935.jpg', 'frame_149924.jpg', 'fram...      2
# 2      ('frame_149931.jpg', 'frame_149915.jpg', 'fram...      2
# 3      ('frame_149949.jpg', 'frame_149922.jpg', 'fram...      2
# 4      ('frame_149941.jpg', 'frame_150459.jpg', 'fram...      3
# ...                                                  ...    ...
# 18078  ('frame_174612.jpg', 'frame_174586.jpg', 'fram...      2
# 18079  ('frame_174574.jpg', 'frame_180855.jpg', 'fram...      1
# 18080  ('frame_174580.jpg', 'frame_174634.jpg', 'fram...      0
# 18081  ('frame_174619.jpg', 'frame_181123.jpg', 'fram...      3
# 18082  ('frame_174585.jpg', 'frame_174623.jpg', 'fram...      0
#
# [18083 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            images.extend(img)
        x = torch.stack(images)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([9, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
batch_size = 128

# training data
train_set = MyDataSet(train_data)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_images, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding*num_images, num_classes))


    def forward(self, x):
      x1 = x[:, 0:3, :, :]
      x2 = x[:, 3:6, :, :]
      x3 = x[:, 6:9, :, :]

      out1 = self.cnn(x1)
      out2 = self.cnn(x2)
      out3 = self.cnn(x3)

      out = torch.cat([out1, out2, out3], axis=1)
      logits = self.mlp(out)
      return logits

# %%
numEpochs = 100
in_features = 3 # TODO: change RGB channels according to num of frames
embedding = 128

learningRate = 0.1
weightDecay = 1e-4

num_images = 3
num_classes = 6

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_images, num_classes)
#network.load_state_dict(torch.load("model_checkpoints/resnet34/lr_0.1-2/model_2.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_1+1_base/best_model_" + str(epoch) + ".pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 0	Batch: 50	Avg-Loss: 97.4249	Training Accuracy : 0.1628
# Epoch: 0	Batch: 100	Avg-Loss: 18.9905	Training Accuracy : 0.1580
# Epoch: 0	Batch: 150	Avg-Loss: 1.9752	Training Accuracy : 0.1633
# Epoch: 0	Batch: 200	Avg-Loss: 1.8719	Training Accuracy : 0.1723
# Epoch: 0	Batch: 250	Avg-Loss: 1.8185	Training Accuracy : 0.1697
# Epoch: 0	Batch: 300	Avg-Loss: 1.8129	Training Accuracy : 0.1589
# Epoch: 0	Batch: 350	Avg-Loss: 1.8123	Training Accuracy : 0.1614
# Epoch: 0	Batch: 400	Avg-Loss: 1.8062	Training Accuracy : 0.1623
# Epoch: 0	Batch: 450	Avg-Loss: 1.8213	Training Accuracy : 0.1695
# Epoch: 0	Batch: 500	Avg-Loss: 1.8046	Training Accuracy : 0.1683
# Epoch: 0	Batch: 550	Avg-Loss: 1.8132	Training Accuracy : 0.1719
# Epoch: 0	Batch: 600	Avg-Loss: 1.8026	Training Accuracy : 0.1761
# Epoch: 0	Batch: 650	Avg-Loss: 1.8022	Training Accuracy : 0.1703
# Epoch: 0, Validation Loss: 1.808, Validation Accuracy: 0.161
# Epoch: 1	Batch: 50	Avg-Loss: 1.8017	Training Accuracy : 0.1666
# Epoch: 1	Batch: 100	Avg-Loss: 1.8004	Training Accuracy : 0.1605
# Epoch: 1	Batch: 150	Avg-Loss: 1.8074	Training Accuracy : 0.1708
# Epoch: 1	Batch: 200	Avg-Loss: 1.8037	Training Accuracy : 0.1714
# Epoch: 1	Batch: 250	Avg-Loss: 1.8032	Training Accuracy : 0.1672
# Epoch: 1	Batch: 300	Avg-Loss: 1.8015	Training Accuracy : 0.1623
# Epoch: 1	Batch: 350	Avg-Loss: 1.7979	Training Accuracy : 0.1775
# Epoch: 1	Batch: 400	Avg-Loss: 1.8002	Training Accuracy : 0.1622
# Epoch: 1	Batch: 450	Avg-Loss: 1.7981	Training Accuracy : 0.1705
# Epoch: 1	Batch: 500	Avg-Loss: 1.7960	Training Accuracy : 0.1792
# Epoch: 1	Batch: 550	Avg-Loss: 1.8030	Training Accuracy : 0.1702
# Epoch: 1	Batch: 600	Avg-Loss: 1.7978	Training Accuracy : 0.1677
# Epoch: 1	Batch: 650	Avg-Loss: 1.7957	Training Accuracy : 0.1613
# Epoch: 1, Validation Loss: 1.797, Validation Accuracy: 0.169
# Epoch: 2	Batch: 50	Avg-Loss: 1.7938	Training Accuracy : 0.1636
# Epoch: 2	Batch: 100	Avg-Loss: 1.7954	Training Accuracy : 0.1620
# Epoch: 2	Batch: 150	Avg-Loss: 1.7942	Training Accuracy : 0.1703
# Epoch: 2	Batch: 200	Avg-Loss: 1.7942	Training Accuracy : 0.1703
# Epoch: 2	Batch: 250	Avg-Loss: 1.7956	Training Accuracy : 0.1638
# Epoch: 2	Batch: 300	Avg-Loss: 1.7952	Training Accuracy : 0.1681
# Epoch: 2	Batch: 350	Avg-Loss: 1.7949	Training Accuracy : 0.1716
# Epoch: 2	Batch: 400	Avg-Loss: 1.7947	Training Accuracy : 0.1653
# Epoch: 2	Batch: 450	Avg-Loss: 1.7946	Training Accuracy : 0.1620
# Epoch: 2	Batch: 500	Avg-Loss: 1.7941	Training Accuracy : 0.1695
# Epoch: 2	Batch: 550	Avg-Loss: 1.7940	Training Accuracy : 0.1644
# Epoch: 2	Batch: 600	Avg-Loss: 1.7947	Training Accuracy : 0.1677
# Epoch: 2	Batch: 650	Avg-Loss: 1.7931	Training Accuracy : 0.1725
# Epoch: 2, Validation Loss: 1.795, Validation Accuracy: 0.169
# Epoch: 3	Batch: 50	Avg-Loss: 1.7945	Training Accuracy : 0.1636
# Epoch: 3	Batch: 100	Avg-Loss: 1.7946	Training Accuracy : 0.1673
# Epoch: 3	Batch: 150	Avg-Loss: 1.7936	Training Accuracy : 0.1786
# Epoch: 3	Batch: 200	Avg-Loss: 1.7933	Training Accuracy : 0.1642
# Epoch: 3	Batch: 250	Avg-Loss: 1.7936	Training Accuracy : 0.1700
# Epoch: 3	Batch: 300	Avg-Loss: 1.7928	Training Accuracy : 0.1688
# Epoch: 3	Batch: 350	Avg-Loss: 1.7927	Training Accuracy : 0.1641
# Epoch: 3	Batch: 400	Avg-Loss: 1.7941	Training Accuracy : 0.1633
# Epoch: 3	Batch: 450	Avg-Loss: 1.7932	Training Accuracy : 0.1627
# Epoch: 3	Batch: 500	Avg-Loss: 1.7933	Training Accuracy : 0.1584
# Epoch: 3	Batch: 550	Avg-Loss: 1.7940	Training Accuracy : 0.1638
# Epoch: 3	Batch: 600	Avg-Loss: 1.7945	Training Accuracy : 0.1739
# Epoch: 3	Batch: 650	Avg-Loss: 1.7931	Training Accuracy : 0.1694
# Epoch: 3, Validation Loss: 1.795, Validation Accuracy: 0.166
# Epoch: 4	Batch: 50	Avg-Loss: 1.7922	Training Accuracy : 0.1650
# Epoch: 4	Batch: 100	Avg-Loss: 1.7946	Training Accuracy : 0.1602
# Epoch: 4	Batch: 150	Avg-Loss: 1.7925	Training Accuracy : 0.1638
# Epoch: 4	Batch: 200	Avg-Loss: 1.7934	Training Accuracy : 0.1694
# Epoch: 4	Batch: 250	Avg-Loss: 1.7940	Training Accuracy : 0.1670
# Epoch: 4	Batch: 300	Avg-Loss: 1.7937	Training Accuracy : 0.1653
# Epoch: 4	Batch: 350	Avg-Loss: 1.7935	Training Accuracy : 0.1655
# Epoch: 4	Batch: 400	Avg-Loss: 1.7927	Training Accuracy : 0.1750
# Epoch: 4	Batch: 450	Avg-Loss: 1.7937	Training Accuracy : 0.1664
# Epoch: 4	Batch: 500	Avg-Loss: 1.7919	Training Accuracy : 0.1688
# Epoch: 4	Batch: 550	Avg-Loss: 1.7939	Training Accuracy : 0.1741
# Epoch: 4	Batch: 600	Avg-Loss: 1.7925	Training Accuracy : 0.1695
# Epoch: 4	Batch: 650	Avg-Loss: 1.7937	Training Accuracy : 0.1603
# Epoch: 4, Validation Loss: 1.793, Validation Accuracy: 0.169
# Epoch: 5	Batch: 50	Avg-Loss: 1.7932	Training Accuracy : 0.1667
# Epoch: 5	Batch: 100	Avg-Loss: 1.7936	Training Accuracy : 0.1666
# Epoch: 5	Batch: 150	Avg-Loss: 1.7944	Training Accuracy : 0.1586
# Epoch: 5	Batch: 200	Avg-Loss: 1.7938	Training Accuracy : 0.1591
# Epoch: 5	Batch: 250	Avg-Loss: 1.7931	Training Accuracy : 0.1673
# Epoch: 5	Batch: 300	Avg-Loss: 1.7938	Training Accuracy : 0.1597
# Epoch: 5	Batch: 350	Avg-Loss: 1.7928	Training Accuracy : 0.1739
# Epoch: 5	Batch: 400	Avg-Loss: 1.7924	Training Accuracy : 0.1713
# Epoch: 5	Batch: 450	Avg-Loss: 1.7941	Training Accuracy : 0.1697
# Epoch: 5	Batch: 500	Avg-Loss: 1.7929	Training Accuracy : 0.1725
# Epoch: 5	Batch: 550	Avg-Loss: 1.7935	Training Accuracy : 0.1627
# Epoch: 5	Batch: 600	Avg-Loss: 1.7924	Training Accuracy : 0.1644
# Epoch: 5	Batch: 650	Avg-Loss: 1.7930	Training Accuracy : 0.1638
# Epoch: 5, Validation Loss: 1.793, Validation Accuracy: 0.169
# Epoch: 6	Batch: 50	Avg-Loss: 1.7923	Training Accuracy : 0.1720
# Epoch: 6	Batch: 100	Avg-Loss: 1.7933	Training Accuracy : 0.1672
# Epoch: 6	Batch: 150	Avg-Loss: 1.7926	Training Accuracy : 0.1714
# Epoch: 6	Batch: 200	Avg-Loss: 1.7933	Training Accuracy : 0.1689
# Epoch: 6	Batch: 250	Avg-Loss: 1.7936	Training Accuracy : 0.1656
# Epoch: 6	Batch: 300	Avg-Loss: 1.7926	Training Accuracy : 0.1702
# Epoch: 6	Batch: 350	Avg-Loss: 1.7933	Training Accuracy : 0.1714
# Epoch: 6	Batch: 400	Avg-Loss: 1.7938	Training Accuracy : 0.1639
# Epoch: 6	Batch: 450	Avg-Loss: 1.7928	Training Accuracy : 0.1683
# Epoch: 6	Batch: 500	Avg-Loss: 1.7929	Training Accuracy : 0.1667
# Epoch: 6	Batch: 550	Avg-Loss: 1.7928	Training Accuracy : 0.1714
# Epoch: 6	Batch: 600	Avg-Loss: 1.7927	Training Accuracy : 0.1728
# Epoch: 6	Batch: 650	Avg-Loss: 1.7934	Training Accuracy : 0.1673
# Epoch: 6, Validation Loss: 1.793, Validation Accuracy: 0.169
# Epoch: 7	Batch: 50	Avg-Loss: 1.7932	Training Accuracy : 0.1733
# Epoch: 7	Batch: 100	Avg-Loss: 1.7930	Training Accuracy : 0.1655
# Epoch: 7	Batch: 150	Avg-Loss: 1.7933	Training Accuracy : 0.1695
# Epoch: 7	Batch: 200	Avg-Loss: 1.7922	Training Accuracy : 0.1664
# Epoch: 7	Batch: 250	Avg-Loss: 1.7925	Training Accuracy : 0.1709
# Epoch: 7	Batch: 300	Avg-Loss: 1.7934	Training Accuracy : 0.1641
# Epoch: 7	Batch: 350	Avg-Loss: 1.7935	Training Accuracy : 0.1644
# Epoch: 7	Batch: 400	Avg-Loss: 1.7935	Training Accuracy : 0.1666
# Epoch: 7	Batch: 450	Avg-Loss: 1.7932	Training Accuracy : 0.1669
# Epoch: 7	Batch: 500	Avg-Loss: 1.7937	Training Accuracy : 0.1641
# Epoch: 7	Batch: 550	Avg-Loss: 1.7931	Training Accuracy : 0.1702
# Epoch: 7	Batch: 600	Avg-Loss: 1.7942	Training Accuracy : 0.1581
# Epoch: 7	Batch: 650	Avg-Loss: 1.7937	Training Accuracy : 0.1631
# Epoch: 7, Validation Loss: 1.792, Validation Accuracy: 0.169
# Epoch: 8	Batch: 50	Avg-Loss: 1.7924	Training Accuracy : 0.1664
# Epoch: 8	Batch: 100	Avg-Loss: 1.7935	Training Accuracy : 0.1689
# Epoch: 8	Batch: 150	Avg-Loss: 1.7934	Training Accuracy : 0.1666
# Epoch: 8	Batch: 200	Avg-Loss: 1.7937	Training Accuracy : 0.1620
# Epoch: 8	Batch: 250	Avg-Loss: 1.7946	Training Accuracy : 0.1608
# Epoch: 8	Batch: 300	Avg-Loss: 1.7928	Training Accuracy : 0.1678
# Epoch: 8	Batch: 350	Avg-Loss: 1.7925	Training Accuracy : 0.1709
# Epoch: 8	Batch: 400	Avg-Loss: 1.7934	Training Accuracy : 0.1661
# Epoch: 8	Batch: 450	Avg-Loss: 1.7940	Training Accuracy : 0.1680
# Epoch: 8	Batch: 500	Avg-Loss: 1.7932	Training Accuracy : 0.1708
# Epoch: 8	Batch: 550	Avg-Loss: 1.7941	Training Accuracy : 0.1669
# Epoch: 8	Batch: 600	Avg-Loss: 1.7938	Training Accuracy : 0.1655
# Epoch: 8	Batch: 650	Avg-Loss: 1.7927	Training Accuracy : 0.1661
# Epoch: 8, Validation Loss: 1.794, Validation Accuracy: 0.167
# Epoch: 9	Batch: 50	Avg-Loss: 1.7929	Training Accuracy : 0.1684
# Epoch: 9	Batch: 100	Avg-Loss: 1.7923	Training Accuracy : 0.1644
# Epoch: 9	Batch: 150	Avg-Loss: 1.7938	Training Accuracy : 0.1706
# Epoch: 9	Batch: 200	Avg-Loss: 1.7931	Training Accuracy : 0.1681
# Epoch: 9	Batch: 250	Avg-Loss: 1.7931	Training Accuracy : 0.1625
# Epoch: 9	Batch: 300	Avg-Loss: 1.7936	Training Accuracy : 0.1675
# Epoch: 9	Batch: 350	Avg-Loss: 1.7933	Training Accuracy : 0.1745
# Epoch: 9	Batch: 400	Avg-Loss: 1.7931	Training Accuracy : 0.1680
# Epoch: 9	Batch: 450	Avg-Loss: 1.7927	Training Accuracy : 0.1680
# Epoch: 9	Batch: 500	Avg-Loss: 1.7935	Training Accuracy : 0.1644
# Epoch: 9	Batch: 550	Avg-Loss: 1.7932	Training Accuracy : 0.1675
# Epoch: 9	Batch: 600	Avg-Loss: 1.7943	Training Accuracy : 0.1641
# Epoch: 9	Batch: 650	Avg-Loss: 1.7935	Training Accuracy : 0.1717
# Epoch: 9, Validation Loss: 1.794, Validation Accuracy: 0.168
# Epoch: 10	Batch: 50	Avg-Loss: 1.7942	Training Accuracy : 0.1645
# Epoch: 10	Batch: 100	Avg-Loss: 1.7919	Training Accuracy : 0.1748
# Epoch: 10	Batch: 150	Avg-Loss: 1.7937	Training Accuracy : 0.1623
# Epoch: 10	Batch: 200	Avg-Loss: 1.7929	Training Accuracy : 0.1720
# Epoch: 10	Batch: 250	Avg-Loss: 1.7927	Training Accuracy : 0.1636
# Epoch: 10	Batch: 300	Avg-Loss: 1.7926	Training Accuracy : 0.1747
# Epoch: 10	Batch: 350	Avg-Loss: 1.7923	Training Accuracy : 0.1663
# Epoch: 10	Batch: 400	Avg-Loss: 1.7937	Training Accuracy : 0.1613
# Epoch: 10	Batch: 450	Avg-Loss: 1.7934	Training Accuracy : 0.1684
# Epoch: 10	Batch: 500	Avg-Loss: 1.7938	Training Accuracy : 0.1641
# Epoch: 10	Batch: 550	Avg-Loss: 1.7941	Training Accuracy : 0.1714
# Epoch: 10	Batch: 600	Avg-Loss: 1.7933	Training Accuracy : 0.1678
# Epoch: 10	Batch: 650	Avg-Loss: 1.7936	Training Accuracy : 0.1702
# Epoch    11: reducing learning rate of group 0 to 5.0000e-02.
# Epoch: 10, Validation Loss: 1.792, Validation Accuracy: 0.169
# Epoch: 11	Batch: 50	Avg-Loss: 1.7921	Training Accuracy : 0.1698
# Epoch: 11	Batch: 100	Avg-Loss: 1.7925	Training Accuracy : 0.1675
# Epoch: 11	Batch: 150	Avg-Loss: 1.7934	Training Accuracy : 0.1694
# Epoch: 11	Batch: 200	Avg-Loss: 1.7920	Training Accuracy : 0.1688
# Epoch: 11	Batch: 250	Avg-Loss: 1.7922	Training Accuracy : 0.1680
# Epoch: 11	Batch: 300	Avg-Loss: 1.7923	Training Accuracy : 0.1669
# Epoch: 11	Batch: 350	Avg-Loss: 1.7928	Training Accuracy : 0.1578
# Epoch: 11	Batch: 400	Avg-Loss: 1.7926	Training Accuracy : 0.1673
# Epoch: 11	Batch: 450	Avg-Loss: 1.7927	Training Accuracy : 0.1639
# Epoch: 11	Batch: 500	Avg-Loss: 1.7923	Training Accuracy : 0.1636
# Epoch: 11	Batch: 550	Avg-Loss: 1.7922	Training Accuracy : 0.1739
# Epoch: 11	Batch: 600	Avg-Loss: 1.7918	Training Accuracy : 0.1789
# Epoch: 11	Batch: 650	Avg-Loss: 1.7927	Training Accuracy : 0.1616
# Epoch: 11, Validation Loss: 1.793, Validation Accuracy: 0.167
# Epoch: 12	Batch: 50	Avg-Loss: 1.7925	Training Accuracy : 0.1638
# Epoch: 12	Batch: 100	Avg-Loss: 1.7919	Training Accuracy : 0.1717
# Epoch: 12	Batch: 150	Avg-Loss: 1.7924	Training Accuracy : 0.1600
# Epoch: 12	Batch: 200	Avg-Loss: 1.7928	Training Accuracy : 0.1670
# Epoch: 12	Batch: 250	Avg-Loss: 1.7929	Training Accuracy : 0.1691
# Epoch: 12	Batch: 300	Avg-Loss: 1.7920	Training Accuracy : 0.1663
# Epoch: 12	Batch: 350	Avg-Loss: 1.7932	Training Accuracy : 0.1663
# Epoch: 12	Batch: 400	Avg-Loss: 1.7923	Training Accuracy : 0.1667
# Epoch: 12	Batch: 450	Avg-Loss: 1.7926	Training Accuracy : 0.1695
# Epoch: 12	Batch: 500	Avg-Loss: 1.7920	Training Accuracy : 0.1611
# Epoch: 12	Batch: 550	Avg-Loss: 1.7924	Training Accuracy : 0.1678
# Epoch: 12	Batch: 600	Avg-Loss: 1.7924	Training Accuracy : 0.1609
# Epoch: 12	Batch: 650	Avg-Loss: 1.7922	Training Accuracy : 0.1728
# Epoch: 12, Validation Loss: 1.793, Validation Accuracy: 0.167
# Epoch: 13	Batch: 50	Avg-Loss: 1.7924	Training Accuracy : 0.1631
# Epoch: 13	Batch: 100	Avg-Loss: 1.7928	Training Accuracy : 0.1689
# Epoch: 13	Batch: 150	Avg-Loss: 1.7922	Training Accuracy : 0.1700
# Epoch: 13	Batch: 200	Avg-Loss: 1.7924	Training Accuracy : 0.1697
# Epoch: 13	Batch: 250	Avg-Loss: 1.7917	Training Accuracy : 0.1705
# Epoch: 13	Batch: 300	Avg-Loss: 1.7918	Training Accuracy : 0.1764
# Epoch: 13	Batch: 350	Avg-Loss: 1.7927	Training Accuracy : 0.1647
# Epoch: 13	Batch: 400	Avg-Loss: 1.7928	Training Accuracy : 0.1678
# Epoch: 13	Batch: 450	Avg-Loss: 1.7929	Training Accuracy : 0.1653
# Epoch: 13	Batch: 500	Avg-Loss: 1.7915	Training Accuracy : 0.1817
# Epoch: 13	Batch: 550	Avg-Loss: 1.7931	Training Accuracy : 0.1614
# Epoch: 13	Batch: 600	Avg-Loss: 1.7924	Training Accuracy : 0.1667
# Epoch: 13	Batch: 650	Avg-Loss: 1.7923	Training Accuracy : 0.1688
# Epoch    14: reducing learning rate of group 0 to 2.5000e-02.
# Epoch: 13, Validation Loss: 1.793, Validation Accuracy: 0.166
# Epoch: 14	Batch: 50	Avg-Loss: 1.7921	Training Accuracy : 0.1733
# Epoch: 14	Batch: 100	Avg-Loss: 1.7921	Training Accuracy : 0.1650
# Epoch: 14	Batch: 150	Avg-Loss: 1.7927	Training Accuracy : 0.1623
# Epoch: 14	Batch: 200	Avg-Loss: 1.7921	Training Accuracy : 0.1616
# Epoch: 14	Batch: 250	Avg-Loss: 1.7923	Training Accuracy : 0.1598
# Epoch: 14	Batch: 300	Avg-Loss: 1.7922	Training Accuracy : 0.1628
# Epoch: 14	Batch: 350	Avg-Loss: 1.7919	Training Accuracy : 0.1713
# Epoch: 14	Batch: 400	Avg-Loss: 1.7920	Training Accuracy : 0.1683
# Epoch: 14	Batch: 450	Avg-Loss: 1.7921	Training Accuracy : 0.1648
# Epoch: 14	Batch: 500	Avg-Loss: 1.7921	Training Accuracy : 0.1697
# Epoch: 14	Batch: 550	Avg-Loss: 1.7922	Training Accuracy : 0.1733
# Epoch: 14	Batch: 600	Avg-Loss: 1.7920	Training Accuracy : 0.1669
# Epoch: 14	Batch: 650	Avg-Loss: 1.7917	Training Accuracy : 0.1750
# Epoch: 14, Validation Loss: 1.792, Validation Accuracy: 0.166
# Epoch: 15	Batch: 50	Avg-Loss: 1.7926	Training Accuracy : 0.1636
# Epoch: 15	Batch: 100	Avg-Loss: 1.7921	Training Accuracy : 0.1664
# Epoch: 15	Batch: 150	Avg-Loss: 1.7923	Training Accuracy : 0.1705
# Epoch: 15	Batch: 200	Avg-Loss: 1.7913	Training Accuracy : 0.1752
# Epoch: 15	Batch: 250	Avg-Loss: 1.7922	Training Accuracy : 0.1688
# Epoch: 15	Batch: 300	Avg-Loss: 1.7921	Training Accuracy : 0.1622
# Epoch: 15	Batch: 350	Avg-Loss: 1.7926	Training Accuracy : 0.1688
# Epoch: 15	Batch: 400	Avg-Loss: 1.7923	Training Accuracy : 0.1691
# Epoch: 15	Batch: 450	Avg-Loss: 1.7916	Training Accuracy : 0.1728
# Epoch: 15	Batch: 500	Avg-Loss: 1.7924	Training Accuracy : 0.1664
# Epoch: 15	Batch: 550	Avg-Loss: 1.7922	Training Accuracy : 0.1661
# Epoch: 15	Batch: 600	Avg-Loss: 1.7920	Training Accuracy : 0.1772
# Epoch: 15	Batch: 650	Avg-Loss: 1.7920	Training Accuracy : 0.1634
# Epoch: 15, Validation Loss: 1.792, Validation Accuracy: 0.168
# Epoch: 16	Batch: 50	Avg-Loss: 1.7917	Training Accuracy : 0.1697
# Epoch: 16	Batch: 100	Avg-Loss: 1.7923	Training Accuracy : 0.1703
# Epoch: 16	Batch: 150	Avg-Loss: 1.7923	Training Accuracy : 0.1595
# Epoch: 16	Batch: 200	Avg-Loss: 1.7923	Training Accuracy : 0.1672
# Epoch: 16	Batch: 250	Avg-Loss: 1.7916	Training Accuracy : 0.1725
# Epoch: 16	Batch: 300	Avg-Loss: 1.7923	Training Accuracy : 0.1639
# Epoch: 16	Batch: 350	Avg-Loss: 1.7928	Training Accuracy : 0.1633
# Epoch: 16	Batch: 400	Avg-Loss: 1.7915	Training Accuracy : 0.1755
# Epoch: 16	Batch: 450	Avg-Loss: 1.7923	Training Accuracy : 0.1698
# Epoch: 16	Batch: 500	Avg-Loss: 1.7917	Training Accuracy : 0.1636
# Epoch: 16	Batch: 550	Avg-Loss: 1.7920	Training Accuracy : 0.1667
# Epoch: 16	Batch: 600	Avg-Loss: 1.7918	Training Accuracy : 0.1672
# Epoch: 16	Batch: 650	Avg-Loss: 1.7913	Training Accuracy : 0.1806
# Epoch    17: reducing learning rate of group 0 to 1.2500e-02.
# Epoch: 16, Validation Loss: 1.793, Validation Accuracy: 0.169
# Epoch: 17	Batch: 50	Avg-Loss: 1.7925	Training Accuracy : 0.1658
# Epoch: 17	Batch: 100	Avg-Loss: 1.7922	Training Accuracy : 0.1666
# Epoch: 17	Batch: 150	Avg-Loss: 1.7915	Training Accuracy : 0.1709
# Epoch: 17	Batch: 200	Avg-Loss: 1.7922	Training Accuracy : 0.1636
# Epoch: 17	Batch: 250	Avg-Loss: 1.7918	Training Accuracy : 0.1666
# Epoch: 17	Batch: 300	Avg-Loss: 1.7922	Training Accuracy : 0.1663
# Epoch: 17	Batch: 350	Avg-Loss: 1.7916	Training Accuracy : 0.1756
# Epoch: 17	Batch: 400	Avg-Loss: 1.7921	Training Accuracy : 0.1669
# Epoch: 17	Batch: 450	Avg-Loss: 1.7920	Training Accuracy : 0.1627
# Epoch: 17	Batch: 500	Avg-Loss: 1.7916	Training Accuracy : 0.1719
# Epoch: 17	Batch: 550	Avg-Loss: 1.7921	Training Accuracy : 0.1672
# Epoch: 17	Batch: 600	Avg-Loss: 1.7919	Training Accuracy : 0.1634
# Epoch: 17	Batch: 650	Avg-Loss: 1.7916	Training Accuracy : 0.1695
# Epoch: 17, Validation Loss: 1.792, Validation Accuracy: 0.166
# Epoch: 18	Batch: 50	Avg-Loss: 1.7922	Training Accuracy : 0.1673
# Epoch: 18	Batch: 100	Avg-Loss: 1.7915	Training Accuracy : 0.1762
# Epoch: 18	Batch: 150	Avg-Loss: 1.7917	Training Accuracy : 0.1664
# Epoch: 18	Batch: 200	Avg-Loss: 1.7920	Training Accuracy : 0.1617
# Epoch: 18	Batch: 250	Avg-Loss: 1.7910	Training Accuracy : 0.1786
# Epoch: 18	Batch: 300	Avg-Loss: 1.7923	Training Accuracy : 0.1628
# Epoch: 18	Batch: 350	Avg-Loss: 1.7915	Training Accuracy : 0.1705
# Epoch: 18	Batch: 400	Avg-Loss: 1.7919	Training Accuracy : 0.1713
# Epoch: 18	Batch: 450	Avg-Loss: 1.7919	Training Accuracy : 0.1683
# Epoch: 18	Batch: 500	Avg-Loss: 1.7919	Training Accuracy : 0.1669
# Epoch: 18	Batch: 550	Avg-Loss: 1.7921	Training Accuracy : 0.1720
# Epoch: 18	Batch: 600	Avg-Loss: 1.7918	Training Accuracy : 0.1666
# Epoch: 18	Batch: 650	Avg-Loss: 1.7917	Training Accuracy : 0.1642
# Epoch: 18, Validation Loss: 1.792, Validation Accuracy: 0.168
# Epoch: 19	Batch: 50	Avg-Loss: 1.7917	Training Accuracy : 0.1611
# Epoch: 19	Batch: 100	Avg-Loss: 1.7919	Training Accuracy : 0.1723
# Epoch: 19	Batch: 150	Avg-Loss: 1.7920	Training Accuracy : 0.1595
# Epoch: 19	Batch: 200	Avg-Loss: 1.7920	Training Accuracy : 0.1628
# Epoch: 19	Batch: 250	Avg-Loss: 1.7917	Training Accuracy : 0.1648
# Epoch: 19	Batch: 300	Avg-Loss: 1.7915	Training Accuracy : 0.1663
# Epoch: 19	Batch: 350	Avg-Loss: 1.7921	Training Accuracy : 0.1567
# Epoch: 19	Batch: 400	Avg-Loss: 1.7920	Training Accuracy : 0.1663
# Epoch: 19	Batch: 450	Avg-Loss: 1.7920	Training Accuracy : 0.1658
# Epoch: 19	Batch: 500	Avg-Loss: 1.7915	Training Accuracy : 0.1675
# Epoch: 19	Batch: 550	Avg-Loss: 1.7922	Training Accuracy : 0.1689
# Epoch: 19	Batch: 600	Avg-Loss: 1.7922	Training Accuracy : 0.1625
# Epoch: 19	Batch: 650	Avg-Loss: 1.7918	Training Accuracy : 0.1698
# Epoch    20: reducing learning rate of group 0 to 6.2500e-03.
# Epoch: 19, Validation Loss: 1.792, Validation Accuracy: 0.166
# Epoch: 20	Batch: 50	Avg-Loss: 1.7920	Training Accuracy : 0.1706
# Epoch: 20	Batch: 100	Avg-Loss: 1.7920	Training Accuracy : 0.1697
# Epoch: 20	Batch: 150	Avg-Loss: 1.7915	Training Accuracy : 0.1711
# Epoch: 20	Batch: 200	Avg-Loss: 1.7919	Training Accuracy : 0.1681
# Epoch: 20	Batch: 250	Avg-Loss: 1.7914	Training Accuracy : 0.1717
# Epoch: 20	Batch: 300	Avg-Loss: 1.7922	Training Accuracy : 0.1605
# Epoch: 20	Batch: 350	Avg-Loss: 1.7917	Training Accuracy : 0.1661
# Epoch: 20	Batch: 400	Avg-Loss: 1.7919	Training Accuracy : 0.1720
# Epoch: 20	Batch: 450	Avg-Loss: 1.7916	Training Accuracy : 0.1739
# Epoch: 20	Batch: 500	Avg-Loss: 1.7921	Training Accuracy : 0.1641
# Epoch: 20	Batch: 550	Avg-Loss: 1.7918	Training Accuracy : 0.1663
# Epoch: 20	Batch: 600	Avg-Loss: 1.7916	Training Accuracy : 0.1745
# Epoch: 20	Batch: 650	Avg-Loss: 1.7914	Training Accuracy : 0.1737
# Epoch: 20, Validation Loss: 1.792, Validation Accuracy: 0.167
# Epoch: 21	Batch: 50	Avg-Loss: 1.7917	Training Accuracy : 0.1644
# Epoch: 21	Batch: 100	Avg-Loss: 1.7919	Training Accuracy : 0.1659
# Epoch: 21	Batch: 150	Avg-Loss: 1.7915	Training Accuracy : 0.1709
# Epoch: 21	Batch: 200	Avg-Loss: 1.7921	Training Accuracy : 0.1586
# Epoch: 21	Batch: 250	Avg-Loss: 1.7916	Training Accuracy : 0.1728
# Epoch: 21	Batch: 300	Avg-Loss: 1.7915	Training Accuracy : 0.1689
# Epoch: 21	Batch: 350	Avg-Loss: 1.7918	Training Accuracy : 0.1688
# Epoch: 21	Batch: 400	Avg-Loss: 1.7920	Training Accuracy : 0.1686
# Epoch: 21	Batch: 450	Avg-Loss: 1.7921	Training Accuracy : 0.1652
# Epoch: 21	Batch: 500	Avg-Loss: 1.7918	Training Accuracy : 0.1645
# Epoch: 21	Batch: 550	Avg-Loss: 1.7916	Training Accuracy : 0.1641
# Epoch: 21	Batch: 600	Avg-Loss: 1.7920	Training Accuracy : 0.1606
# Epoch: 21	Batch: 650	Avg-Loss: 1.7917	Training Accuracy : 0.1673
# Epoch: 21, Validation Loss: 1.792, Validation Accuracy: 0.167
# Epoch: 22	Batch: 50	Avg-Loss: 1.7919	Training Accuracy : 0.1575
# Epoch: 22	Batch: 100	Avg-Loss: 1.7918	Training Accuracy : 0.1691
# Epoch: 22	Batch: 150	Avg-Loss: 1.7921	Training Accuracy : 0.1609
# Epoch: 22	Batch: 200	Avg-Loss: 1.7917	Training Accuracy : 0.1580
# Epoch: 22	Batch: 250	Avg-Loss: 1.7918	Training Accuracy : 0.1689
# Epoch: 22	Batch: 300	Avg-Loss: 1.7916	Training Accuracy : 0.1670
# Epoch: 22	Batch: 350	Avg-Loss: 1.7919	Training Accuracy : 0.1641
# Epoch: 22	Batch: 400	Avg-Loss: 1.7917	Training Accuracy : 0.1684
# Epoch: 22	Batch: 450	Avg-Loss: 1.7918	Training Accuracy : 0.1700
# Epoch: 22	Batch: 500	Avg-Loss: 1.7919	Training Accuracy : 0.1705
# Epoch: 22	Batch: 550	Avg-Loss: 1.7918	Training Accuracy : 0.1659
# Epoch: 22	Batch: 600	Avg-Loss: 1.7915	Training Accuracy : 0.1739
# Epoch: 22	Batch: 650	Avg-Loss: 1.7920	Training Accuracy : 0.1581
# Epoch    23: reducing learning rate of group 0 to 3.1250e-03.
# Epoch: 22, Validation Loss: 1.792, Validation Accuracy: 0.166
# Epoch: 23	Batch: 50	Avg-Loss: 1.7914	Training Accuracy : 0.1739
# Epoch: 23	Batch: 100	Avg-Loss: 1.7918	Training Accuracy : 0.1705
# Epoch: 23	Batch: 150	Avg-Loss: 1.7917	Training Accuracy : 0.1656
# Epoch: 23	Batch: 200	Avg-Loss: 1.7918	Training Accuracy : 0.1669
# Epoch: 23	Batch: 250	Avg-Loss: 1.7918	Training Accuracy : 0.1691
# Epoch: 23	Batch: 300	Avg-Loss: 1.7921	Training Accuracy : 0.1645
# Epoch: 23	Batch: 350	Avg-Loss: 1.7916	Training Accuracy : 0.1673
# Epoch: 23	Batch: 400	Avg-Loss: 1.7920	Training Accuracy : 0.1581
# Epoch: 23	Batch: 450	Avg-Loss: 1.7918	Training Accuracy : 0.1678
# Epoch: 23	Batch: 500	Avg-Loss: 1.7917	Training Accuracy : 0.1677
# Epoch: 23	Batch: 550	Avg-Loss: 1.7915	Training Accuracy : 0.1670
# Epoch: 23	Batch: 600	Avg-Loss: 1.7914	Training Accuracy : 0.1762
# Epoch: 23	Batch: 650	Avg-Loss: 1.7919	Training Accuracy : 0.1686
# Epoch: 23, Validation Loss: 1.792, Validation Accuracy: 0.167
# Epoch: 24	Batch: 50	Avg-Loss: 1.7914	Training Accuracy : 0.1705
# Epoch: 24	Batch: 100	Avg-Loss: 1.7920	Training Accuracy : 0.1659
# Epoch: 24	Batch: 150	Avg-Loss: 1.7919	Training Accuracy : 0.1652
# Epoch: 24	Batch: 200	Avg-Loss: 1.7917	Training Accuracy : 0.1700
# Epoch: 24	Batch: 250	Avg-Loss: 1.7920	Training Accuracy : 0.1619
# Epoch: 24	Batch: 300	Avg-Loss: 1.7916	Training Accuracy : 0.1711
# Epoch: 24	Batch: 350	Avg-Loss: 1.7916	Training Accuracy : 0.1717
# Epoch: 24	Batch: 400	Avg-Loss: 1.7916	Training Accuracy : 0.1744
# Epoch: 24	Batch: 450	Avg-Loss: 1.7913	Training Accuracy : 0.1691
# Epoch: 24	Batch: 500	Avg-Loss: 1.7917	Training Accuracy : 0.1636
# Epoch: 24	Batch: 550	Avg-Loss: 1.7917	Training Accuracy : 0.1619
# Epoch: 24	Batch: 600	Avg-Loss: 1.7921	Training Accuracy : 0.1677
# Epoch: 24	Batch: 650	Avg-Loss: 1.7918	Training Accuracy : 0.1694
# Epoch: 24, Validation Loss: 1.792, Validation Accuracy: 0.169
# Epoch: 25	Batch: 50	Avg-Loss: 1.7916	Training Accuracy : 0.1666
# Epoch: 25	Batch: 100	Avg-Loss: 1.7921	Training Accuracy : 0.1597
# Epoch: 25	Batch: 150	Avg-Loss: 1.7917	Training Accuracy : 0.1664
# Epoch: 25	Batch: 200	Avg-Loss: 1.7918	Training Accuracy : 0.1716
# Epoch: 25	Batch: 250	Avg-Loss: 1.7917	Training Accuracy : 0.1634
# Epoch: 25	Batch: 300	Avg-Loss: 1.7918	Training Accuracy : 0.1700
# Epoch: 25	Batch: 350	Avg-Loss: 1.7917	Training Accuracy : 0.1630
# Epoch: 25	Batch: 400	Avg-Loss: 1.7918	Training Accuracy : 0.1628
# Epoch: 25	Batch: 450	Avg-Loss: 1.7915	Training Accuracy : 0.1741
# Epoch: 25	Batch: 500	Avg-Loss: 1.7914	Training Accuracy : 0.1658
# Epoch: 25	Batch: 550	Avg-Loss: 1.7915	Training Accuracy : 0.1658
# Epoch: 25	Batch: 600	Avg-Loss: 1.7923	Training Accuracy : 0.1645
# Epoch: 25	Batch: 650	Avg-Loss: 1.7918	Training Accuracy : 0.1647
# Epoch    26: reducing learning rate of group 0 to 1.5625e-03.
# Epoch: 25, Validation Loss: 1.792, Validation Accuracy: 0.166
# Epoch: 26	Batch: 50	Avg-Loss: 1.7915	Training Accuracy : 0.1725
# Epoch: 26	Batch: 100	Avg-Loss: 1.7918	Training Accuracy : 0.1664
# Epoch: 26	Batch: 150	Avg-Loss: 1.7916	Training Accuracy : 0.1694
# Epoch: 26	Batch: 200	Avg-Loss: 1.7916	Training Accuracy : 0.1638
# Epoch: 26	Batch: 250	Avg-Loss: 1.7918	Training Accuracy : 0.1689
# Epoch: 26	Batch: 300	Avg-Loss: 1.7917	Training Accuracy : 0.1686
# Epoch: 26	Batch: 350	Avg-Loss: 1.7917	Training Accuracy : 0.1648
# Epoch: 26	Batch: 400	Avg-Loss: 1.7917	Training Accuracy : 0.1669
# Epoch: 26	Batch: 450	Avg-Loss: 1.7916	Training Accuracy : 0.1689
# Epoch: 26	Batch: 500	Avg-Loss: 1.7917	Training Accuracy : 0.1697
# Epoch: 26	Batch: 550	Avg-Loss: 1.7918	Training Accuracy : 0.1658
# Epoch: 26	Batch: 600	Avg-Loss: 1.7915	Training Accuracy : 0.1670
# Epoch: 26	Batch: 650	Avg-Loss: 1.7919	Training Accuracy : 0.1642
# Epoch: 26, Validation Loss: 1.792, Validation Accuracy: 0.166
# Epoch: 27	Batch: 50	Avg-Loss: 1.7916	Training Accuracy : 0.1717
# Epoch: 27	Batch: 100	Avg-Loss: 1.7917	Training Accuracy : 0.1706
# Epoch: 27	Batch: 150	Avg-Loss: 1.7915	Training Accuracy : 0.1706
# Epoch: 27	Batch: 200	Avg-Loss: 1.7919	Training Accuracy : 0.1697
# Epoch: 27	Batch: 250	Avg-Loss: 1.7917	Training Accuracy : 0.1694
# Epoch: 27	Batch: 300	Avg-Loss: 1.7917	Training Accuracy : 0.1717
# Epoch: 27	Batch: 350	Avg-Loss: 1.7920	Training Accuracy : 0.1575
# Epoch: 27	Batch: 400	Avg-Loss: 1.7916	Training Accuracy : 0.1728
# Epoch: 27	Batch: 450	Avg-Loss: 1.7917	Training Accuracy : 0.1627
# Epoch: 27	Batch: 500	Avg-Loss: 1.7917	Training Accuracy : 0.1658
# Epoch: 27	Batch: 550	Avg-Loss: 1.7917	Training Accuracy : 0.1688
# Epoch: 27	Batch: 600	Avg-Loss: 1.7913	Training Accuracy : 0.1719
# Epoch: 27	Batch: 650	Avg-Loss: 1.7916	Training Accuracy : 0.1705
# Epoch: 27, Validation Loss: 1.792, Validation Accuracy: 0.167
# Epoch: 28	Batch: 50	Avg-Loss: 1.7915	Training Accuracy : 0.1684
# Epoch: 28	Batch: 100	Avg-Loss: 1.7916	Training Accuracy : 0.1705
# Epoch: 28	Batch: 150	Avg-Loss: 1.7915	Training Accuracy : 0.1688
# Epoch: 28	Batch: 200	Avg-Loss: 1.7920	Training Accuracy : 0.1647
# Epoch: 28	Batch: 250	Avg-Loss: 1.7916	Training Accuracy : 0.1723
# Epoch: 28	Batch: 300	Avg-Loss: 1.7917	Training Accuracy : 0.1716
# Epoch: 28	Batch: 350	Avg-Loss: 1.7916	Training Accuracy : 0.1655
# Epoch: 28	Batch: 400	Avg-Loss: 1.7917	Training Accuracy : 0.1705
# Epoch: 28	Batch: 450	Avg-Loss: 1.7917	Training Accuracy : 0.1698
# Epoch: 28	Batch: 500	Avg-Loss: 1.7919	Training Accuracy : 0.1631
# Epoch: 28	Batch: 550	Avg-Loss: 1.7916	Training Accuracy : 0.1636
# Epoch: 28	Batch: 600	Avg-Loss: 1.7918	Training Accuracy : 0.1672
# Epoch: 28	Batch: 650	Avg-Loss: 1.7917	Training Accuracy : 0.1683
# Epoch    29: reducing learning rate of group 0 to 7.8125e-04.
# Epoch: 28, Validation Loss: 1.792, Validation Accuracy: 0.166
# Epoch: 29	Batch: 50	Avg-Loss: 1.7918	Training Accuracy : 0.1670
# Epoch: 29	Batch: 100	Avg-Loss: 1.7912	Training Accuracy : 0.1809
# Epoch: 29	Batch: 150	Avg-Loss: 1.7916	Training Accuracy : 0.1739
# Epoch: 29	Batch: 200	Avg-Loss: 1.7914	Training Accuracy : 0.1709
# Epoch: 29	Batch: 250	Avg-Loss: 1.7916	Training Accuracy : 0.1734
# Epoch: 29	Batch: 300	Avg-Loss: 1.7917	Training Accuracy : 0.1684
# Epoch: 29	Batch: 350	Avg-Loss: 1.7917	Training Accuracy : 0.1656
# Epoch: 29	Batch: 400	Avg-Loss: 1.7914	Training Accuracy : 0.1644
# Epoch: 29	Batch: 450	Avg-Loss: 1.7918	Training Accuracy : 0.1680
# Epoch: 29	Batch: 500	Avg-Loss: 1.7923	Training Accuracy : 0.1672
# Epoch: 29	Batch: 550	Avg-Loss: 1.7919	Training Accuracy : 0.1669
# Epoch: 29	Batch: 600	Avg-Loss: 1.7918	Training Accuracy : 0.1586
# Epoch: 29	Batch: 650	Avg-Loss: 1.7916	Training Accuracy : 0.1611
# Epoch: 29, Validation Loss: 1.792, Validation Accuracy: 0.167
# Epoch: 30	Batch: 50	Avg-Loss: 1.7921	Training Accuracy : 0.1733
# Epoch: 30	Batch: 100	Avg-Loss: 1.7917	Training Accuracy : 0.1748
# Epoch: 30	Batch: 150	Avg-Loss: 1.7917	Training Accuracy : 0.1659
# Epoch: 30	Batch: 200	Avg-Loss: 1.7916	Training Accuracy : 0.1706
# Epoch: 30	Batch: 250	Avg-Loss: 1.7916	Training Accuracy : 0.1689
# Epoch: 30	Batch: 300	Avg-Loss: 1.7917	Training Accuracy : 0.1619
# Epoch: 30	Batch: 350	Avg-Loss: 1.7918	Training Accuracy : 0.1719
# Epoch: 30	Batch: 400	Avg-Loss: 1.7918	Training Accuracy : 0.1639
# Epoch: 30	Batch: 450	Avg-Loss: 1.7916	Training Accuracy : 0.1717
# Epoch: 30	Batch: 500	Avg-Loss: 1.7917	Training Accuracy : 0.1700
# Epoch: 30	Batch: 550	Avg-Loss: 1.7914	Training Accuracy : 0.1733
# Epoch: 30	Batch: 600	Avg-Loss: 1.7918	Training Accuracy : 0.1628
# Epoch: 30	Batch: 650	Avg-Loss: 1.7914	Training Accuracy : 0.1706
# Epoch: 30, Validation Loss: 1.792, Validation Accuracy: 0.166
# Epoch: 31	Batch: 50	Avg-Loss: 1.7913	Training Accuracy : 0.1636
# Epoch: 31	Batch: 100	Avg-Loss: 1.7920	Training Accuracy : 0.1694
# Epoch: 31	Batch: 150	Avg-Loss: 1.7913	Training Accuracy : 0.1670
# Epoch: 31	Batch: 200	Avg-Loss: 1.7917	Training Accuracy : 0.1700
# Epoch: 31	Batch: 250	Avg-Loss: 1.7918	Training Accuracy : 0.1659
# Epoch: 31	Batch: 300	Avg-Loss: 1.7917	Training Accuracy : 0.1633
# Epoch: 31	Batch: 350	Avg-Loss: 1.7919	Training Accuracy : 0.1648
# Epoch: 31	Batch: 400	Avg-Loss: 1.7918	Training Accuracy : 0.1573
# Epoch: 31	Batch: 450	Avg-Loss: 1.7916	Training Accuracy : 0.1650
# Epoch: 31	Batch: 500	Avg-Loss: 1.7913	Training Accuracy : 0.1755
# Epoch: 31	Batch: 550	Avg-Loss: 1.7916	Training Accuracy : 0.1638
# Epoch: 31	Batch: 600	Avg-Loss: 1.7919	Training Accuracy : 0.1634
# Epoch: 31	Batch: 650	Avg-Loss: 1.7916	Training Accuracy : 0.1656
# Epoch    32: reducing learning rate of group 0 to 3.9063e-04.
# Epoch: 31, Validation Loss: 1.792, Validation Accuracy: 0.167
# Epoch: 32	Batch: 50	Avg-Loss: 1.7917	Training Accuracy : 0.1638
# Epoch: 32	Batch: 100	Avg-Loss: 1.7912	Training Accuracy : 0.1675
# Epoch: 32	Batch: 150	Avg-Loss: 1.7915	Training Accuracy : 0.1727
# Epoch: 32	Batch: 200	Avg-Loss: 1.7917	Training Accuracy : 0.1680
# Epoch: 32	Batch: 250	Avg-Loss: 1.7918	Training Accuracy : 0.1658
# Epoch: 32	Batch: 300	Avg-Loss: 1.7916	Training Accuracy : 0.1745
# Epoch: 32	Batch: 350	Avg-Loss: 1.7920	Training Accuracy : 0.1638
# Epoch: 32	Batch: 400	Avg-Loss: 1.7916	Training Accuracy : 0.1727
# Epoch: 32	Batch: 450	Avg-Loss: 1.7917	Training Accuracy : 0.1623
# Epoch: 32	Batch: 500	Avg-Loss: 1.7915	Training Accuracy : 0.1647
# Epoch: 32	Batch: 550	Avg-Loss: 1.7917	Training Accuracy : 0.1625
# Epoch: 32	Batch: 600	Avg-Loss: 1.7918	Training Accuracy : 0.1647
# Epoch: 32	Batch: 650	Avg-Loss: 1.7917	Training Accuracy : 0.1664
# Epoch: 32, Validation Loss: 1.792, Validation Accuracy: 0.167
# Epoch: 33	Batch: 50	Avg-Loss: 1.7918	Training Accuracy : 0.1677
# Epoch: 33	Batch: 100	Avg-Loss: 1.7919	Training Accuracy : 0.1611
# Epoch: 33	Batch: 150	Avg-Loss: 1.7919	Training Accuracy : 0.1672
# Epoch: 33	Batch: 200	Avg-Loss: 1.7916	Training Accuracy : 0.1688
# Epoch: 33	Batch: 250	Avg-Loss: 1.7918	Training Accuracy : 0.1666
# Epoch: 33	Batch: 300	Avg-Loss: 1.7916	Training Accuracy : 0.1753
# Epoch: 33	Batch: 350	Avg-Loss: 1.7914	Training Accuracy : 0.1717
# Epoch: 33	Batch: 400	Avg-Loss: 1.7918	Training Accuracy : 0.1636
# Epoch: 33	Batch: 450	Avg-Loss: 1.7916	Training Accuracy : 0.1673
# Epoch: 33	Batch: 500	Avg-Loss: 1.7914	Training Accuracy : 0.1716
# Epoch: 33	Batch: 550	Avg-Loss: 1.7917	Training Accuracy : 0.1678
# Epoch: 33	Batch: 600	Avg-Loss: 1.7917	Training Accuracy : 0.1694
# Epoch: 33	Batch: 650	Avg-Loss: 1.7917	Training Accuracy : 0.1720
# Epoch: 33, Validation Loss: 1.792, Validation Accuracy: 0.167
# Epoch: 34	Batch: 50	Avg-Loss: 1.7915	Training Accuracy : 0.1773
# Epoch: 34	Batch: 100	Avg-Loss: 1.7914	Training Accuracy : 0.1686
# Epoch: 34	Batch: 150	Avg-Loss: 1.7918	Training Accuracy : 0.1698
# Epoch: 34	Batch: 200	Avg-Loss: 1.7916	Training Accuracy : 0.1639
# Epoch: 34	Batch: 250	Avg-Loss: 1.7916	Training Accuracy : 0.1631
# Epoch: 34	Batch: 300	Avg-Loss: 1.7917	Training Accuracy : 0.1766
# Epoch: 34	Batch: 350	Avg-Loss: 1.7917	Training Accuracy : 0.1684
# Epoch: 34	Batch: 400	Avg-Loss: 1.7916	Training Accuracy : 0.1672
# Epoch: 34	Batch: 450	Avg-Loss: 1.7919	Training Accuracy : 0.1605
# Epoch: 34	Batch: 500	Avg-Loss: 1.7919	Training Accuracy : 0.1722
# Epoch: 34	Batch: 550	Avg-Loss: 1.7919	Training Accuracy : 0.1617
# Epoch: 34	Batch: 600	Avg-Loss: 1.7914	Training Accuracy : 0.1680
# Epoch: 34	Batch: 650	Avg-Loss: 1.7917	Training Accuracy : 0.1575
# Epoch    35: reducing learning rate of group 0 to 1.9531e-04.
# Epoch: 34, Validation Loss: 1.792, Validation Accuracy: 0.167
# Epoch: 35	Batch: 50	Avg-Loss: 1.7916	Training Accuracy : 0.1655
# Epoch: 35	Batch: 100	Avg-Loss: 1.7916	Training Accuracy : 0.1720
# Epoch: 35	Batch: 150	Avg-Loss: 1.7916	Training Accuracy : 0.1709
# Epoch: 35	Batch: 200	Avg-Loss: 1.7915	Training Accuracy : 0.1750
# Epoch: 35	Batch: 250	Avg-Loss: 1.7916	Training Accuracy : 0.1663
# Epoch: 35	Batch: 300	Avg-Loss: 1.7917	Training Accuracy : 0.1664
# Epoch: 35	Batch: 350	Avg-Loss: 1.7920	Training Accuracy : 0.1614
# Epoch: 35	Batch: 400	Avg-Loss: 1.7917	Training Accuracy : 0.1697
# Epoch: 35	Batch: 450	Avg-Loss: 1.7916	Training Accuracy : 0.1773
# Epoch: 35	Batch: 500	Avg-Loss: 1.7912	Training Accuracy : 0.1742
# Epoch: 35	Batch: 550	Avg-Loss: 1.7917	Training Accuracy : 0.1645
# Epoch: 35	Batch: 600	Avg-Loss: 1.7917	Training Accuracy : 0.1681
# Epoch: 35	Batch: 650	Avg-Loss: 1.7920	Training Accuracy : 0.1631
# Epoch: 35, Validation Loss: 1.792, Validation Accuracy: 0.167
# Epoch: 36	Batch: 50	Avg-Loss: 1.7914	Training Accuracy : 0.1681
# Epoch: 36	Batch: 100	Avg-Loss: 1.7915	Training Accuracy : 0.1667
# Epoch: 36	Batch: 150	Avg-Loss: 1.7915	Training Accuracy : 0.1667
# Epoch: 36	Batch: 200	Avg-Loss: 1.7917	Training Accuracy : 0.1683
# Epoch: 36	Batch: 250	Avg-Loss: 1.7917	Training Accuracy : 0.1675
# Epoch: 36	Batch: 300	Avg-Loss: 1.7917	Training Accuracy : 0.1659
# Epoch: 36	Batch: 350	Avg-Loss: 1.7917	Training Accuracy : 0.1744
# Epoch: 36	Batch: 400	Avg-Loss: 1.7918	Training Accuracy : 0.1673
# Epoch: 36	Batch: 450	Avg-Loss: 1.7918	Training Accuracy : 0.1683
# Epoch: 36	Batch: 500	Avg-Loss: 1.7916	Training Accuracy : 0.1655
# Epoch: 36	Batch: 550	Avg-Loss: 1.7917	Training Accuracy : 0.1675
# Epoch: 36	Batch: 600	Avg-Loss: 1.7916	Training Accuracy : 0.1695
# Epoch: 36	Batch: 650	Avg-Loss: 1.7916	Training Accuracy : 0.1698
# Epoch: 36, Validation Loss: 1.792, Validation Accuracy: 0.167
# Epoch: 37	Batch: 50	Avg-Loss: 1.7915	Training Accuracy : 0.1700
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-6f4ae6508a18> in <module>()
#      25             avg_train_acc = 0.0
#      26
# ---> 27         torch.cuda.empty_cache()
#      28         del x
#      29         del y
#
# /usr/local/lib/python3.7/dist-packages/torch/cuda/memory.py in empty_cache()
#     112     """
#     113     if is_initialized():
# --> 114         torch._C._cuda_emptyCache()
#     115
#     116
#
# KeyboardInterrupt:

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Sun Nov 28 18:47:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    32W / 250W |   1019MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_images, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet_2+1_base/best_model_1.pt"))
network = network.to(device)

# %%
with torch.no_grad():
  network.eval()
  num_correct = 0
  for x, y in tqdm(test_loader):
    x, y = x.to(device), y.to(device)
    outputs = network(x)
    num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

  test_acc = num_correct / len(test_set)
  print(test_acc)
# Out:
# 100%|██████████| 142/142 [00:55<00:00,  2.58it/s]
# 0.16927500967759773

# %%
print(test_acc)
# Out:
# 0.16927500967759773
