# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("4+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149670.jpg', 'frame_149739.jpg', 'fram...     16
# 1      ('frame_149738.jpg', 'frame_149692.jpg', 'fram...     80
# 2      ('frame_149729.jpg', 'frame_149716.jpg', 'fram...     86
# 3      ('frame_149669.jpg', 'frame_149712.jpg', 'fram...      7
# 4      ('frame_149683.jpg', 'frame_149707.jpg', 'fram...     34
# ...                                                  ...    ...
# 17942  ('frame_180809.jpg', 'frame_174579.jpg', 'fram...    101
# 17943  ('frame_174581.jpg', 'frame_174634.jpg', 'fram...     14
# 17944  ('frame_174605.jpg', 'frame_174596.jpg', 'fram...     54
# 17945  ('frame_181123.jpg', 'frame_174585.jpg', 'fram...     96
# 17946  ('frame_181333.jpg', 'frame_174579.jpg', 'fram...     97
#
# [17947 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, transform=None, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]
        self.transform = transform

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            # img = torchvision.transforms.Normalize(mean=[0.2068, 0.2242, 0.2269], std=[0.2520, 0.2394, 0.2320])(img)
            if self.transform:
                img = self.transform(img)
            images.extend(img)
        x = torch.stack(images)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([15, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
# transform_train = torchvision.transforms.Compose([
#     torchvision.transforms.Normalize(mean=[0.4967, 0.4858, 0.4584, 0.4969, 0.4700, 0.4585, 0.4964, 0.4854, 0.4580, 0.4972, 0.4862, 0.4585, 0.4964, 0.4857, 0.4584],
#                                       std=[0.2681, 0.2574, 0.2433, 0.2678, 0.2500, 0.2429, 0.2679, 0.2572, 0.2428, 0.2680, 0.2573, 0.2428, 0.2680, 0.2574, 0.2431])
# ])

transform_train = torchvision.transforms.Compose([
    torchvision.transforms.RandomVerticalFlip(p=0.5)
])

# %%
batch_size = 128

# training data
train_set = MyDataSet(train_data, transform_train)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %%
# def batch_mean_and_sd(loader, num_channels):
    
#     cnt = 0
#     fst_moment = torch.empty(num_channels)
#     snd_moment = torch.empty(num_channels)

#     for images, _ in tqdm(loader):
#         b, c, h, w = images.shape
#         nb_pixels = b * h * w
#         sum_ = torch.sum(images, dim=[0, 2, 3])
#         sum_of_square = torch.sum(images ** 2,
#                                   dim=[0, 2, 3])
#         fst_moment = (cnt * fst_moment + sum_) / (cnt + nb_pixels)
#         snd_moment = (cnt * snd_moment + sum_of_square) / (cnt + nb_pixels)
#         cnt += nb_pixels

#     mean, std = fst_moment, torch.sqrt(snd_moment - fst_moment ** 2)        
#     return mean,std
  
# num_channels = 15
# mean, std = batch_mean_and_sd(train_loader, num_channels)
# print("mean and std: \n", mean, std)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding,num_classes))


    def forward(self, x):
      out = self.cnn(x)
      out = self.mlp(out)
      return out

# %%
numEpochs = 100
in_features = 15 # TODO: change RGB channels according to num of frames
embedding = 512

learningRate = 0.1
weightDecay = 1e-4

num_classes = 120

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_classes)
#network.load_state_dict(torch.load("model_checkpoints/resnet34/lr_0.1-2/model_2.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      checkpoint_name = "/content/gdrive/MyDrive/regnet_ours_data7/model_" + str(epoch) + ".pt"
      torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/regnet_ours_data7/best_model.pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 0	Batch: 50	Avg-Loss: 4.9703	Training Accuracy : 0.0080
# Epoch: 0	Batch: 100	Avg-Loss: 4.6551	Training Accuracy : 0.0133
# Epoch: 0	Batch: 150	Avg-Loss: 4.3191	Training Accuracy : 0.0222
# Epoch: 0	Batch: 200	Avg-Loss: 4.0272	Training Accuracy : 0.0284
# Epoch: 0	Batch: 250	Avg-Loss: 3.7275	Training Accuracy : 0.0392
# Epoch: 0	Batch: 300	Avg-Loss: 3.6125	Training Accuracy : 0.0358
# Epoch: 0	Batch: 350	Avg-Loss: 3.5476	Training Accuracy : 0.0398
# Epoch: 0	Batch: 400	Avg-Loss: 3.4971	Training Accuracy : 0.0459
# Epoch: 13	Batch: 350	Avg-Loss: 2.7215	Training Accuracy : 0.1577
# Epoch: 13	Batch: 400	Avg-Loss: 2.7388	Training Accuracy : 0.1542
# Epoch: 13	Batch: 450	Avg-Loss: 2.7427	Training Accuracy : 0.1530
# Epoch: 13	Batch: 500	Avg-Loss: 2.7030	Training Accuracy : 0.1606
# Epoch: 13	Batch: 550	Avg-Loss: 2.6953	Training Accuracy : 0.1597
# Epoch: 13	Batch: 600	Avg-Loss: 2.7256	Training Accuracy : 0.1508
# Epoch: 13	Batch: 650	Avg-Loss: 2.7191	Training Accuracy : 0.1567
# Epoch: 13, Validation Loss: 2.627, Validation Accuracy: 0.184
# Epoch: 14	Batch: 50	Avg-Loss: 2.6709	Training Accuracy : 0.1589
# Epoch: 14	Batch: 100	Avg-Loss: 2.6720	Training Accuracy : 0.1684
# Epoch: 14	Batch: 150	Avg-Loss: 2.6839	Training Accuracy : 0.1661
# Epoch: 14	Batch: 200	Avg-Loss: 2.6876	Training Accuracy : 0.1648
# Epoch: 14	Batch: 250	Avg-Loss: 2.7032	Training Accuracy : 0.1631
# Epoch: 14	Batch: 300	Avg-Loss: 2.6896	Training Accuracy : 0.1694
# Epoch: 14	Batch: 350	Avg-Loss: 2.6354	Training Accuracy : 0.1702
# Epoch: 14	Batch: 400	Avg-Loss: 2.6705	Training Accuracy : 0.1722
# Epoch: 14	Batch: 450	Avg-Loss: 2.6892	Training Accuracy : 0.1669
# Epoch: 14	Batch: 500	Avg-Loss: 2.6441	Training Accuracy : 0.1759
# Epoch: 14	Batch: 550	Avg-Loss: 2.6492	Training Accuracy : 0.1619
# Epoch: 14	Batch: 600	Avg-Loss: 2.6529	Training Accuracy : 0.1656
# Epoch: 14	Batch: 650	Avg-Loss: 2.6470	Training Accuracy : 0.1734
# Epoch: 14, Validation Loss: 2.977, Validation Accuracy: 0.186
# Epoch: 15	Batch: 50	Avg-Loss: 2.6425	Training Accuracy : 0.1727
# Epoch: 15	Batch: 100	Avg-Loss: 2.6503	Training Accuracy : 0.1678
# Epoch: 15	Batch: 150	Avg-Loss: 2.6096	Training Accuracy : 0.1766
# Epoch: 15	Batch: 200	Avg-Loss: 2.6293	Training Accuracy : 0.1722
# Epoch: 15	Batch: 250	Avg-Loss: 2.6377	Training Accuracy : 0.1694
# Epoch: 15	Batch: 300	Avg-Loss: 2.5914	Training Accuracy : 0.1798
# Epoch: 15	Batch: 350	Avg-Loss: 2.6230	Training Accuracy : 0.1683
# Epoch: 15	Batch: 400	Avg-Loss: 2.6171	Training Accuracy : 0.1789
# Epoch: 15	Batch: 450	Avg-Loss: 2.6275	Training Accuracy : 0.1750
# Epoch: 15	Batch: 500	Avg-Loss: 2.6364	Training Accuracy : 0.1634
# Epoch: 15	Batch: 550	Avg-Loss: 2.6426	Training Accuracy : 0.1711
# Epoch: 15	Batch: 600	Avg-Loss: 2.6050	Training Accuracy : 0.1737
# Epoch: 15	Batch: 650	Avg-Loss: 2.6330	Training Accuracy : 0.1702
# Epoch: 15, Validation Loss: 2.562, Validation Accuracy: 0.209
# Epoch: 16	Batch: 50	Avg-Loss: 2.5817	Training Accuracy : 0.1805
# Epoch: 16	Batch: 100	Avg-Loss: 2.5725	Training Accuracy : 0.1855
# Epoch: 16	Batch: 150	Avg-Loss: 2.5835	Training Accuracy : 0.1831
# Epoch: 16	Batch: 200	Avg-Loss: 2.6191	Training Accuracy : 0.1789
# Epoch: 16	Batch: 250	Avg-Loss: 2.5792	Training Accuracy : 0.1861
# Epoch: 16	Batch: 300	Avg-Loss: 2.5793	Training Accuracy : 0.1872
# Epoch: 16	Batch: 350	Avg-Loss: 2.5774	Training Accuracy : 0.1853
# Epoch: 16	Batch: 400	Avg-Loss: 2.6160	Training Accuracy : 0.1827
# Epoch: 16	Batch: 450	Avg-Loss: 2.5775	Training Accuracy : 0.1753
# Epoch: 16	Batch: 500	Avg-Loss: 2.5830	Training Accuracy : 0.1827
# Epoch: 16	Batch: 550	Avg-Loss: 2.6059	Training Accuracy : 0.1798
# Epoch: 16	Batch: 600	Avg-Loss: 2.5833	Training Accuracy : 0.1783
# Epoch: 16	Batch: 650	Avg-Loss: 2.5953	Training Accuracy : 0.1827
# Epoch: 16, Validation Loss: 2.494, Validation Accuracy: 0.213
# Epoch: 17	Batch: 50	Avg-Loss: 2.5603	Training Accuracy : 0.1808
# Epoch: 17	Batch: 100	Avg-Loss: 2.5471	Training Accuracy : 0.1964
# Epoch: 17	Batch: 150	Avg-Loss: 2.5623	Training Accuracy : 0.1848
# Epoch: 17	Batch: 200	Avg-Loss: 2.5705	Training Accuracy : 0.1841
# Epoch: 17	Batch: 250	Avg-Loss: 2.5313	Training Accuracy : 0.1911
# Epoch: 17	Batch: 300	Avg-Loss: 2.5377	Training Accuracy : 0.1878
# Epoch: 17	Batch: 350	Avg-Loss: 2.5375	Training Accuracy : 0.1913
# Epoch: 17	Batch: 400	Avg-Loss: 2.5558	Training Accuracy : 0.1853
# Epoch: 17	Batch: 450	Avg-Loss: 2.5810	Training Accuracy : 0.1778
# Epoch: 17	Batch: 500	Avg-Loss: 2.5474	Training Accuracy : 0.1794
# Epoch: 17	Batch: 550	Avg-Loss: 2.5464	Training Accuracy : 0.1822
# Epoch: 17	Batch: 600	Avg-Loss: 2.5386	Training Accuracy : 0.1889
# Epoch: 17	Batch: 650	Avg-Loss: 2.5394	Training Accuracy : 0.1911
# Epoch: 17, Validation Loss: 2.443, Validation Accuracy: 0.224
# Epoch: 18	Batch: 50	Avg-Loss: 2.5545	Training Accuracy : 0.1895
# Epoch: 18	Batch: 100	Avg-Loss: 2.5080	Training Accuracy : 0.1911
# Epoch: 18	Batch: 150	Avg-Loss: 2.5284	Training Accuracy : 0.1894
# Epoch: 18	Batch: 200	Avg-Loss: 2.5259	Training Accuracy : 0.1953
# Epoch: 18	Batch: 250	Avg-Loss: 2.5339	Training Accuracy : 0.1936
# Epoch: 18	Batch: 300	Avg-Loss: 2.5481	Training Accuracy : 0.1894
# Epoch: 18	Batch: 350	Avg-Loss: 2.4986	Training Accuracy : 0.2023
# Epoch: 18	Batch: 400	Avg-Loss: 2.5169	Training Accuracy : 0.1889
# Epoch: 18	Batch: 450	Avg-Loss: 2.5197	Training Accuracy : 0.1884
# Epoch: 18	Batch: 500	Avg-Loss: 2.5005	Training Accuracy : 0.1955
# Epoch: 18	Batch: 550	Avg-Loss: 2.5278	Training Accuracy : 0.1925
# Epoch: 18	Batch: 600	Avg-Loss: 2.4859	Training Accuracy : 0.2017
# Epoch: 18	Batch: 650	Avg-Loss: 2.5168	Training Accuracy : 0.1944
# Epoch: 18, Validation Loss: 2.471, Validation Accuracy: 0.216
# Epoch: 19	Batch: 50	Avg-Loss: 2.5052	Training Accuracy : 0.1950
# Epoch: 19	Batch: 100	Avg-Loss: 2.4966	Training Accuracy : 0.2023
# Epoch: 19	Batch: 150	Avg-Loss: 2.4920	Training Accuracy : 0.1981
# Epoch: 19	Batch: 200	Avg-Loss: 2.5115	Training Accuracy : 0.1961
# Epoch: 19	Batch: 250	Avg-Loss: 2.4749	Training Accuracy : 0.2008
# Epoch: 19	Batch: 300	Avg-Loss: 2.4880	Training Accuracy : 0.1997
# Epoch: 19	Batch: 350	Avg-Loss: 2.5012	Training Accuracy : 0.1973
# Epoch: 19	Batch: 400	Avg-Loss: 2.4841	Training Accuracy : 0.1956
# Epoch: 19	Batch: 450	Avg-Loss: 2.4674	Training Accuracy : 0.1956
# Epoch: 19	Batch: 500	Avg-Loss: 2.4776	Training Accuracy : 0.1981
# Epoch: 19	Batch: 550	Avg-Loss: 2.4881	Training Accuracy : 0.1925
# Epoch: 19	Batch: 600	Avg-Loss: 2.4856	Training Accuracy : 0.1988
# Epoch: 19	Batch: 650	Avg-Loss: 2.4925	Training Accuracy : 0.1933
# Epoch: 19, Validation Loss: 2.432, Validation Accuracy: 0.228
# Epoch: 20	Batch: 50	Avg-Loss: 2.4392	Training Accuracy : 0.2127
# Epoch: 20	Batch: 100	Avg-Loss: 2.4736	Training Accuracy : 0.2000
# Epoch: 20	Batch: 150	Avg-Loss: 2.5059	Training Accuracy : 0.1967
# Epoch: 20	Batch: 200	Avg-Loss: 2.4647	Training Accuracy : 0.1959
# Epoch: 20	Batch: 250	Avg-Loss: 2.4511	Training Accuracy : 0.1988
# Epoch: 20	Batch: 300	Avg-Loss: 2.4668	Training Accuracy : 0.2053
# Epoch: 20	Batch: 350	Avg-Loss: 2.4392	Training Accuracy : 0.1927
# Epoch: 20	Batch: 400	Avg-Loss: 2.4766	Training Accuracy : 0.2017
# Epoch: 20	Batch: 450	Avg-Loss: 2.4407	Training Accuracy : 0.2103
# Epoch: 20	Batch: 500	Avg-Loss: 2.4583	Training Accuracy : 0.1988
# Epoch: 20	Batch: 550	Avg-Loss: 2.4711	Training Accuracy : 0.2077
# Epoch: 20	Batch: 600	Avg-Loss: 2.4709	Training Accuracy : 0.1927
# Epoch: 20	Batch: 650	Avg-Loss: 2.4835	Training Accuracy : 0.1966
# Epoch: 20, Validation Loss: 2.578, Validation Accuracy: 0.203
# Epoch: 21	Batch: 50	Avg-Loss: 2.4152	Training Accuracy : 0.2091
# Epoch: 21	Batch: 100	Avg-Loss: 2.4243	Training Accuracy : 0.2134
# Epoch: 23	Batch: 500	Avg-Loss: 2.1995	Training Accuracy : 0.2470
# Epoch: 23	Batch: 550	Avg-Loss: 2.2169	Training Accuracy : 0.2423
# Epoch: 23	Batch: 600	Avg-Loss: 2.2267	Training Accuracy : 0.2345
# Epoch: 23	Batch: 650	Avg-Loss: 2.2237	Training Accuracy : 0.2386
# Epoch: 23, Validation Loss: 2.417, Validation Accuracy: 0.234
# Epoch: 24	Batch: 50	Avg-Loss: 2.1920	Training Accuracy : 0.2445
# Epoch: 24	Batch: 100	Avg-Loss: 2.1619	Training Accuracy : 0.2486
# Epoch: 24	Batch: 150	Avg-Loss: 2.1747	Training Accuracy : 0.2483
# Epoch: 24	Batch: 200	Avg-Loss: 2.2036	Training Accuracy : 0.2416
# Epoch: 24	Batch: 250	Avg-Loss: 2.2007	Training Accuracy : 0.2434
# Epoch: 24	Batch: 300	Avg-Loss: 2.1557	Training Accuracy : 0.2422
# Epoch: 24	Batch: 350	Avg-Loss: 2.1848	Training Accuracy : 0.2402
# Epoch: 24	Batch: 400	Avg-Loss: 2.1794	Training Accuracy : 0.2441
# Epoch: 24	Batch: 450	Avg-Loss: 2.1807	Training Accuracy : 0.2444
# Epoch: 24	Batch: 500	Avg-Loss: 2.2109	Training Accuracy : 0.2309
# Epoch: 24	Batch: 550	Avg-Loss: 2.1964	Training Accuracy : 0.2362
# Epoch: 24	Batch: 600	Avg-Loss: 2.1678	Training Accuracy : 0.2509
# Epoch: 24	Batch: 650	Avg-Loss: 2.2204	Training Accuracy : 0.2389
# Epoch: 24, Validation Loss: 2.597, Validation Accuracy: 0.231
# Epoch: 25	Batch: 50	Avg-Loss: 2.1621	Training Accuracy : 0.2456
# Epoch: 25	Batch: 100	Avg-Loss: 2.1290	Training Accuracy : 0.2487
# Epoch: 25	Batch: 150	Avg-Loss: 2.1451	Training Accuracy : 0.2506
# Epoch: 25	Batch: 200	Avg-Loss: 2.1595	Training Accuracy : 0.2477
# Epoch: 25	Batch: 250	Avg-Loss: 2.1767	Training Accuracy : 0.2427
# Epoch: 25	Batch: 300	Avg-Loss: 2.1552	Training Accuracy : 0.2528
# Epoch: 25	Batch: 350	Avg-Loss: 2.1638	Training Accuracy : 0.2472
# Epoch: 25	Batch: 400	Avg-Loss: 2.1864	Training Accuracy : 0.2356
# Epoch: 25	Batch: 450	Avg-Loss: 2.1460	Training Accuracy : 0.2459
# Epoch: 25	Batch: 500	Avg-Loss: 2.1331	Training Accuracy : 0.2466
# Epoch: 25	Batch: 550	Avg-Loss: 2.1522	Training Accuracy : 0.2509
# Epoch: 25	Batch: 600	Avg-Loss: 2.1560	Training Accuracy : 0.2508
# Epoch: 25	Batch: 650	Avg-Loss: 2.1685	Training Accuracy : 0.2461
# Epoch: 25, Validation Loss: 2.477, Validation Accuracy: 0.232
# Epoch: 26	Batch: 50	Avg-Loss: 2.1080	Training Accuracy : 0.2614
# Epoch: 26	Batch: 100	Avg-Loss: 2.1313	Training Accuracy : 0.2531
# Epoch: 26	Batch: 150	Avg-Loss: 2.1231	Training Accuracy : 0.2506
# Epoch: 26	Batch: 200	Avg-Loss: 2.0916	Training Accuracy : 0.2620
# Epoch: 26	Batch: 250	Avg-Loss: 2.1404	Training Accuracy : 0.2533
# Epoch: 26	Batch: 300	Avg-Loss: 2.1485	Training Accuracy : 0.2542
# Epoch: 26	Batch: 350	Avg-Loss: 2.1418	Training Accuracy : 0.2445
# Epoch: 26	Batch: 400	Avg-Loss: 2.1136	Training Accuracy : 0.2597
# Epoch: 26	Batch: 450	Avg-Loss: 2.1032	Training Accuracy : 0.2550
# Epoch: 26	Batch: 500	Avg-Loss: 2.1365	Training Accuracy : 0.2547
# Epoch: 26	Batch: 550	Avg-Loss: 2.1165	Training Accuracy : 0.2509
# Epoch: 26	Batch: 600	Avg-Loss: 2.1439	Training Accuracy : 0.2547
# Epoch: 26	Batch: 650	Avg-Loss: 2.1340	Training Accuracy : 0.2431
# Epoch    27: reducing learning rate of group 0 to 2.5000e-02.
# Epoch: 26, Validation Loss: 2.480, Validation Accuracy: 0.229
# Epoch: 27	Batch: 50	Avg-Loss: 1.9867	Training Accuracy : 0.2806
# Epoch: 27	Batch: 100	Avg-Loss: 1.9724	Training Accuracy : 0.2855
# Epoch: 27	Batch: 150	Avg-Loss: 1.9759	Training Accuracy : 0.2780
# Epoch: 27	Batch: 200	Avg-Loss: 1.9469	Training Accuracy : 0.2898
# Epoch: 27	Batch: 250	Avg-Loss: 1.9644	Training Accuracy : 0.2888
# Epoch: 27	Batch: 300	Avg-Loss: 1.9025	Training Accuracy : 0.3086
# Epoch: 27	Batch: 350	Avg-Loss: 1.9563	Training Accuracy : 0.2781
# Epoch: 27	Batch: 400	Avg-Loss: 1.9843	Training Accuracy : 0.2867
# Epoch: 27	Batch: 450	Avg-Loss: 1.9648	Training Accuracy : 0.2791
# Epoch: 27	Batch: 500	Avg-Loss: 1.9648	Training Accuracy : 0.2833
# Epoch: 27	Batch: 550	Avg-Loss: 1.9716	Training Accuracy : 0.2859
# Epoch: 27	Batch: 600	Avg-Loss: 1.9406	Training Accuracy : 0.2812
# Epoch: 27	Batch: 650	Avg-Loss: 1.9465	Training Accuracy : 0.2916
# Epoch: 27, Validation Loss: 2.515, Validation Accuracy: 0.235
# Epoch: 28	Batch: 50	Avg-Loss: 1.9116	Training Accuracy : 0.2938
# Epoch: 28	Batch: 100	Avg-Loss: 1.8791	Training Accuracy : 0.3020
# Epoch: 28	Batch: 150	Avg-Loss: 1.9208	Training Accuracy : 0.2970
# Epoch: 28	Batch: 200	Avg-Loss: 1.8867	Training Accuracy : 0.3039
# Epoch: 28	Batch: 250	Avg-Loss: 1.8761	Training Accuracy : 0.3030
# Epoch: 28	Batch: 300	Avg-Loss: 1.9199	Training Accuracy : 0.2966
# Epoch: 28	Batch: 350	Avg-Loss: 1.8935	Training Accuracy : 0.3019
# Epoch: 28	Batch: 400	Avg-Loss: 1.9263	Training Accuracy : 0.2989
# Epoch: 28	Batch: 450	Avg-Loss: 1.9092	Training Accuracy : 0.3059
# Epoch: 28	Batch: 500	Avg-Loss: 1.9046	Training Accuracy : 0.3008
# Epoch: 28	Batch: 550	Avg-Loss: 1.9274	Training Accuracy : 0.2992
# Epoch: 28	Batch: 600	Avg-Loss: 1.9362	Training Accuracy : 0.3039
# Epoch: 28	Batch: 650	Avg-Loss: 1.9581	Training Accuracy : 0.2886
# Epoch: 28, Validation Loss: 2.541, Validation Accuracy: 0.232
# Epoch: 29	Batch: 50	Avg-Loss: 1.8671	Training Accuracy : 0.3059
# Epoch: 29	Batch: 100	Avg-Loss: 1.8518	Training Accuracy : 0.3270
# Epoch: 29	Batch: 150	Avg-Loss: 1.8795	Training Accuracy : 0.3058
# Epoch: 29	Batch: 200	Avg-Loss: 1.8743	Training Accuracy : 0.3114
# Epoch: 29	Batch: 250	Avg-Loss: 1.8854	Training Accuracy : 0.3102
# Epoch: 29	Batch: 300	Avg-Loss: 1.8813	Training Accuracy : 0.3144
# Epoch: 29	Batch: 350	Avg-Loss: 1.8529	Training Accuracy : 0.3153
# Epoch: 29	Batch: 400	Avg-Loss: 1.8810	Training Accuracy : 0.3052
# Epoch: 29	Batch: 450	Avg-Loss: 1.8847	Training Accuracy : 0.3131
# Epoch: 29	Batch: 500	Avg-Loss: 1.9081	Training Accuracy : 0.2984
# Epoch: 29	Batch: 550	Avg-Loss: 1.8827	Training Accuracy : 0.3084
# Epoch: 29	Batch: 600	Avg-Loss: 1.8740	Training Accuracy : 0.3170
# Epoch: 29	Batch: 650	Avg-Loss: 1.8891	Training Accuracy : 0.3008
# Epoch    30: reducing learning rate of group 0 to 1.2500e-02.
# Epoch: 29, Validation Loss: 2.584, Validation Accuracy: 0.229
# Epoch: 30	Batch: 50	Avg-Loss: 1.7760	Training Accuracy : 0.3483
# Epoch: 30	Batch: 100	Avg-Loss: 1.7455	Training Accuracy : 0.3497
# Epoch: 30	Batch: 150	Avg-Loss: 1.7349	Training Accuracy : 0.3617
# Epoch: 30	Batch: 200	Avg-Loss: 1.7585	Training Accuracy : 0.3416
# Epoch: 30	Batch: 250	Avg-Loss: 1.7484	Training Accuracy : 0.3450
# Epoch: 30	Batch: 300	Avg-Loss: 1.7535	Training Accuracy : 0.3431
# Epoch: 30	Batch: 350	Avg-Loss: 1.7432	Training Accuracy : 0.3556
# Epoch: 30	Batch: 400	Avg-Loss: 1.7344	Training Accuracy : 0.3556
# Epoch: 30	Batch: 450	Avg-Loss: 1.7232	Training Accuracy : 0.3550
# Epoch: 30	Batch: 500	Avg-Loss: 1.7271	Training Accuracy : 0.3577
# Epoch: 30	Batch: 550	Avg-Loss: 1.7408	Training Accuracy : 0.3513
# Epoch: 30	Batch: 600	Avg-Loss: 1.7335	Training Accuracy : 0.3595
# Epoch: 30	Batch: 650	Avg-Loss: 1.7528	Training Accuracy : 0.3509
# Epoch: 30, Validation Loss: 2.600, Validation Accuracy: 0.237
# Epoch: 31	Batch: 50	Avg-Loss: 1.6868	Training Accuracy : 0.3677
# Epoch: 31	Batch: 100	Avg-Loss: 1.6852	Training Accuracy : 0.3758
# Epoch: 31	Batch: 150	Avg-Loss: 1.7044	Training Accuracy : 0.3658
# Epoch: 31	Batch: 200	Avg-Loss: 1.6621	Training Accuracy : 0.3761
# Epoch: 31	Batch: 250	Avg-Loss: 1.6656	Training Accuracy : 0.3856
# Epoch: 31	Batch: 300	Avg-Loss: 1.6804	Training Accuracy : 0.3764
# Epoch: 31	Batch: 350	Avg-Loss: 1.6987	Training Accuracy : 0.3766
# Epoch: 31	Batch: 400	Avg-Loss: 1.6836	Training Accuracy : 0.3727
# Epoch: 31	Batch: 450	Avg-Loss: 1.6792	Training Accuracy : 0.3842
# Epoch: 31	Batch: 500	Avg-Loss: 1.6861	Training Accuracy : 0.3814
# Epoch: 31	Batch: 550	Avg-Loss: 1.7047	Training Accuracy : 0.3703
# Epoch: 31	Batch: 600	Avg-Loss: 1.6937	Training Accuracy : 0.3803
# Epoch: 31	Batch: 650	Avg-Loss: 1.6751	Training Accuracy : 0.3866
# Epoch: 31, Validation Loss: 2.667, Validation Accuracy: 0.224
# Epoch: 32	Batch: 50	Avg-Loss: 1.6287	Training Accuracy : 0.4003
# Epoch: 32	Batch: 100	Avg-Loss: 1.6514	Training Accuracy : 0.3991
# Epoch: 32	Batch: 150	Avg-Loss: 1.6216	Training Accuracy : 0.4039
# Epoch: 32	Batch: 200	Avg-Loss: 1.6518	Training Accuracy : 0.4019
# Epoch: 32	Batch: 250	Avg-Loss: 1.6675	Training Accuracy : 0.4022
# Epoch: 32	Batch: 300	Avg-Loss: 1.6580	Training Accuracy : 0.4014
# Epoch: 32	Batch: 350	Avg-Loss: 1.6761	Training Accuracy : 0.4002
# Epoch: 32	Batch: 400	Avg-Loss: 1.6398	Training Accuracy : 0.4003
# Epoch: 32	Batch: 450	Avg-Loss: 1.6566	Training Accuracy : 0.4083
# Epoch: 32	Batch: 500	Avg-Loss: 1.6478	Training Accuracy : 0.4044
# Epoch: 32	Batch: 550	Avg-Loss: 1.6684	Training Accuracy : 0.4005
# Epoch: 32	Batch: 600	Avg-Loss: 1.6429	Training Accuracy : 0.4109
# Epoch: 32	Batch: 650	Avg-Loss: 1.6519	Training Accuracy : 0.4113
# Epoch    33: reducing learning rate of group 0 to 6.2500e-03.
# Epoch: 32, Validation Loss: 2.786, Validation Accuracy: 0.221
# Epoch: 33	Batch: 50	Avg-Loss: 1.5551	Training Accuracy : 0.4403
# Epoch: 33	Batch: 100	Avg-Loss: 1.5151	Training Accuracy : 0.4658
# Epoch: 33	Batch: 150	Avg-Loss: 1.5464	Training Accuracy : 0.4553
# Epoch: 33	Batch: 200	Avg-Loss: 1.4966	Training Accuracy : 0.4670
# Epoch: 33	Batch: 250	Avg-Loss: 1.5042	Training Accuracy : 0.4702
# Epoch: 33	Batch: 300	Avg-Loss: 1.5143	Training Accuracy : 0.4630
# Epoch: 33	Batch: 350	Avg-Loss: 1.5079	Training Accuracy : 0.4714
# Epoch: 33	Batch: 400	Avg-Loss: 1.4816	Training Accuracy : 0.4792
# Epoch: 33	Batch: 450	Avg-Loss: 1.4963	Training Accuracy : 0.4720
# Epoch: 33	Batch: 500	Avg-Loss: 1.4842	Training Accuracy : 0.4720
# Epoch: 33	Batch: 550	Avg-Loss: 1.4970	Training Accuracy : 0.4738
# Epoch: 33	Batch: 600	Avg-Loss: 1.4824	Training Accuracy : 0.4784
# Epoch: 33	Batch: 650	Avg-Loss: 1.4807	Training Accuracy : 0.4870
# Epoch: 33, Validation Loss: 2.830, Validation Accuracy: 0.236
# Epoch: 34	Batch: 50	Avg-Loss: 1.4182	Training Accuracy : 0.5108
# Epoch: 34	Batch: 100	Avg-Loss: 1.4346	Training Accuracy : 0.5044
# Epoch: 34	Batch: 150	Avg-Loss: 1.4211	Training Accuracy : 0.5111
# Epoch: 34	Batch: 200	Avg-Loss: 1.4315	Training Accuracy : 0.5034
# Epoch: 34	Batch: 250	Avg-Loss: 1.4263	Training Accuracy : 0.5034
# Epoch: 34	Batch: 300	Avg-Loss: 1.4223	Training Accuracy : 0.5069
# Epoch: 34	Batch: 350	Avg-Loss: 1.4141	Training Accuracy : 0.5095
# Epoch: 34	Batch: 400	Avg-Loss: 1.4197	Training Accuracy : 0.5158
# Epoch: 34	Batch: 450	Avg-Loss: 1.4100	Training Accuracy : 0.5092
# Epoch: 34	Batch: 500	Avg-Loss: 1.4234	Training Accuracy : 0.5216
# Epoch: 34	Batch: 550	Avg-Loss: 1.4222	Training Accuracy : 0.5034
# Epoch: 34	Batch: 600	Avg-Loss: 1.4466	Training Accuracy : 0.5009
# Epoch: 34	Batch: 650	Avg-Loss: 1.4168	Training Accuracy : 0.5133
# Epoch: 34, Validation Loss: 2.950, Validation Accuracy: 0.231
# Epoch: 35	Batch: 50	Avg-Loss: 1.3587	Training Accuracy : 0.5336
# Epoch: 35	Batch: 100	Avg-Loss: 1.3564	Training Accuracy : 0.5436
# Epoch: 35	Batch: 150	Avg-Loss: 1.3194	Training Accuracy : 0.5417
# Epoch: 35	Batch: 200	Avg-Loss: 1.3578	Training Accuracy : 0.5392
# Epoch: 35	Batch: 250	Avg-Loss: 1.3653	Training Accuracy : 0.5378
# Epoch: 35	Batch: 300	Avg-Loss: 1.3911	Training Accuracy : 0.5328
# Epoch: 35	Batch: 350	Avg-Loss: 1.3469	Training Accuracy : 0.5523
# Epoch: 35	Batch: 400	Avg-Loss: 1.3783	Training Accuracy : 0.5288
# Epoch: 35	Batch: 450	Avg-Loss: 1.3486	Training Accuracy : 0.5467
# Epoch: 35	Batch: 500	Avg-Loss: 1.3248	Training Accuracy : 0.5448
# Epoch: 35	Batch: 550	Avg-Loss: 1.3615	Training Accuracy : 0.5420
# Epoch: 35	Batch: 600	Avg-Loss: 1.3517	Training Accuracy : 0.5452
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-2dfc1c48cd0d> in <module>()
#      16
#      17         loss = criterion(outputs, y.long())
# ---> 18         loss.backward()
#      19         optimizer.step()
#      20         avg_loss += loss.item()
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     157
#     158
#
# KeyboardInterrupt:

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/regnet_ours_data7/best_model.pt"))
network = network.to(device)

# %%
network.eval()
num_correct = 0
for x, y in tqdm(test_loader):
  x, y = x.to(device), y.to(device)
  outputs = network(x)
  num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

test_acc = num_correct / len(test_set)
print(test_acc)
# Out:
# 100%|██████████| 141/141 [02:41<00:00,  1.15s/it]
# 0.23040062405973144
