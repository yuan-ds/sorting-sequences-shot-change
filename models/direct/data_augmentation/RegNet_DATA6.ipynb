# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("4+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149670.jpg', 'frame_149739.jpg', 'fram...     16
# 1      ('frame_149738.jpg', 'frame_149692.jpg', 'fram...     80
# 2      ('frame_149729.jpg', 'frame_149716.jpg', 'fram...     86
# 3      ('frame_149669.jpg', 'frame_149712.jpg', 'fram...      7
# 4      ('frame_149683.jpg', 'frame_149707.jpg', 'fram...     34
# ...                                                  ...    ...
# 17942  ('frame_180809.jpg', 'frame_174579.jpg', 'fram...    101
# 17943  ('frame_174581.jpg', 'frame_174634.jpg', 'fram...     14
# 17944  ('frame_174605.jpg', 'frame_174596.jpg', 'fram...     54
# 17945  ('frame_181123.jpg', 'frame_174585.jpg', 'fram...     96
# 17946  ('frame_181333.jpg', 'frame_174579.jpg', 'fram...     97
#
# [17947 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, transform=None, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]
        self.transform = transform

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            # img = torchvision.transforms.Normalize(mean=[0.2068, 0.2242, 0.2269], std=[0.2520, 0.2394, 0.2320])(img)
            images.extend(img)
        x = torch.stack(images)
        if self.transform:
          x = self.transform(x)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([15, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
# transform_train = torchvision.transforms.Compose([
#     torchvision.transforms.Normalize(mean=[0.4967, 0.4858, 0.4584, 0.4969, 0.4700, 0.4585, 0.4964, 0.4854, 0.4580, 0.4972, 0.4862, 0.4585, 0.4964, 0.4857, 0.4584],
#                                       std=[0.2681, 0.2574, 0.2433, 0.2678, 0.2500, 0.2429, 0.2679, 0.2572, 0.2428, 0.2680, 0.2573, 0.2428, 0.2680, 0.2574, 0.2431])
# ])

transform_train = torchvision.transforms.Compose([
    torchvision.transforms.RandomHorizontalFlip(p=0.5)
])

# %%
batch_size = 128

# training data
train_set = MyDataSet(train_data, transform_train)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %%
# def batch_mean_and_sd(loader, num_channels):
    
#     cnt = 0
#     fst_moment = torch.empty(num_channels)
#     snd_moment = torch.empty(num_channels)

#     for images, _ in tqdm(loader):
#         b, c, h, w = images.shape
#         nb_pixels = b * h * w
#         sum_ = torch.sum(images, dim=[0, 2, 3])
#         sum_of_square = torch.sum(images ** 2,
#                                   dim=[0, 2, 3])
#         fst_moment = (cnt * fst_moment + sum_) / (cnt + nb_pixels)
#         snd_moment = (cnt * snd_moment + sum_of_square) / (cnt + nb_pixels)
#         cnt += nb_pixels

#     mean, std = fst_moment, torch.sqrt(snd_moment - fst_moment ** 2)        
#     return mean,std
  
# num_channels = 15
# mean, std = batch_mean_and_sd(train_loader, num_channels)
# print("mean and std: \n", mean, std)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding,num_classes))


    def forward(self, x):
      out = self.cnn(x)
      out = self.mlp(out)
      return out

# %%
numEpochs = 100
in_features = 15 # TODO: change RGB channels according to num of frames
embedding = 512

learningRate = 0.1
weightDecay = 1e-4

num_classes = 120

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_classes)
#network.load_state_dict(torch.load("model_checkpoints/resnet34/lr_0.1-2/model_2.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/regnet_ours_data6/best_model.pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 0	Batch: 50	Avg-Loss: 5.0122	Training Accuracy : 0.0084
# Epoch: 0	Batch: 100	Avg-Loss: 4.5363	Training Accuracy : 0.0175
# Epoch: 0	Batch: 150	Avg-Loss: 3.7711	Training Accuracy : 0.0405
# Epoch: 0	Batch: 200	Avg-Loss: 3.4937	Training Accuracy : 0.0389
# Epoch: 0	Batch: 250	Avg-Loss: 3.4390	Training Accuracy : 0.0380
# Epoch: 0	Batch: 300	Avg-Loss: 3.4041	Training Accuracy : 0.0450
# Epoch: 0	Batch: 350	Avg-Loss: 3.3652	Training Accuracy : 0.0467
# Epoch: 0	Batch: 400	Avg-Loss: 3.3525	Training Accuracy : 0.0486
# Epoch: 0	Batch: 450	Avg-Loss: 3.3336	Training Accuracy : 0.0500
# Epoch: 0	Batch: 500	Avg-Loss: 3.3402	Training Accuracy : 0.0498
# Epoch: 0	Batch: 550	Avg-Loss: 3.3028	Training Accuracy : 0.0586
# Epoch: 0	Batch: 600	Avg-Loss: 3.3142	Training Accuracy : 0.0528
# Epoch: 0	Batch: 650	Avg-Loss: 3.2971	Training Accuracy : 0.0575
# Epoch: 0, Validation Loss: 3.501, Validation Accuracy: 0.053
# Epoch: 1	Batch: 50	Avg-Loss: 3.2626	Training Accuracy : 0.0594
# Epoch: 1	Batch: 100	Avg-Loss: 3.2601	Training Accuracy : 0.0616
# Epoch: 1	Batch: 150	Avg-Loss: 3.2468	Training Accuracy : 0.0672
# Epoch: 1	Batch: 200	Avg-Loss: 3.1989	Training Accuracy : 0.0705
# Epoch: 1	Batch: 250	Avg-Loss: 3.2193	Training Accuracy : 0.0675
# Epoch: 1	Batch: 300	Avg-Loss: 3.1841	Training Accuracy : 0.0750
# Epoch: 1	Batch: 350	Avg-Loss: 3.1431	Training Accuracy : 0.0848
# Epoch: 1	Batch: 400	Avg-Loss: 3.1448	Training Accuracy : 0.0781
# Epoch: 1	Batch: 450	Avg-Loss: 3.1558	Training Accuracy : 0.0798
# Epoch: 1	Batch: 500	Avg-Loss: 3.1306	Training Accuracy : 0.0795
# Epoch: 1	Batch: 550	Avg-Loss: 3.1023	Training Accuracy : 0.0862
# Epoch: 1	Batch: 600	Avg-Loss: 3.1173	Training Accuracy : 0.0906
# Epoch: 1	Batch: 650	Avg-Loss: 3.0754	Training Accuracy : 0.0967
# Epoch: 1, Validation Loss: 3.078, Validation Accuracy: 0.090
# Epoch: 2	Batch: 50	Avg-Loss: 3.0677	Training Accuracy : 0.0852
# Epoch: 2	Batch: 100	Avg-Loss: 3.0420	Training Accuracy : 0.0911
# Epoch: 2	Batch: 150	Avg-Loss: 3.0192	Training Accuracy : 0.1047
# Epoch: 2	Batch: 200	Avg-Loss: 3.1072	Training Accuracy : 0.0961
# Epoch: 2	Batch: 250	Avg-Loss: 3.0648	Training Accuracy : 0.0984
# Epoch: 2	Batch: 300	Avg-Loss: 3.0866	Training Accuracy : 0.0970
# Epoch: 2	Batch: 350	Avg-Loss: 3.0435	Training Accuracy : 0.1037
# Epoch: 2	Batch: 400	Avg-Loss: 2.9972	Training Accuracy : 0.1105
# Epoch: 2	Batch: 450	Avg-Loss: 2.9709	Training Accuracy : 0.1070
# Epoch: 2	Batch: 500	Avg-Loss: 2.9972	Training Accuracy : 0.1022
# Epoch: 2	Batch: 550	Avg-Loss: 2.9698	Training Accuracy : 0.1058
# Epoch: 2	Batch: 600	Avg-Loss: 2.9376	Training Accuracy : 0.1150
# Epoch: 2	Batch: 650	Avg-Loss: 2.9531	Training Accuracy : 0.1170
# Epoch: 2, Validation Loss: 2.980, Validation Accuracy: 0.111
# Epoch: 3	Batch: 50	Avg-Loss: 2.9111	Training Accuracy : 0.1231
# Epoch: 3	Batch: 100	Avg-Loss: 2.8929	Training Accuracy : 0.1258
# Epoch: 3	Batch: 150	Avg-Loss: 2.8978	Training Accuracy : 0.1200
# Epoch: 3	Batch: 200	Avg-Loss: 2.8543	Training Accuracy : 0.1331
# Epoch: 3	Batch: 250	Avg-Loss: 2.8248	Training Accuracy : 0.1378
# Epoch: 3	Batch: 300	Avg-Loss: 2.8056	Training Accuracy : 0.1456
# Epoch: 3	Batch: 350	Avg-Loss: 2.7866	Training Accuracy : 0.1406
# Epoch: 3	Batch: 400	Avg-Loss: 2.7820	Training Accuracy : 0.1491
# Epoch: 3	Batch: 450	Avg-Loss: 2.7661	Training Accuracy : 0.1469
# Epoch: 3	Batch: 500	Avg-Loss: 2.7506	Training Accuracy : 0.1514
# Epoch: 3	Batch: 550	Avg-Loss: 2.7183	Training Accuracy : 0.1542
# Epoch: 3	Batch: 600	Avg-Loss: 2.6962	Training Accuracy : 0.1539
# Epoch: 3	Batch: 650	Avg-Loss: 2.6627	Training Accuracy : 0.1694
# Epoch: 3, Validation Loss: 2.724, Validation Accuracy: 0.157
# Epoch: 4	Batch: 50	Avg-Loss: 2.6633	Training Accuracy : 0.1663
# Epoch: 4	Batch: 100	Avg-Loss: 2.6071	Training Accuracy : 0.1822
# Epoch: 4	Batch: 150	Avg-Loss: 2.5935	Training Accuracy : 0.1817
# Epoch: 4	Batch: 200	Avg-Loss: 2.5797	Training Accuracy : 0.1884
# Epoch: 4	Batch: 250	Avg-Loss: 2.5493	Training Accuracy : 0.1802
# Epoch: 4	Batch: 300	Avg-Loss: 2.5299	Training Accuracy : 0.1902
# Epoch: 4	Batch: 350	Avg-Loss: 2.5157	Training Accuracy : 0.1966
# Epoch: 4	Batch: 400	Avg-Loss: 2.5113	Training Accuracy : 0.1933
# Epoch: 4	Batch: 450	Avg-Loss: 2.5053	Training Accuracy : 0.1991
# Epoch: 4	Batch: 500	Avg-Loss: 2.5451	Training Accuracy : 0.1981
# Epoch: 4	Batch: 550	Avg-Loss: 2.5194	Training Accuracy : 0.2044
# Epoch: 4	Batch: 600	Avg-Loss: 2.4961	Training Accuracy : 0.2033
# Epoch: 4	Batch: 650	Avg-Loss: 2.4426	Training Accuracy : 0.2062
# Epoch: 4, Validation Loss: 2.447, Validation Accuracy: 0.213
# Epoch: 5	Batch: 50	Avg-Loss: 2.4440	Training Accuracy : 0.2122
# Epoch: 5	Batch: 100	Avg-Loss: 2.4272	Training Accuracy : 0.2238
# Epoch: 5	Batch: 150	Avg-Loss: 2.4466	Training Accuracy : 0.2028
# Epoch: 5	Batch: 200	Avg-Loss: 2.4708	Training Accuracy : 0.2087
# Epoch: 5	Batch: 250	Avg-Loss: 2.4822	Training Accuracy : 0.2100
# Epoch: 5	Batch: 300	Avg-Loss: 2.4947	Training Accuracy : 0.2011
# Epoch: 5	Batch: 350	Avg-Loss: 2.4184	Training Accuracy : 0.2195
# Epoch: 5	Batch: 400	Avg-Loss: 2.4573	Training Accuracy : 0.2042
# Epoch: 5	Batch: 450	Avg-Loss: 2.4258	Training Accuracy : 0.2205
# Epoch: 5	Batch: 500	Avg-Loss: 2.4053	Training Accuracy : 0.2105
# Epoch: 5	Batch: 550	Avg-Loss: 2.4293	Training Accuracy : 0.2133
# Epoch: 5	Batch: 600	Avg-Loss: 2.4099	Training Accuracy : 0.2095
# Epoch: 5	Batch: 650	Avg-Loss: 2.4002	Training Accuracy : 0.2234
# Epoch: 5, Validation Loss: 2.440, Validation Accuracy: 0.218
# Epoch: 6	Batch: 50	Avg-Loss: 2.3399	Training Accuracy : 0.2317
# Epoch: 6	Batch: 100	Avg-Loss: 2.3864	Training Accuracy : 0.2205
# Epoch: 6	Batch: 150	Avg-Loss: 2.3794	Training Accuracy : 0.2238
# Epoch: 6	Batch: 200	Avg-Loss: 2.3549	Training Accuracy : 0.2278
# Epoch: 6	Batch: 250	Avg-Loss: 2.3237	Training Accuracy : 0.2344
# Epoch: 6	Batch: 300	Avg-Loss: 2.3742	Training Accuracy : 0.2188
# Epoch: 6	Batch: 350	Avg-Loss: 2.3258	Training Accuracy : 0.2352
# Epoch: 6	Batch: 400	Avg-Loss: 2.3298	Training Accuracy : 0.2353
# Epoch: 6	Batch: 450	Avg-Loss: 2.3211	Training Accuracy : 0.2266
# Epoch: 6	Batch: 500	Avg-Loss: 2.3040	Training Accuracy : 0.2409
# Epoch: 6	Batch: 550	Avg-Loss: 2.3045	Training Accuracy : 0.2408
# Epoch: 6	Batch: 600	Avg-Loss: 2.3017	Training Accuracy : 0.2378
# Epoch: 6	Batch: 650	Avg-Loss: 2.3230	Training Accuracy : 0.2358
# Epoch: 6, Validation Loss: 2.352, Validation Accuracy: 0.234
# Epoch: 7	Batch: 50	Avg-Loss: 2.3247	Training Accuracy : 0.2358
# Epoch: 7	Batch: 100	Avg-Loss: 2.2667	Training Accuracy : 0.2394
# Epoch: 7	Batch: 150	Avg-Loss: 2.2784	Training Accuracy : 0.2397
# Epoch: 7	Batch: 200	Avg-Loss: 2.2988	Training Accuracy : 0.2411
# Epoch: 7	Batch: 250	Avg-Loss: 2.3040	Training Accuracy : 0.2313
# Epoch: 7	Batch: 300	Avg-Loss: 2.2984	Training Accuracy : 0.2348
# Epoch: 7	Batch: 350	Avg-Loss: 2.2910	Training Accuracy : 0.2369
# Epoch: 7	Batch: 400	Avg-Loss: 2.2384	Training Accuracy : 0.2475
# Epoch: 7	Batch: 450	Avg-Loss: 2.2784	Training Accuracy : 0.2439
# Epoch: 7	Batch: 500	Avg-Loss: 2.2496	Training Accuracy : 0.2544
# Epoch: 7	Batch: 550	Avg-Loss: 2.2672	Training Accuracy : 0.2470
# Epoch: 7	Batch: 600	Avg-Loss: 2.2397	Training Accuracy : 0.2572
# Epoch: 7	Batch: 650	Avg-Loss: 2.2636	Training Accuracy : 0.2486
# Epoch: 7, Validation Loss: 2.658, Validation Accuracy: 0.202
# Epoch: 8	Batch: 50	Avg-Loss: 2.2204	Training Accuracy : 0.2537
# Epoch: 8	Batch: 100	Avg-Loss: 2.2303	Training Accuracy : 0.2464
# Epoch: 8	Batch: 150	Avg-Loss: 2.2160	Training Accuracy : 0.2470
# Epoch: 8	Batch: 200	Avg-Loss: 2.2336	Training Accuracy : 0.2520
# Epoch: 8	Batch: 250	Avg-Loss: 2.2521	Training Accuracy : 0.2425
# Epoch: 8	Batch: 300	Avg-Loss: 2.2841	Training Accuracy : 0.2342
# Epoch: 8	Batch: 350	Avg-Loss: 2.2308	Training Accuracy : 0.2466
# Epoch: 8	Batch: 400	Avg-Loss: 2.4128	Training Accuracy : 0.2191
# Epoch: 8	Batch: 450	Avg-Loss: 2.4568	Training Accuracy : 0.2078
# Epoch: 8	Batch: 500	Avg-Loss: 2.3749	Training Accuracy : 0.2233
# Epoch: 8	Batch: 550	Avg-Loss: 2.3137	Training Accuracy : 0.2322
# Epoch: 8	Batch: 600	Avg-Loss: 2.3040	Training Accuracy : 0.2281
# Epoch: 8	Batch: 650	Avg-Loss: 2.3019	Training Accuracy : 0.2373
# Epoch: 8, Validation Loss: 2.560, Validation Accuracy: 0.211
# Epoch: 9	Batch: 50	Avg-Loss: 2.2720	Training Accuracy : 0.2380
# Epoch: 9	Batch: 100	Avg-Loss: 2.2310	Training Accuracy : 0.2473
# Epoch: 9	Batch: 150	Avg-Loss: 2.2270	Training Accuracy : 0.2492
# Epoch: 9	Batch: 200	Avg-Loss: 2.2315	Training Accuracy : 0.2442
# Epoch: 9	Batch: 250	Avg-Loss: 2.2669	Training Accuracy : 0.2436
# Epoch: 9	Batch: 300	Avg-Loss: 2.2434	Training Accuracy : 0.2500
# Epoch: 9	Batch: 350	Avg-Loss: 2.2084	Training Accuracy : 0.2592
# Epoch: 9	Batch: 400	Avg-Loss: 2.2146	Training Accuracy : 0.2491
# Epoch: 9	Batch: 450	Avg-Loss: 2.2817	Training Accuracy : 0.2431
# Epoch: 9	Batch: 500	Avg-Loss: 2.2497	Training Accuracy : 0.2417
# Epoch: 9	Batch: 550	Avg-Loss: 2.2362	Training Accuracy : 0.2550
# Epoch: 9	Batch: 600	Avg-Loss: 2.2675	Training Accuracy : 0.2425
# Epoch: 9	Batch: 650	Avg-Loss: 2.2037	Training Accuracy : 0.2564
# Epoch: 9, Validation Loss: 2.291, Validation Accuracy: 0.246
# Epoch: 10	Batch: 50	Avg-Loss: 2.1986	Training Accuracy : 0.2603
# Epoch: 10	Batch: 100	Avg-Loss: 2.2062	Training Accuracy : 0.2572
# Epoch: 10	Batch: 150	Avg-Loss: 2.1296	Training Accuracy : 0.2656
# Epoch: 10	Batch: 200	Avg-Loss: 2.1982	Training Accuracy : 0.2548
# Epoch: 10	Batch: 250	Avg-Loss: 2.1917	Training Accuracy : 0.2497
# Epoch: 10	Batch: 300	Avg-Loss: 2.2004	Training Accuracy : 0.2505
# Epoch: 10	Batch: 350	Avg-Loss: 2.1820	Training Accuracy : 0.2539
# Epoch: 10	Batch: 400	Avg-Loss: 2.1791	Training Accuracy : 0.2648
# Epoch: 10	Batch: 450	Avg-Loss: 2.1818	Training Accuracy : 0.2577
# Epoch: 10	Batch: 500	Avg-Loss: 2.1676	Training Accuracy : 0.2559
# Epoch: 10	Batch: 550	Avg-Loss: 2.2023	Training Accuracy : 0.2528
# Epoch: 10	Batch: 600	Avg-Loss: 2.1492	Training Accuracy : 0.2630
# Epoch: 10	Batch: 650	Avg-Loss: 2.1722	Training Accuracy : 0.2587
# Epoch: 10, Validation Loss: 2.581, Validation Accuracy: 0.214
# Epoch: 11	Batch: 50	Avg-Loss: 2.1816	Training Accuracy : 0.2555
# Epoch: 11	Batch: 100	Avg-Loss: 2.1747	Training Accuracy : 0.2623
# Epoch: 11	Batch: 150	Avg-Loss: 2.1495	Training Accuracy : 0.2652
# Epoch: 11	Batch: 200	Avg-Loss: 2.1751	Training Accuracy : 0.2548
# Epoch: 11	Batch: 250	Avg-Loss: 2.1248	Training Accuracy : 0.2725
# Epoch: 11	Batch: 300	Avg-Loss: 2.1540	Training Accuracy : 0.2683
# Epoch: 11	Batch: 350	Avg-Loss: 2.1291	Training Accuracy : 0.2630
# Epoch: 11	Batch: 400	Avg-Loss: 2.1402	Training Accuracy : 0.2719
# Epoch: 11	Batch: 450	Avg-Loss: 2.1077	Training Accuracy : 0.2750
# Epoch: 11	Batch: 500	Avg-Loss: 2.1266	Training Accuracy : 0.2698
# Epoch: 11	Batch: 550	Avg-Loss: 2.1081	Training Accuracy : 0.2794
# Epoch: 11	Batch: 600	Avg-Loss: 2.1540	Training Accuracy : 0.2695
# Epoch: 11	Batch: 650	Avg-Loss: 2.1322	Training Accuracy : 0.2662
# Epoch: 11, Validation Loss: 2.389, Validation Accuracy: 0.249
# Epoch: 12	Batch: 50	Avg-Loss: 2.1329	Training Accuracy : 0.2653
# Epoch: 12	Batch: 100	Avg-Loss: 2.1016	Training Accuracy : 0.2720
# Epoch: 12	Batch: 150	Avg-Loss: 2.0682	Training Accuracy : 0.2802
# Epoch: 12	Batch: 200	Avg-Loss: 2.1280	Training Accuracy : 0.2652
# Epoch: 12	Batch: 250	Avg-Loss: 2.1060	Training Accuracy : 0.2641
# Epoch: 12	Batch: 300	Avg-Loss: 2.1030	Training Accuracy : 0.2725
# Epoch: 12	Batch: 350	Avg-Loss: 2.0763	Training Accuracy : 0.2830
# Epoch: 12	Batch: 400	Avg-Loss: 2.1002	Training Accuracy : 0.2678
# Epoch: 12	Batch: 450	Avg-Loss: 2.1042	Training Accuracy : 0.2698
# Epoch: 12	Batch: 500	Avg-Loss: 2.0804	Training Accuracy : 0.2808
# Epoch: 12	Batch: 550	Avg-Loss: 2.0598	Training Accuracy : 0.2784
# Epoch: 12	Batch: 600	Avg-Loss: 2.0920	Training Accuracy : 0.2686
# Epoch: 12	Batch: 650	Avg-Loss: 2.1092	Training Accuracy : 0.2752
# Epoch: 12, Validation Loss: 2.269, Validation Accuracy: 0.255
# Epoch: 13	Batch: 50	Avg-Loss: 2.0863	Training Accuracy : 0.2752
# Epoch: 13	Batch: 100	Avg-Loss: 2.0429	Training Accuracy : 0.2884
# Epoch: 13	Batch: 150	Avg-Loss: 2.0658	Training Accuracy : 0.2863
# Epoch: 13	Batch: 200	Avg-Loss: 2.0435	Training Accuracy : 0.2881
# Epoch: 13	Batch: 250	Avg-Loss: 2.0672	Training Accuracy : 0.2816
# Epoch: 13	Batch: 300	Avg-Loss: 2.0657	Training Accuracy : 0.2759
# Epoch: 13	Batch: 350	Avg-Loss: 2.0913	Training Accuracy : 0.2656
# Epoch: 13	Batch: 400	Avg-Loss: 2.0332	Training Accuracy : 0.2822
# Epoch: 13	Batch: 450	Avg-Loss: 2.0681	Training Accuracy : 0.2711
# Epoch: 13	Batch: 500	Avg-Loss: 2.0581	Training Accuracy : 0.2734
# Epoch: 13	Batch: 550	Avg-Loss: 2.0782	Training Accuracy : 0.2742
# Epoch: 13	Batch: 600	Avg-Loss: 2.0685	Training Accuracy : 0.2719
# Epoch: 13	Batch: 650	Avg-Loss: 2.0576	Training Accuracy : 0.2797
# Epoch: 13, Validation Loss: 2.231, Validation Accuracy: 0.265
# Epoch: 14	Batch: 50	Avg-Loss: 1.9764	Training Accuracy : 0.2841
# Epoch: 14	Batch: 100	Avg-Loss: 2.0161	Training Accuracy : 0.2922
# Epoch: 14	Batch: 150	Avg-Loss: 2.0230	Training Accuracy : 0.2886
# Epoch: 14	Batch: 200	Avg-Loss: 1.9994	Training Accuracy : 0.2917
# Epoch: 14	Batch: 250	Avg-Loss: 2.0327	Training Accuracy : 0.2769
# Epoch: 14	Batch: 300	Avg-Loss: 2.0109	Training Accuracy : 0.2952
# Epoch: 14	Batch: 350	Avg-Loss: 1.9983	Training Accuracy : 0.2911
# Epoch: 14	Batch: 400	Avg-Loss: 2.0535	Training Accuracy : 0.2731
# Epoch: 14	Batch: 450	Avg-Loss: 2.0327	Training Accuracy : 0.2881
# Epoch: 14	Batch: 500	Avg-Loss: 2.0201	Training Accuracy : 0.2870
# Epoch: 14	Batch: 550	Avg-Loss: 2.0062	Training Accuracy : 0.2838
# Epoch: 14	Batch: 600	Avg-Loss: 2.0083	Training Accuracy : 0.2858
# Epoch: 14	Batch: 650	Avg-Loss: 2.0295	Training Accuracy : 0.2845
# Epoch: 14, Validation Loss: 2.221, Validation Accuracy: 0.260
# Epoch: 15	Batch: 50	Avg-Loss: 1.9797	Training Accuracy : 0.2847
# Epoch: 15	Batch: 100	Avg-Loss: 1.9719	Training Accuracy : 0.2903
# Epoch: 15	Batch: 150	Avg-Loss: 1.9818	Training Accuracy : 0.2928
# Epoch: 15	Batch: 200	Avg-Loss: 1.9806	Training Accuracy : 0.2892
# Epoch: 15	Batch: 250	Avg-Loss: 1.9393	Training Accuracy : 0.3030
# Epoch: 15	Batch: 300	Avg-Loss: 1.9473	Training Accuracy : 0.3011
# Epoch: 15	Batch: 350	Avg-Loss: 1.9634	Training Accuracy : 0.2908
# Epoch: 15	Batch: 400	Avg-Loss: 1.9410	Training Accuracy : 0.2998
# Epoch: 15	Batch: 450	Avg-Loss: 1.9289	Training Accuracy : 0.2967
# Epoch: 15	Batch: 500	Avg-Loss: 1.9479	Training Accuracy : 0.2969
# Epoch: 15	Batch: 550	Avg-Loss: 1.9308	Training Accuracy : 0.2930
# Epoch: 15	Batch: 600	Avg-Loss: 1.9996	Training Accuracy : 0.2855
# Epoch: 15	Batch: 650	Avg-Loss: 1.9317	Training Accuracy : 0.2963
# Epoch: 15, Validation Loss: 2.536, Validation Accuracy: 0.229
# Epoch: 16	Batch: 50	Avg-Loss: 1.8976	Training Accuracy : 0.3131
# Epoch: 16	Batch: 100	Avg-Loss: 1.8854	Training Accuracy : 0.3044
# Epoch: 16	Batch: 150	Avg-Loss: 1.8941	Training Accuracy : 0.3061
# Epoch: 16	Batch: 200	Avg-Loss: 1.9034	Training Accuracy : 0.2952
# Epoch: 16	Batch: 250	Avg-Loss: 1.9059	Training Accuracy : 0.2986
# Epoch: 16	Batch: 300	Avg-Loss: 1.9239	Training Accuracy : 0.2948
# Epoch: 16	Batch: 350	Avg-Loss: 1.8966	Training Accuracy : 0.2961
# Epoch: 16	Batch: 400	Avg-Loss: 1.9176	Training Accuracy : 0.3030
# Epoch: 16	Batch: 450	Avg-Loss: 1.9169	Training Accuracy : 0.2945
# Epoch: 16	Batch: 500	Avg-Loss: 1.8924	Training Accuracy : 0.2961
# Epoch: 16	Batch: 550	Avg-Loss: 1.9275	Training Accuracy : 0.2967
# Epoch: 16	Batch: 600	Avg-Loss: 1.9012	Training Accuracy : 0.2983
# Epoch: 16	Batch: 650	Avg-Loss: 1.8806	Training Accuracy : 0.3083
# Epoch: 16, Validation Loss: 2.321, Validation Accuracy: 0.254
# Epoch: 17	Batch: 50	Avg-Loss: 1.8565	Training Accuracy : 0.3148
# Epoch: 17	Batch: 100	Avg-Loss: 1.8576	Training Accuracy : 0.3127
# Epoch: 17	Batch: 150	Avg-Loss: 1.8653	Training Accuracy : 0.3102
# Epoch: 17	Batch: 200	Avg-Loss: 1.8733	Training Accuracy : 0.2947
# Epoch: 17	Batch: 250	Avg-Loss: 1.8692	Training Accuracy : 0.3081
# Epoch: 17	Batch: 300	Avg-Loss: 1.8583	Training Accuracy : 0.3155
# Epoch: 17	Batch: 350	Avg-Loss: 1.8416	Training Accuracy : 0.3164
# Epoch: 17	Batch: 400	Avg-Loss: 1.8473	Training Accuracy : 0.3120
# Epoch: 17	Batch: 450	Avg-Loss: 1.8358	Training Accuracy : 0.3141
# Epoch: 17	Batch: 500	Avg-Loss: 1.8555	Training Accuracy : 0.3066
# Epoch: 17	Batch: 550	Avg-Loss: 1.8533	Training Accuracy : 0.3166
# Epoch: 17	Batch: 600	Avg-Loss: 1.8488	Training Accuracy : 0.3081
# Epoch: 17	Batch: 650	Avg-Loss: 1.8134	Training Accuracy : 0.3173
# Epoch    18: reducing learning rate of group 0 to 5.0000e-02.
# Epoch: 17, Validation Loss: 2.318, Validation Accuracy: 0.271
# Epoch: 18	Batch: 50	Avg-Loss: 1.6854	Training Accuracy : 0.3441
# Epoch: 18	Batch: 100	Avg-Loss: 1.6385	Training Accuracy : 0.3522
# Epoch: 18	Batch: 150	Avg-Loss: 1.5967	Training Accuracy : 0.3681
# Epoch: 18	Batch: 200	Avg-Loss: 1.5814	Training Accuracy : 0.3714
# Epoch: 18	Batch: 250	Avg-Loss: 1.6002	Training Accuracy : 0.3681
# Epoch: 18	Batch: 300	Avg-Loss: 1.6274	Training Accuracy : 0.3597
# Epoch: 18	Batch: 350	Avg-Loss: 1.6098	Training Accuracy : 0.3623
# Epoch: 18	Batch: 400	Avg-Loss: 1.5956	Training Accuracy : 0.3689
# Epoch: 18	Batch: 450	Avg-Loss: 1.5850	Training Accuracy : 0.3642
# Epoch: 18	Batch: 500	Avg-Loss: 1.6119	Training Accuracy : 0.3486
# Epoch: 18	Batch: 550	Avg-Loss: 1.5816	Training Accuracy : 0.3741
# Epoch: 18	Batch: 600	Avg-Loss: 1.5687	Training Accuracy : 0.3663
# Epoch: 18	Batch: 650	Avg-Loss: 1.5967	Training Accuracy : 0.3697
# Epoch: 18, Validation Loss: 2.365, Validation Accuracy: 0.271
# Epoch: 19	Batch: 50	Avg-Loss: 1.5226	Training Accuracy : 0.3906
# Epoch: 19	Batch: 100	Avg-Loss: 1.5154	Training Accuracy : 0.3839
# Epoch: 19	Batch: 150	Avg-Loss: 1.5618	Training Accuracy : 0.3775
# Epoch: 19	Batch: 200	Avg-Loss: 1.5242	Training Accuracy : 0.3811
# Epoch: 19	Batch: 250	Avg-Loss: 1.5409	Training Accuracy : 0.3855
# Epoch: 19	Batch: 300	Avg-Loss: 1.5639	Training Accuracy : 0.3908
# Epoch: 19	Batch: 350	Avg-Loss: 1.5052	Training Accuracy : 0.3991
# Epoch: 19	Batch: 400	Avg-Loss: 1.5275	Training Accuracy : 0.3866
# Epoch: 19	Batch: 450	Avg-Loss: 1.4970	Training Accuracy : 0.3983
# Epoch: 19	Batch: 500	Avg-Loss: 1.5840	Training Accuracy : 0.3859
# Epoch: 19	Batch: 550	Avg-Loss: 1.5316	Training Accuracy : 0.3869
# Epoch: 19	Batch: 600	Avg-Loss: 1.5327	Training Accuracy : 0.3983
# Epoch: 19	Batch: 650	Avg-Loss: 1.5263	Training Accuracy : 0.3916
# Epoch: 19, Validation Loss: 2.431, Validation Accuracy: 0.271
# Epoch: 20	Batch: 50	Avg-Loss: 1.4776	Training Accuracy : 0.4128
# Epoch: 20	Batch: 100	Avg-Loss: 1.4669	Training Accuracy : 0.4195
# Epoch: 20	Batch: 150	Avg-Loss: 1.4444	Training Accuracy : 0.4255
# Epoch: 20	Batch: 200	Avg-Loss: 1.4591	Training Accuracy : 0.4300
# Epoch: 20	Batch: 250	Avg-Loss: 1.4986	Training Accuracy : 0.4092
# Epoch: 20	Batch: 300	Avg-Loss: 1.4516	Training Accuracy : 0.4197
# Epoch: 20	Batch: 350	Avg-Loss: 1.4524	Training Accuracy : 0.4295
# Epoch: 20	Batch: 400	Avg-Loss: 1.4336	Training Accuracy : 0.4387
# Epoch: 20	Batch: 450	Avg-Loss: 1.4795	Training Accuracy : 0.4364
# Epoch: 20	Batch: 500	Avg-Loss: 1.4820	Training Accuracy : 0.4342
# Epoch: 20	Batch: 550	Avg-Loss: 1.4757	Training Accuracy : 0.4336
# Epoch: 20	Batch: 600	Avg-Loss: 1.4490	Training Accuracy : 0.4577
# Epoch: 20	Batch: 650	Avg-Loss: 1.4593	Training Accuracy : 0.4580
# Epoch    21: reducing learning rate of group 0 to 2.5000e-02.
# Epoch: 20, Validation Loss: 2.461, Validation Accuracy: 0.280
# Epoch: 21	Batch: 50	Avg-Loss: 1.2791	Training Accuracy : 0.5100
# Epoch: 21	Batch: 100	Avg-Loss: 1.2106	Training Accuracy : 0.5384
# Epoch: 21	Batch: 150	Avg-Loss: 1.1876	Training Accuracy : 0.5483
# Epoch: 21	Batch: 200	Avg-Loss: 1.1994	Training Accuracy : 0.5559
# Epoch: 21	Batch: 250	Avg-Loss: 1.1972	Training Accuracy : 0.5542
# Epoch: 21	Batch: 300	Avg-Loss: 1.1675	Training Accuracy : 0.5713
# Epoch: 21	Batch: 350	Avg-Loss: 1.1683	Training Accuracy : 0.5769
# Epoch: 21	Batch: 400	Avg-Loss: 1.1703	Training Accuracy : 0.5731
# Epoch: 21	Batch: 450	Avg-Loss: 1.1524	Training Accuracy : 0.5800
# Epoch: 21	Batch: 500	Avg-Loss: 1.1426	Training Accuracy : 0.5813
# Epoch: 21	Batch: 550	Avg-Loss: 1.1524	Training Accuracy : 0.5861
# Epoch: 21	Batch: 600	Avg-Loss: 1.1398	Training Accuracy : 0.6002
# Epoch: 21	Batch: 650	Avg-Loss: 1.1418	Training Accuracy : 0.6036
# Epoch: 21, Validation Loss: 2.838, Validation Accuracy: 0.275
# Epoch: 22	Batch: 50	Avg-Loss: 0.9982	Training Accuracy : 0.6553
# Epoch: 22	Batch: 100	Avg-Loss: 1.0318	Training Accuracy : 0.6433
# Epoch: 22	Batch: 150	Avg-Loss: 1.0472	Training Accuracy : 0.6394
# Epoch: 22	Batch: 200	Avg-Loss: 1.0093	Training Accuracy : 0.6473
# Epoch: 22	Batch: 250	Avg-Loss: 1.0494	Training Accuracy : 0.6420
# Epoch: 22	Batch: 300	Avg-Loss: 1.0209	Training Accuracy : 0.6462
# Epoch: 22	Batch: 350	Avg-Loss: 1.0074	Training Accuracy : 0.6528
# Epoch: 22	Batch: 400	Avg-Loss: 1.0104	Training Accuracy : 0.6550
# Epoch: 22	Batch: 450	Avg-Loss: 0.9925	Training Accuracy : 0.6538
# Epoch: 22	Batch: 500	Avg-Loss: 1.0192	Training Accuracy : 0.6620
# Epoch: 22	Batch: 550	Avg-Loss: 1.0168	Training Accuracy : 0.6559
# Epoch: 22	Batch: 600	Avg-Loss: 0.9936	Training Accuracy : 0.6569
# Epoch: 22	Batch: 650	Avg-Loss: 0.9759	Training Accuracy : 0.6664
# Epoch: 22, Validation Loss: 2.992, Validation Accuracy: 0.277
# Epoch: 23	Batch: 50	Avg-Loss: 0.9013	Training Accuracy : 0.6942
# Epoch: 23	Batch: 100	Avg-Loss: 0.8756	Training Accuracy : 0.7069
# Epoch: 23	Batch: 150	Avg-Loss: 0.9031	Training Accuracy : 0.6972
# Epoch: 23	Batch: 200	Avg-Loss: 0.9286	Training Accuracy : 0.6892
# Epoch: 23	Batch: 250	Avg-Loss: 0.9040	Training Accuracy : 0.6875
# Epoch: 23	Batch: 300	Avg-Loss: 0.9168	Training Accuracy : 0.6820
# Epoch: 23	Batch: 350	Avg-Loss: 0.8809	Training Accuracy : 0.7009
# Epoch: 23	Batch: 400	Avg-Loss: 0.8732	Training Accuracy : 0.7041
# Epoch: 23	Batch: 450	Avg-Loss: 0.8730	Training Accuracy : 0.7064
# Epoch: 23	Batch: 500	Avg-Loss: 0.8809	Training Accuracy : 0.6978
# Epoch: 23	Batch: 550	Avg-Loss: 0.9021	Training Accuracy : 0.7048
# Epoch: 23	Batch: 600	Avg-Loss: 0.8920	Training Accuracy : 0.6931
# Epoch: 23	Batch: 650	Avg-Loss: 0.8718	Training Accuracy : 0.7048
# Epoch    24: reducing learning rate of group 0 to 1.2500e-02.
# Epoch: 23, Validation Loss: 3.170, Validation Accuracy: 0.281
# Epoch: 24	Batch: 50	Avg-Loss: 0.7144	Training Accuracy : 0.7614
# Epoch: 24	Batch: 100	Avg-Loss: 0.6702	Training Accuracy : 0.7759
# Epoch: 24	Batch: 150	Avg-Loss: 0.6529	Training Accuracy : 0.7850
# Epoch: 24	Batch: 200	Avg-Loss: 0.6132	Training Accuracy : 0.7958
# Epoch: 24	Batch: 250	Avg-Loss: 0.6358	Training Accuracy : 0.7836
# Epoch: 24	Batch: 300	Avg-Loss: 0.6318	Training Accuracy : 0.7869
# Epoch: 24	Batch: 350	Avg-Loss: 0.6277	Training Accuracy : 0.7886
# Epoch: 24	Batch: 400	Avg-Loss: 0.6147	Training Accuracy : 0.7923
# Epoch: 24	Batch: 450	Avg-Loss: 0.6315	Training Accuracy : 0.7923
# Epoch: 24	Batch: 500	Avg-Loss: 0.6391	Training Accuracy : 0.7859
# Epoch: 24	Batch: 550	Avg-Loss: 0.6466	Training Accuracy : 0.7828
# Epoch: 24	Batch: 600	Avg-Loss: 0.6368	Training Accuracy : 0.7847
# Epoch: 24	Batch: 650	Avg-Loss: 0.6349	Training Accuracy : 0.7850
# Epoch: 24, Validation Loss: 3.538, Validation Accuracy: 0.280
# Epoch: 25	Batch: 50	Avg-Loss: 0.5356	Training Accuracy : 0.8203
# Epoch: 25	Batch: 100	Avg-Loss: 0.5497	Training Accuracy : 0.8166
# Epoch: 25	Batch: 150	Avg-Loss: 0.5588	Training Accuracy : 0.8127
# Epoch: 25	Batch: 200	Avg-Loss: 0.5480	Training Accuracy : 0.8147
# Epoch: 25	Batch: 250	Avg-Loss: 0.5419	Training Accuracy : 0.8173
# Epoch: 25	Batch: 300	Avg-Loss: 0.5510	Training Accuracy : 0.8137
# Epoch: 25	Batch: 350	Avg-Loss: 0.5365	Training Accuracy : 0.8208
# Epoch: 25	Batch: 400	Avg-Loss: 0.5322	Training Accuracy : 0.8178
# Epoch: 25	Batch: 450	Avg-Loss: 0.5418	Training Accuracy : 0.8158
# Epoch: 25	Batch: 500	Avg-Loss: 0.5671	Training Accuracy : 0.8109
# Epoch: 25	Batch: 550	Avg-Loss: 0.5601	Training Accuracy : 0.8081
# Epoch: 25	Batch: 600	Avg-Loss: 0.5777	Training Accuracy : 0.8086
# Epoch: 25	Batch: 650	Avg-Loss: 0.5670	Training Accuracy : 0.8073
# Epoch: 25, Validation Loss: 3.726, Validation Accuracy: 0.282
# Epoch: 26	Batch: 50	Avg-Loss: 0.5023	Training Accuracy : 0.8358
# Epoch: 26	Batch: 100	Avg-Loss: 0.4803	Training Accuracy : 0.8397
# Epoch: 26	Batch: 150	Avg-Loss: 0.4967	Training Accuracy : 0.8314
# Epoch: 26	Batch: 200	Avg-Loss: 0.4797	Training Accuracy : 0.8358
# Epoch: 26	Batch: 250	Avg-Loss: 0.4894	Training Accuracy : 0.8341
# Epoch: 26	Batch: 300	Avg-Loss: 0.5219	Training Accuracy : 0.8242
# Epoch: 26	Batch: 350	Avg-Loss: 0.5055	Training Accuracy : 0.8313
# Epoch: 26	Batch: 400	Avg-Loss: 0.5347	Training Accuracy : 0.8172
# Epoch: 26	Batch: 450	Avg-Loss: 0.5047	Training Accuracy : 0.8253
# Epoch: 26	Batch: 500	Avg-Loss: 0.5099	Training Accuracy : 0.8209
# Epoch: 26	Batch: 550	Avg-Loss: 0.4991	Training Accuracy : 0.8325
# Epoch: 26	Batch: 600	Avg-Loss: 0.5366	Training Accuracy : 0.8184
# Epoch: 26	Batch: 650	Avg-Loss: 0.5205	Training Accuracy : 0.8239
# Epoch    27: reducing learning rate of group 0 to 6.2500e-03.
# Epoch: 26, Validation Loss: 4.074, Validation Accuracy: 0.276
# Epoch: 27	Batch: 50	Avg-Loss: 0.4289	Training Accuracy : 0.8562
# Epoch: 27	Batch: 100	Avg-Loss: 0.4016	Training Accuracy : 0.8625
# Epoch: 27	Batch: 150	Avg-Loss: 0.3970	Training Accuracy : 0.8700
# Epoch: 27	Batch: 200	Avg-Loss: 0.3913	Training Accuracy : 0.8680
# Epoch: 27	Batch: 250	Avg-Loss: 0.3693	Training Accuracy : 0.8809
# Epoch: 27	Batch: 300	Avg-Loss: 0.3768	Training Accuracy : 0.8772
# Epoch: 27	Batch: 350	Avg-Loss: 0.3931	Training Accuracy : 0.8672
# Epoch: 27	Batch: 400	Avg-Loss: 0.3762	Training Accuracy : 0.8748
# Epoch: 27	Batch: 450	Avg-Loss: 0.3759	Training Accuracy : 0.8742
# Epoch: 27	Batch: 500	Avg-Loss: 0.3857	Training Accuracy : 0.8712
# Epoch: 27	Batch: 550	Avg-Loss: 0.3852	Training Accuracy : 0.8741
# Epoch: 27	Batch: 600	Avg-Loss: 0.3985	Training Accuracy : 0.8667
# Epoch: 27	Batch: 650	Avg-Loss: 0.3718	Training Accuracy : 0.8745
# Epoch: 27, Validation Loss: 4.166, Validation Accuracy: 0.282
# Epoch: 28	Batch: 50	Avg-Loss: 0.3418	Training Accuracy : 0.8864
# Epoch: 28	Batch: 100	Avg-Loss: 0.3271	Training Accuracy : 0.8922
# Epoch: 28	Batch: 150	Avg-Loss: 0.3277	Training Accuracy : 0.8936
# Epoch: 28	Batch: 200	Avg-Loss: 0.3261	Training Accuracy : 0.8945
# Epoch: 28	Batch: 250	Avg-Loss: 0.3303	Training Accuracy : 0.8934
# Epoch: 28	Batch: 300	Avg-Loss: 0.3371	Training Accuracy : 0.8869
# Epoch: 28	Batch: 350	Avg-Loss: 0.3281	Training Accuracy : 0.8903

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/regnet_ours_data6/best_model.pt"))
network = network.to(device)

# %%
network.eval()
num_correct = 0
for x, y in tqdm(test_loader):
  x, y = x.to(device), y.to(device)
  outputs = network(x)
  num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

test_acc = num_correct / len(test_set)
print(test_acc)
# Out:
# 100%|██████████| 141/141 [03:17<00:00,  1.40s/it]
# 0.2501253691424751
