# %% [markdown]
# ## 1. Libraries and Setup

# %%
from google.colab import drive
import json
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp /content/gdrive/MyDrive/dl_project/converted_224x224.tar.gz /content
# %cd /content
# !tar -xzf converted_224x224.tar.gz
# Out:
# /content

# %%
import os
import sys
import time

import numpy as np
import pandas as pd

import pdb
import gc
from tqdm.notebook import trange, tqdm
from PIL import Image

import torch
import torchvision 
from torchvision import transforms
import torch.nn as nn

from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
# from torchinfo import summary

import warnings
warnings.filterwarnings('ignore')

# %%
cuda = torch.cuda.is_available()
device = torch.device("cuda" if cuda else "cpu")

num_workers = 8 if cuda else 0

print("Cuda = ", str(cuda), " with num_workers = ", str(num_workers),  " system version = ", sys.version)
# Out:
# Cuda =  True  with num_workers =  8  system version =  3.7.12 (default, Sep 10 2021, 00:21:48)
# [GCC 7.5.0]

# %% [markdown]
# ## 2. Data Loading

# %% [markdown]
# ### 2.1 Load Data

# %%
np.random.seed(0)
df = pd.read_csv("4+1.csv")
df = df.iloc[:, 1:]

train_end = int(len(df)*0.7)
val_end = int(len(df)*0.85)
train_data = df[:train_end]
val_data = df[train_end:val_end]
test_data = df[val_end:]

# %%
train_data = train_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
val_data = val_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)
test_data = test_data.reset_index().drop('Unnamed: 0.1',1).drop('index',1)

# %%
test_data
# Out:
#                                                   frames  label
# 0      ('frame_149670.jpg', 'frame_149739.jpg', 'fram...     16
# 1      ('frame_149738.jpg', 'frame_149692.jpg', 'fram...     80
# 2      ('frame_149729.jpg', 'frame_149716.jpg', 'fram...     86
# 3      ('frame_149669.jpg', 'frame_149712.jpg', 'fram...      7
# 4      ('frame_149683.jpg', 'frame_149707.jpg', 'fram...     34
# ...                                                  ...    ...
# 17942  ('frame_180809.jpg', 'frame_174579.jpg', 'fram...    101
# 17943  ('frame_174581.jpg', 'frame_174634.jpg', 'fram...     14
# 17944  ('frame_174605.jpg', 'frame_174596.jpg', 'fram...     54
# 17945  ('frame_181123.jpg', 'frame_174585.jpg', 'fram...     96
# 17946  ('frame_181333.jpg', 'frame_174579.jpg', 'fram...     97
#
# [17947 rows x 2 columns]

# %% [markdown]
# ### 2.2 Custom Dataset Class

# %%
# cur_dir = "data/qscale31_unique/"
cur_dir = "/content/converted_224x224/"

# %%
# Define dataset class
class MyDataSet(Dataset):

    # load the dataset
    def __init__(self, data, **kwargs):
        self.X = data["frames"]
        self.Y = data["label"]

    # get number of items/rows in dataset
    def __len__(self):
        return len(self.Y)
    
    def __getitem__(self, index):
        x, y = self.X[index], self.Y[index]
        for c in ["(",")",",","'"]:
            x = x.replace(c, "")
        x = x.split(" ")
        images = []
        for img_file in x:
            img = Image.open(cur_dir + img_file)
            img = torchvision.transforms.ToTensor()(img)
            images.extend(img)
        x = torch.stack(images)
        return x, y

# %%
train_set = MyDataSet(train_data)
train_set[0][0].shape
# Out:
# torch.Size([15, 224, 224])

# %% [markdown]
# ### 2.3 Dataloader

# %%
batch_size = 128

# training data
train_set = MyDataSet(train_data)
train_loader = DataLoader(train_set, shuffle=True, batch_size=batch_size, num_workers=8)

# validation data
val_set = MyDataSet(val_data)
val_loader = DataLoader(val_set, shuffle=False, batch_size=batch_size, num_workers=8)

# test data
test_set = MyDataSet(test_data)
test_loader = DataLoader(test_set, shuffle=False, batch_size=batch_size, num_workers=8)

# %% [markdown]
# # Model

# %%
# Code based on https://pytorch.org/vision/stable/_modules/torchvision/models/regnet.html

import math
import torch

from collections import OrderedDict
from functools import partial
from typing import Any, Callable, List, Optional, Tuple
from torch import nn, Tensor

__all__ = ["RegNet", "regnet_y_400mf", "regnet_y_800mf", "regnet_y_1_6gf",
           "regnet_y_3_2gf", "regnet_y_8gf", "regnet_y_16gf", "regnet_y_32gf",
           "regnet_x_400mf", "regnet_x_800mf", "regnet_x_1_6gf", "regnet_x_3_2gf",
           "regnet_x_8gf", "regnet_x_16gf", "regnet_x_32gf"]

class ConvNormActivation(torch.nn.Sequential):
    """
    Configurable block used for Convolution-Normalzation-Activation blocks.
    Args:
        in_channels (int): Number of channels in the input image
        out_channels (int): Number of channels produced by the Convolution-Normalzation-Activation block
        kernel_size: (int, optional): Size of the convolving kernel. Default: 3
        stride (int, optional): Stride of the convolution. Default: 1
        padding (int, tuple or str, optional): Padding added to all four sides of the input. Default: None, in wich case it will calculated as ``padding = (kernel_size - 1) // 2 * dilation``
        groups (int, optional): Number of blocked connections from input channels to output channels. Default: 1
        norm_layer (Callable[..., torch.nn.Module], optional): Norm layer that will be stacked on top of the convolutiuon layer. If ``None`` this layer wont be used. Default: ``torch.nn.BatchNorm2d``
        activation_layer (Callable[..., torch.nn.Module], optinal): Activation function which will be stacked on top of the normalization layer (if not None), otherwise on top of the conv layer. If ``None`` this layer wont be used. Default: ``torch.nn.ReLU``
        dilation (int): Spacing between kernel elements. Default: 1
        inplace (bool): Parameter for the activation layer, which can optionally do the operation in-place. Default ``True``
    """

    def __init__(
        self,
        in_channels: int,
        out_channels: int,
        kernel_size: int = 3,
        stride: int = 1,
        padding: Optional[int] = None,
        groups: int = 1,
        norm_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.BatchNorm2d,
        activation_layer: Optional[Callable[..., torch.nn.Module]] = torch.nn.ReLU,
        dilation: int = 1,
        inplace: bool = True,
    ) -> None:
        if padding is None:
            padding = (kernel_size - 1) // 2 * dilation
        layers = [
            torch.nn.Conv2d(
                in_channels,
                out_channels,
                kernel_size,
                stride,
                padding,
                dilation=dilation,
                groups=groups,
                bias=norm_layer is None,
            )
        ]
        if norm_layer is not None:
            layers.append(norm_layer(out_channels))
        if activation_layer is not None:
            layers.append(activation_layer(inplace=inplace))
        super().__init__(*layers)
        # _log_api_usage_once(self)
        self.out_channels = out_channels


class SqueezeExcitation(torch.nn.Module):
    """
    This block implements the Squeeze-and-Excitation block from https://arxiv.org/abs/1709.01507 (see Fig. 1).
    Parameters ``activation``, and ``scale_activation`` correspond to ``delta`` and ``sigma`` in in eq. 3.
    Args:
        input_channels (int): Number of channels in the input image
        squeeze_channels (int): Number of squeeze channels
        activation (Callable[..., torch.nn.Module], optional): ``delta`` activation. Default: ``torch.nn.ReLU``
        scale_activation (Callable[..., torch.nn.Module]): ``sigma`` activation. Default: ``torch.nn.Sigmoid``
    """

    def __init__(
        self,
        input_channels: int,
        squeeze_channels: int,
        activation: Callable[..., torch.nn.Module] = torch.nn.ReLU,
        scale_activation: Callable[..., torch.nn.Module] = torch.nn.Sigmoid,
    ) -> None:
        super().__init__()
        # _log_api_usage_once(self)
        self.avgpool = torch.nn.AdaptiveAvgPool2d(1)
        self.fc1 = torch.nn.Conv2d(input_channels, squeeze_channels, 1)
        self.fc2 = torch.nn.Conv2d(squeeze_channels, input_channels, 1)
        self.activation = activation()
        self.scale_activation = scale_activation()

    def _scale(self, input: Tensor) -> Tensor:
        scale = self.avgpool(input)
        scale = self.fc1(scale)
        scale = self.activation(scale)
        scale = self.fc2(scale)
        return self.scale_activation(scale)

    def forward(self, input: Tensor) -> Tensor:
        scale = self._scale(input)
        return scale * input

def _make_divisible(v: float, divisor: int, min_value: Optional[int] = None) -> int:
    """
    This function is taken from the original tf repo.
    It ensures that all layers have a channel number that is divisible by 8
    It can be seen here:
    https://github.com/tensorflow/models/blob/master/research/slim/nets/mobilenet/mobilenet.py
    """
    if min_value is None:
        min_value = divisor
    new_v = max(min_value, int(v + divisor / 2) // divisor * divisor)
    # Make sure that round down does not go down by more than 10%.
    if new_v < 0.9 * v:
        new_v += divisor
    return new_v


class SimpleStemIN(ConvNormActivation):
    """Simple stem for ImageNet: 3x3, BN, ReLU."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
    ) -> None:
        super().__init__(width_in, width_out, kernel_size=3, stride=2,
                         norm_layer=norm_layer, activation_layer=activation_layer)


class BottleneckTransform(nn.Sequential):
    """Bottleneck transformation: 1x1, 3x3 [+SE], 1x1."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float],
    ) -> None:
        layers: OrderedDict[str, nn.Module] = OrderedDict()
        w_b = int(round(width_out * bottleneck_multiplier))
        g = w_b // group_width

        layers["a"] = ConvNormActivation(width_in, w_b, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=activation_layer)
        layers["b"] = ConvNormActivation(w_b, w_b, kernel_size=3, stride=stride, groups=g,
                                         norm_layer=norm_layer, activation_layer=activation_layer)

        if se_ratio:
            # The SE reduction ratio is defined with respect to the
            # beginning of the block
            width_se_out = int(round(se_ratio * width_in))
            layers["se"] = SqueezeExcitation(
                input_channels=w_b,
                squeeze_channels=width_se_out,
                activation=activation_layer,
            )

        layers["c"] = ConvNormActivation(w_b, width_out, kernel_size=1, stride=1,
                                         norm_layer=norm_layer, activation_layer=None)
        super().__init__(layers)


class ResBottleneckBlock(nn.Module):
    """Residual bottleneck block: x + F(x), F = bottleneck transform."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int = 1,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
    ) -> None:
        super().__init__()

        # Use skip connection with projection if shape changes
        self.proj = None
        should_proj = (width_in != width_out) or (stride != 1)
        if should_proj:
            self.proj = ConvNormActivation(width_in, width_out, kernel_size=1,
                                           stride=stride, norm_layer=norm_layer, activation_layer=None)
        self.f = BottleneckTransform(
            width_in,
            width_out,
            stride,
            norm_layer,
            activation_layer,
            group_width,
            bottleneck_multiplier,
            se_ratio,
        )
        self.activation = activation_layer(inplace=True)

    def forward(self, x: Tensor) -> Tensor:
        if self.proj is not None:
            x = self.proj(x) + self.f(x)
        else:
            x = x + self.f(x)
        return self.activation(x)


class AnyStage(nn.Sequential):
    """AnyNet stage (sequence of blocks w/ the same output shape)."""

    def __init__(
        self,
        width_in: int,
        width_out: int,
        stride: int,
        depth: int,
        block_constructor: Callable[..., nn.Module],
        norm_layer: Callable[..., nn.Module],
        activation_layer: Callable[..., nn.Module],
        group_width: int,
        bottleneck_multiplier: float,
        se_ratio: Optional[float] = None,
        stage_index: int = 0,
    ) -> None:
        super().__init__()

        for i in range(depth):
            block = block_constructor(
                width_in if i == 0 else width_out,
                width_out,
                stride if i == 0 else 1,
                norm_layer,
                activation_layer,
                group_width,
                bottleneck_multiplier,
                se_ratio,
            )

            self.add_module(f"block{stage_index}-{i}", block)


class BlockParams:
    def __init__(
        self,
        depths: List[int],
        widths: List[int],
        group_widths: List[int],
        bottleneck_multipliers: List[float],
        strides: List[int],
        se_ratio: Optional[float] = None,
    ) -> None:
        self.depths = depths
        self.widths = widths
        self.group_widths = group_widths
        self.bottleneck_multipliers = bottleneck_multipliers
        self.strides = strides
        self.se_ratio = se_ratio

    @classmethod
    def from_init_params(
        cls,
        depth: int,
        w_0: int,
        w_a: float,
        w_m: float,
        group_width: int,
        bottleneck_multiplier: float = 1.0,
        se_ratio: Optional[float] = None,
        **kwargs: Any,
    ) -> "BlockParams":
        """
        Programatically compute all the per-block settings,
        given the RegNet parameters.

        The first step is to compute the quantized linear block parameters,
        in log space. Key parameters are:
        - `w_a` is the width progression slope
        - `w_0` is the initial width
        - `w_m` is the width stepping in the log space

        In other terms
        `log(block_width) = log(w_0) + w_m * block_capacity`,
        with `bock_capacity` ramping up following the w_0 and w_a params.
        This block width is finally quantized to multiples of 8.

        The second step is to compute the parameters per stage,
        taking into account the skip connection and the final 1x1 convolutions.
        We use the fact that the output width is constant within a stage.
        """

        QUANT = 8
        STRIDE = 2

        if w_a < 0 or w_0 <= 0 or w_m <= 1 or w_0 % 8 != 0:
            raise ValueError("Invalid RegNet settings")
        # Compute the block widths. Each stage has one unique block width
        widths_cont = torch.arange(depth) * w_a + w_0
        block_capacity = torch.round(torch.log(widths_cont / w_0) / math.log(w_m))
        block_widths = (
            torch.round(torch.divide(w_0 * torch.pow(w_m, block_capacity), QUANT))
            * QUANT
        ).int().tolist()
        num_stages = len(set(block_widths))

        # Convert to per stage parameters
        split_helper = zip(
            block_widths + [0],
            [0] + block_widths,
            block_widths + [0],
            [0] + block_widths,
        )
        splits = [w != wp or r != rp for w, wp, r, rp in split_helper]

        stage_widths = [w for w, t in zip(block_widths, splits[:-1]) if t]
        stage_depths = torch.diff(torch.tensor([d for d, t in enumerate(splits) if t])).int().tolist()

        strides = [STRIDE] * num_stages
        bottleneck_multipliers = [bottleneck_multiplier] * num_stages
        group_widths = [group_width] * num_stages

        # Adjust the compatibility of stage widths and group widths
        stage_widths, group_widths = cls._adjust_widths_groups_compatibilty(
            stage_widths, bottleneck_multipliers, group_widths
        )

        return cls(
            depths=stage_depths,
            widths=stage_widths,
            group_widths=group_widths,
            bottleneck_multipliers=bottleneck_multipliers,
            strides=strides,
            se_ratio=se_ratio,
        )

    def _get_expanded_params(self):
        return zip(
            self.widths, self.strides, self.depths, self.group_widths, self.bottleneck_multipliers
        )

    @staticmethod
    def _adjust_widths_groups_compatibilty(
            stage_widths: List[int], bottleneck_ratios: List[float],
            group_widths: List[int]) -> Tuple[List[int], List[int]]:
        """
        Adjusts the compatibility of widths and groups,
        depending on the bottleneck ratio.
        """
        # Compute all widths for the current settings
        widths = [int(w * b) for w, b in zip(stage_widths, bottleneck_ratios)]
        group_widths_min = [min(g, w_bot) for g, w_bot in zip(group_widths, widths)]

        # Compute the adjusted widths so that stage and group widths fit
        ws_bot = [_make_divisible(w_bot, g) for w_bot, g in zip(widths, group_widths_min)]
        stage_widths = [int(w_bot / b) for w_bot, b in zip(ws_bot, bottleneck_ratios)]
        return stage_widths, group_widths_min


class RegNet(nn.Module):
    def __init__(
        self,
        block_params: BlockParams,
        in_channels: int = 3,
        num_classes: int = 1000,
        stem_width: int = 32,
        stem_type: Optional[Callable[..., nn.Module]] = None,
        block_type: Optional[Callable[..., nn.Module]] = None,
        norm_layer: Optional[Callable[..., nn.Module]] = None,
        activation: Optional[Callable[..., nn.Module]] = None,
    ) -> None:
        super().__init__()

        if stem_type is None:
            stem_type = SimpleStemIN
        if norm_layer is None:
            norm_layer = nn.BatchNorm2d
        if block_type is None:
            block_type = ResBottleneckBlock
        if activation is None:
            activation = nn.ReLU

        # Ad hoc stem
        self.stem = stem_type(
            in_channels,  # width_in
            stem_width,
            norm_layer,
            activation,
        )

        current_width = stem_width

        blocks = []
        for i, (
            width_out,
            stride,
            depth,
            group_width,
            bottleneck_multiplier,
        ) in enumerate(block_params._get_expanded_params()):
            blocks.append(
                (
                    f"block{i+1}",
                    AnyStage(
                        current_width,
                        width_out,
                        stride,
                        depth,
                        block_type,
                        norm_layer,
                        activation,
                        group_width,
                        bottleneck_multiplier,
                        block_params.se_ratio,
                        stage_index=i + 1,
                    ),
                )
            )

            current_width = width_out

        self.trunk_output = nn.Sequential(OrderedDict(blocks))

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(in_features=current_width, out_features=num_classes)

        # Init weights and good to go
        self._reset_parameters()

        # initial weights
        for m in self.modules():
          if isinstance(m, nn.Conv2d):
            nn.init.kaiming_normal_(m.weight, mode="fan_out")
            if m.bias is not None:
                nn.init.zeros_(m.bias)
          elif isinstance(m, nn.BatchNorm2d):
            nn.init.ones_(m.weight)
            nn.init.zeros_(m.bias)
          elif isinstance(m, nn.Linear):
            nn.init.normal_(m.weight, 0, 0.01)
            nn.init.zeros_(m.bias)

    def forward(self, x: Tensor) -> Tensor:
        x = self.stem(x)
        x = self.trunk_output(x)

        x = self.avgpool(x)
        x = x.flatten(start_dim=1)
        x = self.fc(x)

        return x

    def _reset_parameters(self) -> None:
        # Performs ResNet-style weight initialization
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                # Note that there is no bias due to BN
                fan_out = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                nn.init.normal_(m.weight, mean=0.0, std=math.sqrt(2.0 / fan_out))
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.ones_(m.weight)
                nn.init.zeros_(m.bias)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, mean=0.0, std=0.01)
                nn.init.zeros_(m.bias)


def _regnet(arch: str, block_params: BlockParams, in_channels, num_classes, pretrained: bool, progress: bool, **kwargs: Any) -> RegNet:
    model = RegNet(block_params, in_channels=in_channels, num_classes=num_classes, norm_layer=partial(nn.BatchNorm2d, eps=1e-05, momentum=0.1), **kwargs)
    if pretrained:
        if arch not in model_urls:
            raise ValueError(f"No checkpoint is available for model type {arch}")
        # state_dict = load_state_dict_from_url(model_urls[arch], progress=progress)
        # model.load_state_dict(state_dict)
    return model

def regnet_y_400mf(in_channels, num_classes, pretrained: bool = False, progress: bool = True, **kwargs: Any) -> RegNet:
    """
    Constructs a RegNetY_400MF architecture from
    `"Designing Network Design Spaces" <https://arxiv.org/abs/2003.13678>`_.

    Args:
        pretrained (bool): If True, returns a model pre-trained on ImageNet
        progress (bool): If True, displays a progress bar of the download to stderr
    """
    params = BlockParams.from_init_params(depth=16, w_0=48, w_a=27.89, w_m=2.09,
                                          group_width=8, se_ratio=0.25, **kwargs)
    return _regnet("regnet_y_400mf", params, in_channels, num_classes, pretrained, progress, **kwargs)

# %%
class ClassificationNetwork(torch.nn.Module):
    def __init__(self, in_channels, embedding, num_classes):
        super().__init__()
        self.cnn = regnet_y_400mf(in_channels, embedding)
        self.mlp = nn.Sequential(nn.Linear(embedding,num_classes))


    def forward(self, x):
      out = self.cnn(x)
      out = self.mlp(out)
      return out

# %%
numEpochs = 100
in_features = 15 # TODO: change RGB channels according to num of frames
embedding = 512

learningRate = 0.1
weightDecay = 1e-4

num_classes = 120

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

network = ClassificationNetwork(in_features, embedding, num_classes)
#network.load_state_dict(torch.load("model_checkpoints/resnet34/lr_0.1-2/model_2.pt"))
network = network.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(network.parameters(), lr=learningRate, weight_decay=weightDecay, momentum=0.9)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5, verbose=True)

# %%
# Train!
max_val_acc = 0
for epoch in range(numEpochs):
    # Train
    network.train()
    avg_loss = 0.0
    avg_train_acc = 0.0
    for batch_num, (x, y) in enumerate(train_loader):
        optimizer.zero_grad()
        x.requires_grad_()
        x, y = x.to(device), y.to(device)
        outputs = network(x)
        num_train_correct = (torch.argmax(outputs, axis=1) == y).sum().item()
        num_labels = len(y)
        avg_train_acc += (num_train_correct/num_labels)

        loss = criterion(outputs, y.long())
        loss.backward()
        optimizer.step()
        avg_loss += loss.item()

        if batch_num % 50 == 49:
            print('Epoch: {}\tBatch: {}\tAvg-Loss: {:.4f}\tTraining Accuracy : {:.4f}'.format(epoch, batch_num+1, avg_loss/50, avg_train_acc/50))
            avg_loss = 0.0
            avg_train_acc = 0.0

        torch.cuda.empty_cache()
        del x
        del y
        del loss
    
    # Validate
    with torch.no_grad():
      network.eval()
      avg_val_loss = 0.0
      num_correct = 0
      for batch_num, (x, y) in enumerate(val_loader):
          x, y = x.to(device), y.to(device)
          outputs = network(x)
          num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()
          loss = criterion(outputs, y.long())
          avg_val_loss += loss.item()

          torch.cuda.empty_cache()
          del x
          del y

      avg_val_loss = avg_val_loss / len(val_loader)
      val_acc = num_correct / len(val_set)
      # checkpoint_name = "/content/gdrive/MyDrive/dl_project/model_checkpoints/efficientnet2/model_" + str(epoch) + ".pt"
      # torch.save(network.state_dict(), checkpoint_name)
      if val_acc > max_val_acc:
          max_val_acc = val_acc
          torch.save(network.state_dict(), "/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet/best_model.pt")
    scheduler.step(avg_val_loss)
    print('Epoch: {}, Validation Loss: {:.3f}, Validation Accuracy: {:.3f}'.format(epoch, avg_val_loss, val_acc))
# Out:
# Epoch: 0	Batch: 50	Avg-Loss: 5.1207	Training Accuracy : 0.0078
# Epoch: 0	Batch: 100	Avg-Loss: 4.7583	Training Accuracy : 0.0152
# Epoch: 0	Batch: 150	Avg-Loss: 4.3644	Training Accuracy : 0.0234
# Epoch: 0	Batch: 200	Avg-Loss: 3.7180	Training Accuracy : 0.0327
# Epoch: 0	Batch: 250	Avg-Loss: 3.4801	Training Accuracy : 0.0434
# Epoch: 0	Batch: 300	Avg-Loss: 3.4502	Training Accuracy : 0.0392
# Epoch: 0	Batch: 350	Avg-Loss: 3.3846	Training Accuracy : 0.0425
# Epoch: 0	Batch: 400	Avg-Loss: 3.3838	Training Accuracy : 0.0453
# Epoch: 0	Batch: 450	Avg-Loss: 3.3614	Training Accuracy : 0.0431
# Epoch: 0	Batch: 500	Avg-Loss: 3.3456	Training Accuracy : 0.0455
# Epoch: 0	Batch: 550	Avg-Loss: 3.3326	Training Accuracy : 0.0475
# Epoch: 0	Batch: 600	Avg-Loss: 3.3102	Training Accuracy : 0.0552
# Epoch: 0	Batch: 650	Avg-Loss: 3.3112	Training Accuracy : 0.0494
# Epoch: 0, Validation Loss: 3.263, Validation Accuracy: 0.060
# Epoch: 1	Batch: 50	Avg-Loss: 3.2901	Training Accuracy : 0.0567
# Epoch: 1	Batch: 100	Avg-Loss: 3.2560	Training Accuracy : 0.0577
# Epoch: 1	Batch: 150	Avg-Loss: 3.2366	Training Accuracy : 0.0653
# Epoch: 1	Batch: 200	Avg-Loss: 3.2412	Training Accuracy : 0.0642
# Epoch: 1	Batch: 250	Avg-Loss: 3.1894	Training Accuracy : 0.0728
# Epoch: 1	Batch: 300	Avg-Loss: 3.1892	Training Accuracy : 0.0683
# Epoch: 1	Batch: 350	Avg-Loss: 3.1659	Training Accuracy : 0.0744
# Epoch: 1	Batch: 400	Avg-Loss: 3.1638	Training Accuracy : 0.0791
# Epoch: 1	Batch: 450	Avg-Loss: 3.1272	Training Accuracy : 0.0788
# Epoch: 1	Batch: 500	Avg-Loss: 3.0810	Training Accuracy : 0.0909
# Epoch: 1	Batch: 550	Avg-Loss: 3.1113	Training Accuracy : 0.0920
# Epoch: 1	Batch: 600	Avg-Loss: 3.0786	Training Accuracy : 0.0948
# Epoch: 1	Batch: 650	Avg-Loss: 3.0376	Training Accuracy : 0.0967
# Epoch: 1, Validation Loss: 3.091, Validation Accuracy: 0.093
# Epoch: 2	Batch: 50	Avg-Loss: 3.0436	Training Accuracy : 0.0998
# Epoch: 2	Batch: 100	Avg-Loss: 3.0223	Training Accuracy : 0.1037
# Epoch: 2	Batch: 150	Avg-Loss: 2.9798	Training Accuracy : 0.1089
# Epoch: 2	Batch: 200	Avg-Loss: 2.9800	Training Accuracy : 0.1095
# Epoch: 2	Batch: 250	Avg-Loss: 2.9814	Training Accuracy : 0.1161
# Epoch: 2	Batch: 300	Avg-Loss: 2.9304	Training Accuracy : 0.1128
# Epoch: 2	Batch: 350	Avg-Loss: 2.9408	Training Accuracy : 0.1114
# Epoch: 2	Batch: 400	Avg-Loss: 2.9059	Training Accuracy : 0.1205
# Epoch: 2	Batch: 450	Avg-Loss: 2.9115	Training Accuracy : 0.1234
# Epoch: 2	Batch: 500	Avg-Loss: 2.8872	Training Accuracy : 0.1233
# Epoch: 2	Batch: 550	Avg-Loss: 2.8148	Training Accuracy : 0.1364
# Epoch: 2	Batch: 600	Avg-Loss: 2.7902	Training Accuracy : 0.1434
# Epoch: 2	Batch: 650	Avg-Loss: 2.8068	Training Accuracy : 0.1391
# Epoch: 2, Validation Loss: 3.079, Validation Accuracy: 0.109
# Epoch: 3	Batch: 50	Avg-Loss: 2.7886	Training Accuracy : 0.1414
# Epoch: 3	Batch: 100	Avg-Loss: 2.7815	Training Accuracy : 0.1383
# Epoch: 3	Batch: 150	Avg-Loss: 2.7127	Training Accuracy : 0.1420
# Epoch: 3	Batch: 200	Avg-Loss: 2.6649	Training Accuracy : 0.1636
# Epoch: 3	Batch: 250	Avg-Loss: 2.6567	Training Accuracy : 0.1680
# Epoch: 3	Batch: 300	Avg-Loss: 2.6290	Training Accuracy : 0.1733
# Epoch: 3	Batch: 350	Avg-Loss: 2.6780	Training Accuracy : 0.1733
# Epoch: 3	Batch: 400	Avg-Loss: 2.6422	Training Accuracy : 0.1742
# Epoch: 3	Batch: 450	Avg-Loss: 2.6265	Training Accuracy : 0.1753
# Epoch: 3	Batch: 500	Avg-Loss: 2.5784	Training Accuracy : 0.1833
# Epoch: 3	Batch: 550	Avg-Loss: 2.5825	Training Accuracy : 0.1867
# Epoch: 3	Batch: 600	Avg-Loss: 2.5644	Training Accuracy : 0.1803
# Epoch: 3	Batch: 650	Avg-Loss: 2.5356	Training Accuracy : 0.1988
# Epoch: 3, Validation Loss: 2.493, Validation Accuracy: 0.205
# Epoch: 4	Batch: 50	Avg-Loss: 2.4621	Training Accuracy : 0.2002
# Epoch: 4	Batch: 100	Avg-Loss: 2.4917	Training Accuracy : 0.2067
# Epoch: 4	Batch: 150	Avg-Loss: 2.4861	Training Accuracy : 0.2036
# Epoch: 4	Batch: 200	Avg-Loss: 2.4646	Training Accuracy : 0.2111
# Epoch: 4	Batch: 250	Avg-Loss: 2.4694	Training Accuracy : 0.2080
# Epoch: 4	Batch: 300	Avg-Loss: 2.4351	Training Accuracy : 0.2125
# Epoch: 4	Batch: 350	Avg-Loss: 2.4674	Training Accuracy : 0.2059
# Epoch: 4	Batch: 400	Avg-Loss: 2.4299	Training Accuracy : 0.2128
# Epoch: 4	Batch: 450	Avg-Loss: 2.4489	Training Accuracy : 0.2175
# Epoch: 4	Batch: 500	Avg-Loss: 2.4393	Training Accuracy : 0.2137
# Epoch: 4	Batch: 550	Avg-Loss: 2.4234	Training Accuracy : 0.2130
# Epoch: 4	Batch: 600	Avg-Loss: 2.4259	Training Accuracy : 0.2222
# Epoch: 4	Batch: 650	Avg-Loss: 2.3969	Training Accuracy : 0.2114
# Epoch: 4, Validation Loss: 2.473, Validation Accuracy: 0.217
# Epoch: 5	Batch: 50	Avg-Loss: 2.3815	Training Accuracy : 0.2277
# Epoch: 5	Batch: 100	Avg-Loss: 2.3810	Training Accuracy : 0.2245
# Epoch: 5	Batch: 150	Avg-Loss: 2.3609	Training Accuracy : 0.2272
# Epoch: 5	Batch: 200	Avg-Loss: 2.3435	Training Accuracy : 0.2181
# Epoch: 5	Batch: 250	Avg-Loss: 2.3657	Training Accuracy : 0.2242
# Epoch: 5	Batch: 300	Avg-Loss: 2.3435	Training Accuracy : 0.2259
# Epoch: 5	Batch: 350	Avg-Loss: 2.3732	Training Accuracy : 0.2248
# Epoch: 5	Batch: 400	Avg-Loss: 2.4004	Training Accuracy : 0.2147
# Epoch: 5	Batch: 450	Avg-Loss: 2.3579	Training Accuracy : 0.2236
# Epoch: 5	Batch: 500	Avg-Loss: 2.3664	Training Accuracy : 0.2219
# Epoch: 5	Batch: 550	Avg-Loss: 2.3215	Training Accuracy : 0.2308
# Epoch: 5	Batch: 600	Avg-Loss: 2.3266	Training Accuracy : 0.2350
# Epoch: 5	Batch: 650	Avg-Loss: 2.3474	Training Accuracy : 0.2288
# Epoch: 5, Validation Loss: 2.629, Validation Accuracy: 0.200
# Epoch: 6	Batch: 50	Avg-Loss: 2.3043	Training Accuracy : 0.2437
# Epoch: 6	Batch: 100	Avg-Loss: 2.2260	Training Accuracy : 0.2497
# Epoch: 6	Batch: 150	Avg-Loss: 2.3217	Training Accuracy : 0.2369
# Epoch: 6	Batch: 200	Avg-Loss: 2.3025	Training Accuracy : 0.2375
# Epoch: 6	Batch: 250	Avg-Loss: 2.3046	Training Accuracy : 0.2341
# Epoch: 6	Batch: 300	Avg-Loss: 2.2883	Training Accuracy : 0.2403
# Epoch: 6	Batch: 350	Avg-Loss: 2.2436	Training Accuracy : 0.2406
# Epoch: 6	Batch: 400	Avg-Loss: 2.2665	Training Accuracy : 0.2461
# Epoch: 6	Batch: 450	Avg-Loss: 2.2734	Training Accuracy : 0.2392
# Epoch: 6	Batch: 500	Avg-Loss: 2.2503	Training Accuracy : 0.2442
# Epoch: 6	Batch: 550	Avg-Loss: 2.2858	Training Accuracy : 0.2414
# Epoch: 6	Batch: 600	Avg-Loss: 2.2772	Training Accuracy : 0.2366
# Epoch: 6	Batch: 650	Avg-Loss: 2.2528	Training Accuracy : 0.2502
# Epoch: 6, Validation Loss: 2.547, Validation Accuracy: 0.210
# Epoch: 7	Batch: 50	Avg-Loss: 2.2515	Training Accuracy : 0.2470
# Epoch: 7	Batch: 100	Avg-Loss: 2.2201	Training Accuracy : 0.2611
# Epoch: 7	Batch: 150	Avg-Loss: 2.2199	Training Accuracy : 0.2486
# Epoch: 7	Batch: 200	Avg-Loss: 2.2122	Training Accuracy : 0.2608
# Epoch: 7	Batch: 250	Avg-Loss: 2.2127	Training Accuracy : 0.2492
# Epoch: 7	Batch: 300	Avg-Loss: 2.2465	Training Accuracy : 0.2395
# Epoch: 7	Batch: 350	Avg-Loss: 2.2311	Training Accuracy : 0.2503
# Epoch: 7	Batch: 400	Avg-Loss: 2.2024	Training Accuracy : 0.2502
# Epoch: 7	Batch: 450	Avg-Loss: 2.2509	Training Accuracy : 0.2437
# Epoch: 7	Batch: 500	Avg-Loss: 2.2237	Training Accuracy : 0.2592
# Epoch: 7	Batch: 550	Avg-Loss: 2.2246	Training Accuracy : 0.2445
# Epoch: 7	Batch: 600	Avg-Loss: 2.2175	Training Accuracy : 0.2491
# Epoch: 7	Batch: 650	Avg-Loss: 2.2406	Training Accuracy : 0.2586
# Epoch: 7, Validation Loss: 2.303, Validation Accuracy: 0.249
# Epoch: 8	Batch: 50	Avg-Loss: 2.2098	Training Accuracy : 0.2664
# Epoch: 8	Batch: 100	Avg-Loss: 2.2093	Training Accuracy : 0.2573
# Epoch: 8	Batch: 150	Avg-Loss: 2.1683	Training Accuracy : 0.2664
# Epoch: 8	Batch: 200	Avg-Loss: 2.1969	Training Accuracy : 0.2545
# Epoch: 8	Batch: 250	Avg-Loss: 2.1808	Training Accuracy : 0.2698
# Epoch: 8	Batch: 300	Avg-Loss: 2.2055	Training Accuracy : 0.2548
# Epoch: 8	Batch: 350	Avg-Loss: 2.1980	Training Accuracy : 0.2581
# Epoch: 8	Batch: 400	Avg-Loss: 2.1660	Training Accuracy : 0.2614
# Epoch: 8	Batch: 450	Avg-Loss: 2.1804	Training Accuracy : 0.2578
# Epoch: 8	Batch: 500	Avg-Loss: 2.1847	Training Accuracy : 0.2600
# Epoch: 8	Batch: 550	Avg-Loss: 2.1836	Training Accuracy : 0.2614
# Epoch: 8	Batch: 600	Avg-Loss: 2.1670	Training Accuracy : 0.2647
# Epoch: 8	Batch: 650	Avg-Loss: 2.1976	Training Accuracy : 0.2552
# Epoch: 8, Validation Loss: 2.341, Validation Accuracy: 0.254
# Epoch: 9	Batch: 50	Avg-Loss: 2.1189	Training Accuracy : 0.2700
# Epoch: 9	Batch: 100	Avg-Loss: 2.1198	Training Accuracy : 0.2773
# Epoch: 9	Batch: 150	Avg-Loss: 2.1448	Training Accuracy : 0.2641
# Epoch: 9	Batch: 200	Avg-Loss: 2.1526	Training Accuracy : 0.2636
# Epoch: 9	Batch: 250	Avg-Loss: 2.1353	Training Accuracy : 0.2722
# Epoch: 9	Batch: 300	Avg-Loss: 2.1827	Training Accuracy : 0.2584
# Epoch: 9	Batch: 350	Avg-Loss: 2.1655	Training Accuracy : 0.2598
# Epoch: 9	Batch: 400	Avg-Loss: 2.1078	Training Accuracy : 0.2792
# Epoch: 9	Batch: 450	Avg-Loss: 2.1206	Training Accuracy : 0.2708
# Epoch: 9	Batch: 500	Avg-Loss: 2.1462	Training Accuracy : 0.2619
# Epoch: 9	Batch: 550	Avg-Loss: 2.1396	Training Accuracy : 0.2553
# Epoch: 9	Batch: 600	Avg-Loss: 2.1270	Training Accuracy : 0.2709
# Epoch: 9	Batch: 650	Avg-Loss: 2.1395	Training Accuracy : 0.2744
# Epoch: 9, Validation Loss: 2.481, Validation Accuracy: 0.256
# Epoch: 10	Batch: 50	Avg-Loss: 2.0993	Training Accuracy : 0.2764
# Epoch: 10	Batch: 100	Avg-Loss: 2.0797	Training Accuracy : 0.2820
# Epoch: 10	Batch: 150	Avg-Loss: 2.0837	Training Accuracy : 0.2734
# Epoch: 10	Batch: 200	Avg-Loss: 2.1145	Training Accuracy : 0.2711
# Epoch: 10	Batch: 250	Avg-Loss: 2.0960	Training Accuracy : 0.2775
# Epoch: 10	Batch: 300	Avg-Loss: 2.0915	Training Accuracy : 0.2772
# Epoch: 10	Batch: 350	Avg-Loss: 2.1020	Training Accuracy : 0.2748
# Epoch: 10	Batch: 400	Avg-Loss: 2.0895	Training Accuracy : 0.2737
# Epoch: 10	Batch: 450	Avg-Loss: 2.1405	Training Accuracy : 0.2641
# Epoch: 10	Batch: 500	Avg-Loss: 2.0887	Training Accuracy : 0.2742
# Epoch: 10	Batch: 550	Avg-Loss: 2.1198	Training Accuracy : 0.2653
# Epoch: 10	Batch: 600	Avg-Loss: 2.0998	Training Accuracy : 0.2764
# Epoch: 10	Batch: 650	Avg-Loss: 2.1131	Training Accuracy : 0.2645
# Epoch    11: reducing learning rate of group 0 to 5.0000e-02.
# Epoch: 10, Validation Loss: 2.535, Validation Accuracy: 0.255
# Epoch: 11	Batch: 50	Avg-Loss: 1.9644	Training Accuracy : 0.2947
# Epoch: 11	Batch: 100	Avg-Loss: 1.9396	Training Accuracy : 0.2972
# Epoch: 11	Batch: 150	Avg-Loss: 1.9253	Training Accuracy : 0.3023
# Epoch: 11	Batch: 200	Avg-Loss: 1.9122	Training Accuracy : 0.3078
# Epoch: 11	Batch: 250	Avg-Loss: 1.9088	Training Accuracy : 0.3125
# Epoch: 11	Batch: 300	Avg-Loss: 1.8918	Training Accuracy : 0.3111
# Epoch: 11	Batch: 350	Avg-Loss: 1.9236	Training Accuracy : 0.3036
# Epoch: 11	Batch: 400	Avg-Loss: 1.9117	Training Accuracy : 0.3111
# Epoch: 11	Batch: 450	Avg-Loss: 1.9312	Training Accuracy : 0.3050
# Epoch: 11	Batch: 500	Avg-Loss: 1.9136	Training Accuracy : 0.2948
# Epoch: 11	Batch: 550	Avg-Loss: 1.9048	Training Accuracy : 0.3027
# Epoch: 11	Batch: 600	Avg-Loss: 1.9146	Training Accuracy : 0.3056
# Epoch: 11	Batch: 650	Avg-Loss: 1.9101	Training Accuracy : 0.2942
# Epoch: 11, Validation Loss: 3.079, Validation Accuracy: 0.274
# Epoch: 12	Batch: 50	Avg-Loss: 1.7875	Training Accuracy : 0.3422
# Epoch: 12	Batch: 100	Avg-Loss: 1.8355	Training Accuracy : 0.3147
# Epoch: 12	Batch: 150	Avg-Loss: 1.8511	Training Accuracy : 0.3148
# Epoch: 12	Batch: 200	Avg-Loss: 1.8661	Training Accuracy : 0.3094
# Epoch: 12	Batch: 250	Avg-Loss: 1.8401	Training Accuracy : 0.3231
# Epoch: 12	Batch: 300	Avg-Loss: 1.8804	Training Accuracy : 0.3084
# Epoch: 12	Batch: 350	Avg-Loss: 1.8260	Training Accuracy : 0.3198
# Epoch: 12	Batch: 400	Avg-Loss: 1.8496	Training Accuracy : 0.3212
# Epoch: 12	Batch: 450	Avg-Loss: 1.8500	Training Accuracy : 0.3084
# Epoch: 12	Batch: 500	Avg-Loss: 1.9161	Training Accuracy : 0.3095
# Epoch: 12	Batch: 550	Avg-Loss: 1.8941	Training Accuracy : 0.3059
# Epoch: 12	Batch: 600	Avg-Loss: 1.8803	Training Accuracy : 0.3145
# Epoch: 12	Batch: 650	Avg-Loss: 1.8542	Training Accuracy : 0.3102
# Epoch: 12, Validation Loss: 2.339, Validation Accuracy: 0.275
# Epoch: 13	Batch: 50	Avg-Loss: 1.7162	Training Accuracy : 0.3498
# Epoch: 13	Batch: 100	Avg-Loss: 1.7720	Training Accuracy : 0.3352
# Epoch: 13	Batch: 150	Avg-Loss: 1.7517	Training Accuracy : 0.3383
# Epoch: 13	Batch: 200	Avg-Loss: 1.7825	Training Accuracy : 0.3319
# Epoch: 13	Batch: 250	Avg-Loss: 1.8057	Training Accuracy : 0.3281
# Epoch: 13	Batch: 300	Avg-Loss: 1.7944	Training Accuracy : 0.3369
# Epoch: 13	Batch: 350	Avg-Loss: 1.7720	Training Accuracy : 0.3273
# Epoch: 13	Batch: 400	Avg-Loss: 1.7756	Training Accuracy : 0.3344
# Epoch: 13	Batch: 450	Avg-Loss: 1.8039	Training Accuracy : 0.3295
# Epoch: 13	Batch: 500	Avg-Loss: 1.7818	Training Accuracy : 0.3328
# Epoch: 13	Batch: 550	Avg-Loss: 1.8088	Training Accuracy : 0.3162
# Epoch: 13	Batch: 600	Avg-Loss: 1.7591	Training Accuracy : 0.3316
# Epoch: 13	Batch: 650	Avg-Loss: 1.8307	Training Accuracy : 0.3212
# Epoch    14: reducing learning rate of group 0 to 2.5000e-02.
# Epoch: 13, Validation Loss: 2.358, Validation Accuracy: 0.265
# Epoch: 14	Batch: 50	Avg-Loss: 1.5709	Training Accuracy : 0.3733
# Epoch: 14	Batch: 100	Avg-Loss: 1.5229	Training Accuracy : 0.3855
# Epoch: 14	Batch: 150	Avg-Loss: 1.5520	Training Accuracy : 0.3833
# Epoch: 14	Batch: 200	Avg-Loss: 1.5617	Training Accuracy : 0.3766
# Epoch: 14	Batch: 250	Avg-Loss: 1.5597	Training Accuracy : 0.3812
# Epoch: 14	Batch: 300	Avg-Loss: 1.5251	Training Accuracy : 0.3781
# Epoch: 14	Batch: 350	Avg-Loss: 1.5523	Training Accuracy : 0.3822
# Epoch: 14	Batch: 400	Avg-Loss: 1.5260	Training Accuracy : 0.3805
# Epoch: 14	Batch: 450	Avg-Loss: 1.5411	Training Accuracy : 0.3862
# Epoch: 14	Batch: 500	Avg-Loss: 1.5719	Training Accuracy : 0.3689
# Epoch: 14	Batch: 550	Avg-Loss: 1.5439	Training Accuracy : 0.3816
# Epoch: 14	Batch: 600	Avg-Loss: 1.5487	Training Accuracy : 0.3844
# Epoch: 14	Batch: 650	Avg-Loss: 1.5556	Training Accuracy : 0.3787
# Epoch: 14, Validation Loss: 2.395, Validation Accuracy: 0.272
# Epoch: 15	Batch: 50	Avg-Loss: 1.3712	Training Accuracy : 0.4292
# Epoch: 15	Batch: 100	Avg-Loss: 1.3758	Training Accuracy : 0.4322
# Epoch: 15	Batch: 150	Avg-Loss: 1.3999	Training Accuracy : 0.4186
# Epoch: 15	Batch: 200	Avg-Loss: 1.4278	Training Accuracy : 0.4152
# Epoch: 15	Batch: 250	Avg-Loss: 1.4753	Training Accuracy : 0.4066
# Epoch: 15	Batch: 300	Avg-Loss: 1.4741	Training Accuracy : 0.4052
# Epoch: 15	Batch: 350	Avg-Loss: 1.4725	Training Accuracy : 0.4116
# Epoch: 15	Batch: 400	Avg-Loss: 1.4731	Training Accuracy : 0.4022
# Epoch: 15	Batch: 450	Avg-Loss: 1.4807	Training Accuracy : 0.3994
# Epoch: 15	Batch: 500	Avg-Loss: 1.4711	Training Accuracy : 0.4108
# Epoch: 15	Batch: 550	Avg-Loss: 1.4837	Training Accuracy : 0.3995
# Epoch: 15	Batch: 600	Avg-Loss: 1.4630	Training Accuracy : 0.4167
# Epoch: 15	Batch: 650	Avg-Loss: 1.4874	Training Accuracy : 0.4058
# Epoch: 15, Validation Loss: 2.607, Validation Accuracy: 0.275
# Epoch: 16	Batch: 50	Avg-Loss: 1.3360	Training Accuracy : 0.4436
# Epoch: 16	Batch: 100	Avg-Loss: 1.3521	Training Accuracy : 0.4411
# Epoch: 16	Batch: 150	Avg-Loss: 1.3194	Training Accuracy : 0.4653
# Epoch: 16	Batch: 200	Avg-Loss: 1.3613	Training Accuracy : 0.4503
# Epoch: 16	Batch: 250	Avg-Loss: 1.3707	Training Accuracy : 0.4486
# Epoch: 16	Batch: 300	Avg-Loss: 1.3772	Training Accuracy : 0.4419
# Epoch: 16	Batch: 350	Avg-Loss: 1.4245	Training Accuracy : 0.4422
# Epoch: 16	Batch: 400	Avg-Loss: 1.3945	Training Accuracy : 0.4411
# Epoch: 16	Batch: 450	Avg-Loss: 1.4209	Training Accuracy : 0.4356
# Epoch: 16	Batch: 500	Avg-Loss: 1.4056	Training Accuracy : 0.4363
# Epoch: 16	Batch: 550	Avg-Loss: 1.4001	Training Accuracy : 0.4373
# Epoch: 16	Batch: 600	Avg-Loss: 1.4237	Training Accuracy : 0.4313
# Epoch: 16	Batch: 650	Avg-Loss: 1.4227	Training Accuracy : 0.4412
# Epoch    17: reducing learning rate of group 0 to 1.2500e-02.
# Epoch: 16, Validation Loss: 2.642, Validation Accuracy: 0.270
# Epoch: 17	Batch: 50	Avg-Loss: 1.1893	Training Accuracy : 0.5128
# Epoch: 17	Batch: 100	Avg-Loss: 1.1367	Training Accuracy : 0.5334
# Epoch: 17	Batch: 150	Avg-Loss: 1.0975	Training Accuracy : 0.5561
# Epoch: 17	Batch: 200	Avg-Loss: 1.1053	Training Accuracy : 0.5430
# Epoch: 17	Batch: 250	Avg-Loss: 1.1112	Training Accuracy : 0.5425
# Epoch: 17	Batch: 300	Avg-Loss: 1.1379	Training Accuracy : 0.5309
# Epoch: 17	Batch: 350	Avg-Loss: 1.1107	Training Accuracy : 0.5398
# Epoch: 17	Batch: 400	Avg-Loss: 1.1077	Training Accuracy : 0.5589
# Epoch: 17	Batch: 450	Avg-Loss: 1.1092	Training Accuracy : 0.5492
# Epoch: 17	Batch: 500	Avg-Loss: 1.1264	Training Accuracy : 0.5455
# Epoch: 17	Batch: 550	Avg-Loss: 1.1222	Training Accuracy : 0.5519
# Epoch: 17	Batch: 600	Avg-Loss: 1.1398	Training Accuracy : 0.5630
# Epoch: 17	Batch: 650	Avg-Loss: 1.1363	Training Accuracy : 0.5498
# Epoch: 17, Validation Loss: 4.924, Validation Accuracy: 0.273
# Epoch: 18	Batch: 50	Avg-Loss: 0.9537	Training Accuracy : 0.6264
# Epoch: 18	Batch: 100	Avg-Loss: 0.9363	Training Accuracy : 0.6402
# Epoch: 18	Batch: 150	Avg-Loss: 0.9519	Training Accuracy : 0.6352
# Epoch: 18	Batch: 200	Avg-Loss: 0.9632	Training Accuracy : 0.6227
# Epoch: 18	Batch: 250	Avg-Loss: 0.9913	Training Accuracy : 0.6170
# Epoch: 18	Batch: 300	Avg-Loss: 0.9999	Training Accuracy : 0.6214
# Epoch: 18	Batch: 350	Avg-Loss: 0.9794	Training Accuracy : 0.6200
# Epoch: 18	Batch: 400	Avg-Loss: 0.9808	Training Accuracy : 0.6308
# Epoch: 18	Batch: 450	Avg-Loss: 1.0164	Training Accuracy : 0.6088
# Epoch: 18	Batch: 500	Avg-Loss: 0.9949	Training Accuracy : 0.6261
# Epoch: 18	Batch: 550	Avg-Loss: 1.0179	Training Accuracy : 0.6136
# Epoch: 18	Batch: 600	Avg-Loss: 1.0205	Training Accuracy : 0.6162
# Epoch: 18	Batch: 650	Avg-Loss: 1.0280	Training Accuracy : 0.6181
# Epoch: 18, Validation Loss: 3.416, Validation Accuracy: 0.272
# Epoch: 19	Batch: 50	Avg-Loss: 0.8403	Training Accuracy : 0.6977
# Epoch: 19	Batch: 100	Avg-Loss: 0.8269	Training Accuracy : 0.7033
# Epoch: 19	Batch: 150	Avg-Loss: 0.8552	Training Accuracy : 0.6966
# Epoch: 19	Batch: 200	Avg-Loss: 0.8452	Training Accuracy : 0.6958
# Epoch: 19	Batch: 250	Avg-Loss: 0.8554	Training Accuracy : 0.6898
# Epoch: 19	Batch: 300	Avg-Loss: 0.8784	Training Accuracy : 0.6814
# Epoch: 19	Batch: 350	Avg-Loss: 0.8778	Training Accuracy : 0.6867
# Epoch: 19	Batch: 400	Avg-Loss: 0.9174	Training Accuracy : 0.6717
# Epoch: 19	Batch: 450	Avg-Loss: 0.9030	Training Accuracy : 0.6741
# Epoch: 19	Batch: 500	Avg-Loss: 0.9370	Training Accuracy : 0.6634
# Epoch: 19	Batch: 550	Avg-Loss: 0.9352	Training Accuracy : 0.6728
# Epoch: 19	Batch: 600	Avg-Loss: 0.8905	Training Accuracy : 0.6828
# Epoch: 19	Batch: 650	Avg-Loss: 0.9533	Training Accuracy : 0.6589
# Epoch    20: reducing learning rate of group 0 to 6.2500e-03.
# Epoch: 19, Validation Loss: 3.950, Validation Accuracy: 0.269
# Epoch: 20	Batch: 50	Avg-Loss: 0.7018	Training Accuracy : 0.7633
# Epoch: 20	Batch: 100	Avg-Loss: 0.6381	Training Accuracy : 0.7784
# Epoch: 20	Batch: 150	Avg-Loss: 0.6054	Training Accuracy : 0.7980
# Epoch: 20	Batch: 200	Avg-Loss: 0.5829	Training Accuracy : 0.8067
# Epoch: 20	Batch: 250	Avg-Loss: 0.5661	Training Accuracy : 0.8103
# Epoch: 20	Batch: 300	Avg-Loss: 0.5767	Training Accuracy : 0.8064
# Epoch: 20	Batch: 350	Avg-Loss: 0.5845	Training Accuracy : 0.8084
# Epoch: 20	Batch: 400	Avg-Loss: 0.5863	Training Accuracy : 0.7984
# Epoch: 20	Batch: 450	Avg-Loss: 0.5769	Training Accuracy : 0.8070
# Epoch: 20	Batch: 500	Avg-Loss: 0.5759	Training Accuracy : 0.8036
# Epoch: 20	Batch: 550	Avg-Loss: 0.5783	Training Accuracy : 0.8067
# Epoch: 20	Batch: 600	Avg-Loss: 0.5769	Training Accuracy : 0.8003
# Epoch: 20	Batch: 650	Avg-Loss: 0.5674	Training Accuracy : 0.8127
# Epoch: 20, Validation Loss: 4.138, Validation Accuracy: 0.276
# Epoch: 21	Batch: 50	Avg-Loss: 0.4542	Training Accuracy : 0.8531
# Epoch: 21	Batch: 100	Avg-Loss: 0.4143	Training Accuracy : 0.8734
# Epoch: 21	Batch: 150	Avg-Loss: 0.4225	Training Accuracy : 0.8661
# Epoch: 21	Batch: 200	Avg-Loss: 0.4200	Training Accuracy : 0.8675
# Epoch: 21	Batch: 250	Avg-Loss: 0.4265	Training Accuracy : 0.8612
# Epoch: 21	Batch: 300	Avg-Loss: 0.4359	Training Accuracy : 0.8573
# Epoch: 21	Batch: 350	Avg-Loss: 0.4478	Training Accuracy : 0.8511
# Epoch: 21	Batch: 400	Avg-Loss: 0.4400	Training Accuracy : 0.8564
# Epoch: 21	Batch: 450	Avg-Loss: 0.4510	Training Accuracy : 0.8525
# Epoch: 21	Batch: 500	Avg-Loss: 0.4304	Training Accuracy : 0.8630
# Epoch: 21	Batch: 550	Avg-Loss: 0.4667	Training Accuracy : 0.8423
# Epoch: 21	Batch: 600	Avg-Loss: 0.4672	Training Accuracy : 0.8428
# Epoch: 21	Batch: 650	Avg-Loss: 0.4705	Training Accuracy : 0.8455
# Epoch: 21, Validation Loss: 4.255, Validation Accuracy: 0.274
# Epoch: 22	Batch: 50	Avg-Loss: 0.3474	Training Accuracy : 0.8955
# Epoch: 22	Batch: 100	Avg-Loss: 0.3363	Training Accuracy : 0.8995
# Epoch: 22	Batch: 150	Avg-Loss: 0.3450	Training Accuracy : 0.8948
# Epoch: 22	Batch: 200	Avg-Loss: 0.3359	Training Accuracy : 0.8956
# Epoch: 22	Batch: 250	Avg-Loss: 0.3618	Training Accuracy : 0.8836
# Epoch: 22	Batch: 300	Avg-Loss: 0.3563	Training Accuracy : 0.8880
# Epoch: 22	Batch: 350	Avg-Loss: 0.3652	Training Accuracy : 0.8819
# Epoch: 22	Batch: 400	Avg-Loss: 0.3620	Training Accuracy : 0.8872
# Epoch: 22	Batch: 450	Avg-Loss: 0.3995	Training Accuracy : 0.8683
# Epoch: 22	Batch: 500	Avg-Loss: 0.4053	Training Accuracy : 0.8680
# Epoch: 22	Batch: 550	Avg-Loss: 0.3831	Training Accuracy : 0.8775
# Epoch: 22	Batch: 600	Avg-Loss: 0.4297	Training Accuracy : 0.8544
# Epoch: 22	Batch: 650	Avg-Loss: 0.4106	Training Accuracy : 0.8648
# Epoch    23: reducing learning rate of group 0 to 3.1250e-03.
# Epoch: 22, Validation Loss: 4.733, Validation Accuracy: 0.262
# Epoch: 23	Batch: 50	Avg-Loss: 0.3043	Training Accuracy : 0.9097
# Epoch: 23	Batch: 100	Avg-Loss: 0.2857	Training Accuracy : 0.9206
# Epoch: 23	Batch: 150	Avg-Loss: 0.2807	Training Accuracy : 0.9152
# Epoch: 23	Batch: 200	Avg-Loss: 0.2647	Training Accuracy : 0.9211
# Epoch: 23	Batch: 250	Avg-Loss: 0.2652	Training Accuracy : 0.9194
# Epoch: 23	Batch: 300	Avg-Loss: 0.2329	Training Accuracy : 0.9339
# Epoch: 23	Batch: 350	Avg-Loss: 0.2569	Training Accuracy : 0.9244
# Epoch: 23	Batch: 400	Avg-Loss: 0.2579	Training Accuracy : 0.9230
# Epoch: 23	Batch: 450	Avg-Loss: 0.2735	Training Accuracy : 0.9189
# Epoch: 23	Batch: 500	Avg-Loss: 0.2622	Training Accuracy : 0.9225
# Epoch: 23	Batch: 550	Avg-Loss: 0.2519	Training Accuracy : 0.9275
# Epoch: 23	Batch: 600	Avg-Loss: 0.2552	Training Accuracy : 0.9253
# Epoch: 23	Batch: 650	Avg-Loss: 0.2557	Training Accuracy : 0.9261
# Epoch: 23, Validation Loss: 4.864, Validation Accuracy: 0.269
# Epoch: 24	Batch: 50	Avg-Loss: 0.2160	Training Accuracy : 0.9419
# Epoch: 24	Batch: 100	Avg-Loss: 0.2087	Training Accuracy : 0.9450
# Epoch: 24	Batch: 150	Avg-Loss: 0.1927	Training Accuracy : 0.9489
# Epoch: 24	Batch: 200	Avg-Loss: 0.2012	Training Accuracy : 0.9463
# Epoch: 24	Batch: 250	Avg-Loss: 0.1831	Training Accuracy : 0.9522
# Epoch: 24	Batch: 300	Avg-Loss: 0.1937	Training Accuracy : 0.9473
# Epoch: 24	Batch: 350	Avg-Loss: 0.2210	Training Accuracy : 0.9395
# Epoch: 24	Batch: 400	Avg-Loss: 0.2091	Training Accuracy : 0.9405
# Epoch: 24	Batch: 450	Avg-Loss: 0.2050	Training Accuracy : 0.9428
# Epoch: 24	Batch: 500	Avg-Loss: 0.2208	Training Accuracy : 0.9372
# Epoch: 24	Batch: 550	Avg-Loss: 0.2111	Training Accuracy : 0.9434
# Epoch: 24	Batch: 600	Avg-Loss: 0.2226	Training Accuracy : 0.9363
# Epoch: 24	Batch: 650	Avg-Loss: 0.2174	Training Accuracy : 0.9367
# Epoch: 24, Validation Loss: 4.828, Validation Accuracy: 0.274
# Epoch: 25	Batch: 50	Avg-Loss: 0.1688	Training Accuracy : 0.9552
# Epoch: 25	Batch: 100	Avg-Loss: 0.1829	Training Accuracy : 0.9525
# Epoch: 25	Batch: 150	Avg-Loss: 0.1831	Training Accuracy : 0.9509
# Epoch: 25	Batch: 200	Avg-Loss: 0.1765	Training Accuracy : 0.9533
# Epoch: 25	Batch: 250	Avg-Loss: 0.1871	Training Accuracy : 0.9486
# Epoch: 25	Batch: 300	Avg-Loss: 0.1913	Training Accuracy : 0.9469
# Epoch: 25	Batch: 350	Avg-Loss: 0.1765	Training Accuracy : 0.9533
# Epoch: 25	Batch: 400	Avg-Loss: 0.1786	Training Accuracy : 0.9508
# Epoch: 25	Batch: 450	Avg-Loss: 0.1827	Training Accuracy : 0.9494
# Epoch: 25	Batch: 500	Avg-Loss: 0.1864	Training Accuracy : 0.9467
# Epoch: 25	Batch: 550	Avg-Loss: 0.1857	Training Accuracy : 0.9486
# Epoch: 25	Batch: 600	Avg-Loss: 0.1754	Training Accuracy : 0.9533
# Epoch: 25	Batch: 650	Avg-Loss: 0.1788	Training Accuracy : 0.9527
# Epoch    26: reducing learning rate of group 0 to 1.5625e-03.
# Epoch: 25, Validation Loss: 5.175, Validation Accuracy: 0.270
# Epoch: 26	Batch: 50	Avg-Loss: 0.1405	Training Accuracy : 0.9636
# Epoch: 26	Batch: 100	Avg-Loss: 0.1489	Training Accuracy : 0.9613
# Epoch: 26	Batch: 150	Avg-Loss: 0.1465	Training Accuracy : 0.9623
# Epoch: 26	Batch: 200	Avg-Loss: 0.1556	Training Accuracy : 0.9594
# Epoch: 26	Batch: 250	Avg-Loss: 0.1456	Training Accuracy : 0.9633
# Epoch: 26	Batch: 300	Avg-Loss: 0.1419	Training Accuracy : 0.9633
# Epoch: 26	Batch: 350	Avg-Loss: 0.1623	Training Accuracy : 0.9583
# Epoch: 26	Batch: 400	Avg-Loss: 0.1446	Training Accuracy : 0.9616
# Epoch: 26	Batch: 450	Avg-Loss: 0.1552	Training Accuracy : 0.9581
# Epoch: 26	Batch: 500	Avg-Loss: 0.1506	Training Accuracy : 0.9592
# Epoch: 26	Batch: 550	Avg-Loss: 0.1681	Training Accuracy : 0.9559
# Epoch: 26	Batch: 600	Avg-Loss: 0.1408	Training Accuracy : 0.9622
# Epoch: 26	Batch: 650	Avg-Loss: 0.1502	Training Accuracy : 0.9597
# Epoch: 26, Validation Loss: 5.080, Validation Accuracy: 0.271
# Epoch: 27	Batch: 50	Avg-Loss: 0.1396	Training Accuracy : 0.9639
# Epoch: 27	Batch: 100	Avg-Loss: 0.1377	Training Accuracy : 0.9666
# Epoch: 27	Batch: 150	Avg-Loss: 0.1260	Training Accuracy : 0.9691
# Epoch: 27	Batch: 200	Avg-Loss: 0.1320	Training Accuracy : 0.9663
# Epoch: 27	Batch: 250	Avg-Loss: 0.1299	Training Accuracy : 0.9652
# Epoch: 27	Batch: 300	Avg-Loss: 0.1456	Training Accuracy : 0.9622
# Epoch: 27	Batch: 350	Avg-Loss: 0.1373	Training Accuracy : 0.9625
# Epoch: 27	Batch: 400	Avg-Loss: 0.1408	Training Accuracy : 0.9641
# Epoch: 27	Batch: 450	Avg-Loss: 0.1330	Training Accuracy : 0.9648
# Epoch: 27	Batch: 500	Avg-Loss: 0.1245	Training Accuracy : 0.9678
# Epoch: 27	Batch: 550	Avg-Loss: 0.1332	Training Accuracy : 0.9661
# Epoch: 27	Batch: 600	Avg-Loss: 0.1360	Training Accuracy : 0.9639
# Epoch: 27	Batch: 650	Avg-Loss: 0.1416	Training Accuracy : 0.9619
# Epoch: 27, Validation Loss: 5.053, Validation Accuracy: 0.274
# Epoch: 28	Batch: 50	Avg-Loss: 0.1150	Training Accuracy : 0.9727
# Epoch: 28	Batch: 100	Avg-Loss: 0.1257	Training Accuracy : 0.9667
# Epoch: 28	Batch: 150	Avg-Loss: 0.1254	Training Accuracy : 0.9692
# Epoch: 28	Batch: 200	Avg-Loss: 0.1271	Training Accuracy : 0.9692
# Epoch: 28	Batch: 250	Avg-Loss: 0.1269	Training Accuracy : 0.9672
# Epoch: 28	Batch: 300	Avg-Loss: 0.1181	Training Accuracy : 0.9698
# Epoch: 28	Batch: 350	Avg-Loss: 0.1339	Training Accuracy : 0.9647
# Epoch: 28	Batch: 400	Avg-Loss: 0.1285	Training Accuracy : 0.9670
# Epoch: 28	Batch: 450	Avg-Loss: 0.1204	Training Accuracy : 0.9692
# Epoch: 28	Batch: 500	Avg-Loss: 0.1382	Training Accuracy : 0.9630
# Epoch: 28	Batch: 550	Avg-Loss: 0.1268	Training Accuracy : 0.9677
# Epoch: 28	Batch: 600	Avg-Loss: 0.1315	Training Accuracy : 0.9655
# Epoch: 28	Batch: 650	Avg-Loss: 0.1328	Training Accuracy : 0.9650
# Epoch    29: reducing learning rate of group 0 to 7.8125e-04.
# Epoch: 28, Validation Loss: 5.279, Validation Accuracy: 0.269
# Epoch: 29	Batch: 50	Avg-Loss: 0.1168	Training Accuracy : 0.9712
# Epoch: 29	Batch: 100	Avg-Loss: 0.1117	Training Accuracy : 0.9722
# Epoch: 29	Batch: 150	Avg-Loss: 0.1104	Training Accuracy : 0.9730
# Epoch: 29	Batch: 200	Avg-Loss: 0.1314	Training Accuracy : 0.9644
# Epoch: 29	Batch: 250	Avg-Loss: 0.1115	Training Accuracy : 0.9711
# Epoch: 29	Batch: 300	Avg-Loss: 0.1107	Training Accuracy : 0.9733
# Epoch: 29	Batch: 350	Avg-Loss: 0.1253	Training Accuracy : 0.9655
# Epoch: 29	Batch: 400	Avg-Loss: 0.1060	Training Accuracy : 0.9730
# Epoch: 29	Batch: 450	Avg-Loss: 0.1053	Training Accuracy : 0.9742
# Epoch: 29	Batch: 500	Avg-Loss: 0.1111	Training Accuracy : 0.9712
# Epoch: 29	Batch: 550	Avg-Loss: 0.1141	Training Accuracy : 0.9702
# Epoch: 29	Batch: 600	Avg-Loss: 0.1122	Training Accuracy : 0.9725
# Epoch: 29	Batch: 650	Avg-Loss: 0.1059	Training Accuracy : 0.9723
# Epoch: 29, Validation Loss: 5.111, Validation Accuracy: 0.270
# Epoch: 30	Batch: 50	Avg-Loss: 0.1184	Training Accuracy : 0.9709
# Epoch: 30	Batch: 100	Avg-Loss: 0.0929	Training Accuracy : 0.9786
# Epoch: 30	Batch: 150	Avg-Loss: 0.1119	Training Accuracy : 0.9745
# Epoch: 30	Batch: 200	Avg-Loss: 0.1127	Training Accuracy : 0.9741
# Epoch: 30	Batch: 250	Avg-Loss: 0.1022	Training Accuracy : 0.9761
# Epoch: 30	Batch: 300	Avg-Loss: 0.1050	Training Accuracy : 0.9736
# Epoch: 30	Batch: 350	Avg-Loss: 0.1029	Training Accuracy : 0.9745
# Epoch: 30	Batch: 400	Avg-Loss: 0.1035	Training Accuracy : 0.9742
# Epoch: 30	Batch: 450	Avg-Loss: 0.1043	Training Accuracy : 0.9753
# Epoch: 30	Batch: 500	Avg-Loss: 0.1071	Training Accuracy : 0.9716
# Epoch: 30	Batch: 550	Avg-Loss: 0.1178	Training Accuracy : 0.9706
# Epoch: 30	Batch: 600	Avg-Loss: 0.1058	Training Accuracy : 0.9750
# Epoch: 30	Batch: 650	Avg-Loss: 0.1094	Training Accuracy : 0.9719
# Epoch: 30, Validation Loss: 5.112, Validation Accuracy: 0.272
# Epoch: 31	Batch: 50	Avg-Loss: 0.0956	Training Accuracy : 0.9769
# Epoch: 31	Batch: 100	Avg-Loss: 0.0988	Training Accuracy : 0.9767
# Epoch: 31	Batch: 150	Avg-Loss: 0.0958	Training Accuracy : 0.9767
# Epoch: 31	Batch: 200	Avg-Loss: 0.1041	Training Accuracy : 0.9734
# Epoch: 31	Batch: 250	Avg-Loss: 0.0961	Training Accuracy : 0.9761
# Epoch: 31	Batch: 300	Avg-Loss: 0.1024	Training Accuracy : 0.9747
# Epoch: 31	Batch: 350	Avg-Loss: 0.0991	Training Accuracy : 0.9759
# Epoch: 31	Batch: 400	Avg-Loss: 0.0942	Training Accuracy : 0.9764
# Epoch: 31	Batch: 450	Avg-Loss: 0.1089	Training Accuracy : 0.9736
# Epoch: 31	Batch: 500	Avg-Loss: 0.1106	Training Accuracy : 0.9719
# Epoch: 31	Batch: 550	Avg-Loss: 0.1083	Training Accuracy : 0.9708
# Epoch: 31	Batch: 600	Avg-Loss: 0.1107	Training Accuracy : 0.9716
# Epoch: 31	Batch: 650	Avg-Loss: 0.1026	Training Accuracy : 0.9738
# Epoch    32: reducing learning rate of group 0 to 3.9063e-04.
# Epoch: 31, Validation Loss: 5.294, Validation Accuracy: 0.270
# Epoch: 32	Batch: 50	Avg-Loss: 0.0923	Training Accuracy : 0.9780
# Epoch: 32	Batch: 100	Avg-Loss: 0.0929	Training Accuracy : 0.9797
# Epoch: 32	Batch: 150	Avg-Loss: 0.0914	Training Accuracy : 0.9767
# Epoch: 32	Batch: 200	Avg-Loss: 0.1006	Training Accuracy : 0.9748
# Epoch: 32	Batch: 250	Avg-Loss: 0.0977	Training Accuracy : 0.9750
# Epoch: 32	Batch: 300	Avg-Loss: 0.0806	Training Accuracy : 0.9795
# Epoch: 32	Batch: 350	Avg-Loss: 0.0991	Training Accuracy : 0.9745
# Epoch: 32	Batch: 400	Avg-Loss: 0.0972	Training Accuracy : 0.9770
# Epoch: 32	Batch: 450	Avg-Loss: 0.0939	Training Accuracy : 0.9772
# Epoch: 32	Batch: 500	Avg-Loss: 0.1007	Training Accuracy : 0.9753
# Epoch: 32	Batch: 550	Avg-Loss: 0.0928	Training Accuracy : 0.9767
# Epoch: 32	Batch: 600	Avg-Loss: 0.1005	Training Accuracy : 0.9759
# Epoch: 32	Batch: 650	Avg-Loss: 0.0963	Training Accuracy : 0.9770
# Epoch: 32, Validation Loss: 5.296, Validation Accuracy: 0.271
# Epoch: 33	Batch: 50	Avg-Loss: 0.0973	Training Accuracy : 0.9764
# Epoch: 33	Batch: 100	Avg-Loss: 0.0898	Training Accuracy : 0.9783
# Epoch: 33	Batch: 150	Avg-Loss: 0.0923	Training Accuracy : 0.9775
# Epoch: 33	Batch: 200	Avg-Loss: 0.0921	Training Accuracy : 0.9769
# Epoch: 33	Batch: 250	Avg-Loss: 0.0861	Training Accuracy : 0.9797
# Epoch: 33	Batch: 300	Avg-Loss: 0.0928	Training Accuracy : 0.9767
# Epoch: 33	Batch: 350	Avg-Loss: 0.0912	Training Accuracy : 0.9772
# Epoch: 33	Batch: 400	Avg-Loss: 0.0944	Training Accuracy : 0.9769
# Epoch: 33	Batch: 450	Avg-Loss: 0.1024	Training Accuracy : 0.9717
# Epoch: 33	Batch: 500	Avg-Loss: 0.0984	Training Accuracy : 0.9750
# Epoch: 33	Batch: 550	Avg-Loss: 0.0828	Training Accuracy : 0.9800
# Epoch: 33	Batch: 600	Avg-Loss: 0.0822	Training Accuracy : 0.9803
# Epoch: 33	Batch: 650	Avg-Loss: 0.0893	Training Accuracy : 0.9788
# Epoch: 33, Validation Loss: 5.198, Validation Accuracy: 0.271
# Epoch: 34	Batch: 50	Avg-Loss: 0.0772	Training Accuracy : 0.9817
# Epoch: 34	Batch: 100	Avg-Loss: 0.0853	Training Accuracy : 0.9802
# Epoch: 34	Batch: 150	Avg-Loss: 0.0848	Training Accuracy : 0.9798
# Epoch: 34	Batch: 200	Avg-Loss: 0.0913	Training Accuracy : 0.9772
# Epoch: 34	Batch: 250	Avg-Loss: 0.0908	Training Accuracy : 0.9762
# Epoch: 34	Batch: 300	Avg-Loss: 0.0834	Training Accuracy : 0.9803
# Epoch: 34	Batch: 350	Avg-Loss: 0.0853	Training Accuracy : 0.9798
# Epoch: 34	Batch: 400	Avg-Loss: 0.0899	Training Accuracy : 0.9772
# Epoch: 34	Batch: 450	Avg-Loss: 0.0898	Training Accuracy : 0.9770
# Epoch: 34	Batch: 500	Avg-Loss: 0.0881	Training Accuracy : 0.9770
# Epoch: 34	Batch: 550	Avg-Loss: 0.0920	Training Accuracy : 0.9791
# Epoch: 34	Batch: 600	Avg-Loss: 0.0990	Training Accuracy : 0.9745
# Epoch: 34	Batch: 650	Avg-Loss: 0.0913	Training Accuracy : 0.9775
# Epoch    35: reducing learning rate of group 0 to 1.9531e-04.
# Epoch: 34, Validation Loss: 5.283, Validation Accuracy: 0.272
# Epoch: 35	Batch: 50	Avg-Loss: 0.0875	Training Accuracy : 0.9788
# Epoch: 35	Batch: 100	Avg-Loss: 0.0882	Training Accuracy : 0.9761
# Epoch: 35	Batch: 150	Avg-Loss: 0.0731	Training Accuracy : 0.9823
# Epoch: 35	Batch: 200	Avg-Loss: 0.0897	Training Accuracy : 0.9780
# Epoch: 35	Batch: 250	Avg-Loss: 0.0773	Training Accuracy : 0.9808
# Epoch: 35	Batch: 300	Avg-Loss: 0.0806	Training Accuracy : 0.9816
# Epoch: 35	Batch: 350	Avg-Loss: 0.0954	Training Accuracy : 0.9767
# Epoch: 35	Batch: 400	Avg-Loss: 0.0801	Training Accuracy : 0.9808
# Epoch: 35	Batch: 450	Avg-Loss: 0.0864	Training Accuracy : 0.9781
# Epoch: 35	Batch: 500	Avg-Loss: 0.0737	Training Accuracy : 0.9814
# Epoch: 35	Batch: 550	Avg-Loss: 0.0836	Training Accuracy : 0.9798
# Epoch: 35	Batch: 600	Avg-Loss: 0.0799	Training Accuracy : 0.9817
# Epoch: 35	Batch: 650	Avg-Loss: 0.0817	Training Accuracy : 0.9809
# Epoch: 35, Validation Loss: 5.248, Validation Accuracy: 0.271
# Epoch: 36	Batch: 50	Avg-Loss: 0.0834	Training Accuracy : 0.9798
# Epoch: 36	Batch: 100	Avg-Loss: 0.0799	Training Accuracy : 0.9805
# Epoch: 36	Batch: 150	Avg-Loss: 0.0833	Training Accuracy : 0.9805
# Epoch: 36	Batch: 200	Avg-Loss: 0.0802	Training Accuracy : 0.9812
# Epoch: 36	Batch: 250	Avg-Loss: 0.0840	Training Accuracy : 0.9781
# Epoch: 36	Batch: 300	Avg-Loss: 0.0913	Training Accuracy : 0.9778
# Epoch: 36	Batch: 350	Avg-Loss: 0.0768	Training Accuracy : 0.9822
# Epoch: 36	Batch: 400	Avg-Loss: 0.0866	Training Accuracy : 0.9788
# Epoch: 36	Batch: 450	Avg-Loss: 0.0736	Training Accuracy : 0.9823
# Epoch: 36	Batch: 500	Avg-Loss: 0.0769	Training Accuracy : 0.9819
# Epoch: 36	Batch: 550	Avg-Loss: 0.0672	Training Accuracy : 0.9848
# Epoch: 36	Batch: 600	Avg-Loss: 0.0782	Training Accuracy : 0.9778
# Epoch: 36	Batch: 650	Avg-Loss: 0.0932	Training Accuracy : 0.9764
# Epoch: 36, Validation Loss: 5.406, Validation Accuracy: 0.272
# Epoch: 37	Batch: 50	Avg-Loss: 0.0806	Training Accuracy : 0.9802
# Epoch: 37	Batch: 100	Avg-Loss: 0.0795	Training Accuracy : 0.9809
# Epoch: 37	Batch: 150	Avg-Loss: 0.0754	Training Accuracy : 0.9816
# Epoch: 37	Batch: 200	Avg-Loss: 0.0702	Training Accuracy : 0.9828
# Epoch: 37	Batch: 250	Avg-Loss: 0.0822	Training Accuracy : 0.9811
# Epoch: 37	Batch: 300	Avg-Loss: 0.0774	Training Accuracy : 0.9798
# Epoch: 37	Batch: 350	Avg-Loss: 0.0871	Training Accuracy : 0.9791
# Epoch: 37	Batch: 400	Avg-Loss: 0.0802	Training Accuracy : 0.9809
# Epoch: 37	Batch: 450	Avg-Loss: 0.0836	Training Accuracy : 0.9783
# Epoch: 37	Batch: 500	Avg-Loss: 0.0744	Training Accuracy : 0.9828
# Epoch: 37	Batch: 550	Avg-Loss: 0.0816	Training Accuracy : 0.9808
# Epoch: 37	Batch: 600	Avg-Loss: 0.0821	Training Accuracy : 0.9805
# Epoch: 37	Batch: 650	Avg-Loss: 0.0814	Training Accuracy : 0.9798
# Epoch    38: reducing learning rate of group 0 to 9.7656e-05.
# Epoch: 37, Validation Loss: 5.318, Validation Accuracy: 0.271
# Epoch: 38	Batch: 50	Avg-Loss: 0.0790	Training Accuracy : 0.9800
# Epoch: 38	Batch: 100	Avg-Loss: 0.0770	Training Accuracy : 0.9823
# Epoch: 38	Batch: 150	Avg-Loss: 0.0748	Training Accuracy : 0.9828
# Epoch: 38	Batch: 200	Avg-Loss: 0.0786	Training Accuracy : 0.9800
# Epoch: 38	Batch: 250	Avg-Loss: 0.0807	Training Accuracy : 0.9811
# Epoch: 38	Batch: 300	Avg-Loss: 0.0764	Training Accuracy : 0.9820
# Epoch: 38	Batch: 350	Avg-Loss: 0.0741	Training Accuracy : 0.9825
# Epoch: 38	Batch: 400	Avg-Loss: 0.0801	Training Accuracy : 0.9805
# Epoch: 38	Batch: 450	Avg-Loss: 0.0819	Training Accuracy : 0.9803
# Epoch: 38	Batch: 500	Avg-Loss: 0.0781	Training Accuracy : 0.9811
# Epoch: 38	Batch: 550	Avg-Loss: 0.0825	Training Accuracy : 0.9791
# Epoch: 38	Batch: 600	Avg-Loss: 0.0815	Training Accuracy : 0.9800
# Epoch: 38	Batch: 650	Avg-Loss: 0.0714	Training Accuracy : 0.9839
# Epoch: 38, Validation Loss: 5.244, Validation Accuracy: 0.270
# Epoch: 39	Batch: 50	Avg-Loss: 0.0785	Training Accuracy : 0.9817
# Epoch: 39	Batch: 100	Avg-Loss: 0.0837	Training Accuracy : 0.9784
# Epoch: 39	Batch: 150	Avg-Loss: 0.0783	Training Accuracy : 0.9798
# Epoch: 39	Batch: 200	Avg-Loss: 0.0773	Training Accuracy : 0.9814
# Epoch: 39	Batch: 250	Avg-Loss: 0.0823	Training Accuracy : 0.9798
# Epoch: 39	Batch: 300	Avg-Loss: 0.0744	Training Accuracy : 0.9817
# Epoch: 39	Batch: 350	Avg-Loss: 0.0701	Training Accuracy : 0.9838
# Epoch: 39	Batch: 400	Avg-Loss: 0.0809	Training Accuracy : 0.9805
# Epoch: 39	Batch: 450	Avg-Loss: 0.0714	Training Accuracy : 0.9842
# Epoch: 39	Batch: 500	Avg-Loss: 0.0731	Training Accuracy : 0.9836
# Epoch: 39	Batch: 550	Avg-Loss: 0.0785	Training Accuracy : 0.9808
# Epoch: 39	Batch: 600	Avg-Loss: 0.0826	Training Accuracy : 0.9795
# Epoch: 39	Batch: 650	Avg-Loss: 0.0718	Training Accuracy : 0.9820
# Epoch: 39, Validation Loss: 5.238, Validation Accuracy: 0.270
# Epoch: 40	Batch: 50	Avg-Loss: 0.0730	Training Accuracy : 0.9839
# Epoch: 40	Batch: 100	Avg-Loss: 0.0743	Training Accuracy : 0.9819
# Epoch: 40	Batch: 150	Avg-Loss: 0.0709	Training Accuracy : 0.9825
# Epoch: 40	Batch: 200	Avg-Loss: 0.0656	Training Accuracy : 0.9850
# Epoch: 40	Batch: 250	Avg-Loss: 0.0759	Training Accuracy : 0.9830
# Epoch: 40	Batch: 300	Avg-Loss: 0.0758	Training Accuracy : 0.9806
# Epoch: 40	Batch: 350	Avg-Loss: 0.0767	Training Accuracy : 0.9809
# Epoch: 40	Batch: 400	Avg-Loss: 0.0707	Training Accuracy : 0.9842
# Epoch: 40	Batch: 450	Avg-Loss: 0.0798	Training Accuracy : 0.9831
# Epoch: 40	Batch: 500	Avg-Loss: 0.0849	Training Accuracy : 0.9778
# Epoch: 40	Batch: 550	Avg-Loss: 0.0748	Training Accuracy : 0.9817
# Epoch: 40	Batch: 600	Avg-Loss: 0.0805	Training Accuracy : 0.9806
# Epoch: 40	Batch: 650	Avg-Loss: 0.0775	Training Accuracy : 0.9791
# Epoch    41: reducing learning rate of group 0 to 4.8828e-05.
# Epoch: 40, Validation Loss: 5.314, Validation Accuracy: 0.269
# Epoch: 41	Batch: 50	Avg-Loss: 0.0735	Training Accuracy : 0.9833
# Epoch: 41	Batch: 100	Avg-Loss: 0.0732	Training Accuracy : 0.9811
# Epoch: 41	Batch: 150	Avg-Loss: 0.0803	Training Accuracy : 0.9802
# Epoch: 41	Batch: 200	Avg-Loss: 0.0701	Training Accuracy : 0.9831
# Epoch: 41	Batch: 250	Avg-Loss: 0.0705	Training Accuracy : 0.9830
# Epoch: 41	Batch: 300	Avg-Loss: 0.0747	Training Accuracy : 0.9823
# Epoch: 41	Batch: 350	Avg-Loss: 0.0698	Training Accuracy : 0.9831
# Epoch: 41	Batch: 400	Avg-Loss: 0.0774	Training Accuracy : 0.9825
# Epoch: 41	Batch: 450	Avg-Loss: 0.0756	Training Accuracy : 0.9803
# Epoch: 41	Batch: 500	Avg-Loss: 0.0802	Training Accuracy : 0.9783
# Epoch: 41	Batch: 550	Avg-Loss: 0.0691	Training Accuracy : 0.9833
# Epoch: 41	Batch: 600	Avg-Loss: 0.0711	Training Accuracy : 0.9836
# Epoch: 41	Batch: 650	Avg-Loss: 0.0824	Training Accuracy : 0.9791
# Epoch: 41, Validation Loss: 5.283, Validation Accuracy: 0.271
# Epoch: 42	Batch: 50	Avg-Loss: 0.0723	Training Accuracy : 0.9823
# Epoch: 42	Batch: 100	Avg-Loss: 0.0694	Training Accuracy : 0.9858
# Epoch: 42	Batch: 150	Avg-Loss: 0.0739	Training Accuracy : 0.9828
# Epoch: 42	Batch: 200	Avg-Loss: 0.0666	Training Accuracy : 0.9838
# Epoch: 42	Batch: 250	Avg-Loss: 0.0738	Training Accuracy : 0.9822
# Epoch: 42	Batch: 300	Avg-Loss: 0.0784	Training Accuracy : 0.9795
# Epoch: 42	Batch: 350	Avg-Loss: 0.0797	Training Accuracy : 0.9794
# Epoch: 42	Batch: 400	Avg-Loss: 0.0723	Training Accuracy : 0.9823
# Epoch: 42	Batch: 450	Avg-Loss: 0.0655	Training Accuracy : 0.9853
# Epoch: 42	Batch: 500	Avg-Loss: 0.0743	Training Accuracy : 0.9817
# Epoch: 42	Batch: 550	Avg-Loss: 0.0725	Training Accuracy : 0.9828
# Epoch: 42	Batch: 600	Avg-Loss: 0.0693	Training Accuracy : 0.9841
# Epoch: 42	Batch: 650	Avg-Loss: 0.0753	Training Accuracy : 0.9800
# Epoch: 42, Validation Loss: 5.287, Validation Accuracy: 0.271
# Epoch: 43	Batch: 50	Avg-Loss: 0.0734	Training Accuracy : 0.9838
# Epoch: 43	Batch: 100	Avg-Loss: 0.0758	Training Accuracy : 0.9823
# Epoch: 43	Batch: 150	Avg-Loss: 0.0676	Training Accuracy : 0.9848
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-fa5d4302f62f> in <module>()
#      16
#      17         loss = criterion(outputs, y.long())
# ---> 18         loss.backward()
#      19         optimizer.step()
#      20         avg_loss += loss.item()
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     157
#     158
#
# KeyboardInterrupt:

# %%
torch.save(network.state_dict(), "/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet/model_43.pt")

# %%
import gc
gc.collect()
torch.cuda.empty_cache()

# %%
# !nvidia-smi
# Out:
# Fri Nov 26 18:24:24 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P0    56W / 250W |   7597MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from tqdm import tqdm

# %%
network = ClassificationNetwork(in_features, embedding, num_classes)
network.load_state_dict(torch.load("/content/gdrive/MyDrive/dl_project/model_checkpoints/regnet/best_model.pt"))
network = network.to(device)

# %%
network.eval()
num_correct = 0
for x, y in tqdm(test_loader):
  x, y = x.to(device), y.to(device)
  outputs = network(x)
  num_correct += (torch.argmax(outputs, axis=1) == y).sum().item()

test_acc = num_correct / len(test_set)
print(test_acc)
# Out:
# 100%|██████████| 141/141 [01:36<00:00,  1.46it/s]
# 0.247840864768485

# %%
print(test_acc)
# Out:
# 0.247840864768485
